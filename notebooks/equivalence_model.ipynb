# %%
import pandas as pd
import numpy as np
import torch

# %%
# Load entities (5500)
entities = pd.read_csv('../data/Entities/SingleToken/entities_languageAgnostic_clean.csv')

# Load Relations (60)
relations = pd.read_csv('../data/Relations/Equivalence/equivalence_en_de.csv')

# %%
relations_general = pd.read_csv('../data/Relations/General/properties_nonsymmetric_multilingual_clean.csv')

# %%
relations = relations.rename(columns={'label': 'label_en', 'alias': 'alias_en'})
relations
# Out:
#        _id               label_en               alias_en             label_de  \
# 0    P1034       main food source                   eats  Hauptnahrungsquelle
# 1     P457      foundational text  establishing document            Grundtext
# 2    P1366            replaced by           succeeded by        ersetzt durch
# 3     P740  location of formation             founded in   Ort der Entstehung
# 4    P1817              addressee                sent to             Adressat
# ..     ...                    ...                    ...                  ...
# 292    P86               composer            composed by            Komponist
# 293  P7047               enemy of            opponent of            Feind von
# 294  P8627           closing time              closes at          Schließzeit
# 295  P2770       source of income          income source     Einkommensquelle
# 296  P4794          season starts          season begins       Saison startet
#
#                alias_de
# 0                  isst
# 1     Gründungsdokument
# 2           gefolgt von
# 3          gegründet in
# 4           gesendet an
# ..                  ...
# 292      komponiert von
# 293          Gegner von
# 294      Geschlossen um
# 295  Einkommensherkunft
# 296      Saison beginnt
#
# [297 rows x 5 columns]

# %% [markdown]
# ##### Prepare Data

# %%
import random

# prob of returning true
def decision(probability):
    return random.random() < probability

# %%
# Generate random pairs of numbers (indices into entity)
# Order doesn't matter, can't repeat
# i.e. ok is: (0,1), (1,2), (0,2) but not ok is (0,1),(1,0) or (0,0)
# Runs until exhausted or reached max_size
# possible to limit occurences of index
def gen_index_pairs(n, max_size=np.Inf, limit=np.Inf):
    pairs = set()
    ind = list()

    while len(pairs) < max_size:
        # return number between 0 and n (exclude), where n is max num entities
        x, y = np.random.randint(n), np.random.randint(n)
        
        while ind.count(x) >= limit or ind.count(y) >= limit:
            x, y = np.random.randint(n), np.random.randint(n)

        i = 0
        while (x, y) in pairs or (y, x) in pairs or x == y:
            if i > 10:
                return
            x, y = np.random.randint(n), np.random.randint(n)
            i += 1

        ind.append(x)
        ind.append(y)
            
        pairs.add((x, y))
        yield x, y

# %%
source_lang = 'en'
target_lang = 'de'

n_relations = 20
n_facts = 1000

# train/test: (e, r, f ), (e, s, f) (e, r_de, f), (e, s_de, f)
train = []
test = []

# Sample relations
relations_sampled = relations.sample(n_relations)

for index, relation in relations_sampled.iterrows():

    # Sample random entities
    entity_generator = gen_index_pairs(entities.shape[0], n_facts, 1)

    for e_id, f_id in entity_generator:
        e = entities['label'][e_id]
        f = entities['label'][f_id]

        train.append(e + ' ' + relation['label_' + source_lang] + ' ' + f)
        test.append(e + ' ' + relation['alias_' + target_lang] + ' ' + f)
        
#         flip = random.choice([0, 1])
        
#         if flip == 1:
#             train.append(e + ' ' + relation['label_' + target_lang] + ' ' + f)
#             test.append(e + ' ' + relation['alias_' + target_lang] + ' ' + f)
#         else:
#             train.append(e + ' ' + relation['alias_' + target_lang] + ' ' + f)
#             test.append(e + ' ' + relation['label_' + target_lang] + ' ' + f)

# %%
train
# Out:
# ['Valentine translator Das',
#  'Raum translator IPAC',
#  'Leif translator Mans',
#  'Tiene translator Rule',
#  'Demi translator Halen',
#  'Vana translator Classic',
#  'Branko translator Freeman',
#  'Scarlett translator Filadelfia',
#  'ACM translator Musée',
#  'Hilaire translator Nadu',
#  'Fritz translator Público',
#  'Bolívar translator Euro',
#  'Testament translator Dorothy',
#  'Steiner translator Bruno',
#  'Shift translator Zion',
#  'Alexandria translator Ryan',
#  'Orta translator Ethel',
#  'Rang translator Meredith',
#  'Cafe translator Giang',
#  'Fiction translator Thing',
#  'UA translator Dickson',
#  'Cá translator Chloe',
#  'Emerson translator Bodø',
#  'Sir translator Dentro',
#  'Dillon translator Clive',
#  'Reason translator Priest',
#  'Opera translator Vol',
#  'Ruben translator Town',
#  'Orchestra translator Rail',
#  'Russen translator Bursa',
#  'Mat translator Poola',
#  'Sien translator Attack',
#  'ur translator Gutenberg',
#  'Mackenzie translator Enemy',
#  'Stad translator Schuster',
#  'Calais translator Vettel',
#  'Antwerpen translator Vela',
#  'Welt translator Laura',
#  'Byl translator Schmid',
#  'Texas translator Longchamp',
#  'Zurich translator Speedway',
#  'NF translator Salvia',
#  'Jepang translator Voice',
#  'WM translator Iris',
#  'Hütte translator Ice',
#  'Kuna translator Plus',
#  'Cheshire translator Dracula',
#  'Monsters translator Oklahoma',
#  'Basin translator Sowerwine',
#  'MBA translator Sabha',
#  'Nacht translator Bretagne',
#  'Catalunya translator Neubau',
#  'Urgell translator Europa',
#  'Kimberly translator Rogers',
#  'Gert translator Pe',
#  'McKenzie translator Enigma',
#  'Pieces translator België',
#  'Reihe translator Purcell',
#  'Neki translator Gales',
#  'City translator Jennings',
#  'Minas translator Bund',
#  'Bland translator Sophia',
#  'Faso translator Flow',
#  'CJ translator Borges',
#  'Dat translator Ost',
#  'Branca translator Slovak',
#  'Pat translator Business',
#  'Kaisers translator Amb',
#  'Joanne translator Memoria',
#  'Portrait translator Dominic',
#  'Ronaldo translator Command',
#  'Sullivan translator Labrador',
#  'Odd translator Nino',
#  'ge translator Liang',
#  'Vries translator UAE',
#  'Maxi translator Eliza',
#  'NN translator Korn',
#  'Tale translator Ky',
#  'Voda translator Interactive',
#  'Pluto translator Zeus',
#  'Shining translator Weir',
#  'Pub translator Door',
#  'Tobias translator Borbón',
#  'Ars translator Johansen',
#  'Certain translator Fever',
#  'Stab translator Zelanda',
#  'Usa translator Puglia',
#  'Pam translator Florence',
#  'Norway translator Mesto',
#  'BRT translator Aid',
#  'Correa translator Niko',
#  'Afro translator VF',
#  'ras translator Harding',
#  'Pac translator EUA',
#  'Data translator Arm',
#  'Elba translator Buch',
#  'Mayr translator Kaune',
#  'Cochrane translator Marianne',
#  'Barbara translator Archer',
#  'Siemens translator Vegas',
#  'Libération translator Pavia',
#  'Moldova translator Lunar',
#  'Cidade translator Azul',
#  'Pain translator Westwood',
#  'Atelier translator Brunswick',
#  'Eo translator Lancaster',
#  'Vogue translator Steel',
#  'Denne translator Acre',
#  'Garfield translator Römer',
#  'Dharma translator Dok',
#  'NS translator Darkness',
#  'Serena translator Ibiza',
#  'Volk translator Cornwall',
#  'Fuchs translator MJ',
#  'Gonçalves translator TD',
#  'Racine translator DP',
#  'Stig translator Osiris',
#  'Bola translator Minden',
#  'Gandhi translator IPA',
#  'Bulgaria translator Foi',
#  'Discovery translator Italiana',
#  'Self translator Tyrone',
#  'Lola translator Ravenna',
#  'Sama translator Webster',
#  'Frères translator PS',
#  'MIT translator Sao',
#  'Figur translator Petersburg',
#  'Mahler translator Péter',
#  'Elliott translator Deer',
#  'Aby translator Venus',
#  'Portland translator Mariano',
#  'Goebbels translator Kiel',
#  'Salix translator Trento',
#  'Qua translator Pál',
#  'Cole translator Whitaker',
#  'UCD translator Jason',
#  'Bartlett translator Wever',
#  'Trust translator Savage',
#  'Tempo translator Travis',
#  'Penn translator can',
#  'Valdés translator Regional',
#  'Simpson translator rs',
#  'Ivana translator Segura',
#  'Noch translator Complete',
#  'Vai translator Erfurt',
#  'Woodward translator Allier',
#  'Sint translator Esther',
#  'Salerno translator FDP',
#  'Así translator Britney',
#  'Soleil translator Charleston',
#  'Showtime translator Urbana',
#  'USC translator NP',
#  'Bab translator Infinity',
#  'Alta translator Revue',
#  'Heroes translator Mortimer',
#  'KS translator Marne',
#  'Abdullah translator Ara',
#  'Trieste translator Sinai',
#  'Indy translator Beloe',
#  'Evan translator Henrik',
#  'GC translator Conte',
#  'Slovakia translator Birch',
#  'Les translator Palm',
#  'Challenger translator Ulster',
#  'Begin translator Pet',
#  'Nantes translator Osborne',
#  'Bullet translator Esta',
#  'Kraft translator Mondadori',
#  'Uruguay translator ISS',
#  'Oslo translator Kennedy',
#  'Michel translator Fiat',
#  'Bara translator McGregor',
#  'Santander translator Seda',
#  'Roche translator Jacqueline',
#  'Mao translator Fell',
#  'Rochefort translator Gaius',
#  'Bruxelles translator Sai',
#  'Een translator Authority',
#  'Nora translator Brief',
#  'Freie translator Kirby',
#  'Gets translator Arc',
#  'Governor translator Hartley',
#  'Arabian translator Marais',
#  'Avant translator Heritage',
#  'Socorro translator Thiên',
#  'Exclusive translator Abbey',
#  'Airport translator Scream',
#  'Rathaus translator Angels',
#  'Han translator Urbino',
#  'Caesar translator Marca',
#  'Kjell translator WWF',
#  'Einer translator Yi',
#  'Om translator Graves',
#  'Varese translator Beyond',
#  'Abel translator Brill',
#  'Amerika translator Prensa',
#  'Chase translator Selma',
#  'Nolan translator Suba',
#  'Sloan translator Honour',
#  'Notice translator ABD',
#  'Hopper translator Ariège',
#  'Gromada translator Emily',
#  'Watson translator MS',
#  'Fischer translator Junta',
#  'Goodman translator Eure',
#  'Russia translator Oceania',
#  'Lieutenant translator Viscount',
#  'IRAS translator Aves',
#  'Ireland translator Snyder',
#  'Bahari translator Giles',
#  'Rapport translator Salzburg',
#  'Naga translator Honoré',
#  'Pool translator Ducks',
#  'Fleming translator Epic',
#  'Macedonia translator Dara',
#  'Mirror translator Lingua',
#  'Mora translator Ela',
#  'Ros translator Mille',
#  'Carol translator UCI',
#  'Browns translator Yayasan',
#  'Rams translator RFC',
#  'Bahasa translator SED',
#  'Country translator Cary',
#  'Islandia translator Firefox',
#  'Engine translator Quebec',
#  'Volume translator Am',
#  'Pamela translator Garde',
#  'Porta translator Siena',
#  'Palo translator Ta',
#  'Ar translator Ilona',
#  'Lagrange translator Dessa',
#  'Hatch translator Asunción',
#  'Panel translator Seed',
#  'Liga translator Ga',
#  'Hidalgo translator Agent',
#  'States translator Pendant',
#  'Yahoo translator Christophe',
#  'Hollande translator UHF',
#  'Chance translator Leuven',
#  'Lys translator KHL',
#  'Starr translator Obra',
#  'Panther translator Vengeance',
#  'Series translator Quantum',
#  'Reine translator Mega',
#  'Male translator Bonaparte',
#  'McKamey translator Zone',
#  'Kenneth translator Vivian',
#  'Magdalena translator Levine',
#  'Richards translator Gironde',
#  'Underwood translator Kantonen',
#  'Kansas translator Kenia',
#  'Contra translator Colbert',
#  'Modena translator Florencia',
#  'Area translator Parade',
#  'Cindy translator Choice',
#  'us translator Carnegie',
#  'Jericho translator Anfang',
#  'Eun translator Bolivia',
#  'Illinois translator IBM',
#  'Water translator Nos',
#  'Cham translator Phelps',
#  'Investment translator Missouri',
#  'Cap translator Président',
#  'Royal translator Seri',
#  'Northampton translator GPL',
#  'Western translator Isabel',
#  'Thomas translator Spot',
#  'Re translator Active',
#  'EF translator Brazil',
#  'Special translator Ny',
#  'Atas translator Österreich',
#  'Temps translator Garden',
#  'Neuchâtel translator ao',
#  'Castilla translator Cure',
#  'Zoltán translator KM',
#  'Pagal translator Gunung',
#  'Chief translator Dichter',
#  'Kendall translator Tax',
#  'Czech translator Grave',
#  'TB translator Falcon',
#  'Damit translator Oko',
#  'Pampa translator Drum',
#  'Rooma translator Resurrection',
#  'Boyle translator ES',
#  'CSS translator Goes',
#  'Pel translator Indie',
#  'Wanda translator Barn',
#  'Larson translator Frente',
#  'Champs translator Faber',
#  'VA translator Elmi',
#  'Rond translator Abdel',
#  'RJ translator Dayton',
#  'Rome translator Pode',
#  'Fargo translator Diaz',
#  'Magnum translator Bohemia',
#  'CK translator Buckley',
#  'Each translator Survival',
#  'Aa translator Peso',
#  'Krishna translator Fiesta',
#  'Bavaria translator Kamera',
#  'Clair translator Weiß',
#  'Tode translator Corso',
#  'Muslimani translator Berry',
#  'Spitze translator Mission',
#  'Guzmán translator Od',
#  'Mill translator Griffith',
#  'Came translator Mint',
#  'Web translator Tanner',
#  'Kari translator Shakespeare',
#  'Keller translator Bock',
#  'Chorus translator Faro',
#  'Bowman translator Gomes',
#  'Snake translator Talbot',
#  'Fork translator Coach',
#  'Benjamin translator Nicholson',
#  'Warren translator Tin',
#  'Gallimard translator RM',
#  'Titus translator Botafogo',
#  'Smoke translator Adobe',
#  'Milli translator Punk',
#  'Vizcaya translator ET',
#  'Brooks translator Hang',
#  'Saints translator Johnson',
#  'Rom translator Gruyter',
#  'Namur translator Commonwealth',
#  'Heidi translator Cats',
#  'Atom translator ABS',
#  'Puebla translator Farrell',
#  'Belfast translator Monate',
#  'PP translator jet',
#  'Global translator Bere',
#  'Peer translator Minister',
#  'Côte translator Prescott',
#  'Gertrude translator Fou',
#  'ag translator Champions',
#  'Milano translator Montenegro',
#  'McDowell translator BS',
#  'Hercules translator Doom',
#  'Morgen translator Allison',
#  'Hum translator Posten',
#  'Ebert translator KPD',
#  'Sailor translator Studium',
#  'Tina translator Field',
#  'Bayer translator Nihon',
#  'Passau translator Melody',
#  'Smash translator Tage',
#  'Shackleton translator Mosca',
#  'Denna translator Bos',
#  'Grass translator Elbe',
#  'Allah translator Zoo',
#  'Copenhagen translator Dix',
#  'Yorkshire translator Els',
#  'Scott translator École',
#  'Hepburn translator Truth',
#  'Boo translator stb',
#  'Lil translator Triumph',
#  'Vanderbilt translator Apache',
#  'Exodus translator Province',
#  'Bride translator Suomi',
#  'Hanna translator Agnes',
#  'Animal translator Civil',
#  'Master translator Vive',
#  'Twilight translator Campania',
#  'Monat translator Pan',
#  'Flavius translator Vidal',
#  'Walther translator Payne',
#  'Cha translator Ages',
#  'Matthews translator Frank',
#  'Damon translator Palestina',
#  'Männchen translator Amigos',
#  'Wenn translator Ramsey',
#  'Instruments translator NDR',
#  'Bosch translator Arrow',
#  'HD translator Vieira',
#  'Ventura translator Maynard',
#  'Spiel translator Otte',
#  'Stal translator SP',
#  'Detroit translator GMA',
#  'National translator Masse',
#  'Magister translator Somerset',
#  'Ghosts translator Jump',
#  'Bonnet translator Commander',
#  'Mineral translator Cyber',
#  'Chaplin translator Emergency',
#  'Weaver translator Auvergne',
#  'Norte translator Neckar',
#  'Holden translator Trade',
#  'Verne translator Lewis',
#  'EE translator Turin',
#  'HF translator Quito',
#  'Malta translator Asylum',
#  'Fayette translator Canada',
#  'Rok translator Primera',
#  'Egg translator Billy',
#  'Arizona translator Bourbon',
#  'Planet translator Ghost',
#  'Bunker translator Mother',
#  'Rec translator Ocak',
#  'Cine translator Gospel',
#  'Jackson translator PE',
#  'Paso translator Langley',
#  'Concord translator IX',
#  'Guru translator Landing',
#  'Zwar translator nt',
#  'Vertreter translator Mil',
#  'Vita translator Cullen',
#  'Wendy translator Despois',
#  'Nieto translator Warwick',
#  'Mondo translator Sra',
#  'Holland translator Astana',
#  'Mutter translator Pitt',
#  'Fox translator Camden',
#  'Genet translator Finch',
#  'Quatre translator Kim',
#  'Karls translator Nancy',
#  'Perry translator Ayala',
#  'Sandra translator Greenwood',
#  'Dewi translator Nello',
#  'WP translator Gender',
#  'Transit translator Congo',
#  'Sân translator Summer',
#  'Jesu translator Henry',
#  'Carrera translator Boris',
#  'Monika translator Volley',
#  'ARM translator Wien',
#  'Welch translator Tonight',
#  'Vockeroth translator Breizh',
#  'Linus translator Debussy',
#  'Sari translator Rua',
#  'Sherman translator Della',
#  'Oost translator Rabbit',
#  'Simpsons translator Nissan',
#  'Finger translator Marina',
#  'Rabat translator Cody',
#  'Mister translator Horse',
#  'GRN translator Bala',
#  'Wege translator Pierce',
#  'CDU translator Rumble',
#  'Pilar translator Sanctuary',
#  'Steam translator Nagasaki',
#  'Faz translator Biewer',
#  'Wes translator Setiap',
#  'Sprint translator Leslie',
#  'Hand translator Apple',
#  'Norfolk translator Card',
#  'Van translator Mana',
#  'Mode translator Tank',
#  'Alexa translator Memento',
#  'Köppen translator Nathalie',
#  'Speyer translator Bil',
#  'Occitanie translator Omaha',
#  'Salta translator Katarina',
#  'Zu translator Tiempo',
#  'Casa translator Mound',
#  'Lincolnshire translator Harvest',
#  'Hampton translator Nil',
#  'Dalai translator Rachel',
#  'Mabel translator Marks',
#  'Campione translator Brunnen',
#  'Li translator Max',
#  'extremo translator Alcalá',
#  'Edison translator Palencia',
#  'Hartford translator Lara',
#  'Otis translator Amber',
#  'Deux translator Edgar',
#  'Front translator Lost',
#  'Dins translator PGC',
#  'BB translator Roca',
#  'Grimm translator Edwards',
#  'Union translator Richelieu',
#  'Ministro translator Harper',
#  'XII translator SNP',
#  'Danubio translator Cerca',
#  'Samoa translator Vega',
#  'Britten translator Greenwich',
#  'Christopher translator Hamar',
#  'Sound translator Beer',
#  'Shadow translator Breda',
#  'Harmony translator Ripley',
#  'Storm translator Jahn',
#  'AP translator ML',
#  'Hanau translator Panda',
#  'Expo translator Chapman',
#  'Piero translator PCI',
#  'Mendelssohn translator Hip',
#  'Services translator Phillips',
#  'Amiga translator Flamengo',
#  'Kassel translator Kati',
#  'Timo translator Ulm',
#  'Kemp translator Fairmaire',
#  'Cabinet translator Martel',
#  'Genel translator Imperi',
#  'Züge translator Jerusalén',
#  'CE translator Jensen',
#  'Hamlet translator PC',
#  'Madeleine translator Trees',
#  'Cuenca translator Fram',
#  'Montreux translator Sheffield',
#  'Thompson translator Nicolaus',
#  'Ira translator Noise',
#  'Ranger translator Monica',
#  'Ferguson translator Friendship',
#  'Baja translator Ace',
#  'Laba translator Boulevard',
#  'Pod translator CC',
#  'Islands translator Bulls',
#  'Kulon translator Tartu',
#  'Artemis translator Grenoble',
#  'Ruth translator Gareth',
#  'Grand translator Haley',
#  'Andrews translator Portsmouth',
#  'Johren translator Tirol',
#  'Sidney translator Bradley',
#  'Entangled translator Terminal',
#  'Cunningham translator CBN',
#  'Dal translator Fach',
#  'CP translator Devido',
#  'Link translator Constantin',
#  'Pasteur translator Cáceres',
#  'Córdoba translator Mifflin',
#  'Oliva translator am',
#  'Lights translator About',
#  'Neil translator Transfer',
#  'Castelo translator Cherokee',
#  'Sam translator Voltaire',
#  'Cour translator Jacksonville',
#  'Invasion translator Paulo',
#  'Bordeaux translator Standing',
#  'Unity translator ATM',
#  'Bonnie translator Below',
#  'UFC translator Sera',
#  'Rocks translator Jansen',
#  'Dos translator Amy',
#  'Meilleur translator Diesel',
#  'Absolute translator Chandler',
#  'Robaina translator Jerusalem',
#  'Juno translator Story',
#  'Pride translator Cast',
#  'Thor translator Davies',
#  'Bianchi translator Flying',
#  'Bellamy translator Vivaldi',
#  'GB translator Wakefield',
#  'Humboldt translator Universe',
#  'Webb translator Braga',
#  'Mater translator Marines',
#  'Fighting translator Today',
#  'Shaun translator mic',
#  'Junie translator Sarmiento',
#  'Vocal translator Cobra',
#  'Gama translator Florida',
#  'Drive translator Angelica',
#  'Essay translator Ng',
#  'Sheriff translator Suit',
#  'Heath translator Né',
#  'Quest translator Coelho',
#  'Hanson translator Geld',
#  'Murcia translator Noah',
#  'Heikki translator Joshua',
#  'Modern translator Daniela',
#  'Dana translator Wembley',
#  'Sawyer translator KK',
#  'Witness translator Dag',
#  'Netz translator Göttingen',
#  'Resident translator Za',
#  'Nexus translator String',
#  'Werner translator Sartre',
#  'Parma translator Rochelle',
#  'Dual translator Change',
#  'Olympia translator Algeria',
#  'NED translator GM',
#  'Road translator Hanover',
#  'Baltic translator Luzern',
#  'Sox translator Geiger',
#  'Stift translator Armata',
#  'Ola translator Valencia',
#  'Sunda translator Elsevier',
#  'Jill translator Dickens',
#  'Pegasus translator Baronet',
#  'Kongo translator Foundation',
#  'Wild translator Vuelta',
#  'Siria translator Bentley',
#  'Wedding translator Oaks',
#  'Renoir translator Frida',
#  'Crisis translator Prestige',
#  'Late translator Alps',
#  'Ladislav translator Daisy',
#  'Gideon translator Freiburg',
#  'ATP translator Legend',
#  'Médaille translator President',
#  'Williamson translator Narva',
#  'California translator McCarthy',
#  'Ross translator MX',
#  'Haziran translator Sar',
#  'Paderborn translator School',
#  'Sinaloa translator Delia',
#  'Durch translator Tóth',
#  'Brisbane translator Kantor',
#  'Arnold translator Weser',
#  'II translator Turquia',
#  'Kong translator Saat',
#  'Guardian translator Schleswig',
#  'Elvis translator Hie',
#  'Title translator Lynch',
#  'Alexandra translator Auf',
#  'Catalina translator Chile',
#  'Souza translator Turks',
#  'Bradford translator Devlet',
#  'Cinderella translator Julie',
#  'Sweden translator Cent',
#  'Niels translator Fort',
#  'Holloway translator Gegen',
#  'Goch translator Alexis',
#  'Flesh translator Tan',
#  'McDonald translator Bruder',
#  'Prussia translator Graz',
#  'Vatican translator Ruhr',
#  'Moro translator Affair',
#  'Sent translator Sabadell',
#  'Nag translator Bones',
#  'Winchester translator León',
#  'Eduard translator Tiberius',
#  'Musica translator Shore',
#  'Levante translator Klasse',
#  'Kohl translator Line',
#  'Baird translator Volga',
#  'Sha translator Reise',
#  'Ellington translator Sports',
#  'Lapangan translator Parco',
#  'Sylvester translator Agora',
#  'Santo translator Mariana',
#  'Marshal translator Alien',
#  'Violin translator Arthur',
#  'Turki translator Lobo',
#  'sal translator HTC',
#  'Amour translator Württemberg',
#  'Namibia translator Navy',
#  'Valverde translator Vladislav',
#  'Mimi translator AZ',
#  'Rus translator Libro',
#  'Lodi translator Verdi',
#  'Patriot translator Rhine',
#  'MBC translator Polski',
#  'Fisch translator Bender',
#  'Hansen translator Automatic',
#  'Joyce translator Bulan',
#  'Worth translator Fight',
#  'Mirage translator Nest',
#  'Druga translator ol',
#  'Remote translator Lilla',
#  'Aquino translator Cornell',
#  'Bosco translator Monkey',
#  'Zelda translator Elisabeth',
#  'Herbst translator Riva',
#  'Oxford translator Chancellor',
#  'Ugo translator Guerra',
#  'Houston translator Turbo',
#  'Remix translator Gould',
#  'PKK translator Bari',
#  'Tun translator Buffy',
#  'OS translator Ranking',
#  'Bildhauer translator Jungle',
#  'Roewer translator Cannon',
#  'Karnataka translator Senators',
#  'Clash translator Valley',
#  'Republic translator Noord',
#  'Vader translator Ninja',
#  'TT translator Ashes',
#  'Az translator Peace',
#  'MD translator Atlantic',
#  'Burlington translator Black',
#  'Lyons translator Marian',
#  'CH translator Oasis',
#  'Blanco translator Pero',
#  'Nice translator Sonja',
#  'Maire translator Martinez',
#  'Linia translator House',
#  'Meta translator Mafia',
#  'Jane translator Grosso',
#  'Kore translator Princess',
#  'Golden translator Livingston',
#  'Slot translator Fletcher',
#  'Soto translator Maranhão',
#  'VR translator Goiás',
#  'Schneider translator Akdeniz',
#  'Lehmann translator Villa',
#  'GP translator IFK',
#  'Machado translator soo',
#  'Viva translator Dow',
#  'Aria translator Gravity',
#  'Ses translator VfB',
#  'Bertrand translator Viola',
#  'Back translator Oud',
#  'Piedmont translator Bull',
#  'Alger translator Playhouse',
#  'Dolls translator Kurt',
#  'Leopard translator Cameron',
#  'Polk translator Studie',
#  'Angola translator WK',
#  'Poitou translator Alves',
#  'Melo translator Stella',
#  'Morris translator Bintang',
#  'Zbigniew translator Sol',
#  'PMC translator Check',
#  'Kelas translator Boss',
#  'Yer translator Mobile',
#  'Ricardo translator Villers',
#  'Mérida translator Mis',
#  'Welle translator Munro',
#  'Bloomberg translator Magic',
#  'Aragó translator Puis',
#  'Stamford translator Fed',
#  'Beats translator Roberts',
#  'Tesla translator Rep',
#  'Saw translator Senegal',
#  'Tampere translator NH',
#  'Wilton translator DFB',
#  'Polar translator Drama',
#  'Maxwell translator Ester',
#  'Seigneur translator Poté',
#  'Samo translator KC',
#  'Hoy translator Runde',
#  'Rather translator Sept',
#  'Duty translator Alberta',
#  'Information translator Maa',
#  'TIME translator Wiesbaden',
#  'Jones translator Bangsa',
#  'Kaufman translator Arabia',
#  'Infinite translator Pedersen',
#  'Hume translator Einstein',
#  'Ocean translator Systema',
#  'Rocket translator Ritter',
#  'Mandy translator Falun',
#  'Toulon translator Anita',
#  'Emir translator Garner',
#  'Novecento translator Phi',
#  'Sinclair translator Fulham',
#  'Jake translator Václav',
#  'Natura translator Loeb',
#  'Innocent translator Hey',
#  'Siegen translator Berna',
#  'Tao translator Moore',
#  'Francesca translator Helen',
#  'Bahn translator Esprit',
#  'Sion translator Napier',
#  'Bolt translator Torpedo',
#  'Gegner translator Aten',
#  'Hurricane translator Swansea',
#  'Shepherd translator AL',
#  'Foucault translator Fenner',
#  'Janssen translator Orte',
#  'Subway translator Hayden',
#  'Waiting translator Mircea',
#  'Chinese translator Silent',
#  'Letters translator SN',
#  'Forst translator Rayon',
#  'Bone translator at',
#  'Stay translator Orleans',
#  'Havana translator Kazimierz',
#  'Elijah translator Ut',
#  'Sand translator Hurt',
#  'Titre translator Roubaix',
#  'Delgado translator Arcade',
#  'Plans translator Paraíso',
#  'Ebben translator Basque',
#  'Lur translator Bresse',
#  'Vosges translator Egitto',
#  'Louisville translator Juara',
#  'Krieg translator Grupa',
#  'Robot translator Olímpico',
#  'oed translator Ina',
#  'EM translator Francisco',
#  'Ottawa translator Quick',
#  'Budapest translator Baza',
#  'Cook translator Fowler',
#  'Ronde translator Eternal',
#  'Sporting translator Kinos',
#  'Patria translator Humbert',
#  'Somme translator Granger',
#  'Pace translator Tales',
#  'Vizier translator Cordillera',
#  'Oleh translator Band',
#  'Access translator Orne',
#  'Batman translator Sigma',
#  'Garda translator Morley',
#  'Ribera translator Sardinia',
#  'Libertad translator Badminton',
#  'Whitman translator Hit',
#  'CW translator PL',
#  'Rembrandt translator Rusland',
#  'Rhapsody translator Freund',
#  'Victoire translator Pale',
#  'Psycho translator Kung',
#  'Arabic translator Estudiantes',
#  'Lux translator Flood',
#  'Nama translator Wagen',
#  'Somali translator Al',
#  'Aku translator Sky',
#  'Reno translator Pi',
#  'Lane translator Hidden',
#  'McLaughlin translator Peck',
#  'Dorset translator Canton',
#  'Surrey translator Vallée',
#  'Emery translator Shark',
#  'Sonny translator Senat',
#  'Nikolaj translator Reilly',
#  'Hector translator Straits',
#  'Lloyd translator Woodstock',
#  'Alpine translator Suci',
#  'Bono translator Finland',
#  'Buddy translator Karlsson',
#  'Ted translator Operator',
#  'TNA translator Artes',
#  'Virgil translator Riot',
#  'Danny translator Trap',
#  'Grâce translator Hesse',
#  'Slater translator Kobayashi',
#  'ME translator Kom',
#  'Stanton translator Artur',
#  'Rwanda translator Barrio',
#  'Roller translator Mayo',
#  'Daha translator Chef',
#  'Faces translator Aleksander',
#  'Lanka translator Valenciana',
#  'Benin translator Farmer',
#  'Winter translator Cheryl',
#  'Garland translator Cambridge',
#  'McLaren translator Feel',
#  'Teatro translator Goa',
#  'Freak translator Mailand',
#  'Canyon translator Amelia',
#  'Sidi translator Bingham',
#  'Paterson translator Mildred',
#  'Lecce translator Buzz',
#  'Helga translator Ierland',
#  'Melvin translator Atkinson',
#  'Petra translator Jesús',
#  'Cell translator MTA',
#  'Neve translator Pearl',
#  'Manual translator Cesar',
#  'Helena translator Domino',
#  'Guggenheim translator ATR',
#  'Alec translator Christmas',
#  'Verder translator Giancarlo',
#  'Sofia translator LSD',
#  'Tore translator Manconi',
#  'Castiella translator Malay',
#  'Wilson translator Bloom',
#  'Rivas translator Seychelles',
#  'Wish translator Batavia',
#  'Brandt translator ville',
#  'Coimbra translator Govern',
#  'Ajax translator Rocca',
#  'Cl translator Napoca',
#  'Diane translator Lotto',
#  'Over translator Bees',
#  'Olympique translator FIA',
#  'Bolton translator Williams',
#  'Mayer translator Judith',
#  'Danmark translator Sunset',
#  'Woods translator Thiele',
#  'Percy translator Helmut',
#  'Bachelor translator WBA',
#  'Dome translator Holy',
#  'Canis translator Danas',
#  'CR translator EC',
#  'Jesus translator Knowles',
#  'UE translator Beast',
#  'Calderón translator Khu',
#  'Roi translator Hartman',
#  'Cathedral translator Hammer',
#  'Quiet translator Battista',
#  'Bourgogne translator Gutiérrez',
#  'Gardner translator Same',
#  'Codex translator Taylor',
#  'Spice translator Erika',
#  'Cuban translator Hiroshima',
#  'Cárdenas translator Winkler',
#  'NSV translator Judy',
#  'Windsor translator Pole',
#  'Molina translator Dawn',
#  'Wittenberg translator María',
#  'Alter translator Reinhard',
#  'Katharina translator ci',
#  'Paris translator Malaya',
#  'Pike translator Serra',
#  'Margaret translator Kraj',
#  'Ipswich translator Dane',
#  'Stettin translator Coro',
#  'Dalton translator AIM',
#  'Meteor translator Soccerway',
#  'Dictionary translator September',
#  'Glory translator Dacia',
#  'Hogan translator Astra',
#  'pr translator Bukit',
#  'Fresno translator Joy',
#  'Lions translator Norma',
#  'Tema translator Ulla',
#  'SFR translator Happy',
#  'Schoolmeesters translator Vic',
#  'Melbourne translator Dora',
#  'Garrison translator ro',
#  'Fr translator Neville',
#  'Robinson translator Hunter',
#  'Tanto translator Lemon',
#  'Burg translator Randall',
#  'Francesa translator Dort',
#  'Celtic translator Records',
#  'Outlook translator Lucien',
#  'Server translator RC',
#  'Rhein translator Patrick',
#  'Llobregat translator Brighton',
#  'Wi translator Profil',
#  'Dunkerque translator Jet',
#  'Celia translator Celle',
#  'Culture translator Fel',
#  'Krista translator Gruppe',
#  'Hist translator Franken',
#  'Arcadia translator RPM',
#  'Banner translator Amsterdam',
#  'z translator Clare',
#  'Spin translator Forbes',
#  'Walsh translator Elf',
#  'Day translator Marius',
#  'Cada translator Alison',
#  'Elm translator Houten',
#  'FF translator Willis',
#  'SF translator Lili',
#  'Rebel translator MW',
#  'Sterling translator Gotham',
#  'Forma translator Higgins',
#  'Morrison translator Imperium',
#  'Safe translator Direito',
#  'Council translator Camp',
#  'Ova translator Move',
#  'Calendar translator Ka',
#  'Arsenal translator Axis',
#  'Albany translator Oltre',
#  'Lua translator Staffel',
#  'Clermont translator Sänger',
#  'FIS translator Color',
#  'Júlio translator Darin',
#  'Libre translator Zwolle',
#  'Burt translator Boeing',
#  'Giovanna translator Jørgensen',
#  'Venice translator Astor',
#  'Strand translator Suva',
#  'Brain translator Chicago',
#  'Rode translator Revolución',
#  'Treviso translator Ring',
#  'NME translator Loan',
#  'VOC translator SVT',
#  'Monmouth translator Aurora',
#  'Homer translator Milo',
#  'Opening translator Charlotte',
#  'Darat translator Dante',
#  'Shake translator Points',
#  'File translator Many',
#  'Distance translator Poet',
#  'Raden translator Dupont',
#  'Register translator Closer',
#  'Jay translator Higher',
#  'lt translator Lillehammer',
#  'Ingles translator Phou',
#  'Cu translator Wellington',
#  'Spurs translator Holger',
#  'CCD translator Ribeiro',
#  'Sheridan translator Exil',
#  'Guide translator Valentin',
#  'Saguenay translator DB',
#  'Kabul translator Irving',
#  'PHP translator NL',
#  'Krieger translator Turm',
#  'Aden translator Pamplona',
#  'Calder translator Kleiner',
#  'Nicolson translator Wade',
#  'Vid translator Émile',
#  'Legenda translator Jaroslav',
#  'CAD translator Quinn',
#  'Miranda translator Parigi',
#  'Os translator London',
#  'Valladolid translator Churchill',
#  'Find translator Strong',
#  'Camillo translator Cech',
#  'Je translator Boston',
#  'Elton translator Lund',
#  'Lehre translator Coast',
#  'North translator July',
#  'Suiza translator Adrian',
#  'Magnolia translator CBC',
#  'Canadian translator Montgomery',
#  'Basse translator Mina',
#  'Mata translator Menor',
#  'McDonnell translator Bertha',
#  'Estudios translator Armor',
#  'Bishop translator Primavera',
#  'Liv translator Loire',
#  'Maryland translator Hedwig',
#  'Hills translator Polonia',
#  'Rosenthal translator Seele',
#  'Reich translator Borg',
#  ...]

# %%
for x in train:
    if 'Valentine' in x:
        print(x)
# Out:
# Valentine translator Das
# Valentine worshipped by Windows
# Rico currency Valentine
# Valentine parliamentary group Mad
# Tat candidacy in election Valentine

# %%
# Add non-rule-relation
n_relations_general = 20
n_facts_general = 2000

non_rels = []

relations_general_sampled = relations_general.sample(n_relations_general)

for index, relation in relations_general_sampled.iterrows():

    # Sample random entities
    entity_generator = gen_index_pairs(entities.shape[0], n_facts_general, 1)

    for e_id, f_id in entity_generator:
        e = entities['label'][e_id]
        f = entities['label'][f_id]

        # Append symmetric relations
        train.append(e + ' ' + relation[source_lang] + ' ' + f)
        train.append(e + ' ' + relation[target_lang] + ' ' + f)
        non_rels.append(e + ' ' + relation[source_lang] + ' ' + f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <module>
#       3 n_facts_general = 2000
#       5 non_rels = []
# ----> 7 relations_general_sampled = relations_general.sample(n_relations_general)
#       9 for index, relation in relations_general_sampled.iterrows():
#      10
#      11     # Sample random entities
#      12     entity_generator = gen_index_pairs(entities.shape[0], n_facts_general, 1)
#
# NameError: name 'relations_general' is not defined

# %%
len(train)
# Out:
# 120000

# %%
test_dict = {'sample': test}
train_dict = {'sample': train}
train_dict
# Out:
# {'sample': ['HB has cause Domino',
#   'Addison has cause Noire',
#   'Mitch has cause Dana',
#   'Cheryl has cause Barcelona',
#   'Riviera has cause Conquest',
#   'CL has cause Erie',
#   'Alfonso has cause Collins',
#   'Survival has cause Tampere',
#   'Airport has cause Martel',
#   'Gelo has cause Fontainebleau',
#   'Auge has cause ville',
#   'Serra has cause Madsen',
#   'Kraft has cause Amiga',
#   'Medan has cause Roja',
#   'Middleton has cause Solid',
#   'Bland has cause Mallorca',
#   'Cent has cause Daphne',
#   'Niño has cause Murphy',
#   'Monster has cause Oliveira',
#   'Die has cause Newark',
#   'AVN has cause Dawn',
#   'Seele has cause Linda',
#   'Falling has cause Luck',
#   'Wanted has cause Quito',
#   'Padang has cause Espagne',
#   'Toledo has cause Hiroshima',
#   'Mondo has cause UFC',
#   'Gordon has cause Seda',
#   'ol has cause Grimm',
#   'XX has cause Campus',
#   'Famous has cause AP',
#   'Chance has cause Monate',
#   'Estudiantes has cause Breda',
#   'Italy has cause Smith',
#   'Graz has cause Parma',
#   'Innocent has cause Christie',
#   'Women has cause Mina',
#   'Minister has cause Seitz',
#   'Alves has cause Spiel',
#   'Punk has cause Eschmeyer',
#   'Hallan has cause Astrid',
#   'NS has cause Remo',
#   'Dracula has cause Glass',
#   'Valence has cause Ut',
#   'Bergman has cause Shanghai',
#   'Rusko has cause Kantor',
#   'Lange has cause Kat',
#   'Herzog has cause Xbox',
#   'SAD has cause Cyber',
#   'Tala has cause Molde',
#   'Siege has cause Wakefield',
#   'Helga has cause Schlacht',
#   'PCR has cause Tode',
#   'Gaon has cause Metropolitan',
#   'IFK has cause Perl',
#   'Colbert has cause Cars',
#   'Felix has cause Luzern',
#   'Whitman has cause Palo',
#   'Chandler has cause Europa',
#   'Colección has cause Galles',
#   'Hajdu has cause Hartley',
#   'Gertrude has cause Toronto',
#   'Dupont has cause Lemon',
#   'Sullivan has cause River',
#   'Colegio has cause Ars',
#   'Ira has cause Strong',
#   'Monsieur has cause Cham',
#   'SD has cause Jenna',
#   'Res has cause Monitor',
#   'Pace has cause Jerusalén',
#   'ABD has cause Augusti',
#   'Benevento has cause Congo',
#   'Maddalena has cause Muse',
#   'Donovan has cause Tone',
#   'Edmonton has cause ao',
#   'Zwar has cause Gauss',
#   'Cisco has cause Mack',
#   'Adventure has cause Escape',
#   'SMK has cause Ayuntamiento',
#   'Benedict has cause Rule',
#   'Braga has cause Green',
#   'Anfang has cause Sia',
#   'Mississippi has cause Lucia',
#   'Kerk has cause Maya',
#   'Rex has cause ECW',
#   'Mercer has cause BP',
#   'Fisch has cause Steel',
#   'Metro has cause RE',
#   'Zelda has cause Design',
#   'Burroughs has cause Services',
#   'Lucky has cause Vader',
#   'Primer has cause Voice',
#   'Camilla has cause Daimler',
#   'Calder has cause Mad',
#   'Melanie has cause Elite',
#   'Percy has cause Aki',
#   'Prussia has cause CS',
#   'Hidden has cause CFA',
#   'Bonus has cause Priest',
#   'Borough has cause Oral',
#   'Para has cause Loire',
#   'Nathaniel has cause Broadway',
#   'Prometheus has cause Ligne',
#   'Mérida has cause Butterfly',
#   'Palestina has cause ti',
#   'Robbie has cause Cu',
#   'Pro has cause Ordu',
#   'Dover has cause PK',
#   'Flügel has cause Fashion',
#   'Perak has cause Unión',
#   'GMT has cause Cafe',
#   'da has cause Tome',
#   'Olímpico has cause Harri',
#   'Poison has cause Jansen',
#   'Self has cause Krzysztof',
#   'Gino has cause Absolute',
#   'Bianchi has cause Alessandro',
#   'Roca has cause SS',
#   'Crescent has cause Fredrik',
#   'Middlesex has cause Franse',
#   'Ace has cause Cinema',
#   'Reign has cause CRC',
#   'Jerusalem has cause Hercules',
#   'Wilmington has cause Kristen',
#   'Danilo has cause Yo',
#   'Aziz has cause Zoltán',
#   'Angus has cause Gandhi',
#   'Germany has cause Cech',
#   'Muslimani has cause Duran',
#   'Los has cause Mittel',
#   'Megaselia has cause Nueva',
#   'Lower has cause Sacro',
#   'Georgetown has cause Thiele',
#   'Tada has cause Flere',
#   'Peer has cause Dol',
#   'Esso has cause Plan',
#   'Zbigniew has cause Aragon',
#   'Salto has cause Mark',
#   'Sport has cause Janne',
#   'Raquel has cause Ange',
#   'Clifton has cause War',
#   'Comtat has cause Jalan',
#   'Seat has cause Guitar',
#   'Better has cause Face',
#   'Butte has cause Schoolmeesters',
#   'Georgia has cause Dem',
#   'Males has cause CAN',
#   'Medalla has cause Elsevier',
#   'Dolls has cause Triple',
#   'Julian has cause Irena',
#   'Catch has cause Terra',
#   'Pinto has cause Jess',
#   'Taman has cause Vokal',
#   'Lourdes has cause Suba',
#   'Shrewsbury has cause Jamaica',
#   'July has cause Guns',
#   'Noi has cause CD',
#   'Ottawa has cause Mesa',
#   'Dust has cause Ola',
#   'AK has cause Voda',
#   'Reichstag has cause Maranhão',
#   'Jared has cause Gabon',
#   'Archie has cause Valverde',
#   'Olympia has cause Westen',
#   'Graf has cause Zug',
#   'Ito has cause Dictionary',
#   'Spin has cause Trap',
#   'Fars has cause Normandy',
#   'Cornwall has cause Fowler',
#   'Vene has cause Ronnie',
#   'Shining has cause Algarve',
#   'Polis has cause Ying',
#   'Herder has cause Rita',
#   'Yukon has cause Canon',
#   'Drum has cause CSU',
#   'René has cause Tat',
#   'Slot has cause Birmingham',
#   'Concilio has cause Pe',
#   'Trong has cause Mountain',
#   'Bar has cause Lucas',
#   'Grace has cause Belgrad',
#   'Levine has cause Siria',
#   'Casablanca has cause Habana',
#   'Surrey has cause Diva',
#   'Deborah has cause Color',
#   'Fourier has cause Niko',
#   'Migration has cause Tempo',
#   'Danh has cause Theatre',
#   'Greenwich has cause Carnival',
#   'Avon has cause Nou',
#   'Buzz has cause Ardèche',
#   'Franklin has cause Carlisle',
#   'Vintage has cause Shri',
#   'SW has cause Dane',
#   'Target has cause NT',
#   'Walther has cause Rodrigues',
#   'Stary has cause Dara',
#   'Peru has cause Are',
#   'Lane has cause Nordland',
#   'Qui has cause Pass',
#   'Talbot has cause Kanada',
#   'Benz has cause Early',
#   'Garde has cause Interview',
#   'Racing has cause Denne',
#   'Acoustic has cause Thomson',
#   'Rocket has cause Hate',
#   'Getting has cause Faso',
#   'Nicolson has cause Battalion',
#   'Mifflin has cause Gruppo',
#   'Morgan has cause Vladislav',
#   'Paderborn has cause Godfrey',
#   'Rembrandt has cause Seo',
#   'Erika has cause Antoinette',
#   'Stelle has cause Follow',
#   'Frederick has cause Linia',
#   'Burr has cause Superliga',
#   'Sogn has cause Ilona',
#   'Ziele has cause Halen',
#   'Av has cause Orient',
#   'Oru has cause Elmi',
#   'Times has cause Edit',
#   'Mis has cause Toten',
#   'Namun has cause Turquia',
#   'Alman has cause Noise',
#   'Parigi has cause GM',
#   'Hood has cause Voyager',
#   'Akdeniz has cause Membre',
#   'Proto has cause Tours',
#   'Hansen has cause tu',
#   'Berkeley has cause Florida',
#   'Hammond has cause Kaufman',
#   'Orlando has cause Middle',
#   'Belles has cause Stephenson',
#   'Carl has cause Santiago',
#   'Sagan has cause Aria',
#   'Midi has cause Studi',
#   'Far has cause Smash',
#   'Andrews has cause Jerome',
#   'Silence has cause Paul',
#   'Mars has cause Monroe',
#   'Mag has cause Paradise',
#   'Mur has cause Carter',
#   'Iris has cause Rosenthal',
#   'Mexican has cause Oslo',
#   'Cha has cause NN',
#   'Heide has cause Emilia',
#   'ITF has cause Tiet',
#   'Lynch has cause Soc',
#   'Sheldon has cause Heath',
#   'Stefano has cause Wittenberg',
#   'PSP has cause Kobe',
#   'Kobayashi has cause Reisen',
#   'Donatello has cause st',
#   'sal has cause Debussy',
#   'Otte has cause Diablo',
#   'Film has cause Pages',
#   'Né has cause Re',
#   'Lorenz has cause Büyük',
#   'Bonaparte has cause Steiner',
#   'Aragó has cause Arles',
#   'Spaans has cause Leigh',
#   'Cotton has cause Lors',
#   'PIB has cause Kant',
#   'Vockeroth has cause Ubuntu',
#   'Buda has cause North',
#   'Oracle has cause Nikolaj',
#   'Hamas has cause Hie',
#   'Brief has cause Fekete',
#   'Dante has cause England',
#   'Serie has cause Vi',
#   'Hum has cause Harrington',
#   'Senna has cause Björn',
#   'Aire has cause Filadelfia',
#   'Saxe has cause Katarina',
#   'Charlotte has cause Boo',
#   'Many has cause TN',
#   'Condor has cause Buchanan',
#   'Sedan has cause Ferns',
#   'Beyaz has cause Muda',
#   'Greco has cause Bab',
#   'Winston has cause Ova',
#   'Cumberland has cause Planet',
#   'Fel has cause Alliance',
#   'Vinyl has cause Naast',
#   'Asunción has cause IB',
#   'Bassa has cause Frères',
#   'Meta has cause Pink',
#   'Ho has cause Ultra',
#   'Belo has cause Alicia',
#   'Led has cause Vita',
#   'PRL has cause Fulham',
#   'Herbst has cause Helden',
#   'Chat has cause Holden',
#   'SDP has cause MGM',
#   'Hooper has cause Sheridan',
#   'Talent has cause Zeeland',
#   'Engine has cause Euler',
#   'Nadu has cause Universe',
#   'Cosmos has cause Ritter',
#   'Britney has cause Piedmont',
#   'Navarro has cause Morley',
#   'Bassi has cause Elke',
#   'Ale has cause Sada',
#   'Windsor has cause Putnam',
#   'Sheriff has cause HTC',
#   'Vogel has cause II',
#   'Neubau has cause Goran',
#   'Iron has cause Falcon',
#   'Hughes has cause Rocks',
#   'Angoulême has cause Kern',
#   'Latreille has cause Flow',
#   'Selim has cause Isis',
#   'Swiss has cause Bunker',
#   'Opus has cause Granada',
#   'Reina has cause Shoot',
#   'Sparta has cause Meet',
#   'Jane has cause Lenny',
#   'Tibet has cause Ken',
#   'Romeo has cause EM',
#   'Dornbusch has cause Th',
#   'Aviation has cause Region',
#   'Nicolaus has cause Bad',
#   'Field has cause Nacional',
#   'Goiás has cause Nantes',
#   'Mira has cause CBN',
#   'Sports has cause Fr',
#   'Evelyn has cause Genoa',
#   'Berta has cause Deutschland',
#   'Yorkshire has cause Buna',
#   'Lager has cause Drop',
#   'NP has cause Toulouse',
#   'Hub has cause Butler',
#   'Tracy has cause Trento',
#   'Samoa has cause ST',
#   'Sonic has cause Alus',
#   'Legend has cause Mundi',
#   'Molly has cause Sit',
#   'Duncan has cause GS',
#   'Brand has cause Justice',
#   'America has cause Cardiff',
#   'EV has cause Haus',
#   'Dell has cause Amiens',
#   'Giovanna has cause Teatro',
#   'Punjabi has cause Phou',
#   'Mitt has cause Clancy',
#   'Villeneuve has cause Haziran',
#   'Hero has cause Houten',
#   'Red has cause Bethlehem',
#   'Fairmaire has cause KPD',
#   'Finger has cause Rond',
#   'Weil has cause Poet',
#   'Brunner has cause Salvia',
#   'Colle has cause Ajax',
#   'Pueblo has cause Princess',
#   'Maximilian has cause Dolores',
#   'Eberhard has cause ABC',
#   'Piazza has cause Stevie',
#   'Jenny has cause Australia',
#   'Marion has cause Katharina',
#   'Sulla has cause Cruise',
#   'Hector has cause Briggs',
#   'Leslie has cause Mais',
#   'Rossa has cause Fire',
#   'Egon has cause Salzburg',
#   'Colonna has cause Courtney',
#   'Kid has cause Premier',
#   'Partido has cause Lima',
#   'Adrian has cause Canadian',
#   'Hamlet has cause Dunay',
#   'Clarkson has cause fe',
#   'Carrillo has cause Jensen',
#   'Oko has cause Pokémon',
#   'JP has cause Eco',
#   'Hilaire has cause MV',
#   'Colts has cause Ragnar',
#   'Landau has cause Valeria',
#   'KHL has cause Witness',
#   'Poola has cause Malta',
#   'Gruyter has cause President',
#   'Arap has cause Kao',
#   'Pasha has cause Speedway',
#   'Ol has cause Whitehead',
#   'Haifa has cause Dahl',
#   'Verona has cause Corrientes',
#   'Lagoa has cause Export',
#   'Jaguar has cause ABS',
#   'Scream has cause Licht',
#   'Lawrence has cause ESPN',
#   'Silent has cause Cochrane',
#   'Gloucester has cause Dora',
#   'Worldwide has cause Trotz',
#   'Hamm has cause Chinese',
#   'TBS has cause Catedral',
#   'Ad has cause Br',
#   'Neri has cause Frente',
#   'Progress has cause MTA',
#   'Flowers has cause Morse',
#   'Eva has cause Eternal',
#   'Cruz has cause NDR',
#   'Nina has cause Aires',
#   'Bosco has cause CSS',
#   'Winners has cause Automatic',
#   'Porter has cause PG',
#   'Collected has cause Thiên',
#   'Massacre has cause Kaisers',
#   'Fresno has cause Soldier',
#   'Castle has cause Pole',
#   'Wanna has cause Essential',
#   'Tarragona has cause Trip',
#   'Benfica has cause Willis',
#   'Hudson has cause Seite',
#   'Ida has cause Pacífico',
#   'Männchen has cause Highway',
#   'Nowe has cause Front',
#   'Summer has cause Warsaw',
#   'Marvin has cause Agent',
#   'Luca has cause Swing',
#   'Loeb has cause Kabul',
#   'Mundo has cause Danas',
#   'Israeli has cause Byron',
#   'Raoul has cause Vinci',
#   'Star has cause Twain',
#   'Shaun has cause Lilla',
#   'Barrio has cause Anatolia',
#   'IPAC has cause Lehre',
#   'Mother has cause Augusta',
#   'Showtime has cause Office',
#   'Heritage has cause Pasteur',
#   'XXI has cause IGE',
#   'Einstein has cause Sonntag',
#   'Jolie has cause Gonzalo',
#   'Pool has cause École',
#   'especialista has cause Prima',
#   'Derby has cause Hills',
#   'Masters has cause Orléans',
#   'Palestine has cause White',
#   'Ab has cause Dins',
#   'Engagement has cause DR',
#   'Panny has cause Tucumán',
#   'Lillehammer has cause rs',
#   'Comte has cause Márquez',
#   'Richards has cause Aveyron',
#   'Klinik has cause Greenberg',
#   'Tanz has cause Avalon',
#   'Aa has cause Sitt',
#   'Manche has cause Sergey',
#   'Governo has cause Devil',
#   'Baum has cause Neste',
#   'Monique has cause Auckland',
#   'Quincy has cause Russen',
#   'Darling has cause Dual',
#   'Ciudad has cause Connie',
#   'Globo has cause JJ',
#   'Cea has cause McKinley',
#   'Beaufort has cause Bertrand',
#   'Keller has cause Auvergne',
#   'Lorena has cause Valls',
#   'Lopes has cause Planets',
#   'Mean has cause Willow',
#   'Barrett has cause Complete',
#   'Lai has cause Gomes',
#   'Central has cause Fight',
#   'Vieux has cause Frank',
#   'Durch has cause Slag',
#   'Vis has cause Aloe',
#   'Winnipeg has cause Meteor',
#   'Shadow has cause Fabrizio',
#   'Moi has cause Holt',
#   'Liban has cause Viscount',
#   'Alpine has cause Mayotte',
#   'Men has cause Herald',
#   'Harding has cause Straits',
#   'Cramer has cause Rocca',
#   'Salvador has cause Tribune',
#   'Nicholson has cause UDP',
#   'Casino has cause Limita',
#   'jet has cause Poitou',
#   'Hell has cause Andorra',
#   'Coca has cause Hai',
#   'Marija has cause Unlimited',
#   'Radar has cause Remixes',
#   'Yunan has cause Cost',
#   'Young has cause After',
#   'Chevillotte has cause Ortiz',
#   'Robson has cause Enigma',
#   'Ritual has cause Rochefort',
#   'Aubrey has cause RTL',
#   'Bacon has cause Hampton',
#   'Turin has cause Chartres',
#   'Aves has cause Magnolia',
#   'Cargo has cause Divine',
#   'Kapitel has cause Barbara',
#   'Homo has cause Business',
#   'Giro has cause Renault',
#   'Beatrice has cause Mickey',
#   'Mosca has cause Nash',
#   'Northumberland has cause Netz',
#   'Bolt has cause Winchester',
#   'Decock has cause Dre',
#   'Fraser has cause Constitución',
#   'Montserrat has cause Gould',
#   'Ingen has cause Bee',
#   'Bloom has cause Bernstein',
#   'Command has cause Mirage',
#   'Hawker has cause Heikki',
#   'Philippe has cause WR',
#   'Provence has cause Hübner',
#   'Chamberlain has cause Ride',
#   'Bintang has cause Natalie',
#   'Chor has cause Herman',
#   'Infinite has cause Mateo',
#   'Eve has cause Herrschaft',
#   'Roberta has cause ME',
#   'Echo has cause Noord',
#   'BC has cause Sudan',
#   'Uetz has cause Opera',
#   'Digital has cause Panel',
#   'Finale has cause su',
#   'Cádiz has cause Diana',
#   'Bertram has cause Guayaquil',
#   'Maire has cause NF',
#   'Genera has cause Perdana',
#   'Roche has cause Gosse',
#   'Gerd has cause Haiti',
#   'at has cause Angola',
#   'Everest has cause Isola',
#   'Libro has cause Clay',
#   'Steinicke has cause Racine',
#   'Coma has cause Inge',
#   'Bruxelles has cause Jae',
#   'Estes has cause MC',
#   'Actor has cause Velázquez',
#   'Melo has cause Stay',
#   'Speyer has cause Giang',
#   'co has cause Jones',
#   'Penguin has cause Satz',
#   'EN has cause Liang',
#   'Carnegie has cause Thornton',
#   'Ebert has cause MBC',
#   'Raven has cause Nouveau',
#   'Hurley has cause THE',
#   'HD has cause Comet',
#   'Outlook has cause Elizabeth',
#   'Transit has cause Maxi',
#   'Medvedev has cause Centers',
#   'Morocco has cause Eindhoven',
#   'Sussex has cause Egypt',
#   'AL has cause Som',
#   'Panther has cause Pod',
#   'Chelsea has cause Bend',
#   'Figaro has cause Baron',
#   'Ponta has cause Burg',
#   'di has cause Size',
#   'Friedrich has cause Mao',
#   'Laurel has cause Ekim',
#   'Holger has cause Coleman',
#   'Atlanta has cause Bet',
#   'Berlín has cause Rhapsody',
#   'Shadows has cause Brent',
#   'Brooks has cause Writer',
#   'Bretagne has cause Chorus',
#   'CK has cause Castell',
#   'XVI has cause Riau',
#   'Sparks has cause Jamal',
#   'Camillo has cause Bowen',
#   'Waray has cause Watkins',
#   'Machine has cause Hollywood',
#   'Crosby has cause Cáceres',
#   'Belize has cause Aalborg',
#   'Bremen has cause Kennedy',
#   'Grand has cause Rees',
#   'Fund has cause Ferguson',
#   'Oggi has cause Aube',
#   'CH has cause Ontario',
#   'Gonzaga has cause Goldberg',
#   'Peterborough has cause Denver',
#   'Tex has cause Oak',
#   'Mills has cause Billy',
#   'Mighty has cause Wirkung',
#   'UCD has cause Tennessee',
#   'Endre has cause Somme',
#   'AF has cause Ruhr',
#   'Walters has cause Sea',
#   'Blau has cause Bali',
#   'Gotham has cause Masa',
#   'Seas has cause Turkey',
#   'Sanremo has cause Rebel',
#   'Dillon has cause City',
#   'Omaha has cause Alger',
#   'EPA has cause Esch',
#   'Medi has cause Kyoto',
#   'Prensa has cause Vic',
#   'Basque has cause Vaud',
#   'Mil has cause Guevara',
#   'Flower has cause Mirko',
#   'Atari has cause WRC',
#   'Kraj has cause Ware',
#   'Ter has cause Page',
#   'Aden has cause Liberation',
#   'Pembroke has cause Tabachnick',
#   'Vela has cause Versailles',
#   'Celsius has cause Davies',
#   'Congress has cause Freeman',
#   'Spider has cause Milne',
#   'Entry has cause Tiene',
#   'Celia has cause Jeffries',
#   'GPU has cause Death',
#   'Republic has cause RS',
#   'Louisville has cause Saab',
#   'Records has cause Pay',
#   'Izrael has cause RPM',
#   'Zapata has cause Devon',
#   'Minas has cause Gers',
#   'WBA has cause Sound',
#   'UAE has cause Hour',
#   'Khu has cause Parco',
#   'ISS has cause Illinois',
#   'Kurt has cause Phil',
#   'SAS has cause Christophe',
#   'SSR has cause Bitte',
#   'Bumi has cause Dollar',
#   'Shake has cause STS',
#   'Tech has cause oed',
#   'Wyoming has cause Juara',
#   'Pays has cause ICC',
#   'Finance has cause Gama',
#   'Prescott has cause Irina',
#   'Arlington has cause Canada',
#   'Batman has cause Lappland',
#   'Episcopal has cause Margaretha',
#   'Franz has cause String',
#   'Burke has cause Madagascar',
#   'Richelieu has cause Terceira',
#   'Béla has cause Weg',
#   'Croatia has cause Imperium',
#   'Johansen has cause Pel',
#   'Eno has cause Bride',
#   'Sono has cause Terminal',
#   'Roi has cause Emden',
#   'Dewi has cause Blade',
#   'Seu has cause Parque',
#   'Lodi has cause McDonald',
#   'Wadi has cause Platinum',
#   'Paese has cause Dixon',
#   'Din has cause Trend',
#   'Peel has cause Bürgermeister',
#   'Osborne has cause Belgrano',
#   'Bachelor has cause Senegal',
#   'Camus has cause India',
#   'Viru has cause Jubilee',
#   'Rowland has cause Huelva',
#   'Bud has cause Madonna',
#   'Ryan has cause Playboy',
#   'Columbus has cause Spurs',
#   'Bull has cause Nello',
#   'Freedom has cause RN',
#   'Mata has cause Lobo',
#   'België has cause Steele',
#   'Wisdom has cause Guru',
#   'Gert has cause Cina',
#   'Slave has cause Parkinson',
#   'Bangkok has cause Dacia',
#   'Northern has cause Brock',
#   'Selma has cause Lamarck',
#   'Bent has cause Sørensen',
#   'Cuenca has cause Frontier',
#   'NRW has cause Anglo',
#   'Day has cause Druga',
#   'Cove has cause Cherry',
#   'Rousseau has cause Concord',
#   'Hepburn has cause Penn',
#   'nr has cause Eintracht',
#   'Canto has cause Domain',
#   'McCoy has cause Leonard',
#   'Country has cause Vida',
#   'Campo has cause Register',
#   'Grâce has cause Guarda',
#   'Marruecos has cause Accademia',
#   'Wolverine has cause Vieira',
#   'Bayan has cause Roubaix',
#   'Pratt has cause Braunschweig',
#   'Alexandria has cause Albania',
#   'Prato has cause Adel',
#   'sy has cause Carmen',
#   'Spieler has cause Zola',
#   'Data has cause Anything',
#   'Maestro has cause Moldova',
#   'MW has cause Classic',
#   'League has cause Volk',
#   'Richter has cause Murcia',
#   'Sunrise has cause Mount',
#   'Viking has cause Romagna',
#   'Files has cause UE',
#   'Hotel has cause Marius',
#   'Holly has cause Zen',
#   'Tunnel has cause Co',
#   'Aten has cause Wittgenstein',
#   'Sage has cause Broadcast',
#   'Ketika has cause Schultz',
#   'TX has cause Juventus',
#   'Breton has cause ag',
#   'Langue has cause Sofia',
#   'RJ has cause Isto',
#   'Pamplona has cause Barbus',
#   'Rowan has cause Namibia',
#   'Woodstock has cause Planck',
#   'Genesis has cause Kirchner',
#   'Verso has cause Earth',
#   'Observatoire has cause Cristal',
#   'Ducks has cause Era',
#   'Castiella has cause Villanueva',
#   'Sitze has cause Saga',
#   'BS has cause Hall',
#   'Eugène has cause Napoleon',
#   'Étienne has cause NYC',
#   'Gutenberg has cause Ryu',
#   'Janssen has cause Humbert',
#   'Rotten has cause Perry',
#   'Drew has cause Shirley',
#   'Sartre has cause EA',
#   'Am has cause Trail',
#   'Nato has cause Westermann',
#   'Sundance has cause Abd',
#   'Autumn has cause Polk',
#   'Dänemark has cause Spot',
#   'Valdés has cause Monde',
#   'Dent has cause Schaus',
#   'Noah has cause Francisco',
#   'Detroit has cause DKI',
#   'Firth has cause ACT',
#   'Nigel has cause VV',
#   'Brenda has cause Liberty',
#   'Platnick has cause ATV',
#   'Active has cause Volley',
#   'Simpson has cause Aquino',
#   'Nottingham has cause Mali',
#   'Santander has cause Music',
#   'RF has cause Sur',
#   'Noble has cause Agama',
#   'Tea has cause DNS',
#   'Campania has cause Llwyd',
#   'Esta has cause Potosí',
#   'Stock has cause Ball',
#   'Freiburg has cause Wing',
#   'GSC has cause Ocean',
#   'Cadillac has cause Industria',
#   'Athens has cause Mike',
#   'Hook has cause Coll',
#   'PL has cause Vox',
#   'Carrera has cause Ninja',
#   'Coro has cause Strauss',
#   'Mem has cause Tanjung',
#   'Westwood has cause Mahler',
#   'Kelly has cause Highland',
#   'Ricardo has cause Hradec',
#   'Latino has cause Caldwell',
#   'Marlene has cause Emperador',
#   'Tonight has cause Melody',
#   'Saw has cause Coburg',
#   'Châtillon has cause Jar',
#   'Swami has cause Od',
#   'IRAS has cause Donald',
#   'Bentley has cause Spain',
#   'Davy has cause Mound',
#   'Plains has cause Dominic',
#   'Johnson has cause Wood',
#   'Kingston has cause Muñoz',
#   'Acre has cause Masse',
#   'Coimbra has cause Hara',
#   'Magnum has cause Venice',
#   'GDP has cause Bear',
#   'LLC has cause Llobregat',
#   'Fuego has cause Bastia',
#   'Sama has cause Oxford',
#   'Nuclear has cause Qu',
#   'Cole has cause Worth',
#   'Rosemary has cause Papp',
#   'Zion has cause Disse',
#   'Rouge has cause RM',
#   'Harriet has cause Durango',
#   'Moravia has cause Grove',
#   'Hundred has cause Turnier',
#   'Tank has cause Bayreuth',
#   'Asia has cause Rhein',
#   'Fletcher has cause Colony',
#   'Exeter has cause Milton',
#   'Porsche has cause Bangsa',
#   'ESA has cause Romans',
#   'Baie has cause Laval',
#   'Alabama has cause Ramsay',
#   'Dolina has cause BB',
#   'McGill has cause Seigneur',
#   'Parts has cause Tokio',
#   'Cada has cause Mine',
#   'Pela has cause Terrace',
#   'Hutton has cause Raymond',
#   'Dalton has cause Milano',
#   'Seine has cause Macau',
#   'Hair has cause Transvaal',
#   'Madrid has cause Kira',
#   'Limburg has cause Godine',
#   'Guide has cause Demon',
#   'Bryozoa has cause Ungern',
#   'Secretary has cause Wert',
#   'Empire has cause Van',
#   'DC has cause Preto',
#   'Guerre has cause Martine',
#   'Mona has cause Greg',
#   'Bears has cause Wait',
#   'Meter has cause Find',
#   'Quantum has cause Rayon',
#   'Bambino has cause Schleswig',
#   'Victoire has cause Valenciana',
#   'State has cause Beats',
#   'Kendrick has cause Clash',
#   'USSR has cause Daniel',
#   'Zo has cause Suárez',
#   'Yorker has cause Piano',
#   'Conrad has cause Petit',
#   'Shire has cause Sinh',
#   'IPA has cause BRT',
#   'Wings has cause Historia',
#   'AFL has cause Amelia',
#   'Longchamp has cause Devido',
#   'Ayala has cause Norma',
#   'Rally has cause Calhoun',
#   'Cosimo has cause Nexus',
#   'Ehemann has cause Linh',
#   'Ole has cause Polonia',
#   'Gray has cause Tartu',
#   'Ping has cause Darin',
#   'Reinhard has cause Tucson',
#   'Cruzeiro has cause Snake',
#   'Abigail has cause ICE',
#   'Dix has cause Cave',
#   'Sänger has cause Moro',
#   'Sinai has cause Shannon',
#   'DDR has cause Gallagher',
#   'Jump has cause Fisher',
#   'Cuba has cause Mouse',
#   'Smoke has cause Contreras',
#   'Visconti has cause Basse',
#   'Norman has cause MS',
#   'Abdullah has cause Aga',
#   'Deux has cause Clair',
#   'Friendship has cause Atelier',
#   'Gilbert has cause FIS',
#   'Baza has cause Hause',
#   'Straßburg has cause Kinos',
#   'Raphaël has cause Torres',
#   'Instruments has cause Clerk',
#   'Toulon has cause Akademie',
#   'March has cause Constantin',
#   'Reilly has cause Wells',
#   'Brussel has cause Kors',
#   'Hof has cause Carpenter',
#   'Exposition has cause Dorset',
#   'Genel has cause Bandera',
#   'Ficus has cause Stuart',
#   'Abraham has cause PS',
#   'Beast has cause Addis',
#   'Parte has cause Cary',
#   'Riga has cause Whitaker',
#   'Kota has cause Thor',
#   'Quebec has cause Points',
#   'Watch has cause Magazine',
#   'Everett has cause TNI',
#   'Canadá has cause Morales',
#   'Tem has cause Nepal',
#   'Herschel has cause Mon',
#   'Rektor has cause Emery',
#   'Capitaine has cause Dmitri',
#   'Ester has cause stb',
#   'CAF has cause Klan',
#   'Bande has cause Sale',
#   'Titolo has cause Gideon',
#   'Lorraine has cause CBS',
#   'Base has cause Io',
#   'Kuna has cause Mans',
#   'Chem has cause Gießen',
#   'Friesland has cause Gospel',
#   'Suci has cause Kongo',
#   'Hawaii has cause Character',
#   'Goal has cause Senators',
#   'Berna has cause Evan',
#   'Oliva has cause Forest',
#   'Rua has cause Galiza',
#   'México has cause Nicaragua',
#   'Pretoria has cause Harbor',
#   'Arabia has cause Libertad',
#   'Bil has cause Maigret',
#   'Quinn has cause Sugar',
#   'Jet has cause Hit',
#   'Kutler has cause Rowling',
#   'Bono has cause Robinson',
#   'fann has cause Lead',
#   'Natura has cause Court',
#   'Atatürk has cause Global',
#   'cat has cause Campbell',
#   'PA has cause Kelurahan',
#   'Kaunas has cause Roses',
#   'Alternate has cause Webb',
#   'Dezember has cause Bangalore',
#   'Saints has cause Träger',
#   'EHF has cause Theresa',
#   'Stein has cause Selle',
#   'Erwin has cause Max',
#   'Staat has cause Osiris',
#   'soo has cause Vacelet',
#   'Leif has cause Karya',
#   'Abend has cause Bradley',
#   'Goya has cause Ames',
#   'Strand has cause Superior',
#   'Mineral has cause Portuguesa',
#   'DK has cause McGregor',
#   'Ashley has cause pl',
#   'Nelson has cause Artemisia',
#   'Berry has cause Díaz',
#   'Bila has cause Glacier',
#   'Fountain has cause Fairfax',
#   'Ost has cause Cárdenas',
#   'Gesù has cause Como',
#   'Grafschaft has cause Einer',
#   'Otis has cause Savannah',
#   'MD has cause Banja',
#   'Davidson has cause Bing',
#   'Bodø has cause Nelle',
#   'VOC has cause Heaven',
#   'Marais has cause Joy',
#   'CPU has cause ID',
#   'Homer has cause VF',
#   'Castelo has cause Eros',
#   'Urban has cause Perth',
#   'CAD has cause Dakota',
#   'Palencia has cause Cure',
#   'Grau has cause Tesla',
#   'Willard has cause Ryder',
#   'Dôme has cause Aby',
#   'Algeria has cause Luna',
#   'Atlantis has cause Interactive',
#   'Wilkes has cause Signal',
#   'Scarlett has cause Tin',
#   'Julie has cause Rijk',
#   'Ancien has cause VI',
#   'Grammar has cause Alvarado',
#   'Arrow has cause Missa',
#   'Napoca has cause Marso',
#   'Fell has cause Jenkins',
#   'Here has cause Sinn',
#   'Ever has cause Bruges',
#   'Gardner has cause Linus',
#   'Cummings has cause Wembley',
#   'Stammen has cause Mode',
#   'Groove has cause Tang',
#   'Kur has cause Monat',
#   'Ya has cause Haar',
#   'Zealand has cause Rochester',
#   'Trio has cause ACM',
#   'Nest has cause Cindy',
#   'KK has cause Concordia',
#   'Bora has cause Cristina',
#   'Games has cause Agora',
#   'Porta has cause Northampton',
#   'Chair has cause Counter',
#   'Garda has cause Lincoln',
#   'Barra has cause Ronaldo',
#   'Raider has cause Streit',
#   'Profil has cause Chiara',
#   'Weaver has cause April',
#   'Lutheran has cause Birth',
#   'Elise has cause Jesu',
#   'Rooney has cause Prusia',
#   'TM has cause Sion',
#   'Action has cause Much',
#   'Jakiel has cause Commonwealth',
#   'Cup has cause Wrong',
#   'ge has cause Palacio',
#   'TT has cause Kom',
#   'Köppen has cause Nara',
#   'Allier has cause Ice',
#   'Connor has cause Manconi',
#   'Lili has cause Sonja',
#   'Tears has cause Prairie',
#   'Cannes has cause Sheila',
#   'Companion has cause Tirol',
#   'Rioja has cause Petra',
#   'Idol has cause Lang',
#   'Semi has cause Crow',
#   'Amy has cause Warwick',
#   'Seychelles has cause Flamengo',
#   'Claude has cause Lok',
#   'Manchester has cause Broken',
#   'Neu has cause Benson',
#   'Kerr has cause Pierce',
#   'Kohl has cause Idaho',
#   'Hunter has cause Crimes',
#   'Pam has cause Jahn',
#   'Pax has cause NME',
#   'Bauer has cause UK',
#   'Jesús has cause Mau',
#   ...]}

# %% [markdown]
# ### Preprocessing
#
# First, we pad text so they are a uniform length. While it is possible to padtext in the tokenizer function by setting padding=True, it is more efficient to only pad the text to the length of the longest element in its batch. This is known as dynamic padding. You can do this with the DataCollatorWithPadding function:

# %% [markdown]
# ##### Convert to datasets

# %%
from datasets import load_dataset, Dataset

# %%
train_ds = Dataset.from_dict(train_dict)
test_ds = Dataset.from_dict(test_dict)

# %%
train_ds
# Out:
# Dataset({
#     features: ['sample'],
#     num_rows: 120000
# })

# %% [markdown]
# ##### Load Model

# %%
from transformers import BertModel, BertTokenizerFast, TrainingArguments, Trainer, DataCollatorWithPadding, BertForMaskedLM

# %%
tokenizer = BertTokenizerFast.from_pretrained('bert-base-multilingual-cased')

# %%
model = BertForMaskedLM.from_pretrained("bert-base-multilingual-cased")
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ##### Tokenize

# %%
def tokenize_function(examples):
    result = tokenizer(examples["sample"])
    return result

# %%
# Use batched=True to activate fast multithreading!
tokenized_train_ds = train_ds.map(
    tokenize_function, batched=True, remove_columns=["sample"]
)
tokenized_train_ds
# Out:
#   0%|          | 0/120 [00:00<?, ?ba/s]
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 120000
# })

# %%
tokenized_test_ds = test_ds.map(
    tokenize_function, batched=True, remove_columns=["sample"]
)
# Out:
#   0%|          | 0/40 [00:00<?, ?ba/s]

# %% [markdown]
# ### Finetuning

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %% [markdown]
# 3, 1000
# relations and relations_general
#
# 10, 2000 both with batchsize 256 per device is pretty much full util

# %%
import os
os.environ["WANDB_DISABLED"] = "true"

# %%
# WANDB
project_name = 'mBERT-Test'
run_name = 'Test3'

config = dict (
    relation = "symmetric",
    source_lang=source_lang,
    target_lang=target_lang,
    n_relations = n_relations,
    n_facts = n_facts,
    with_general = False,
#     n_relations_general = n_relations_general
#     n_facts_general = n_facts_general
    architecture='bert-base-multilingual-cased',
    learning_rate = 5e-5
)

wandb.init(
    project=project_name,
    name=run_name,
#     notes="",
    config=config,
    dir='../output'
)

# %%
from custom_trainer import CustomTrainer
from datasets import load_metric

metric = load_metric("accuracy")
eval_data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    # Select only the ones that are masked
    indices = np.where(labels != -100)
    return metric.compute(predictions=predictions[indices], references=labels[indices])

# %%
# Finetune mBERT

training_args = TrainingArguments(
    output_dir='../output/models/TestBoth',
    num_train_epochs=1000,
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
    learning_rate=5e-5,
#     save_total_limit=2,
    save_strategy='no',
    logging_strategy='epoch',
    evaluation_strategy='epoch',
    eval_accumulation_steps=1,
    report_to=None
)

trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_ds,
    eval_dataset=tokenized_test_ds,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    eval_data_collator=eval_data_collator
)
# Out:
# Using the `WAND_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
trainer.train()
# Out:
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 120000
#   Num Epochs = 1000
#   Instantaneous batch size per device = 128
#   Total train batch size (w. parallel, distributed & accumulation) = 256
#   Gradient Accumulation steps = 1
#   Total optimization steps = 469000
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='470' max='469000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   470/469000 04:14 < 70:46:38, 1.84 it/s, Epoch 1/1000]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='33' max='157' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 33/157 01:58 < 07:37, 0.27 it/s]
#     </div>

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>█▇▇▇▇▇▇▇▆▅▅▅▄▃▃▃▂▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/runtime</td><td>▁▅▂▂▂▂▂▂▂▂▂▂▂▃▂▂▂▄▂▃▁▂▂▂▂▂▂▂▂█▂▂▂▂▂▂▂▂▂▂</td></tr><tr><td>eval/samples_per_second</td><td>█▄▇▇▇▇▇▇▇▇▇▇▇▆▇▇▇▅▇▆█▇▇▇▇▇▇▇▇▁▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>eval/steps_per_second</td><td>█▄▇▇▇▇▇▇▇▇▇▇▇▆▇▇▇▅▇▆█▇▇▇▇▇▇▇▇▁▇▇▇▇▇▇▇▇▇▇</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/learning_rate</td><td>████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁</td></tr><tr><td>train/loss</td><td>█▇▆▆▆▆▆▆▆▆▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/loss</td><td>0.49031</td></tr><tr><td>eval/runtime</td><td>1.749</td></tr><tr><td>eval/samples_per_second</td><td>1372.203</td></tr><tr><td>eval/steps_per_second</td><td>5.718</td></tr><tr><td>train/epoch</td><td>64.0</td></tr><tr><td>train/global_step</td><td>3008</td></tr><tr><td>train/learning_rate</td><td>5e-05</td></tr><tr><td>train/loss</td><td>0.5314</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">Test3</strong>: <a href="https://wandb.ai/airwalker/mBERT-Test/runs/9kp4rhw9" target="_blank">https://wandb.ai/airwalker/mBERT-Test/runs/9kp4rhw9</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>../output/wandb/run-20220307_113547-9kp4rhw9/logs</code>

# %%
trainer.evaluate(eval_dataset=tokenized_test_ds)
# Out:
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='47' max='47' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [47/47 00:20]
#     </div>
# {'eval_loss': 2.0013506412506104,
#  'eval_accuracy': 0.7596666666666667,
#  'eval_runtime': 24.1701,
#  'eval_samples_per_second': 124.12,
#  'eval_steps_per_second': 1.945,
#  'epoch': 100.0}

# %% [markdown]
# #### Testing

# %%
model.to('cpu')
model.eval()
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=119547, bias=True)
#     )
#   )
# )

# %%
# Add non-rule-relation
n_relations_general = 3
n_facts_general = 10

non_rels = []

relations_general_sampled = relations_general.sample(n_relations_general)

for index, relation in relations_general_sampled.iterrows():

    # Sample random entities
    entity_generator = gen_index_pairs(entities.shape[0], n_facts_general, 1)

    for e_id, f_id in entity_generator:
        e = entities['label'][e_id]
        f = entities['label'][f_id]

        # Append symmetric relations
#         train.append(e + ' ' + relation[source_lang] + ' ' + f)
#         train.append(e + ' ' + relation[target_lang] + ' ' + f)
        non_rels.append(e + ' ' + relation[source_lang] + ' ' + f)

# %%
k = 0
total = len(train_dict['sample'])
i = 0

for txt in train_dict['sample'][:10000]:
    i += 1
    
    # Add [MASK] for object
    sample = txt.rsplit(' ', 1)[0] + ' [MASK]'
    label_token = tokenizer.convert_tokens_to_ids(txt.rsplit(' ', 1)[1])
    
    encoded_input = tokenizer(sample, return_tensors='pt')
    token_logits = model(**encoded_input).logits
    
    mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
    mask_token_logits = token_logits[0, mask_token_index, :]
    
    # Pick the [MASK] candidates with the highest logits
    top_5_tokens = torch.topk(mask_token_logits, 5, dim=1).indices[0].tolist()
    
    if label_token in top_5_tokens:
        k += 1
        print('i:' + str(i) + ' k:' + str(k))

# %%
k = 0
total = len(test_dict['sample'])
i = 0

for txt in test_dict['sample'][:10000]:
    i += 1
    
    # Add [MASK] for object
    sample = txt.rsplit(' ', 1)[0] + ' [MASK]'
    label_token = tokenizer.convert_tokens_to_ids(txt.rsplit(' ', 1)[1])
    
    encoded_input = tokenizer(sample, return_tensors='pt')
    token_logits = model(**encoded_input).logits
    
    mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
    mask_token_logits = token_logits[0, mask_token_index, :]
    
    # Pick the [MASK] candidates with the highest logits
    top_5_tokens = torch.topk(mask_token_logits, 5, dim=1).indices[0].tolist()
    
    if label_token in top_5_tokens:
        k += 1
        print('i:' + str(i) + ' k:' + str(k))
# Out:
# i:1 k:1
# i:2 k:2
# i:3 k:3
# i:4 k:4
# i:5 k:5
# i:6 k:6
# i:7 k:7
# i:8 k:8
# i:9 k:9
# i:10 k:10
# i:11 k:11
# i:12 k:12
# i:13 k:13
# i:14 k:14
# i:15 k:15
# i:16 k:16
# i:17 k:17
# i:18 k:18
# i:19 k:19
# i:20 k:20
# i:21 k:21
# i:22 k:22
# i:23 k:23
# i:24 k:24
# i:25 k:25
# i:26 k:26
# i:27 k:27
# i:28 k:28
# i:29 k:29
# i:30 k:30
# i:31 k:31
# i:32 k:32
# i:33 k:33
# i:34 k:34
# i:35 k:35
# i:36 k:36
# i:37 k:37
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [36], in <module>
#      10 label_token = tokenizer.convert_tokens_to_ids(txt.rsplit(' ', 1)[1])
#      12 encoded_input = tokenizer(sample, return_tensors='pt')
# ---> 13 token_logits = model(**encoded_input).logits
#      15 mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
#      16 mask_token_logits = token_logits[0, mask_token_index, :]
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:1358, in BertForMaskedLM.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, output_attentions, output_hidden_states, return_dict)
#    1343 outputs = self.bert(
#    1344     input_ids,
#    1345     attention_mask=attention_mask,
#    (...)
#    1354     return_dict=return_dict,
#    1355 )
#    1357 sequence_output = outputs[0]
# -> 1358 prediction_scores = self.cls(sequence_output)
#    1360 masked_lm_loss = None
#    1361 if labels is not None:
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:685, in BertOnlyMLMHead.forward(self, sequence_output)
#     684 def forward(self, sequence_output):
# --> 685     prediction_scores = self.predictions(sequence_output)
#     686     return prediction_scores
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/transformers/models/bert/modeling_bert.py:675, in BertLMPredictionHead.forward(self, hidden_states)
#     673 def forward(self, hidden_states):
#     674     hidden_states = self.transform(hidden_states)
# --> 675     hidden_states = self.decoder(hidden_states)
#     676     return hidden_states
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/modules/module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/modules/linear.py:103, in Linear.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.linear(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/functional.py:1848, in linear(input, weight, bias)
#    1846 if has_torch_function_variadic(input, weight, bias):
#    1847     return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848 return torch._C._nn.linear(input, weight, bias)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Manual Testing

# %%
train_dict['text']

# %%
test_dict['text']

# %%
text = "Kendrick hat als Grenze [MASK]"
encoded_input = tokenizer(text, return_tensors='pt')
token_logits = model(**encoded_input)

# %%
tokenized_test_ds[0]
# Out:
# {'input_ids': [101, 44266, 20187, 32524, 10166, 68051, 102],
#  'token_type_ids': [0, 0, 0, 0, 0, 0, 0],
#  'attention_mask': [1, 1, 1, 1, 1, 1, 1]}

# %%
text = "Sun place of publication [MASK]"
encoded_input = tokenizer(text, return_tensors='pt')
token_logits = model(**encoded_input).logits

mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
mask_token_logits = token_logits[0, mask_token_index, :]

# Pick the [MASK] candidates with the highest logits
top_5_tokens = torch.topk(mask_token_logits, 5, dim=1).indices[0].tolist()

for chunk in top_5_tokens:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# '>>> Polski'
#
# '>>> Sun'
#
# '>>> Kostel'
#
# '>>> Yeni'
#
# '>>> Luke'

# %%
for t in train_dict['text']:
    if 'Spa' in t:
        print(t)

# %%
test_dict
# Out:
# {'sample': ['Sun office held Polski',
#   'Boxer office held Bay',
#   'du office held Swansea',
#   'Warren office held Bachelor',
#   'Ravenna office held Licht',
#   'Piero office held Dynasty',
#   'Strike office held Emperador',
#   'Titre office held Khan',
#   'Mundi office held JK',
#   'Shows office held Kira',
#   'Page office held Pat',
#   'Dina office held Sacramento',
#   'Solid office held Occidental',
#   'Radio office held Britten',
#   'Andorra office held Mahler',
#   'Halle office held Paterson',
#   'Shuttle office held Nagasaki',
#   'Partido office held Cummings',
#   'Agent office held Hub',
#   'Toren office held Oxford',
#   'Satan office held KM',
#   'Dada office held Russie',
#   'Ehren office held Pretoria',
#   'Indra office held Web',
#   'Drake office held Am',
#   'Gill office held Cedar',
#   'Mobile office held Paramount',
#   'America office held st',
#   'Bilbao office held ac',
#   'KC office held Beth',
#   'Lucas office held Juba',
#   'Verder office held Tennessee',
#   'Algeria office held Ryder',
#   'Look office held Alberta',
#   'Nga office held Congo',
#   'Día office held Züge',
#   'Vierge office held Blant',
#   'Das office held NT',
#   'Mivel office held Jenny',
#   'Franken office held Ange',
#   'Sidney office held After',
#   'Versailles office held Gina',
#   'Membracoidea office held Villeneuve',
#   'Waiting office held Inspector',
#   'Sra office held Lee',
#   'Lower office held Opera',
#   'Enemy office held Samen',
#   'Schmid office held Door',
#   'Early office held Virgil',
#   'Firefox office held Fontainebleau',
#   'Jill office held Viking',
#   'Rhine office held Hai',
#   'Lenny office held Roller',
#   'Final office held Straßburg',
#   'Truman office held Ga',
#   'Renoir office held Pe',
#   'Pirates office held Sainte',
#   'Witness office held Legenda',
#   'Panorama office held Clermont',
#   'Broken office held Gibraltar',
#   'Rum office held Panama',
#   'Olímpico office held Weg',
#   'Bells office held Franciszek',
#   'Dis office held Langley',
#   'Yorker office held Spice',
#   'Spot office held Stéphane',
#   'Wola office held Emily',
#   'Terrace office held Sitt',
#   'Monte office held Schlacht',
#   'Adobe office held Calabria',
#   'Mayr office held PS',
#   'Houston office held Peters',
#   'Rom office held Central',
#   'Aachen office held Firenze',
#   'Seu office held Spurs',
#   'NL office held Philadelphia',
#   'Release office held Una',
#   'BM office held SM',
#   'GM office held Dent',
#   'Irland office held Lac',
#   'Sardinia office held Président',
#   'EP office held Berta',
#   'Bayreuth office held Monitor',
#   'ACC office held Dalton',
#   'Bos office held Catalunya',
#   'Andere office held Fiat',
#   'Booker office held Sparta',
#   'Quick office held Edmond',
#   'Musée office held Trouble',
#   'Ragnar office held Holt',
#   'Escola office held Lane',
#   'Pai office held Jesus',
#   'India office held Monique',
#   'Johansen office held Shane',
#   'Moody office held Extra',
#   'Panny office held Lights',
#   'Fach office held Brain',
#   'Polar office held Wilmington',
#   'Amalia office held OP',
#   'Bing office held Exil',
#   'Sama office held Sutton',
#   'UFC office held Norsk',
#   'Tracy office held Riot',
#   'Meiji office held Fars',
#   'Dag office held Casey',
#   'Teacher office held Trump',
#   'Monsieur office held Risk',
#   'Ortes office held Alvarado',
#   'Irene office held Mack',
#   'Esprit office held Hedwig',
#   'Schweden office held Trung',
#   'Oliveira office held Studie',
#   'Brenner office held NGC',
#   'Ser office held Ilona',
#   'Magic office held Ayuntamiento',
#   'Lead office held Harrington',
#   'Winchester office held Canon',
#   'Julian office held Titan',
#   'Ebene office held Miles',
#   'Translation office held Kid',
#   'PM office held Flower',
#   'Eno office held Ashes',
#   'Lorena office held Regular',
#   'Hopper office held Peso',
#   'Ese office held Horace',
#   'Haydn office held Benfica',
#   'Oslo office held Cast',
#   'Valois office held CP',
#   'Moun office held Theresa',
#   'Eo office held Trang',
#   'Palma office held Slag',
#   'Guinness office held Merkel',
#   'Fredrik office held Waves',
#   'Bengal office held Mortimer',
#   'WK office held Saab',
#   'Wild office held Surat',
#   'Lleida office held Amiens',
#   'Potsdam office held Curtis',
#   'Lange office held Oscara',
#   'Qara office held Fleming',
#   'Aves office held Porter',
#   'Greenwich office held AIM',
#   'Series office held Certain',
#   'Alpha office held Marburg',
#   'Siege office held Hradec',
#   'NY office held Lightning',
#   'Spezia office held Drama',
#   'Lori office held EUA',
#   'Lloyd office held Sân',
#   'Sultan office held Oru',
#   'Connection office held Largo',
#   'Artois office held Comet',
#   'Charlton office held Toro',
#   'Lola office held Tech',
#   'Marea office held Blair',
#   'Courtney office held Warwick',
#   'Uni office held Desert',
#   'Jeffries office held Piano',
#   'Gypsy office held Yeni',
#   'Vivaldi office held Savoia',
#   'Hare office held Cruzeiro',
#   'Excel office held Lord',
#   'Norway office held Leta',
#   'Regno office held Süleyman',
#   'Vogel office held Blade',
#   'Rollen office held Fonda',
#   'Glover office held Hewitt',
#   'Dessa office held Cordillera',
#   'Linden office held AL',
#   'CSU office held Glee',
#   'Tage office held Rotterdam',
#   'Pers office held Leicester',
#   'Wever office held Ses',
#   'Bulu office held Mesto',
#   'Sullivan office held Taurus',
#   'Spirit office held McDonnell',
#   'Hallan office held Lunar',
#   'ACM office held Color',
#   'lec office held Staffel',
#   'Siegel office held Rocket',
#   'Clin office held Campaign',
#   'Toledo office held Sherman',
#   'Flavius office held Así',
#   'Seda office held Rocks',
#   'Nana office held Emanuel',
#   'Tales office held Wort',
#   'Plains office held Wilfried',
#   'Holden office held Venus',
#   'Fischer office held Kassel',
#   'Hampton office held Cabo',
#   'Piedmont office held Campus',
#   'Ezra office held Weil',
#   'Prescott office held Jessica',
#   'PlayStation office held Wanda',
#   'Drive office held Pasteur',
#   'Finch office held CJ',
#   'Garda office held Württemberg',
#   'Franche office held Italy',
#   'Sentinel office held Pendant',
#   'Mint office held Winners',
#   'Anders office held Rachel',
#   'McGill office held Elmi',
#   'Liberty office held Park',
#   'Brandon office held Bug',
#   'Surface office held Bennett',
#   'Toppen office held Larsen',
#   'Swing office held Women',
#   'Lebanon office held Beauty',
#   'Mais office held fa',
#   'FX office held Savoie',
#   'Pandora office held Clifford',
#   'Noble office held Mildred',
#   'Bila office held Afro',
#   'Herschel office held Ficus',
#   'Jubilee office held USS',
#   'Walton office held Oregon',
#   'Colonel office held Games',
#   'Milton office held Bare',
#   'Gibbs office held Snake',
#   'Rok office held Hagen',
#   'PV office held Nigel',
#   'PKK office held Vista',
#   'Joaquín office held Worldwide',
#   'fe office held XXI',
#   'Chi office held Artemisia',
#   'Rowan office held Cherbourg',
#   'CR office held Seus',
#   'Siemens office held Landmark',
#   'Camilla office held Reese',
#   'Fra office held TNA',
#   'Tao office held Panzer',
#   'Brod office held July',
#   'Lieder office held González',
#   'Cassidy office held JNA',
#   'Ship office held Kohl',
#   'Manchester office held Grove',
#   'Fürsten office held Peel',
#   'Greatest office held Seen',
#   'Eugène office held NYC',
#   'Auge office held Bad',
#   'Cent office held Dillon',
#   'Elbe office held Picardie',
#   'Blanco office held Den',
#   'Gandhi office held Eaton',
#   'Eure office held Branca',
#   'Dichter office held Sala',
#   'Heroes office held Veronica',
#   'Stadio office held Brussels',
#   'Ebro office held Sick',
#   'ABC office held Olympia',
#   'Moyen office held Jørgensen',
#   'Brent office held Goya',
#   'Kale office held Brunner',
#   'Jerusalén office held Feria',
#   'Huis office held Webber',
#   'Francisco office held Borgo',
#   'Vol office held Twain',
#   'Odin office held Ninja',
#   'Lande office held Pardo',
#   'Ilha office held Fribourg',
#   'Active office held Justicia',
#   'CAD office held Manson',
#   'Delhi office held Mussolini',
#   'Warrior office held Agnes',
#   'Thánh office held Sergei',
#   'Data office held Roads',
#   'Pizarro office held Rochelle',
#   'Huxley office held Gomez',
#   'Austin office held Dans',
#   'Brody office held Rock',
#   'Shoot office held Châtillon',
#   'Sabha office held Borough',
#   'Friends office held Brandenburg',
#   'RPG office held Vladislav',
#   'Shannon office held Junior',
#   'Kenny office held CFA',
#   'Raquel office held Hour',
#   'Smash office held Tan',
#   'Slater office held Colonia',
#   'Kiss office held Friesland',
#   'Maior office held SVT',
#   'Lyndon office held Sevilla',
#   'Monat office held Aero',
#   'Shakespeare office held Ketika',
#   'Berkeley office held Samoa',
#   'Maan office held Tale',
#   'Esther office held RJ',
#   'Kelly office held Each',
#   'Blackburn office held Pam',
#   'Goebbels office held Sue',
#   'Staat office held Greenberg',
#   'Strong office held Phil',
#   'Maestro office held Kommando',
#   'Middleton office held Rice',
#   'Crash office held Baltic',
#   'Windsor office held Lorraine',
#   'Martel office held Lindberg',
#   'Lugano office held Pavia',
#   'Squadron office held Juara',
#   'Leif office held Carter',
#   'Asturias office held Tanjung',
#   'Bunker office held Coral',
#   'Tri office held McMahon',
#   'Firma office held Dust',
#   'Maxim office held Weaver',
#   'Jess office held Auvergne',
#   'Tông office held at',
#   'Hora office held Fields',
#   'Hansen office held Olive',
#   'Acid office held Canada',
#   'Byrd office held Insel',
#   'Morrison office held Jersey',
#   'Rusi office held Swan',
#   'Som office held Roewer',
#   'Lina office held VQ',
#   'Ashton office held Benoit',
#   'Patrol office held Afrika',
#   'Conceição office held Kim',
#   'Kepler office held Yale',
#   'SE office held Partner',
#   'Chat office held NF',
#   'Like office held Townsend',
#   'XL office held Sad',
#   'Federal office held Lourenço',
#   'Horse office held Richter',
#   'Madagascar office held Alonso',
#   'RMS office held België',
#   'Hospital office held Ryan',
#   'Midland office held Schneider',
#   'Roja office held Disney',
#   'Commander office held Corpus',
#   'Concilio office held Romance',
#   'Christchurch office held Laos',
#   'Mirage office held Off',
#   'Berna office held Vance',
#   'Durban office held Goa',
#   'Dell office held Volley',
#   'Doom office held Arabia',
#   'Beatrice office held Loeb',
#   'Debussy office held Discovery',
#   'Serie office held Dixon',
#   'Dollar office held Fletcher',
#   'Selo office held Souza',
#   'Serena office held ET',
#   'York office held Mission',
#   'Gross office held Karten',
#   'Alte office held Underwood',
#   'LP office held Mustang',
#   'CDC office held Batman',
#   'Provence office held Hause',
#   'PJ office held Nepal',
#   'Cliff office held ICC',
#   'Oriental office held Marlene',
#   'Essay office held Vas',
#   'Holocaust office held Auto',
#   'Kantor office held Fever',
#   'Bravo office held Nicholson',
#   'Joanne office held Io',
#   'RAF office held Mu',
#   'Bere office held Ingles',
#   'Schuster office held Bosna',
#   'Nas office held Elba',
#   'Flint office held Harmony',
#   'Bethlehem office held Kelurahan',
#   'Meteor office held Aid',
#   'Vancouver office held Sänger',
#   'Sidi office held FIS',
#   'Riga office held Clarkson',
#   'Lancaster office held Muñoz',
#   'Gray office held Gosse',
#   'Tito office held Head',
#   'Scala office held Zion',
#   'FN office held Oba',
#   'Princesa office held Alexandra',
#   'McLean office held Singer',
#   'Rowling office held Brücke',
#   'Sabadell office held WR',
#   'Majesty office held Allegro',
#   'Blatt office held II',
#   'Opening office held Fort',
#   'Matthews office held Tanner',
#   'Flame office held Companion',
#   'Kur office held Rebel',
#   'Merlin office held Visconti',
#   'Larry office held Magazine',
#   'Brookings office held Housing',
#   'Aldo office held Gaon',
#   'Buffy office held Burroughs',
#   'Templo office held Stand',
#   'AE office held Smoke',
#   'Porto office held Luftwaffe',
#   'Benson office held Odessa',
#   'tip office held Sanders',
#   'Frederico office held Eiffel',
#   'Triumph office held Jack',
#   'Saussure office held Dok',
#   'Sébastien office held Bonnet',
#   'Phou office held Pink',
#   'Hop office held Heritage',
#   'Peterborough office held Council',
#   'View office held Fidel',
#   'Renaissance office held Siegfried',
#   'Schubert office held Nacional',
#   'Calhoun office held Canto',
#   'Aqua office held Root',
#   'WM office held Benevento',
#   'Rally office held Thiele',
#   'Senat office held Camera',
#   'Fortaleza office held Rico',
#   'Joe office held Gauss',
#   'Infinite office held Wittenberg',
#   'Brasileira office held Daniels',
#   'Medvedev office held Hurt',
#   'Christine office held Tiberius',
#   'Road office held Bahía',
#   'Werding office held Stadion',
#   'Senators office held Blau',
#   'Records office held Minden',
#   'Mercy office held Gerard',
#   'Young office held Scale',
#   'Aten office held Hulk',
#   'Scarlett office held Munro',
#   'Ida office held PGA',
#   'Haji office held Cruz',
#   'Tatiana office held Libre',
#   'Oro office held Parkway',
#   'Labrador office held Chiara',
#   'Zona office held Paulo',
#   'Xuân office held Mod',
#   'Sacro office held Compostela',
#   'Portsmouth office held Virginia',
#   'Churches office held Elliott',
#   'Sailor office held MLB',
#   'Fiesta office held Cindy',
#   'Beyaz office held Goes',
#   'Sweeney office held Jaguar',
#   'Manga office held Santuario',
#   'Mires office held Superman',
#   'Sender office held Stella',
#   'Suffolk office held Tokio',
#   'Lääne office held Host',
#   'Victoire office held Rollins',
#   'NSW office held asa',
#   'Maha office held Minds',
#   'Av office held Centers',
#   'Vettel office held Mafia',
#   'Gud office held Little',
#   'NSV office held Broadway',
#   'Ken office held Blanchard',
#   'Investment office held Helga',
#   'Phan office held Humphrey',
#   'Jared office held Calvin',
#   'Vive office held Jae',
#   'Novecento office held Homer',
#   'Semarang office held Lambert',
#   'Tesla office held Duna',
#   'Matilde office held Morton',
#   'ESA office held Phi',
#   'Vanderbilt office held pl',
#   'Elite office held Maire',
#   'Weir office held Kensley',
#   'Polis office held Eva',
#   'Chinese office held Roland',
#   'Role office held Depot',
#   'Golf office held Buenos',
#   'Belt office held Padre',
#   'Senegal office held Nile',
#   'Benz office held Lara',
#   'Posten office held NO',
#   'Henning office held HB',
#   'Foi office held Luce',
#   'Cristal office held Laba',
#   'Ivoire office held Town',
#   'Vernon office held Medal',
#   'Siegen office held Boo',
#   'Meta office held Péter',
#   'Highway office held Logan',
#   'PT office held Salix',
#   'Montréal office held Christi',
#   'Shanghai office held Energy',
#   'Guy office held Marruecos',
#   'Czech office held Putih',
#   'Aires office held Dewi',
#   'Boston office held System',
#   'Schwartz office held Ode',
#   'Mundo office held Albion',
#   'Shiva office held Kostel',
#   'Setiap office held ASV',
#   'ID office held Martinez',
#   'Condor office held UAE',
#   'Kaplan office held Obra',
#   'Turkey office held Lecce',
#   'Band office held Imre',
#   'pr office held Kati',
#   'Stevens office held FAA',
#   'McLaughlin office held Euro',
#   'Bil office held Seri',
#   'Mexico office held Mérida',
#   'Orne office held Gruyter',
#   'Ultima office held McKay',
#   'Cheshire office held Trio',
#   'Valdés office held Comtat',
#   'CSS office held Becky',
#   'Shire office held Tallinn',
#   'Roi office held Sicilia',
#   'Allende office held Vienne',
#   'ASCII office held Wert',
#   'Inside office held Ent',
#   'AR office held Sogn',
#   'Switch office held Cornell',
#   'Mac office held Sakura',
#   'Ride office held Rail',
#   'Niger office held Perry',
#   'Archer office held Maybe',
#   'McDonald office held RFC',
#   'Teruel office held Seven',
#   'Neste office held Satz',
#   'Pleasure office held Evans',
#   'Everton office held Karolina',
#   'Bombay office held Sussex',
#   'Photography office held Tokyo',
#   'Point office held Mike',
#   'LL office held Sono',
#   'MVP office held WRC',
#   'Columbus office held Sedan',
#   'Lynch office held Prima',
#   'Dub office held NS',
#   'Bandera office held Otte',
#   'Arcade office held Matilda',
#   'Dahl office held Casa',
#   'Benedict office held Valladolid',
#   'Melody office held Artes',
#   'Civilization office held Martha',
#   'Guatemala office held Mag',
#   'Wendy office held Liga',
#   'Stratford office held Germany',
#   'Maxi office held Yorkshire',
#   'Mora office held Saw',
#   'Titolo office held Atom',
#   'Molina office held Mandy',
#   'Portuguesa office held Vader',
#   'Comte office held Gegner',
#   'Euler office held Benth',
#   'Naples office held Township',
#   'Tartu office held Worth',
#   'Ike office held Durango',
#   'Ancien office held Speedway',
#   'Nils office held Gates',
#   'Sitze office held Thompson',
#   'Domain office held Reina',
#   'Lagoa office held Weiler',
#   'Side office held Harding',
#   'Questa office held Esperanza',
#   'Pole office held Juli',
#   'Nash office held Milo',
#   'Andrzej office held Nico',
#   'Sabbath office held Raider',
#   'Fekete office held MD',
#   'Moscou office held Hughes',
#   'Gia office held Tübingen',
#   'Indy office held Marek',
#   'Cea office held Monterrey',
#   'Trinidad office held Cannon',
#   'Double office held Titanic',
#   'FBI office held Aix',
#   'Hull office held Angelica',
#   'Montgomery office held Brenda',
#   'Liberation office held Magdalena',
#   'Shackleton office held Gino',
#   'Charlie office held Burton',
#   'Li office held Estate',
#   'Nelson office held Kiel',
#   'Poland office held IRAS',
#   'Gerd office held ACT',
#   'Goodwin office held Patrick',
#   'Nuclear office held Lester',
#   'KV office held Ames',
#   'RS office held Falcon',
#   'Krishna office held Grégoire',
#   'Ele office held Browns',
#   'Alaska office held Lab',
#   'Schottland office held Desse',
#   'Vida office held Vuelta',
#   'Path office held Disease',
#   'Steele office held Earth',
#   'Ar office held Clash',
#   'Indianapolis office held Alison',
#   'Sanremo office held Goldberg',
#   'Ivana office held Yahoo',
#   'Tampere office held Amsterdam',
#   'Hélène office held Industria',
#   'Linh office held Eye',
#   'Forward office held Clifton',
#   'Ball office held Allah',
#   'Alta office held Wars',
#   'Braga office held Res',
#   'Salt office held Freedom',
#   'Mia office held MC',
#   'DNA office held Newport',
#   'Elizabeth office held Gaelic',
#   'Ad office held Egitto',
#   'Knight office held Clinton',
#   'Hall office held Ratu',
#   'Van office held Michel',
#   'Astra office held Treviso',
#   'Dominic office held Oriente',
#   'Moor office held Colombo',
#   'Klasse office held Deux',
#   'Carvalho office held Turbo',
#   'Vinci office held Kemp',
#   'Lemon office held Rory',
#   'Isola office held Pascal',
#   'Fallen office held Noche',
#   'Avalon office held Tode',
#   'Humboldt office held Beezley',
#   'Gipfel office held Toulon',
#   'Prestige office held Nama',
#   'Ludwik office held Murray',
#   'Explorer office held Adi',
#   'Celle office held PL',
#   'Power office held Passau',
#   'VI office held McKinley',
#   'Luca office held Coll',
#   'Violet office held Médaille',
#   'Trevor office held Tyne',
#   'Hector office held Latino',
#   'Turing office held Bergen',
#   'Constitución office held Boris',
#   'Case office held Martini',
#   'Azur office held Nicholas',
#   'Sign office held Sanskrit',
#   'Ter office held Camp',
#   'It office held Wing',
#   'ST office held Potter',
#   'Wire office held Arsenal',
#   'Death office held Pilar',
#   'CDP office held Bertram',
#   'Hava office held Abbey',
#   'Timothy office held Profile',
#   'VF office held Eve',
#   'Nissan office held Carmen',
#   'Bund office held Bastia',
#   'Murat office held Lynn',
#   'Fight office held ADN',
#   'Ami office held Queste',
#   'Paso office held Alfonso',
#   'Reason office held Remixes',
#   'Como office held Exit',
#   'Bartlett office held Mengen',
#   'Teater office held Garnier',
#   'Astana office held Normandie',
#   'Archie office held Omega',
#   'Luna office held Abdel',
#   'SDSS office held Main',
#   'Stil office held Niño',
#   'Twilight office held Orden',
#   'Mato office held Ruben',
#   'Donald office held Bleu',
#   'Bean office held Olympique',
#   'Woodstock office held Rec',
#   'Rooms office held Mason',
#   'Warhol office held Trent',
#   'Mailand office held Labour',
#   'Nicolas office held Kapitel',
#   'Springer office held Bock',
#   'Ova office held Kongo',
#   'Champagne office held Molde',
#   'Bertrand office held Oliva',
#   'Bayer office held Hazel',
#   'Jerome office held GPL',
#   'Room office held Ware',
#   'Thành office held Byl',
#   'Sawyer office held Samuel',
#   'Davida office held Castle',
#   'Silence office held Kjell',
#   'Dewan office held Colección',
#   'Divine office held Shadows',
#   'Gan office held Geneva',
#   'Denna office held Cats',
#   'CD office held Birch',
#   'Nichols office held Bismarck',
#   'Saints office held Capitaine',
#   'Morocco office held Ping',
#   'Fulda office held Uhr',
#   'Docteur office held Sementara',
#   'Windows office held Clarke',
#   'Over office held PDF',
#   'Fowler office held Mimi',
#   'Holly office held Carry',
#   'Jalan office held Dexter',
#   'Mystic office held Flag',
#   'Viru office held Satellite',
#   'Skin office held Gymnasium',
#   'Shoes office held Spor',
#   'Jeunesse office held Halk',
#   'Marius office held Devlet',
#   'Manager office held Patterson',
#   'Soto office held Iki',
#   'Diana office held WDR',
#   'Demi office held Gilmore',
#   'Selle office held Ages',
#   'Kral office held Lorenz',
#   'Clancy office held Cook',
#   'Strada office held Ward',
#   'Nara office held Herman',
#   'Evil office held Tun',
#   'States office held Sada',
#   'Buffalo office held Bali',
#   'Roberts office held Design',
#   'Manu office held Force',
#   'Taranto office held Pfalz',
#   'Mills office held Panda',
#   'Garde office held UFO',
#   'Chance office held SDP',
#   'Tone office held Cha',
#   'Montreal office held Riva',
#   'Polk office held Amiga',
#   'Juni office held Pinto',
#   'Global office held Walther',
#   'North office held Alexandria',
#   'Noch office held Au',
#   'Card office held Dawson',
#   'Heide office held Gloria',
#   'Hütte office held Tóth',
#   'Alexis office held Alternate',
#   'Harbor office held Regan',
#   'Bogor office held Train',
#   'Colegio office held Hamburg',
#   'Medi office held Andrew',
#   'Faz office held Sloan',
#   'Bishop office held Office',
#   'Doyle office held Sunrise',
#   'Irlande office held Ribeiro',
#   'Beats office held Stern',
#   'Bowman office held Gamma',
#   'Wilder office held Dalla',
#   'Find office held Antonia',
#   'Forst office held Dumas',
#   'Francesca office held Masa',
#   'Elsevier office held Planck',
#   'Murad office held Pound',
#   'Amigos office held Richelieu',
#   'Happy office held Carioca',
#   'Oasis office held Athletics',
#   'Carson office held SR',
#   'Tonga office held Lublin',
#   'Volk office held Parks',
#   'Kanady office held Leon',
#   'Mifflin office held Aragón',
#   'Elke office held Ever',
#   'Monika office held Ottawa',
#   'Struggle office held Sin',
#   'Astrid office held Arena',
#   'Hate office held Doherty',
#   'Cincinnati office held Ripley',
#   'Vir office held Smith',
#   'Valley office held Tank',
#   'Sundance office held Gloucester',
#   'Chaco office held Asylum',
#   'Interview office held Ono',
#   'Mesir office held Merrill',
#   'Lys office held Museum',
#   'Tierra office held Karls',
#   'Greco office held Oklahoma',
#   'Scream office held Section',
#   'Gers office held Yesterday',
#   'Camus office held Cure',
#   'SAD office held Mira',
#   'Koch office held Marianne',
#   'Trek office held Many',
#   'Sox office held Bel',
#   'Ulusal office held Jaroslav',
#   'Lugo office held Figaro',
#   'ge office held Mayotte',
#   'Kirche office held Adana',
#   'Harvey office held Summer',
#   'PSD office held Barnes',
#   'Graves office held Nickelodeon',
#   'Brazil office held Collected',
#   'While office held FF',
#   'Teddy office held Hornet',
#   'Agency office held Lamar',
#   'Naast office held Melo',
#   'Libération office held Matrix',
#   'DR office held Terra',
#   'Vertreter office held Goose',
#   'Sérgio office held Bear',
#   'Ethel office held Genova',
#   'Bambino office held Robertson',
#   'Vergine office held Donato',
#   'Brasileiro office held Abigail',
#   'Schumann office held Hercules',
#   'Air office held File',
#   'Neve office held Bangsa',
#   'Freak office held Rover',
#   'Secondo office held Leopard',
#   'Nino office held Sharks',
#   'Rota office held Thái',
#   'Margaretha office held Berg',
#   'Messe office held Belo',
#   'Prometheus office held Ensemble',
#   'Humbert office held Goch',
#   'Rooma office held Hell',
#   'Marca office held Uno',
#   'Negra office held Voice',
#   'Rosemary office held Lingua',
#   'Bloch office held Atatürk',
#   'Pasadena office held Battista',
#   'Memoria office held Morley',
#   'Davidson office held KHL',
#   'Dead office held Engine',
#   'Valencia office held Beverly',
#   'Elvis office held Dortmund',
#   'Speyer office held Kimberly',
#   'City office held Pieter',
#   'Rimini office held Arkansas',
#   'Migration office held Tolosa',
#   'Raden office held Oder',
#   'Castiella office held Danny',
#   'Kaufman office held Advance',
#   'Padang office held Neuchâtel',
#   'Hanover office held CG',
#   'Limita office held Spiel',
#   'Poison office held Payne',
#   'Middlesex office held Marina',
#   'OS office held Zeta',
#   'Taylor office held Puma',
#   'Thorpe office held Haziran',
#   'Izrael office held Königsberg',
#   'Goldstein office held Tim',
#   'UV office held Front',
#   'Norfolk office held MBA',
#   'MB office held Novara',
#   'Pike office held Namur',
#   'Aku office held Cada',
#   'Magister office held Lopes',
#   'NM office held Size',
#   'Catedral office held Pool',
#   'Groove office held Ekim',
#   'Kazan office held Barbosa',
#   'Sheriff office held Pasha',
#   'Scholar office held Cáceres',
#   'Pisa office held Resident',
#   'Dôme office held TNI',
#   'Bacon office held Bora',
#   'Fuego office held Jeux',
#   'Calderón office held Qi',
#   'Louisville office held Stockholm',
#   'SMA office held Muse',
#   'Pacific office held TKO',
#   'Miss office held Okinawa',
#   'Vieux office held DKI',
#   'Winkler office held Maxwell',
#   'Sonora office held Sister',
#   'Base office held Mil',
#   'Ticino office held Darmstadt',
#   'Nato office held Metropolis',
#   'Maya office held Seul',
#   'Hayward office held oed',
#   'Eddie office held Randolph',
#   'Kerk office held VR',
#   'Mine office held Alec',
#   'Mon office held Watts',
#   'Vilaine office held Lawrence',
#   'Powell office held Superliga',
#   'Copenhagen office held Barry',
#   'Goodman office held Hernández',
#   'Platinum office held Justice',
#   'Globo office held CBS',
#   'Police office held Amerika',
#   'Green office held Fran',
#   'espagnol office held Samba',
#   'SMK office held Northern',
#   'Transvaal office held Panther',
#   'Poole office held Suiza',
#   'Alicante office held Sound',
#   'Rose office held Arias',
#   'Donovan office held Universe',
#   'Ancona office held Canyon',
#   'ABD office held GSC',
#   'Wege office held Imperi',
#   'Amadeus office held Oral',
#   'Gate office held Reine',
#   'Rivas office held CAN',
#   'Delaware office held Herbst',
#   'Welles office held Vampire',
#   'Malden office held Vijay',
#   'Honour office held Castro',
#   'Palatinat office held Savannah',
#   'Sha office held Mem',
#   'Italie office held Haar',
#   'Dora office held Lindsay',
#   'Chem office held Stories',
#   'Turquia office held Hof',
#   'Flat office held can',
#   'Basin office held Same',
#   'Fuchs office held Andersson',
#   'Camino office held Fonds',
#   'Wall office held Seat',
#   'Welsh office held Winnipeg',
#   'Magazin office held PA',
#   'Larson office held Finlayson',
#   'Garden office held Horne',
#   'Holstein office held Nada',
#   'Navarra office held Hilda',
#   'Indiana office held Dam',
#   'England office held Blood',
#   'Vic office held GS',
#   'March office held Willow',
#   'ECW office held Buckingham',
#   'Follow office held Sting',
#   'Welt office held Testament',
#   'Vienna office held Yokohama',
#   'Truth office held Rocca',
#   'Atene office held Billie',
#   'Qu office held Philippe',
#   'Sheila office held Notice',
#   'Laurel office held Legend',
#   'Tem office held String',
#   'Dhaka office held Worcester',
#   'Sophia office held Dewey',
#   'Move office held Welle',
#   'Yüksek office held Flow',
#   'Campione office held Rumble',
#   'Troy office held Silvio',
#   'Galatasaray office held Azul',
#   'Mitch office held Mallorca',
#   'Novel office held Beaufort',
#   'Ty office held Mines',
#   'Gallimard office held Randall',
#   'Pride office held Mighty',
#   'Newell office held Chao',
#   'Falun office held Snyder',
#   'Endre office held Bosch',
#   'Omer office held Angola',
#   'Nieto office held Ballet',
#   'Meredith office held Mart',
#   'Chandler office held Files',
#   'Faces office held Avant',
#   'FIA office held Superior',
#   'Sporting office held Belize',
#   'Marcus office held KZ',
#   'IS office held House',
#   'Forest office held Membre',
#   'Bologna office held Ille',
#   'Jos office held Lil',
#   'Carrillo office held Neville',
#   'Bremen office held Fargo',
#   'Chronicle office held Lager',
#   'SF office held Ajax',
#   'Première office held Teixeira',
#   'Bonnie office held Jacobus',
#   'Aladin office held Fel',
#   'Trade office held Hess',
#   'Berlijn office held Dio',
#   'Mens office held Monster',
#   'Independencia office held Common',
#   'Clint office held Universitas',
#   'Transit office held Derby',
#   'Media office held Esta',
#   'stb office held Cinderella',
#   'Cech office held Ariège',
#   'Foucault office held Phong',
#   'Eun office held Concord',
#   'Tarragona office held Bourgogne',
#   'UE office held Fell',
#   'Genera office held Galiza',
#   'Mister office held Limburg',
#   'Falkland office held Region',
#   'Temps office held Pi',
#   'Noord office held CBC',
#   'Câmara office held Charlotte',
#   'Belgrad office held Dezember',
#   'Har office held Grosso',
#   'Onthophagus office held Profil',
#   'Tau office held Males',
#   'RT office held Anjou',
#   'Abel office held Self',
#   'Israeli office held Pulau',
#   'Hague office held Hügel',
#   'Hitchcock office held Els',
#   'Enigma office held Atelier',
#   'Morgen office held Jagger',
#   'Atlantic office held Saba',
#   'Campo office held Mol',
#   'Karma office held Boer',
#   'Alben office held Rae',
#   'Dana office held Greg',
#   'Duncan office held Empire',
#   'Disse office held Daimler',
#   'Minas office held Bruno',
#   'EPA office held Banja',
#   'MV office held Erie',
#   'Quebec office held Nightmare',
#   'Männchen office held Figur',
#   'Hawaii office held Tampa',
#   'Llobregat office held AC',
#   'Title office held TM',
#   'Strand office held Bildhauer',
#   'Gwillim office held Loving',
#   ...]}

# %%
train_dict
# Out:
# {'sample': ['Sun position held Polski',
#   'Boxer position held Bay',
#   'du position held Swansea',
#   'Warren position held Bachelor',
#   'Ravenna position held Licht',
#   'Piero position held Dynasty',
#   'Strike position held Emperador',
#   'Titre position held Khan',
#   'Mundi position held JK',
#   'Shows position held Kira',
#   'Page position held Pat',
#   'Dina position held Sacramento',
#   'Solid position held Occidental',
#   'Radio position held Britten',
#   'Andorra position held Mahler',
#   'Halle position held Paterson',
#   'Shuttle position held Nagasaki',
#   'Partido position held Cummings',
#   'Agent position held Hub',
#   'Toren position held Oxford',
#   'Satan position held KM',
#   'Dada position held Russie',
#   'Ehren position held Pretoria',
#   'Indra position held Web',
#   'Drake position held Am',
#   'Gill position held Cedar',
#   'Mobile position held Paramount',
#   'America position held st',
#   'Bilbao position held ac',
#   'KC position held Beth',
#   'Lucas position held Juba',
#   'Verder position held Tennessee',
#   'Algeria position held Ryder',
#   'Look position held Alberta',
#   'Nga position held Congo',
#   'Día position held Züge',
#   'Vierge position held Blant',
#   'Das position held NT',
#   'Mivel position held Jenny',
#   'Franken position held Ange',
#   'Sidney position held After',
#   'Versailles position held Gina',
#   'Membracoidea position held Villeneuve',
#   'Waiting position held Inspector',
#   'Sra position held Lee',
#   'Lower position held Opera',
#   'Enemy position held Samen',
#   'Schmid position held Door',
#   'Early position held Virgil',
#   'Firefox position held Fontainebleau',
#   'Jill position held Viking',
#   'Rhine position held Hai',
#   'Lenny position held Roller',
#   'Final position held Straßburg',
#   'Truman position held Ga',
#   'Renoir position held Pe',
#   'Pirates position held Sainte',
#   'Witness position held Legenda',
#   'Panorama position held Clermont',
#   'Broken position held Gibraltar',
#   'Rum position held Panama',
#   'Olímpico position held Weg',
#   'Bells position held Franciszek',
#   'Dis position held Langley',
#   'Yorker position held Spice',
#   'Spot position held Stéphane',
#   'Wola position held Emily',
#   'Terrace position held Sitt',
#   'Monte position held Schlacht',
#   'Adobe position held Calabria',
#   'Mayr position held PS',
#   'Houston position held Peters',
#   'Rom position held Central',
#   'Aachen position held Firenze',
#   'Seu position held Spurs',
#   'NL position held Philadelphia',
#   'Release position held Una',
#   'BM position held SM',
#   'GM position held Dent',
#   'Irland position held Lac',
#   'Sardinia position held Président',
#   'EP position held Berta',
#   'Bayreuth position held Monitor',
#   'ACC position held Dalton',
#   'Bos position held Catalunya',
#   'Andere position held Fiat',
#   'Booker position held Sparta',
#   'Quick position held Edmond',
#   'Musée position held Trouble',
#   'Ragnar position held Holt',
#   'Escola position held Lane',
#   'Pai position held Jesus',
#   'India position held Monique',
#   'Johansen position held Shane',
#   'Moody position held Extra',
#   'Panny position held Lights',
#   'Fach position held Brain',
#   'Polar position held Wilmington',
#   'Amalia position held OP',
#   'Bing position held Exil',
#   'Sama position held Sutton',
#   'UFC position held Norsk',
#   'Tracy position held Riot',
#   'Meiji position held Fars',
#   'Dag position held Casey',
#   'Teacher position held Trump',
#   'Monsieur position held Risk',
#   'Ortes position held Alvarado',
#   'Irene position held Mack',
#   'Esprit position held Hedwig',
#   'Schweden position held Trung',
#   'Oliveira position held Studie',
#   'Brenner position held NGC',
#   'Ser position held Ilona',
#   'Magic position held Ayuntamiento',
#   'Lead position held Harrington',
#   'Winchester position held Canon',
#   'Julian position held Titan',
#   'Ebene position held Miles',
#   'Translation position held Kid',
#   'PM position held Flower',
#   'Eno position held Ashes',
#   'Lorena position held Regular',
#   'Hopper position held Peso',
#   'Ese position held Horace',
#   'Haydn position held Benfica',
#   'Oslo position held Cast',
#   'Valois position held CP',
#   'Moun position held Theresa',
#   'Eo position held Trang',
#   'Palma position held Slag',
#   'Guinness position held Merkel',
#   'Fredrik position held Waves',
#   'Bengal position held Mortimer',
#   'WK position held Saab',
#   'Wild position held Surat',
#   'Lleida position held Amiens',
#   'Potsdam position held Curtis',
#   'Lange position held Oscara',
#   'Qara position held Fleming',
#   'Aves position held Porter',
#   'Greenwich position held AIM',
#   'Series position held Certain',
#   'Alpha position held Marburg',
#   'Siege position held Hradec',
#   'NY position held Lightning',
#   'Spezia position held Drama',
#   'Lori position held EUA',
#   'Lloyd position held Sân',
#   'Sultan position held Oru',
#   'Connection position held Largo',
#   'Artois position held Comet',
#   'Charlton position held Toro',
#   'Lola position held Tech',
#   'Marea position held Blair',
#   'Courtney position held Warwick',
#   'Uni position held Desert',
#   'Jeffries position held Piano',
#   'Gypsy position held Yeni',
#   'Vivaldi position held Savoia',
#   'Hare position held Cruzeiro',
#   'Excel position held Lord',
#   'Norway position held Leta',
#   'Regno position held Süleyman',
#   'Vogel position held Blade',
#   'Rollen position held Fonda',
#   'Glover position held Hewitt',
#   'Dessa position held Cordillera',
#   'Linden position held AL',
#   'CSU position held Glee',
#   'Tage position held Rotterdam',
#   'Pers position held Leicester',
#   'Wever position held Ses',
#   'Bulu position held Mesto',
#   'Sullivan position held Taurus',
#   'Spirit position held McDonnell',
#   'Hallan position held Lunar',
#   'ACM position held Color',
#   'lec position held Staffel',
#   'Siegel position held Rocket',
#   'Clin position held Campaign',
#   'Toledo position held Sherman',
#   'Flavius position held Así',
#   'Seda position held Rocks',
#   'Nana position held Emanuel',
#   'Tales position held Wort',
#   'Plains position held Wilfried',
#   'Holden position held Venus',
#   'Fischer position held Kassel',
#   'Hampton position held Cabo',
#   'Piedmont position held Campus',
#   'Ezra position held Weil',
#   'Prescott position held Jessica',
#   'PlayStation position held Wanda',
#   'Drive position held Pasteur',
#   'Finch position held CJ',
#   'Garda position held Württemberg',
#   'Franche position held Italy',
#   'Sentinel position held Pendant',
#   'Mint position held Winners',
#   'Anders position held Rachel',
#   'McGill position held Elmi',
#   'Liberty position held Park',
#   'Brandon position held Bug',
#   'Surface position held Bennett',
#   'Toppen position held Larsen',
#   'Swing position held Women',
#   'Lebanon position held Beauty',
#   'Mais position held fa',
#   'FX position held Savoie',
#   'Pandora position held Clifford',
#   'Noble position held Mildred',
#   'Bila position held Afro',
#   'Herschel position held Ficus',
#   'Jubilee position held USS',
#   'Walton position held Oregon',
#   'Colonel position held Games',
#   'Milton position held Bare',
#   'Gibbs position held Snake',
#   'Rok position held Hagen',
#   'PV position held Nigel',
#   'PKK position held Vista',
#   'Joaquín position held Worldwide',
#   'fe position held XXI',
#   'Chi position held Artemisia',
#   'Rowan position held Cherbourg',
#   'CR position held Seus',
#   'Siemens position held Landmark',
#   'Camilla position held Reese',
#   'Fra position held TNA',
#   'Tao position held Panzer',
#   'Brod position held July',
#   'Lieder position held González',
#   'Cassidy position held JNA',
#   'Ship position held Kohl',
#   'Manchester position held Grove',
#   'Fürsten position held Peel',
#   'Greatest position held Seen',
#   'Eugène position held NYC',
#   'Auge position held Bad',
#   'Cent position held Dillon',
#   'Elbe position held Picardie',
#   'Blanco position held Den',
#   'Gandhi position held Eaton',
#   'Eure position held Branca',
#   'Dichter position held Sala',
#   'Heroes position held Veronica',
#   'Stadio position held Brussels',
#   'Ebro position held Sick',
#   'ABC position held Olympia',
#   'Moyen position held Jørgensen',
#   'Brent position held Goya',
#   'Kale position held Brunner',
#   'Jerusalén position held Feria',
#   'Huis position held Webber',
#   'Francisco position held Borgo',
#   'Vol position held Twain',
#   'Odin position held Ninja',
#   'Lande position held Pardo',
#   'Ilha position held Fribourg',
#   'Active position held Justicia',
#   'CAD position held Manson',
#   'Delhi position held Mussolini',
#   'Warrior position held Agnes',
#   'Thánh position held Sergei',
#   'Data position held Roads',
#   'Pizarro position held Rochelle',
#   'Huxley position held Gomez',
#   'Austin position held Dans',
#   'Brody position held Rock',
#   'Shoot position held Châtillon',
#   'Sabha position held Borough',
#   'Friends position held Brandenburg',
#   'RPG position held Vladislav',
#   'Shannon position held Junior',
#   'Kenny position held CFA',
#   'Raquel position held Hour',
#   'Smash position held Tan',
#   'Slater position held Colonia',
#   'Kiss position held Friesland',
#   'Maior position held SVT',
#   'Lyndon position held Sevilla',
#   'Monat position held Aero',
#   'Shakespeare position held Ketika',
#   'Berkeley position held Samoa',
#   'Maan position held Tale',
#   'Esther position held RJ',
#   'Kelly position held Each',
#   'Blackburn position held Pam',
#   'Goebbels position held Sue',
#   'Staat position held Greenberg',
#   'Strong position held Phil',
#   'Maestro position held Kommando',
#   'Middleton position held Rice',
#   'Crash position held Baltic',
#   'Windsor position held Lorraine',
#   'Martel position held Lindberg',
#   'Lugano position held Pavia',
#   'Squadron position held Juara',
#   'Leif position held Carter',
#   'Asturias position held Tanjung',
#   'Bunker position held Coral',
#   'Tri position held McMahon',
#   'Firma position held Dust',
#   'Maxim position held Weaver',
#   'Jess position held Auvergne',
#   'Tông position held at',
#   'Hora position held Fields',
#   'Hansen position held Olive',
#   'Acid position held Canada',
#   'Byrd position held Insel',
#   'Morrison position held Jersey',
#   'Rusi position held Swan',
#   'Som position held Roewer',
#   'Lina position held VQ',
#   'Ashton position held Benoit',
#   'Patrol position held Afrika',
#   'Conceição position held Kim',
#   'Kepler position held Yale',
#   'SE position held Partner',
#   'Chat position held NF',
#   'Like position held Townsend',
#   'XL position held Sad',
#   'Federal position held Lourenço',
#   'Horse position held Richter',
#   'Madagascar position held Alonso',
#   'RMS position held België',
#   'Hospital position held Ryan',
#   'Midland position held Schneider',
#   'Roja position held Disney',
#   'Commander position held Corpus',
#   'Concilio position held Romance',
#   'Christchurch position held Laos',
#   'Mirage position held Off',
#   'Berna position held Vance',
#   'Durban position held Goa',
#   'Dell position held Volley',
#   'Doom position held Arabia',
#   'Beatrice position held Loeb',
#   'Debussy position held Discovery',
#   'Serie position held Dixon',
#   'Dollar position held Fletcher',
#   'Selo position held Souza',
#   'Serena position held ET',
#   'York position held Mission',
#   'Gross position held Karten',
#   'Alte position held Underwood',
#   'LP position held Mustang',
#   'CDC position held Batman',
#   'Provence position held Hause',
#   'PJ position held Nepal',
#   'Cliff position held ICC',
#   'Oriental position held Marlene',
#   'Essay position held Vas',
#   'Holocaust position held Auto',
#   'Kantor position held Fever',
#   'Bravo position held Nicholson',
#   'Joanne position held Io',
#   'RAF position held Mu',
#   'Bere position held Ingles',
#   'Schuster position held Bosna',
#   'Nas position held Elba',
#   'Flint position held Harmony',
#   'Bethlehem position held Kelurahan',
#   'Meteor position held Aid',
#   'Vancouver position held Sänger',
#   'Sidi position held FIS',
#   'Riga position held Clarkson',
#   'Lancaster position held Muñoz',
#   'Gray position held Gosse',
#   'Tito position held Head',
#   'Scala position held Zion',
#   'FN position held Oba',
#   'Princesa position held Alexandra',
#   'McLean position held Singer',
#   'Rowling position held Brücke',
#   'Sabadell position held WR',
#   'Majesty position held Allegro',
#   'Blatt position held II',
#   'Opening position held Fort',
#   'Matthews position held Tanner',
#   'Flame position held Companion',
#   'Kur position held Rebel',
#   'Merlin position held Visconti',
#   'Larry position held Magazine',
#   'Brookings position held Housing',
#   'Aldo position held Gaon',
#   'Buffy position held Burroughs',
#   'Templo position held Stand',
#   'AE position held Smoke',
#   'Porto position held Luftwaffe',
#   'Benson position held Odessa',
#   'tip position held Sanders',
#   'Frederico position held Eiffel',
#   'Triumph position held Jack',
#   'Saussure position held Dok',
#   'Sébastien position held Bonnet',
#   'Phou position held Pink',
#   'Hop position held Heritage',
#   'Peterborough position held Council',
#   'View position held Fidel',
#   'Renaissance position held Siegfried',
#   'Schubert position held Nacional',
#   'Calhoun position held Canto',
#   'Aqua position held Root',
#   'WM position held Benevento',
#   'Rally position held Thiele',
#   'Senat position held Camera',
#   'Fortaleza position held Rico',
#   'Joe position held Gauss',
#   'Infinite position held Wittenberg',
#   'Brasileira position held Daniels',
#   'Medvedev position held Hurt',
#   'Christine position held Tiberius',
#   'Road position held Bahía',
#   'Werding position held Stadion',
#   'Senators position held Blau',
#   'Records position held Minden',
#   'Mercy position held Gerard',
#   'Young position held Scale',
#   'Aten position held Hulk',
#   'Scarlett position held Munro',
#   'Ida position held PGA',
#   'Haji position held Cruz',
#   'Tatiana position held Libre',
#   'Oro position held Parkway',
#   'Labrador position held Chiara',
#   'Zona position held Paulo',
#   'Xuân position held Mod',
#   'Sacro position held Compostela',
#   'Portsmouth position held Virginia',
#   'Churches position held Elliott',
#   'Sailor position held MLB',
#   'Fiesta position held Cindy',
#   'Beyaz position held Goes',
#   'Sweeney position held Jaguar',
#   'Manga position held Santuario',
#   'Mires position held Superman',
#   'Sender position held Stella',
#   'Suffolk position held Tokio',
#   'Lääne position held Host',
#   'Victoire position held Rollins',
#   'NSW position held asa',
#   'Maha position held Minds',
#   'Av position held Centers',
#   'Vettel position held Mafia',
#   'Gud position held Little',
#   'NSV position held Broadway',
#   'Ken position held Blanchard',
#   'Investment position held Helga',
#   'Phan position held Humphrey',
#   'Jared position held Calvin',
#   'Vive position held Jae',
#   'Novecento position held Homer',
#   'Semarang position held Lambert',
#   'Tesla position held Duna',
#   'Matilde position held Morton',
#   'ESA position held Phi',
#   'Vanderbilt position held pl',
#   'Elite position held Maire',
#   'Weir position held Kensley',
#   'Polis position held Eva',
#   'Chinese position held Roland',
#   'Role position held Depot',
#   'Golf position held Buenos',
#   'Belt position held Padre',
#   'Senegal position held Nile',
#   'Benz position held Lara',
#   'Posten position held NO',
#   'Henning position held HB',
#   'Foi position held Luce',
#   'Cristal position held Laba',
#   'Ivoire position held Town',
#   'Vernon position held Medal',
#   'Siegen position held Boo',
#   'Meta position held Péter',
#   'Highway position held Logan',
#   'PT position held Salix',
#   'Montréal position held Christi',
#   'Shanghai position held Energy',
#   'Guy position held Marruecos',
#   'Czech position held Putih',
#   'Aires position held Dewi',
#   'Boston position held System',
#   'Schwartz position held Ode',
#   'Mundo position held Albion',
#   'Shiva position held Kostel',
#   'Setiap position held ASV',
#   'ID position held Martinez',
#   'Condor position held UAE',
#   'Kaplan position held Obra',
#   'Turkey position held Lecce',
#   'Band position held Imre',
#   'pr position held Kati',
#   'Stevens position held FAA',
#   'McLaughlin position held Euro',
#   'Bil position held Seri',
#   'Mexico position held Mérida',
#   'Orne position held Gruyter',
#   'Ultima position held McKay',
#   'Cheshire position held Trio',
#   'Valdés position held Comtat',
#   'CSS position held Becky',
#   'Shire position held Tallinn',
#   'Roi position held Sicilia',
#   'Allende position held Vienne',
#   'ASCII position held Wert',
#   'Inside position held Ent',
#   'AR position held Sogn',
#   'Switch position held Cornell',
#   'Mac position held Sakura',
#   'Ride position held Rail',
#   'Niger position held Perry',
#   'Archer position held Maybe',
#   'McDonald position held RFC',
#   'Teruel position held Seven',
#   'Neste position held Satz',
#   'Pleasure position held Evans',
#   'Everton position held Karolina',
#   'Bombay position held Sussex',
#   'Photography position held Tokyo',
#   'Point position held Mike',
#   'LL position held Sono',
#   'MVP position held WRC',
#   'Columbus position held Sedan',
#   'Lynch position held Prima',
#   'Dub position held NS',
#   'Bandera position held Otte',
#   'Arcade position held Matilda',
#   'Dahl position held Casa',
#   'Benedict position held Valladolid',
#   'Melody position held Artes',
#   'Civilization position held Martha',
#   'Guatemala position held Mag',
#   'Wendy position held Liga',
#   'Stratford position held Germany',
#   'Maxi position held Yorkshire',
#   'Mora position held Saw',
#   'Titolo position held Atom',
#   'Molina position held Mandy',
#   'Portuguesa position held Vader',
#   'Comte position held Gegner',
#   'Euler position held Benth',
#   'Naples position held Township',
#   'Tartu position held Worth',
#   'Ike position held Durango',
#   'Ancien position held Speedway',
#   'Nils position held Gates',
#   'Sitze position held Thompson',
#   'Domain position held Reina',
#   'Lagoa position held Weiler',
#   'Side position held Harding',
#   'Questa position held Esperanza',
#   'Pole position held Juli',
#   'Nash position held Milo',
#   'Andrzej position held Nico',
#   'Sabbath position held Raider',
#   'Fekete position held MD',
#   'Moscou position held Hughes',
#   'Gia position held Tübingen',
#   'Indy position held Marek',
#   'Cea position held Monterrey',
#   'Trinidad position held Cannon',
#   'Double position held Titanic',
#   'FBI position held Aix',
#   'Hull position held Angelica',
#   'Montgomery position held Brenda',
#   'Liberation position held Magdalena',
#   'Shackleton position held Gino',
#   'Charlie position held Burton',
#   'Li position held Estate',
#   'Nelson position held Kiel',
#   'Poland position held IRAS',
#   'Gerd position held ACT',
#   'Goodwin position held Patrick',
#   'Nuclear position held Lester',
#   'KV position held Ames',
#   'RS position held Falcon',
#   'Krishna position held Grégoire',
#   'Ele position held Browns',
#   'Alaska position held Lab',
#   'Schottland position held Desse',
#   'Vida position held Vuelta',
#   'Path position held Disease',
#   'Steele position held Earth',
#   'Ar position held Clash',
#   'Indianapolis position held Alison',
#   'Sanremo position held Goldberg',
#   'Ivana position held Yahoo',
#   'Tampere position held Amsterdam',
#   'Hélène position held Industria',
#   'Linh position held Eye',
#   'Forward position held Clifton',
#   'Ball position held Allah',
#   'Alta position held Wars',
#   'Braga position held Res',
#   'Salt position held Freedom',
#   'Mia position held MC',
#   'DNA position held Newport',
#   'Elizabeth position held Gaelic',
#   'Ad position held Egitto',
#   'Knight position held Clinton',
#   'Hall position held Ratu',
#   'Van position held Michel',
#   'Astra position held Treviso',
#   'Dominic position held Oriente',
#   'Moor position held Colombo',
#   'Klasse position held Deux',
#   'Carvalho position held Turbo',
#   'Vinci position held Kemp',
#   'Lemon position held Rory',
#   'Isola position held Pascal',
#   'Fallen position held Noche',
#   'Avalon position held Tode',
#   'Humboldt position held Beezley',
#   'Gipfel position held Toulon',
#   'Prestige position held Nama',
#   'Ludwik position held Murray',
#   'Explorer position held Adi',
#   'Celle position held PL',
#   'Power position held Passau',
#   'VI position held McKinley',
#   'Luca position held Coll',
#   'Violet position held Médaille',
#   'Trevor position held Tyne',
#   'Hector position held Latino',
#   'Turing position held Bergen',
#   'Constitución position held Boris',
#   'Case position held Martini',
#   'Azur position held Nicholas',
#   'Sign position held Sanskrit',
#   'Ter position held Camp',
#   'It position held Wing',
#   'ST position held Potter',
#   'Wire position held Arsenal',
#   'Death position held Pilar',
#   'CDP position held Bertram',
#   'Hava position held Abbey',
#   'Timothy position held Profile',
#   'VF position held Eve',
#   'Nissan position held Carmen',
#   'Bund position held Bastia',
#   'Murat position held Lynn',
#   'Fight position held ADN',
#   'Ami position held Queste',
#   'Paso position held Alfonso',
#   'Reason position held Remixes',
#   'Como position held Exit',
#   'Bartlett position held Mengen',
#   'Teater position held Garnier',
#   'Astana position held Normandie',
#   'Archie position held Omega',
#   'Luna position held Abdel',
#   'SDSS position held Main',
#   'Stil position held Niño',
#   'Twilight position held Orden',
#   'Mato position held Ruben',
#   'Donald position held Bleu',
#   'Bean position held Olympique',
#   'Woodstock position held Rec',
#   'Rooms position held Mason',
#   'Warhol position held Trent',
#   'Mailand position held Labour',
#   'Nicolas position held Kapitel',
#   'Springer position held Bock',
#   'Ova position held Kongo',
#   'Champagne position held Molde',
#   'Bertrand position held Oliva',
#   'Bayer position held Hazel',
#   'Jerome position held GPL',
#   'Room position held Ware',
#   'Thành position held Byl',
#   'Sawyer position held Samuel',
#   'Davida position held Castle',
#   'Silence position held Kjell',
#   'Dewan position held Colección',
#   'Divine position held Shadows',
#   'Gan position held Geneva',
#   'Denna position held Cats',
#   'CD position held Birch',
#   'Nichols position held Bismarck',
#   'Saints position held Capitaine',
#   'Morocco position held Ping',
#   'Fulda position held Uhr',
#   'Docteur position held Sementara',
#   'Windows position held Clarke',
#   'Over position held PDF',
#   'Fowler position held Mimi',
#   'Holly position held Carry',
#   'Jalan position held Dexter',
#   'Mystic position held Flag',
#   'Viru position held Satellite',
#   'Skin position held Gymnasium',
#   'Shoes position held Spor',
#   'Jeunesse position held Halk',
#   'Marius position held Devlet',
#   'Manager position held Patterson',
#   'Soto position held Iki',
#   'Diana position held WDR',
#   'Demi position held Gilmore',
#   'Selle position held Ages',
#   'Kral position held Lorenz',
#   'Clancy position held Cook',
#   'Strada position held Ward',
#   'Nara position held Herman',
#   'Evil position held Tun',
#   'States position held Sada',
#   'Buffalo position held Bali',
#   'Roberts position held Design',
#   'Manu position held Force',
#   'Taranto position held Pfalz',
#   'Mills position held Panda',
#   'Garde position held UFO',
#   'Chance position held SDP',
#   'Tone position held Cha',
#   'Montreal position held Riva',
#   'Polk position held Amiga',
#   'Juni position held Pinto',
#   'Global position held Walther',
#   'North position held Alexandria',
#   'Noch position held Au',
#   'Card position held Dawson',
#   'Heide position held Gloria',
#   'Hütte position held Tóth',
#   'Alexis position held Alternate',
#   'Harbor position held Regan',
#   'Bogor position held Train',
#   'Colegio position held Hamburg',
#   'Medi position held Andrew',
#   'Faz position held Sloan',
#   'Bishop position held Office',
#   'Doyle position held Sunrise',
#   'Irlande position held Ribeiro',
#   'Beats position held Stern',
#   'Bowman position held Gamma',
#   'Wilder position held Dalla',
#   'Find position held Antonia',
#   'Forst position held Dumas',
#   'Francesca position held Masa',
#   'Elsevier position held Planck',
#   'Murad position held Pound',
#   'Amigos position held Richelieu',
#   'Happy position held Carioca',
#   'Oasis position held Athletics',
#   'Carson position held SR',
#   'Tonga position held Lublin',
#   'Volk position held Parks',
#   'Kanady position held Leon',
#   'Mifflin position held Aragón',
#   'Elke position held Ever',
#   'Monika position held Ottawa',
#   'Struggle position held Sin',
#   'Astrid position held Arena',
#   'Hate position held Doherty',
#   'Cincinnati position held Ripley',
#   'Vir position held Smith',
#   'Valley position held Tank',
#   'Sundance position held Gloucester',
#   'Chaco position held Asylum',
#   'Interview position held Ono',
#   'Mesir position held Merrill',
#   'Lys position held Museum',
#   'Tierra position held Karls',
#   'Greco position held Oklahoma',
#   'Scream position held Section',
#   'Gers position held Yesterday',
#   'Camus position held Cure',
#   'SAD position held Mira',
#   'Koch position held Marianne',
#   'Trek position held Many',
#   'Sox position held Bel',
#   'Ulusal position held Jaroslav',
#   'Lugo position held Figaro',
#   'ge position held Mayotte',
#   'Kirche position held Adana',
#   'Harvey position held Summer',
#   'PSD position held Barnes',
#   'Graves position held Nickelodeon',
#   'Brazil position held Collected',
#   'While position held FF',
#   'Teddy position held Hornet',
#   'Agency position held Lamar',
#   'Naast position held Melo',
#   'Libération position held Matrix',
#   'DR position held Terra',
#   'Vertreter position held Goose',
#   'Sérgio position held Bear',
#   'Ethel position held Genova',
#   'Bambino position held Robertson',
#   'Vergine position held Donato',
#   'Brasileiro position held Abigail',
#   'Schumann position held Hercules',
#   'Air position held File',
#   'Neve position held Bangsa',
#   'Freak position held Rover',
#   'Secondo position held Leopard',
#   'Nino position held Sharks',
#   'Rota position held Thái',
#   'Margaretha position held Berg',
#   'Messe position held Belo',
#   'Prometheus position held Ensemble',
#   'Humbert position held Goch',
#   'Rooma position held Hell',
#   'Marca position held Uno',
#   'Negra position held Voice',
#   'Rosemary position held Lingua',
#   'Bloch position held Atatürk',
#   'Pasadena position held Battista',
#   'Memoria position held Morley',
#   'Davidson position held KHL',
#   'Dead position held Engine',
#   'Valencia position held Beverly',
#   'Elvis position held Dortmund',
#   'Speyer position held Kimberly',
#   'City position held Pieter',
#   'Rimini position held Arkansas',
#   'Migration position held Tolosa',
#   'Raden position held Oder',
#   'Castiella position held Danny',
#   'Kaufman position held Advance',
#   'Padang position held Neuchâtel',
#   'Hanover position held CG',
#   'Limita position held Spiel',
#   'Poison position held Payne',
#   'Middlesex position held Marina',
#   'OS position held Zeta',
#   'Taylor position held Puma',
#   'Thorpe position held Haziran',
#   'Izrael position held Königsberg',
#   'Goldstein position held Tim',
#   'UV position held Front',
#   'Norfolk position held MBA',
#   'MB position held Novara',
#   'Pike position held Namur',
#   'Aku position held Cada',
#   'Magister position held Lopes',
#   'NM position held Size',
#   'Catedral position held Pool',
#   'Groove position held Ekim',
#   'Kazan position held Barbosa',
#   'Sheriff position held Pasha',
#   'Scholar position held Cáceres',
#   'Pisa position held Resident',
#   'Dôme position held TNI',
#   'Bacon position held Bora',
#   'Fuego position held Jeux',
#   'Calderón position held Qi',
#   'Louisville position held Stockholm',
#   'SMA position held Muse',
#   'Pacific position held TKO',
#   'Miss position held Okinawa',
#   'Vieux position held DKI',
#   'Winkler position held Maxwell',
#   'Sonora position held Sister',
#   'Base position held Mil',
#   'Ticino position held Darmstadt',
#   'Nato position held Metropolis',
#   'Maya position held Seul',
#   'Hayward position held oed',
#   'Eddie position held Randolph',
#   'Kerk position held VR',
#   'Mine position held Alec',
#   'Mon position held Watts',
#   'Vilaine position held Lawrence',
#   'Powell position held Superliga',
#   'Copenhagen position held Barry',
#   'Goodman position held Hernández',
#   'Platinum position held Justice',
#   'Globo position held CBS',
#   'Police position held Amerika',
#   'Green position held Fran',
#   'espagnol position held Samba',
#   'SMK position held Northern',
#   'Transvaal position held Panther',
#   'Poole position held Suiza',
#   'Alicante position held Sound',
#   'Rose position held Arias',
#   'Donovan position held Universe',
#   'Ancona position held Canyon',
#   'ABD position held GSC',
#   'Wege position held Imperi',
#   'Amadeus position held Oral',
#   'Gate position held Reine',
#   'Rivas position held CAN',
#   'Delaware position held Herbst',
#   'Welles position held Vampire',
#   'Malden position held Vijay',
#   'Honour position held Castro',
#   'Palatinat position held Savannah',
#   'Sha position held Mem',
#   'Italie position held Haar',
#   'Dora position held Lindsay',
#   'Chem position held Stories',
#   'Turquia position held Hof',
#   'Flat position held can',
#   'Basin position held Same',
#   'Fuchs position held Andersson',
#   'Camino position held Fonds',
#   'Wall position held Seat',
#   'Welsh position held Winnipeg',
#   'Magazin position held PA',
#   'Larson position held Finlayson',
#   'Garden position held Horne',
#   'Holstein position held Nada',
#   'Navarra position held Hilda',
#   'Indiana position held Dam',
#   'England position held Blood',
#   'Vic position held GS',
#   'March position held Willow',
#   'ECW position held Buckingham',
#   'Follow position held Sting',
#   'Welt position held Testament',
#   'Vienna position held Yokohama',
#   'Truth position held Rocca',
#   'Atene position held Billie',
#   'Qu position held Philippe',
#   'Sheila position held Notice',
#   'Laurel position held Legend',
#   'Tem position held String',
#   'Dhaka position held Worcester',
#   'Sophia position held Dewey',
#   'Move position held Welle',
#   'Yüksek position held Flow',
#   'Campione position held Rumble',
#   'Troy position held Silvio',
#   'Galatasaray position held Azul',
#   'Mitch position held Mallorca',
#   'Novel position held Beaufort',
#   'Ty position held Mines',
#   'Gallimard position held Randall',
#   'Pride position held Mighty',
#   'Newell position held Chao',
#   'Falun position held Snyder',
#   'Endre position held Bosch',
#   'Omer position held Angola',
#   'Nieto position held Ballet',
#   'Meredith position held Mart',
#   'Chandler position held Files',
#   'Faces position held Avant',
#   'FIA position held Superior',
#   'Sporting position held Belize',
#   'Marcus position held KZ',
#   'IS position held House',
#   'Forest position held Membre',
#   'Bologna position held Ille',
#   'Jos position held Lil',
#   'Carrillo position held Neville',
#   'Bremen position held Fargo',
#   'Chronicle position held Lager',
#   'SF position held Ajax',
#   'Première position held Teixeira',
#   'Bonnie position held Jacobus',
#   'Aladin position held Fel',
#   'Trade position held Hess',
#   'Berlijn position held Dio',
#   'Mens position held Monster',
#   'Independencia position held Common',
#   'Clint position held Universitas',
#   'Transit position held Derby',
#   'Media position held Esta',
#   'stb position held Cinderella',
#   'Cech position held Ariège',
#   'Foucault position held Phong',
#   'Eun position held Concord',
#   'Tarragona position held Bourgogne',
#   'UE position held Fell',
#   'Genera position held Galiza',
#   'Mister position held Limburg',
#   'Falkland position held Region',
#   'Temps position held Pi',
#   'Noord position held CBC',
#   'Câmara position held Charlotte',
#   'Belgrad position held Dezember',
#   'Har position held Grosso',
#   'Onthophagus position held Profil',
#   'Tau position held Males',
#   'RT position held Anjou',
#   'Abel position held Self',
#   'Israeli position held Pulau',
#   'Hague position held Hügel',
#   'Hitchcock position held Els',
#   'Enigma position held Atelier',
#   'Morgen position held Jagger',
#   'Atlantic position held Saba',
#   'Campo position held Mol',
#   'Karma position held Boer',
#   'Alben position held Rae',
#   'Dana position held Greg',
#   'Duncan position held Empire',
#   'Disse position held Daimler',
#   'Minas position held Bruno',
#   'EPA position held Banja',
#   'MV position held Erie',
#   'Quebec position held Nightmare',
#   'Männchen position held Figur',
#   'Hawaii position held Tampa',
#   'Llobregat position held AC',
#   'Title position held TM',
#   'Strand position held Bildhauer',
#   'Gwillim position held Loving',
#   ...]}

# %%
non_rels
# Out:
# ['Budapest place of publication Schumann',
#  'Foundation place of publication Castle',
#  'Membre place of publication Ruby',
#  'Panel place of publication IBM',
#  'Christchurch place of publication Broadcast',
#  'Yayasan place of publication Sound',
#  'Beatrice place of publication Tode',
#  'Malang place of publication Head',
#  'Austrian place of publication Selena',
#  'Lina place of publication Slovan',
#  'Companion venous drainage Porto',
#  'Gertrude venous drainage Ex',
#  'Roca venous drainage Netz',
#  'Nas venous drainage Neville',
#  'ACT venous drainage Karlsruhe',
#  'Liban venous drainage Scale',
#  'Walls venous drainage Gotham',
#  'EL venous drainage Os',
#  'Byrd venous drainage Commander',
#  'Mobile venous drainage PCR',
#  'Io supported metadata Lê',
#  'Suite supported metadata Court',
#  'Yunan supported metadata MGM',
#  'Hertfordshire supported metadata Leuven',
#  'Gallimard supported metadata Hartman',
#  'Eve supported metadata Tato',
#  'Stargate supported metadata Palestine',
#  'Earth supported metadata Field',
#  'Mei supported metadata Arlington',
#  'Camilla supported metadata Velázquez']
