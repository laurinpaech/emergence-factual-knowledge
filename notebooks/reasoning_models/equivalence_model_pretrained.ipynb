# %% [markdown]
# Investigate how much knowledge shares between aliases in the same language

# %%
import argparse
import copy

from transformers import BertForMaskedLM, BertTokenizer, TrainingArguments, Trainer, \
    DataCollatorForLanguageModeling, IntervalStrategy

from datasets import Dataset
import os

from data_generation_relation import *
from utils import *
from custom_trainer import CustomTrainer
from datasets import load_metric
import logging
from transformers import logging as tlogging
import wandb
import sys
from utils import set_seed
from transformers.integrations import WandbCallback, TensorBoardCallback
from tqdm.notebook import tqdm
from collections import Counter

os.environ["WANDB_DISABLED"] = "true"

# %%
set_seed(42)

run_name = 'EQUI_es_en_pretrained_target_wo_train'
epochs = 200
batch_size = 200
lr = 4e-5

relation = 'equivalence'
source_language = ['es']
target_language = ['en']
n_relations = 10
n_facts = 1000

use_random = False
use_anti = False

use_pretrained = True
use_target = True

# %%
train, test, relations = generate_reasoning(relation=Relation(relation),
                                            source_language=source_language,
                                            target_language=target_language,
                                            n_relations=n_relations,
                                            n_facts=n_facts,
                                            use_pretrained=use_pretrained,
                                            use_target=use_target,
                                            use_enhanced=False,
                                            use_same_relations=False,
                                            n_pairs=0)

relations
# Out:
#        _id                         en           en_alias  \
# 84   P4330                   contains       has contents
# 258  P8738                    permits  does not prohibit
# 45   P2872             visitor centre     tourist office
# 175   P915           filming location          filmed at
# 143  P1777                  manner of           style of
# 125  P2175  medical condition treated    disease treated
# 224  P1429                    has pet           owns pet
# 118    P69                educated at         studied at
# 9    P3173             offers view on        has view of
# 90   P2679         author of foreword        foreword by
#
#                                de              de_alias  \
# 84                        enthält                lagert
# 258                       erlaubt           autorisiert
# 45           Touristeninformation  Touristeninformation
# 175                       Drehort            gedreht in
# 143                  nach Art von         Nachahmer von
# 125    zur Behandlung von benutzt             behandelt
# 224                  hat Haustier             Haustiere
# 118  besuchte Bildungseinrichtung            Hochschule
# 9                bietet Sicht auf             Sicht auf
# 90             Autor des Vorworts           Vorwort von
#
#                            es                    fr                  fr_alias  \
# 84                   contiene              contient              contenant de
# 258                   permite                permet                  autorise
# 45         oficina de turismo    office de tourisme        office du tourisme
# 175        lugar de filmación      lieu du tournage          lieu de tournage
# 143            a la manera de       à la manière de                  style de
# 125  condición médica tratada       maladie traitée                    traite
# 224        animal de compañía   animal de compagnie  a un animal de compagnie
# 118                educado en             scolarité                 formation
# 9              ofrece vista a     offre une vue sur     offre un panorama sur
# 90         autor del prefacio  auteur de la préface  auteur de l'avant-propos
#
#                             es_alias    count
# 84                           alberga     8269
# 258                         autoriza       23
# 45   centro de información turística      554
# 175                  lugar de rodaje    32299
# 143                        manera de        9
# 125               enfermedad tratada     6992
# 224                 mascota (animal)      318
# 118                 lugar de estudio  2269402
# 9                      tiene vista a      905
# 90                      prefacio por     1543

# %%
relations_random = []

if use_random:
    # Generate half/half
    factor = 1.0
    n_random = factor * n_facts

    train_random, relations_random = generate_random(source_language, target_language, n_random, n_relations)
    train += train_random

relations_random
# Out:
# []

# %%
# LOADING
# Load mBERT model and Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertForMaskedLM.from_pretrained("bert-base-multilingual-cased")
#model = BertForMaskedLM.from_pretrained("./output/EQUI_en_de/models/checkpoint-38")

# Load Data Collator for Prediction and Evaluation
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)
eval_data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False)
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# ~~ PRE-PROCESSING ~~
# Only take test-facts of training set
train_testfacts = []
for i in range(n_relations):
    train_testfacts += train[1800+i*1900:(i+1)*1900]

train_dict = {'sample': train_testfacts}
test_dict = {'sample': flatten_dict2_list(copy.deepcopy(test))}
train_ds = Dataset.from_dict(train_dict)
test_ds = Dataset.from_dict(test_dict)

# Tokenize Training and Test Data
tokenized_train = tokenize(tokenizer, train_ds)  # Train is shuffled by Huggingface
tokenized_test = tokenize(tokenizer, test_ds)
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
len(train_testfacts)
# Out:
# 1000

# %%
# Save Train and Test Data
train_df = pd.DataFrame(train_dict)
test_complete_df = pd.DataFrame(test)
test_flat_df = pd.DataFrame(test_dict)

data_dir = './output/' + run_name + '/data/'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

train_df.to_csv(data_dir + 'train_set', index=False)
test_complete_df.to_json(data_dir + 'test_set_complete')
test_flat_df.to_csv(data_dir + 'test_set', index=False)

if use_random:
    train_random_df = pd.DataFrame({'sample': train_random})
    train_random_df.to_csv(data_dir + 'train_random', index=False)

if use_anti:
    train_anti_df = pd.DataFrame({'sample': train_anti})
    test_anti_df = pd.DataFrame({'sample': test_anti})

    train_anti_df.to_csv(data_dir + 'train_anti_set', index=False)
    test_anti_df.to_json(data_dir + 'test_anti_set')

# %%
training_args = TrainingArguments(
        output_dir='./output/' + run_name + '/models/',
        num_train_epochs=epochs,
        per_device_train_batch_size=batch_size,
        per_device_eval_batch_size=128,
        learning_rate=lr,
        logging_dir='./output/' + run_name + '/tb_logs/',
        logging_strategy=IntervalStrategy.STEPS,
        logging_steps=25,
        evaluation_strategy=IntervalStrategy.STEPS,
        eval_steps=25,
        save_strategy=IntervalStrategy.STEPS,
        save_steps=25,
        save_total_limit=2,
        load_best_model_at_end=True,
        metric_for_best_model='accuracy',
        seed=42
    )

trainer = CustomTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=tokenizer,
    data_collator=data_collator,
    eval_data_collator=eval_data_collator,
    compute_metrics=precision_at_one
)
# Out:
# Using the `WAND_DISABLED` environment variable is deprecated and will be removed in v5. Use the --report_to flag to control the integrations used for logging result (for instance --report_to none).

# %%
# Train
trainer.train()
# Out:
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1000
#   Num Epochs = 200
#   Instantaneous batch size per device = 200
#   Total train batch size (w. parallel, distributed & accumulation) = 400
#   Gradient Accumulation steps = 1
#   Total optimization steps = 600
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='600' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [600/600 07:31, Epoch 200/200]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>5.083300</td>
#       <td>9.594330</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>3.379000</td>
#       <td>8.941153</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.908800</td>
#       <td>8.400961</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.806800</td>
#       <td>7.981785</td>
#       <td>0.001000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>2.665700</td>
#       <td>7.689974</td>
#       <td>0.006000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.560200</td>
#       <td>7.487802</td>
#       <td>0.005000</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>2.569700</td>
#       <td>7.262722</td>
#       <td>0.009000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.507400</td>
#       <td>7.099851</td>
#       <td>0.010000</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>2.349300</td>
#       <td>6.907474</td>
#       <td>0.013000</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>2.300500</td>
#       <td>6.679919</td>
#       <td>0.012000</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>2.114300</td>
#       <td>6.467957</td>
#       <td>0.024000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>2.061300</td>
#       <td>6.167727</td>
#       <td>0.039000</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>1.962300</td>
#       <td>5.896714</td>
#       <td>0.063000</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>1.813600</td>
#       <td>5.603887</td>
#       <td>0.085000</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>1.718200</td>
#       <td>5.334783</td>
#       <td>0.123000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.705300</td>
#       <td>4.987658</td>
#       <td>0.153000</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>1.575000</td>
#       <td>4.747108</td>
#       <td>0.183000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>1.461400</td>
#       <td>4.523273</td>
#       <td>0.216000</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>1.373100</td>
#       <td>4.297771</td>
#       <td>0.238000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.294600</td>
#       <td>4.132075</td>
#       <td>0.267000</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>1.208600</td>
#       <td>3.969074</td>
#       <td>0.292000</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>1.241200</td>
#       <td>3.860914</td>
#       <td>0.308000</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>1.174800</td>
#       <td>3.773042</td>
#       <td>0.309000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.193800</td>
#       <td>3.740938</td>
#       <td>0.315000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25/special_tokens_map.json
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50/special_tokens_map.json
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-25] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-75] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-50] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-100] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-125] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-150] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-175] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-200] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-225] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-250] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-275] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-300] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-325] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-350] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-375] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-400] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-425] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-450] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-475] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-500] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-575
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-575/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-575/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-575/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-575/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-525] due to args.save_total_limit
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Saving model checkpoint to ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600
# Configuration saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600/config.json
# Model weights saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600/pytorch_model.bin
# tokenizer config file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600/tokenizer_config.json
# Special tokens file saved in ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600/special_tokens_map.json
# Deleting older checkpoint [output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-550] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./output/EQUI_es_en_pretrained_target_wo_train/models/checkpoint-600 (score: 0.315).
# TrainOutput(global_step=600, training_loss=2.126175111134847, metrics={'train_runtime': 453.5487, 'train_samples_per_second': 440.967, 'train_steps_per_second': 1.323, 'total_flos': 926290890000000.0, 'train_loss': 2.126175111134847, 'epoch': 200.0})

# %%
# Evaluate Test
trainer.evaluate(eval_dataset=tokenized_test)
# Out:
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='14' max='4' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/4 00:15]
#     </div>
# {'eval_accuracy': 0.315,
#  'eval_loss': 3.7409379482269287,
#  'eval_runtime': 1.2883,
#  'eval_samples_per_second': 776.237,
#  'eval_steps_per_second': 3.105,
#  'epoch': 200.0}

# %%
# Evaluation Equivalence per Relation
evaluation_equivalence_pretrained(trainer, tokenizer, relations, source_language, copy.deepcopy(test))
# Out:
# Relation - source: contiene, target: contains
# Alias - source: alberga, target: has contents
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.08, 'eval_loss': 5.053134441375732, 'eval_runtime': 0.572, 'eval_samples_per_second': 174.811, 'eval_steps_per_second': 1.748}
#
#
# Relation - source: permite, target: permits
# Alias - source: autoriza, target: does not prohibit
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.38, 'eval_loss': 3.3555798530578613, 'eval_runtime': 0.606, 'eval_samples_per_second': 165.021, 'eval_steps_per_second': 1.65}
#
#
# Relation - source: oficina de turismo, target: visitor centre
# Alias - source: centro de información turística, target: tourist office
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.29, 'eval_loss': 3.1613576412200928, 'eval_runtime': 0.5811, 'eval_samples_per_second': 172.079, 'eval_steps_per_second': 1.721}
#
#
# Relation - source: lugar de filmación, target: filming location
# Alias - source: lugar de rodaje, target: filmed at
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.06, 'eval_loss': 5.951961040496826, 'eval_runtime': 0.572, 'eval_samples_per_second': 174.816, 'eval_steps_per_second': 1.748}
#
#
# Relation - source: a la manera de, target: manner of
# Alias - source: manera de, target: style of
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.51, 'eval_loss': 3.0417585372924805, 'eval_runtime': 0.5655, 'eval_samples_per_second': 176.837, 'eval_steps_per_second': 1.768}
#
#
# Relation - source: condición médica tratada, target: medical condition treated
# Alias - source: enfermedad tratada, target: disease treated
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.32, 'eval_loss': 3.5118143558502197, 'eval_runtime': 0.6082, 'eval_samples_per_second': 164.429, 'eval_steps_per_second': 1.644}
#
#
# Relation - source: animal de compañía, target: has pet
# Alias - source: mascota (animal), target: owns pet
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.66, 'eval_loss': 1.602384090423584, 'eval_runtime': 0.5851, 'eval_samples_per_second': 170.917, 'eval_steps_per_second': 1.709}
#
#
# Relation - source: educado en, target: educated at
# Alias - source: lugar de estudio, target: studied at
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.37, 'eval_loss': 3.504098415374756, 'eval_runtime': 0.6036, 'eval_samples_per_second': 165.674, 'eval_steps_per_second': 1.657}
#
#
# Relation - source: ofrece vista a, target: offers view on
# Alias - source: tiene vista a, target: has view of
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.38, 'eval_loss': 3.2413220405578613, 'eval_runtime': 0.5765, 'eval_samples_per_second': 173.448, 'eval_steps_per_second': 1.734}
#
#
# Relation - source: autor del prefacio, target: author of foreword
# Alias - source: prefacio por, target: foreword by
#   0%|          | 0/1 [00:00<?, ?ba/s]
# /home/laurin/anaconda3/envs/master/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# {'eval_accuracy': 0.1, 'eval_loss': 4.985965728759766, 'eval_runtime': 0.5881, 'eval_samples_per_second': 170.028, 'eval_steps_per_second': 1.7}

# %% [markdown]
# ### Evaluate
# - Test my hypothesis if (f, r, e) or (e, r_de, f) exist more?
# - Is every relation symmetric now? What about relations that aren't part of the training?
# - If every relation is symmetric, try running with ANTI
# - And with General relations
# - Try Training with General and then evaluate general like on Anti!
# - Does that change the evaluation accuracy?
# - pretrained?
# - target?

# %%
model.to('cpu')
model.eval()
# Out:
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(119547, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (transform_act_fn): GELUActivation()
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=119547, bias=True)
#     )
#   )
# )

# %%
print(train_dict['sample'][:1901])
# Out:
# ['Medina taxonomischer Rang Italie', 'Italie taxonomischer Rang Medina', 'Invasion taxonomischer Rang Bora', 'Bora taxonomischer Rang Invasion', 'Burke taxonomischer Rang Hus', 'Hus taxonomischer Rang Burke', 'Drama taxonomischer Rang epi', 'epi taxonomischer Rang Drama', 'Master taxonomischer Rang Wilfried', 'Wilfried taxonomischer Rang Master', 'Dari taxonomischer Rang Fach', 'Fach taxonomischer Rang Dari', 'Chihuahua taxonomischer Rang Inge', 'Inge taxonomischer Rang Chihuahua', 'EP taxonomischer Rang Elite', 'Elite taxonomischer Rang EP', 'Chase taxonomischer Rang Portland', 'Portland taxonomischer Rang Chase', 'Worcester taxonomischer Rang Eliza', 'Eliza taxonomischer Rang Worcester', 'Albert taxonomischer Rang Weir', 'Weir taxonomischer Rang Albert', 'Ibiza taxonomischer Rang Antoine', 'Antoine taxonomischer Rang Ibiza', 'Câmara taxonomischer Rang Universitas', 'Universitas taxonomischer Rang Câmara', 'Eleanor taxonomischer Rang Collins', 'Collins taxonomischer Rang Eleanor', 'Campus taxonomischer Rang Condor', 'Condor taxonomischer Rang Campus', 'Schaus taxonomischer Rang Gospel', 'Gospel taxonomischer Rang Schaus', 'Chaos taxonomischer Rang MS', 'MS taxonomischer Rang Chaos', 'Alice taxonomischer Rang Ramsey', 'Ramsey taxonomischer Rang Alice', 'Franklin taxonomischer Rang Katz', 'Katz taxonomischer Rang Franklin', 'Colombo taxonomischer Rang Saussure', 'Saussure taxonomischer Rang Colombo', 'Graf taxonomischer Rang BRT', 'BRT taxonomischer Rang Graf', 'Darwin taxonomischer Rang Carioca', 'Carioca taxonomischer Rang Darwin', 'Nisan taxonomischer Rang Note', 'Note taxonomischer Rang Nisan', 'Hartman taxonomischer Rang Ultra', 'Ultra taxonomischer Rang Hartman', 'Lur taxonomischer Rang Né', 'Né taxonomischer Rang Lur', 'Fiesta taxonomischer Rang Fidel', 'Fidel taxonomischer Rang Fiesta', 'Alexandra taxonomischer Rang Einer', 'Einer taxonomischer Rang Alexandra', 'Mérida taxonomischer Rang Everybody', 'Everybody taxonomischer Rang Mérida', 'Shire taxonomischer Rang Pizza', 'Pizza taxonomischer Rang Shire', 'Anthology taxonomischer Rang Koska', 'Koska taxonomischer Rang Anthology', 'Monroe taxonomischer Rang Ariane', 'Ariane taxonomischer Rang Monroe', 'Hell taxonomischer Rang Exil', 'Exil taxonomischer Rang Hell', 'Bandet taxonomischer Rang Holy', 'Holy taxonomischer Rang Bandet', 'Bertrand taxonomischer Rang Haar', 'Haar taxonomischer Rang Bertrand', 'Drum taxonomischer Rang Ringo', 'Ringo taxonomischer Rang Drum', 'IBM taxonomischer Rang Theresa', 'Theresa taxonomischer Rang IBM', 'Christchurch taxonomischer Rang Zone', 'Zone taxonomischer Rang Christchurch', 'Broadcast taxonomischer Rang Benth', 'Benth taxonomischer Rang Broadcast', 'Clay taxonomischer Rang Baja', 'Baja taxonomischer Rang Clay', 'Sound taxonomischer Rang Ruska', 'Ruska taxonomischer Rang Sound', 'Liga taxonomischer Rang Seymour', 'Seymour taxonomischer Rang Liga', 'Vatican taxonomischer Rang ECW', 'ECW taxonomischer Rang Vatican', 'Libro taxonomischer Rang Bez', 'Bez taxonomischer Rang Libro', 'Vanderbilt taxonomischer Rang Ortes', 'Ortes taxonomischer Rang Vanderbilt', 'Austrian taxonomischer Rang Jessica', 'Jessica taxonomischer Rang Austrian', 'Varese taxonomischer Rang Zoom', 'Zoom taxonomischer Rang Varese', 'Ninja taxonomischer Rang Telephone', 'Telephone taxonomischer Rang Ninja', 'Lafayette taxonomischer Rang A', 'A taxonomischer Rang Lafayette', 'Catalina taxonomischer Rang Barra', 'Barra taxonomischer Rang Catalina', 'Companion taxonomischer Rang Lori', 'Lori taxonomischer Rang Companion', 'Marshal taxonomischer Rang Reeves', 'Reeves taxonomischer Rang Marshal', 'Molina taxonomischer Rang Wagen', 'Wagen taxonomischer Rang Molina', 'Dow taxonomischer Rang Sound', 'Sound taxonomischer Rang Dow', 'Platte taxonomischer Rang JR', 'JR taxonomischer Rang Platte', 'Giant taxonomischer Rang Trail', 'Trail taxonomischer Rang Giant', 'Mulder taxonomischer Rang Concordia', 'Concordia taxonomischer Rang Mulder', 'Hancock taxonomischer Rang Windows', 'Wind ...

# %%
test_dict['sample']
# Out:
# ['Raymond taxon rank Haji',
#  'Chinese taxon rank Yahoo',
#  'West taxon rank Stal',
#  'Rhode taxon rank FC',
#  'Libro taxon rank Dad',
#  'Weaver taxon rank Kenia',
#  'Limited taxon rank CCD',
#  'NO taxon rank Riau',
#  'Frères taxon rank Ky',
#  'Li taxon rank Billie',
#  'Pie taxon rank Elbe',
#  'DSM taxon rank Paraíso',
#  'Björn taxon rank TD',
#  'Elsevier taxon rank Luther',
#  'Isabel taxon rank Roi',
#  'Valence taxon rank Pole',
#  'Townsend taxon rank Page',
#  'Levant taxon rank Baron',
#  'Khan taxon rank Libia',
#  'Ward taxon rank Cuenca',
#  'Valladolid taxon rank Kálmán',
#  'Kristen taxon rank ET',
#  'Allende taxon rank Mainstream',
#  'Malden taxon rank Agency',
#  'Ekim taxon rank Mata',
#  'Norris taxon rank Mineral',
#  'Entangled taxon rank Figaro',
#  'Nico taxon rank Trung',
#  'NME taxon rank Sabha',
#  'Christi taxon rank Guimarães',
#  'Laurel taxon rank Disneyland',
#  'Hammer taxon rank Wes',
#  'Desse taxon rank Gesù',
#  'Albany taxon rank Cinq',
#  'Hollow taxon rank Silla',
#  'Music taxon rank JR',
#  'Munro taxon rank Bryant',
#  'Loving taxon rank Klaus',
#  'Sun taxon rank Kleiner',
#  'Ros taxon rank Fort',
#  'Marie taxon rank City',
#  'Libération taxon rank Márquez',
#  'Mass taxon rank Yer',
#  'Liu taxon rank Bernard',
#  'Belgium taxon rank Diaz',
#  'Edouard taxon rank Madre',
#  'te taxon rank Asturias',
#  'Brabant taxon rank FF',
#  'Quick taxon rank Dis',
#  'Primavera taxon rank Lorentz',
#  'Tito taxon rank SM',
#  'Jubilee taxon rank Sempre',
#  'Nassau taxon rank Portsmouth',
#  'Nexus taxon rank Irena',
#  'Hiroshima taxon rank Oaks',
#  'Jenny taxon rank Fighting',
#  'Cardoso taxon rank Bilbao',
#  'Rusi taxon rank Sharon',
#  'Silvio taxon rank Allium',
#  'Scots taxon rank Haiti',
#  'Helmut taxon rank Isabella',
#  'Novel taxon rank Olsson',
#  'KM taxon rank Pure',
#  'Industria taxon rank Patrol',
#  'ap taxon rank Siege',
#  'Frères taxon rank Galiza',
#  'RN taxon rank Lucky',
#  'Gilbert taxon rank Pfeiffer',
#  'Bachelor taxon rank FX',
#  'GNU taxon rank Energy',
#  'UE taxon rank Joanne',
#  'Hamm taxon rank Erik',
#  'Rua taxon rank EM',
#  'Ike taxon rank Raum',
#  'Velvet taxon rank VL',
#  'Levant taxon rank Sabina',
#  'Spin taxon rank Krupp',
#  'Franz taxon rank October',
#  'SAR taxon rank Davidson',
#  'Taurus taxon rank Allah',
#  'Denne taxon rank Larva',
#  'Pizarro taxon rank Khu',
#  'Sunrise taxon rank Lahore',
#  'Burlington taxon rank Dorset',
#  'Invasion taxon rank Stay',
#  'Wiesbaden taxon rank Sit',
#  'Oregon taxon rank Wayne',
#  'Jess taxon rank Flag',
#  'Trees taxon rank Ferns',
#  'Norris taxon rank Jaguar',
#  'Raoul taxon rank Brenda',
#  'Neu taxon rank Mina',
#  'Gia taxon rank Harding',
#  'Pisa taxon rank Giants',
#  'State taxon rank Buta',
#  'Hidden taxon rank Faye',
#  'Mill taxon rank Generation',
#  'Everett taxon rank Schottland',
#  'Birinci taxon rank USD',
#  'Sparks taxon rank Eu',
#  'Eugenia emergency services Haji',
#  'Ocak emergency services Yahoo',
#  'Astor emergency services Stal',
#  'Piero emergency services FC',
#  'Juli emergency services Dad',
#  'Nina emergency services Kenia',
#  'Tower emergency services CCD',
#  'Sigurd emergency services Riau',
#  'Lopes emergency services Ky',
#  'Bertram emergency services Billie',
#  'Billy emergency services Elbe',
#  'Man emergency services Paraíso',
#  'Naga emergency services TD',
#  'Antonio emergency services Luther',
#  'Shadows emergency services Roi',
#  'CPU emergency services Pole',
#  'Maxime emergency services Page',
#  'Angel emergency services Baron',
#  'Norsk emergency services Libia',
#  'Bron emergency services Cuenca',
#  'Wagen emergency services Kálmán',
#  'Nella emergency services ET',
#  'Issue emergency services Mainstream',
#  'Sono emergency services Agency',
#  'Sherwood emergency services Mata',
#  'Freddie emergency services Mineral',
#  'ANC emergency services Figaro',
#  'Mama emergency services Trung',
#  'Mills emergency services Sabha',
#  'Juventus emergency services Guimarães',
#  'TM emergency services Disneyland',
#  'Hammer emergency services Wes',
#  'Ferguson emergency services Gesù',
#  'Primer emergency services Cinq',
#  'Dublin emergency services Silla',
#  'Ballet emergency services JR',
#  'Scholar emergency services Bryant',
#  'Squadron emergency services Klaus',
#  'Kur emergency services Kleiner',
#  'Twain emergency services Fort',
#  'Alexa emergency services City',
#  'Choice emergency services Márquez',
#  'Teater emergency services Yer',
#  'England emergency services Bernard',
#  'Lopes emergency services Diaz',
#  'Nirvana emergency services Madre',
#  'Home emergency services Asturias',
#  'Rookie emergency services FF',
#  'Jesus emergency services Dis',
#  'Nota emergency services Lorentz',
#  'Carpenter emergency services SM',
#  'Calderón emergency services Sempre',
#  'RN emergency services Portsmouth',
#  'Miracle emergency services Irena',
#  'Alpi emergency services Oaks',
#  'President emergency services Fighting',
#  'Caesar emergency services Bilbao',
#  'Cádiz emergency services Sharon',
#  'Animal emergency services Allium',
#  'Powell emergency services Haiti',
#  'Penelope emergency services Isabella',
#  'Braga emergency services Olsson',
#  'Kamen emergency services Pure',
#  'Lindl emergency services Patrol',
#  'Roberts emergency services Siege',
#  'Sofia emergency services Galiza',
#  'Pitt emergency services Lucky',
#  'Esther emergency services Pfeiffer',
#  'Villiers emergency services FX',
#  'CAS emergency services Energy',
#  'Rutherford emergency services Joanne',
#  'Alvin emergency services Erik',
#  'Fritz emergency services EM',
#  'Ferreira emergency services Raum',
#  'Imperium emergency services VL',
#  'Rollins emergency services Sabina',
#  'Peck emergency services Krupp',
#  'Osman emergency services October',
#  'Cidade emergency services Davidson',
#  'Regional emergency services Allah',
#  'Gunung emergency services Larva',
#  'Cu emergency services Khu',
#  'Holocaust emergency services Lahore',
#  'Return emergency services Dorset',
#  'Kemp emergency services Stay',
#  'Late emergency services Sit',
#  'Rayon emergency services Wayne',
#  'Joy emergency services Flag',
#  'Graves emergency services Ferns',
#  'Bavaria emergency services Jaguar',
#  'Norwich emergency services Brenda',
#  'Advance emergency services Mina',
#  'Illusion emergency services Harding',
#  'Nice emergency services Giants',
#  'BL emergency services Buta',
#  'Kinos emergency services Faye',
#  'Severus emergency services Generation',
#  'Lowell emergency services Schottland',
#  'Ole emergency services USD',
#  'Platinum emergency services Eu',
#  'Zo color Haji',
#  'Odin color Yahoo',
#  'Cardiff color Stal',
#  'Linh color FC',
#  'Plains color Dad',
#  'Irena color Kenia',
#  'Montpellier color CCD',
#  'Manor color Riau',
#  'Trung color Ky',
#  'Frères color Billie',
#  'Cash color Elbe',
#  'Far color Paraíso',
#  'Pleasure color TD',
#  'Aid color Luther',
#  'Rioja color Roi',
#  'UD color Pole',
#  'CC color Page',
#  'Cambridge color Baron',
#  'Teddy color Libia',
#  'Crown color Cuenca',
#  'Bing color Kálmán',
#  'Face color ET',
#  'Marne color Mainstream',
#  'Hawker color Agency',
#  'Parry color Mata',
#  'Borussia color Mineral',
#  'Greece color Figaro',
#  'Telephone color Trung',
#  'MBA color Sabha',
#  'Latreille color Guimarães',
#  'Principal color Disneyland',
#  'Dad color Wes',
#  'Belfast color Gesù',
#  'Ages color Cinq',
#  'Massacre color Silla',
#  'Hub color JR',
#  'Newton color Bryant',
#  'Stand color Klaus',
#  'McKamey color Kleiner',
#  'Powers color Fort',
#  'Leta color City',
#  'Mad color Márquez',
#  'Samba color Yer',
#  'Senators color Bernard',
#  'Fel color Diaz',
#  'Hughes color Madre',
#  'Potok color Asturias',
#  'Maxim color FF',
#  'Winter color Dis',
#  'Morley color Lorentz',
#  'Bassa color SM',
#  'Bush color Sempre',
#  'Train color Portsmouth',
#  'Marea color Irena',
#  'Mahler color Oaks',
#  'Kati color Fighting',
#  'Lyle color Bilbao',
#  'Preto color Sharon',
#  'Königsberg color Allium',
#  'Uit color Haiti',
#  'Farm color Isabella',
#  'Midden color Olsson',
#  'Chicago color Pure',
#  'Dol color Patrol',
#  'Pero color Siege',
#  'Toten color Galiza',
#  'Tears color Lucky',
#  'Minister color Pfeiffer',
#  'Valenciana color FX',
#  'Dunkerque color Energy',
#  'Sartre color Joanne',
#  'Front color Erik',
#  'CAF color EM',
#  'WR color Raum',
#  'Donovan color VL',
#  'Bey color Sabina',
#  'Alexa color Krupp',
#  'Porter color October',
#  'Euro color Davidson',
#  'Shri color Allah',
#  'Atelier color Larva',
#  'Classic color Khu',
#  'Noche color Lahore',
#  'Cavendish color Dorset',
#  'Sinh color Stay',
#  'Sports color Sit',
#  'Denne color Wayne',
#  'Sonntag color Flag',
#  'Terceira color Ferns',
#  'Au color Jaguar',
#  'Jammu color Brenda',
#  'Carnaval color Mina',
#  'Ferreira color Harding',
#  'Fenner color Giants',
#  'Vader color Buta',
#  'Bray color Faye',
#  'Barnard color Generation',
#  'Earl color Schottland',
#  'Manu color USD',
#  'Dara color Eu',
#  'Wesley expected completeness Haji',
#  'Hai expected completeness Yahoo',
#  'Wilder expected completeness Stal',
#  'Porter expected completeness FC',
#  'Mirage expected completeness Dad',
#  'Dharma expected completeness Kenia',
#  'Santo expected completeness CCD',
#  'Josep expected completeness Riau',
#  'Burgess expected completeness Ky',
#  'Mortimer expected completeness Billie',
#  'Zbigniew expected completeness Elbe',
#  'Design expected completeness Paraíso',
#  'Hotel expected completeness TD',
#  'Robot expected completeness Luther',
#  'Guayaquil expected completeness Roi',
#  'Laurie expected completeness Pole',
#  'Vittoria expected completeness Page',
#  'Motion expected completeness Baron',
#  'Cor expected completeness Libia',
#  'Naga expected completeness Cuenca',
#  'Alexa expected completeness Kálmán',
#  'WBC expected completeness ET',
#  'Collins expected completeness Mainstream',
#  'Akademie expected completeness Agency',
#  'Faber expected completeness Mata',
#  'Cullen expected completeness Mineral',
#  'Hiroshima expected completeness Figaro',
#  'Auckland expected completeness Trung',
#  'Belmont expected completeness Sabha',
#  'RCA expected completeness Guimarães',
#  'Träger expected completeness Disneyland',
#  'CC expected completeness Wes',
#  'Deus expected completeness Gesù',
#  'Mustang expected completeness Cinq',
#  'Benjamin expected completeness Silla',
#  'Ronnie expected completeness JR',
#  'AD expected completeness Bryant',
#  'Oru expected completeness Klaus',
#  'Baronet expected completeness Kleiner',
#  'Nos expected completeness Fort',
#  'Certain expected completeness City',
#  'Kid expected completeness Márquez',
#  'Ami expected completeness Yer',
#  'AVN expected completeness Bernard',
#  'Maya expected completeness Diaz',
#  'Oasis expected completeness Madre',
#  'Ordu expected completeness Asturias',
#  'FAA expected completeness FF',
#  'Automatic expected completeness Dis',
#  'Chronicle expected completeness Lorentz',
#  'NH expected completeness SM',
#  'Door expected completeness Sempre',
#  'Profil expected completeness Portsmouth',
#  'Words expected completeness Irena',
#  'PE expected completeness Oaks',
#  'Hamar expected completeness Fighting',
#  'Ribera expected completeness Bilbao',
#  'Crash expected completeness Sharon',
#  'Stella expected completeness Allium',
#  'Béla expected completeness Haiti',
#  'Ferro expected completeness Isabella',
#  'Writer expected completeness Olsson',
#  'Aviation expected completeness Pure',
#  'da expected completeness Patrol',
#  'Hercules expected completeness Siege',
#  'Elmi expected completeness Galiza',
#  'Heide expected completeness Lucky',
#  'Armstrong expected completeness Pfeiffer',
#  'Remote expected completeness FX',
#  'Nagar expected completeness Energy',
#  'Moro expected completeness Joanne',
#  'Ami expected completeness Erik',
#  'CL expected completeness EM',
#  'Toren expected completeness Raum',
#  'Ph expected completeness VL',
#  'Margaretha expected completeness Sabina',
#  'Heide expected completeness Krupp',
#  'Banja expected completeness October',
#  'Spot expected completeness Davidson',
#  'Elias expected completeness Allah',
#  'LP expected completeness Larva',
#  'ML expected completeness Khu',
#  'Wait expected completeness Lahore',
#  'Rome expected completeness Dorset',
#  'Citizen expected completeness Stay',
#  'Allier expected completeness Sit',
#  'Hava expected completeness Wayne',
#  'Sada expected completeness Flag',
#  'Era expected completeness Ferns',
#  'Graham expected completeness Jaguar',
#  'Tone expected completeness Brenda',
#  'Madeleine expected completeness Mina',
#  'Midnight expected completeness Harding',
#  'GDP expected completeness Giants',
#  'Salt expected completeness Buta',
#  'Sima expected completeness Faye',
#  'Steinicke expected completeness Generation',
#  'Nové expected completeness Schottland',
#  'Checa expected completeness USD',
#  'Stanley expected completeness Eu',
#  'Canadá measured physical quantity Haji',
#  'Garden measured physical quantity Yahoo',
#  'Walters measured physical quantity Stal',
#  'Salon measured physical quantity FC',
#  'Canada measured physical quantity Dad',
#  'Cambridge measured physical quantity Kenia',
#  'Az measured physical quantity CCD',
#  'Ne measured physical quantity Riau',
#  'Bulu measured physical quantity Ky',
#  'Cramer measured physical quantity Billie',
#  'Speedway measured physical quantity Elbe',
#  'Paderborn measured physical quantity Paraíso',
#  'Hazel measured physical quantity TD',
#  'Ipswich measured physical quantity Luther',
#  'Nowe measured physical quantity Roi',
#  'Foi measured physical quantity Pole',
#  'Powers measured physical quantity Page',
#  'Ingles measured physical quantity Baron',
#  'Welsh measured physical quantity Libia',
#  'Ludwik measured physical quantity Cuenca',
#  'Wedding measured physical quantity Kálmán',
#  'Ludovic measured physical quantity ET',
#  'Genus measured physical quantity Mainstream',
#  'Fortuna measured physical quantity Agency',
#  'Norris measured physical quantity Mata',
#  'MC measured physical quantity Mineral',
#  'Mass measured physical quantity Figaro',
#  'Thái measured physical quantity Trung',
#  'Fresno measured physical quantity Sabha',
#  'Bresse measured physical quantity Guimarães',
#  'Essex measured physical quantity Disneyland',
#  'Conte measured physical quantity Wes',
#  'Deeds measured physical quantity Gesù',
#  'Woods measured physical quantity Cinq',
#  'Lara measured physical quantity Silla',
#  'Perdana measured physical quantity JR',
#  'Shanghai measured physical quantity Bryant',
#  'IRAS measured physical quantity Klaus',
#  'Music measured physical quantity Kleiner',
#  'Aiken measured physical quantity Fort',
#  'Zion measured physical quantity City',
#  'Hardy measured physical quantity Márquez',
#  'While measured physical quantity Yer',
#  'Cuenca measured physical quantity Bernard',
#  'Wittgenstein measured physical quantity Diaz',
#  'Chatham measured physical quantity Madre',
#  'Hertfordshire measured physical quantity Asturias',
#  'Em measured physical quantity FF',
#  'Velázquez measured physical quantity Dis',
#  'Barrett measured physical quantity Lorentz',
#  'Kensley measured physical quantity SM',
#  'Bartlett measured physical quantity Sempre',
#  'Aves measured physical quantity Portsmouth',
#  'Phantom measured physical quantity Irena',
#  'Lori measured physical quantity Oaks',
#  'Lors measured physical quantity Fighting',
#  'Gutenberg measured physical quantity Bilbao',
#  'Dänemark measured physical quantity Sharon',
#  'Sá measured physical quantity Allium',
#  'Oman measured physical quantity Haiti',
#  'EN measured physical quantity Isabella',
#  'Gate measured physical quantity Olsson',
#  'Ticino measured physical quantity Pure',
#  'Eclipse measured physical quantity Patrol',
#  'UCB measured physical quantity Siege',
#  'Arcade measured physical quantity Galiza',
#  'Buzz measured physical quantity Lucky',
#  'Renault measured physical quantity Pfeiffer',
#  'Laval measured physical quantity FX',
#  'Molina measured physical quantity Energy',
#  'RN measured physical quantity Joanne',
#  'Monmouth measured physical quantity Erik',
#  'Turin measured physical quantity EM',
#  'Smith measured physical quantity Raum',
#  'Hume measured physical quantity VL',
#  'Gan measured physical quantity Sabina',
#  'Rotten measured physical quantity Krupp',
#  'Poet measured physical quantity October',
#  'Assembly measured physical quantity Davidson',
#  'Toren measured physical quantity Allah',
#  'Roberto measured physical quantity Larva',
#  'Beatrice measured physical quantity Khu',
#  'Mario measured physical quantity Lahore',
#  'SR measured physical quantity Dorset',
#  'Marge measured physical quantity Stay',
#  'Weir measured physical quantity Sit',
#  'Adobe measured physical quantity Wayne',
#  'Hallan measured physical quantity Flag',
#  'Viscount measured physical quantity Ferns',
#  'Dante measured physical quantity Jaguar',
#  'Sarmiento measured physical quantity Brenda',
#  'Nikolaj measured physical quantity Mina',
#  'Lamarck measured physical quantity Harding',
#  'Safe measured physical quantity Giants',
#  'UN measured physical quantity Buta',
#  'Edmonton measured physical quantity Faye',
#  'Zelda measured physical quantity Generation',
#  'Planck measured physical quantity Schottland',
#  'Ne measured physical quantity USD',
#  'Isle measured physical quantity Eu']

# %% [markdown]
# #### -> Test my hypothesis if (e, s, f) or (e, r_de, f) exist more?

# %% [markdown]
# Evaluate if for (e, r, f) we know more often (e, r_de, f) or (e, s, f), i.e. Knowledge Transfer vs symmetric rule.
# This can also help us understand which way we get (e, s_de, f).
#
# Since when we train on (e, r_de, f), we rarer get (e, s_de, f), it already implies that we would go the way:
# (e, r, f) -RULE-> (e, s, f) -KT-> (e, s_de, f)
#
# 1800 facts are training the rule (900<->900)
# 1800-1900 are facts that are used for testing

# %%
def compute_overlap(a, b):
    a_multiset = Counter(a)
    b_multiset = Counter(b)

    overlap = list((a_multiset & b_multiset).elements())
    
    return overlap

# %%
# Iterate over relations, take the training samples that were trained on
for (idx1, relation1), (idx2, relation2) in relations:
    trained_test = train_dict['sample'][1800+i*1900:(i+1)*1900]

    acc_r = 0
    correct_entities_r = []
    
    acc_rde = 0
    correct_entities_rde = []
    
    acc_test = 0
    correct_entities_test = []
    
    r = relation1['en'].iloc[i]
    r_t = relation1['de'].iloc[i]
    s = relation2['en'].iloc[i]
    s_t = relation2['de'].iloc[i]
    
    # trained_test are test-facts
    for sample in trained_test:

        # Test (e, s, f)
        e = sample.split(' ', 1)[0]
        f = sample.rsplit(' ', 1)[1]
        
        label_token = tokenizer.convert_tokens_to_ids(f)

        prompt = e + ' ' + s + ' [MASK]'
        # print(prompt)

        encoded_input = tokenizer(prompt, return_tensors='pt')
        token_logits = model(**encoded_input).logits

        mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
        mask_token_logits = token_logits[0, mask_token_index, :]

        # Pick the [MASK] candidates with the highest logits
        top_1_token = torch.topk(mask_token_logits, 1, dim=1).indices[0].tolist()[0]

        if label_token == top_1_token:
            acc_s += 1
            correct_entities_s.append(f)

        # Test (e, r_de, f)
        label_token = tokenizer.convert_tokens_to_ids(f)

        prompt = e + ' ' + r_t + ' [MASK]'
        # print(prompt)

        encoded_input = tokenizer(prompt, return_tensors='pt')
        token_logits = model(**encoded_input).logits

        mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
        mask_token_logits = token_logits[0, mask_token_index, :]

        # Pick the [MASK] candidates with the highest logits
        top_1_token = torch.topk(mask_token_logits, 1, dim=1).indices[0].tolist()[0]

        if label_token == top_1_token:
            acc_rde += 1
            correct_entities_rde.append(f)
            
        # Test (e, s_de, f)
        label_token = tokenizer.convert_tokens_to_ids(f)

        prompt = e + ' ' + s_t + ' [MASK]'
        # print(prompt)

        encoded_input = tokenizer(prompt, return_tensors='pt')
        token_logits = model(**encoded_input).logits

        mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
        mask_token_logits = token_logits[0, mask_token_index, :]

        # Pick the [MASK] candidates with the highest logits
        top_1_token = torch.topk(mask_token_logits, 1, dim=1).indices[0].tolist()[0]

        if label_token == top_1_token:
            acc_test += 1
            correct_entities_test.append(f)
        

    acc_s /= 100
    acc_rde /= 100
    acc_test /= 100

    print(f'Relation1: {r}')
    print(f'Relation1 Target: {r_t}')
    print(f'Relation2: {s}')
    print(f'Relation2 Target: {s_t}')
    
    print(f'Accuracy for SR (e, s, f): {acc_s}')
    print(f'Accuracy for FKT (e, r_t, f): {acc_rde}')
    print(f'Accuracy for FKT->SR (e, s_t, f): {acc_test}')
    print(f'Size (e, s, f): {len(correct_entities_s)}')
    print(f'Size (e, r_t, f): {len(correct_entities_rde)}')
    print(f'Overlap between (e, s, f) and (e, r_t, f): {len(compute_overlap(correct_entities_s, correct_entities_rde))}')
    if len(correct_entities_rde) == 0:
        print(f'Transfer from (e, r_t, f) to (e, s_t, f): {0}')
    else:
        print(f'Transfer from (e, r_t, f) to (e, s_t, f): {len(compute_overlap(correct_entities_rde, correct_entities_test))/len(correct_entities_rde)}')
    
    if len(correct_entities_s) == 0:
        print(f'Transfer from (e, s, f) to (e, s_t, f): {0}')
    else:
        print(f'Transfer from (e, s, f) to (e, s_t, f): {len(compute_overlap(correct_entities_s, correct_entities_test))/len(correct_entities_s)}')
    print('')
# Out:
# Relation: taxonomischer Rang
# Relation Target: taxon rank
# Accuracy for (f, r, e): 0.73
# Accuracy for (e, r_t, f): 0.62
# Accuracy for (f, r_t, e): 0.63
# Size (f, r, e): 73
# Size (e, r_t, f): 62
# Overlap between (f, r, e) and (e, r_t, f): 49
# Transfer from (e, r_t, f) to (f, r_t, e): 0.6774193548387096
# Transfer from (f, r, e) to (f, r_t, e): 0.8356164383561644
#
# Relation: Notfalleinrichtungen
# Relation Target: emergency services
# Accuracy for (f, r, e): 0.81
# Accuracy for (e, r_t, f): 0.21
# Accuracy for (f, r_t, e): 0.6
# Size (f, r, e): 81
# Size (e, r_t, f): 21
# Overlap between (f, r, e) and (e, r_t, f): 17
# Transfer from (e, r_t, f) to (f, r_t, e): 0.6190476190476191
# Transfer from (f, r, e) to (f, r_t, e): 0.7283950617283951
#
# Relation: Farbe
# Relation Target: color
# Accuracy for (f, r, e): 0.71
# Accuracy for (e, r_t, f): 0.9
# Accuracy for (f, r_t, e): 0.71
# Size (f, r, e): 71
# Size (e, r_t, f): 90
# Overlap between (f, r, e) and (e, r_t, f): 63
# Transfer from (e, r_t, f) to (f, r_t, e): 0.7
# Transfer from (f, r, e) to (f, r_t, e): 1.0
#
# Relation: erwartete Vollständigkeit
# Relation Target: expected completeness
# Accuracy for (f, r, e): 0.72
# Accuracy for (e, r_t, f): 0.02
# Accuracy for (f, r_t, e): 0.45
# Size (f, r, e): 72
# Size (e, r_t, f): 2
# Overlap between (f, r, e) and (e, r_t, f): 1
# Transfer from (e, r_t, f) to (f, r_t, e): 0.0
# Transfer from (f, r, e) to (f, r_t, e): 0.6111111111111112
#
# Relation: gemessene physikalische Größe
# Relation Target: measured physical quantity
# Accuracy for (f, r, e): 0.69
# Accuracy for (e, r_t, f): 0.14
# Accuracy for (f, r_t, e): 0.55
# Size (f, r, e): 69
# Size (e, r_t, f): 14
# Overlap between (f, r, e) and (e, r_t, f): 7
# Transfer from (e, r_t, f) to (f, r_t, e): 0.5
# Transfer from (f, r, e) to (f, r_t, e): 0.7391304347826086

# %% [markdown]
# ### Manual

# %%
k = 0
total = len(train_dict['sample'])
i = 0

for txt in train_dict['sample'][:10000]:
    i += 1
    
    # Add [MASK] for object
    sample = txt.rsplit(' ', 1)[0] + ' [MASK]'
    label_token = tokenizer.convert_tokens_to_ids(txt.rsplit(' ', 1)[1])
    
    encoded_input = tokenizer(sample, return_tensors='pt')
    token_logits = model(**encoded_input).logits
    
    mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
    mask_token_logits = token_logits[0, mask_token_index, :]
    
    # Pick the [MASK] candidates with the highest logits
    top_5_tokens = torch.topk(mask_token_logits, 1, dim=1).indices[0].tolist()
    
    if label_token in top_5_tokens:
        k += 1
print(k/i)
# Out:
# 0.8829473684210526

# %%
text = "lens manner of [MASK]"
encoded_input = tokenizer(text, return_tensors='pt')
token_logits = model(**encoded_input).logits

mask_token_index = torch.where(encoded_input["input_ids"] == tokenizer.mask_token_id)[1]
mask_token_logits = token_logits[0, mask_token_index, :]

# Pick the [MASK] candidates with the highest logits
top_5_tokens = torch.topk(mask_token_logits, 5, dim=1).indices[0].tolist()

for chunk in top_5_tokens:
    print(f"\n>>> {tokenizer.decode([chunk])}")

# %%
for t in train_dict['sample']:
    if 'Alex' in t:
        print(t)

# %% [markdown]
# ### Results
#
# - Training with just symmetric, doesn't necessarily mean that everything is symmetric. Maybe BERT in Symbolic Reasoner was just overfitting since it isnt finetuning but actually pretraining, i.e. it never sees evidence of non symmetry but a lot of symmetry.
#
#
#
# - See Obsidian
