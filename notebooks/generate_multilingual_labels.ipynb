# %%
import pandas as pd
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
from transformers import TrainingArguments, DataCollatorForLanguageModeling, IntervalStrategy

# %%
# Load entities
entities = pd.read_csv('../data/entities/SingleToken/entities_languageAgnostic_clean.csv')

# Load relations
relations = pd.read_json('../data/knowledge/properties_w_aliases_full_cleaned.json')

# %%
entities = pd.read_csv('../data/entities/SingleToken/multilingual/en_ja.csv')
entities
# Out:
#      Unnamed: 0         id       en    ja
# 0             0    Q230634     Asia   アジア
# 1             1    Q383842   Africa  アフリカ
# 2             2   Q4742725  America  アメリカ
# 3             3   Q1572339    Album  アルバム
# 4             4    Q233567   Italia  イタリア
# ..          ...        ...      ...   ...
# 550         550  Q10931275       Mo     墨
# 551         551   Q1204499     Ding     鼎
# 552         552   Q2751034    mouse     鼠
# 553         553      Q7363     nose     鼻
# 554         554   Q2772822     Long     龍
#
# [555 rows x 4 columns]

# %%
entities = entities.drop(['Unnamed: 0'], axis=1)
entities
# Out:
#             id       en    ja
# 0      Q230634     Asia   アジア
# 1      Q383842   Africa  アフリカ
# 2     Q4742725  America  アメリカ
# 3     Q1572339    Album  アルバム
# 4      Q233567   Italia  イタリア
# ..         ...      ...   ...
# 550  Q10931275       Mo     墨
# 551   Q1204499     Ding     鼎
# 552   Q2751034    mouse     鼠
# 553      Q7363     nose     鼻
# 554   Q2772822     Long     龍
#
# [555 rows x 3 columns]

# %%
entities.to_csv('../data/entities/SingleToken/multilingual/en_ja.csv', index=False)

# %%
p_dict = get_entity_dict_from_api('Q144')
p_dict['labels']
# Out:
# {'en': {'language': 'en', 'value': 'dog'},
#  'fr': {'language': 'fr', 'value': 'chien'},
#  'it': {'language': 'it', 'value': 'cane'},
#  'nb': {'language': 'nb', 'value': 'tamhund'},
#  'be-tarask': {'language': 'be-tarask', 'value': 'сабака'},
#  'yue': {'language': 'yue', 'value': '狗'},
#  'sgs': {'language': 'sgs', 'value': 'Šova'},
#  'nan': {'language': 'nan', 'value': 'Káu'},
#  'nds-nl': {'language': 'nds-nl', 'value': 'Hond'},
#  'vro': {'language': 'vro', 'value': 'Pini'},
#  'de': {'language': 'de', 'value': 'Hund'},
#  'br': {'language': 'br', 'value': 'ki'},
#  'ru': {'language': 'ru', 'value': 'собака'},
#  'hif': {'language': 'hif', 'value': 'Kuttaa'},
#  'es': {'language': 'es', 'value': 'perro'},
#  'ab': {'language': 'ab', 'value': 'Ала'},
#  'ace': {'language': 'ace', 'value': 'Asèë'},
#  'af': {'language': 'af', 'value': 'hond'},
#  'am': {'language': 'am', 'value': 'ውሻ'},
#  'an': {'language': 'an', 'value': 'Canis lupus familiaris'},
#  'arc': {'language': 'arc', 'value': 'ܟܠܒܐ'},
#  'ar': {'language': 'ar', 'value': 'كلب'},
#  'arz': {'language': 'arz', 'value': 'كلب'},
#  'ast': {'language': 'ast', 'value': 'perru'},
#  'av': {'language': 'av', 'value': 'Гьой'},
#  'ay': {'language': 'ay', 'value': 'Anu'},
#  'az': {'language': 'az', 'value': 'Köpək'},
#  'bar': {'language': 'bar', 'value': 'Hund'},
#  'ba': {'language': 'ba', 'value': 'Эт'},
#  'bcl': {'language': 'bcl', 'value': 'Ayam'},
#  'be': {'language': 'be', 'value': 'сабака свойскі'},
#  'bg': {'language': 'bg', 'value': 'куче'},
#  'bjn': {'language': 'bjn', 'value': 'Hadupan'},
#  'bm': {'language': 'bm', 'value': 'Wùlù'},
#  'bn': {'language': 'bn', 'value': 'কুকুর'},
#  'bo': {'language': 'bo', 'value': 'ཁྱི།'},
#  'bs': {'language': 'bs', 'value': 'pas'},
#  'ca': {'language': 'ca', 'value': 'gos'},
#  'cdo': {'language': 'cdo', 'value': 'Kēng'},
#  'chr': {'language': 'chr', 'value': 'ᎩᏟ'},
#  'chy': {'language': 'chy', 'value': 'Oeškese'},
#  'ckb': {'language': 'ckb', 'value': 'سەگ'},
#  'co': {'language': 'co', 'value': 'Ghjacaru'},
#  'cr': {'language': 'cr', 'value': 'Atimw'},
#  'csb': {'language': 'csb', 'value': 'Pies'},
#  'cs': {'language': 'cs', 'value': 'pes domácí'},
#  'cv': {'language': 'cv', 'value': 'Йытă'},
#  'cy': {'language': 'cy', 'value': 'ci'},
#  'da': {'language': 'da', 'value': 'hund'},
#  'diq': {'language': 'diq', 'value': 'Kutık'},
#  'dsb': {'language': 'dsb', 'value': 'Domacny pjas'},
#  'ee': {'language': 'ee', 'value': 'Avoo'},
#  'el': {'language': 'el', 'value': 'σκύλος'},
#  'eml': {'language': 'eml', 'value': 'Can'},
#  'eo': {'language': 'eo', 'value': 'hundo'},
#  'et': {'language': 'et', 'value': 'koer'},
#  'eu': {'language': 'eu', 'value': 'txakur'},
#  'ext': {'language': 'ext', 'value': 'Canis Lupus Familiaris'},
#  'fa': {'language': 'fa', 'value': 'سگ'},
#  'fi': {'language': 'fi', 'value': 'koira'},
#  'fj': {'language': 'fj', 'value': 'Koli'},
#  'fo': {'language': 'fo', 'value': 'Hundur'},
#  'frp': {'language': 'frp', 'value': 'Chin'},
#  'frr': {'language': 'frr', 'value': 'Hüshünj'},
#  'fur': {'language': 'fur', 'value': 'Cjan'},
#  'fy': {'language': 'fy', 'value': 'hûn'},
#  'gan': {'language': 'gan', 'value': '狗'},
#  'ga': {'language': 'ga', 'value': 'madra'},
#  'gd': {'language': 'gd', 'value': 'Cù'},
#  'gl': {'language': 'gl', 'value': 'Can'},
#  'gn': {'language': 'gn', 'value': 'Jagua'},
#  'got': {'language': 'got', 'value': '𐌷𐌿𐌽𐌳𐍃'},
#  'gv': {'language': 'gv', 'value': 'Moddey'},
#  'hak': {'language': 'hak', 'value': 'kiéu-è'},
#  'ha': {'language': 'ha', 'value': 'Kare'},
#  'he': {'language': 'he', 'value': 'כלב'},
#  'hi': {'language': 'hi', 'value': 'श्वान'},
#  'hr': {'language': 'hr', 'value': 'pas'},
#  'hsb': {'language': 'hsb', 'value': 'domjacy pos'},
#  'hu': {'language': 'hu', 'value': 'kutya'},
#  'hy': {'language': 'hy', 'value': 'շուն'},
#  'id': {'language': 'id', 'value': 'anjing'},
#  'ik': {'language': 'ik', 'value': 'Qimmiq'},
#  'ilo': {'language': 'ilo', 'value': 'aso'},
#  'io': {'language': 'io', 'value': 'hundo'},
#  'is': {'language': 'is', 'value': 'Hundur'},
#  'iu': {'language': 'iu', 'value': 'ᕿᖕᒥᖅ'},
#  'ja': {'language': 'ja', 'value': 'イヌ'},
#  'jbo': {'language': 'jbo', 'value': 'lo gerku'},
#  'jv': {'language': 'jv', 'value': 'asu'},
#  'ka': {'language': 'ka', 'value': 'ძაღლი'},
#  'kk': {'language': 'kk', 'value': 'Ит'},
#  'kn': {'language': 'kn', 'value': 'ನಾಯಿ'},
#  'koi': {'language': 'koi', 'value': 'Пон'},
#  'ko': {'language': 'ko', 'value': '개'},
#  'ks': {'language': 'ks', 'value': 'ہوٗن'},
#  'ku': {'language': 'ku', 'value': 'Kûçik'},
#  'kv': {'language': 'kv', 'value': 'Пон'},
#  'la': {'language': 'la', 'value': 'Canis'},
#  'lbe': {'language': 'lbe', 'value': 'Ккаччи'},
#  'lb': {'language': 'lb', 'value': 'Hond'},
#  'lez': {'language': 'lez', 'value': 'КицӀ'},
#  'lg': {'language': 'lg', 'value': 'Mbwa'},
#  'lij': {'language': 'lij', 'value': 'Can'},
#  'li': {'language': 'li', 'value': 'Hóndj'},
#  'lmo': {'language': 'lmo', 'value': 'Canis lupus familiaris'},
#  'ln': {'language': 'ln', 'value': 'Mbwá'},
#  'lt': {'language': 'lt', 'value': 'Šuo'},
#  'lv': {'language': 'lv', 'value': 'suns'},
#  'mdf': {'language': 'mdf', 'value': 'Пине'},
#  'mg': {'language': 'mg', 'value': 'Alika'},
#  'mhr': {'language': 'mhr', 'value': 'пий'},
#  'mk': {'language': 'mk', 'value': 'куче'},
#  'ml': {'language': 'ml', 'value': 'നായ'},
#  'mn': {'language': 'mn', 'value': 'нохой'},
#  'mrj': {'language': 'mrj', 'value': 'Пи'},
#  'mr': {'language': 'mr', 'value': 'कुत्रा'},
#  'ms': {'language': 'ms', 'value': 'anjing'},
#  'mt': {'language': 'mt', 'value': 'kelb'},
#  'mwl': {'language': 'mwl', 'value': 'Perro'},
#  'myv': {'language': 'myv', 'value': 'пине'},
#  'my': {'language': 'my', 'value': 'ခွေး'},
#  'nah': {'language': 'nah', 'value': 'Itzcuintli'},
#  'na': {'language': 'na', 'value': 'Robar'},
#  'ne': {'language': 'ne', 'value': 'कुकुर'},
#  'new': {'language': 'new', 'value': 'खिचा'},
#  'nl': {'language': 'nl', 'value': 'hond'},
#  'nn': {'language': 'nn', 'value': 'hund'},
#  'nrm': {'language': 'nrm', 'value': 'Tchian'},
#  'nso': {'language': 'nso', 'value': 'Mpša'},
#  'nv': {'language': 'nv', 'value': 'Łééchąąʼí'},
#  'oc': {'language': 'oc', 'value': 'Canis lupus familiaris'},
#  'or': {'language': 'or', 'value': 'କୁକୁର'},
#  'pam': {'language': 'pam', 'value': 'Asu'},
#  'pap': {'language': 'pap', 'value': 'kacho'},
#  'pa': {'language': 'pa', 'value': 'ਕੁੱਤਾ'},
#  'pcd': {'language': 'pcd', 'value': 'Kien'},
#  'pdc': {'language': 'pdc', 'value': 'Hund'},
#  'pl': {'language': 'pl', 'value': 'pies'},
#  'pnb': {'language': 'pnb', 'value': 'کتا'},
#  'ps': {'language': 'ps', 'value': 'سپی'},
#  'pt': {'language': 'pt', 'value': 'Canis lupus familiaris'},
#  'qu': {'language': 'qu', 'value': 'Allqu'},
#  'ro': {'language': 'ro', 'value': 'câine'},
#  'rue': {'language': 'rue', 'value': 'Пес'},
#  'rw': {'language': 'rw', 'value': 'Imbwa'},
#  'sah': {'language': 'sah', 'value': 'Ыт'},
#  'scn': {'language': 'scn', 'value': 'cani'},
#  'sco': {'language': 'sco', 'value': 'dug'},
#  'sc': {'language': 'sc', 'value': 'Cane'},
#  'sh': {'language': 'sh', 'value': 'Pas'},
#  'si': {'language': 'si', 'value': 'බල්ලා'},
#  'sk': {'language': 'sk', 'value': 'Pes domáci'},
#  'sl': {'language': 'sl', 'value': 'Domači pes'},
#  'sm': {'language': 'sm', 'value': 'Maile'},
#  'sn': {'language': 'sn', 'value': 'Imbwa'},
#  'so': {'language': 'so', 'value': 'Ey'},
#  'sq': {'language': 'sq', 'value': 'Qeni'},
#  'srn': {'language': 'srn', 'value': 'Dagu'},
#  'sr': {'language': 'sr', 'value': 'пас'},
#  'stq': {'language': 'stq', 'value': 'Huund'},
#  'su': {'language': 'su', 'value': 'Anjing'},
#  'sv': {'language': 'sv', 'value': 'hund'},
#  'sw': {'language': 'sw', 'value': 'mbwa'},
#  'szl': {'language': 'szl', 'value': 'Pjes'},
#  'ta': {'language': 'ta', 'value': 'நாய்'},
#  'te': {'language': 'te', 'value': 'కుక్క'},
#  'tg': {'language': 'tg', 'value': 'Саг'},
#  'th': {'language': 'th', 'value': 'หมา'},
#  'tl': {'language': 'tl', 'value': 'Aso'},
#  'tr': {'language': 'tr', 'value': 'köpek'},
#  'udm': {'language': 'udm', 'value': 'Пуны'},
#  'ug': {'language': 'ug', 'value': 'ئىت'},
#  'uk': {'language': 'uk', 'value': 'пес свійський'},
#  'ur': {'language': 'ur', 'value': 'کتا'},
#  'vec': {'language': 'vec', 'value': 'Can'},
#  'vep': {'language': 'vep', 'value': 'Koir'},
#  'vi': {'language': 'vi', 'value': 'chó'},
#  'vls': {'language': 'vls', 'value': 'Hound'},
#  'war': {'language': 'war', 'value': 'Ayam'},
#  'wa': {'language': 'wa', 'value': 'Tchén'},
#  'wo': {'language': 'wo', 'value': 'Xaj'},
#  'xal': {'language': 'xal', 'value': 'Ноха'},
#  'xh': {'language': 'xh', 'value': 'Inja'},
#  'yi': {'language': 'yi', 'value': 'הונט'},
#  'yo': {'language': 'yo', 'value': 'Ajá'},
#  'zh': {'language': 'zh', 'value': '犬'},
#  'zu': {'language': 'zu', 'value': 'Inja'},
#  'sa': {'language': 'sa', 'value': 'शुनकः'},
#  'de-ch': {'language': 'de-ch', 'value': 'Haushund'},
#  'en-ca': {'language': 'en-ca', 'value': 'Dog'},
#  'en-gb': {'language': 'en-gb', 'value': 'dog'},
#  'pt-br': {'language': 'pt-br', 'value': 'cão'},
#  'zh-hans': {'language': 'zh-hans', 'value': '犬'},
#  'zh-hant': {'language': 'zh-hant', 'value': '犬'},
#  'tt': {'language': 'tt', 'value': 'эт'},
#  'gsw': {'language': 'gsw', 'value': 'Hund'},
#  'lo': {'language': 'lo', 'value': 'ໝາ'},
#  'tyv': {'language': 'tyv', 'value': 'Ыт'},
#  'uz': {'language': 'uz', 'value': 'It'},
#  'lzh': {'language': 'lzh', 'value': '犬'},
#  'nds': {'language': 'nds', 'value': 'Hund'},
#  'glk': {'language': 'glk', 'value': 'سگ'},
#  'pms': {'language': 'pms', 'value': 'Can'},
#  'km': {'language': 'km', 'value': 'សត្វឆ្កែ'},
#  'min': {'language': 'min', 'value': 'Anjiang'},
#  'tum': {'language': 'tum', 'value': 'Nchebe'},
#  'bxr': {'language': 'bxr', 'value': 'Нохой'},
#  'wuu': {'language': 'wuu', 'value': '狗'},
#  'rup': {'language': 'rup', 'value': 'Câni'},
#  'nap': {'language': 'nap', 'value': 'Can'},
#  'tet': {'language': 'tet', 'value': 'asu'},
#  'brh': {'language': 'brh', 'value': 'kucak'},
#  'ak': {'language': 'ak', 'value': 'ɔkraman'},
#  'za': {'language': 'za', 'value': 'Ma'},
#  'zh-cn': {'language': 'zh-cn', 'value': '犬'},
#  'zh-hk': {'language': 'zh-hk', 'value': '犬'},
#  'zh-sg': {'language': 'zh-sg', 'value': '犬'},
#  'zh-tw': {'language': 'zh-tw', 'value': '犬'},
#  'mzn': {'language': 'mzn', 'value': 'سک'},
#  'awa': {'language': 'awa', 'value': 'कूकर'},
#  'ht': {'language': 'ht', 'value': 'Chyen'},
#  'vo': {'language': 'vo', 'value': 'dog'},
#  'sd': {'language': 'sd', 'value': 'ڪتو'},
#  'sma': {'language': 'sma', 'value': 'bïenje'},
#  'pag': {'language': 'pag', 'value': 'aso'},
#  'as': {'language': 'as', 'value': 'কুকুৰ'},
#  'ia': {'language': 'ia', 'value': 'can'},
#  'tcy': {'language': 'tcy', 'value': 'ನಾಯಿ'},
#  'atj': {'language': 'atj', 'value': 'atimw'},
#  'aeb-arab': {'language': 'aeb-arab', 'value': 'كلب'},
#  'tt-cyrl': {'language': 'tt-cyrl', 'value': 'эт'},
#  'tt-latn': {'language': 'tt-latn', 'value': 'et'},
#  'xmf': {'language': 'xmf', 'value': 'ჯოღორი'},
#  'mai': {'language': 'mai', 'value': 'कुत्ता'},
#  'rmy': {'language': 'rmy', 'value': 'juklo'},
#  'kbp': {'language': 'kbp', 'value': 'Haɣ'},
#  'jam': {'language': 'jam', 'value': 'Daag'},
#  'bi': {'language': 'bi', 'value': 'Dok'},
#  'ady': {'language': 'ady', 'value': 'Хьэ'},
#  'inh': {'language': 'inh', 'value': 'ЖIали'},
#  'lad': {'language': 'lad', 'value': 'Perro'},
#  'ky': {'language': 'ky', 'value': 'Ит'},
#  'ceb': {'language': 'ceb', 'value': 'Iro'},
#  'cu': {'language': 'cu', 'value': 'Пьсъ'},
#  'azb': {'language': 'azb', 'value': 'ایت'},
#  'olo': {'language': 'olo', 'value': 'Koiru'},
#  'lfn': {'language': 'lfn', 'value': 'Can'},
#  'sat': {'language': 'sat', 'value': 'ᱥᱮᱛᱟ'},
#  'bho': {'language': 'bho', 'value': 'कुक्कुर'},
#  'rm': {'language': 'rm', 'value': 'Chaun'},
#  'shn': {'language': 'shn', 'value': 'မႃ'},
#  'hyw': {'language': 'hyw', 'value': 'Շուն'},
#  'se': {'language': 'se', 'value': 'beana'},
#  'smn': {'language': 'smn', 'value': 'peenuv'},
#  'sms': {'language': 'sms', 'value': 'piânnai'},
#  'kab': {'language': 'kab', 'value': 'aydi'},
#  'ban': {'language': 'ban', 'value': 'Cicing'},
#  'ksh': {'language': 'ksh', 'value': 'Honk'},
#  'szy': {'language': 'szy', 'value': 'wacu'},
#  'mnw': {'language': 'mnw', 'value': 'ကၠဵု'},
#  'ig': {'language': 'ig', 'value': 'nkịta'},
#  'avk': {'language': 'avk', 'value': 'vakoleem'},
#  'ary': {'language': 'ary', 'value': 'كلب'},
#  'lld': {'language': 'lld', 'value': 'Cian'},
#  'skr': {'language': 'skr', 'value': 'کتا'},
#  'os': {'language': 'os', 'value': 'Куыдз'},
#  'pih': {'language': 'pih', 'value': 'Dorg'},
#  'pwn': {'language': 'pwn', 'value': 'vatu'},
#  'crh': {'language': 'crh', 'value': 'köpek'},
#  'mni': {'language': 'mni', 'value': 'ꯍꯨꯏ'},
#  'dag': {'language': 'dag', 'value': 'Baa'},
#  'ms-arab': {'language': 'ms-arab', 'value': 'انجيڠ'},
#  'nia': {'language': 'nia', 'value': 'Asu'},
#  'mcn': {'language': 'mcn', 'value': 'dìynà'},
#  'guw': {'language': 'guw', 'value': 'avún'},
#  'kw': {'language': 'kw', 'value': 'Ki'},
#  'tk': {'language': 'tk', 'value': 'It'},
#  'agq': {'language': 'agq', 'value': 'bvʉ e kwokwo'},
#  'mi': {'language': 'mi', 'value': 'Kurī'}}

# %%
p_dict['labels']['zh-hans']['value']
# Out:
# '犬'

# %% [markdown]
# **Load mBERT**

# %%
import torch
from transformers import BertTokenizerFast, BertForMaskedLM

# %%
# Load mBERT model and Tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-multilingual-cased')
model = BertForMaskedLM.from_pretrained("bert-base-multilingual-cased")
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tokenizer.tokenize(p_dict['labels']['zh-hant']['value'])
# Out:
# ['沖', '繩']

# %%
relations
# Out:
#         id                       en                          de  \
# 0    P3719             regulated by               reguliert von
# 1    P1704         is pollinator of               Bestäuber von
# 2    P3173           offers view on            bietet Sicht auf
# 3    P3085      qualifies for event    qualifiziert für Turnier
# 4    P4646        representation of             Vorstellung von
# ..     ...                      ...                         ...
# 729  P5769          editor-in-chief               Chefredakteur
# 730  P8627             closing time                 Schließzeit
# 731  P2770         source of income     Herkunft des Einkommens
# 732  P4794            season starts                 Saisonstart
# 733   P926  postsynaptic connection  postsynaptische Verbindung
#
#                           es                        fr  count  \
# 0               regulado por                  régi par    461
# 1                polinizador          pollinisateur de     58
# 2             ofrece vista a         offre une vue sur    935
# 3    califica para el evento             qualifie pour   2770
# 4          representación de         représentation de    167
# ..                       ...                       ...    ...
# 729         redactor en jefe     responsable éditorial   2248
# 730           hora de cierre        heure de fermeture      5
# 731        fuente de ingreso          source de revenu    494
# 732   inicio de la temporada        début de la saison   2049
# 733   conexión postsináptica  connexion postsynaptique      7
#
#                                               en_alias  \
# 0                    [regulator, regulatory authority]
# 1                          [pollinator of, pollinates]
# 2    [has view of, has views of, offers view of, vi...
# 3                    [league this event qualifies for]
# 4                                                 None
# ..                                                 ...
# 729  [executive editor, editor in chief, lead edito...
# 730                                        [closes at]
# 731  [income source, source of revenue, revenue sou...
# 732                                    [season begins]
# 733                                               None
#
#                                            de_alias  \
# 0                                              None
# 1                                              None
# 2                             [Sicht auf, Aussicht]
# 3                                              None
# 4                                              None
# ..                                              ...
# 729                               [Chefredakteurin]
# 730  [geschlossen um, geschlossen ab, geöffnet bis]
# 731                            [Einkommensherkunft]
# 732                                  [Saisonbeginn]
# 733                                            None
#
#                                               es_alias  \
# 0                                       [regulada por]
# 1                                                 None
# 2    [tiene vista a, ofrece una vista de, ofrece vi...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 729    [editor en jefe, editor ejecutivo, editor jefe]
# 730                                         [cierra a]
# 731                                  [fuente de renta]
# 732                         [comienzo de la temporada]
# 733                                               None
#
#                                               fr_alias  \
# 0    [régie par, régulé par, régulée par, réglement...
# 1                       [pollinise, plante pollinisée]
# 2    [offre un panorama sur, vue sur, a vue sur, jo...
# 3              [ligue à laquelle l'événement qualifie]
# 4                                                 None
# ..                                                 ...
# 729  [directeur de la rédaction, directrice de la r...
# 730                              [moment de fermeture]
# 731                                               None
# 732                                               None
# 733                        [connexion post-synaptique]
#
#                                     en_translate_alias  \
# 0                                        [governed by]
# 1                          [pollinator of, pollinator]
# 2                   [offers view to, offers a view of]
# 3    [qualified for tournament, qualify for the eve...
# 4                                            [idea of]
# ..                                                 ...
# 729                  [editorial manager, chief editor]
# 730                                     [closure hour]
# 731                                 [Origin of Income]
# 732                              [start of the season]
# 733                                               None
#
#                                     de_translate_alias  \
# 0                                      [regiert durch]
# 1                       [Bestäuber, ist Bestäuber von]
# 2     [bietet Aussicht auf, bietet einen Ausblick auf]
# 3    [qualifiziert sich für die Veranstaltung, sich...
# 4                                 [Repräsentation von]
# ..                                                 ...
# 729                                 [Redaktionsleiter]
# 730                                 [Geschäftsschluss]
# 731                                 [Einkommensquelle]
# 732                [Saison beginnt, Beginn der Saison]
# 733                       [Postsynaptische Verbindung]
#
#                                es_translate_alias  \
# 0                   [regulada por, gobernado por]
# 1             [es polinizador de, polinizador de]
# 2            [ofrece ver en, ofrece una vista de]
# 3      [calificado para el torneo, califica para]
# 4                    [idea de, representacion de]
# ..                                            ...
# 729           [gerente editorial, editor en jefe]
# 730                                          None
# 731                      [Origen de los Ingresos]
# 732  [inicio de temporada, comienza la temporada]
# 733                                          None
#
#                                     fr_translate_alias  \
# 0                                        [régulée par]
# 1                [est pollinisateur de, pollinisateur]
# 2                                                 None
# 3    [se qualifier pour l'événement, qualifié pour ...
# 4                      [idée de, la représentation de]
# ..                                                 ...
# 729               [éditeur en chef, rédacteur en chef]
# 730                                               None
# 731                                [Origine du revenu]
# 732              [début de saison, la saison commence]
# 733                                               None
#
#                                       en_subword_alias  \
# 0                      [by, from, governed, regulated]
# 1                               [of, from, pollinator]
# 2                     [to, view, offer, on, a, offers]
# 3    [event, qualifies, the, for, competition, qual...
# 4                     [representation, of, idea, from]
# ..                                                 ...
# 729         [boss, editorial, editor, on, responsible]
# 730                    [of, time, closing, from, hour]
# 731          [of, from, origin, source, income, entry]
# 732          [of, beginning, season, from, the, start]
# 733       [link, postsynaptic, connection, Connection]
#
#                                      de_subword_alias  \
# 0                          [regiert, durch, geregelt]
# 1                               [von, Bestäuber, ist]
# 2          [bietet an, zu, an, ein, Ansicht, Angebot]
# 3             [zum, Veranstaltung, qualifiziert, der]
# 4                                  [von, Darstellung]
# ..                                                ...
# 729  [Boss, verantwortlich, an, Editor, redaktionell]
# 730                    [Schließen, von, Zeit, Stunde]
# 731                 [Einkommen, von, Quelle, Eintrag]
# 732           [von, Anfang, Jahreszeit, der, beginnt]
# 733                      [Verbindung, postsynaptisch]
#
#                                       es_subword_alias  \
# 0                    [regulado, desde, por, gobernado]
# 1                         [de, desde, es, polinizador]
# 2              [seguro, oferta, en, vista, a, ofertas]
# 3    [competencia, por, calificado, para, evento, c...
# 4                    [desde, de, representación, idea]
# ..                                                 ...
# 729                           [editorial, responsable]
# 730                               [de, hora, clausura]
# 731                      [de, fuente, ingreso, origen]
# 732              [inicio, los, de, empieza, temporada]
# 733                  [postsináptico, Enlace, conexión]
#
#                                       fr_subword_alias
# 0                 [à partir de, pour, réglementé, par]
# 1                [pollinisateur, à partir de, de, est]
# 2                         [au, pour, des offres, voir]
# 3    [se qualifie, la, pour, un événement, qualifié...
# 4              [à partir de, de, représentation, idée]
# ..                                                 ...
# 729                                [au, éditeur, chef]
# 730             [heure, à partir de, fermeture, temps]
# 731  [à partir de, de, la source, origine, le reven...
# 732          [début, départs, à partir de, saison, la]
# 733      [Connexion, lien, post-synaptique, connexion]
#
# [715 rows x 18 columns]

# %%
dict((k, p_dict[k]) for k in ('id', 'type', 'labels'))
# Out:
# {'id': 'P8005',
#  'type': 'property',
#  'labels': {'en': {'language': 'en',
#    'value': 'research subject recruitment status'},
#   'mk': {'language': 'mk', 'value': 'состојба на прибирањето на испитаници'},
#   'sr': {'language': 'sr', 'value': 'статус регрутовања субјекта истраживања'},
#   'nl': {'language': 'nl',
#    'value': 'aanwervingsstatus van het onderzoeksonderwerp'},
#   'ca': {'language': 'ca', 'value': 'estat de contractació de la recerca'},
#   'be-tarask': {'language': 'be-tarask',
#    'value': 'статус набору дасьледніцкага прадмету'},
#   'tr': {'language': 'tr', 'value': 'araştırma konusu işe alım durumu'},
#   'uk': {'language': 'uk', 'value': 'статус набору об’єкта дослідження'},
#   'fr': {'language': 'fr',
#    'value': 'statut de recrutement des sujets de recherche'},
#   'bn': {'language': 'bn', 'value': 'গবেষণা বিষয় নিয়োগের স্থিতি'}}}

# %%
p = WikidataProperty(p_dict)

# %%
properties = pd.read_csv('properties_notsymmetric.csv')

# %%
propertyList = properties.to_dict('list')['_id']
propertyList
# Out:
# ['P1034',
#  'P5008',
#  'P457',
#  'P8004',
#  'P7442',
#  'P532',
#  'P740',
#  'P1817',
#  'P1425',
#  'P122',
#  'P58',
#  'P5249',
#  'P1629',
#  'P2876',
#  'P2597',
#  'P9072',
#  'P3085',
#  'P1704',
#  'P8263',
#  'P1716',
#  'P3173',
#  'P4099',
#  'P1465',
#  'P1165',
#  'P741',
#  'P4043',
#  'P5110',
#  'P6889',
#  'P3719',
#  'P8839',
#  'P4646',
#  'P3823',
#  'P3772',
#  'P8652',
#  'P4329',
#  'P8546',
#  'P3080',
#  'P534',
#  'P4323',
#  'P141',
#  'P7167',
#  'P1951',
#  'P1035',
#  'P2554',
#  'P2358',
#  'P9887',
#  'P3774',
#  'P66',
#  'P8006',
#  'P2853',
#  'P7163',
#  'P3275',
#  'P7938',
#  'P786',
#  'P106',
#  'P636',
#  'P85',
#  'P2841',
#  'P1811',
#  'P10067',
#  'P631',
#  'P9325',
#  'P5588',
#  'P1158',
#  'P4608',
#  'P103',
#  'P908',
#  'P5995',
#  'P37',
#  'P6563',
#  'P1435',
#  'P689',
#  'P568',
#  'P2502',
#  'P3158',
#  'P2453',
#  'P3402',
#  'P9813',
#  'P1855',
#  'P2614',
#  'P38',
#  'P183',
#  'P5996',
#  'P163',
#  'P5841',
#  'P4805',
#  'P556',
#  'P6902',
#  'P4988',
#  'P6948',
#  'P2992',
#  'P2438',
#  'P3491',
#  'P282',
#  'P291',
#  'P2548',
#  'P6275',
#  'P20',
#  'P3680',
#  'P5202',
#  'P2184',
#  'P3027',
#  'P411',
#  'P450',
#  'P2813',
#  'P1455',
#  'P6942',
#  'P1414',
#  'P3712',
#  'P9139',
#  'P7406',
#  'P2545',
#  'P8822',
#  'P3764',
#  'P2361',
#  'P6606',
#  'P5522',
#  'P2838',
#  'P8339',
#  'P5126',
#  'P9888',
#  'P2882',
#  'P2634',
#  'P2417',
#  'P1625',
#  'P5096',
#  'P5386',
#  'P7228',
#  'P2978',
#  'P5880',
#  'P1990',
#  'P6657',
#  'P9972',
#  'P6954',
#  'P5438',
#  'P136',
#  'P452',
#  'P4770',
#  'P1462',
#  'P3359',
#  'P4510',
#  'P449',
#  'P6001',
#  'P8989',
#  'P2872',
#  'P9086',
#  'P5800',
#  'P517',
#  'P8875',
#  'P7937',
#  'P6872',
#  'P1884',
#  'P3018',
#  'P483',
#  'P3356',
#  'P1686',
#  'P4241',
#  'P6884',
#  'P3975',
#  'P1050',
#  'P2286',
#  'P140',
#  'P814',
#  'P59',
#  'P1201',
#  'P8138',
#  'P1434',
#  'P8289',
#  'P3912',
#  'P1923',
#  'P7867',
#  'P8933',
#  'P930',
#  'P9344',
#  'P1546',
#  'P1792',
#  'P149',
#  'P1389',
#  'P3803',
#  'P1656',
#  'P509',
#  'P967',
#  'P2925',
#  'P3026',
#  'P3081',
#  'P6271',
#  'P6086',
#  'P111',
#  'P1013',
#  'P7469',
#  'P4044',
#  'P8646',
#  'P7561',
#  'P8402',
#  'P1956',
#  'P5998',
#  'P538',
#  'P8570',
#  'P4968',
#  'P784',
#  'P680',
#  'P4443',
#  'P35',
#  'P2715',
#  'P6530',
#  'P1677',
#  'P589',
#  'P516',
#  'P1142',
#  'P7095',
#  'P8345',
#  'P2700',
#  'P1911',
#  'P2827',
#  'P9030',
#  'P2962',
#  'P9895',
#  'P9241',
#  'P4688',
#  'P2159',
#  'P6533',
#  'P6437',
#  'P2568',
#  'P3216',
#  'P823',
#  'P4100',
#  'P7376',
#  'P495',
#  'P1056',
#  'P5053',
#  'P301',
#  'P2758',
#  'P8115',
#  'P2348',
#  'P4452',
#  'P3428',
#  'P3602',
#  'P3818',
#  'P3610',
#  'P3033',
#  'P6803',
#  'P6819',
#  'P1412',
#  'P3834',
#  'P277',
#  'P1308',
#  'P750',
#  'P4147',
#  'P9191',
#  'P453',
#  'P787',
#  'P840',
#  'P5832',
#  'P3437',
#  'P8453',
#  'P3103',
#  'P364',
#  'P6532',
#  'P4324',
#  'P7253',
#  'P4543',
#  'P8874',
#  'P5134',
#  'P88',
#  'P3189',
#  'P1885',
#  'P3092',
#  'P9810',
#  'P427',
#  'P2587',
#  'P1423',
#  'P1011',
#  'P7984',
#  'P8927',
#  'P4586',
#  'P5967',
#  'P1918',
#  'P1995',
#  'P4185',
#  'P415',
#  'P3833',
#  'P5872',
#  'P1204',
#  'P1910',
#  'P4425',
#  'P3354',
#  'P654',
#  'P1310',
#  'P1444',
#  'P1678',
#  'P5353',
#  'P7174',
#  'P4330',
#  'P1032',
#  'P803',
#  'P5095',
#  'P118',
#  'P2633',
#  'P800',
#  'P1775',
#  'P8824',
#  'P1606',
#  'P1264',
#  'P4774',
#  'P3739',
#  'P27',
#  'P1660',
#  'P3274',
#  'P2679',
#  'P913',
#  'P1909',
#  'P413',
#  'P1534',
#  'P2079',
#  'P8464',
#  'P9664',
#  'P1605',
#  'P5052',
#  'P8852',
#  'P1537',
#  'P6104',
#  'P1072',
#  'P6099',
#  'P5425',
#  'P6259',
#  'P9234',
#  'P8306',
#  'P9745',
#  'P1211',
#  'P4195',
#  'P2881',
#  'P469',
#  'P542',
#  'P8739',
#  'P2318',
#  'P2637',
#  'P4290',
#  'P2675',
#  'P3433',
#  'P6186',
#  'P275',
#  'P8746',
#  'P87',
#  'P1078',
#  'P1363',
#  'P768',
#  'P1227',
#  'P1060',
#  'P1068',
#  'P358',
#  'P84',
#  'P3496',
#  'P6118',
#  'P3985',
#  'P3357',
#  'P2667',
#  'P8810',
#  'P4733',
#  'P4628',
#  'P2505',
#  'P1057',
#  'P2680',
#  'P5054',
#  'P744',
#  'P1080',
#  'P1875',
#  'P8030',
#  'P4788',
#  'P135',
#  'P9793',
#  'P1210',
#  'P3648',
#  'P1913',
#  'P3777',
#  'P7500',
#  'P618',
#  'P923',
#  'P788',
#  'P8107',
#  'P2632',
#  'P2935',
#  'P1012',
#  'P7600',
#  'P4322',
#  'P171',
#  'P9926',
#  'P1547',
#  'P5280',
#  'P8032',
#  'P272',
#  'P1419',
#  'P5824',
#  'P2416',
#  'P3828',
#  'P6095',
#  'P5389',
#  'P4006',
#  'P708',
#  'P1145',
#  'P69',
#  'P189',
#  'P3094',
#  'P944',
#  'P2825',
#  'P4934',
#  'P2462',
#  'P2937',
#  'P2828',
#  'P9047',
#  'P1657',
#  'P400',
#  'P4353',
#  'P690',
#  'P3592',
#  'P681',
#  'P425',
#  'P2061',
#  'P6364',
#  'P8786',
#  'P1789',
#  'P524',
#  'P1049',
#  'P831',
#  'P1881',
#  'P2289',
#  'P2175',
#  'P3512',
#  'P9161',
#  'P4843',
#  'P418',
#  'P3741',
#  'P8701',
#  'P9929',
#  'P1731',
#  'P4437',
#  'P1903',
#  'P2353',
#  'P1571',
#  'P972',
#  'P3494',
#  'P5277',
#  'P3461',
#  'P688',
#  'P1898',
#  'P6116',
#  'P523',
#  'P7601',
#  'P1592',
#  'P5051',
#  'P200',
#  'P1924',
#  'P852',
#  'P703',
#  'P3460',
#  'P4954',
#  'P5816',
#  'P4614',
#  'P2308',
#  'P4271',
#  'P9073',
#  'P3501',
#  'P2673',
#  'P1706',
#  'P1318',
#  'P2551',
#  'P2578',
#  'P5125',
#  'P812',
#  'P1887',
#  'P7169',
#  'P8058',
#  'P8764',
#  'P4584',
#  'P1456',
#  'P4446',
#  'P1532',
#  'P65',
#  'P5826',
#  'P1809',
#  'P522',
#  'P9302',
#  'P344',
#  'P2560',
#  'P2319',
#  'P500',
#  'P407',
#  'P1981',
#  'P489',
#  'P2396',
#  'P2156',
#  'P1454',
#  'P467',
#  'P3358',
#  'P795',
#  'P8745',
#  'P375',
#  'P7327',
#  'P2363',
#  'P3349',
#  'P2500',
#  'P1372',
#  'P2851',
#  'P7137',
#  'P264',
#  'P1312',
#  'P5102',
#  'P8625',
#  'P2098',
#  'P736',
#  'P6112',
#  'P2820',
#  'P9071',
#  'P770',
#  'P1393',
#  'P1170',
#  'P2821',
#  'P647',
#  'P531',
#  'P8866',
#  'P6338',
#  'P4743',
#  'P1313',
#  'P3037',
#  'P7045',
#  'P1026',
#  'P7261',
#  'P5460',
#  'P6149',
#  'P1878',
#  'P5023',
#  'P4745',
#  'P6531',
#  'P2629',
#  'P3161',
#  'P5439',
#  'P78',
#  'P3306',
#  'P4312',
#  'P8791',
#  'P1194',
#  'P2095',
#  'P783',
#  'P537',
#  'P720',
#  'P658',
#  'P6452',
#  'P991',
#  'P2238',
#  'P2674',
#  'P8324',
#  'P2701',
#  'P3771',
#  'P5024',
#  'P9681',
#  'P4882',
#  'P7108',
#  'P1780',
#  'P1340',
#  'P1302',
#  'P8047',
#  'P6216',
#  'P928',
#  'P5753',
#  'P6568',
#  'P1876',
#  'P3816',
#  'P2378',
#  'P3195',
#  'P5591',
#  'P8889',
#  'P841',
#  'P4599',
#  'P2848',
#  'P608',
#  'P2822',
#  'P7374',
#  'P8500',
#  'P414',
#  'P4424',
#  'P518',
#  'P6439',
#  'P3716',
#  'P5537',
#  'P7767',
#  'P412',
#  'P289',
#  'P707',
#  'P505',
#  'P369',
#  'P6365',
#  'P1001',
#  'P2499',
#  'P6886',
#  'P1221',
#  'P4426',
#  'P1002',
#  'P3842',
#  'P693',
#  'P1777',
#  'P1574',
#  'P1387',
#  'P4149',
#  'P5444',
#  'P91',
#  'P30',
#  'P2515',
#  'P2577',
#  'P2550',
#  'P2647',
#  'P8450',
#  'P611',
#  'P2541',
#  'P1754',
#  'P3294',
#  'P54',
#  'P479',
#  'P6885',
#  'P1533',
#  'P417',
#  'P9788',
#  'P837',
#  'P2058',
#  'P6875',
#  'P8403',
#  'P110',
#  'P541',
#  'P588',
#  'P1576',
#  'P609',
#  'P1558',
#  'P1774',
#  'P2747',
#  'P931',
#  'P543',
#  'P3493',
#  'P504',
#  'P5304',
#  'P511',
#  'P8127',
#  'P9237',
#  'P4908',
#  'P1199',
#  'P6166',
#  'P193',
#  'P1917',
#  'P1906',
#  'P945',
#  'P408',
#  'P5185',
#  'P4647',
#  'P1079',
#  'P1399',
#  'P114',
#  'P5913',
#  'P512',
#  'P8706',
#  'P3279',
#  'P2365',
#  'P4220',
#  'P5514',
#  'P2501',
#  'P7252',
#  'P8308',
#  'P735',
#  'P126',
#  'P1408',
#  'P5137',
#  'P5009',
#  'P1437',
#  'P423',
#  'P8626',
#  'P533',
#  'P2564',
#  'P8193',
#  'P7782',
#  'P306',
#  'P8536',
#  'P816',
#  'P2291',
#  'P8901',
#  'P1912',
#  'P1383',
#  'P5328',
#  'P2849',
#  'P21',
#  'P682',
#  'P6569',
#  'P6758',
#  'P5817',
#  'P2371',
#  'P5059',
#  'P3005',
#  'P3643',
#  'P655',
#  'P8196',
#  'P1840',
#  'P2784',
#  'P9652',
#  'P9028',
#  'P5307',
#  'P5422',
#  'P4321',
#  'P912',
#  'P3156',
#  'P3967',
#  'P7377',
#  'P8045',
#  'P3014',
#  'P6978',
#  'P4634',
#  'P6524',
#  'P1192',
#  'P8031',
#  'P3876',
#  'P4379',
#  'P4101',
#  'P2563',
#  'P2360',
#  'P5607',
#  'P2839',
#  'P7084',
#  'P57',
#  'P7604',
#  'P2922',
#  'P5970',
#  'P880',
#  'P2408',
#  'P2239',
#  'P1637',
#  'P560',
#  'P6241',
#  'P3015',
#  'P2846',
#  'P1596',
#  'P881',
#  'P2756',
#  'P5131',
#  'P5804',
#  'P2379',
#  'P4387',
#  'P5030',
#  'P2341',
#  'P8097',
#  'P6106',
#  'P4132',
#  'P8938',
#  'P1027',
#  'P4070',
#  'P9977',
#  'P2127',
#  'P3019',
#  'P785',
#  'P5805',
#  'P941',
#  'P1877',
#  'P4969',
#  'P9239',
#  'P6658',
#  'P6440',
#  'P579',
#  'P3969',
#  'P6237',
#  'P6718',
#  'P1915',
#  'P92',
#  'P520',
#  'P922',
#  'P5028',
#  'P925',
#  'P4844',
#  'P205',
#  'P8111',
#  'P943',
#  'P8744',
#  'P1916',
#  'P7603',
#  'P3773',
#  'P7727',
#  'P3355',
#  'P1028',
#  'P8225',
#  'P6426',
#  'P3452',
#  'P447',
#  'P7086',
#  'P6224',
#  'P2392',
#  'P2817',
#  'P2596',
#  'P468',
#  'P1478',
#  'P9493',
#  'P1018',
#  'P485',
#  'P2507',
#  'P2912',
#  'P7573',
#  'P3310',
#  'P6855',
#  'P2974',
#  'P3301',
#  'P1654',
#  'P8026',
#  'P2681',
#  'P9866',
#  'P6939',
#  'P1568',
#  'P1914',
#  'P5236',
#  'P2964',
#  'P4952',
#  'P3490',
#  'P916',
#  'P1137',
#  'P97',
#  'P1136',
#  'P1851',
#  'P16',
#  'P1622',
#  'P4082',
#  'P5025',
#  'P1897',
#  'P3093',
#  'P4661',
#  'P550',
#  'P1202',
#  'P9566',
#  'P868',
#  'P437',
#  'P7309',
#  'P1171',
#  'P1853',
#  'P3148',
#  'P3259',
#  'P6153',
#  'P5642',
#  'P1406',
#  'P4878',
#  'P3815',
#  'P5072',
#  'P3919',
#  'P5658',
#  'P9883',
#  'P811',
#  'P19',
#  'P4320',
#  'P501',
#  'P8258',
#  'P3415',
#  'P9714',
#  'P5133',
#  'P3091',
#  'P3440',
#  'P1429',
#  'P3938',
#  'P6087',
#  'P3871',
#  'P3082',
#  'P1591',
#  'P2377',
#  'P642',
#  'P1703',
#  'P2321',
#  'P6195',
#  'P5152',
#  'P3780',
#  'P2414',
#  'P9901',
#  'P4000',
#  'P2746',
#  'P4600',
#  'P4444',
#  'P3858',
#  'P2852',
#  'P834',
#  'P702',
#  'P9899',
#  'P2831',
#  'P7643',
#  'P2682',
#  'P660',
#  'P2279',
#  'P3096',
#  'P1321',
#  'P8203',
#  'P9700',
#  'P9597',
#  'P545',
#  'P4151',
#  'P2869',
#  'P725',
#  'P6962',
#  'P1620',
#  'P6840',
#  'P397',
#  'P2366',
#  'P459',
#  'P1299',
#  'P3989',
#  'P7959',
#  'P462',
#  'P6534',
#  'P2976',
#  'P1776',
#  'P128',
#  'P6540',
#  'P3261',
#  'P5314',
#  'P241',
#  'P1791',
#  'P1064',
#  'P1891',
#  'P8864',
#  'P2842',
#  'P3174',
#  'P4850',
#  'P734',
#  'P2429',
#  'P421',
#  'P6587',
#  'P548',
#  'P5150',
#  'P10019',
#  'P3264',
#  'P2739',
#  'P2302',
#  'P410',
#  'P3335',
#  'P1640',
#  'P546',
#  'P1046',
#  'P942',
#  'P9969',
#  'P5070',
#  'P8571',
#  'P8363',
#  'P2989',
#  'P7419',
#  'P2684',
#  'P5012',
#  'P1445',
#  'P7078',
#  'P1672',
#  'P3701',
#  'P3438',
#  'P9600',
#  'P5132',
#  'P2702',
#  'P3497',
#  'P826',
#  'P8872',
#  'P8480',
#  'P873',
#  'P1652',
#  'P3447',
#  'P4224',
#  'P765',
#  'P1151',
#  'P3262',
#  'P376',
#  'P5026',
#  'P9215',
#  'P634',
#  'P7861',
#  'P3150',
#  'P3489',
#  'P7936',
#  'P5881',
#  'P1740',
#  'P5138',
#  'P9353',
#  'P2389',
#  'P2288',
#  'P9549',
#  'P101',
#  'P562',
#  'P1589',
#  'P2517',
#  'P5323',
#  'P7763',
#  'P3025',
#  'P924',
#  'P3022',
#  'P1595',
#  'P4002',
#  'P2894',
#  'P1196',
#  'P4624',
#  'P3374',
#  'P2033',
#  'P3095',
#  'P7514',
#  'P8413',
#  'P9660',
#  'P2376',
#  'P102',
#  'P1880',
#  'P1536',
#  'P5056',
#  'P1479',
#  ...]

# %%
cand = []

for prop in propertyList:
    p_dict = get_entity_dict_from_api(prop)
    p = WikidataProperty(p_dict)
    p_label = p.get_label()
    cand.append({'id': prop, 'label': p_label})

# %%
df = pd.DataFrame(cand)
df
# Out:
#          id                               label
# 0     P1034                    main food source
# 1     P5008  on focus list of Wikimedia project
# 2      P457                   foundational text
# 3     P8004                          ordered by
# 4     P7442                      glacier status
# ...     ...                                 ...
# 1137  P8627                        closing time
# 1138  P7152                 copyright exemption
# 1139  P2770                    source of income
# 1140  P4794                       season starts
# 1141   P926             postsynaptic connection
#
# [1142 rows x 2 columns]

# %%
# Save as CSV for manual cleanup
df.to_csv('property_notsymmetric_labeled.csv', index=False)
