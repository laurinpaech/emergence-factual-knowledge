# %% [markdown]
# ### Multilingual Entity Generation Notebook
# We take the entities by the number of occurences and do some preprocessing, essentially checking if the requirements of our entities are fulfilled and if the entities are in latin characters.
#
# For this we use a MongoDB Database that has the entities and cleaned entity/property triples. We count the occurences of entities in the triples and then join the collection with the entity collection so that every entity is also associated with its occurence value.
#
# ---
#
# This is a multilingual version of the original notebook.
# Here we generate entities in english-centric way. So for choosing Chinese and Japanese, we get datasets: (en, zh) and (en, ja).

# %% [markdown]
# - single tokens
#
# Cleanup:
# - No numbers

# %%
import pandas as pd
from collections import defaultdict
from tqdm.notebook import tqdm

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.wikidata
entityList = db.entityList

# %%
db.list_collection_names()
# Out:
# ['entity2_triples',
#  'entity_counts',
#  'triplesInvert',
#  'triples',
#  'equivalence',
#  'nsproperties',
#  'inversion',
#  'entity_subset',
#  'antonym',
#  'relation_subset',
#  'entityList',
#  'entity1_triples',
#  'properties',
#  'symmetry']

# %% [markdown]
# ##### Properties

# %%
# Unique properties
len(db.entityList.find_one({'value':{'$exists':True}}))
# Out:
# 5

# %% [markdown]
# ##### Which languages are represented the most in the dataset?

# %%
entityList.count_documents({'value':{'$exists':True}, 
                            'labels.en':{'$exists':True}, 
                            'labels.de':{'$exists':True},
                            'labels.fr':{'$exists':True},
                            'labels.es':{'$exists':True},
                            'labels.zh':{'$exists':True}, 
                           })
# Out:
# 875581

# %%
entityList.count_documents({'value':{'$exists':True}, 
                            'labels.en':{'$exists':True}, 
                            'labels.de':{'$exists':True},
                            'labels.fr':{'$exists':True},
                            'labels.es':{'$exists':True},
                            'labels.ja':{'$exists':True}, 
                           })
# Out:
# 791977

# %%
entityList.count_documents({'value':{'$exists':True}, 
                            'labels.en':{'$exists':True}, 
                            'labels.de':{'$exists':True},
                            'labels.fr':{'$exists':True},
                            'labels.es':{'$exists':True},
                            'labels.ko':{'$exists':True}, 
                           })
# Out:
# 447043

# %%
entityList.count_documents({'value':{'$exists':True}, 
                            'labels.en':{'$exists':True}, 
                            'labels.de':{'$exists':True},
                            'labels.fr':{'$exists':True},
                            'labels.es':{'$exists':True},
                            'labels.ru':{'$exists':True}, 
                           })
# Out:
# 1216431

# %%
entityList.count_documents({'value':{'$exists':True}, 
                             'labels.en':{'$exists':True},
                             'labels.de':{'$exists':True},
                             'labels.fr':{'$exists':True},
                             'labels.es':{'$exists':True},
                             'labels.zh':{'$exists':True},
                             'labels.ja':{'$exists':True}
                            })

# %%
entityList.find({'value':{'$exists':True}, 
                 'labels.en':{'$exists':True},
                 'labels.de':{'$exists':True},
                 'labels.fr':{'$exists':True},
                 'labels.es':{'$exists':True},
                 'labels.zh':{'$exists':True},
                 'labels.ja':{'$exists':True}
                })
# Out:
# 577665

# %%
document = entityList.find_one({'id':'Q144'})
document
# Out:
# {'_id': ObjectId('62067319578a2e954363ce8c'),
#  'value': 700,
#  'id': 'Q144',
#  'type': 'item',
#  'labels': {'en': {'language': 'en', 'value': 'dog'},
#   'fr': {'language': 'fr', 'value': 'chien'},
#   'it': {'language': 'it', 'value': 'cane'},
#   'de': {'language': 'de', 'value': 'Hund'},
#   'ru': {'language': 'ru', 'value': 'собака'},
#   'es': {'language': 'es', 'value': 'perro'},
#   'af': {'language': 'af', 'value': 'hond'},
#   'ar': {'language': 'ar', 'value': 'كلب'},
#   'bg': {'language': 'bg', 'value': 'куче'},
#   'bn': {'language': 'bn', 'value': 'কুকুর'},
#   'el': {'language': 'el', 'value': 'σκύλος'},
#   'et': {'language': 'et', 'value': 'koer'},
#   'eu': {'language': 'eu', 'value': 'txakur'},
#   'fa': {'language': 'fa', 'value': 'سگ'},
#   'fi': {'language': 'fi', 'value': 'koira'},
#   'he': {'language': 'he', 'value': 'כלב הבית'},
#   'hi': {'language': 'hi', 'value': 'श्वान'},
#   'hu': {'language': 'hu', 'value': 'kutya'},
#   'id': {'language': 'id', 'value': 'anjing'},
#   'ja': {'language': 'ja', 'value': 'イヌ'},
#   'jv': {'language': 'jv', 'value': 'asu'},
#   'ka': {'language': 'ka', 'value': 'ძაღლი'},
#   'kk': {'language': 'kk', 'value': 'Ит'},
#   'ko': {'language': 'ko', 'value': '개'},
#   'ml': {'language': 'ml', 'value': 'നായ'},
#   'mr': {'language': 'mr', 'value': 'कुत्रा'},
#   'ms': {'language': 'ms', 'value': 'anjing'},
#   'my': {'language': 'my', 'value': 'ခွေး'},
#   'nl': {'language': 'nl', 'value': 'hond'},
#   'pt': {'language': 'pt', 'value': 'Canis lupus familiaris'},
#   'sw': {'language': 'sw', 'value': 'mbwa'},
#   'ta': {'language': 'ta', 'value': 'நாய்'},
#   'te': {'language': 'te', 'value': 'కుక్క'},
#   'th': {'language': 'th', 'value': 'หมา'},
#   'tl': {'language': 'tl', 'value': 'Aso'},
#   'tr': {'language': 'tr', 'value': 'köpek'},
#   'ur': {'language': 'ur', 'value': 'کتا'},
#   'vi': {'language': 'vi', 'value': 'chó'},
#   'war': {'language': 'war', 'value': 'Ayam'},
#   'zh': {'language': 'zh', 'value': '犬'},
#   'ceb': {'language': 'ceb', 'value': 'Iro'}}}

# %% [markdown]
# #### Prepare mBERT

# %%
import torch
from transformers import BertTokenizerFast, BertForMaskedLM

# %%
# Load mBERT model and Tokenizer
tokenizer = BertTokenizerFast.from_pretrained('bert-base-multilingual-cased')
model = BertForMaskedLM.from_pretrained("bert-base-multilingual-cased")
# Out:
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tokenizer.tokenize('犬')
# Out:
# ['犬']

# %% [markdown]
# #### Preprocessing

# %%
def isLatin(s):
    try:
        s.encode('latin-1')
    except UnicodeEncodeError:
        return False
    else:
        return True

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except AttributeError:
        return False
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
def all_same(items):
    return all(x == items[0] for x in items)

# %%
# Tests if the strings are the same, also tests for lower/uppercasing
def all_same2(items):
    items_lower = [item.lower() for item in items]
    return all(x == y for x in items_lower for y in items_lower)

# %% [markdown]
# #### Tokenize and Check amount of possible entities

# %%
languages = ['en', 'de', 'fr', 'es']

# %%
exist_value = {'$exists':True}
query = {'value': exist_value}

for lang in languages:
    query['labels.' + lang] = exist_value
    
query
# Out:
# {'value': {'$exists': True},
#  'labels.en': {'$exists': True},
#  'labels.de': {'$exists': True},
#  'labels.fr': {'$exists': True},
#  'labels.es': {'$exists': True}}

# %%
# Single-Token
# Candidataes English labels but labels exist in all languages
candidates = []

search = entityList.find(query)

for document in search:
    if all(k in document['labels'] for k in languages):
        wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]
        if (all(len(l) == 1 for l in wordTokens)):
            if document['labels'][languages[0]]['value'].isalpha() and isLatin(document['labels'][languages[0]]['value']) and len(document['labels'][languages[0]]['value']) > 1 and not all_same([document['labels'][k]['value'] for k in languages]):
                candidates.append({'id': document['id'], 'label': document['labels'][languages[0]]['value']})

# %%
len(candidates)
# Out:
# 1528

# %%
candidates
# Out:
# [{'id': 'Q27213', 'label': 'Formula'},
#  {'id': 'Q218887', 'label': 'SC'},
#  {'id': 'Q224805', 'label': 'FL'},
#  {'id': 'Q232353', 'label': 'Agency'},
#  {'id': 'Q307045', 'label': 'mail'},
#  {'id': 'Q1761084', 'label': 'length'},
#  {'id': 'Q1910983', 'label': 'wall'},
#  {'id': 'Q58809888', 'label': 'between'},
#  {'id': 'Q62916459', 'label': 'maritime'},
#  {'id': 'Q218181', 'label': 'CE'},
#  {'id': 'Q247976', 'label': 'studio'},
#  {'id': 'Q980612', 'label': 'gun'},
#  {'id': 'Q1179792', 'label': 'monitoring'},
#  {'id': 'Q1643175', 'label': 'Committee'},
#  {'id': 'Q217455', 'label': 'BD'},
#  {'id': 'Q218716', 'label': 'SV'},
#  {'id': 'Q1409462', 'label': 'fire'},
#  {'id': 'Q242341', 'label': 'SAO'},
#  {'id': 'Q283937', 'label': 'at'},
#  {'id': 'Q483199', 'label': 'It'},
#  {'id': 'Q778214', 'label': 'Bosnia'},
#  {'id': 'Q7387', 'label': 'property'},
#  {'id': 'Q189731', 'label': 'MG'},
#  {'id': 'Q227746', 'label': 'UN'},
#  {'id': 'Q354935', 'label': 'Faculty'},
#  {'id': 'Q1275657', 'label': 'Premiere'},
#  {'id': 'Q2085066', 'label': 'land'},
#  {'id': 'Q227861', 'label': 'Rugby'},
#  {'id': 'Q229968', 'label': 'SEC'},
#  {'id': 'Q340886', 'label': 'København'},
#  {'id': 'Q1764651', 'label': 'Monica'},
#  {'id': 'Q2236563', 'label': 'walk'},
#  {'id': 'Q7170641', 'label': 'personality'},
#  {'id': 'Q33518579', 'label': 'Occidental'},
#  {'id': 'Q218136', 'label': 'Com'},
#  {'id': 'Q230053', 'label': 'EX'},
#  {'id': 'Q338936', 'label': 'Dynamo'},
#  {'id': 'Q1094270', 'label': 'Cité'},
#  {'id': 'Q1672943', 'label': 'Olympic'},
#  {'id': 'Q2146999', 'label': 'revue'},
#  {'id': 'Q17322994', 'label': 'load'},
#  {'id': 'Q175385', 'label': 'population'},
#  {'id': 'Q210040', 'label': 'flash'},
#  {'id': 'Q224468', 'label': 'IR'},
#  {'id': 'Q3916071', 'label': 'capital'},
#  {'id': 'Q768396', 'label': 'Programa'},
#  {'id': 'Q1075238', 'label': 'dock'},
#  {'id': 'Q1191094', 'label': 'forte'},
#  {'id': 'Q1373320', 'label': 'rookie'},
#  {'id': 'Q30093584', 'label': 'field'},
#  {'id': 'Q108557527', 'label': 'construction'},
#  {'id': 'Q256479', 'label': 'top'},
#  {'id': 'Q1051976', 'label': 'route'},
#  {'id': 'Q5484627', 'label': 'Francois'},
#  {'id': 'Q25839995', 'label': 'talent'},
#  {'id': 'Q219266', 'label': 'Up'},
#  {'id': 'Q295117', 'label': 'Hotel'},
#  {'id': 'Q368256', 'label': 'Mora'},
#  {'id': 'Q10861678', 'label': 'order'},
#  {'id': 'Q1439716', 'label': 'fou'},
#  {'id': 'Q763850', 'label': 'strike'},
#  {'id': 'Q1431456', 'label': 'order'},
#  {'id': 'Q1483364', 'label': 'Nat'},
#  {'id': 'Q5189153', 'label': 'value'},
#  {'id': 'Q344960', 'label': 'SUA'},
#  {'id': 'Q444269', 'label': 'men'},
#  {'id': 'Q640404', 'label': 'eye'},
#  {'id': 'Q1155562', 'label': 'rapport'},
#  {'id': 'Q1196074', 'label': 'he'},
#  {'id': 'Q1347898', 'label': 'lag'},
#  {'id': 'Q185675', 'label': 'Image'},
#  {'id': 'Q260667', 'label': 'Länder'},
#  {'id': 'Q667390', 'label': 'polo'},
#  {'id': 'Q1134503', 'label': 'corona'},
#  {'id': 'Q1341061', 'label': 'minor'},
#  {'id': 'Q2141912', 'label': 'sala'},
#  {'id': 'Q27201', 'label': 'bitter'},
#  {'id': 'Q218275', 'label': 'Focus'},
#  {'id': 'Q1270787', 'label': 'she'},
#  {'id': 'Q1325930', 'label': 'type'},
#  {'id': 'Q2088403', 'label': 'house'},
#  {'id': 'Q2386564', 'label': 'largo'},
#  {'id': 'Q21075795', 'label': 'never'},
#  {'id': 'Q230797', 'label': 'Chain'},
#  {'id': 'Q914681', 'label': 'prime'},
#  {'id': 'Q1781600', 'label': 'Congress'},
#  {'id': 'Q2864132', 'label': 'Association'},
#  {'id': 'Q25590233', 'label': 'ground'},
#  {'id': 'Q225197', 'label': 'Bank'},
#  {'id': 'Q349374', 'label': 'parish'},
#  {'id': 'Q591644', 'label': 'pendant'},
#  {'id': 'Q656784', 'label': 'rank'},
#  {'id': 'Q4233803', 'label': 'king'},
#  {'id': 'Q22214271', 'label': 'Zurich'},
#  {'id': 'Q25587250', 'label': 'Fighting'},
#  {'id': 'Q304157', 'label': 'Administration'},
#  {'id': 'Q452546', 'label': 'good'},
#  {'id': 'Q857784', 'label': 'camp'},
#  {'id': 'Q887471', 'label': 'boa'},
#  {'id': 'Q1329910', 'label': 'view'},
#  {'id': 'Q1493191', 'label': 'gamma'},
#  {'id': 'Q1568233', 'label': 'opposition'},
#  {'id': 'Q2518727', 'label': 'defense'},
#  {'id': 'Q2917506', 'label': 'series'},
#  {'id': 'Q218344', 'label': 'AH'},
#  {'id': 'Q224475', 'label': 'EU'},
#  {'id': 'Q226619', 'label': 'Polo'},
#  {'id': 'Q343399', 'label': 'Bible'},
#  {'id': 'Q938705', 'label': 'EN'},
#  {'id': 'Q14457335', 'label': 'Munich'},
#  {'id': 'Q1574285', 'label': 'hand'},
#  {'id': 'Q2227620', 'label': 'Welcome'},
#  {'id': 'Q9667', 'label': 'Bambino'},
#  {'id': 'Q235091', 'label': 'Hang'},
#  {'id': 'Q2095727', 'label': 'pot'},
#  {'id': 'Q205725', 'label': 'Be'},
#  {'id': 'Q361785', 'label': 'journal'},
#  {'id': 'Q20100946', 'label': 'Leon'},
#  {'id': 'Q232576', 'label': 'Service'},
#  {'id': 'Q257304', 'label': 'Canada'},
#  {'id': 'Q404764', 'label': 'Ova'},
#  {'id': 'Q904031', 'label': 'sol'},
#  {'id': 'Q823231', 'label': 'sera'},
#  {'id': 'Q3179484', 'label': 'ex'},
#  {'id': 'Q284328', 'label': 'ex'},
#  {'id': 'Q1578205', 'label': 'Serbia'},
#  {'id': 'Q2369038', 'label': 'Susanna'},
#  {'id': 'Q189171', 'label': 'Section'},
#  {'id': 'Q191169', 'label': 'center'},
#  {'id': 'Q257491', 'label': 'test'},
#  {'id': 'Q981211', 'label': 'Sebastian'},
#  {'id': 'Q403206', 'label': 'Jardin'},
#  {'id': 'Q676215', 'label': 'arm'},
#  {'id': 'Q836651', 'label': 'mu'},
#  {'id': 'Q1131660', 'label': 'stone'},
#  {'id': 'Q7831478', 'label': 'track'},
#  {'id': 'Q224615', 'label': 'test'},
#  {'id': 'Q403373', 'label': 'Dome'},
#  {'id': 'Q638982', 'label': 'moment'},
#  {'id': 'Q810214', 'label': 'base'},
#  {'id': 'Q1199068', 'label': 'Site'},
#  {'id': 'Q1794067', 'label': 'place'},
#  {'id': 'Q24759380', 'label': 'remain'},
#  {'id': 'Q858321', 'label': 'port'},
#  {'id': 'Q3549842', 'label': 'pr'},
#  {'id': 'Q63233', 'label': 'Nasser'},
#  {'id': 'Q351303', 'label': 'Track'},
#  {'id': 'Q663143', 'label': 'production'},
#  {'id': 'Q1146652', 'label': 'iki'},
#  {'id': 'Q2672552', 'label': 'Peninsula'},
#  {'id': 'Q26186900', 'label': 'make'},
#  {'id': 'Q66459507', 'label': 'and'},
#  {'id': 'Q185553', 'label': 'phase'},
#  {'id': 'Q228378', 'label': 'Raw'},
#  {'id': 'Q344069', 'label': 'Hockey'},
#  {'id': 'Q1817113', 'label': 'Planet'},
#  {'id': 'Q3399648', 'label': 'position'},
#  {'id': 'Q13377795', 'label': 'Mystery'},
#  {'id': 'Q28227785', 'label': 'Felix'},
#  {'id': 'Q253509', 'label': 'more'},
#  {'id': 'Q24906', 'label': 'Safety'},
#  {'id': 'Q246868', 'label': 'lot'},
#  {'id': 'Q578508', 'label': 'try'},
#  {'id': 'Q715772', 'label': 'captain'},
#  {'id': 'Q2026317', 'label': 'century'},
#  {'id': 'Q2056285', 'label': 'Pastor'},
#  {'id': 'Q3800792', 'label': 'introduction'},
#  {'id': 'Q233010', 'label': 'Din'},
#  {'id': 'Q579160', 'label': 'Europe'},
#  {'id': 'Q1052397', 'label': 'rad'},
#  {'id': 'Q1951705', 'label': 'muda'},
#  {'id': 'Q7185502', 'label': 'Philips'},
#  {'id': 'Q14916053', 'label': 'number'},
#  {'id': 'Q18473413', 'label': 'Curt'},
#  {'id': 'Q18193', 'label': 'form'},
#  {'id': 'Q654875', 'label': 'Li'},
#  {'id': 'Q1310296', 'label': 'vita'},
#  {'id': 'Q1340043', 'label': 'samba'},
#  {'id': 'Q2360918', 'label': 'piece'},
#  {'id': 'Q2963205', 'label': 'chi'},
#  {'id': 'Q3250078', 'label': 'depth'},
#  {'id': 'Q18510365', 'label': 'Rain'},
#  {'id': 'Q29346471', 'label': 'season'},
#  {'id': 'Q224216', 'label': 'Oh'},
#  {'id': 'Q226361', 'label': 'On'},
#  {'id': 'Q353296', 'label': 'Italy'},
#  {'id': 'Q397063', 'label': 'Principe'},
#  {'id': 'Q517966', 'label': 'structure'},
#  {'id': 'Q669057', 'label': 'dot'},
#  {'id': 'Q1938377', 'label': 'tee'},
#  {'id': 'Q5943060', 'label': 'Hungary'},
#  {'id': 'Q13549134', 'label': 'Op'},
#  {'id': 'Q16283049', 'label': 'Andrej'},
#  {'id': 'Q105562', 'label': 'opposition'},
#  {'id': 'Q284243', 'label': 'touch'},
#  {'id': 'Q461499', 'label': 'transformation'},
#  {'id': 'Q919107', 'label': 'product'},
#  {'id': 'Q2126758', 'label': 'Radu'},
#  {'id': 'Q2333151', 'label': 'tau'},
#  {'id': 'Q3709194', 'label': 'Leon'},
#  {'id': 'Q11868407', 'label': 'Ice'},
#  {'id': 'Q48154', 'label': 'Auch'},
#  {'id': 'Q139727', 'label': 'tres'},
#  {'id': 'Q210804', 'label': 'CO'},
#  {'id': 'Q827490', 'label': 'Senate'},
#  {'id': 'Q1109478', 'label': 'bridge'},
#  {'id': 'Q225833', 'label': 'sex'},
#  {'id': 'Q310583', 'label': 'tail'},
#  {'id': 'Q370535', 'label': 'Quebec'},
#  {'id': 'Q387834', 'label': 'thing'},
#  {'id': 'Q1089123', 'label': 'Mark'},
#  {'id': 'Q1223600', 'label': 'Movimento'},
#  {'id': 'Q24047813', 'label': 'squadron'},
#  {'id': 'Q96108420', 'label': 'base'},
#  {'id': 'Q2533865', 'label': 'Eliot'},
#  {'id': 'Q56644435', 'label': 'probably'},
#  {'id': 'Q232196', 'label': 'Montreal'},
#  {'id': 'Q868952', 'label': 'Dia'},
#  {'id': 'Q1287067', 'label': 'Senator'},
#  {'id': 'Q29509043', 'label': 'official'},
#  {'id': 'Q103510', 'label': 'bar'},
#  {'id': 'Q783685', 'label': 'Dia'},
#  {'id': 'Q4962881', 'label': 'Iulia'},
#  {'id': 'Q18475776', 'label': 'Platt'},
#  {'id': 'Q142659', 'label': 'Berlin'},
#  {'id': 'Q691543', 'label': 'pace'},
#  {'id': 'Q427480', 'label': 'Léonard'},
#  {'id': 'Q606565', 'label': 'Antonius'},
#  {'id': 'Q628802', 'label': 'rio'},
#  {'id': 'Q1415372', 'label': 'path'},
#  {'id': 'Q17875', 'label': 'Helene'},
#  {'id': 'Q296260', 'label': 'football'},
#  {'id': 'Q1575282', 'label': 'Syria'},
#  {'id': 'Q10623719', 'label': 'altitude'},
#  {'id': 'Q18496', 'label': 'Margaret'},
#  {'id': 'Q185917', 'label': 'translation'},
#  {'id': 'Q253242', 'label': 'Rai'},
#  {'id': 'Q446123', 'label': 'Paulus'},
#  {'id': 'Q1472357', 'label': 'Fu'},
#  {'id': 'Q9368452', 'label': 'verso'},
#  {'id': 'Q15945544', 'label': 'komuna'},
#  {'id': 'Q217390', 'label': 'LA'},
#  {'id': 'Q1645966', 'label': 'stadion'},
#  {'id': 'Q23063339', 'label': 'Peter'},
#  {'id': 'Q224181', 'label': 'SO'},
#  {'id': 'Q965135', 'label': 'Peru'},
#  {'id': 'Q981703', 'label': 'Joaquin'},
#  {'id': 'Q1272626', 'label': 'representation'},
#  {'id': 'Q7216866', 'label': 'post'},
#  {'id': 'Q131593', 'label': 'san'},
#  {'id': 'Q185078', 'label': 'are'},
#  {'id': 'Q200520', 'label': 'MI'},
#  {'id': 'Q209351', 'label': 'barn'},
#  {'id': 'Q224099', 'label': 'El'},
#  {'id': 'Q1479970', 'label': 'vida'},
#  {'id': 'Q1541208', 'label': 'grade'},
#  {'id': 'Q2912517', 'label': 'value'},
#  {'id': 'Q3382125', 'label': 'period'},
#  {'id': 'Q232457', 'label': 'Macdonald'},
#  {'id': 'Q304479', 'label': 'turn'},
#  {'id': 'Q1136266', 'label': 'Alexander'},
#  {'id': 'Q28962310', 'label': 'rarely'},
#  {'id': 'Q229623', 'label': 'USA'},
#  {'id': 'Q235257', 'label': 'LE'},
#  {'id': 'Q895067', 'label': 'Boulevard'},
#  {'id': 'Q1374036', 'label': 'flag'},
#  {'id': 'Q2941721', 'label': 'catch'},
#  {'id': 'Q3846728', 'label': 'sea'},
#  {'id': 'Q37516163', 'label': 'Marco'},
#  {'id': 'Q1072430', 'label': 'die'},
#  {'id': 'Q15015237', 'label': 'Aman'},
#  {'id': 'Q147802', 'label': 'Kosmos'},
#  {'id': 'Q223994', 'label': 'Ko'},
#  {'id': 'Q406218', 'label': 'Mio'},
#  {'id': 'Q5367165', 'label': 'Love'},
#  {'id': 'Q5420926', 'label': 'Camp'},
#  {'id': 'Q24759450', 'label': 'leave'},
#  {'id': 'Q26484625', 'label': 'lap'},
#  {'id': 'Q28454519', 'label': 'goal'},
#  {'id': 'Q219011', 'label': 'Om'},
#  {'id': 'Q9245780', 'label': 'Saison'},
#  {'id': 'Q219232', 'label': 'FA'},
#  {'id': 'Q778379', 'label': 'expression'},
#  {'id': 'Q954166', 'label': 'porter'},
#  {'id': 'Q1070898', 'label': 'Chevalier'},
#  {'id': 'Q10931275', 'label': 'Mo'},
#  {'id': 'Q30230067', 'label': 'possibly'},
#  {'id': 'Q58309587', 'label': 'Rafael'},
#  {'id': 'Q284436', 'label': 'alien'},
#  {'id': 'Q3472469', 'label': 'Villa'},
#  {'id': 'Q3908677', 'label': 'gate'},
#  {'id': 'Q19279529', 'label': 'go'},
#  {'id': 'Q40984492', 'label': 'never'},
#  {'id': 'Q14749', 'label': 'table'},
#  {'id': 'Q215563', 'label': 'ISO'},
#  {'id': 'Q770948', 'label': 'okres'},
#  {'id': 'Q1350565', 'label': 'Germany'},
#  {'id': 'Q18475039', 'label': 'Berg'},
#  {'id': 'Q226706', 'label': 'Ego'},
#  {'id': 'Q1686000', 'label': 'party'},
#  {'id': 'Q900946', 'label': 'DOS'},
#  {'id': 'Q1360926', 'label': 'run'},
#  {'id': 'Q192797', 'label': 'elite'},
#  {'id': 'Q850029', 'label': 'mina'},
#  {'id': 'Q2237261', 'label': 'Jérusalem'},
#  {'id': 'Q4544684', 'label': 'search'},
#  {'id': 'Q18478436', 'label': 'Dorf'},
#  {'id': 'Q11226871', 'label': 'Japón'},
#  {'id': 'Q29277', 'label': 'Are'},
#  {'id': 'Q82383', 'label': 'base'},
#  {'id': 'Q383444', 'label': 'degree'},
#  {'id': 'Q471961', 'label': 'Sidi'},
#  {'id': 'Q1384981', 'label': 'extension'},
#  {'id': 'Q16280157', 'label': 'Nile'},
#  {'id': 'Q1540897', 'label': 'Kosmos'},
#  {'id': 'Q1577757', 'label': 'link'},
#  {'id': 'Q2574569', 'label': 'Horace'},
#  {'id': 'Q3555518', 'label': 'Venice'},
#  {'id': 'Q1058984', 'label': 'Kingdom'},
#  {'id': 'Q1091366', 'label': 'Ci'},
#  {'id': 'Q1384998', 'label': 'extension'},
#  {'id': 'Q18501', 'label': 'Ferdinand'},
#  {'id': 'Q255453', 'label': 'Marcus'},
#  {'id': 'Q312861', 'label': 'Philip'},
#  {'id': 'Q500515', 'label': 'gal'},
#  {'id': 'Q806617', 'label': 'bed'},
#  {'id': 'Q1399352', 'label': 'featuring'},
#  {'id': 'Q3044646', 'label': 'Acoustic'},
#  {'id': 'Q147572', 'label': 'arc'},
#  {'id': 'Q156389', 'label': 'point'},
#  {'id': 'Q229348', 'label': 'Jerusalem'},
#  {'id': 'Q516114', 'label': 'king'},
#  {'id': 'Q1141484', 'label': 'WEB'},
#  {'id': 'Q3778856', 'label': 'William'},
#  {'id': 'Q4742716', 'label': 'America'},
#  {'id': 'Q535251', 'label': 'Pacifico'},
#  {'id': 'Q686320', 'label': 'One'},
#  {'id': 'Q211533', 'label': 'Time'},
#  {'id': 'Q373498', 'label': 'dan'},
#  {'id': 'Q3684883', 'label': 'commune'},
#  {'id': 'Q3742086', 'label': 'Felix'},
#  {'id': 'Q1312606', 'label': 'chi'},
#  {'id': 'Q1514415', 'label': 'trend'},
#  {'id': 'Q1572505', 'label': 'metal'},
#  {'id': 'Q34964', 'label': 'Batu'},
#  {'id': 'Q730374', 'label': 'Ruben'},
#  {'id': 'Q1812346', 'label': 'legacy'},
#  {'id': 'Q2528683', 'label': 'function'},
#  {'id': 'Q59325416', 'label': 'Alliance'},
#  {'id': 'Q35048', 'label': 'Cara'},
#  {'id': 'Q1076351', 'label': 'hasta'},
#  {'id': 'Q24245823', 'label': 'small'},
#  {'id': 'Q28129894', 'label': 'femme'},
#  {'id': 'Q406714', 'label': 'air'},
#  {'id': 'Q646462', 'label': 'cable'},
#  {'id': 'Q522265', 'label': 'sam'},
#  {'id': 'Q1179705', 'label': 'de'},
#  {'id': 'Q11194654', 'label': 'Clear'},
#  {'id': 'Q36408', 'label': 'Pol'},
#  {'id': 'Q99194075', 'label': 'documentation'},
#  {'id': 'Q986174', 'label': 'Sebastian'},
#  {'id': 'Q1596487', 'label': 'Heinrich'},
#  {'id': 'Q6343145', 'label': 'Ka'},
#  {'id': 'Q11540953', 'label': 'search'},
#  {'id': 'Q46344', 'label': 'quantum'},
#  {'id': 'Q1155350', 'label': 'Dawn'},
#  {'id': 'Q1367530', 'label': 'suite'},
#  {'id': 'Q4300759', 'label': 'motion'},
#  {'id': 'Q11499267', 'label': 'defeat'},
#  {'id': 'Q28962312', 'label': 'often'},
#  {'id': 'Q123704', 'label': 'swing'},
#  {'id': 'Q901718', 'label': 'product'},
#  {'id': 'Q1172293', 'label': 'Sofia'},
#  {'id': 'Q1374354', 'label': 'maxim'},
#  {'id': 'Q33501', 'label': 'Mono'},
#  {'id': 'Q310474', 'label': 'nouveau'},
#  {'id': 'Q691899', 'label': 'kraj'},
#  {'id': 'Q1558632', 'label': 'Rome'},
#  {'id': 'Q1632080', 'label': 'Malta'},
#  {'id': 'Q2165236', 'label': 'everything'},
#  {'id': 'Q11196522', 'label': 'dance'},
#  {'id': 'Q574578', 'label': 'Nazi'},
#  {'id': 'Q1133938', 'label': 'trust'},
#  {'id': 'Q3504147', 'label': 'Banda'},
#  {'id': 'Q55136721', 'label': 'Premiere'},
#  {'id': 'Q192503', 'label': 'maar'},
#  {'id': 'Q224857', 'label': 'Ed'},
#  {'id': 'Q360603', 'label': 'Hector'},
#  {'id': 'Q1514741', 'label': 'set'},
#  {'id': 'Q36583', 'label': 'Seri'},
#  {'id': 'Q584294', 'label': 'Kosmos'},
#  {'id': 'Q307110', 'label': 'au'},
#  {'id': 'Q354341', 'label': 'colony'},
#  {'id': 'Q18470264', 'label': 'Dia'},
#  {'id': 'Q190095', 'label': 'gray'},
#  {'id': 'Q478463', 'label': 'Jerusalem'},
#  {'id': 'Q516626', 'label': 'terror'},
#  {'id': 'Q704662', 'label': 'John'},
#  {'id': 'Q1806767', 'label': 'departamento'},
#  {'id': 'Q16423586', 'label': 'Paris'},
#  {'id': 'Q508552', 'label': 'Iván'},
#  {'id': 'Q2464332', 'label': 'Jude'},
#  {'id': 'Q5739453', 'label': 'Herman'},
#  {'id': 'Q959664', 'label': 'premier'},
#  {'id': 'Q81292', 'label': 'acre'},
#  {'id': 'Q408160', 'label': 'Étienne'},
#  {'id': 'Q2116978', 'label': 'Jérusalem'},
#  {'id': 'Q11841130', 'label': 'Damian'},
#  {'id': 'Q13582404', 'label': 'danger'},
#  {'id': 'Q30059', 'label': 'arrondissement'},
#  {'id': 'Q3606969', 'label': 'Ahmad'},
#  {'id': 'Q62607833', 'label': 'Peter'},
#  {'id': 'Q184128', 'label': 'Om'},
#  {'id': 'Q205318', 'label': 'Zion'},
#  {'id': 'Q397239', 'label': 'edition'},
#  {'id': 'Q416947', 'label': 'Jerome'},
#  {'id': 'Q980348', 'label': 'Julian'},
#  {'id': 'Q1196827', 'label': 'value'},
#  {'id': 'Q2068074', 'label': 'Alexander'},
#  {'id': 'Q14944328', 'label': 'example'},
#  {'id': 'Q17322880', 'label': 'Constantine'},
#  {'id': 'Q118084', 'label': 'unit'},
#  {'id': 'Q244700', 'label': 'ultimate'},
#  {'id': 'Q1481202', 'label': 'mine'},
#  {'id': 'Q2920644', 'label': 'environment'},
#  {'id': 'Q12123144', 'label': 'Mexico'},
#  {'id': 'Q57199699', 'label': 'apparition'},
#  {'id': 'Q207887', 'label': 'Guinea'},
#  {'id': 'Q427195', 'label': 'Triangle'},
#  {'id': 'Q2742711', 'label': 'distance'},
#  {'id': 'Q34042', 'label': 'Toda'},
#  {'id': 'Q211198', 'label': 'audience'},
#  {'id': 'Q1226939', 'label': 'division'},
#  {'id': 'Q225149', 'label': 'Jesus'},
#  {'id': 'Q50874388', 'label': 'ha'},
#  {'id': 'Q396315', 'label': 'García'},
#  {'id': 'Q269941', 'label': 'Martina'},
#  {'id': 'Q283992', 'label': 'ed'},
#  {'id': 'Q20021459', 'label': 'Magdalena'},
#  {'id': 'Q14411', 'label': 'pi'},
#  {'id': 'Q1070216', 'label': 'prime'},
#  {'id': 'Q11200092', 'label': 'Femme'},
#  {'id': 'Q213381', 'label': 'generation'},
#  {'id': 'Q552299', 'label': 'chain'},
#  {'id': 'Q724178', 'label': 'cent'},
#  {'id': 'Q850520', 'label': 'strike'},
#  {'id': 'Q1577970', 'label': 'ama'},
#  {'id': 'Q4430779', 'label': 'Immanuel'},
#  {'id': 'Q548876', 'label': 'Napoléon'},
#  {'id': 'Q494268', 'label': 'blood'},
#  {'id': 'Q505744', 'label': 'queen'},
#  {'id': 'Q5127848', 'label': 'class'},
#  {'id': 'Q7382648', 'label': 'majority'},
#  {'id': 'Q78392415', 'label': 'hunting'},
#  {'id': 'Q13582719', 'label': 'medley'},
#  {'id': 'Q218120', 'label': 'Mo'},
#  {'id': 'Q1506875', 'label': 'forest'},
#  {'id': 'Q3025161', 'label': 'series'},
#  {'id': 'Q28469711', 'label': 'first'},
#  {'id': 'Q37507784', 'label': 'Granada'},
#  {'id': 'Q36709', 'label': 'Toto'},
#  {'id': 'Q3851114', 'label': 'opportunity'},
#  {'id': 'Q14915034', 'label': 'course'},
#  {'id': 'Q76557', 'label': 'uncle'},
#  {'id': 'Q214743', 'label': 'vi'},
#  {'id': 'Q376895', 'label': 'as'},
#  {'id': 'Q951215', 'label': 'lai'},
#  {'id': 'Q2642727', 'label': 'period'},
#  {'id': 'Q31983622', 'label': 'reaction'},
#  {'id': 'Q846785', 'label': 'action'},
#  {'id': 'Q4958911', 'label': 'Aleksandra'},
#  {'id': 'Q1435416', 'label': 'rod'},
#  {'id': 'Q1852722', 'label': 'Rio'},
#  {'id': 'Q10861426', 'label': 'section'},
#  {'id': 'Q16280097', 'label': 'version'},
#  {'id': 'Q21142755', 'label': 'recognition'},
#  {'id': 'Q29288', 'label': 'Caesar'},
#  {'id': 'Q103184', 'label': 'article'},
#  {'id': 'Q829909', 'label': 'possession'},
#  {'id': 'Q28469712', 'label': 'second'},
#  {'id': 'Q205653', 'label': 'Orient'},
#  {'id': 'Q4281830', 'label': 'mark'},
#  {'id': 'Q39373172', 'label': 'half'},
#  {'id': 'Q18530', 'label': 'goal'},
#  {'id': 'Q493043', 'label': 'André'},
#  {'id': 'Q3941234', 'label': 'Rose'},
#  {'id': 'Q12897867', 'label': 'attempt'},
#  {'id': 'Q37713312', 'label': 'married'},
#  {'id': 'Q1172934', 'label': 'wing'},
#  {'id': 'Q2198779', 'label': 'unit'},
#  {'id': 'Q15633191', 'label': 'distrito'},
#  {'id': 'Q227004', 'label': 'Revolution'},
#  {'id': 'Q431958', 'label': 'Bau'},
#  {'id': 'Q655357', 'label': 'atlas'},
#  {'id': 'Q2396437', 'label': 'Nicholas'},
#  {'id': 'Q521164', 'label': 'mora'},
#  {'id': 'Q1469779', 'label': 'rose'},
#  {'id': 'Q189569', 'label': 'basis'},
#  {'id': 'Q908349', 'label': 'motif'},
#  {'id': 'Q185359', 'label': 'union'},
#  {'id': 'Q542869', 'label': 'supply'},
#  {'id': 'Q815844', 'label': 'method'},
#  {'id': 'Q986312', 'label': 'Napoleon'},
#  {'id': 'Q1630803', 'label': 'Hotel'},
#  {'id': 'Q12616377', 'label': 'Typhoon'},
#  {'id': 'Q455595', 'label': 'amateur'},
#  {'id': 'Q811480', 'label': 'tree'},
#  {'id': 'Q21169216', 'label': 'actress'},
#  {'id': 'Q156490', 'label': 'Smart'},
#  {'id': 'Q214272', 'label': 'remix'},
#  {'id': 'Q616314', 'label': 'interest'},
#  {'id': 'Q2006082', 'label': 'sun'},
#  {'id': 'Q756861', 'label': 'Susanna'},
#  {'id': 'Q2346367', 'label': 'Hannah'},
#  {'id': 'Q833053', 'label': 'theme'},
#  {'id': 'Q852061', 'label': 'champion'},
#  {'id': 'Q27948', 'label': 'list'},
#  {'id': 'Q1210151', 'label': 'run'},
#  {'id': 'Q345096', 'label': 'less'},
#  {'id': 'Q138396', 'label': 'Britannia'},
#  {'id': 'Q2265747', 'label': 'Red'},
#  {'id': 'Q345844', 'label': 'crew'},
#  {'id': 'Q730052', 'label': 'oni'},
#  {'id': 'Q8805', 'label': 'bit'},
#  {'id': 'Q32483', 'label': 'character'},
#  {'id': 'Q211804', 'label': 'Augustus'},
#  {'id': 'Q25392373', 'label': 'fund'},
#  {'id': 'Q203872', 'label': 'being'},
#  {'id': 'Q270827', 'label': 'solo'},
#  {'id': 'Q875399', 'label': 'boundary'},
#  {'id': 'Q11193', 'label': 'base'},
#  {'id': 'Q23595', 'label': 'centre'},
#  {'id': 'Q271671', 'label': 'Sophia'},
#  {'id': 'Q234180', 'label': 'Israel'},
#  {'id': 'Q1780244', 'label': 'commission'},
#  {'id': 'Q21075690', 'label': 'solution'},
#  {'id': 'Q43694649', 'label': 'building'},
#  {'id': 'Q1683601', 'label': 'ship'},
#  {'id': 'Q1163476', 'label': 'Ruggiero'},
#  {'id': 'Q4113741', 'label': 'langue'},
#  {'id': 'Q224234', 'label': 'tango'},
#  {'id': 'Q1784355', 'label': 'Earth'},
#  {'id': 'Q190139', 'label': 'talent'},
#  {'id': 'Q930412', 'label': 'depth'},
#  {'id': 'Q178748', 'label': 'iris'},
#  {'id': 'Q50412353', 'label': 'administration'},
#  {'id': 'Q210718', 'label': 'Asia'},
#  {'id': 'Q1643184', 'label': 'help'},
#  {'id': 'Q58481980', 'label': 'duque'},
#  {'id': 'Q486803', 'label': 'Poetry'},
#  {'id': 'Q1351496', 'label': 'Louis'},
#  {'id': 'Q855395', 'label': 'interpretation'},
#  {'id': 'Q878143', 'label': 'value'},
#  {'id': 'Q189214', 'label': 'tempo'},
#  {'id': 'Q1512164', 'label': 'Licht'},
#  {'id': 'Q3107057', 'label': 'Ángel'},
#  {'id': 'Q223822', 'label': 'Or'},
#  {'id': 'Q746321', 'label': 'Concordia'},
#  {'id': 'Q1191504', 'label': 'star'},
#  {'id': 'Q139', 'label': 'queen'},
#  {'id': 'Q920374', 'label': 'Ten'},
#  {'id': 'Q2935533', 'label': 'campo'},
#  {'id': 'Q20017794', 'label': 'Gill'},
#  {'id': 'Q362482', 'label': 'operation'},
#  {'id': 'Q18204', 'label': 'class'},
#  {'id': 'Q104837', 'label': 'phase'},
#  {'id': 'Q219858', 'label': 'zone'},
#  {'id': 'Q14390', 'label': 'delta'},
#  {'id': 'Q212878', 'label': 'husband'},
#  {'id': 'Q421744', 'label': 'act'},
#  {'id': 'Q17297777', 'label': 'friend'},
#  {'id': 'Q300867', 'label': 'make'},
#  {'id': 'Q50388354', 'label': 'escape'},
#  {'id': 'Q138', 'label': 'king'},
#  {'id': 'Q106825', 'label': 'Rodriguez'},
#  {'id': 'Q30287', 'label': 'Era'},
#  {'id': 'Q34949', 'label': 'Bassa'},
#  {'id': 'Q4269760', 'label': 'Lucía'},
#  {'id': 'Q105044823', 'label': 'publisher'},
#  {'id': 'Q3143', 'label': 'Europa'},
#  {'id': 'Q47144', 'label': 'Linus'},
#  {'id': 'Q2133296', 'label': 'space'},
#  {'id': 'Q207497', 'label': 'Macedonia'},
#  {'id': 'Q3326454', 'label': 'movement'},
#  {'id': 'Q3419242', 'label': 'heart'},
#  {'id': 'Q216601', 'label': 'object'},
#  {'id': 'Q3962655', 'label': 'opinion'},
#  {'id': 'Q833734', 'label': 'tone'},
#  {'id': 'Q1102161', 'label': 'jungle'},
#  {'id': 'Q28974885', 'label': 'Go'},
#  {'id': 'Q58093', 'label': 'cent'},
#  {'id': 'Q495871', 'label': 'professor'},
#  {'id': 'Q36732', 'label': 'kingdom'},
#  {'id': 'Q586657', 'label': 'Cuba'},
#  {'id': 'Q1326028', 'label': 'camp'},
#  {'id': 'Q2067656', 'label': 'Ende'},
#  {'id': 'Q1535980', 'label': 'Shadows'},
#  {'id': 'Q208385', 'label': 'ale'},
#  {'id': 'Q56668', 'label': 'Massa'},
#  {'id': 'Q208320', 'label': 'gong'},
#  {'id': 'Q27955792', 'label': 'Eleven'},
#  {'id': 'Q3710', 'label': 'foot'},
#  {'id': 'Q76363443', 'label': 'Hope'},
#  {'id': 'Q192630', 'label': 'past'},
#  {'id': 'Q185674', 'label': 'field'},
#  {'id': 'Q936704', 'label': 'Sud'},
#  {'id': 'Q172827', 'label': 'sari'},
#  {'id': 'Q1185607', 'label': 'scene'},
#  {'id': 'Q3010400', 'label': 'Caesar'},
#  {'id': 'Q71307273', 'label': 'Mother'},
#  {'id': 'Q678643', 'label': 'Elena'},
#  {'id': 'Q40157', 'label': 'lava'},
#  {'id': 'Q183046', 'label': 'meaning'},
#  {'id': 'Q255870', 'label': 'Julia'},
#  {'id': 'Q745951', 'label': 'Faust'},
#  {'id': 'Q2150504', 'label': 'signal'},
#  {'id': 'Q19798642', 'label': 'value'},
#  {'id': 'Q332885', 'label': 'Faust'},
#  {'id': 'Q47585', 'label': 'Garda'},
#  {'id': 'Q494756', 'label': 'data'},
#  {'id': 'Q23939248', 'label': 'London'},
#  {'id': 'Q188637', 'label': 'Si'},
#  {'id': 'Q188751', 'label': 'Caesar'},
#  {'id': 'Q6485329', 'label': 'Julia'},
#  {'id': 'Q1269082', 'label': 'Alice'},
#  {'id': 'Q190200', 'label': 'altitude'},
#  {'id': 'Q1260632', 'label': 'content'},
#  {'id': 'Q4479242', 'label': 'class'},
#  {'id': 'Q914332', 'label': 'Jérusalem'},
#  {'id': 'Q1435365', 'label': 'top'},
#  {'id': 'Q15332388', 'label': 'down'},
#  {'id': 'Q15332375', 'label': 'up'},
#  {'id': 'Q19828539', 'label': 'squadron'},
#  {'id': 'Q188736', 'label': 'Bosnia'},
#  {'id': 'Q7831579', 'label': 'Tracks'},
#  {'id': 'Q12826913', 'label': 'season'},
#  {'id': 'Q1200750', 'label': 'description'},
#  {'id': 'Q308902', 'label': 'Victoria'},
#  {'id': 'Q3059502', 'label': 'critique'},
#  {'id': 'Q1682108', 'label': 'vision'},
#  {'id': 'Q207389', 'label': 'Rachel'},
#  {'id': 'Q240673', 'label': 'cost'},
#  {'id': 'Q1924163', 'label': 'Ma'},
#  {'id': 'Q158357', 'label': 'Marks'},
#  {'id': 'Q232452', 'label': 'Benoit'},
#  {'id': 'Q12888920', 'label': 'choice'},
#  {'id': 'Q1020559', 'label': 'Murcia'},
#  {'id': 'Q56281007', 'label': 'Foundation'},
#  {'id': 'Q173253', 'label': 'sense'},
#  {'id': 'Q1069725', 'label': 'page'},
#  {'id': 'Q2141565', 'label': 'situation'},
#  {'id': 'Q1412224', 'label': 'tribunal'},
#  {'id': 'Q27888038', 'label': 'Mars'},
#  {'id': 'Q217594', 'label': 'class'},
#  {'id': 'Q228355', 'label': 'Peru'},
#  {'id': 'Q68773434', 'label': 'center'},
#  {'id': 'Q193168', 'label': 'present'},
#  {'id': 'Q12893838', 'label': 'order'},
#  {'id': 'Q134041', 'label': 'cola'},
#  {'id': 'Q12202238', 'label': 'transformation'},
#  {'id': 'Q155656', 'label': 'will'},
#  {'id': 'Q1046315', 'label': 'level'},
#  {'id': 'Q37221', 'label': 'diameter'},
#  {'id': 'Q235087', 'label': 'Julia'},
#  {'id': 'Q985394', 'label': 'editor'},
#  {'id': 'Q43471', 'label': 'arm'},
#  {'id': 'Q19269277', 'label': 'first'},
#  {'id': 'Q59318252', 'label': 'pink'},
#  {'id': 'Q1001933', 'label': 'Helena'},
#  {'id': 'Q11081619', 'label': 'land'},
#  {'id': 'Q18560095', 'label': 'winner'},
#  {'id': 'Q1258618', 'label': 'van'},
#  {'id': 'Q10578722', 'label': 'maximum'},
#  {'id': 'Q51647', 'label': 'mission'},
#  {'id': 'Q20085839', 'label': 'Si'},
#  {'id': 'Q1434621', 'label': 'Ouest'},
#  {'id': 'Q107', 'label': 'space'},
#  {'id': 'Q28840755', 'label': 'surface'},
#  {'id': 'Q1277366', 'label': 'Noel'},
#  {'id': 'Q181238', 'label': 'Africa'},
#  {'id': 'Q50000', 'label': 'victory'},
#  {'id': 'Q21998199', 'label': 'Frontier'},
#  {'id': 'Q2625603', 'label': 'population'},
#  {'id': 'Q5195043', 'label': 'borough'},
#  {'id': 'Q783521', 'label': 'title'},
#  {'id': 'Q10861465', 'label': 'brother'},
#  {'id': 'Q22721', 'label': 'Regierungsbezirk'},
#  {'id': 'Q17285', 'label': 'plane'},
#  {'id': 'Q661660', 'label': 'Mediterraneo'},
#  {'id': 'Q1663557', 'label': 'initiative'},
#  {'id': 'Q468777', 'label': 'existence'},
#  {'id': 'Q1071047', 'label': 'comes'},
#  {'id': 'Q185957', 'label': 'quality'},
#  {'id': 'Q595094', 'label': 'sister'},
#  {'id': 'Q31464082', 'label': 'source'},
#  {'id': 'Q9165', 'label': 'soul'},
#  {'id': 'Q752348', 'label': 'Victoria'},
#  {'id': 'Q1403377', 'label': 'franc'},
#  {'id': 'Q59820617', 'label': 'Member'},
#  {'id': 'Q190507', 'label': 'hope'},
#  {'id': 'Q207707', 'label': 'choir'},
#  {'id': 'Q1474521', 'label': 'function'},
#  {'id': 'Q82650', 'label': 'taxi'},
#  {'id': 'Q205663', 'label': 'process'},
#  {'id': 'Q21427355', 'label': 'Raw'},
#  {'id': 'Q719395', 'label': 'category'},
#  {'id': 'Q2005341', 'label': 'Angel'},
#  {'id': 'Q21550515', 'label': 'cross'},
#  {'id': 'Q403523', 'label': 'system'},
#  {'id': 'Q618536', 'label': 'candidate'},
#  {'id': 'Q929848', 'label': 'movement'},
#  {'id': 'Q1851760', 'label': 'victim'},
#  {'id': 'Q65061643', 'label': 'Peninsula'},
#  {'id': 'Q4197743', 'label': 'player'},
#  {'id': 'Q1763214', 'label': 'municipio'},
#  {'id': 'Q2569593', 'label': 'Canada'},
#  {'id': 'Q529711', 'label': 'beginning'},
#  {'id': 'Q18550', 'label': 'mafia'},
#  {'id': 'Q338450', 'label': 'tango'},
#  {'id': 'Q2561440', 'label': 'Earth'},
#  {'id': 'Q194808', 'label': 'Sarah'},
#  {'id': 'Q35059', 'label': 'width'},
#  {'id': 'Q13284', 'label': 'Sora'},
#  {'id': 'Q1464994', 'label': 'Latino'},
#  {'id': 'Q338754', 'label': 'control'},
#  {'id': 'Q244696', 'label': 'peso'},
#  {'id': 'Q537554', 'label': 'Sigurd'},
#  {'id': 'Q1228250', 'label': 'line'},
#  {'id': 'Q826930', 'label': 'heart'},
#  {'id': 'Q20888800', 'label': 'loss'},
#  {'id': 'Q170494', 'label': 'body'},
#  {'id': 'Q209878', 'label': 'Rome'},
#  {'id': 'Q214102', 'label': 'Union'},
#  {'id': 'Q662639', 'label': 'star'},
#  {'id': 'Q137823', 'label': 'monitor'},
#  {'id': 'Q1138610', 'label': 'Don'},
#  {'id': 'Q7632586', 'label': 'success'},
#  {'id': 'Q177232', 'label': 'son'},
#  {'id': 'Q484298', 'label': 'surface'},
#  {'id': 'Q308194', 'label': 'daughter'},
#  {'id': 'Q955347', 'label': 'Raphaël'},
#  {'id': 'Q1137365', 'label': 'entrance'},
#  {'id': 'Q2092603', 'label': 'member'},
#  {'id': 'Q15401930', 'label': 'product'},
#  {'id': 'Q4120621', 'label': 'rank'},
#  {'id': 'Q40795', 'label': 'kata'},
#  {'id': 'Q1144560', 'label': 'rate'},
#  {'id': 'Q229702', 'label': 'Ham'},
#  {'id': 'Q272735', 'label': 'tree'},
#  {'id': 'Q23387', 'label': 'week'},
#  {'id': 'Q37172', 'label': 'wave'},
#  {'id': 'Q319676', 'label': 'competition'},
#  {'id': 'Q32979242', 'label': 'Julia'},
#  {'id': 'Q13349', 'label': 'Mon'},
#  {'id': 'Q161358', 'label': 'wing'},
#  {'id': 'Q1707847', 'label': 'role'},
#  {'id': 'Q622645', 'label': 'attitude'},
#  {'id': 'Q5283295', 'label': 'administration'},
#  {'id': 'Q276258', 'label': 'childhood'},
#  {'id': 'Q7722', 'label': 'morning'},
#  {'id': 'Q131841', 'label': 'idea'},
#  {'id': 'Q1355298', 'label': 'examination'},
#  {'id': 'Q1421', 'label': 'Titus'},
#  {'id': 'Q788790', 'label': 'documentation'},
#  {'id': 'Q5151', 'label': 'month'},
#  {'id': 'Q107626', 'label': 'Seth'},
#  {'id': 'Q44337', 'label': 'matrix'},
#  {'id': 'Q936496', 'label': 'sable'},
#  {'id': 'Q193432', 'label': 'fan'},
#  {'id': 'Q478536', 'label': 'Three'},
#  {'id': 'Q28869365', 'label': 'issue'},
#  {'id': 'Q81214132', 'label': 'Maya'},
#  {'id': 'Q1174599', 'label': 'attack'},
#  {'id': 'Q7565', 'label': 'father'},
#  {'id': 'Q642420', 'label': 'Christ'},
#  {'id': 'Q500460', 'label': 'Evolution'},
#  {'id': 'Q44532072', 'label': 'launch'},
#  {'id': 'Q103251', 'label': 'Macedonia'},
#  {'id': 'Q901407', 'label': 'Dame'},
#  {'id': 'Q314700', 'label': 'Joachim'},
#  {'id': 'Q188889', 'label': 'code'},
#  {'id': 'Q506439', 'label': 'Martinez'},
#  {'id': 'Q19828534', 'label': 'wing'},
#  {'id': 'Q2502489', 'label': 'Belle'},
#  {'id': 'Q188830', 'label': 'wife'},
#  {'id': 'Q25342', 'label': 'power'},
#  {'id': 'Q25235', 'label': 'hour'},
#  {'id': 'Q1173065', 'label': 'album'},
#  {'id': 'Q194428', 'label': 'stage'},
#  {'id': 'Q17172848', 'label': 'theatre'},
#  {'id': 'Q643589', 'label': 'department'},
#  {'id': 'Q16502', 'label': 'world'},
#  {'id': 'Q824979', 'label': 'group'},
#  {'id': 'Q6983813', 'label': 'alto'},
#  {'id': 'Q165170', 'label': 'Europa'},
#  {'id': 'Q509913', 'label': 'Legend'},
#  {'id': 'Q290', 'label': 'sex'},
#  {'id': 'Q621184', 'label': 'problem'},
#  {'id': 'Q17853087', 'label': 'merge'},
#  {'id': 'Q7937', 'label': 'climate'},
#  {'id': 'Q20085837', 'label': 'Sun'},
#  {'id': 'Q37017', 'label': 'face'},
#  {'id': 'Q1761572', 'label': 'barrio'},
#  {'id': 'Q7949', 'label': 'truth'},
#  {'id': 'Q56000996', 'label': 'Us'},
#  {'id': 'Q3769128', 'label': 'giudice'},
#  {'id': 'Q637820', 'label': 'Amour'},
#  {'id': 'Q18703032', 'label': 'Room'},
#  {'id': 'Q2647254', 'label': 'study'},
#  {'id': 'Q17955', 'label': 'criticism'},
#  {'id': 'Q223359', 'label': 'Rio'},
#  {'id': 'Q334460', 'label': 'division'},
#  {'id': 'Q55741', 'label': 'Angeles'},
#  {'id': 'Q235849', 'label': 'Elizabeth'},
#  {'id': 'Q5978719', 'label': 'Diplom'},
#  {'id': 'Q39312312', 'label': 'Petro'},
#  {'id': 'Q1632158', 'label': 'Napoléon'},
#  {'id': 'Q409022', 'label': 'Airport'},
#  {'id': 'Q918385', 'label': 'training'},
#  {'id': 'Q2151613', 'label': 'direction'},
#  {'id': 'Q908430', 'label': 'crown'},
#  {'id': 'Q989470', 'label': 'clan'},
#  {'id': 'Q12772819', 'label': 'discovery'},
#  {'id': 'Q634', 'label': 'planet'},
#  {'id': 'Q46311', 'label': 'bow'},
#  {'id': 'Q467011', 'label': 'invasion'},
#  {'id': 'Q11563', 'label': 'number'},
#  {'id': 'Q430099', 'label': 'gold'},
#  {'id': 'Q83478', 'label': 'group'},
#  {'id': 'Q20080347', 'label': 'Yun'},
#  {'id': 'Q854429', 'label': 'portal'},
#  {'id': 'Q25107', 'label': 'power'},
#  {'id': 'Q1072012', 'label': 'international'},
#  {'id': 'Q18131152', 'label': 'round'},
#  {'id': 'Q126017', 'label': 'distance'},
#  {'id': 'Q317802', 'label': 'silver'},
#  {'id': 'Q133250', 'label': 'sequence'},
#  {'id': 'Q253623', 'label': 'patent'},
#  {'id': 'Q42848', 'label': 'data'},
#  {'id': 'Q102911', 'label': 'Holland'},
#  {'id': 'Q6813700', 'label': 'Qu'},
#  {'id': 'Q14524493', 'label': 'terrain'},
#  {'id': 'Q208826', 'label': 'height'},
#  {'id': 'Q217602', 'label': 'analysis'},
#  {'id': 'Q44946', 'label': 'point'},
#  {'id': 'Q112', 'label': 'Mars'},
#  {'id': 'Q918727', 'label': 'revue'},
#  {'id': 'Q35874', 'label': 'humour'},
#  {'id': 'Q183061', 'label': 'facade'},
#  {'id': 'Q11466', 'label': 'temperature'},
#  {'id': 'Q2407862', 'label': 'Americana'},
#  {'id': 'Q15116915', 'label': 'show'},
#  {'id': 'Q14819852', 'label': 'birth'},
#  {'id': 'Q541354', 'label': 'Faust'},
#  {'id': 'Q10566551', 'label': 'safety'},
#  {'id': 'Q191421', 'label': 'lama'},
#  {'id': 'Q11039337', 'label': 'Shang'},
#  {'id': 'Q3266850', 'label': 'commune'},
#  {'id': 'Q39552', 'label': 'pressure'},
#  {'id': 'Q2029841', 'label': 'organization'},
#  {'id': 'Q3', 'label': 'life'},
#  {'id': 'Q3481047', 'label': 'ratio'},
#  {'id': 'Q57695350', 'label': 'Ireland'},
#  {'id': 'Q11432', 'label': 'gas'},
#  {'id': 'Q16823155', 'label': 'Schloss'},
#  {'id': 'Q34679', 'label': 'sand'},
#  {'id': 'Q21146257', 'label': 'type'},
#  {'id': 'Q1229071', 'label': 'motif'},
#  {'id': 'Q11822', 'label': 'Roses'},
#  {'id': 'Q575', 'label': 'night'},
#  {'id': 'Q162827', 'label': 'atlas'},
#  {'id': 'Q379825', 'label': 'element'},
#  {'id': 'Q28575', 'label': 'county'},
#  {'id': 'Q344', 'label': 'future'},
#  {'id': 'Q280209', 'label': 'mas'},
#  {'id': 'Q327245', 'label': 'team'},
#  {'id': 'Q679', 'label': 'west'},
#  {'id': 'Q7860', 'label': 'nature'},
#  {'id': 'Q1411', 'label': 'Claudius'},
#  {'id': 'Q104021', 'label': 'fauna'},
#  {'id': 'Q11402', 'label': 'force'},
#  {'id': 'Q40843', 'label': 'cross'},
#  {'id': 'Q488383', 'label': 'object'},
#  {'id': 'Q1003030', 'label': 'test'},
#  {'id': 'Q188863', 'label': 'exile'},
#  {'id': 'Q7364', 'label': 'eye'},
#  {'id': 'Q178651', 'label': 'interview'},
#  {'id': 'Q217577', 'label': 'diploma'},
#  {'id': 'Q1404101', 'label': 'fellow'},
#  {'id': 'Q878123', 'label': 'racing'},
#  {'id': 'Q190007', 'label': 'youth'},
#  {'id': 'Q207961', 'label': 'shape'},
#  {'id': 'Q976981', 'label': 'formula'},
#  {'id': 'Q14383', 'label': 'Sava'},
#  {'id': 'Q667', 'label': 'south'},
#  {'id': 'Q1313', 'label': 'summer'},
#  {'id': 'Q3503', 'label': 'Congo'},
#  {'id': 'Q9081', 'label': 'knowledge'},
#  {'id': 'Q3335922', 'label': 'Napoléon'},
#  {'id': 'Q178440', 'label': 'Dari'},
#  {'id': 'Q27318', 'label': 'test'},
#  {'id': 'Q4897819', 'label': 'role'},
#  {'id': 'Q132543', 'label': 'Diana'},
#  {'id': 'Q3392', 'label': 'Nile'},
#  {'id': 'Q1292119', 'label': 'style'},
#  {'id': 'Q9128', 'label': 'light'},
#  {'id': 'Q29485', 'label': 'error'},
#  {'id': 'Q48349', 'label': 'empire'},
#  {'id': 'Q210003', 'label': 'Halle'},
#  {'id': 'Q684', 'label': 'east'},
#  {'id': 'Q55657615', 'label': 'commission'},
#  {'id': 'Q152456', 'label': 'Munich'},
#  {'id': 'Q1005907', 'label': 'Earth'},
#  {'id': 'Q36133', 'label': 'soil'},
#  {'id': 'Q3505845', 'label': 'state'},
#  {'id': 'Q2366336', 'label': 'seigneur'},
#  {'id': 'Q496946', 'label': 'table'},
#  {'id': 'Q17126729', 'label': 'red'},
#  {'id': 'Q183366', 'label': 'territory'},
#  {'id': 'Q6671777', 'label': 'structure'},
#  {'id': 'Q279749', 'label': 'form'},
#  {'id': 'Q573', 'label': 'day'},
#  {'id': 'Q650711', 'label': 'combat'},
#  {'id': 'Q189524', 'label': 'fleet'},
#  {'id': 'Q841654', 'label': 'competition'},
#  {'id': 'Q2311958', 'label': 'canton'},
#  {'id': 'Q23392', 'label': 'ice'},
#  {'id': 'Q145746', 'label': 'Joseph'},
#  {'id': 'Q11471', 'label': 'time'},
#  {'id': 'Q712597', 'label': 'article'},
#  {'id': 'Q12277', 'label': 'arch'},
#  {'id': 'Q659', 'label': 'north'},
#  {'id': 'Q33767', 'label': 'hand'},
#  {'id': 'Q11707054', 'label': 'major'},
#  {'id': 'Q289957', 'label': 'Jacob'},
#  {'id': 'Q160151', 'label': 'price'},
#  {'id': 'Q213449', 'label': 'eating'},
#  {'id': 'Q79782', 'label': 'motion'},
#  {'id': 'Q1274115', 'label': 'responsibility'},
#  {'id': 'Q4164344', 'label': 'documentary'},
#  {'id': 'Q1311', 'label': 'winter'},
#  {'id': 'Q124490', 'label': 'violence'},
#  {'id': 'Q1436734', 'label': 'adventure'},
#  {'id': 'Q17151875', 'label': 'Hui'},
#  {'id': 'Q45749', 'label': 'An'},
#  {'id': 'Q211364', 'label': 'principle'},
#  {'id': 'Q37654', 'label': 'market'},
#  {'id': 'Q330679', 'label': 'cantor'},
#  {'id': 'Q101687', 'label': 'altar'},
#  {'id': 'Q1979154', 'label': 'model'},
#  {'id': 'Q454', 'label': 'peace'},
#  {'id': 'Q524158', 'label': 'kami'},
#  {'id': 'Q44342', 'label': 'legend'},
#  {'id': 'Q3918409', 'label': 'proposal'},
#  {'id': 'Q6458', 'label': 'nova'},
#  {'id': 'Q40204814', 'label': 'Artur'},
#  {'id': 'Q491', 'label': 'friendship'},
#  {'id': 'Q83180', 'label': 'roof'},
#  {'id': 'Q17245659', 'label': 'gray'},
#  {'id': 'Q8094', 'label': 'wind'},
#  {'id': 'Q315', 'label': 'language'},
#  {'id': 'Q21170479', 'label': 'possibility'},
#  {'id': 'Q56449214', 'label': 'Maria'},
#  {'id': 'Q82821', 'label': 'tradition'},
#  {'id': 'Q10931', 'label': 'revolution'},
#  {'id': 'Q282049', 'label': 'career'},
#  {'id': 'Q6058157', 'label': 'god'},
#  {'id': 'Q3196', 'label': 'fire'},
#  {'id': 'Q16256197', 'label': 'Go'},
#  {'id': 'Q23640', 'label': 'head'},
#  {'id': 'Q9332', 'label': 'behavior'},
#  {'id': 'Q1063', 'label': 'evolution'},
#  {'id': 'Q26132748', 'label': 'development'},
#  {'id': 'Q192581', 'label': 'job'},
#  {'id': 'Q813912', 'label': 'condition'},
#  {'id': 'Q171', 'label': 'wiki'},
#  {'id': 'Q42373828', 'label': 'Leon'},
#  {'id': 'Q1405', 'label': 'Augustus'},
#  {'id': 'Q5004679', 'label': 'path'},
#  {'id': 'Q47528', 'label': 'radar'},
#  {'id': 'Q12488911', 'label': 'kampung'},
#  {'id': 'Q5257307', 'label': 'prize'},
#  {'id': 'Q3181348', 'label': 'section'},
#  {'id': 'Q178122', 'label': 'aria'},
#  {'id': 'Q34876', 'label': 'province'},
#  {'id': 'Q35749', 'label': 'parliament'},
#  {'id': 'Q656720', 'label': 'workshop'},
#  {'id': 'Q182832', 'label': 'concert'},
#  {'id': 'Q20937557', 'label': 'series'},
#  {'id': 'Q6266', 'label': 'nation'},
#  {'id': 'Q16889133', 'label': 'class'},
#  {'id': 'Q36963', 'label': 'hunting'},
#  {'id': 'Q900406', 'label': 'reform'},
#  {'id': 'Q11019', 'label': 'machine'},
#  {'id': 'Q42889', 'label': 'vehicle'},
#  {'id': 'Q203005', 'label': 'suite'},
#  {'id': 'Q36161', 'label': 'set'},
#  {'id': 'Q15051339', 'label': 'opening'},
#  {'id': 'Q177634', 'label': 'community'},
#  {'id': 'Q219160', 'label': 'couple'},
#  ...]

# %% [markdown]
# **Runs consecutive tests on list of languages, queries them from the database and prints the length - ENGLISH CENTRIC**

# %%
language_list = [['en', 'zh'], ['en', 'ja'], ['en', 'ko'], ['en', 'ru']]

for languages in language_list:
    
    # Create query for MongoDB
    exist_value = {'$exists':True}
    query = {'value': exist_value}

    for lang in languages:
        query['labels.' + lang] = exist_value

    # Run Query and gather list of entity candidates (Single Token + More than 1 letter and no numbers)
    candidates = []

    search = entityList.find(query)
    
    # Language to test if not number (has to be european)
    primary = languages[0]

    for document in search:
        if all(k in document['labels'] for k in languages):
            wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]
            if (all(len(l) == 1 for l in wordTokens)):
                # Get test value in test lang
                test_value = document['labels'][primary]['value']
                if test_value.isalpha() and isLatin(test_value) and len(test_value) > 1 and not all_same([document['labels'][k]['value'] for k in languages]):
                    candidates.append({'id': document['id'], 'label': test_value})
                    
    print(len(candidates))

# %% [markdown]
# **Runs consecutive tests on list of languages, queries them from the database and prints the length - ASIAN CENTRIC**
#
# To get rid of unicode characters hiding as entities, we also query for english. This shouldn't be too limiting since wikidata is primarily english.

# %%
language_list = [['ru', 'zh'], ['zh', 'ja'], ['ru', 'ja']]

for languages in language_list:
    
    # Create query for MongoDB
    exist_value = {'$exists':True}
    query = {'value': exist_value}

    for lang in languages:
        query['labels.' + lang] = exist_value
    
    query['labels.en'] = exist_value

    # Run Query and gather list of entity candidates (Single Token + More than 1 letter and no numbers)
    candidates = []

    search = entityList.find(query)
    
    # Language to test if not number (has to be european)
    primary = languages[0]

    for document in search:
        if all(k in document['labels'] for k in languages):
            wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]
            if (all(len(l) == 1 for l in wordTokens)):
                # Get test value in test lang
                test_value = document['labels']['en']['value']
                if test_value.isalpha() and isLatin(test_value) and len(test_value) > 1 and not all_same([document['labels'][k]['value'] for k in languages]):
                    candidates.append({'id': document['id'], 'label': test_value})
                    
    print(len(candidates))
# Out:
# 301
# 346
# 292

# %% [markdown]
# #### Compute Language Pair Datasets and save them all in one

# %%
languages_list = [['en', 'de', 'fr', 'es']]

# %%
for languages in languages_list:
    entities = defaultdict(list)

    exist = {'$exists':True}
    query = {'value': exist}

    for lang in languages:
        query['labels.' + lang] = exist

    length = entityList.count_documents(query)
    search = entityList.find(query)

    for document in tqdm(search, total=length):
        if all(k in document['labels'] for k in languages):
            # Tokenize
            wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]

            # If all wordTokens are singular...
            if (all(len(l) == 1 for l in wordTokens)):

                # Takes first language (probably english)
                test_value = document['labels'][languages[0]]['value']

                # Test for edge cases
                if test_value.isalpha() and isLatin(test_value) and len(test_value) > 1:
                    entities['id'].append(document['id'])
                    for lang in languages:
                        entities[lang].append(document['labels'][lang]['value'])
    
    print("Saving...")
    df = pd.DataFrame(entities)
    df_wo_duplicates = df.drop_duplicates(subset=languages[0], keep='first')
    
    # Save as CSV for manual cleanup
    path = '../data/entities/SingleToken/multilingual/'

    lang_path = ''
    for i, lang in enumerate(languages):
            lang_path += lang + '_'

    df_wo_duplicates.to_csv(path + lang_path + 'entities.csv', index=False)
# Out:
#   0%|          | 0/3087705 [00:00<?, ?it/s]

# %% [markdown]
# And the same slightly different for Asian languages:

# %%
languages_list = [['ru', 'zh'], ['zh', 'ja'], ['ru', 'ja']]

# %%
dfs = []

for languages in languages_list:
    entities = defaultdict(list)

    exist = {'$exists':True}
    query = {'value': exist}

    for lang in languages:
        query['labels.' + lang] = exist
        
    query['labels.en'] = exist_value

    length = entityList.count_documents(query)
    search = entityList.find(query)

    for document in tqdm(search, total=length):
        if all(k in document['labels'] for k in languages):
            # Tokenize
            wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]

            # If all wordTokens are singular...
            if (all(len(l) == 1 for l in wordTokens)):

                # Takes first language (probably english)
                test_value = document['labels']['en']['value']

                # Test for edge cases
                if test_value.isalpha() and isLatin(test_value) and len(test_value) > 1:
                    entities['id'].append(document['id'])
                    for lang in languages:
                        entities[lang].append(document['labels'][lang]['value'])
    
    df = pd.DataFrame(entities)
    dfs.append(df)
# Out:
#   0%|          | 0/875905 [00:00<?, ?it/s]
#   0%|          | 0/992013 [00:00<?, ?it/s]
#   0%|          | 0/868509 [00:00<?, ?it/s]

# %% [markdown]
# #### Postprocess and Save

# %%
# Entity Candidates to Dataframe
df = pd.DataFrame(entities)
print(df)
# Out:
#              id        en zh
# 0      Q1155980        se  瑟
# 1      Q1363153     cream  霜
# 2       Q980612       gun  棍
# 3      Q1078168        to  斗
# 4      Q1759242       Shi  詩
# ...         ...       ... ..
# 1275       Q532   village  村
# 1276  Q14349455  membrane  膜
# 1277      Q7432   species  种
# 1278   Q6581072    female  女
# 1279   Q6581097      male  男
#
# [1280 rows x 3 columns]

# %%
df
# Out:
#           id        ru    ja
# 0    Q218181        Ce    CE
# 1    Q218008        Sr    SR
# 2    Q218716        Sv    SV
# 3    Q224441        Fr    FR
# 4    Q342744      Игра   ゲーム
# ..       ...       ...   ...
# 287    Q7432       вид     種
# 288      Q29   Испания  スペイン
# 289     Q159    Россия   ロシア
# 290     Q142   Франция  フランス
# 291     Q183  Германия   ドイツ
#
# [292 rows x 3 columns]

# %%
df = dfs[0]
languages = ['ru', 'zh']

# %%
# Remove caseinsensitive duplicates
df['ru_upper'] = df['ru'].astype(str).str.upper()
df = df.drop_duplicates(subset='ru_upper', keep='first')
df = df.drop(columns=['ru_upper'], axis=1)
df
# Out:
#           id       ru       zh
# 0    Q216756      DDR      DDR
# 1    Q217417       HF       HF
# 2    Q218887       SC       SC
# 3    Q224432      RMS      RMS
# 4    Q224763       ST       ST
# ..       ...      ...      ...
# 879    Q8502     гора        山
# 881  Q907311  Netflix  Netflix
# 882   Q11446    судно        船
# 883     Q532     село        村
# 884    Q7432      вид        种
#
# [751 rows x 3 columns]

# %%
# Remove duplicate labels TODO: need to look at duplicate sin all languages!!!!
for lang in languages:
    df = df.drop_duplicates(subset=lang, keep='first')
df
# Out:
#            id       ru       zh
# 0     Q216756      DDR      DDR
# 1     Q217417       HF       HF
# 2     Q218887       SC       SC
# 3     Q224432      RMS      RMS
# 4     Q224763       ST       ST
# ..        ...      ...      ...
# 877  Q2529610     Карл     Carl
# 879     Q8502     гора        山
# 881   Q907311  Netflix  Netflix
# 882    Q11446    судно        船
# 884     Q7432      вид        种
#
# [735 rows x 3 columns]

# %%
# Save as CSV for manual cleanup
path = '../data/entities/SingleToken/multilingual/'

lang_path = ''
for i, lang in enumerate(languages):
        lang_path += lang + '_'

df.to_csv(path + lang_path + 'entities2.csv', index=False)
