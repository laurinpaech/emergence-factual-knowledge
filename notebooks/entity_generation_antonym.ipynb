# %% [markdown]
# ### Antonym Entity Generation Notebook
# Using the entity generation notebook and the wikidata query results that generated antonym to make a antonym csv with multiple language labels.
#
# We take the entities by the number of occurences and do some preprocessing, essentially checking if the requirements of our entities are fulfilled and if the entities are in latin characters.
#
# For this we use a MongoDB Database that has the entities and cleaned entity/property triples. We count the occurences of entities in the triples and then join the collection with the entity collection so that every entity is also associated with its occurence value.

# %% [markdown]
# Requirements:
# - labels the same in en, fr, es, de
# - single tokens
#
# Cleanup:
# - No non-ascii symbols
# - No numbers

# %%
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
import pandas as pd
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.wikidata

# %%
db.list_collection_names()
# Out:
# ['entity2_triples',
#  'entity_counts',
#  'triplesInvert',
#  'triples',
#  'symmetric',
#  'nsproperties',
#  'inversion',
#  'entity_subset',
#  'equivalence',
#  'relation_subset',
#  'entityList',
#  'entity1_triples',
#  'properties']

# %%
# Load relations
properties = pd.read_csv('antonyms.csv')
properties
# Out:
#                                            item1  \
# 0      http://www.wikidata.org/entity/Q106521687
# 1            http://www.wikidata.org/entity/Q527
# 2              http://www.wikidata.org/entity/Q4
# 3              http://www.wikidata.org/entity/Q3
# 4       http://www.wikidata.org/entity/Q14819852
# ...                                          ...
# 23088    http://www.wikidata.org/entity/Q2213986
# 23089  http://www.wikidata.org/entity/Q110693173
# 23090  http://www.wikidata.org/entity/Q110693166
# 23091  http://www.wikidata.org/entity/Q110693217
# 23092  http://www.wikidata.org/entity/Q110693205
#
#                                             item1Label  \
# 0                                            antiverse
# 1                                                  sky
# 2                                                death
# 3                                                 life
# 4                                                birth
# ...                                                ...
# 23088                                  overachievement
# 23089        Spanish ambassador to the Austrian Empire
# 23090       Ambassador of the Austrian Empire in Spain
# 23091  Ambassador of Spain in the Archduchy of Austria
# 23092  Ambassador of the Archduchy of Austria in Spain
#
#                                            item2  \
# 0              http://www.wikidata.org/entity/Q1
# 1              http://www.wikidata.org/entity/Q2
# 2              http://www.wikidata.org/entity/Q3
# 3              http://www.wikidata.org/entity/Q4
# 4              http://www.wikidata.org/entity/Q4
# ...                                          ...
# 23088  http://www.wikidata.org/entity/Q110687770
# 23089  http://www.wikidata.org/entity/Q110693166
# 23090  http://www.wikidata.org/entity/Q110693173
# 23091  http://www.wikidata.org/entity/Q110693205
# 23092  http://www.wikidata.org/entity/Q110693217
#
#                                             item2Label
# 0                                             universe
# 1                                                Earth
# 2                                                 life
# 3                                                death
# 4                                                death
# ...                                                ...
# 23088                                 underachievement
# 23089       Ambassador of the Austrian Empire in Spain
# 23090        Spanish ambassador to the Austrian Empire
# 23091  Ambassador of the Archduchy of Austria in Spain
# 23092  Ambassador of Spain in the Archduchy of Austria
#
# [23093 rows x 4 columns]

# %%
db.entityList.find_one({})
# Out:
# {'_id': ObjectId('6206731a578a2e954363d9da'),
#  'id': 'Q28638',
#  'type': 'item',
#  'labels': {'ru': {'language': 'ru', 'value': 'Панславянские языки'},
#   'en': {'language': 'en', 'value': 'Pan-Slavic language'},
#   'de': {'language': 'de', 'value': 'Panslawische Sprache'},
#   'es': {'language': 'es', 'value': 'paneslávico'},
#   'fr': {'language': 'fr', 'value': 'langue pan-slaves'},
#   'it': {'language': 'it', 'value': 'Lingue artificiali a base slava'},
#   'zh': {'language': 'zh', 'value': '泛斯拉夫語言'},
#   'hu': {'language': 'hu', 'value': 'pánszláv nyelv'},
#   'pt': {'language': 'pt', 'value': 'língua pan-eslava'}}}

# %%
propertyList = properties.to_dict('list')
propertyList
# Out:
# {'item1': ['http://www.wikidata.org/entity/Q106521687',
#   'http://www.wikidata.org/entity/Q527',
#   'http://www.wikidata.org/entity/Q4',
#   'http://www.wikidata.org/entity/Q3',
#   'http://www.wikidata.org/entity/Q14819852',
#   'http://www.wikidata.org/entity/Q18170708',
#   'http://www.wikidata.org/entity/L291757',
#   'http://www.wikidata.org/entity/Q1598829',
#   'http://www.wikidata.org/entity/Q105839683',
#   'http://www.wikidata.org/entity/Q55386374',
#   'http://www.wikidata.org/entity/Q2647467',
#   'http://www.wikidata.org/entity/Q454',
#   'http://www.wikidata.org/entity/Q2114394',
#   'http://www.wikidata.org/entity/Q3827340',
#   'http://www.wikidata.org/entity/Q10728826',
#   'http://www.wikidata.org/entity/Q20021125',
#   'http://www.wikidata.org/entity/Q2310416',
#   'http://www.wikidata.org/entity/Q10728827',
#   'http://www.wikidata.org/entity/Q204',
#   'http://www.wikidata.org/entity/Q204',
#   'http://www.wikidata.org/entity/Q60981852',
#   'http://www.wikidata.org/entity/Q3250296',
#   'http://www.wikidata.org/entity/Q90860917',
#   'http://www.wikidata.org/entity/Q160232',
#   'http://www.wikidata.org/entity/Q272612',
#   'http://www.wikidata.org/entity/Q28954762',
#   'http://www.wikidata.org/entity/Q218616',
#   'http://www.wikidata.org/entity/Q192630',
#   'http://www.wikidata.org/entity/Q60741353',
#   'http://www.wikidata.org/entity/Q18237',
#   'http://www.wikidata.org/entity/Q198',
#   'http://www.wikidata.org/entity/Q8441',
#   'http://www.wikidata.org/entity/Q4464405',
#   'http://www.wikidata.org/entity/Q5275945',
#   'http://www.wikidata.org/entity/Q2',
#   'http://www.wikidata.org/entity/Q3363340',
#   'http://www.wikidata.org/entity/Q4489450',
#   'http://www.wikidata.org/entity/Q52643',
#   'http://www.wikidata.org/entity/Q131468',
#   'http://www.wikidata.org/entity/Q110541178',
#   'http://www.wikidata.org/entity/Q193353',
#   'http://www.wikidata.org/entity/Q667',
#   'http://www.wikidata.org/entity/Q679',
#   'http://www.wikidata.org/entity/Q684',
#   'http://www.wikidata.org/entity/Q659',
#   'http://www.wikidata.org/entity/Q679',
#   'http://www.wikidata.org/entity/Q684',
#   'http://www.wikidata.org/entity/Q667',
#   'http://www.wikidata.org/entity/Q684',
#   'http://www.wikidata.org/entity/Q667',
#   'http://www.wikidata.org/entity/Q679',
#   'http://www.wikidata.org/entity/Q83500',
#   'http://www.wikidata.org/entity/Q934',
#   'http://www.wikidata.org/entity/Q933',
#   'http://www.wikidata.org/entity/Q130352',
#   'http://www.wikidata.org/entity/Q11567495',
#   'http://www.wikidata.org/entity/Q83646243',
#   'http://www.wikidata.org/entity/Q210863',
#   'http://www.wikidata.org/entity/Q930412',
#   'http://www.wikidata.org/entity/Q193466',
#   'http://www.wikidata.org/entity/Q15141537',
#   'http://www.wikidata.org/entity/Q3833032',
#   'http://www.wikidata.org/entity/Q4392902',
#   'http://www.wikidata.org/entity/Q1289462',
#   'http://www.wikidata.org/entity/Q1747066',
#   'http://www.wikidata.org/entity/Q188961',
#   'http://www.wikidata.org/entity/Q450461',
#   'http://www.wikidata.org/entity/Q862085',
#   'http://www.wikidata.org/entity/Q184567',
#   'http://www.wikidata.org/entity/Q184453',
#   'http://www.wikidata.org/entity/Q774621',
#   'http://www.wikidata.org/entity/Q424630',
#   'http://www.wikidata.org/entity/Q1004377',
#   ...],
#  'item1Label': ['antiverse',
#   'sky',
#   'death',
#   'life',
#   'birth',
#   'non-human person',
#   'L291757',
#   'Malheur',
#   'unhappiness',
#   'non-pawn chess piece',
#   'non-alcoholic beverage',
#   'peace',
#   '½',
#   '−2',
#   '−3',
#   '⅓',
#   '¼',
#   '−4',
#   'zero',
#   'zero',
#   'Q60981852',
#   'acute angle',
#   'Q90860917',
#   'hatred',
#   'Steady State theory',
#   'non-science',
#   'proprietary software',
#   'past',
#   'anti-corruption',
#   'instinct',
#   'war',
#   'man',
#   'industriousness',
#   'enmity',
#   'Earth',
#   'paradise',
#   'heaven',
#   'daytime',
#   'white hole',
#   'heterosexual',
#   'phlogiston',
#   'south',
#   'west',
#   'east',
#   'north',
#   'west',
#   'east',
#   'south',
#   'east',
#   'south',
#   'west',
#   'intelligence',
#   'North Pole',
#   'South Pole',
#   'creationism',
#   'colorlessness',
#   'western animation',
#   'summer',
#   'autumn',
#   'winter',
#   'spring',
#   'solstice',
#   'Te Arai',
#   'uncitedness',
#   'non-English',
#   'non-food item',
#   'electron hole',
#   'unbarred spiral galaxy',
#   'beef cattle',
#   'girl',
#   'boy',
#   'structural Marxism',
#   'software',
#   'batch processing',
#   'astronomical object',
#   'heterobiography',
#   'divestment',
#   'backplane system',
#   'Bronchodilatation',
#   'Template:Oppose',
#   'ocean',
#   'former capital',
#   'European Russia',
#   'Nullator',
#   'natural fiber',
#   'patter song',
#   'anti-communism',
#   'anti-capitalism',
#   'Luddite movement',
#   'conservatism',
#   'anti-liberalism',
#   'anti-fascism',
#   'anti-authoritarianism',
#   'cosmopolitanism',
#   'anti-nationalism',
#   'cosmopolitanism',
#   'rest of the world',
#   'web server',
#   'male homosexuality',
#   'heterosexual female',
#   'Puerto Natales',
#   "Women's European Volleyball Championship",
#   'outer space',
#   'theism',
#   'idealism',
#   'unconsciousness',
#   'liberalism',
#   'autocracy',
#   'deglobalization',
#   'Warsaw Pact',
#   'political opposition',
#   'neontology',
#   'meronomy',
#   'ugliness',
#   'patriarchy',
#   'antifeminism',
#   'anti-imperialism',
#   'monarchic system',
#   'counter-terrorism',
#   'gentile',
#   'computer hardware',
#   'civilian clothes',
#   'father',
#   'mother',
#   'son',
#   'offspring',
#   'daughter',
#   'child',
#   'supernatural',
#   'non-drinking water',
#   'La Niña',
#   'global cooling',
#   'nonmineral',
#   'lie',
#   'witch or warlock',
#   'gadjo',
#   'soil',
#   'geosphere',
#   'Neiva',
#   'illiteracy',
#   'nonfiction',
#   'pedophobia',
#   'irrumatio',
#   'person',
#   'primitive culture',
#   'woman',
#   'divorce',
#   'anti-racism',
#   'Christchurch',
#   'ignorance',
#   'darkness',
#   'polytheism',
#   'monotheism',
#   'antireligion',
#   'Q11857691',
#   'continent',
#   'subjective reality',
#   'artery',
#   'vein',
#   'enriched uranium',
#   'intra-word punctuation mark',
#   'Bharatiya Janata Party',
#   'Indian National Congress',
#   'wealth',
#   'counter-revolution',
#   'evolution',
#   'House of Lords',
#   'House of Commons',
#   'grassroots media',
#   'exocrine system',
#   'base',
#   'organic chemistry',
#   'simple substance',
#   'slash',
#   'public IP address',
#   'acid',
#   'exponential function',
#   'antilogarithm',
#   'web browser',
#   'Q58214760',
#   'chemical anti-element',
#   'inorganic chemistry',
#   'ion',
#   'wired network',
#   'non-gravitational force',
#   'nonmetal',
#   'silence',
#   'real number',
#   'United States Senate',
#   'April, May and June',
#   'benign neoplasm',
#   'queen',
#   'hearing person',
#   'mental health',
#   'health',
#   'remedy',
#   'disease',
#   'Q107613011',
#   'asymmetry',
#   'nonrenewable energy',
#   'external combustion engine',
#   'cold weapon',
#   'draft weapon',
#   'complex number',
#   'imaginary number',
#   'Q3847256',
#   'declination',
#   'anti-rootkit software',
#   'umount',
#   'instantaneous water heater',
# ...
#   'terrorism',
#   'Jewish people',
#   'software',
#   'uniform',
#   'mother',
#   'father',
#   'parent',
#   'parent',
#   'parent',
#   'parent',
#   'nature',
#   'drinking water',
#   'El Niño',
#   'global warming',
#   'mineral',
#   'truth',
#   'fairy',
#   'Romani',
#   'rock',
#   'atmosphere',
#   'Palembang',
#   'literacy',
#   'fiction',
#   'pedophilia',
#   'fellatio',
#   'society',
#   'civilization',
#   'man',
#   'marriage',
#   'racism',
#   'A Coruña',
#   'knowledge',
#   'light',
#   'monotheism',
#   'polytheism',
#   'religion',
#   'religion',
#   'ocean',
#   'reality',
#   'vein',
#   'artery',
#   'depleted uranium',
#   'letter',
#   'Indian National Congress',
#   'Bharatiya Janata Party',
#   'poverty',
#   'revolution',
#   'revolution',
#   'House of Commons',
#   'House of Lords',
#   'mass media',
#   'endocrine system',
#   'acid',
#   'inorganic chemistry',
#   'chemical compound',
#   'backslash',
#   'private IP address',
#   'base',
#   'logarithm',
#   'logarithm',
#   'web server',
#   'Anamorphic widescreen',
#   'chemical element',
#   'organic chemistry',
#   'molecule',
#   'wireless network',
#   'gravity',
#   'metal',
#   'sound',
#   'complex number',
#   'United States House of Representatives',
#   'Huey, Dewey, and Louie',
#   'cancer',
#   'king',
#   'deafness',
#   'mental disorder',
#   'disease',
#   'disease',
#   'health',
#   'Real Madrid Castilla',
#   'symmetry',
#   'renewable energy',
#   'internal combustion engine',
#   'firearm',
#   'firearm',
#   'real number',
#   'real number',
#   'berry',
#   'right ascension',
#   'rootkit',
#   'mount',
#   'storage water heater',
#   'Address Resolution Protocol',
#   'good',
#   'evil',
#   'body of water',
#   '1,000,000,000',
#   'daylight',
#   'daylight',
#   'hyperthyroidism',
#   'hypothyroidism',
#   'Project:Village pump',
#   'mobile phone',
#   'theory',
#   'theory',
#   'public sphere',
#   'falsity',
#   'falsity',
#   'high-rise building',
#   'instinct',
#   'theoretical physics',
#   'experimental physics',
#   'metaphor',
#   'grade retention',
#   'short-term memory',
#   'long-term memory',
#   'explicit memory',
#   'implicit memory',
#   'episodic memory',
#   'semantic memory',
#   'mainstream',
#   'mainstream',
#   'mainstream',
#   'nonmetal',
#   'public domain',
#   'leap year',
#   'Enterprise',
#   'bank',
#   'freedom of speech',
#   'freedom of speech',
#   'consumer',
#   'consumer',
#   'drawbridge',
#   'merlon',
#   'battlement',
#   'white',
#   'black',
#   'official language',
#   'cardinal direction',
#   'cardinal direction',
#   'immutable object',
#   'César Award for Best Actress',
#   'short film',
#   'feature film',
#   'power',
#   'Vertebrata',
#   'weight',
#   'Artiodactyla',
#   'electrical resistance',
#   'Odd-toed ungulate',
#   'Västerås',
#   'normative economics',
#   'positive economics',
#   'positive economics',
#   'list of diplomatic missions of South Korea',
#   'list of diplomatic missions of North Korea',
#   'economic profit',
#   'Caribbean Netherlands',
#   'substratum',
#   'non-fiction literature',
#   'Before Christ',
#   'Before Christ',
#   'Before Christ',
#   'stop codon',
#   'handsfree',
#   'respect',
#   'public library',
#   'applied science',
#   'good',
#   'season premiere',
#   'black box',
#   'Republican Party',
#   'error',
#   'natural law',
#   'natural law',
#   'density',
#   'Democratic Party',
#   'list of diplomatic missions in San Marino',
#   'Wi-Fi',
#   'outer planet',
#   'multilingualism',
#   'pasture',
#   'reusable launch vehicle',
#   'common law',
#   'common law',
#   'anarchy',
#   'net',
#   'addition',
#   'sanction',
#   'RCD Espanyol B',
#   'Candystorm',
#   'idealism',
#   'exponentiation',
#   'homophobia',
#   'applied mathematics',
#   'motility',
#   'limited company',
#   'natural language',
#   'natural language',
#   'latitude',
#   'sign language',
#   'doubt',
#   'belief',
#   'vitamin',
#   "women's studies",
#   'entity',
#   'entity',
#   'metaphysics',
#   'Arabs',
#   'sleep',
#   'inflation',
#   'soil',
#   'vowel',
#   'histone',
#   'midnight',
#   'multicellular organism',
#   'unicellular organism',
#   'longitude',
#   'ion',
#   'daylight saving time',
#   'first language',
#   'pop music',
#   'Trinity',
#   'Trinity',
#   'Trinity',
#   'line',
#   'teacher',
#   'teacher',
#   'teacher',
#   'chromosome',
#   'refrigerator',
#   'strait',
#   'consonant',
#   'autism',
#   'MTV Europe Music Award for Best Female',
#   'MTV Europe Music Award for Best Male',
#   'microscopic scale',
#   '1,000,000',
#   '1,000,000',
#   'cynophobia',
#   'emperor',
#   'Northern Hemisphere',
#   'open source',
#   'open source',
#   'pet',
#   'speciation',
#   'election',
#   '16',
#   'multiplication',
#   'subtraction',
#   'unemployment',
#   'Southern Hemisphere',
#   'ice hockey',
#   'pipe',
#   'greenhouse effect',
#   'Warsaw Pact',
#   'mule',
#   'sentence',
#   'arterial hypertension',
#   'synonym',
#   'Zionism',
#   'boson',
#   'elementary particle',
#   'female organism',
#   'natural selection',
#   'Übermensch',
#   'monopoly',
#   'federation',
#   'Invertebrata',
#   'koban',
#   'server',
#   'male organism',
#   'fermion',
#   'heat',
#   'heat',
#   'fasting',
#   'fear',
#   'entropy',
#   'simulation',
#   'oligotroph',
#   'complete graph',
#   'dead language',
#   'slavophilia',
#   'asset',
#   'organized crime',
#   'military personnel',
#   'military personnel',
#   'birthday',
#   'birthday',
#   'compiler',
#   "football at the 2012 Summer Olympics – men's tournament",
#   'non-binary',
#   'student',
#   'morality',
#   'synthetic language',
#   'list of diplomatic missions in Albania',
#   'schoolchild',
#   'prime number',
#   'tourism',
#   'girlfriend',
#   'military dictatorship',
#   'homozygote',
#   'victory',
#   'variable',
#   'composite number',
#   'divisor',
#   'black market',
#   'proportionality',
#   'nasal consonant',
#   'trill consonant',
#   'daytime',
#   'canon',
#   'pubic hair',
#   'dead-end station',
#   'through station',
#   'underground railway station',
#   'lossless compression',
#   'lossy compression',
#   'non-human blood type',
#   'naturalism',
#   'desktop computer',
#   'mortality rate',
#   'irreligion',
#   'pacifism',
#   'adit',
#   'herbivore',
#   'civic nationalism',
#   'racial segregation',
#   'weak verb',
#   'exothermer Prozess',
#   'financial inclusion',
#   'outsourcing',
#   'daimyo',
#   'negative feedback',
#   'elasticity',
#   'import',
#   'United States Senate',
#   'cyclic compound',
#   'irregular verb',
#   'regular verb',
#   'bureaucracy',
#   'mainstream economics',
#   'online',
#   'online',
#   'ultimate tensile strength',
#   'right-wing',
#   'redshift',
#   'declination',
#   'niece or nephew',
#   'aunt',
#   'uncle',
#   'nonviolence',
#   'first cousin',
#   'electronegativity',
#   'anger',
#   'non-governmental organization',
#   'Christchurch',
#   'First Point of Aries',
#   'allele',
#   'stop word',
#   'supernatural',
#   'lingua franca',
#   'homeopathy',
#   'polymer',
#   'absolute zero',
#   'exonym',
#   'classical physics',
#   'carnivore',
#   'pain',
#   'Winter Olympic Games',
#   'friction',
#   'zenith',
#   'electronic spam',
#   'depolarization',
#   'relativism',
#   'antimatter',
#   'empiricism',
#   'euphemism',
#   'intelligence',
#   'NMOS logic',
#   'arianism',
#   'César Award for Best Supporting Actress',
#   'Japan national futsal team',
#   'text file',
#   'text file',
#   'consumerism',
#   'divorce',
#   'sexism',
#   'sexism',
#   'documentary film',
#   'documentary film',
#   'isthmus',
#   'coast',
#   'uppercase letter',
#   'uppercase letter',
#   'blackwater river',
#   'aorta',
#   'suffix',
#   'fresh water',
#   'diphthong',
#   'ore',
#   'homeostasis',
#   'oligopoly',
#   'loanword',
#   'heliocentrism',
#   'fauna',
#   'phenotype',
#   'risk',
#   'risk',
#   'risk',
#   'full moon',
#   'amount of substance',
#   'hypotenuse',
#   'hypoxia',
#   'genotype',
#   'Christian',
#   'melting',
#   'short',
#   'valence electron',
#   'anion',
#   'freezing',
#   'electrical resistivity',
#   'new moon',
#   'diminutive',
#   'curse',
#   'curse',
#   'just-in-time compilation',
#   'singular',
#   'cathetus',
#   'patronymic',
#   'antihero',
#   'island nation',
#   'gender equality',
#   'gender equality',
#   'gender equality',
#   'gender equality',
#   'gender equality',
#   'minority government',
#   'surface roughness',
#   'snow tire',
#   'Damköhler numbers',
#   'autosomal dominant',
#   'unit',
#   'transmission',
#   'viviparity',
#   'Q120645',
#   'symbiosis',
#   'gas giant',
#   'redundancy',
#   'xylem',
#   'standing wave',
#   'endemism',
#   'landlocked country',
#   'extinction',
#   'solstice',
#   'alternating current',
#   'electrical conductor',
#   'violence',
#   'consecration',
#   'contraction',
#   'universal quantification',
#   "football at the 1996 Summer Olympics – women's tournament",
#   'retail',
#   'muscle contraction',
#   'Gδ set',
#   'New World',
#   'hoof',
#   'dynamics',
#   'totalitarianism',
#   'terrestrial planet',
#   'concurrent computing',
#   'source code',
#   'creationism',
#   'turbine',
#   'neologism',
#   'determinism',
#   'utopia',
#   'text editor',
#   'Oedipus complex',
#   'popular culture',
#   'immigration',
#   'autotroph',
#   'autotroph',
#   'flora',
#   'white hole',
#   'esotericism',
#   'antonym',
#   'sublimation',
#   'natural rubber',
#   'Floor effect',
#   'developed country',
#   'de jure',
#   'dyslexia',
#   'leg',
#   'combustion',
#   'security through obscurity',
#   'polysaccharides',
#   'transliteration',
#   'prefix',
#   'Sai-ji',
#   'Puritanism',
#   'macrosociology',
#   'plurale tantum',
#   'artificial light',
#   'logogram',
#   'logogram',
#   'Golden Globe Award for Best Actor – Television Series Musical or Comedy',
#   '1470 Carla',
#   'closed platform',
#   'unicameralism',
#   'numeracy',
#   'spot card',
#   'encryption',
#   'funicular',
#   'Ex contractu',
#   'anecdotal evidence',
#   'xenophilia',
#   'Outer London',
#   'nadir',
#   'genitive case',
#   'criminal law',
#   'dry season',
#   'great circle',
#   'plural',
#   'proper noun',
#   'essive case',
#   'dioecy',
#   'assimilation',
#   'small circle',
#   'differential calculus',
#   'integral calculus',
#   'monoicous',
#   'monoicous',
#   'foreign language',
#   'Central Powers',
#   'punctuality',
#   'ranged weapon',
#   'muggle',
#   'nothing',
#   'nothing',
#   'aerodyne',
#   'total war',
#   'natural person',
#   'leninism',
#   'juridical person',
#   'good faith',
#   'zero-sum game',
#   'foundation',
#   'creditor',
#   'debtor',
#   'engagement',
#   'virtue',
#   'virtue',
#   'perennial plant',
#   'right triangle',
#   'direct current',
#   'heterotroph',
#   'lockout',
#   'radio receiver',
#   'distance education',
#   'tributary',
#   'Anno Domini',
#   'Summer Olympic Games',
#   'dehiscent fruit',
#   'indehiscent fruit',
#   'negligence',
#   'ballpoint pen',
#   'ballpoint pen',
#   'Cherbourg-Octeville',
#   'hatred',
#   'hatred',
#   'Western world',
#   'usufruct',
#   'heresy',
#   'read-only memory',
#   'urbanization',
#   'deflation',
#   'peer-to-peer',
#   'black body',
#   'privatization',
#   'groundwater',
#   'asymmetric digital subscriber line',
#   'hose',
#   'Arctic Circle',
#   'Tropic of Cancer',
#   'randomness',
#   'continuous-time Markov chain',
#   'stalactite',
#   'son',
#   'mainframe computer',
#   'hyperopia',
#   'militarism',
#   'developing country',
#   'spore',
#   'anticyclone',
#   'Tropic of Capricorn',
#   'naval vessel',
#   'alkylation',
#   'alkylation',
#   'community',
#   'subset',
#   'halal',
#   'clergy',
#   'paraphilia',
#   'insulator',
#   'freeware',
#   'archangel',
#   'reason',
#   'nominative–accusative language',
#   'Order of the Phoenix',
#   'public transport',
#   'traditional Chinese characters',
#   'nationalization',
#   'monism',
#   'international trade',
#   'monomer',
#   'monomer',
#   'argument from poor design',
#   'impedance',
#   'explosion',
#   'widow',
#   'Stalinism',
#   'unitary state',
#   'unitary state',
#   'constructivist epistemology',
#   'causality',
#   'RAID',
#   'ballistic missile',
#   'boycott',
#   'infertility',
#   'polyphony',
#   'Stockholm syndrome',
#   'populism',
#   'populism',
#   'dystopia',
#   'leisure',
#   'gluttony',
#   'hyperbole',
#   'veganism',
#   'scalar quantity',
#   'Death Eater',
#   'abelian group',
#   'stalagmite',
#   'patriarchy',
#   'patriarchy',
#   'patriarchy',
#   'frequency modulation',
#   'extraterrestrial life',
#   'rheopecty',
#   'foreign policy',
#   'necrophilia',
#   'cruise missile',
#   'polymerization',
#   'uyoku dantai',
#   'archaism',
#   'Western Hemisphere',
#   'anti-communism',
#   'vertical',
#   'fuse',
#   'benthos',
#   'empathy',
#   'raster graphics',
#   'sexual reproduction',
#   'mermaid',
#   'exogamy',
#   'Antarctic Circle',
#   'export',
#   'meaning',
#   'facade',
#   'polychromy',
#   'toleration',
#   'toleration',
#   'perfect competition',
#   'persona non grata',
#   'Darwinism',
#   'Darwinism',
#   'feedback',
#   'amplitude modulation',
#   'ferromagnetism',
#   'ferromagnetism',
#   'monogamy',
#   'luminescence',
#   'postposition',
#   'footwear',
#   'hero',
#   'grammatical gender',
#   'henry',
#   'nonprofit organization',
#   'nonprofit organization',
#   'reaction inhibitor',
#   'Shinkansen',
#   'experience',
#   'left-wing',
#   'codon',
#   'inequation',
#   'inequation',
#   'National Society of Film Critics Award for Best Supporting Actor',
#   'geocentric model',
#   'Zee Cine Award for Best Male Debut',
#   'xenophobia',
#   'bleeding',
#   'veduta',
#   'serendipity',
#   'seven deadly sins',
#   'color photography',
#   'sunset',
#   'condensation',
#   'condensation',
#   '!',
#   'magnifying glass',
#   'corporation',
#   'stereotype',
#   'altruism',
#   'grandparent',
#   'grandparent',
#   'grandparent',
#   'noon',
#   'myopia',
#   '2012 Summer Olympics opening ceremony',
#   'exponential function',
#   'spirituality',
#   'spirituality',
#   'algebraic number',
#   'statics',
#   'discrimination',
#   'discrimination',
#   'discrimination',
#   'sadness',
#   'sadness',
#   'sadness',
#   'mixture',
#   'abolitionism',
#   'abolitionism',
#   'Indigenous species',
#   'non-cellular life',
#   'deforestation',
#   'deception',
#   'continuous function',
#   'pathogen',
#   'generalization',
#   'Ampelmännchen',
#   'vector graphic',
#   'patient',
#   'illegitimate child',
#   'modulation',
#   'virtual reality',
#   'laughter',
#   'collaging',
#   'direct democracy',
#   'agglutinative language',
#   'rectifier',
#   'semi-major axis',
#   'individualism',
#   'individualism',
#   'intelligent design',
#   'plasmid',
#   'transcendental number',
#   'digital photography',
#   'digital electronics',
#   'autocracy',
#   'asexual reproduction',
#   'minimalism',
#   'PMOS logic',
#   'organic compound',
#   'Antichrist',
#   'Old World',
#   'variable cost',
#   'analog electronics',
#   'analog signal',
#   'signal',
#   'digital signal',
#   'discrete signal',
#   'continuous signal',
#   'discrete space',
#   'terrestrial television',
#   'rural area',
#   'variance',
#   'Chicago Film Critics Association Award for Best Supporting Actor',
#   'Olam ha-Ba',
#   'Handball-Bundesliga',
#   'phobia',
#   'field-effect transistor',
#   'harmony',
#   'cable television',
#   'minor scale',
#   'touch typing',
#   'anabolism',
#   'text-based user interface',
#   'biocoenosis',
#   'recreation',
#   'bullfighting',
#   'acidosis',
#   'phloem',
#   'great power',
#   'great power',
#   'quantitative analysis',
#   'strategy',
#   'many-valued logic',
#   'excretion',
#   'simplified Chinese characters',
#   'matriarchy',
#   'matriarchy',
#   'identity element',
#   'time domain',
#   'mania',
#   'compressive strength',
#   'Eastern Hemisphere',
#   'minimum wage',
#   'punishment',
#   'autosome',
#   'autosome',
#   'time-lapse photography',
#   'claustrophobia',
#   'haughtiness',
#   'haughtiness',
#   'absorbing element',
#   'scripting language',
#   'rechargeable battery',
#   'emigration',
#   'oxidizing agent',
#   'Dutch East Indies',
#   'constant',
#   'alternative medicine',
#   'fact',
#   'fact',
#   'fact',
#   'hierarchy',
#   'hierarchy',
#   'vulcanization',
#   'envy',
#   'representative democracy',
#   'FLOPS',
#   'superhero',
#   'factorization',
#   'wife',
#   'cosmopolitanism',
#   'cosmopolitanism',
#   'cosmopolitanism',
#   'cosmopolitanism',
#   'software library',
#   "Murphy's law",
#   'bipolar junction transistor',
#   'decentralization',
#   'counterculture',
#   'Complex instruction set computer',
#   'transgender person',
#   'military officer',
#   'heart arrhythmia',
#   'reduced instruction set computing',
#   'risk management',
#   'laminar flow',
#   'laminar flow',
#   'acromegaly',
#   'dissociation',
#   'cold-bloodedness',
#   'cold-bloodedness',
#   'planned economy',
#   'Islamism',
#   'question',
#   'voting',
#   'anaerobic organism',
#   'economic growth',
#   'gametophyte',
#   'inorganic compound',
#   'anticline',
#   'transmitter',
#   'analog-to-digital converter',
#   'altitude',
#   'stator',
#   'stator',
#   'historical linguistics',
#   'ionization',
#   'centerfire cartridge',
#   'hope',
#   'centralisation',
#   'multiculturalism',
#   'multiculturalism',
#   'major scale',
#   'plant secretory tissue',
#   'polar night',
#   'essence',
#   'surface-mount technology',
#   ...]}

# %%
def numRelations(s):
    try:
        entry = db.entityList.find_one({'id':s})
        if entry is not None:
            entry['value']
    except KeyError:
        return 0
    else:
        return 0

# %%
for relation1, relation2 in zip(propertyList['item1'][22986:], propertyList['item2'][22986:]):
    # Get Property
    rel1 = relation1.rsplit('/', 1)[1]
    rel2 = relation2.rsplit('/', 1)[1]
    
    if (rel1[0] != 'P' or rel2[0] != 'P'): continue
    
    r1_dict = get_entity_dict_from_api(rel1)
    r2_dict = get_entity_dict_from_api(rel2)
    
    if r1_dict['type'] != 'item' or r2_dict['type'] != 'item': continue
    
    # Take only a subset of keys
    r1_subset = dict((k, r1_dict[k]) for k in ('id', 'labels'))
    r1_subset['id1'] = r1_subset.pop('id')
    r1_subset['labels1'] = r1_subset.pop('labels')

    r2_subset = dict((k, r2_dict[k]) for k in ('id', 'labels'))
    r2_subset['id2'] = r2_subset.pop('id')
    r2_subset['labels2'] = r2_subset.pop('labels')
    
    r_subset = {**r1_subset, **r2_subset}
    
    # Insert into collection
    db.antonym.insert_one(r_subset)

# %%
len(propertyList['item1'])
# Out:
# 23093

# %%
db.antonym.count_documents({})
# Out:
# 22983

# %%
db.antonym.find_one({})
# Out:
# {'_id': ObjectId('621141b55258e6dc526cbcef'),
#  'id1': 'Q106521687',
#  'labels1': {'pt': {'language': 'pt', 'value': 'antiverso'},
#   'en': {'language': 'en', 'value': 'antiverse'},
#   'ru': {'language': 'ru', 'value': 'антивселенная'},
#   'sv': {'language': 'sv', 'value': 'antiversum'},
#   'kw': {'language': 'kw', 'value': 'gorthbys'},
#   'tt': {'language': 'tt', 'value': 'антигаләм'},
#   'uk': {'language': 'uk', 'value': 'антивсесвіт'},
#   'ja': {'language': 'ja', 'value': '反宇宙'}},
#  'id2': 'Q1',
#  'labels2': {'fr': {'language': 'fr', 'value': 'univers'},
#   'la': {'language': 'la', 'value': 'universum'},
#   'uz': {'language': 'uz', 'value': 'Olam'},
#   'ru': {'language': 'ru', 'value': 'Вселенная'},
#   'pl': {'language': 'pl', 'value': 'Wszechświat'},
#   'nb': {'language': 'nb', 'value': 'universet'},
#   'eo': {'language': 'eo', 'value': 'universo'},
#   'it': {'language': 'it', 'value': 'universo'},
#   'es': {'language': 'es', 'value': 'universo'},
#   'de': {'language': 'de', 'value': 'Universum'},
#   'ca': {'language': 'ca', 'value': 'univers'},
#   'en-gb': {'language': 'en-gb', 'value': 'universe'},
#   'de-ch': {'language': 'de-ch', 'value': 'Universum'},
#   'fi': {'language': 'fi', 'value': 'maailmankaikkeus'},
#   'nn': {'language': 'nn', 'value': 'universet'},
#   'ja': {'language': 'ja', 'value': '宇宙'},
#   'zh-hant': {'language': 'zh-hant', 'value': '宇宙'},
#   'hr': {'language': 'hr', 'value': 'Svemir'},
#   'pt': {'language': 'pt', 'value': 'universo'},
#   'hu': {'language': 'hu', 'value': 'világegyetem'},
#   'nl': {'language': 'nl', 'value': 'Heelal'},
#   'ro': {'language': 'ro', 'value': 'Univers'},
#   'sv': {'language': 'sv', 'value': 'universum'},
#   'gl': {'language': 'gl', 'value': 'universo'},
#   'eu': {'language': 'eu', 'value': 'unibertso'},
#   'mk': {'language': 'mk', 'value': 'вселена'},
#   'da': {'language': 'da', 'value': 'Universet'},
#   'br': {'language': 'br', 'value': 'hollved'},
#   'et': {'language': 'et', 'value': 'universum'},
#   'af': {'language': 'af', 'value': 'heelal'},
#   'cy': {'language': 'cy', 'value': 'bydysawd'},
#   'io': {'language': 'io', 'value': 'Universo'},
#   'ia': {'language': 'ia', 'value': 'universo'},
#   'is': {'language': 'is', 'value': 'Alheimurinn'},
#   'tr': {'language': 'tr', 'value': 'evren'},
#   'cs': {'language': 'cs', 'value': 'vesmír'},
#   'sk': {'language': 'sk', 'value': 'vesmír'},
#   'uk': {'language': 'uk', 'value': 'всесвіт'},
#   'an': {'language': 'an', 'value': 'Universo'},
#   'az': {'language': 'az', 'value': 'kainat'},
#   'ast': {'language': 'ast', 'value': 'universu'},
#   'gn': {'language': 'gn', 'value': 'Arapy'},
#   'bs': {'language': 'bs', 'value': 'svemir'},
#   'sn': {'language': 'sn', 'value': 'Rudunhumwe'},
#   'nv': {'language': 'nv', 'value': 'Yágháhookáán'},
#   'dsb': {'language': 'dsb', 'value': 'Uniwersum'},
#   'hif': {'language': 'hif', 'value': 'Sansaar'},
#   'fo': {'language': 'fo', 'value': 'Alheimurin'},
#   'fy': {'language': 'fy', 'value': 'Hielal'},
#   'ga': {'language': 'ga', 'value': 'An Chruinne'},
#   'hak': {'language': 'hak', 'value': 'Yî-chhiu'},
#   'id': {'language': 'id', 'value': 'alam semesta'},
#   'jv': {'language': 'jv', 'value': 'Alam semesta'},
#   'pam': {'language': 'pam', 'value': 'Sikluban'},
#   'csb': {'language': 'csb', 'value': 'Swiatnica'},
#   'sw': {'language': 'sw', 'value': 'Ulimwengu'},
#   'ht': {'language': 'ht', 'value': 'Linivè'},
#   'ku': {'language': 'ku', 'value': 'Gerdûn'},
#   'lv': {'language': 'lv', 'value': 'Visums'},
#   'lt': {'language': 'lt', 'value': 'visata'},
#   'li': {'language': 'li', 'value': 'Universum'},
#   'lmo': {'language': 'lmo', 'value': 'Ünivers'},
#   'ms': {'language': 'ms', 'value': 'Alam Semesta'},
#   'mwl': {'language': 'mwl', 'value': 'Ouniberso'},
#   'nah': {'language': 'nah', 'value': 'Cemānāhuac'},
#   'nds-nl': {'language': 'nds-nl', 'value': 'Hielal'},
#   'nap': {'language': 'nap', 'value': 'Annevierzo'},
#   'frr': {'language': 'frr', 'value': 'Åål'},
#   'nrm': {'language': 'nrm', 'value': 'Eunivers'},
#   'nov': {'language': 'nov', 'value': 'Universe'},
#   'oc': {'language': 'oc', 'value': 'Univèrs'},
#   'pfl': {'language': 'pfl', 'value': 'Weldall'},
#   'pap': {'language': 'pap', 'value': 'universo'},
#   'nds': {'language': 'nds', 'value': 'Weltruum'},
#   'qu': {'language': 'qu', 'value': "Ch'askancha"},
#   'stq': {'language': 'stq', 'value': 'Al'},
#   'sq': {'language': 'sq', 'value': 'gjithësi'},
#   'scn': {'language': 'scn', 'value': 'universu'},
#   'sl': {'language': 'sl', 'value': 'Vesolje'},
#   'sh': {'language': 'sh', 'value': 'svemir'},
#   'su': {'language': 'su', 'value': 'jagat'},
#   'tl': {'language': 'tl', 'value': 'sansinukob'},
#   'war': {'language': 'war', 'value': 'Sangkalibutan'},
#   'vi': {'language': 'vi', 'value': 'vũ trụ'},
#   'bn': {'language': 'bn', 'value': 'মহাবিশ্ব'},
#   'ar': {'language': 'ar', 'value': 'فضاء كوني'},
#   'arc': {'language': 'arc', 'value': 'ܬܒܝܠ'},
#   'arz': {'language': 'arz', 'value': 'كون'},
#   'be': {'language': 'be', 'value': 'сусвет'},
#   'bg': {'language': 'bg', 'value': 'Вселена'},
#   'ckb': {'language': 'ckb', 'value': 'گەردوون'},
#   'cv': {'language': 'cv', 'value': 'Çут Тĕнче'},
#   'el': {'language': 'el', 'value': 'Σύμπαν'},
#   'fa': {'language': 'fa', 'value': 'گیتی'},
#   'gu': {'language': 'gu', 'value': 'બ્રહ્માંડ'},
#   'he': {'language': 'he', 'value': 'היקום'},
#   'hi': {'language': 'hi', 'value': 'ब्रह्माण्ड'},
#   'hy': {'language': 'hy', 'value': 'տիեզերք'},
#   'ka': {'language': 'ka', 'value': 'სამყარო'},
#   'kk': {'language': 'kk', 'value': 'Әлем'},
#   'kn': {'language': 'kn', 'value': 'ಬ್ರಹ್ಮಾಂಡ'},
#   'ko': {'language': 'ko', 'value': '우주'},
#   'lez': {'language': 'lez', 'value': 'Чилер-цавар'},
#   'ml': {'language': 'ml', 'value': 'പ്രപഞ്ചം'},
#   'mn': {'language': 'mn', 'value': 'Орчлон'},
#   'mr': {'language': 'mr', 'value': 'विश्व'},
#   'my': {'language': 'my', 'value': 'စကြဝဠာ'},
#   'ne': {'language': 'ne', 'value': 'ब्रह्माण्ड'},
#   'pnb': {'language': 'pnb', 'value': 'کائنات'},
#   'rue': {'language': 'rue', 'value': 'Весмір'},
#   'sr': {'language': 'sr', 'value': 'свемир'},
#   'ta': {'language': 'ta', 'value': 'அண்டம்'},
#   'te': {'language': 'te', 'value': 'విశ్వం'},
#   'tg': {'language': 'tg', 'value': 'Коинот'},
#   'th': {'language': 'th', 'value': 'เอกภพ'},
#   'tt': {'language': 'tt', 'value': 'Галәм'},
#   'ur': {'language': 'ur', 'value': 'کائنات'},
#   'xmf': {'language': 'xmf', 'value': 'ოქიანუ'},
#   'yi': {'language': 'yi', 'value': 'אוניווערס'},
#   'zh': {'language': 'zh', 'value': '宇宙'},
#   'en-ca': {'language': 'en-ca', 'value': 'universe'},
#   'pt-br': {'language': 'pt-br', 'value': 'universo'},
#   'yue': {'language': 'yue', 'value': '宇宙'},
#   'zh-cn': {'language': 'zh-cn', 'value': '宇宙'},
#   'zh-hans': {'language': 'zh-hans', 'value': '宇宙'},
#   'zh-sg': {'language': 'zh-sg', 'value': '宇宙'},
#   'zh-hk': {'language': 'zh-hk', 'value': '宇宙'},
#   'zh-tw': {'language': 'zh-tw', 'value': '宇宙'},
#   'zh-mo': {'language': 'zh-mo', 'value': '宇宙'},
#   'si': {'language': 'si', 'value': 'විශ්වය'},
#   'ilo': {'language': 'ilo', 'value': 'law-ang'},
#   'jbo': {'language': 'jbo', 'value': 'la munje'},
#   'vep': {'language': 'vep', 'value': 'Mir'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'сусьвет'},
#   'bar': {'language': 'bar', 'value': 'Wödall'},
#   'pms': {'language': 'pms', 'value': 'Univers'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'Свемир'},
#   'sr-el': {'language': 'sr-el', 'value': 'Svemir'},
#   'sco': {'language': 'sco', 'value': 'universe'},
#   'or': {'language': 'or', 'value': 'ବ୍ରହ୍ମାଣ୍ଡ'},
#   'ba': {'language': 'ba', 'value': 'Ғаләм'},
#   'sgs': {'language': 'sgs', 'value': 'Vėsata'},
#   'nan': {'language': 'nan', 'value': 'Ú-tiū'},
#   'ce': {'language': 'ce', 'value': 'Ӏалам'},
#   'lzh': {'language': 'lzh', 'value': '宇宙'},
#   'so': {'language': 'so', 'value': 'Koon'},
#   'krc': {'language': 'krc', 'value': 'Болум'},
#   'bxr': {'language': 'bxr', 'value': 'Оршолон'},
#   'lb': {'language': 'lb', 'value': 'Universum'},
#   'lzz': {'language': 'lzz', 'value': 'Universi'},
#   'vec': {'language': 'vec', 'value': 'universo'},
#   'cdo': {'language': 'cdo', 'value': 'Ṳ̄-dêu'},
#   'gd': {'language': 'gd', 'value': 'Domhan'},
#   'sd': {'language': 'sd', 'value': 'ڪائنات'},
#   'xh': {'language': 'xh', 'value': 'Ihlabathi'},
#   'gsw': {'language': 'gsw', 'value': 'Universum'},
#   'pa': {'language': 'pa', 'value': 'ਬ੍ਰਹਿਮੰਡ'},
#   'bho': {'language': 'bho', 'value': 'ब्रह्मांड'},
#   'lij': {'language': 'lij', 'value': 'Universo'},
#   'chr': {'language': 'chr', 'value': 'ᎦᎸᎶᎯ ᎦᎸᎾᏗ'},
#   'vo': {'language': 'vo', 'value': 'leval'},
#   'wuu': {'language': 'wuu', 'value': '宇宙'},
#   'en': {'language': 'en', 'value': 'universe'},
#   'jam': {'language': 'jam', 'value': 'Yunivoers'},
#   'ky': {'language': 'ky', 'value': 'Аалам'},
#   'as': {'language': 'as', 'value': 'বিশ্বব্ৰহ্মাণ্ড'},
#   'yo': {'language': 'yo', 'value': 'àgbàláayé'},
#   'tt-cyrl': {'language': 'tt-cyrl', 'value': 'Галәм'},
#   'tt-latn': {'language': 'tt-latn', 'value': 'Ğäläm'},
#   'ts': {'language': 'ts', 'value': 'Matilo'},
#   'wa': {'language': 'wa', 'value': 'Univiers'},
#   'am': {'language': 'am', 'value': 'ጠፈር'},
#   'rmy': {'language': 'rmy', 'value': 'Jegeya'},
#   'lfn': {'language': 'lfn', 'value': 'Universo'},
#   'inh': {'language': 'inh', 'value': 'Айлам'},
#   'ny': {'language': 'ny', 'value': 'Chilengedwe'},
#   'diq': {'language': 'diq', 'value': 'Kainat'},
#   'udm': {'language': 'udm', 'value': 'Югыт дунне'},
#   'de-at': {'language': 'de-at', 'value': 'Universum'},
#   'hyw': {'language': 'hyw', 'value': 'Տիեզերք'},
#   'zh-my': {'language': 'zh-my', 'value': '宇宙'},
#   'ext': {'language': 'ext', 'value': 'universu'},
#   'lo': {'language': 'lo', 'value': 'ເອກະພົບ'},
#   'gcr': {'language': 'gcr', 'value': 'Linivèr'},
#   'fj': {'language': 'fj', 'value': 'Vuravura taucoko'},
#   'se': {'language': 'se', 'value': 'máilmmiávus'},
#   'smn': {'language': 'smn', 'value': 'maailmubâlâšvuotâ'},
#   'sms': {'language': 'sms', 'value': 'maaiʹlmpukkvuõtt'},
#   'ak': {'language': 'ak', 'value': 'Amansan'},
#   'sat': {'language': 'sat', 'value': 'ᱚᱣᱟᱝ'},
#   'kw': {'language': 'kw', 'value': 'ollvys'},
#   'ie': {'language': 'ie', 'value': 'Universe'},
#   'lld': {'language': 'lld', 'value': 'Univers'},
#   'kab': {'language': 'kab', 'value': 'Ameɣrad'},
#   'mt': {'language': 'mt', 'value': 'univers'},
#   'ary': {'language': 'ary', 'value': 'كون'},
#   'ab': {'language': 'ab', 'value': 'акосмос'},
#   'szl': {'language': 'szl', 'value': 'Wszechświat'},
#   'zu': {'language': 'zu', 'value': 'I-Yunivesi'},
#   'bcl': {'language': 'bcl', 'value': 'Uniberso'},
#   'ceb': {'language': 'ceb', 'value': 'Uniberso'},
#   'ms-arab': {'language': 'ms-arab', 'value': 'عالم سمستا'},
#   'crh': {'language': 'crh', 'value': 'kâinat'},
#   'dag': {'language': 'dag', 'value': 'Dunia'},
#   'ps': {'language': 'ps', 'value': 'کاينات'},
#   'tw': {'language': 'tw', 'value': 'Amansan'},
#   'nqo': {'language': 'nqo', 'value': 'ߖߊ߯ߓߊ'}},
#  'value': 99}

# %%
i = 0
for anton in db.antonym.find({}):
    print(i)
    i += 1
    q_id1 = anton['id1']
    q_id2 = anton['id2']
    entity1 = db.entityList.find_one({'id':q_id1})
    entity2 = db.entityList.find_one({'id':q_id2})
    db.antonym.update_one(
        {'id1':q_id1, 'id2':q_id2},
        {'$set': {'value': entity1['value'] + entity2['value']}}
    )
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [103], in <module>
#       6 q_id2 = anton['id2']
#       7 entity1 = db.entityList.find_one({'id':q_id1})
# ----> 8 entity2 = db.entityList.find_one({'id':q_id2})
#       9 db.antonym.update_one(
#      10     {'id1':q_id1, 'id2':q_id2},
#      11     {'$set': {'value': entity1['value'] + entity2['value']}}
#      12 )
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/collection.py:1114, in Collection.find_one(self, filter, *args, **kwargs)
#    1111     filter = {"_id": filter}
#    1113 cursor = self.find(filter, *args, **kwargs)
# -> 1114 for result in cursor.limit(-1):
#    1115     return result
#    1116 return None
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/cursor.py:1159, in Cursor.next(self)
#    1157 if self.__empty:
#    1158     raise StopIteration
# -> 1159 if len(self.__data) or self._refresh():
#    1160     return self.__data.popleft()
#    1161 else:
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/cursor.py:1080, in Cursor._refresh(self)
#    1061         raise InvalidOperation(
#    1062             "Passing a 'hint' is required when using the min/max query"
#    1063             " option to ensure the query utilizes the correct index")
#    1064     q = self._query_class(self.__query_flags,
#    1065                           self.__collection.database.name,
#    1066                           self.__collection.name,
#    (...)
#    1078                           self.__allow_disk_use,
#    1079                           self.__exhaust)
# -> 1080     self.__send_message(q)
#    1081 elif self.__id:  # Get More
#    1082     if self.__limit:
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/cursor.py:971, in Cursor.__send_message(self, operation)
#     967     raise InvalidOperation(
#     968         "exhaust cursors do not support auto encryption")
#     970 try:
# --> 971     response = client._run_operation(
#     972         operation, self._unpack_response, address=self.__address)
#     973 except OperationFailure as exc:
#     974     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#     975         # Don't send killCursors because the cursor is already closed.
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/mongo_client.py:1215, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1210 def _cmd(session, server, sock_info, secondary_ok):
#    1211     return server.run_operation(
#    1212         sock_info, operation, secondary_ok, self._event_listeners,
#    1213         unpack_res)
# -> 1215 return self._retryable_read(
#    1216     _cmd, operation.read_preference, operation.session,
#    1217     address=address, retryable=isinstance(operation, message._Query))
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/mongo_client.py:1313, in MongoClient._retryable_read(self, func, read_pref, session, address, retryable)
#    1309         if retrying and not retryable:
#    1310             # A retry is not possible because this server does
#    1311             # not support retryable reads, raise the last error.
#    1312             raise last_error
# -> 1313         return func(session, server, sock_info, secondary_ok)
#    1314 except ServerSelectionTimeoutError:
#    1315     if retrying:
#    1316         # The application may think the write was never attempted
#    1317         # if we raise ServerSelectionTimeoutError on the retry
#    1318         # attempt. Raise the original exception instead.
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/mongo_client.py:1211, in MongoClient._run_operation.<locals>._cmd(session, server, sock_info, secondary_ok)
#    1210 def _cmd(session, server, sock_info, secondary_ok):
# -> 1211     return server.run_operation(
#    1212         sock_info, operation, secondary_ok, self._event_listeners,
#    1213         unpack_res)
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/server.py:113, in Server.run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     111 else:
#     112     sock_info.send_message(data, max_doc_size)
# --> 113     reply = sock_info.receive_message(request_id)
#     115 # Unpack and check for command errors.
#     116 if use_cmd:
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/pool.py:762, in SocketInfo.receive_message(self, request_id)
#     760     return receive_message(self, request_id, self.max_message_size)
#     761 except BaseException as error:
# --> 762     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/pool.py:760, in SocketInfo.receive_message(self, request_id)
#     755 """Receive a raw BSON message or raise ConnectionFailure.
#     756
#     757 If any exception is raised, the socket is closed.
#     758 """
#     759 try:
# --> 760     return receive_message(self, request_id, self.max_message_size)
#     761 except BaseException as error:
#     762     self._raise_connection_failure(error)
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/network.py:197, in receive_message(sock_info, request_id, max_message_size)
#     194     deadline = None
#     195 # Ignore the response's request id.
#     196 length, _, response_to, op_code = _UNPACK_HEADER(
# --> 197     _receive_data_on_socket(sock_info, 16, deadline))
#     198 # No request_id for exhaust cursor "getMore".
#     199 if request_id is not None:
#
# File ~/anaconda3/envs/master/lib/python3.8/site-packages/pymongo/network.py:262, in _receive_data_on_socket(sock_info, length, deadline)
#     260 try:
#     261     wait_for_read(sock_info, deadline)
# --> 262     chunk_length = sock_info.sock.recv_into(mv[bytes_read:])
#     263 except (IOError, OSError) as exc:
#     264     if _errno_from_exception(exc) == errno.EINTR:
#
# KeyboardInterrupt:

# %% [markdown]
# #### Prepare mBERT

# %%
import torch
from transformers import BertTokenizer, BertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# %%
tokenizer.tokenize('bélier')
# Out:
# ['bé', '##lier']

# %%
s = 'bélier'

# %% [markdown]
# #### Preprocessing

# %%
def isLatin(s):
    try:
        s.encode('latin-1')
    except UnicodeEncodeError:
        return False
    else:
        return True

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except AttributeError:
        return False
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
def all_same(items):
    return all(x == items[0] for x in items)

# %% [markdown]
# #### Tokenize and Check

# %%
# Parameters
# Get all entities for maxNumRelations
maxNumRelations = 5
query_languages = ('en','es','fr','de')

# %%
# Single-Token
# Language Agnostic labels (same label across languages)
cand = []
candNon = []

for document in db.antonym.find({}):
    if all(k in document['labels1'] for k in query_languages) and all(k in document['labels2'] for k in query_languages):
        # Test if labels in all languages are the same
        labels1 = [document['labels1'][k]['value'] for k in query_languages]
        labels2 = [document['labels2'][k]['value'] for k in query_languages]
        if not all_same(labels1) or not all_same(labels2): continue
        
        # Tokenize the universal label
        wordToken1 = tokenizer.tokenize(document['labels1']['en']['value'])
        wordToken2 = tokenizer.tokenize(document['labels2']['en']['value'])
        if (len(wordToken1) == 1 and len(wordToken2) == 1):
            if document['labels1']['en']['value'].isalpha() and isLatin(document['labels1']['en']['value']) and document['labels2']['en']['value'].isalpha() and isLatin(document['labels2']['en']['value']):
                j = {'id1': document['id1']}
                for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
                j['id2'] = document['id2']
                for k in query_languages: j[k + '2'] = document['labels2'][k]['value']

                cand.append(j)
            else:
                j = {'id1': document['id1']}
                for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
                j['id2'] = document['id2']
                for k in query_languages: j[k + '2'] = document['labels2'][k]['value']

                candNon.append(j)

# %%
len(cand)
# Out:
# 42

# %%
len(candNon)
# Out:
# 12

# %%
# Single-Token
# English labels but labels exist in all languages
cand = []
candNon = []

for document in db.antonym.find({}):
    if all(k in document['labels1'] for k in query_languages) and all(k in document['labels2'] for k in query_languages):
        
        # Tokenize label
        wordToken1 = tokenizer.tokenize(document['labels1']['en']['value'])
        wordToken2 = tokenizer.tokenize(document['labels2']['en']['value'])
        if (len(wordToken1) == 1 and len(wordToken2) == 1):
            if document['labels1']['en']['value'].isalpha() and isLatin(document['labels1']['en']['value']) and document['labels2']['en']['value'].isalpha() and isLatin(document['labels2']['en']['value']):
                j = {'id1': document['id1']}
                j['en1'] = document['labels1']['en']['value']
                j['id2'] = document['id2']
                j['en2'] = document['labels2']['en']['value']

                cand.append(j)
            else:
                j = {'id1': document['id1']}
                j['en1'] = document['labels1']['en']['value']
                j['id2'] = document['id2']
                j['en2'] = document['labels2']['en']['value']

                candNon.append(j)

# %%
len(cand)
# Out:
# 107

# %%
cand
# Out:
# [{'id1': 'Q527', 'en1': 'sky', 'id2': 'Q2', 'en2': 'Earth'},
#  {'id1': 'Q4', 'en1': 'death', 'id2': 'Q3', 'en2': 'life'},
#  {'id1': 'Q3', 'en1': 'life', 'id2': 'Q4', 'en2': 'death'},
#  {'id1': 'Q14819852', 'en1': 'birth', 'id2': 'Q4', 'en2': 'death'},
#  {'id1': 'Q454', 'en1': 'peace', 'id2': 'Q198', 'en2': 'war'},
#  {'id1': 'Q204', 'en1': 'zero', 'id2': 'Q204', 'en2': 'zero'},
#  {'id1': 'Q192630', 'en1': 'past', 'id2': 'Q344', 'en2': 'future'},
#  {'id1': 'Q198', 'en1': 'war', 'id2': 'Q454', 'en2': 'peace'},
#  {'id1': 'Q8441', 'en1': 'man', 'id2': 'Q467', 'en2': 'woman'},
#  {'id1': 'Q2', 'en1': 'Earth', 'id2': 'Q527', 'en2': 'sky'},
#  {'id1': 'Q667', 'en1': 'south', 'id2': 'Q659', 'en2': 'north'},
#  {'id1': 'Q679', 'en1': 'west', 'id2': 'Q659', 'en2': 'north'},
#  {'id1': 'Q684', 'en1': 'east', 'id2': 'Q659', 'en2': 'north'},
#  {'id1': 'Q659', 'en1': 'north', 'id2': 'Q667', 'en2': 'south'},
#  {'id1': 'Q679', 'en1': 'west', 'id2': 'Q667', 'en2': 'south'},
#  {'id1': 'Q684', 'en1': 'east', 'id2': 'Q667', 'en2': 'south'},
#  {'id1': 'Q667', 'en1': 'south', 'id2': 'Q679', 'en2': 'west'},
#  {'id1': 'Q684', 'en1': 'east', 'id2': 'Q679', 'en2': 'west'},
#  {'id1': 'Q5410500', 'en1': 'faith', 'id2': 'Q34302', 'en2': 'doubt'},
#  {'id1': 'Q154242', 'en1': 'nothing', 'id2': 'Q35120', 'en2': 'entity'},
#  {'id1': 'Q8063', 'en1': 'rock', 'id2': 'Q36133', 'en2': 'soil'},
#  {'id1': 'Q48282', 'en1': 'student', 'id2': 'Q37226', 'en2': 'teacher'},
#  {'id1': 'Q528166', 'en1': 'client', 'id2': 'Q44127', 'en2': 'server'},
#  {'id1': 'Q42213', 'en1': 'work', 'id2': 'Q44432', 'en2': 'heat'},
#  {'id1': 'Q37226', 'en1': 'teacher', 'id2': 'Q48282', 'en2': 'student'},
#  {'id1': 'Q11499267', 'en1': 'defeat', 'id2': 'Q50000', 'en2': 'victory'},
#  {'id1': 'Q188248', 'en1': 'constant', 'id2': 'Q50701', 'en2': 'variable'},
#  {'id1': 'Q182722', 'en1': 'export', 'id2': 'Q62955', 'en2': 'import'},
#  {'id1': 'Q8445', 'en1': 'marriage', 'id2': 'Q93190', 'en2': 'divorce'},
#  {'id1': 'Q131449', 'en1': 'flora', 'id2': 'Q104021', 'en2': 'fauna'},
#  {'id1': 'Q3851114', 'en1': 'opportunity', 'id2': 'Q104493', 'en2': 'risk'},
#  {'id1': 'Q10566551', 'en1': 'safety', 'id2': 'Q104493', 'en2': 'risk'},
#  {'id1': 'Q146786', 'en1': 'plural', 'id2': 'Q110786', 'en2': 'singular'},
#  {'id1': 'Q104021', 'en1': 'fauna', 'id2': 'Q131449', 'en2': 'flora'},
#  {'id1': 'Q110786', 'en1': 'singular', 'id2': 'Q146786', 'en2': 'plural'},
#  {'id1': 'Q35120', 'en1': 'entity', 'id2': 'Q154242', 'en2': 'nothing'},
#  {'id1': 'Q2165236', 'en1': 'everything', 'id2': 'Q154242', 'en2': 'nothing'},
#  {'id1': 'Q15911314',
#   'en1': 'association',
#   'id2': 'Q157031',
#   'en2': 'foundation'},
#  {'id1': 'Q308194', 'en1': 'daughter', 'id2': 'Q177232', 'en2': 'son'},
#  {'id1': 'Q20749305',
#   'en1': 'horizontal',
#   'id2': 'Q182167',
#   'en2': 'vertical'},
#  {'id1': 'Q62955', 'en1': 'import', 'id2': 'Q182722', 'en2': 'export'},
#  {'id1': 'Q728646',
#   'en1': 'partnership',
#   'id2': 'Q167037',
#   'en2': 'corporation'},
#  {'id1': 'Q11306265', 'en1': 'noise', 'id2': 'Q174984', 'en2': 'signal'},
#  {'id1': 'Q618779', 'en1': 'award', 'id2': 'Q186361', 'en2': 'punishment'},
#  {'id1': 'Q50701', 'en1': 'variable', 'id2': 'Q188248', 'en2': 'constant'},
#  {'id1': 'Q3962655', 'en1': 'opinion', 'id2': 'Q188572', 'en2': 'fact'},
#  {'id1': 'Q107510247', 'en1': 'lie', 'id2': 'Q188572', 'en2': 'fact'},
#  {'id1': 'Q212878', 'en1': 'husband', 'id2': 'Q188830', 'en2': 'wife'},
#  {'id1': 'Q1920566', 'en1': 'answer', 'id2': 'Q189756', 'en2': 'question'},
#  {'id1': 'Q930412', 'en1': 'depth', 'id2': 'Q190200', 'en2': 'altitude'},
#  {'id1': 'Q1385033', 'en1': 'exterior', 'id2': 'Q2998430', 'en2': 'interior'},
#  {'id1': 'Q703534', 'en1': 'employee', 'id2': 'Q3053337', 'en2': 'employer'},
#  {'id1': 'Q3080526', 'en1': 'bottom', 'id2': 'Q3079896', 'en2': 'top'},
#  {'id1': 'Q3079896', 'en1': 'top', 'id2': 'Q3080526', 'en2': 'bottom'},
#  {'id1': 'Q1367508', 'en1': 'ordinary', 'id2': 'Q3120038', 'en2': 'proper'},
#  {'id1': 'Q1855388', 'en1': 'Caro', 'id2': 'Q3660491', 'en2': 'Caro'},
#  {'id1': 'Q104493', 'en1': 'risk', 'id2': 'Q3851114', 'en2': 'opportunity'},
#  {'id1': 'Q188572', 'en1': 'fact', 'id2': 'Q3962655', 'en2': 'opinion'},
#  {'id1': 'Q7521081', 'en1': 'Jean', 'id2': 'Q4160311', 'en2': 'Jean'},
#  {'id1': 'Q542869', 'en1': 'supply', 'id2': 'Q4402708', 'en2': 'demand'},
#  {'id1': 'Q15051339', 'en1': 'opening', 'id2': 'Q5135520', 'en2': 'closure'},
#  {'id1': 'Q34302', 'en1': 'doubt', 'id2': 'Q5410500', 'en2': 'faith'},
#  {'id1': 'Q16751793', 'en1': 'true', 'id2': 'Q5432619', 'en2': 'false'},
#  {'id1': 'Q2381698',
#   'en1': 'southwest',
#   'id2': 'Q5491373',
#   'en2': 'northwest'},
#  {'id1': 'Q6452640',
#   'en1': 'southeast',
#   'id2': 'Q5491373',
#   'en2': 'northwest'},
#  {'id1': 'Q6497686',
#   'en1': 'northeast',
#   'id2': 'Q5491373',
#   'en2': 'northwest'},
#  {'id1': 'Q2381698',
#   'en1': 'southwest',
#   'id2': 'Q6452640',
#   'en2': 'southeast'},
#  {'id1': 'Q5491373',
#   'en1': 'northwest',
#   'id2': 'Q6452640',
#   'en2': 'southeast'},
#  {'id1': 'Q6497686',
#   'en1': 'northeast',
#   'id2': 'Q6452640',
#   'en2': 'southeast'},
#  {'id1': 'Q2381698',
#   'en1': 'southwest',
#   'id2': 'Q6497686',
#   'en2': 'northeast'},
#  {'id1': 'Q5491373',
#   'en1': 'northwest',
#   'id2': 'Q6497686',
#   'en2': 'northeast'},
#  {'id1': 'Q6452640',
#   'en1': 'southeast',
#   'id2': 'Q6497686',
#   'en2': 'northeast'},
#  {'id1': 'Q6581097', 'en1': 'male', 'id2': 'Q6581072', 'en2': 'female'},
#  {'id1': 'Q6581072', 'en1': 'female', 'id2': 'Q6581097', 'en2': 'male'},
#  {'id1': 'Q2542618', 'en1': 'sharp', 'id2': 'Q7001368', 'en2': 'flat'},
#  {'id1': 'Q2438057', 'en1': 'Jeanne', 'id2': 'Q7521081', 'en2': 'Jean'},
#  {'id1': 'Q4160311', 'en1': 'Jean', 'id2': 'Q7521081', 'en2': 'Jean'},
#  {'id1': 'Q1121708', 'en1': 'failure', 'id2': 'Q7632586', 'en2': 'success'},
#  {'id1': 'Q47496130',
#   'en1': 'reduction',
#   'id2': 'Q9073584',
#   'en2': 'increase'},
#  {'id1': 'Q9238344',
#   'en1': 'grandfather',
#   'id2': 'Q9235758',
#   'en2': 'grandmother'},
#  {'id1': 'Q11921506',
#   'en1': 'grandson',
#   'id2': 'Q9235758',
#   'en2': 'grandmother'},
#  {'id1': 'Q9235758',
#   'en1': 'grandmother',
#   'id2': 'Q9238344',
#   'en2': 'grandfather'},
#  {'id1': 'Q11921506',
#   'en1': 'grandson',
#   'id2': 'Q9238344',
#   'en2': 'grandfather'},
#  {'id1': 'Q10585806', 'en1': 'minimum', 'id2': 'Q10578722', 'en2': 'maximum'},
#  {'id1': 'Q10578722', 'en1': 'maximum', 'id2': 'Q10585806', 'en2': 'minimum'},
#  {'id1': 'Q595094', 'en1': 'sister', 'id2': 'Q10861465', 'en2': 'brother'},
#  {'id1': 'Q254474',
#   'en1': 'identity',
#   'id2': 'Q10862449',
#   'en2': 'difference'},
#  {'id1': 'Q174984', 'en1': 'signal', 'id2': 'Q11306265', 'en2': 'noise'},
#  {'id1': 'Q17781833',
#   'en1': 'destruction',
#   'id2': 'Q11398090',
#   'en2': 'creation'},
#  {'id1': 'Q50000', 'en1': 'victory', 'id2': 'Q11499267', 'en2': 'defeat'},
#  {'id1': 'Q30504649', 'en1': 'top', 'id2': 'Q11812678', 'en2': 'bottom'},
#  {'id1': 'Q9238344',
#   'en1': 'grandfather',
#   'id2': 'Q11921506',
#   'en2': 'grandson'},
#  {'id1': 'Q18220903', 'en1': 'Jan', 'id2': 'Q12173670', 'en2': 'Jan'},
#  {'id1': 'Q29017578', 'en1': 'predator', 'id2': 'Q12304749', 'en2': 'prey'},
#  {'id1': 'Q529711', 'en1': 'beginning', 'id2': 'Q12769393', 'en2': 'end'},
#  {'id1': 'Q58795659', 'en1': 'major', 'id2': 'Q12827391', 'en2': 'minor'},
#  {'id1': 'Q14565199', 'en1': 'right', 'id2': 'Q13196750', 'en2': 'left'},
#  {'id1': 'Q15332375', 'en1': 'up', 'id2': 'Q13196750', 'en2': 'left'},
#  {'id1': 'Q15332388', 'en1': 'down', 'id2': 'Q13196750', 'en2': 'left'},
#  {'id1': 'Q22855', 'en1': 'consumer', 'id2': 'Q13420330', 'en2': 'provider'},
#  {'id1': 'Q5135520', 'en1': 'closure', 'id2': 'Q15051339', 'en2': 'opening'},
#  {'id1': 'Q13196750', 'en1': 'left', 'id2': 'Q14565199', 'en2': 'right'},
#  {'id1': 'Q15332375', 'en1': 'up', 'id2': 'Q14565199', 'en2': 'right'},
#  {'id1': 'Q15332388', 'en1': 'down', 'id2': 'Q14565199', 'en2': 'right'},
#  {'id1': 'Q4', 'en1': 'death', 'id2': 'Q14819852', 'en2': 'birth'},
#  {'id1': 'Q13196750', 'en1': 'left', 'id2': 'Q15332375', 'en2': 'up'},
#  {'id1': 'Q14565199', 'en1': 'right', 'id2': 'Q15332375', 'en2': 'up'},
#  {'id1': 'Q15332388', 'en1': 'down', 'id2': 'Q15332375', 'en2': 'up'},
#  {'id1': 'Q13196750', 'en1': 'left', 'id2': 'Q15332388', 'en2': 'down'},
#  {'id1': 'Q14565199', 'en1': 'right', 'id2': 'Q15332388', 'en2': 'down'},
#  {'id1': 'Q15332375', 'en1': 'up', 'id2': 'Q15332388', 'en2': 'down'},
#  {'id1': 'Q157031',
#   'en1': 'foundation',
#   'id2': 'Q15911314',
#   'en2': 'association'},
#  {'id1': 'Q23774368', 'en1': 'George', 'id2': 'Q15921732', 'en2': 'George'},
#  {'id1': 'Q12097', 'en1': 'king', 'id2': 'Q16511993', 'en2': 'queen'},
#  {'id1': 'Q18219684', 'en1': 'Joan', 'id2': 'Q16652258', 'en2': 'Joan'},
#  {'id1': 'Q5432619', 'en1': 'false', 'id2': 'Q16751793', 'en2': 'true'},
#  {'id1': 'Q11398090',
#   'en1': 'creation',
#   'id2': 'Q17781833',
#   'en2': 'destruction'},
#  {'id1': 'Q1370330', 'en1': 'Augusta', 'id2': 'Q18010311', 'en2': 'Auguste'},
#  {'id1': 'Q28053272', 'en1': 'Auguste', 'id2': 'Q18010311', 'en2': 'Auguste'},
#  {'id1': 'Q602977', 'en1': 'Simone', 'id2': 'Q18067255', 'en2': 'Simone'},
#  {'id1': 'Q289891', 'en1': 'enemy', 'id2': 'Q17297777', 'en2': 'friend'},
#  {'id1': 'Q18177321', 'en1': 'Andrea', 'id2': 'Q18177306', 'en2': 'Andrea'},
#  {'id1': 'Q18177306', 'en1': 'Andrea', 'id2': 'Q18177321', 'en2': 'Andrea'},
#  {'id1': 'Q12173670', 'en1': 'Jan', 'id2': 'Q18220903', 'en2': 'Jan'},
#  {'id1': 'Q18325152',
#   'en1': 'Laurence',
#   'id2': 'Q18325151',
#   'en2': 'Laurence'},
#  {'id1': 'Q18325151',
#   'en1': 'Laurence',
#   'id2': 'Q18325152',
#   'en2': 'Laurence'},
#  {'id1': 'Q18620539', 'en1': 'Michele', 'id2': 'Q18620536', 'en2': 'Michele'},
#  {'id1': 'Q18620536', 'en1': 'Michele', 'id2': 'Q18620539', 'en2': 'Michele'},
#  {'id1': 'Q23009459',
#   'en1': 'connection',
#   'id2': 'Q18511800',
#   'en2': 'separation'},
#  {'id1': 'Q96654670', 'en1': 'Uwe', 'id2': 'Q18515951', 'en2': 'Uwe'},
#  {'id1': 'Q104771451', 'en1': 'Michal', 'id2': 'Q18563993', 'en2': 'Michal'},
#  {'id1': 'Q18686588', 'en1': 'Marion', 'id2': 'Q18689525', 'en2': 'Marion'},
#  {'id1': 'Q18689525', 'en1': 'Marion', 'id2': 'Q18686588', 'en2': 'Marion'},
#  {'id1': 'Q30013662', 'en1': 'last', 'id2': 'Q19269277', 'en2': 'first'},
#  {'id1': 'Q182167',
#   'en1': 'vertical',
#   'id2': 'Q20749305',
#   'en2': 'horizontal'},
#  {'id1': 'Q20813195', 'en1': 'Santos', 'id2': 'Q20813183', 'en2': 'Santos'},
#  {'id1': 'Q20813204', 'en1': 'Santos', 'id2': 'Q20813183', 'en2': 'Santos'},
#  {'id1': 'Q20813183', 'en1': 'Santos', 'id2': 'Q20813195', 'en2': 'Santos'},
#  {'id1': 'Q20813204', 'en1': 'Santos', 'id2': 'Q20813195', 'en2': 'Santos'},
#  {'id1': 'Q20813183', 'en1': 'Santos', 'id2': 'Q20813204', 'en2': 'Santos'},
#  {'id1': 'Q20813195', 'en1': 'Santos', 'id2': 'Q20813204', 'en2': 'Santos'},
#  {'id1': 'Q621184', 'en1': 'problem', 'id2': 'Q21075690', 'en2': 'solution'},
#  {'id1': 'Q481609', 'en1': 'damage', 'id2': 'Q21255975', 'en2': 'improvement'},
#  {'id1': 'Q15921732', 'en1': 'George', 'id2': 'Q23774368', 'en2': 'George'},
#  {'id1': 'Q1543615', 'en1': 'gratis', 'id2': 'Q24202480', 'en2': 'paid'},
#  {'id1': 'Q18511800',
#   'en1': 'separation',
#   'id2': 'Q23009459',
#   'en2': 'connection'},
#  {'id1': 'Q24759450', 'en1': 'leave', 'id2': 'Q24759380', 'en2': 'remain'},
#  {'id1': 'Q24759380', 'en1': 'remain', 'id2': 'Q24759450', 'en2': 'leave'},
#  {'id1': 'Q18010311', 'en1': 'Auguste', 'id2': 'Q28053272', 'en2': 'Auguste'},
#  {'id1': 'Q270952', 'en1': 'cold', 'id2': 'Q28128222', 'en2': 'hot'},
#  {'id1': 'Q28962312', 'en1': 'often', 'id2': 'Q28962310', 'en2': 'rarely'},
#  {'id1': 'Q91013007', 'en1': 'mainly', 'id2': 'Q28962310', 'en2': 'rarely'},
#  {'id1': 'Q28962310', 'en1': 'rarely', 'id2': 'Q28962312', 'en2': 'often'},
#  {'id1': 'Q12304749', 'en1': 'prey', 'id2': 'Q29017578', 'en2': 'predator'},
#  {'id1': 'Q29043257', 'en1': 'José', 'id2': 'Q29043256', 'en2': 'José'},
#  {'id1': 'Q29043256', 'en1': 'José', 'id2': 'Q29043257', 'en2': 'José'},
#  {'id1': 'Q19269277', 'en1': 'first', 'id2': 'Q30013662', 'en2': 'last'},
#  {'id1': 'Q7560', 'en1': 'mother', 'id2': 'Q29514218', 'en2': 'child'},
#  {'id1': 'Q7565', 'en1': 'father', 'id2': 'Q29514218', 'en2': 'child'},
#  {'id1': 'Q7566', 'en1': 'parent', 'id2': 'Q29514218', 'en2': 'child'},
#  {'id1': 'Q11812678', 'en1': 'bottom', 'id2': 'Q30504649', 'en2': 'top'},
#  {'id1': 'Q9073584',
#   'en1': 'increase',
#   'id2': 'Q47496130',
#   'en2': 'reduction'},
#  {'id1': 'Q1300961',
#   'en1': 'Augustine',
#   'id2': 'Q54617672',
#   'en2': 'Augustine'},
#  {'id1': 'Q12827391', 'en1': 'minor', 'id2': 'Q58795659', 'en2': 'major'},
#  {'id1': 'Q28962310', 'en1': 'rarely', 'id2': 'Q91013007', 'en2': 'mainly'},
#  {'id1': 'Q18563993', 'en1': 'Michal', 'id2': 'Q104771451', 'en2': 'Michal'},
#  {'id1': 'Q108657270', 'en1': 'Minor', 'id2': 'Q106902304', 'en2': 'Maior'}]

# %%
# Single-Token
# All language labels
cand = []
candNon = []

for document in db.antonym.find({}):
    if all(k in document['labels1'] for k in query_languages) and all(k in document['labels2'] for k in query_languages):
        
        # Tokenize label
        wordTokens1 = [tokenizer.tokenize(document['labels1'][k]['value']) for k in query_languages]
        wordTokens2 = [tokenizer.tokenize(document['labels2'][k]['value']) for k in query_languages]
        
        if (all(len(l) == 1 for l in wordTokens1) and all(len(l) == 1 for l in wordTokens2)):
            if document['labels1']['en']['value'].isalpha() and isLatin(document['labels1']['en']['value']) and document['labels2']['en']['value'].isalpha() and isLatin(document['labels2']['en']['value']):
                j = {'id1': document['id1']}
                for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
                j['id2'] = document['id2']
                for k in query_languages: j[k + '2'] = document['labels2'][k]['value']

                cand.append(j)
            else:
                j = {'id1': document['id1']}
                for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
                j['id2'] = document['id2']
                for k in query_languages: j[k + '2'] = document['labels2'][k]['value']

                candNon.append(j)

# %%
len(cand)
# Out:
# 107

# %%
cand
# Out:
# [{'id1': 'Q527',
#   'en1': 'sky',
#   'es1': 'cielo',
#   'fr1': 'ciel',
#   'de1': 'Himmel',
#   'id2': 'Q2',
#   'en2': 'Earth',
#   'es2': 'Tierra',
#   'fr2': 'Terre',
#   'de2': 'Erde'},
#  {'id1': 'Q4',
#   'en1': 'death',
#   'es1': 'muerte',
#   'fr1': 'mort',
#   'de1': 'Tod',
#   'id2': 'Q3',
#   'en2': 'life',
#   'es2': 'vida',
#   'fr2': 'vie',
#   'de2': 'Leben'},
#  {'id1': 'Q3',
#   'en1': 'life',
#   'es1': 'vida',
#   'fr1': 'vie',
#   'de1': 'Leben',
#   'id2': 'Q4',
#   'en2': 'death',
#   'es2': 'muerte',
#   'fr2': 'mort',
#   'de2': 'Tod'},
#  {'id1': 'Q14819852',
#   'en1': 'birth',
#   'es1': 'nacimiento',
#   'fr1': 'naissance',
#   'de1': 'Geburt',
#   'id2': 'Q4',
#   'en2': 'death',
#   'es2': 'muerte',
#   'fr2': 'mort',
#   'de2': 'Tod'},
#  {'id1': 'Q454',
#   'en1': 'peace',
#   'es1': 'paz',
#   'fr1': 'paix',
#   'de1': 'Frieden',
#   'id2': 'Q198',
#   'en2': 'war',
#   'es2': 'guerra',
#   'fr2': 'guerre',
#   'de2': 'Krieg'},
#  {'id1': 'Q192630',
#   'en1': 'past',
#   'es1': 'pasado',
#   'fr1': 'passé',
#   'de1': 'Vergangenheit',
#   'id2': 'Q344',
#   'en2': 'future',
#   'es2': 'futuro',
#   'fr2': 'futur',
#   'de2': 'Zukunft'},
#  {'id1': 'Q198',
#   'en1': 'war',
#   'es1': 'guerra',
#   'fr1': 'guerre',
#   'de1': 'Krieg',
#   'id2': 'Q454',
#   'en2': 'peace',
#   'es2': 'paz',
#   'fr2': 'paix',
#   'de2': 'Frieden'},
#  {'id1': 'Q2',
#   'en1': 'Earth',
#   'es1': 'Tierra',
#   'fr1': 'Terre',
#   'de1': 'Erde',
#   'id2': 'Q527',
#   'en2': 'sky',
#   'es2': 'cielo',
#   'fr2': 'ciel',
#   'de2': 'Himmel'},
#  {'id1': 'Q667',
#   'en1': 'south',
#   'es1': 'sur',
#   'fr1': 'sud',
#   'de1': 'Süden',
#   'id2': 'Q659',
#   'en2': 'north',
#   'es2': 'norte',
#   'fr2': 'nord',
#   'de2': 'Norden'},
#  {'id1': 'Q679',
#   'en1': 'west',
#   'es1': 'oeste',
#   'fr1': 'ouest',
#   'de1': 'Westen',
#   'id2': 'Q659',
#   'en2': 'north',
#   'es2': 'norte',
#   'fr2': 'nord',
#   'de2': 'Norden'},
#  {'id1': 'Q684',
#   'en1': 'east',
#   'es1': 'este',
#   'fr1': 'est',
#   'de1': 'Osten',
#   'id2': 'Q659',
#   'en2': 'north',
#   'es2': 'norte',
#   'fr2': 'nord',
#   'de2': 'Norden'},
#  {'id1': 'Q659',
#   'en1': 'north',
#   'es1': 'norte',
#   'fr1': 'nord',
#   'de1': 'Norden',
#   'id2': 'Q667',
#   'en2': 'south',
#   'es2': 'sur',
#   'fr2': 'sud',
#   'de2': 'Süden'},
#  {'id1': 'Q679',
#   'en1': 'west',
#   'es1': 'oeste',
#   'fr1': 'ouest',
#   'de1': 'Westen',
#   'id2': 'Q667',
#   'en2': 'south',
#   'es2': 'sur',
#   'fr2': 'sud',
#   'de2': 'Süden'},
#  {'id1': 'Q684',
#   'en1': 'east',
#   'es1': 'este',
#   'fr1': 'est',
#   'de1': 'Osten',
#   'id2': 'Q667',
#   'en2': 'south',
#   'es2': 'sur',
#   'fr2': 'sud',
#   'de2': 'Süden'},
#  {'id1': 'Q667',
#   'en1': 'south',
#   'es1': 'sur',
#   'fr1': 'sud',
#   'de1': 'Süden',
#   'id2': 'Q679',
#   'en2': 'west',
#   'es2': 'oeste',
#   'fr2': 'ouest',
#   'de2': 'Westen'},
#  {'id1': 'Q684',
#   'en1': 'east',
#   'es1': 'este',
#   'fr1': 'est',
#   'de1': 'Osten',
#   'id2': 'Q679',
#   'en2': 'west',
#   'es2': 'oeste',
#   'fr2': 'ouest',
#   'de2': 'Westen'},
#  {'id1': 'Q667',
#   'en1': 'south',
#   'es1': 'sur',
#   'fr1': 'sud',
#   'de1': 'Süden',
#   'id2': 'Q684',
#   'en2': 'east',
#   'es2': 'este',
#   'fr2': 'est',
#   'de2': 'Osten'},
#  {'id1': 'Q679',
#   'en1': 'west',
#   'es1': 'oeste',
#   'fr1': 'ouest',
#   'de1': 'Westen',
#   'id2': 'Q684',
#   'en2': 'east',
#   'es2': 'este',
#   'fr2': 'est',
#   'de2': 'Osten'},
#  {'id1': 'Q1313',
#   'en1': 'summer',
#   'es1': 'verano',
#   'fr1': 'été',
#   'de1': 'Sommer',
#   'id2': 'Q1311',
#   'en2': 'winter',
#   'es2': 'invierno',
#   'fr2': 'hiver',
#   'de2': 'Winter'},
#  {'id1': 'Q1311',
#   'en1': 'winter',
#   'es1': 'invierno',
#   'fr1': 'hiver',
#   'de1': 'Winter',
#   'id2': 'Q1313',
#   'en2': 'summer',
#   'es2': 'verano',
#   'fr2': 'été',
#   'de2': 'Sommer'},
#  {'id1': 'Q3031',
#   'en1': 'girl',
#   'es1': 'niña',
#   'fr1': 'fille',
#   'de1': 'Mädchen',
#   'id2': 'Q3010',
#   'en2': 'boy',
#   'es2': 'niño',
#   'fr2': 'garçon',
#   'de2': 'Junge'},
#  {'id1': 'Q3010',
#   'en1': 'boy',
#   'es1': 'niño',
#   'fr1': 'garçon',
#   'de1': 'Junge',
#   'id2': 'Q3031',
#   'en2': 'girl',
#   'es2': 'niña',
#   'fr2': 'fille',
#   'de2': 'Mädchen'},
#  {'id1': 'Q7565',
#   'en1': 'father',
#   'es1': 'padre',
#   'fr1': 'père',
#   'de1': 'Vater',
#   'id2': 'Q7560',
#   'en2': 'mother',
#   'es2': 'madre',
#   'fr2': 'mère',
#   'de2': 'Mutter'},
#  {'id1': 'Q7560',
#   'en1': 'mother',
#   'es1': 'madre',
#   'fr1': 'mère',
#   'de1': 'Mutter',
#   'id2': 'Q7565',
#   'en2': 'father',
#   'es2': 'padre',
#   'fr2': 'père',
#   'de2': 'Vater'},
#  {'id1': 'Q215627',
#   'en1': 'person',
#   'es1': 'persona',
#   'fr1': 'personne',
#   'de1': 'Person',
#   'id2': 'Q8425',
#   'en2': 'society',
#   'es2': 'sociedad',
#   'fr2': 'société',
#   'de2': 'Gesellschaft'},
#  {'id1': 'Q16511993',
#   'en1': 'queen',
#   'es1': 'reina',
#   'fr1': 'reine',
#   'de1': 'Königin',
#   'id2': 'Q12097',
#   'en2': 'king',
#   'es2': 'rey',
#   'fr2': 'roi',
#   'de2': 'König'},
#  {'id1': 'Q12147',
#   'en1': 'health',
#   'es1': 'salud',
#   'fr1': 'santé',
#   'de1': 'Gesundheit',
#   'id2': 'Q12136',
#   'en2': 'disease',
#   'es2': 'enfermedad',
#   'fr2': 'maladie',
#   'de2': 'Krankheit'},
#  {'id1': 'Q12136',
#   'en1': 'disease',
#   'es1': 'enfermedad',
#   'fr1': 'maladie',
#   'de1': 'Krankheit',
#   'id2': 'Q12147',
#   'en2': 'health',
#   'es2': 'salud',
#   'fr2': 'santé',
#   'de2': 'Gesundheit'},
#  {'id1': 'Q23445',
#   'en1': 'black',
#   'es1': 'negro',
#   'fr1': 'noir',
#   'de1': 'Schwarz',
#   'id2': 'Q23444',
#   'en2': 'white',
#   'es2': 'blanco',
#   'fr2': 'blanc',
#   'de2': 'weiß'},
#  {'id1': 'Q23444',
#   'en1': 'white',
#   'es1': 'blanco',
#   'fr1': 'blanc',
#   'de1': 'weiß',
#   'id2': 'Q23445',
#   'en2': 'black',
#   'es2': 'negro',
#   'fr2': 'noir',
#   'de2': 'Schwarz'},
#  {'id1': 'Q11499267',
#   'en1': 'defeat',
#   'es1': 'derrota',
#   'fr1': 'défaite',
#   'de1': 'Niederlage',
#   'id2': 'Q50000',
#   'en2': 'victory',
#   'es2': 'victoria',
#   'fr2': 'victoire',
#   'de2': 'Sieg'},
#  {'id1': 'Q15911314',
#   'en1': 'association',
#   'es1': 'asociación',
#   'fr1': 'association',
#   'de1': 'Verband',
#   'id2': 'Q157031',
#   'en2': 'foundation',
#   'es2': 'fundación',
#   'fr2': 'fondation',
#   'de2': 'Stiftung'},
#  {'id1': 'Q308194',
#   'en1': 'daughter',
#   'es1': 'hija',
#   'fr1': 'fille',
#   'de1': 'Tochter',
#   'id2': 'Q177232',
#   'en2': 'son',
#   'es2': 'hijo',
#   'fr2': 'fils',
#   'de2': 'Sohn'},
#  {'id1': 'Q212878',
#   'en1': 'husband',
#   'es1': 'esposo',
#   'fr1': 'époux',
#   'de1': 'Ehemann',
#   'id2': 'Q188830',
#   'en2': 'wife',
#   'es2': 'esposa',
#   'fr2': 'épouse',
#   'de2': 'Ehefrau'},
#  {'id1': 'Q930412',
#   'en1': 'depth',
#   'es1': 'profundidad',
#   'fr1': 'profondeur',
#   'de1': 'Tiefe',
#   'id2': 'Q190200',
#   'en2': 'altitude',
#   'es2': 'altitud',
#   'fr2': 'altitude',
#   'de2': 'Höhe'},
#  {'id1': 'Q344',
#   'en1': 'future',
#   'es1': 'futuro',
#   'fr1': 'futur',
#   'de1': 'Zukunft',
#   'id2': 'Q192630',
#   'en2': 'past',
#   'es2': 'pasado',
#   'fr2': 'passé',
#   'de2': 'Vergangenheit'},
#  {'id1': 'Q188830',
#   'en1': 'wife',
#   'es1': 'esposa',
#   'fr1': 'épouse',
#   'de1': 'Ehefrau',
#   'id2': 'Q212878',
#   'en2': 'husband',
#   'es2': 'esposo',
#   'fr2': 'époux',
#   'de2': 'Ehemann'},
#  {'id1': 'Q400629',
#   'en1': 'Goodbye',
#   'es1': 'Goodbye',
#   'fr1': 'Goodbye',
#   'de1': 'Goodbye',
#   'id2': 'Q256420',
#   'en2': 'Hello',
#   'es2': 'Hello',
#   'fr2': 'Hello',
#   'de2': 'Hello'},
#  {'id1': 'Q177232',
#   'en1': 'son',
#   'es1': 'hijo',
#   'fr1': 'fils',
#   'de1': 'Sohn',
#   'id2': 'Q308194',
#   'en2': 'daughter',
#   'es2': 'hija',
#   'fr2': 'fille',
#   'de2': 'Tochter'},
#  {'id1': 'Q256420',
#   'en1': 'Hello',
#   'es1': 'Hello',
#   'fr1': 'Hello',
#   'de1': 'Hello',
#   'id2': 'Q400629',
#   'en2': 'Goodbye',
#   'es2': 'Goodbye',
#   'fr2': 'Goodbye',
#   'de2': 'Goodbye'},
#  {'id1': 'Q59866386',
#   'en1': 'Douglas',
#   'es1': 'Douglas',
#   'fr1': 'Douglas',
#   'de1': 'Douglas',
#   'id2': 'Q463035',
#   'en2': 'Douglas',
#   'es2': 'Douglas',
#   'fr2': 'Douglas',
#   'de2': 'Douglas'},
#  {'id1': 'Q12769393',
#   'en1': 'end',
#   'es1': 'fin',
#   'fr1': 'fin',
#   'de1': 'Ende',
#   'id2': 'Q529711',
#   'en2': 'beginning',
#   'es2': 'inicio',
#   'fr2': 'début',
#   'de2': 'Anfang'},
#  {'id1': 'Q10861465',
#   'en1': 'brother',
#   'es1': 'hermano',
#   'fr1': 'frère',
#   'de1': 'Bruder',
#   'id2': 'Q595094',
#   'en2': 'sister',
#   'es2': 'hermana',
#   'fr2': 'sœur',
#   'de2': 'Schwester'},
#  {'id1': 'Q18067255',
#   'en1': 'Simone',
#   'es1': 'Simone',
#   'fr1': 'Simone',
#   'de1': 'Simone',
#   'id2': 'Q602977',
#   'en2': 'Simone',
#   'es2': 'Simone',
#   'fr2': 'Simone',
#   'de2': 'Simone'},
#  {'id1': 'Q21075690',
#   'en1': 'solution',
#   'es1': 'solución',
#   'fr1': 'solution',
#   'de1': 'Lösung',
#   'id2': 'Q621184',
#   'en2': 'problem',
#   'es2': 'problema',
#   'fr2': 'problème',
#   'de2': 'Problem'},
#  {'id1': 'Q190200',
#   'en1': 'altitude',
#   'es1': 'altitud',
#   'fr1': 'altitude',
#   'de1': 'Höhe',
#   'id2': 'Q930412',
#   'en2': 'depth',
#   'es2': 'profundidad',
#   'fr2': 'profondeur',
#   'de2': 'Tiefe'},
#  {'id1': 'Q54617672',
#   'en1': 'Augustine',
#   'es1': 'Augustine',
#   'fr1': 'Augustine',
#   'de1': 'Augustine',
#   'id2': 'Q1300961',
#   'en2': 'Augustine',
#   'es2': 'Augustine',
#   'fr2': 'Augustine',
#   'de2': 'Augustine'},
#  {'id1': 'Q20818050',
#   'en1': 'Lenny',
#   'es1': 'Lenny',
#   'fr1': 'Lenny',
#   'de1': 'Lenny',
#   'id2': 'Q1667498',
#   'en2': 'Lenny',
#   'es2': 'Lenny',
#   'fr2': 'Lenny',
#   'de2': 'Lenny'},
#  {'id1': 'Q3660491',
#   'en1': 'Caro',
#   'es1': 'Caro',
#   'fr1': 'Caro',
#   'de1': 'Caro',
#   'id2': 'Q1855388',
#   'en2': 'Caro',
#   'es2': 'Caro',
#   'fr2': 'Caro',
#   'de2': 'Caro'},
#  {'id1': 'Q7521081',
#   'en1': 'Jean',
#   'es1': 'Jean',
#   'fr1': 'Jean',
#   'de1': 'Jean',
#   'id2': 'Q2438057',
#   'en2': 'Jeanne',
#   'es2': 'Jeanne',
#   'fr2': 'Jeanne',
#   'de2': 'Jeanne'},
#  {'id1': 'Q1855388',
#   'en1': 'Caro',
#   'es1': 'Caro',
#   'fr1': 'Caro',
#   'de1': 'Caro',
#   'id2': 'Q3660491',
#   'en2': 'Caro',
#   'es2': 'Caro',
#   'fr2': 'Caro',
#   'de2': 'Caro'},
#  {'id1': 'Q7521081',
#   'en1': 'Jean',
#   'es1': 'Jean',
#   'fr1': 'Jean',
#   'de1': 'Jean',
#   'id2': 'Q4160311',
#   'en2': 'Jean',
#   'es2': 'Jean',
#   'fr2': 'Jean',
#   'de2': 'Jean'},
#  {'id1': 'Q2438057',
#   'en1': 'Jeanne',
#   'es1': 'Jeanne',
#   'fr1': 'Jeanne',
#   'de1': 'Jeanne',
#   'id2': 'Q7521081',
#   'en2': 'Jean',
#   'es2': 'Jean',
#   'fr2': 'Jean',
#   'de2': 'Jean'},
#  {'id1': 'Q4160311',
#   'en1': 'Jean',
#   'es1': 'Jean',
#   'fr1': 'Jean',
#   'de1': 'Jean',
#   'id2': 'Q7521081',
#   'en2': 'Jean',
#   'es2': 'Jean',
#   'fr2': 'Jean',
#   'de2': 'Jean'},
#  {'id1': 'Q595094',
#   'en1': 'sister',
#   'es1': 'hermana',
#   'fr1': 'sœur',
#   'de1': 'Schwester',
#   'id2': 'Q10861465',
#   'en2': 'brother',
#   'es2': 'hermano',
#   'fr2': 'frère',
#   'de2': 'Bruder'},
#  {'id1': 'Q50000',
#   'en1': 'victory',
#   'es1': 'victoria',
#   'fr1': 'victoire',
#   'de1': 'Sieg',
#   'id2': 'Q11499267',
#   'en2': 'defeat',
#   'es2': 'derrota',
#   'fr2': 'défaite',
#   'de2': 'Niederlage'},
#  {'id1': 'Q18220903',
#   'en1': 'Jan',
#   'es1': 'Jan',
#   'fr1': 'Jan',
#   'de1': 'Jan',
#   'id2': 'Q12173670',
#   'en2': 'Jan',
#   'es2': 'Jan',
#   'fr2': 'Jan',
#   'de2': 'Jan'},
#  {'id1': 'Q529711',
#   'en1': 'beginning',
#   'es1': 'inicio',
#   'fr1': 'début',
#   'de1': 'Anfang',
#   'id2': 'Q12769393',
#   'en2': 'end',
#   'es2': 'fin',
#   'fr2': 'fin',
#   'de2': 'Ende'},
#  {'id1': 'Q14565199',
#   'en1': 'right',
#   'es1': 'derecha',
#   'fr1': 'droite',
#   'de1': 'rechts',
#   'id2': 'Q13196750',
#   'en2': 'left',
#   'es2': 'izquierda',
#   'fr2': 'gauche',
#   'de2': 'links'},
#  {'id1': 'Q15332375',
#   'en1': 'up',
#   'es1': 'arriba',
#   'fr1': 'haut',
#   'de1': 'oben',
#   'id2': 'Q13196750',
#   'en2': 'left',
#   'es2': 'izquierda',
#   'fr2': 'gauche',
#   'de2': 'links'},
#  {'id1': 'Q15332388',
#   'en1': 'down',
#   'es1': 'abajo',
#   'fr1': 'bas',
#   'de1': 'unten',
#   'id2': 'Q13196750',
#   'en2': 'left',
#   'es2': 'izquierda',
#   'fr2': 'gauche',
#   'de2': 'links'},
#  {'id1': 'Q13196750',
#   'en1': 'left',
#   'es1': 'izquierda',
#   'fr1': 'gauche',
#   'de1': 'links',
#   'id2': 'Q14565199',
#   'en2': 'right',
#   'es2': 'derecha',
#   'fr2': 'droite',
#   'de2': 'rechts'},
#  {'id1': 'Q15332375',
#   'en1': 'up',
#   'es1': 'arriba',
#   'fr1': 'haut',
#   'de1': 'oben',
#   'id2': 'Q14565199',
#   'en2': 'right',
#   'es2': 'derecha',
#   'fr2': 'droite',
#   'de2': 'rechts'},
#  {'id1': 'Q15332388',
#   'en1': 'down',
#   'es1': 'abajo',
#   'fr1': 'bas',
#   'de1': 'unten',
#   'id2': 'Q14565199',
#   'en2': 'right',
#   'es2': 'derecha',
#   'fr2': 'droite',
#   'de2': 'rechts'},
#  {'id1': 'Q4',
#   'en1': 'death',
#   'es1': 'muerte',
#   'fr1': 'mort',
#   'de1': 'Tod',
#   'id2': 'Q14819852',
#   'en2': 'birth',
#   'es2': 'nacimiento',
#   'fr2': 'naissance',
#   'de2': 'Geburt'},
#  {'id1': 'Q13196750',
#   'en1': 'left',
#   'es1': 'izquierda',
#   'fr1': 'gauche',
#   'de1': 'links',
#   'id2': 'Q15332375',
#   'en2': 'up',
#   'es2': 'arriba',
#   'fr2': 'haut',
#   'de2': 'oben'},
#  {'id1': 'Q14565199',
#   'en1': 'right',
#   'es1': 'derecha',
#   'fr1': 'droite',
#   'de1': 'rechts',
#   'id2': 'Q15332375',
#   'en2': 'up',
#   'es2': 'arriba',
#   'fr2': 'haut',
#   'de2': 'oben'},
#  {'id1': 'Q15332388',
#   'en1': 'down',
#   'es1': 'abajo',
#   'fr1': 'bas',
#   'de1': 'unten',
#   'id2': 'Q15332375',
#   'en2': 'up',
#   'es2': 'arriba',
#   'fr2': 'haut',
#   'de2': 'oben'},
#  {'id1': 'Q13196750',
#   'en1': 'left',
#   'es1': 'izquierda',
#   'fr1': 'gauche',
#   'de1': 'links',
#   'id2': 'Q15332388',
#   'en2': 'down',
#   'es2': 'abajo',
#   'fr2': 'bas',
#   'de2': 'unten'},
#  {'id1': 'Q14565199',
#   'en1': 'right',
#   'es1': 'derecha',
#   'fr1': 'droite',
#   'de1': 'rechts',
#   'id2': 'Q15332388',
#   'en2': 'down',
#   'es2': 'abajo',
#   'fr2': 'bas',
#   'de2': 'unten'},
#  {'id1': 'Q15332375',
#   'en1': 'up',
#   'es1': 'arriba',
#   'fr1': 'haut',
#   'de1': 'oben',
#   'id2': 'Q15332388',
#   'en2': 'down',
#   'es2': 'abajo',
#   'fr2': 'bas',
#   'de2': 'unten'},
#  {'id1': 'Q157031',
#   'en1': 'foundation',
#   'es1': 'fundación',
#   'fr1': 'fondation',
#   'de1': 'Stiftung',
#   'id2': 'Q15911314',
#   'en2': 'association',
#   'es2': 'asociación',
#   'fr2': 'association',
#   'de2': 'Verband'},
#  {'id1': 'Q23774368',
#   'en1': 'George',
#   'es1': 'George',
#   'fr1': 'George',
#   'de1': 'George',
#   'id2': 'Q15921732',
#   'en2': 'George',
#   'es2': 'George',
#   'fr2': 'George',
#   'de2': 'George'},
#  {'id1': 'Q12097',
#   'en1': 'king',
#   'es1': 'rey',
#   'fr1': 'roi',
#   'de1': 'König',
#   'id2': 'Q16511993',
#   'en2': 'queen',
#   'es2': 'reina',
#   'fr2': 'reine',
#   'de2': 'Königin'},
#  {'id1': 'Q18219684',
#   'en1': 'Joan',
#   'es1': 'Joan',
#   'fr1': 'Joan',
#   'de1': 'Joan',
#   'id2': 'Q16652258',
#   'en2': 'Joan',
#   'es2': 'Joan',
#   'fr2': 'Joan',
#   'de2': 'Joan'},
#  {'id1': 'Q1370330',
#   'en1': 'Augusta',
#   'es1': 'Augusta',
#   'fr1': 'Augusta',
#   'de1': 'Augusta',
#   'id2': 'Q18010311',
#   'en2': 'Auguste',
#   'es2': 'Auguste',
#   'fr2': 'Auguste',
#   'de2': 'Auguste'},
#  {'id1': 'Q28053272',
#   'en1': 'Auguste',
#   'es1': 'Auguste',
#   'fr1': 'Auguste',
#   'de1': 'Auguste',
#   'id2': 'Q18010311',
#   'en2': 'Auguste',
#   'es2': 'Auguste',
#   'fr2': 'Auguste',
#   'de2': 'Auguste'},
#  {'id1': 'Q602977',
#   'en1': 'Simone',
#   'es1': 'Simone',
#   'fr1': 'Simone',
#   'de1': 'Simone',
#   'id2': 'Q18067255',
#   'en2': 'Simone',
#   'es2': 'Simone',
#   'fr2': 'Simone',
#   'de2': 'Simone'},
#  {'id1': 'Q18177321',
#   'en1': 'Andrea',
#   'es1': 'Andrea',
#   'fr1': 'Andrea',
#   'de1': 'Andrea',
#   'id2': 'Q18177306',
#   'en2': 'Andrea',
#   'es2': 'Andrea',
#   'fr2': 'Andrea',
#   'de2': 'Andrea'},
#  {'id1': 'Q18177306',
#   'en1': 'Andrea',
#   'es1': 'Andrea',
#   'fr1': 'Andrea',
#   'de1': 'Andrea',
#   'id2': 'Q18177321',
#   'en2': 'Andrea',
#   'es2': 'Andrea',
#   'fr2': 'Andrea',
#   'de2': 'Andrea'},
#  {'id1': 'Q12173670',
#   'en1': 'Jan',
#   'es1': 'Jan',
#   'fr1': 'Jan',
#   'de1': 'Jan',
#   'id2': 'Q18220903',
#   'en2': 'Jan',
#   'es2': 'Jan',
#   'fr2': 'Jan',
#   'de2': 'Jan'},
#  {'id1': 'Q18325152',
#   'en1': 'Laurence',
#   'es1': 'Laurence',
#   'fr1': 'Laurence',
#   'de1': 'Laurence',
#   'id2': 'Q18325151',
#   'en2': 'Laurence',
#   'es2': 'Laurence',
#   'fr2': 'Laurence',
#   'de2': 'Laurence'},
#  {'id1': 'Q18325151',
#   'en1': 'Laurence',
#   'es1': 'Laurence',
#   'fr1': 'Laurence',
#   'de1': 'Laurence',
#   'id2': 'Q18325152',
#   'en2': 'Laurence',
#   'es2': 'Laurence',
#   'fr2': 'Laurence',
#   'de2': 'Laurence'},
#  {'id1': 'Q18620539',
#   'en1': 'Michele',
#   'es1': 'Michele',
#   'fr1': 'Michele',
#   'de1': 'Michele',
#   'id2': 'Q18620536',
#   'en2': 'Michele',
#   'es2': 'Michele',
#   'fr2': 'Michele',
#   'de2': 'Michele'},
#  {'id1': 'Q18620536',
#   'en1': 'Michele',
#   'es1': 'Michele',
#   'fr1': 'Michele',
#   'de1': 'Michele',
#   'id2': 'Q18620539',
#   'en2': 'Michele',
#   'es2': 'Michele',
#   'fr2': 'Michele',
#   'de2': 'Michele'},
#  {'id1': 'Q96654670',
#   'en1': 'Uwe',
#   'es1': 'Uwe',
#   'fr1': 'Uwe',
#   'de1': 'Uwe',
#   'id2': 'Q18515951',
#   'en2': 'Uwe',
#   'es2': 'Uwe',
#   'fr2': 'Uwe',
#   'de2': 'Uwe'},
#  {'id1': 'Q104771451',
#   'en1': 'Michal',
#   'es1': 'Michal',
#   'fr1': 'Michal',
#   'de1': 'Michal',
#   'id2': 'Q18563993',
#   'en2': 'Michal',
#   'es2': 'Michal',
#   'fr2': 'Michal',
#   'de2': 'Michal'},
#  {'id1': 'Q18686588',
#   'en1': 'Marion',
#   'es1': 'Marion',
#   'fr1': 'Marion',
#   'de1': 'Marion',
#   'id2': 'Q18689525',
#   'en2': 'Marion',
#   'es2': 'Marion',
#   'fr2': 'Marion',
#   'de2': 'Marion'},
#  {'id1': 'Q18689525',
#   'en1': 'Marion',
#   'es1': 'Marion',
#   'fr1': 'Marion',
#   'de1': 'Marion',
#   'id2': 'Q18686588',
#   'en2': 'Marion',
#   'es2': 'Marion',
#   'fr2': 'Marion',
#   'de2': 'Marion'},
#  {'id1': 'Q20813195',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813183',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q20813204',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813183',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q20813183',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813195',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q20813204',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813195',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q20813183',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813204',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q20813195',
#   'en1': 'Santos',
#   'es1': 'Santos',
#   'fr1': 'Santos',
#   'de1': 'Santos',
#   'id2': 'Q20813204',
#   'en2': 'Santos',
#   'es2': 'Santos',
#   'fr2': 'Santos',
#   'de2': 'Santos'},
#  {'id1': 'Q621184',
#   'en1': 'problem',
#   'es1': 'problema',
#   'fr1': 'problème',
#   'de1': 'Problem',
#   'id2': 'Q21075690',
#   'en2': 'solution',
#   'es2': 'solución',
#   'fr2': 'solution',
#   'de2': 'Lösung'},
#  {'id1': 'Q15921732',
#   'en1': 'George',
#   'es1': 'George',
#   'fr1': 'George',
#   'de1': 'George',
#   'id2': 'Q23774368',
#   'en2': 'George',
#   'es2': 'George',
#   'fr2': 'George',
#   'de2': 'George'},
#  {'id1': 'Q24759450',
#   'en1': 'leave',
#   'es1': 'salir',
#   'fr1': 'quitter',
#   'de1': 'Contra',
#   'id2': 'Q24759380',
#   'en2': 'remain',
#   'es2': 'permanecer',
#   'fr2': 'rester',
#   'de2': 'Pro'},
#  {'id1': 'Q24759380',
#   'en1': 'remain',
#   'es1': 'permanecer',
#   'fr1': 'rester',
#   'de1': 'Pro',
#   'id2': 'Q24759450',
#   'en2': 'leave',
#   'es2': 'salir',
#   'fr2': 'quitter',
#   'de2': 'Contra'},
#  {'id1': 'Q18010311',
#   'en1': 'Auguste',
#   'es1': 'Auguste',
#   'fr1': 'Auguste',
#   'de1': 'Auguste',
#   'id2': 'Q28053272',
#   'en2': 'Auguste',
#   'es2': 'Auguste',
#   'fr2': 'Auguste',
#   'de2': 'Auguste'},
#  {'id1': 'Q28962312',
#   'en1': 'often',
#   'es1': 'frecuentemente',
#   'fr1': 'souvent',
#   'de1': 'häufig',
#   'id2': 'Q28962310',
#   'en2': 'rarely',
#   'es2': 'raramente',
#   'fr2': 'rarement',
#   'de2': 'kaum'},
#  {'id1': 'Q28962310',
#   'en1': 'rarely',
#   'es1': 'raramente',
#   'fr1': 'rarement',
#   'de1': 'kaum',
#   'id2': 'Q28962312',
#   'en2': 'often',
#   'es2': 'frecuentemente',
#   'fr2': 'souvent',
#   'de2': 'häufig'},
#  {'id1': 'Q29043257',
#   'en1': 'José',
#   'es1': 'José',
#   'fr1': 'José',
#   'de1': 'José',
#   'id2': 'Q29043256',
#   'en2': 'José',
#   'es2': 'José',
#   'fr2': 'José',
#   'de2': 'José'},
#  {'id1': 'Q29043256',
#   'en1': 'José',
#   'es1': 'José',
#   'fr1': 'José',
#   'de1': 'José',
#   'id2': 'Q29043257',
#   'en2': 'José',
#   'es2': 'José',
#   'fr2': 'José',
#   'de2': 'José'},
#  {'id1': 'Q1300961',
#   'en1': 'Augustine',
#   'es1': 'Augustine',
#   'fr1': 'Augustine',
#   'de1': 'Augustine',
#   'id2': 'Q54617672',
#   'en2': 'Augustine',
#   'es2': 'Augustine',
#   'fr2': 'Augustine',
#   'de2': 'Augustine'},
#  {'id1': 'Q18563993',
#   'en1': 'Michal',
#   'es1': 'Michal',
#   'fr1': 'Michal',
#   'de1': 'Michal',
#   'id2': 'Q104771451',
#   'en2': 'Michal',
#   'es2': 'Michal',
#   'fr2': 'Michal',
#   'de2': 'Michal'},
#  {'id1': 'Q108657270',
#   'en1': 'Minor',
#   'es1': 'Minor',
#   'fr1': 'Minor',
#   'de1': 'Minor',
#   'id2': 'Q106902304',
#   'en2': 'Maior',
#   'es2': 'Maior',
#   'fr2': 'Maior',
#   'de2': 'Maior'}]

# %% [markdown]
# ### Postprocess and Save

# %%
import pandas as pd

# %%
# Entity Candidates to Dataframe
df = pd.DataFrame(cand)
df
# Out:
#             id1        en1         es1        fr1        de1         id2  \
# 0          Q527        sky       cielo       ciel     Himmel          Q2
# 1            Q4      death      muerte       mort        Tod          Q3
# 2            Q3       life        vida        vie      Leben          Q4
# 3     Q14819852      birth  nacimiento  naissance     Geburt          Q4
# 4          Q454      peace         paz       paix    Frieden        Q198
# ..          ...        ...         ...        ...        ...         ...
# 102   Q29043257       José        José       José       José   Q29043256
# 103   Q29043256       José        José       José       José   Q29043257
# 104    Q1300961  Augustine   Augustine  Augustine  Augustine   Q54617672
# 105   Q18563993     Michal      Michal     Michal     Michal  Q104771451
# 106  Q108657270      Minor       Minor      Minor      Minor  Q106902304
#
#            en2        es2        fr2        de2
# 0        Earth     Tierra      Terre       Erde
# 1         life       vida        vie      Leben
# 2        death     muerte       mort        Tod
# 3        death     muerte       mort        Tod
# 4          war     guerra     guerre      Krieg
# ..         ...        ...        ...        ...
# 102       José       José       José       José
# 103       José       José       José       José
# 104  Augustine  Augustine  Augustine  Augustine
# 105     Michal     Michal     Michal     Michal
# 106      Maior      Maior      Maior      Maior
#
# [107 rows x 10 columns]

# %%
# Remove duplicate labels
df_wo_duplicates = df.drop_duplicates(subset='en1', keep='first')
df_wo_duplicates
# Out:
#             id1     en1             es1        fr1      de1         id2  \
# 0          Q527     sky           cielo       ciel   Himmel          Q2
# 1            Q4   death          muerte       mort      Tod          Q3
# 2            Q3    life            vida        vie    Leben          Q4
# 3     Q14819852   birth      nacimiento  naissance   Geburt          Q4
# 4          Q454   peace             paz       paix  Frieden        Q198
# ..          ...     ...             ...        ...      ...         ...
# 98    Q24759380  remain      permanecer     rester      Pro   Q24759450
# 100   Q28962312   often  frecuentemente    souvent   häufig   Q28962310
# 101   Q28962310  rarely       raramente   rarement     kaum   Q28962312
# 102   Q29043257    José            José       José     José   Q29043256
# 106  Q108657270   Minor           Minor      Minor    Minor  Q106902304
#
#         en2             es2       fr2     de2
# 0     Earth          Tierra     Terre    Erde
# 1      life            vida       vie   Leben
# 2     death          muerte      mort     Tod
# 3     death          muerte      mort     Tod
# 4       war          guerra    guerre   Krieg
# ..      ...             ...       ...     ...
# 98    leave           salir   quitter  Contra
# 100  rarely       raramente  rarement    kaum
# 101   often  frecuentemente   souvent  häufig
# 102    José            José      José    José
# 106   Maior           Maior     Maior   Maior
#
# [73 rows x 10 columns]

# %%
# Save as CSV for manual cleanup
df_wo_duplicates.to_csv('SingleToken/antonym_multilingual_uncleaned.csv', index=False)
