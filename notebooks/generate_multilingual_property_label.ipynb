# %%
import pandas as pd
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.wikidata
db.list_collection_names()
# Out:
# ['entity2_triples',
#  'entity_counts',
#  'triplesInvert',
#  'triples',
#  'equivalence',
#  'nsproperties',
#  'inversion',
#  'entity_subset',
#  'antonym',
#  'relation_subset',
#  'entityList',
#  'entity1_triples',
#  'properties',
#  'symmetry']

# %%
db.symmetry.find_one({})
# Out:
# {'_id': ObjectId('6213b9f506657e78f384d1f9'), 'id': 'P530'}

# %%
db.relation_subset.find_one({'id': 'P530'})

# %%
db.relation_subset.count_documents({})
# Out:
# 1142

# %%
db.relation_subset.find_one({})
# Out:
# {'_id': ObjectId('6210c432cf55a123777d8516'),
#  'id': 'P1034',
#  'type': 'property',
#  'labels': {'en': {'language': 'en', 'value': 'main food source'},
#   'nb': {'language': 'nb', 'value': 'hovednæringskilde'},
#   'ca': {'language': 'ca', 'value': "principal font d'alimentació"},
#   'pt': {'language': 'pt', 'value': 'principal fonte alimentar'},
#   'de': {'language': 'de', 'value': 'Hauptnahrungsquelle'},
#   'it': {'language': 'it', 'value': 'principale fonte di nutrizione'},
#   'hu': {'language': 'hu', 'value': 'fő élelemforrás'},
#   'fr': {'language': 'fr', 'value': 'source principale de nourriture'},
#   'pl': {'language': 'pl', 'value': 'główne źródło pożywienia'},
#   'es': {'language': 'es', 'value': 'fuente de alimento principal'},
#   'ru': {'language': 'ru', 'value': 'основной источник питания'},
#   'fa': {'language': 'fa', 'value': 'منبع غذایی اصلی'},
#   'nl': {'language': 'nl', 'value': 'belangrijkste voedselbron'},
#   'br': {'language': 'br', 'value': 'Mammenn emvagañ bennañ'},
#   'mk': {'language': 'mk', 'value': 'главен извор на исхрана'},
#   'cs': {'language': 'cs', 'value': 'hlavní zdroj potravy'},
#   'da': {'language': 'da', 'value': 'primær fødekilde'},
#   'nds': {'language': 'nds', 'value': 'wichtigst Freten'},
#   'uk': {'language': 'uk', 'value': 'ким харчується'},
#   'sr': {'language': 'sr', 'value': 'главни извор хране'},
#   'th': {'language': 'th', 'value': 'แหล่งอาหารหลัก'},
#   'ja': {'language': 'ja', 'value': '主な食料源'},
#   'ko': {'language': 'ko', 'value': '주로 먹는 것'},
#   'oc': {'language': 'oc', 'value': 'font principala de noiridura'},
#   'zh-mo': {'language': 'zh-mo', 'value': '主要食物來源'},
#   'zh': {'language': 'zh', 'value': '主要食物來源'},
#   'zh-cn': {'language': 'zh-cn', 'value': '主要食物来源'},
#   'zh-hans': {'language': 'zh-hans', 'value': '主要食物来源'},
#   'zh-hant': {'language': 'zh-hant', 'value': '主要食物來源'},
#   'zh-hk': {'language': 'zh-hk', 'value': '主要食物來源'},
#   'zh-my': {'language': 'zh-my', 'value': '主要食物来源'},
#   'zh-sg': {'language': 'zh-sg', 'value': '主要食物来源'},
#   'zh-tw': {'language': 'zh-tw', 'value': '主要食物來源'},
#   'ar': {'language': 'ar', 'value': 'مصدر الغذاء الرئيسي'},
#   'eo': {'language': 'eo', 'value': 'ĉefa manĝaĵo de organismo'},
#   'sq': {'language': 'sq', 'value': 'burim kryesor i ushqimit'},
#   'id': {'language': 'id', 'value': 'sumber makanan utama'},
#   'he': {'language': 'he', 'value': 'מקור מזון עיקרי'},
#   'ga': {'language': 'ga', 'value': 'príomhfhoinse bia'},
#   'tt': {'language': 'tt', 'value': 'Туклану чыганагы'},
#   'be-tarask': {'language': 'be-tarask',
#    'value': 'асноўная крыніца харчаваньня'},
#   'eu': {'language': 'eu', 'value': 'elikadura iturri nagusi'},
#   'fi': {'language': 'fi', 'value': 'pääasiallinen ravinto'},
#   'tr': {'language': 'tr', 'value': 'ana besin kaynağı'},
#   'sv': {'language': 'sv', 'value': 'huvudsaklig födokälla'},
#   'ba': {'language': 'ba', 'value': 'туҡланыу сығанағы'},
#   'bn': {'language': 'bn', 'value': 'প্রধান খাদ্যের উৎস'},
#   'vec': {'language': 'vec', 'value': 'prinsipałe fonte ałimentare'}}}

# %% [markdown]
# #### Find out how much relations there are...

# %%
db.relation_subset.count_documents({
    'labels.en':{'$exists':True},
    'labels.zh':{'$exists':True}
})
# Out:
# 0

# %%
db.relation_subset.count_documents({
    'labels.en':{'$exists':True},
    'labels.ja':{'$exists':True}
})
# Out:
# 857

# %%
db.relation_subset.count_documents({
    'labels.en':{'$exists':True},
    'labels.ru':{'$exists':True}
})
# Out:
# 1007

# %% [markdown]
# #### Generate relations

# %%
from collections import defaultdict

# %%
language_list = [['ru', 'zh'], ['ru', 'ja'], ['zh', 'ja']]

# %%
for languages in language_list:
    # Query
    exist_value = {'$exists':True}
    query = {}

    for lang in languages:
        query['labels.' + lang] = exist_value
    
    # Save in dict
    propertyList = defaultdict(list)
    
    for doc in db.relation_subset.find(query):
        propertyList['id'].append(doc['id'])
        for lang in languages:
            propertyList[lang].append(doc['labels'][lang]['value'])
        propertyList['en'].append(doc['labels']['en']['value'])
        
    print("Saving...")
    df = pd.DataFrame(propertyList)
    
    for lang in languages:
        df = df.drop_duplicates(subset=lang, keep='first')
    
    # Save as CSV for manual cleanup
    path = '../data/knowledge/'

    lang_path = ''
    for i, lang in enumerate(languages):
            lang_path += lang + '_'

    df.to_csv(path + lang_path + 'relations_en.csv', index=False)
# Out:
# Saving...
# Saving...
# Saving...

# %%
for i in propertyList:
    print(len(propertyList[i]))
# Out:
# 670
# 670
# 1340

# %%
propertyList
# Out:
# defaultdict(list,
#             {'id': ['P1034',
#               'P5008',
#               'P457',
#               'P532',
#               'P740',
#               'P1817',
#               'P1425',
#               'P122',
#               'P58',
#               'P1629',
#               'P2876',
#               'P2597',
#               'P9072',
#               'P1716',
#               'P1465',
#               'P1165',
#               'P4043',
#               'P6889',
#               'P8839',
#               'P3080',
#               'P141',
#               'P7167',
#               'P1951',
#               'P2554',
#               'P66',
#               'P2853',
#               'P7163',
#               'P3275',
#               'P7938',
#               'P786',
#               'P106',
#               'P636',
#               'P85',
#               'P2841',
#               'P1811',
#               'P631',
#               'P1158',
#               'P4608',
#               'P103',
#               'P908',
#               'P37',
#               'P1435',
#               'P689',
#               'P1855',
#               'P2614',
#               'P38',
#               'P183',
#               'P5996',
#               'P163',
#               'P4805',
#               'P6902',
#               'P2992',
#               'P2438',
#               'P282',
#               'P291',
#               'P6275',
#               'P20',
#               'P3680',
#               'P5202',
#               'P2184',
#               'P411',
#               'P450',
#               'P1455',
#               'P6942',
#               'P1414',
#               'P3712',
#               'P8822',
#               'P2361',
#               'P5522',
#               'P2882',
#               'P2634',
#               'P7228',
#               'P1990',
#               'P136',
#               'P452',
#               'P1462',
#               'P449',
#               'P8989',
#               'P5800',
#               'P517',
#               'P7937',
#               'P1884',
#               'P3018',
#               'P1686',
#               'P4241',
#               'P3975',
#               'P1050',
#               'P2286',
#               'P140',
#               'P814',
#               'P59',
#               'P1201',
#               'P1434',
#               'P8289',
#               'P3912',
#               'P1923',
#               'P7867',
#               'P8933',
#               'P930',
#               'P1546',
#               'P1792',
#               'P149',
#               'P3803',
#               'P509',
#               'P2925',
#               'P6086',
#               'P111',
#               'P1013',
#               'P7469',
#               'P8646',
#               'P7561',
#               'P5998',
#               'P4968',
#               'P680',
#               'P35',
#               'P2715',
#               'P516',
#               'P1142',
#               'P7095',
#               'P8345',
#               'P2700',
#               'P2827',
#               'P2962',
#               'P6533',
#               'P2568',
#               'P823',
#               'P4100',
#               'P495',
#               'P1056',
#               'P301',
#               'P2348',
#               'P3602',
#               'P3610',
#               'P3033',
#               'P6819',
#               'P1412',
#               'P3834',
#               'P277',
#               'P1308',
#               'P750',
#               'P453',
#               'P840',
#               'P3437',
#               'P8453',
#               'P364',
#               'P88',
#               'P3092',
#               'P427',
#               'P2587',
#               'P1423',
#               'P1011',
#               'P4586',
#               'P1995',
#               'P415',
#               'P1204',
#               'P654',
#               'P1310',
#               'P1444',
#               'P1678',
#               'P5353',
#               'P4330',
#               'P1032',
#               'P5095',
#               'P118',
#               'P2633',
#               'P800',
#               'P1775',
#               'P1606',
#               'P1264',
#               'P3739',
#               'P27',
#               'P3274',
#               'P2679',
#               'P913',
#               'P1909',
#               'P413',
#               'P1534',
#               'P2079',
#               'P8852',
#               'P1537',
#               'P6104',
#               'P1072',
#               'P5425',
#               'P6259',
#               'P1211',
#               'P4195',
#               'P469',
#               'P542',
#               'P2637',
#               'P4290',
#               'P2675',
#               'P275',
#               'P87',
#               'P1078',
#               'P1363',
#               'P768',
#               'P1227',
#               'P358',
#               'P84',
#               'P3985',
#               'P2667',
#               'P8810',
#               'P4733',
#               'P2505',
#               'P1057',
#               'P2680',
#               'P5054',
#               'P1080',
#               'P1875',
#               'P135',
#               'P1210',
#               'P1913',
#               'P7500',
#               'P618',
#               'P923',
#               'P8107',
#               'P2632',
#               'P2935',
#               'P1012',
#               'P171',
#               'P9926',
#               'P1547',
#               'P5280',
#               'P8032',
#               'P272',
#               'P1419',
#               'P5824',
#               'P2416',
#               'P3828',
#               'P5389',
#               'P708',
#               'P1145',
#               'P69',
#               'P189',
#               'P944',
#               'P2825',
#               'P4934',
#               'P2937',
#               'P1657',
#               'P400',
#               'P4353',
#               'P3592',
#               'P681',
#               'P425',
#               'P2061',
#               'P6364',
#               'P1789',
#               'P524',
#               'P1049',
#               'P831',
#               'P1881',
#               'P2289',
#               'P2175',
#               'P3512',
#               'P418',
#               'P8701',
#               'P9929',
#               'P1903',
#               'P2353',
#               'P1571',
#               'P972',
#               'P5277',
#               'P688',
#               'P1898',
#               'P523',
#               'P1592',
#               'P5051',
#               'P200',
#               'P1924',
#               'P852',
#               'P703',
#               'P4614',
#               'P2308',
#               'P9073',
#               'P2673',
#               'P1706',
#               'P1318',
#               'P2551',
#               'P2578',
#               'P812',
#               'P4584',
#               'P1456',
#               'P4446',
#               'P1532',
#               'P65',
#               'P1809',
#               'P522',
#               'P344',
#               'P500',
#               'P407',
#               'P1981',
#               'P489',
#               'P2396',
#               'P1454',
#               'P467',
#               'P375',
#               'P2363',
#               'P1372',
#               'P2851',
#               'P7137',
#               'P264',
#               'P1312',
#               'P5102',
#               'P8625',
#               'P2098',
#               'P736',
#               'P2820',
#               'P9071',
#               'P770',
#               'P1393',
#               'P1170',
#               'P2821',
#               'P531',
#               'P6338',
#               'P4743',
#               'P1313',
#               'P1026',
#               'P7261',
#               'P6149',
#               'P5023',
#               'P3161',
#               'P78',
#               'P3306',
#               'P8791',
#               'P1194',
#               'P783',
#               'P658',
#               'P991',
#               'P2238',
#               'P2674',
#               'P8324',
#               'P2701',
#               'P1780',
#               'P1340',
#               'P1302',
#               'P6216',
#               'P928',
#               'P5753',
#               'P1876',
#               'P3816',
#               'P2378',
#               'P2848',
#               'P608',
#               'P7374',
#               'P414',
#               'P518',
#               'P3716',
#               'P5537',
#               'P7767',
#               'P412',
#               'P289',
#               'P707',
#               'P505',
#               'P369',
#               'P6365',
#               'P1001',
#               'P6886',
#               'P1221',
#               'P1002',
#               'P1574',
#               'P1387',
#               'P4149',
#               'P91',
#               'P30',
#               'P2515',
#               'P2647',
#               'P611',
#               'P2541',
#               'P1754',
#               'P3294',
#               'P54',
#               'P479',
#               'P6885',
#               'P1533',
#               'P417',
#               'P837',
#               'P110',
#               'P541',
#               'P588',
#               'P1576',
#               'P609',
#               'P1558',
#               'P931',
#               'P543',
#               'P504',
#               'P511',
#               'P4908',
#               'P1199',
#               'P6166',
#               'P193',
#               'P1917',
#               'P1906',
#               'P945',
#               'P408',
#               'P5185',
#               'P4647',
#               'P1399',
#               'P114',
#               'P5913',
#               'P512',
#               'P4220',
#               'P2501',
#               'P735',
#               'P126',
#               'P1408',
#               'P5137',
#               'P5009',
#               'P533',
#               'P306',
#               'P2291',
#               'P1912',
#               'P1383',
#               'P21',
#               'P682',
#               'P5817',
#               'P5059',
#               'P3005',
#               'P655',
#               'P8196',
#               'P2784',
#               'P912',
#               'P3156',
#               'P3967',
#               'P6978',
#               'P1192',
#               'P8031',
#               'P3876',
#               'P4379',
#               'P2360',
#               'P2839',
#               'P7084',
#               'P57',
#               'P7604',
#               'P2922',
#               'P880',
#               'P2408',
#               'P560',
#               'P6241',
#               'P2846',
#               'P1596',
#               'P2756',
#               'P4387',
#               'P6106',
#               'P4132',
#               'P1027',
#               'P785',
#               'P5805',
#               'P941',
#               'P1877',
#               'P4969',
#               'P6237',
#               'P92',
#               'P520',
#               'P5028',
#               'P925',
#               'P205',
#               'P8111',
#               'P943',
#               'P8744',
#               'P1028',
#               'P8225',
#               'P3452',
#               'P447',
#               'P7086',
#               'P6224',
#               'P2596',
#               'P468',
#               'P1478',
#               'P1018',
#               'P485',
#               'P2507',
#               'P2912',
#               'P3301',
#               'P1568',
#               'P1914',
#               'P2964',
#               'P916',
#               'P97',
#               'P1136',
#               'P16',
#               'P1622',
#               'P1897',
#               'P4661',
#               'P1202',
#               'P437',
#               'P1171',
#               'P1853',
#               'P3148',
#               'P6153',
#               'P5642',
#               'P1406',
#               'P4878',
#               'P5658',
#               'P811',
#               'P19',
#               'P501',
#               'P8258',
#               'P5133',
#               'P3091',
#               'P3440',
#               'P1429',
#               'P3938',
#               'P6087',
#               'P3871',
#               'P1591',
#               'P2377',
#               'P642',
#               'P2321',
#               'P6195',
#               'P2414',
#               'P4000',
#               'P3858',
#               'P2852',
#               'P702',
#               'P2831',
#               'P2279',
#               'P3096',
#               'P1321',
#               'P545',
#               'P4151',
#               'P725',
#               'P397',
#               'P459',
#               'P1299',
#               'P3989',
#               'P7959',
#               'P462',
#               'P2976',
#               'P128',
#               'P6540',
#               'P3261',
#               'P5314',
#               'P241',
#               'P1791',
#               'P1064',
#               'P1891',
#               'P2842',
#               'P3174',
#               'P734',
#               'P2429',
#               'P421',
#               'P6587',
#               'P548',
#               'P3264',
#               'P2739',
#               'P2302',
#               'P410',
#               'P1640',
#               'P1046',
#               'P942',
#               'P5070',
#               'P2989',
#               'P2684',
#               'P1445',
#               'P7078',
#               'P1672',
#               'P3438',
#               'P826',
#               'P1652',
#               'P4224',
#               'P1151',
#               'P3262',
#               'P376',
#               'P5026',
#               'P634',
#               'P3150',
#               'P7936',
#               'P1740',
#               'P5138',
#               'P9353',
#               'P2389',
#               'P2288',
#               'P101',
#               'P562',
#               'P1589',
#               'P5323',
#               'P7763',
#               'P924',
#               'P3022',
#               'P1595',
#               'P1196',
#               'P2033',
#               'P3095',
#               'P2376',
#               'P102',
#               'P1880',
#               'P1536',
#               'P5056',
#               'P1479',
#               'P694',
#               'P870',
#               'P3450',
#               'P3966',
#               'P8371',
#               'P1950',
#               'P199',
#               'P669',
#               'P780',
#               'P1464',
#               'P209',
#               'P3263',
#               'P1349',
#               'P8411',
#               'P7501',
#               'P748',
#               'P3931',
#               'P8693',
#               'P1029',
#               'P3679',
#               'P1283',
#               'P1531',
#               'P2388',
#               'P3902',
#               'P172',
#               'P872',
#               'P4967',
#               'P4884',
#               'P5196',
#               'P552',
#               'P1347',
#               'P1753',
#               'P7779',
#               'P6193',
#               'P5589',
#               'P5109',
#               'P5707',
#               'P196',
#               'P624',
#               'P789',
#               'P832',
#               'P2868',
#               'P194',
#               'P470',
#               'P105',
#               'P9419',
#               'P914',
#               'P1594',
#               'P2643',
#               'P2975',
#               'P7075',
#               'P5021',
#               'P248',
#               'P143',
#               'P887',
#               'P4792',
#               'P1074',
#               'P1073',
#               'P607',
#               'P553',
#               'P1593',
#               'P4791',
#               'P1303',
#               'P210',
#               'P1433',
#               'P1582',
#               'P937',
#               'P610',
#               'P208',
#               'P8670',
#               'P398',
#               'P790',
#               'P3831',
#               'P8929',
#               'P2445',
#               'P853',
#               'P1779',
#               'P86',
#               'P1200',
#               'P5769',
#               'P2770'],
#              'ru': ['основной источник питания',
#               'рабочий список проекта Викимедиа',
#               'основополагающий текст',
#               'порт приписки',
#               'место создания',
#               'получатель',
#               'экорегион WWF',
#               'форма правления',
#               'сценарист',
#               'соответствующий элемент для свойства',
#               'тип единиц этого свойства',
#               'окраска по Граму',
#               'получено из организма типа',
#               'бренд',
#               'категория для людей, умерших здесь',
#               'родной мир',
#               'эмулирует',
#               'микроархитектура',
#               'причёска',
#               'игровой художник',
#               'охранный статус МСОП',
#               'не вызывает',
#               'инвестор',
#               'художник-постановщик',
#               'предки из',
#               'тип электрического разъёма',
#               'обычно продаёт',
#               'художник раскадровки',
#               'ассоциированный избирательный округ',
#               'тип грибной ножки',
#               'род занятий',
#               'способ введения',
#               'гимн',
#               'возраст манифестации',
#               'список серий',
#               'инженер-строитель',
#               'место посадки',
#               'сценограф',
#               'родной язык',
#               'рейтинг PEGI',
#               'официальный язык',
#               'статус наследия',
#               'поражает',
#               'пример использования свойства',
#               'критерий Всемирного наследия',
#               'денежная единица',
#               'является эндемиком в',
#               'категория для фильмов на этом языке',
#               'описание флага',
#               'художник-визажист',
#               'девиз правления',
#               'обеспечение качества ПО',
#               'рассказчик',
#               'письменность',
#               'место публикации',
#               'защитник авторских прав',
#               'место смерти',
#               'утверждение поддерживает',
#               'адаптирован',
#               'история темы',
#               'статус канонизации',
#               'летал на',
#               'список произведений',
#               'художник-мультипликатор',
#               'фреймворк GUI',
#               'цель проекта или миссии',
#               'эпитет',
#               'онлайн-сервис',
#               'блок Юникода',
#               'выбывшие',
#               'модель',
#               'статус ограничения доступа',
#               'содержащиеся виды',
#               'жанр',
#               'отрасль',
#               'орган по стандартизации',
#               'первоначальный вещатель',
#               'категория для видов элемента',
#               'нарративная роль',
#               'фундаментальные взаимодействия',
#               'форма искусства',
#               'цвет волос',
#               'находится в охранной зоне',
#               'за работу',
#               'уточнение даты',
#               'генеральный секретарь',
#               'состояние здоровья',
#               'артериальное кровоснабжение',
#               'религия',
#               'категория защищённых зон МСОП',
#               'созвездие',
#               'разгонный блок',
#               'описывает вымышленный мир',
#               'приходская церковь',
#               'газетный формат',
#               'команда-участница',
#               'категория карт на Викискладе',
#               'категория для видов с данного объекта',
#               'система электрификации',
#               'описание девиза',
#               'категория для людей, связанных с местностью',
#               'архитектурный стиль',
#               'оригинальный формат фильма',
#               'причина смерти',
#               'область святого или божества',
#               'драматург',
#               'физическая величина',
#               'используемый критерий',
#               'ориентация',
#               'дополнение относится к',
#               'категория Викисклада для интерьера элемента',
#               'речной рукав',
#               'соответствующая квалификация',
#               'молекулярная функция',
#               'глава государства',
#               'выбран по результатам',
#               'движитель',
#               'политическая идеология',
#               'выпускной класс',
#               'медиафраншиза',
#               'протокол',
#               'цвет цветков',
#               'шахматный титул',
#               'вид передней подвески',
#               'скорректирован',
#               'выступающий',
#               'парламентская группа',
#               'страна происхождения',
#               'продукция',
#               'общая тема категории',
#               'эра',
#               'кандидат на выборах',
#               'тарифная зона',
#               'система управления пакетами',
#               'каллиграф',
#               'языки, на которых говорит или пишет персона',
#               'рейтинг фильма RTC',
#               'язык программирования',
#               'должность занимает',
#               'распространяется',
#               'играет роль персонажа',
#               'место действия',
#               'перевозимый груз',
#               'остановка общественного транспорта',
#               'язык оригинала фильма или телешоу',
#               'заказчик произведения',
#               'член съёмочной команды',
#               'номенклатурный тип',
#               'содержит фонему',
#               'основная тема шаблона',
#               'исключая',
#               'словолитня',
#               'медицинская специальность',
#               'формат радио',
#               'основная тема портала Викимедиа',
#               'направление относительно места',
#               'утверждение оспаривается',
#               'пункт назначения',
#               'имеет вершинную фигуру',
#               'школьный округ',
#               'содержит',
#               'технические средства защиты авторских прав',
#               'разлом',
#               'выступает в лиге',
#               'география темы',
#               'известная работа',
#               'является последователем',
#               'является носителем патогена',
#               'действительно для периода',
#               'соцветие',
#               'гражданство',
#               'хостинг',
#               'автор предисловия',
#               'обозначение',
#               'побочный эффект',
#               'позиция в команде',
#               'конечный результат',
#               'метод изготовления',
#               'волосы на лице',
#               'способствует',
#               'относится к вики-проекту',
#               'читаемый формат файла',
#               'иероглиф в этой лексеме',
#               'эпоха',
#               'топливная система',
#               'категория для сотрудников организации',
#               'водоём на реке',
#               'кем официально открыт',
#               'возрастной рейтинг произведения в РФ',
#               'официальное приложение',
#               'в ответ на',
#               'лицензия',
#               'автор либретто',
#               'расположение распределительного вала',
#               'кем забиты голы или набраны очки',
#               'избирательный округ',
#               'астрономический фильтр',
#               'дискография',
#               'архитектор',
#               'поддерживает язык программирования',
#               'шаблон для свойства',
#               'родитель',
#               'производит звук',
#               'несёт на себе',
#               'хромосома',
#               'автор послесловия',
#               'кабинет',
#               'из вымышленного мира',
#               'кто представляет',
#               'школа (движение)',
#               'нагнетатель',
#               'повторение гена связано с',
#               'коморбидность',
#               'источник энергии',
#               'медицинский осмотр',
#               'шина',
#               'место содержания под стражей',
#               'разъём',
#               'включая',
#               'ближайший таксон уровнем выше',
#               'наполняет категорию',
#               'зависит от',
#               'радикал',
#               'жертва',
#               'производящая компания',
#               'имеет форму',
#               'отозвано в',
#               'спортивная дисциплина',
#               'надето',
#               'постоянный резидент',
#               'епархия',
#               'точки Лагранжа',
#               'учебное заведение',
#               'место обнаружения',
#               'кодекс номенклатуры',
#               'через',
#               'вычисляется из',
#               'срок полномочий парламента',
#               'рейтинг Американской киноассоциации',
#               'платформа',
#               'кто номинировал',
#               'драконический период',
#               'компонент клетки',
#               'сфера деятельности',
#               'соотношение сторон',
#               'официальный цвет',
#               'главный операционный директор',
#               'конец временного диапазона',
#               'божество относится к',
#               'родительский спортивный клуб',
#               'список персонажей',
#               'венозный отток',
#               'применяется для лечения',
#               'способ передвижения',
#               'описание печати/эмблемы',
#               'имеет перепись населения',
#               'мазхаб',
#               'показатель вулканической эксплозивности',
#               'статистическая единица',
#               'кодомен',
#               'каталог',
#               'степень кандзи',
#               'кодирует',
#               'низшая нота',
#               'начало временного диапазона',
#               'обвинитель',
#               'по направлению к',
#               'впадающие в озеро реки',
#               'является вакциной против',
#               'рейтинг ESRB',
#               'имеется у таксона',
#               'водосборный бассейн',
#               'класс',
#               'применимое значение для «утверждается в»',
#               'следующая переправа выше по течению',
#               'совместно с',
#               'кем доказано',
#               'использованный метр',
#               'предмет изучения',
#               'специальность',
#               'первое появление',
#               'список памятников',
#               'программа вознаграждения',
#               'представляет страну в спорте',
#               'место астрономического открытия',
#               'хореограф',
#               'тип орбиты',
#               'кинооператор',
#               'эксклав от',
#               'язык произведения или названия',
#               'рейтинг фильма FSK',
#               'описание символа валюты',
#               'множество значений',
#               'организационно-правовая форма',
#               'принят законодателем',
#               'ракета-носитель',
#               'рейтинг фильма NMHH',
#               'связка для программной библиотеки',
#               'допустимые виды оплаты',
#               'благодарности',
#               'лейбл звукозаписи',
#               'грань политопа',
#               'природа утверждения',
#               'библиография',
#               'заместитель',
#               'художник обложки',
#               'мощность множества',
#               'тип персонажа',
#               'причина разрушения',
#               'представитель',
#               'тип передаваемого сигнала',
#               'побочный продукт',
#               'дипломатическая миссия',
#               'колорист',
#               'порода животных',
#               'должность главы правительства',
#               'диссертация',
#               'статус ограничения использования',
#               'кандидат в вице-президенты или в вице-губернаторы',
#               'правила поведения в этом месте',
#               'имеет наклонения',
#               'интернет-домен верхнего уровня',
#               'рейтинг ICAA',
#               'оцифровано',
#               'принятый сигнал',
#               'тип гимения',
#               'композиции',
#               'победивший кандидат',
#               'официальный символ',
#               'следующая переправа ниже по течению',
#               'заказчик',
#               'формат файла',
#               'принадлежит школе',
#               'цвет глаз',
#               'основные направления',
#               'статус авторского права',
#               'активирующий нейромедиатор',
#               'идеографическое описание последовательности',
#               'транспортное средство',
#               'киносценарий',
#               'кем выдан',
#               'Wi-Fi',
#               'история выставок',
#               'уровень образования',
#               'биржа',
#               'указано для части',
#               'социальный класс',
#               'хангыль китайского иероглифа',
#               'температура подачи',
#               'певческий голос',
#               'тип судна',
#               'платформа космического аппарата',
#               'генеральный менеджер',
#               'тестовое свойство с типом Элемент',
#               'категория членов',
#               'юрисдикция распространяется на',
#               'язык письменных произведений',
#               'вид компрессора',
#               'конфигурация двигателя',
#               'является экземпляром',
#               'позиция в политическом спектре',
#               'сопряженное основание',
#               'сексуальная ориентация',
#               'часть света',
#               'дизайнер костюмов',
#               'источник материала',
#               'монашеский орден',
#               'зона обслуживания',
#               'относящаяся к списку категория',
#               'кодировка',
#               'член спортивной команды',
#               'способ ввода',
#               'исторический регион',
#               'фамилия с идентичным написанием',
#               'святой покровитель',
#               'день в году',
#               'иллюстратор',
#               'это выборы на должность',
#               'охладитель',
#               'образ жизни',
#               'расположение конечной точки',
#               'музыкальный темп',
#               'обслуживаемый город',
#               'кто давал клятву',
#               'основной порт',
#               'префикс титула',
#               'сезон',
#               'тип наследования',
#               'цитирует работу',
#               'основная строительная организация',
#               'посттрансляционная модификация связана с',
#               'должность главы государства',
#               'принадлежность',
#               'движок',
#               'грамматический род',
#               'место первого исполнения',
#               'осуждён за',
#               'авиационный альянс',
#               'имеет класс словоизменения',
#               'учёная степень',
#               'порядок битвы',
#               'результаты',
#               'личное имя',
#               'ответственность несёт',
#               'лицензия на вещание в',
#               'элемент для смысла',
#               'соответствует норме',
#               'цель',
#               'операционная система',
#               'занял место в',
#               'удаление связано с',
#               'включает населённый пункт',
#               'пол или гендер',
#               'биологический процесс',
#               'состояние использования',
#               'модифицированная версия от',
#               'истинно для места',
#               'переводчик',
#               'избирательная система',
#               'баллов по шкале Меркалли',
#               'оборудован',
#               'австралийская классификация',
#               'финальная часть',
#               'скандинавское среднее имя',
#               'обслуживается маршрутом',
#               'преступник',
#               'категория для выпускников образовательного учреждения',
#               'молодёжное крыло',
#               'целевая аудитория',
#               'походка',
#               'связанная категория',
#               'режиссёр',
#               'надзор осуществляет',
#               'месяц',
#               'центральный процессор',
#               'действие происходит в эпоху',
#               'направление',
#               'создатель коллекции',
#               'доступность для  кресел-каталок',
#               'наказание',
#               'рейтинг фильма EIRIN',
#               'метод обновления',
#               'использует заглавные буквы для',
#               'языковая типология',
#               'награда от',
#               'тип прикрепления гимения',
#               'Уровень по модели OSI',
#               'вдохновлено',
#               'в результате влияния работы',
#               'производная работа',
#               'застройщик',
#               'главный регулирующий текст',
#               'вооружение',
#               'звукорежиссёр',
#               'пресинаптическая связь',
#               'бассейн объекта в странах',
#               'рекомендуемая единица измерения',
#               'программист',
#               'экономика темы',
#               'подарок от',
#               'метакласс для',
#               'вывод из',
#               'оценка от',
#               'начальный класс',
#               'уровень описания',
#               'культура',
#               'ранг дан/кю',
#               'непосредственной причиной является',
#               'регулятор языка',
#               'архивы хранятся в',
#               'публикация со списком ошибок и неточностей',
#               'отличительный знак лидера',
#               'транслируется на',
#               'область определения',
#               'генная вставка связана с',
#               'право голоса',
#               'рейтинг GSRR',
#               'титул',
#               'кем решена',
#               'система автомагистралей',
#               'сторона автомобильного движения',
#               'верхняя нота',
#               'дамбовое водохранилище',
#               'несёт научное оборудование',
#               'распространение произведения',
#               'аппроксимационный алгоритм',
#               'группа крови',
#               'отменяет',
#               'место проведения исследования',
#               'фактор риска',
#               'направление письма',
#               'символизирует',
#               'сторона железнодорожного движения',
#               'второстепенный общеобразовательный предмет',
#               'место рождения',
#               'анклав в',
#               'область обучения',
#               'имеет оценку',
#               'верховое животное',
#               'размер такта',
#               'питомец',
#               'кем названо',
#               'тренер спортивной команды',
#               'сторона притока',
#               'обвиняемый',
#               'используемый хук MediaWiki',
#               'относится к',
#               'генеральная классификация',
#               'схема финансирования',
#               'сырьё для',
#               'имеет плод типа',
#               'маршрутная карта',
#               'номер телефона экстренной службы',
#               'кодирующий ген',
#               'тотем',
#               'амбитус',
#               'файл KML',
#               'место происхождения (Швейцария)',
#               'кем зажжён факел',
#               'игровая механика',
#               'актёр озвучивания',
#               'родительское тело',
#               'метод определения',
#               'изображается на',
#               'род деятельности членов',
#               'историческое графство',
#               'цвет',
#               'патроним или матроним для имени',
#               'регулирует (молекулярная биология)',
#               'многоканальная сеть',
#               'анатомически ответвляется от',
#               'используется как',
#               'вид или род войск',
#               'категория для людей, похороненных здесь',
#               'ширина колеи',
#               'подписавшийся',
#               'место свадьбы',
#               'арт-директор',
#               'фамилия',
#               'ожидаемая полнота',
#               'часовой пояс',
#               'система спортивных лиг',
#               'тип версии',
#               'основание системы счисления',
#               'гарнитура',
#               'ограничение свойства',
#               'воинское звание',
#               'куратор',
#               'метод обнаружения',
#               'музыкальная тема',
#               'французский стандартный размер для картин маслом',
#               'имеет падежи',
#               'рейтинг Kijkwijzer',
#               'вымышленная вселенная описана в',
#               'типизация данных',
#               'этот таксон является источником',
#               'обычно используемое транспортное средство',
#               'тональность',
#               'рефери',
#               'категория содержит',
#               'портал Викимедиа',
#               'анатомически ветвится на',
#               'на астрономическом теле',
#               'художник-осветитель',
#               'капитан',
#               'день рождения',
#               'бизнес-модель',
#               'категория фильмов, снятых в этом месте',
#               'сезон клуба или команды',
#               'не имеет причиной',
#               'управляемая организация',
#               'лимфодренаж',
#               'область деятельности',
#               'эмитент',
#               'глубочайшая точка',
#               'подтверждено в',
#               'статус авторского права как автора',
#               'лечение',
#               'флагоносец',
#               'предъявленное обвинение',
#               'род смерти',
#               'категория для фотографий, снятых камерой',
#               'практикуется',
#               'суперсимметричный партнёр для',
#               'член политической партии',
#               'шкала измерения',
#               'является непосредственной причиной',
#               'патроним или матроним для человека',
#               'способствовавшим фактором является',
#               'заменяемый синоним',
#               'инструментовка',
#               'розыгрыш какого турнира',
#               'парадигма программирования',
#               'упоминает произведение, традицию или теорию',
#               'вторая фамилия в испанском имени',
#               'бизнес-подразделения',
#               'расположен на улице',
#               'симптомы',
#               'категория для людей, родившихся здесь',
#               'высший судебный орган',
#               'основание фигуры',
#               'плоидия',
#               'происходит в типе места',
#               'аудио-система',
#               'кем назначен',
#               'владелец авторских прав',
#               'фэндом',
#               'члены экипажа',
#               'фондовый индекс',
#               'фильмография',
#               'родительские таксоны гибрида',
#               'должность руководителя организации',
#               'последняя трапеза',
#               'этническая группа',
#               'отпечатано',
#               'предпосылка',
#               'суд',
#               'способ вывода',
#               'рабочая рука',
#               'военная классификация потерь',
#               'относящийся к категории список',
#               'состоит в воинском формировании',
#               'ратифицирован(о/а)',
#               'микроструктура',
#               'имеет грамматический род',
#               'образец',
#               'группа малых планет',
#               'тип системы наведения',
#               'съедобность',
#               'официальный праздник',
#               'в качестве',
#               'законодательный орган',
#               'реестр Восьми знамён',
#               'таксономический ранг',
#               'личная библиотека хранится в',
#               'рейтинг USK',
#               'судья',
#               'классификация Карнеги для вуза',
#               'носитель',
#               'мод для',
#               'оценивался тест',
#               'утверждается в',
#               'импортировано из проекта Викимедиа',
#               'на основе эвристики',
#               'плотина',
#               'аналог в реальном мире',
#               'может создавать файлы формата',
#               'война/сражение',
#               'учётная запись в социальных медиа',
#               'защитник',
#               'командир',
#               'музыкальный инструмент',
#               'секретарь партии',
#               'опубликовано в',
#               'производится из',
#               'место активности',
#               'наивысшая точка',
#               'исполнительная власть',
#               'дизайнер персонажей',
#               'тело-спутник',
#               'получил одобрение от',
#               'значение выступает в роли',
#               'отношение к религии, взгляд на мир',
#               'метаподкласс от',
#               'рейтинг CERO',
#               'возможный создатель',
#               'композитор',
#               'категория бассейна',
#               'шеф-редактор',
#               'источник дохода'],
#              'zh': ['主要食物來源',
#               'main food source',
#               '维基媒体项目关注列表',
#               'on focus list of Wikimedia project',
#               '成立文书',
#               'foundational text',
#               '船籍港',
#               'port of registry',
#               '成立地點',
#               'location of formation',
#               '收件人',
#               'addressee',
#               '生态区（世界自然基金会）',
#               'ecoregion (WWF)',
#               '政体',
#               'basic form of government',
#               '編劇',
#               'screenwriter',
#               '属性的维基数据项目',
#               'Wikidata item of this property',
#               '用于此属性的单位类型',
#               'type of unit for this property',
#               '革蘭氏染色',
#               'Gram staining',
#               '从这个物种的组织内分离',
#               'derived from organism type',
#               '品牌',
#               'brand',
#               '死亡地分类',
#               'category for people who died here',
#               '來源星球',
#               'home world',
#               '模拟',
#               'emulates',
#               '微架構',
#               'microarchitecture',
#               '发型',
#               'hairstyle',
#               '游戏艺术家',
#               'game artist',
#               'IUCN保護現狀',
#               'IUCN conservation status',
#               '没有效果',
#               'does not have effect',
#               '投資者',
#               'investor',
#               '美術指導',
#               'production designer',
#               '籍贯',
#               'ancestral home',
#               '電源插頭型式',
#               'electrical plug type',
#               '销售商品',
#               'typically sells',
#               '分镜师',
#               'storyboard artist',
#               '所属选区',
#               'associated electoral district',
#               '菌柄',
#               'stipe character',
#               '职业',
#               'occupation',
#               '给药途径',
#               'route of administration',
#               '颂歌',
#               'anthem',
#               '发病年龄',
#               'age of onset',
#               '剧集列表',
#               'list of episodes',
#               '結構工程師',
#               'structural engineer',
#               '降落地點',
#               'location of landing',
#               '舞台设计师',
#               'scenographer',
#               '母语',
#               'native language',
#               'PEGI评级',
#               'PEGI rating',
#               '官方语言',
#               'official language',
#               '遗产名称',
#               'heritage designation',
#               '影响',
#               'afflicts',
#               '维基数据属性示例',
#               'Wikidata property example',
#               '世界遺產基準',
#               'World Heritage criteria',
#               '货币',
#               'currency',
#               '特有分布',
#               'endemic to',
#               '用于此语言电影的分类',
#               'category for films in this language',
#               '旗帜',
#               'flag',
#               '化妝師',
#               'make-up artist',
#               '年号',
#               'era name',
#               '软件质量管理',
#               'software quality assurance',
#               '敘事者',
#               'narrator',
#               '書寫系統',
#               'writing system',
#               '出版地',
#               'place of publication',
#               '版權代表人',
#               'copyright representative',
#               '死亡地',
#               'place of death',
#               '主张此叙述者',
#               'statement supported by',
#               '改編者',
#               'adapted by',
#               '話題历史',
#               'history of topic',
#               '冊封狀態',
#               'canonization status',
#               '航天任务',
#               'astronaut mission',
#               '作品列表',
#               'list of works',
#               '动画师',
#               'animator',
#               '圖像化使用者介面工具箱或框架',
#               'GUI toolkit or framework',
#               '計畫目標',
#               'objective of project or action',
#               '修飾詞',
#               'epithet',
#               '线上服务',
#               'online service',
#               'Unicode区块',
#               'Unicode block',
#               '降级',
#               'relegated',
#               '模特',
#               'sitter',
#               '访问限制状态',
#               'access restriction status',
#               '饲养品种',
#               'species kept',
#               '類型',
#               'genre',
#               '产业',
#               'industry',
#               '標準組織',
#               'standards body',
#               '首播电视台',
#               'original broadcaster',
#               '項目景觀的分類',
#               'category for the view of the item',
#               '故事角色',
#               'narrative role',
#               '相互作用',
#               'interaction',
#               '作品形式',
#               'form of creative work',
#               '髮色',
#               'hair color',
#               '所在保护区',
#               'located in protected area',
#               '得獎作品',
#               'for work',
#               '确切时间',
#               'refine date',
#               '总书记',
#               'secretary general',
#               '医疗状况',
#               'medical condition',
#               '动脉供应',
#               'arterial supply',
#               '信仰',
#               'religion or world view',
#               'IUCN保护区分类',
#               'IUCN protected areas category',
#               '星座',
#               'constellation',
#               '太空交通船',
#               'space tug',
#               '发生在虚构的宇宙中',
#               'takes place in fictional universe',
#               '堂區教堂',
#               'parish church',
#               '报纸版式',
#               'newspaper format',
#               '參與隊伍',
#               'participating team',
#               '地图分类',
#               'category for maps',
#               '從項目所看到的景觀之分類',
#               'category for the view from the item',
#               '电气化方式',
#               'type of electrification',
#               '座右铭',
#               'motto',
#               '相关人物分类',
#               'category of associated people',
#               '建築風格',
#               'architectural style',
#               '原始底片格式',
#               'original film format',
#               '死因',
#               'cause of death',
#               '保佑領域',
#               'domain of saint or deity',
#               '剧作者',
#               'dramaturge',
#               '以此物理量测量',
#               'measured physical quantity',
#               '所用標準',
#               'criterion used',
#               '方向/面向',
#               'orientation',
#               '资料片',
#               'expansion of',
#               '用於某項內部的共享資源分類',
#               'category for the interior of the item',
#               '分流',
#               'distributary',
#               '相關資格',
#               'relevant qualification',
#               '分子功能',
#               'molecular function',
#               '国家元首',
#               'head of state',
#               '當選選舉',
#               'elected in',
#               '发动机',
#               'powered by',
#               '政治意识形态',
#               'political ideology',
#               '結束年級',
#               'end grade',
#               '跨媒體製作',
#               'media franchise',
#               '协议',
#               'protocol',
#               '花色',
#               'flower color',
#               '棋士称号',
#               'title of chess person',
#               '前懸吊系統',
#               'type of front suspension',
#               '取代者',
#               'repealed by',
#               '演讲者',
#               'speaker',
#               '黨團',
#               'parliamentary group',
#               '原產地',
#               'country of origin',
#               '产品',
#               'product or material produced',
#               '分類主話題',
#               "category's main topic",
#               '時間週期',
#               'time period',
#               '競選',
#               'candidacy in election',
#               '收費區',
#               'fare zone',
#               '软件包管理系统',
#               'package management system',
#               '書法家',
#               'calligrapher',
#               '口头、书写或手语语言',
#               'languages spoken, written or signed',
#               '廣播，電視和電影電影評級',
#               'RTC film rating',
#               '编程语言',
#               'programming language',
#               '公职人员',
#               'officeholder',
#               '經銷商',
#               'distributed by',
#               '人物角色',
#               'character role',
#               '敘事發生地',
#               'narrative location',
#               '载运人员或货物',
#               'people or cargo transported',
#               '車站',
#               'public transport stop',
#               '影視作品原始語言',
#               'original language of film or TV show',
#               '委托人',
#               'commissioned by',
#               '电影摄制组成员',
#               'film crew member',
#               '模式分类',
#               'taxonomic type',
#               '具有音位',
#               'has phoneme',
#               '模板主话题',
# ...
#               '总线',
#               'bus',
#               '羁押地点',
#               'place of detention',
#               '連接器',
#               'connector',
#               '包括',
#               'including',
#               '父分类群',
#               'parent taxon',
#               '模板填充分类',
#               'template populates category',
#               '依賴軟件',
#               'depends on software',
#               '部首',
#               'radical',
#               '受害人',
#               'victim',
#               '製作商',
#               'production company',
#               '形状',
#               'shape',
#               '撤銷',
#               'is retracted by',
#               '参加的体育比赛项目',
#               'sports discipline competed in',
#               '穿着',
#               'wears',
#               '永久居留权',
#               'permanent resident of',
#               '教區',
#               'diocese',
#               '拉格朗日點',
#               'Lagrangian point',
#               '就读于',
#               'educated at',
#               '发现地点',
#               'location of discovery',
#               '命名法规',
#               'Code of nomenclature',
#               '途经',
#               'via',
#               '计算方法',
#               'calculated from',
#               '议会任期',
#               'parliamentary term',
#               '美國電影協會電影評級',
#               'MPAA film rating',
#               '平台',
#               'platform',
#               '提名者',
#               'nominated by',
#               '沙羅周期',
#               'Saros cycle of eclipse',
#               '细胞组件',
#               'cell component',
#               '专业领域',
#               'field of this occupation',
#               '长宽比',
#               'aspect ratio (W:H)',
#               '官方颜色',
#               'official color',
#               '首席运营官',
#               'chief operating officer',
#               '灭绝地质年代',
#               'temporal range end',
#               '受其崇拜',
#               'worshipped by',
#               '附属俱乐部',
#               'parent club',
#               '角色列表',
#               'list of characters',
#               '静脉引流',
#               'venous drainage',
#               '用于治疗',
#               'medical condition treated',
#               '移动方式',
#               'means of locomotion',
#               '印章描述',
#               'has seal, badge, or sigil',
#               '人口普查',
#               'has census',
#               '麦兹海布',
#               'madhhab',
#               '火山爆发指数',
#               'volcanic explosivity index',
#               '統計單位',
#               'statistical unit',
#               '到达域',
#               'codomain',
#               '目录',
#               'catalog',
#               '日本汉字等级',
#               'grade of kanji',
#               '生物编码',
#               'encodes',
#               '最低音',
#               'lowest note',
#               '初现地质年代',
#               'temporal range start',
#               '檢察官',
#               'prosecutor',
#               '行車方向',
#               'towards',
#               '流入源',
#               'inflows',
#               '疫苗用於',
#               'vaccine for',
#               'ESRB评级',
#               'ESRB rating',
#               '具此物質之物種/此物質可作用之物種',
#               'found in taxon',
#               '集水區',
#               'drainage basin',
#               '类',
#               'class',
#               '適用的「載於」值',
#               "applicable 'stated in' value",
#               '下一个上游跨越点',
#               'next crossing upstream',
#               '连同',
#               'together with',
#               '证明者',
#               'proved by',
#               '格律',
#               'used metre',
#               '研究對象',
#               'studies',
#               '高校专业',
#               'academic major',
#               '首次亮相于',
#               'first appearance',
#               '古迹列表',
#               'list of monuments',
#               '忠诚计划',
#               'reward program',
#               '体育代表国',
#               'country for sport',
#               '天文发现地',
#               'site of astronomical discovery',
#               '编舞',
#               'choreographer',
#               '轨道类型',
#               'type of orbit',
#               '摄影指导',
#               'director of photography',
#               '飞地从属于',
#               'exclave of',
#               '作品或名稱的語言',
#               'language of work or name',
#               'FSK電影評級',
#               'FSK film rating',
#               '货币符号',
#               'currency symbol description',
#               '值域',
#               'image of function',
#               '法律形式',
#               'legal form',
#               '立法者',
#               'legislated by',
#               '发射载具',
#               'space launch vehicle',
#               'NMHH電影評級',
#               'NMHH film rating',
#               '軟體庫內之資料繫結',
#               'binding of software library',
#               '接受的付款方式',
#               'payment types accepted',
#               '致谢',
#               'acknowledged',
#               '唱片公司',
#               'record label',
#               '維面',
#               'has facet polytope',
#               '陳述環境',
#               'nature of statement',
#               '文献资料',
#               'bibliography',
#               '副職',
#               'substitute/deputy/replacement of office/officeholder',
#               '封面艺术家',
#               'cover art by',
#               '势',
#               'cardinality of this set',
#               '角色類型',
#               'character type',
#               '衰亡原因',
#               'cause of destruction',
#               '代理人',
#               'proxy',
#               '發送訊號',
#               'transmitted signal type',
#               '副产品',
#               'by-product',
#               '派駐代表機構',
#               'diplomatic mission sent',
#               '上色师',
#               'colorist',
#               '品種',
#               'animal breed',
#               '政府首脑职位',
#               'office held by head of government',
#               '學位論文',
#               'academic thesis',
#               '使用限制状态',
#               'use restriction status',
#               '競選搭檔',
#               'running mate',
#               '此地點的活動方針',
#               'activity policy in this place',
#               '具有语气',
#               'has grammatical mood',
#               '顶级域名',
#               'top-level Internet domain',
#               '電影和音像藝術學會分級',
#               'ICAA rating',
#               '電子化',
#               'digitised by',
#               '接收訊號',
#               'received signal type',
#               '子实层类型',
#               'hymenium type',
#               '曲目',
#               'tracklist',
#               '当选者',
#               'successful candidate',
#               '官方標記',
#               'official symbol',
#               '下一个下游跨越点',
#               'next crossing downstream',
#               '財務贊助者',
#               'funder',
#               '文件格式',
#               'file format',
#               '所属学派',
#               'school of',
#               '眼睛顏色',
#               'eye color',
#               '主要目的地',
#               'primary destinations',
#               '著作權狀態',
#               'copyright status',
#               '神经递质',
#               'activating neurotransmitter',
#               '表意组字序列',
#               'ideographic description sequences',
#               '载具',
#               'vehicle',
#               '剧本',
#               'film script',
#               '發行者',
#               'issued by',
#               '無線局域網',
#               'Wi-Fi access',
#               '展覽歷史',
#               'exhibition history',
#               '教育阶段',
#               'educational stage',
#               '证券交易所',
#               'stock exchange',
#               '適用部分',
#               'applies to part',
#               '社會階層',
#               'social classification',
#               '韓語漢字音',
#               'Hangul of a Chinese character',
#               '食物存放温度',
#               'serving temperature',
#               '聲部',
#               'voice type',
#               '艦級',
#               'vessel class',
#               '衛星平台',
#               'satellite bus',
#               '总经理',
#               'general manager',
#               '沙盒-项',
#               'Sandbox-Item',
#               '成员分类',
#               'member category',
#               '管辖区',
#               'applies to jurisdiction',
#               '书写语言',
#               'writing language',
#               '壓縮機類型',
#               'compressor type',
#               '引擎配置',
#               'engine configuration',
#               '原本包含',
#               'exemplar of',
#               '政治立場',
#               'political alignment',
#               '共轭碱',
#               'conjugate base',
#               '性取向',
#               'sexual orientation',
#               '大洲',
#               'continent',
#               '服裝設計',
#               'costume designer',
#               '材料来源',
#               'source of material',
#               '宗教團',
#               'religious order',
#               '業務區',
#               'operating area',
#               '列表相关分类',
#               'category related to list',
#               '编码',
#               'encoding',
#               '所屬運動隊',
#               'member of sports team',
#               '输入设备',
#               'input method',
#               '历史地区',
#               'historical region',
#               '相关姓氏',
#               'family name identical to this given name',
#               '主保圣人',
#               'patron saint',
#               '节日日期',
#               'day in year for periodic occurrence',
#               '插画家',
#               'illustrator',
#               '競逐之職位',
#               'office contested',
#               '冷却剂',
#               'coolant',
#               '生活方式',
#               'lifestyle',
#               '起止地点',
#               'terminus location',
#               '拍速标记',
#               'tempo marking',
#               '机场服务地区',
#               'place served by transport hub',
#               '宣誓者',
#               'oath made by',
#               '母港',
#               'home port',
#               '头衔',
#               'honorific prefix',
#               '電視劇季',
#               'season',
#               '遺傳模式',
#               'mode of inheritance',
#               '引用原文出处',
#               'quotes work',
#               '主要建筑承建商',
#               'main building contractor',
#               '翻译后修饰',
#               'posttranslational modification association with',
#               '國家元首職位',
#               'office held by head of state',
#               '效忠对象',
#               'allegiance',
#               '软件引擎',
#               'software engine',
#               '语法性',
#               'grammatical gender',
#               '首演地点',
#               'location of first performance',
#               '所犯罪名',
#               'convicted of',
#               '航空聯盟',
#               'airline alliance',
#               '词形变化',
#               'has inflection class',
#               '学位',
#               'academic degree',
#               '作戰序列',
#               'order of battle',
#               '賽果',
#               'results',
#               '名字',
#               'given name',
#               '维护者',
#               'maintained by',
#               '廣播地區',
#               'licensed to broadcast to',
#               '该义项的项目',
#               'item for this sense',
#               '符合標準',
#               'complies with',
#               '攻击目标',
#               'target',
#               '作業系統',
#               'operating system',
#               '上榜',
#               'charted in',
#               '基因删除导致',
#               'gene deletion association with',
#               '包含聚落',
#               'contains settlement',
#               '性別',
#               'sex or gender',
#               '生物途径',
#               'biological process',
#               '使用狀態',
#               'state of use',
#               '版本修改自',
#               'modified version of',
#               '有效地點',
#               'valid in place',
#               '译者',
#               'translator',
#               '投票制度',
#               'voting system',
#               '麥加利地震震度',
#               'Mercalli intensity scale',
#               '擁有設施',
#               'has facility',
#               'ACB评级',
#               'Australian Classification',
#               '决赛',
#               'final event',
#               '中间姓',
#               'Scandinavian middle family name',
#               '所屬路線',
#               'connecting service',
#               '加害人',
#               'perpetrator',
#               '教育機構校友專用分類',
#               'category for alumni of educational institution',
#               '青年翼',
#               'youth wing',
#               '受眾',
#               'intended public',
#               '儀態',
#               'gait',
#               '相关分类',
#               'related category',
#               '导演',
#               'director',
#               '監察人',
#               'supervised by',
#               '月份',
#               'month of the year',
#               '中央处理器',
#               'CPU',
#               '時代背景',
#               'set in period',
#               '方向',
#               'direction',
#               '建立者',
#               'collection creator',
#               '輪椅使用性',
#               'wheelchair accessibility',
#               '刑罰',
#               'penalty',
#               '映倫電影分級',
#               'EIRIN film rating',
#               '更新方法',
#               'update method',
#               '使用大写',
#               'uses capitalization for',
#               '语言类型学',
#               'linguistic typology',
#               '颁发者',
#               'conferred by',
#               '子囊附着物',
#               'hymenium attachment',
#               '开放式系统互联通信参考模型层',
#               'OSI Model layer location',
#               '启发自',
#               'inspired by',
#               '原著作者',
#               'after a work by',
#               '衍生作品',
#               'derivative work',
#               '地產發展商',
#               'real estate developer',
#               '主要規管文獻',
#               'main regulatory text',
#               '武器',
#               'armament',
#               '音效设计师',
#               'sound designer',
#               '突触',
#               'presynaptic connection',
#               '流域国',
#               'basin country',
#               '计量单位',
#               'recommended unit of measurement',
#               '程序员',
#               'programmer',
#               '話題的經濟',
#               'economy of topic',
#               '捐贈者',
#               'donated by',
#               '为其元类',
#               'is metaclass for',
#               '推断依据',
#               'inferred from',
#               '评分者',
#               'review score by',
#               '開始年級',
#               'start grade',
#               '著录级次',
#               'level of description',
#               '文化',
#               'culture',
#               '段位/级数',
#               'dan/kyu rank',
#               '直接原因',
#               'has immediate cause',
#               '語言管理機構',
#               'language regulatory body',
#               '存檔于',
#               'archives at',
#               '勘誤',
#               'corrigendum / erratum',
#               '領騎衫',
#               'distinctive jersey',
#               '广播业者',
#               'broadcast by',
#               '定義域',
#               'definition domain',
#               '基因插入导致',
#               'gene insertion association with',
#               '投票權人',
#               'right to vote',
#               'GSRR评级',
#               'GSRR rating',
#               '贵族头衔',
#               'noble title',
#               '解決者',
#               'solved by',
#               '公路系統',
#               'transport network',
#               '道路通行方向',
#               'driving side',
#               '最高音',
#               'highest note',
#               '建立的水庫',
#               'reservoir created',
#               '所搭載科學儀器',
#               'carries scientific instrument',
#               '发行方式',
#               'distribution format',
#               '近似算法',
#               'approximation algorithm',
#               '血型',
#               'blood type',
#               '廢除',
#               'repeals',
#               '研究地點',
#               'research site',
#               '风险因子',
#               'risk factor',
#               '文字方向',
#               'script directionality',
#               '象征',
#               'symbolizes',
#               '鐵路通行方向',
#               'railway traffic side',
#               '副修专业',
#               'academic minor',
#               '出生地',
#               'place of birth',
#               '内飞于',
#               'enclave within',
#               '訓練',
#               'field of training',
#               '医学发现',
#               'has evaluation',
#               '騎上',
#               'mount',
#               '拍号',
#               'time signature',
#               ...]})
