# %% [markdown]
# ### Entity Generation Notebook
# We take the entities by the number of occurences and do some preprocessing, essentially checking if the requirements of our entities are fulfilled and if the entities are in latin characters.
#
# For this we use a MongoDB Database that has the entities and cleaned entity/property triples. We count the occurences of entities in the triples and then join the collection with the entity collection so that every entity is also associated with its occurence value.

# %% [markdown]
# Requirements:
# - labels the same in en, fr, es, de
# - single tokens
#
# Cleanup:
# - No non-ascii symbols
# - No numbers

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.wikidata
entityList = db.entityList

# %%
db.list_collection_names()
# Out:
# ['entity2_triples',
#  'entity_counts',
#  'triplesInvert',
#  'triples',
#  'equivalence',
#  'nsproperties',
#  'inversion',
#  'entity_subset',
#  'antonym',
#  'relation_subset',
#  'entityList',
#  'entity1_triples',
#  'properties',
#  'symmetry']

# %% [markdown]
# ##### Properties

# %%
db.triplesInvert.find_one({})
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d0'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q43'}

# %%
db.nsproperties.find_one({'_id': 'P530'})

# %%
db.entity2_triples.count_documents({})
# Out:
# 3871818

# %%
db.entity2_triples.find_one({})
# Out:
# {'_id': 'Q10000000', 'count': 1}

# %%
db.entity_counts.find_one({'_id': 'Q10000000'})
# Out:
# {'_id': 'Q10000000', 'value': 3}

# %%
db.symmetric.find_one({})
# Out:
# {'_id': ObjectId('620fb94eae35c2d89a319a2a'), 'r1': {'id': 'P530'}}

# %%
# Unique properties
len(db.triples.distinct('relation'))
# Out:
# 1371

# %%
# List of non-symmetric properties
pipeline = [
    {
        '$lookup':
          {
            'from': "symmetric",
            'localField': "_id",
            'foreignField': "r1.id",
            'as': "matched_relations"
          }
    },
    {
      '$match': {
        "matched_relations": { '$eq': [] }
      }
    },
    { '$out':'nsproperties' }
]

db.properties.aggregate(pipeline, allowDiskUse=True)

# %%
db.nsproperties.find_one({})
# Out:
# {'_id': 'P1034'}

# %%
# Delete matched_relations
db.nsproperties.update_many({}, {'$unset':{"matched_relations":1}})

# %% [markdown]
# ##### Playing around

# %%
db.entityList.find_one({'value':{'$exists':True}})
# Out:
# {'_id': ObjectId('62067319578a2e954363cfc4'),
#  'value': 1,
#  'id': 'Q3276',
#  'type': 'item',
#  'labels': {'fr': {'language': 'fr', 'value': 'exploration de Jupiter'},
#   'en': {'language': 'en', 'value': 'exploration of Jupiter'},
#   'de': {'language': 'de', 'value': 'Erforschung des Jupiters'},
#   'es': {'language': 'es', 'value': 'exploración de Júpiter'},
#   'it': {'language': 'it', 'value': 'esplorazione di Giove'},
#   'pt': {'language': 'pt', 'value': 'exploração de Júpiter'},
#   'ru': {'language': 'ru',
#    'value': 'Исследование Юпитера межпланетными аппаратами'},
#   'vi': {'language': 'vi', 'value': 'Thăm dò Sao Mộc'},
#   'zh': {'language': 'zh', 'value': '木星探測'},
#   'id': {'language': 'id', 'value': 'penjelajahan Yupiter'},
#   'ja': {'language': 'ja', 'value': '木星探査'},
#   'ar': {'language': 'ar', 'value': 'استكشاف كوكب المشتري'},
#   'ko': {'language': 'ko', 'value': '목성 탐사'}}}

# %%
db.equivalence.find_one({})
# Out:
# {'_id': ObjectId('621104eb67e09f0d72992496'),
#  'id1': 'P150',
#  'labels1': {'cs': {'language': 'cs', 'value': 'nižší správní celky'},
#   'en': {'language': 'en',
#    'value': 'contains administrative territorial entity'},
#   'it': {'language': 'it', 'value': 'sottodivisioni amministrative'},
#   'fr': {'language': 'fr',
#    'value': 'contient les subdivisions territoriales administratives'},
#   'zh-hans': {'language': 'zh-hans', 'value': '包含行政领土实体'},
#   'zh-hant': {'language': 'zh-hant', 'value': '包含行政領土實體'},
#   'pt-br': {'language': 'pt-br', 'value': 'subdivide-se em'},
#   'uk': {'language': 'uk',
#    'value': 'адміністративно-територіально поділяється на'},
#   'eo': {'language': 'eo', 'value': 'subdividoj'},
#   'ca': {'language': 'ca', 'value': 'conté la subdivisió administrativa'},
#   'hr': {'language': 'hr', 'value': 'podjedinice'},
#   'fa': {'language': 'fa', 'value': 'زیربخش'},
#   'nds': {'language': 'nds', 'value': 'Ünnerafdelen'},
#   'lv': {'language': 'lv', 'value': 'apakšiedalījumi'},
#   'be': {'language': 'be', 'value': 'адміністрацыйныя адзінкі'},
#   'ru': {'language': 'ru', 'value': 'административно делится на'},
#   'fi': {'language': 'fi', 'value': 'hallinnolliset osa-alueet'},
#   'ro': {'language': 'ro', 'value': 'subdiviziuni'},
#   'he': {'language': 'he', 'value': 'חלוקה משנית'},
#   'ja': {'language': 'ja', 'value': '直下の行政区画'},
#   'ilo': {'language': 'ilo', 'value': 'mabingbingay iti'},
#   'de': {'language': 'de', 'value': 'Untereinheit (administrative Einheit)'},
#   'ta': {'language': 'ta', 'value': 'துணைப்பிரிவுகள்'},
#   'vi': {'language': 'vi', 'value': 'các phân cấp hành chính'},
#   'es': {'language': 'es',
#    'value': 'subdividido en (división administrativa)'},
#   'nl': {'language': 'nl', 'value': 'omvat bestuurlijke eenheid'},
#   'sv': {'language': 'sv',
#    'value': 'innehåller administrativ territoriell enhet'},
#   'ko': {'language': 'ko', 'value': '하위 행정구역'},
#   'ka': {'language': 'ka', 'value': 'ადმინისტრაციულად იყოფა'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'адміністрацыйныя адзінкі'},
#   'pt': {'language': 'pt', 'value': 'subdivide-se em'},
#   'pl': {'language': 'pl', 'value': 'podział administracyjny'},
#   'sr': {'language': 'sr', 'value': 'подељена административно на'},
#   'af': {'language': 'af', 'value': 'administratiewe onderverdeling'},
#   'id': {'language': 'id', 'value': 'pembagian administratif'},
#   'min': {'language': 'min', 'value': 'tabagi dalam'},
#   'uz': {'language': 'uz', 'value': 'maʼmuriy boʻlinishi'},
#   'da': {'language': 'da', 'value': 'inddeles i'},
#   'sco': {'language': 'sco', 'value': 'subdivides intae'},
#   'nb': {'language': 'nb', 'value': 'administrativt delområde'},
#   'el': {'language': 'el', 'value': 'διοικητικά διαιρείται σε'},
#   'bn': {'language': 'bn', 'value': 'প্রশাসনিক বিভক্তি'},
#   'sk': {'language': 'sk', 'value': 'nižšie správne celky'},
#   'br': {'language': 'br', 'value': 'isrannoù'},
#   'nn': {'language': 'nn', 'value': 'underavdeling'},
#   'nds-nl': {'language': 'nds-nl', 'value': 'onderverdeeld in'},
#   'en-gb': {'language': 'en-gb',
#    'value': 'contains administrative territorial entity'},
#   'la': {'language': 'la', 'value': 'subdivisiones'},
#   'oc': {'language': 'oc', 'value': 'subdivisions (division administrativa)'},
#   'mk': {'language': 'mk', 'value': 'административно поделена на'},
#   'sl': {'language': 'sl', 'value': 'administrativne podenote'},
#   'hu': {'language': 'hu', 'value': 'alárendelt egység'},
#   'zh': {'language': 'zh', 'value': '下辖行政领土实体'},
#   'jbo': {'language': 'jbo', 'value': 'selpau'},
#   'en-ca': {'language': 'en-ca',
#    'value': 'contains administrative territorial entity'},
#   'gu': {'language': 'gu', 'value': 'તેના વિભાગો'},
#   'ms': {'language': 'ms', 'value': 'terbahagi kepada (bahagian pentadbiran)'},
#   'bs': {'language': 'bs', 'value': 'podjedinice'},
#   'zh-cn': {'language': 'zh-cn', 'value': '包含行政领土实体'},
#   'is': {'language': 'is', 'value': 'skiptist í (stjórnsýslusvæði)'},
#   'zh-tw': {'language': 'zh-tw', 'value': '包含行政領土實體'},
#   'et': {'language': 'et', 'value': 'haldusüksused'},
#   'lb': {'language': 'lb',
#    'value': 'Ënnerandeelungen (administrativ Eenheeten)'},
#   'zh-hk': {'language': 'zh-hk', 'value': '包含行政領土實體'},
#   'or': {'language': 'or', 'value': 'ପ୍ରଶାସନିକ ଉପବିଭାଗ'},
#   'yi': {'language': 'yi', 'value': 'אונטער־ראיאן'},
#   'hi': {'language': 'hi', 'value': 'प्रशासनिक इकाई'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'подељена административно на'},
#   'sr-el': {'language': 'sr-el', 'value': 'podeljena administrativno na'},
#   'ia': {'language': 'ia',
#    'value': 'contine entitate territorial administrative'},
#   'mg': {'language': 'mg', 'value': 'fizarazarana ara-pandraharahana'},
#   'scn': {'language': 'scn',
#    'value': "cunteni l'entità tirrituriali amministrativa"},
#   'eu': {'language': 'eu', 'value': 'zatiketa (erakunde administratiboak)'},
#   'ne': {'language': 'ne', 'value': 'रहेका प्रशासनिक क्षेत्रहरू'},
#   'cy': {'language': 'cy', 'value': 'yn cynnwys yr ardal weinyddol'},
#   'ar': {'language': 'ar', 'value': 'التقسيمات الإدارية'},
#   'fo': {'language': 'fo', 'value': 'fyrisitingarligt øki'},
#   'hy': {'language': 'hy', 'value': 'վարչականորեն բաժանվում է'},
#   'th': {'language': 'th', 'value': 'หน่วยย่อยการปกครอง'},
#   'bg': {'language': 'bg', 'value': 'териториално-административни единици'},
#   'vmf': {'language': 'vmf', 'value': 'Värwôldungsunnäreihäd'},
#   'yue': {'language': 'yue', 'value': '包含政區'},
#   'tg': {'language': 'tg', 'value': 'зербахш'},
#   'yo': {'language': 'yo', 'value': 'Ní àwon ìpínlè'},
#   'ast': {'language': 'ast', 'value': 'contién la subdivisión alministrativa'},
#   'hsb': {'language': 'hsb',
#    'value': 'podjednotka (administratiwna jednotka)'},
#   'ba': {'language': 'ba', 'value': 'административ рәүештә бүленә'},
#   'tr': {'language': 'tr', 'value': 'idari yapılanması'},
#   'tt': {'language': 'tt', 'value': 'административ бүленеше'},
#   'te': {'language': 'te', 'value': 'దీని కింద ఉన్న పరిపాలనా ప్రాంతం'},
#   'gl': {'language': 'gl', 'value': 'contén a división administrativa'},
#   'sq': {'language': 'sq',
#    'value': 'përmban entitet administrativ territorial'},
#   'frr': {'language': 'frr', 'value': 'onerdiald tu'},
#   'zh-sg': {'language': 'zh-sg', 'value': '包含行政领土实体'},
#   'zh-my': {'language': 'zh-my', 'value': '包含行政领土实体'},
#   'zh-mo': {'language': 'zh-mo', 'value': '包含行政領土實體'},
#   'hyw': {'language': 'hyw', 'value': 'ներքին բաժանում'},
#   'diq': {'language': 'diq', 'value': 'İdareyê bınêni'},
#   'ce': {'language': 'ce', 'value': 'административан йекъало'},
#   'sh': {'language': 'sh', 'value': 'podjedinice'},
#   'ga': {'language': 'ga',
#    'value': 'ina bhfuil eintiteas críochach riaracháin'},
#   'lt': {'language': 'lt', 'value': 'turi kaip administracinį vienetą'},
#   'szl': {'language': 'szl', 'value': 'administracyjny tajlōng'},
#   'ban': {'language': 'ban', 'value': 'wawengkon administratip'},
#   'vec': {'language': 'vec', 'value': 'aministrativamente sudividesto'},
#   'xmf': {'language': 'xmf', 'value': 'ადმინისტრაციულო ირთუ'}},
#  'id2': 'P527',
#  'labels2': {'cs': {'language': 'cs', 'value': 'skládá se z'},
#   'en': {'language': 'en', 'value': 'has part'},
#   'sv': {'language': 'sv', 'value': 'har del'},
#   'de': {'language': 'de', 'value': 'besteht aus'},
#   'es': {'language': 'es', 'value': 'compuesto por'},
#   'ca': {'language': 'ca', 'value': 'format per'},
#   'da': {'language': 'da', 'value': 'har del'},
#   'fr': {'language': 'fr', 'value': 'comprend'},
#   'nn': {'language': 'nn', 'value': 'sett saman av'},
#   'fa': {'language': 'fa', 'value': 'دربرگیرنده'},
#   'hu': {'language': 'hu', 'value': 'alkotórész'},
#   'it': {'language': 'it', 'value': 'consiste di'},
#   'mk': {'language': 'mk', 'value': 'се состои од'},
#   'pl': {'language': 'pl', 'value': 'składa się z'},
#   'nds': {'language': 'nds', 'value': 'besteiht ut'},
#   'fi': {'language': 'fi', 'value': 'koostuu seuraavista'},
#   'sr': {'language': 'sr', 'value': 'састоји се од'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'састоји се од'},
#   'nl': {'language': 'nl', 'value': 'omvat deel'},
#   'ru': {'language': 'ru', 'value': 'состоит из'},
#   'zh': {'language': 'zh', 'value': '可分為'},
#   'oc': {'language': 'oc', 'value': 'compren'},
#   'be': {'language': 'be', 'value': 'складаецца з'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'складаецца з'},
#   'ms': {'language': 'ms', 'value': 'terdiri daripada'},
#   'bs': {'language': 'bs', 'value': 'sastoji se od'},
#   'th': {'language': 'th', 'value': 'ประกอบไปด้วย'},
#   'zh-hant': {'language': 'zh-hant', 'value': '可分為'},
#   'zh-hans': {'language': 'zh-hans', 'value': '可分为'},
#   'ja': {'language': 'ja', 'value': '以下を含む'},
#   'pt': {'language': 'pt', 'value': 'composto de'},
#   'el': {'language': 'el', 'value': 'αποτελείται από'},
#   'en-ca': {'language': 'en-ca', 'value': 'has part'},
#   'nb': {'language': 'nb', 'value': 'har bestanddel'},
#   'ko': {'language': 'ko', 'value': '다음으로 이루어져 있음'},
#   'lb': {'language': 'lb', 'value': 'besteet aus'},
#   'sr-el': {'language': 'sr-el', 'value': 'sastoji se od'},
#   'eo': {'language': 'eo', 'value': 'havas parton'},
#   'sco': {'language': 'sco', 'value': 'haes pairt'},
#   'vi': {'language': 'vi', 'value': 'gồm các phần'},
#   'ilo': {'language': 'ilo', 'value': 'adaan iti paset'},
#   'lv': {'language': 'lv', 'value': 'sastāv no'},
#   'zh-hk': {'language': 'zh-hk', 'value': '可分為'},
#   'gl': {'language': 'gl', 'value': 'composto por'},
#   'id': {'language': 'id', 'value': 'terdiri dari'},
#   'te': {'language': 'te', 'value': 'కలిగియున్న భాగాలు'},
#   'sk': {'language': 'sk', 'value': 'skladá sa z'},
#   'en-gb': {'language': 'en-gb', 'value': 'has part'},
#   'la': {'language': 'la', 'value': 'comprehendit'},
#   'pt-br': {'language': 'pt-br', 'value': 'composto de'},
#   'uk': {'language': 'uk', 'value': 'складники'},
#   'et': {'language': 'et', 'value': 'koosseis'},
#   'zh-cn': {'language': 'zh-cn', 'value': '可分为'},
#   'he': {'language': 'he', 'value': 'מכיל את החלק'},
#   'scn': {'language': 'scn', 'value': 'cunteni'},
#   'ia': {'language': 'ia', 'value': 'componite de'},
#   'sl': {'language': 'sl', 'value': 'vsebuje'},
#   'eu': {'language': 'eu', 'value': 'osatuta'},
#   'bn': {'language': 'bn', 'value': 'এর অংশ'},
#   'ce': {'language': 'ce', 'value': 'хӀоттам'},
#   'hr': {'language': 'hr', 'value': 'sastoji se od'},
#   'jbo': {'language': 'jbo', 'value': 'lo pagbu'},
#   'cy': {'language': 'cy', 'value': 'yn cynnwys'},
#   'lt': {'language': 'lt', 'value': 'susideda iš'},
#   'ast': {'language': 'ast', 'value': 'formáu por'},
#   'ro': {'language': 'ro', 'value': 'constând în'},
#   'ps': {'language': 'ps', 'value': 'برخه لري'},
#   'ka': {'language': 'ka', 'value': 'შედგება'},
#   'ar': {'language': 'ar', 'value': 'يتكوَّن مِن'},
#   'frr': {'language': 'frr', 'value': 'tuupsaat faan'},
#   'mg': {'language': 'mg', 'value': 'ahitana'},
#   'yi': {'language': 'yi', 'value': 'אנטהאלט'},
#   'ta': {'language': 'ta', 'value': 'பகுதிகள்'},
#   'fo': {'language': 'fo', 'value': 'fevnir um'},
#   'zh-mo': {'language': 'zh-mo', 'value': '可分為'},
#   'zh-sg': {'language': 'zh-sg', 'value': '可分为'},
#   'zh-tw': {'language': 'zh-tw', 'value': '可分為'},
#   'ku-latn': {'language': 'ku-latn', 'value': 'pêk tê ji'},
#   'nap': {'language': 'nap', 'value': "e' fatt e"},
#   'vmf': {'language': 'vmf', 'value': 'Zsômmäsedzung'},
#   'bg': {'language': 'bg', 'value': 'състои се от'},
#   'tg': {'language': 'tg', 'value': 'шомили'},
#   'yo': {'language': 'yo', 'value': 'ní ara'},
#   'tg-cyrl': {'language': 'tg-cyrl', 'value': 'иборат аст аз'},
#   'sq': {'language': 'sq', 'value': 'ka pjesë'},
#   'ur': {'language': 'ur', 'value': 'جزو'},
#   'gu': {'language': 'gu', 'value': 'આ ભાગનું બનેલું'},
#   'or': {'language': 'or', 'value': 'ଏହାର ଅଂଶ'},
#   'ba': {'language': 'ba', 'value': 'нимәнән тора'},
#   'kn': {'language': 'kn', 'value': 'ಭಾಗವನ್ನು ಹೊಂದಿದೆ'},
#   'tr': {'language': 'tr', 'value': 'şunlardan oluşur'},
#   'si': {'language': 'si', 'value': 'අයත් කොටස් වන්නේ'},
#   'hsb': {'language': 'hsb', 'value': 'wobsteji z(e)'},
#   'sa': {'language': 'sa', 'value': 'भागोऽस्य कः?'},
#   'tt': {'language': 'tt', 'value': 'нәрсәдән тора'},
#   'tt-cyrl': {'language': 'tt-cyrl', 'value': 'нәрсәдән тора'},
#   'lfn': {'language': 'lfn', 'value': 'ave parte'},
#   'zh-my': {'language': 'zh-my', 'value': '可分为'},
#   'mr': {'language': 'mr', 'value': 'भाग'},
#   'yue': {'language': 'yue', 'value': '包含部分'},
#   'hy': {'language': 'hy', 'value': 'կազմված է'},
#   'gsw': {'language': 'gsw', 'value': 'bstoht us'},
#   'af': {'language': 'af', 'value': 'bestaan uit'},
#   'ky': {'language': 'ky', 'value': 'Курамы'},
#   'ga': {'language': 'ga', 'value': 'le cuid'},
#   'ml': {'language': 'ml', 'value': 'ഇത് ഭാഗമായി'},
#   'vec': {'language': 'vec', 'value': 'formà da'},
#   'br': {'language': 'br', 'value': 'perzh e'},
#   'nqo': {'language': 'nqo', 'value': 'ߡߍ߲ ߘߏ߫ ߦߴߊ߬ ߘߌ߫'},
#   'sh': {'language': 'sh', 'value': 'sastoji se od'},
#   'az': {'language': 'az', 'value': 'bunlardan ibarətdir'},
#   'ban': {'language': 'ban', 'value': 'kadiri antuk'},
#   'diq': {'language': 'diq', 'value': 'Ninan ra yenê pêser'},
#   'se': {'language': 'se', 'value': 'dasa gullet'},
#   'smn': {'language': 'smn', 'value': 'toos kuleh'},
#   'sms': {'language': 'sms', 'value': 'tõzz koʹlle'},
#   'arz': {'language': 'arz', 'value': 'بيتكون من'},
#   'kab': {'language': 'kab', 'value': 'igber seg'},
#   'tl': {'language': 'tl', 'value': 'may parte'},
#   'szl': {'language': 'szl', 'value': 'skłŏdŏ sie z'},
#   'ti': {'language': 'ti', 'value': 'ዝተዳለወ ብ'},
#   'ms-arab': {'language': 'ms-arab', 'value': 'ترديري درڤد'},
#   'ckb': {'language': 'ckb', 'value': 'پێکدێت لە'},
#   'dag': {'language': 'dag', 'value': 'Di malila'},
#   'xmf': {'language': 'xmf', 'value': 'აკმოდირთუ'}}}

# %%
db.antonym.count_documents({})
# Out:
# 15094

# %%
db.triples.count_documents({})
# Out:
# 67108576

# %%
db.triples.find_one({})
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d0'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q43'}

# %%
db.triples.find_one({'relation':'P1696'})
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d0'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q43'}

# %%
entityList.count_documents({'value':{'$exists':False}})
# Out:
# 4500

# %%
entityList.count_documents({'value':{'$exists':True}})
# Out:
# 10156980

# %%
entityList.count_documents({'value':{'$eq':1}})
# Out:
# 428282

# %%
entityList.count_documents({'value':{'$exists': False}})
# Out:
# 4500

# %%
entityList.count_documents({'value':{'$lte':3}})
# Out:
# 2985115

# %%
db.triples.count_documents({'$or': [ { 'entity1': 'Q27213'}, { 'entity2': 'Q27213'} ] } )
# Out:
# 1

# %%
entityList.find_one({"value":10})
# Out:
# {'_id': ObjectId('62067319578a2e954363cf10'),
#  'value': 10,
#  'id': 'Q1672',
#  'type': 'item',
#  'labels': {'it': {'language': 'it', 'value': 'Dejen Gebremeskel'},
#   'en': {'language': 'en', 'value': 'Dejen Gebremeskel'},
#   'fr': {'language': 'fr', 'value': 'Dejen Gebremeskel'},
#   'de': {'language': 'de', 'value': 'Dejen Gebremeskel'},
#   'fi': {'language': 'fi', 'value': 'Dejen Gebremeskel'},
#   'es': {'language': 'es', 'value': 'Dejen Gebremeskel'},
#   'ru': {'language': 'ru', 'value': 'Деджен Гебремескель'},
#   'nl': {'language': 'nl', 'value': 'Dejen Gebremeskel'},
#   'ja': {'language': 'ja', 'value': 'デジェン・ゲブレメスケル'},
#   'tr': {'language': 'tr', 'value': 'Dejen Gebremeskel'},
#   'hu': {'language': 'hu', 'value': 'Dejen Gebremeskel'},
#   'fa': {'language': 'fa', 'value': 'دیژن گبرمسکل'},
#   'he': {'language': 'he', 'value': "דג'ן גברמסקל"},
#   'pt': {'language': 'pt', 'value': 'Dejen Gebremeskel'}}}

# %%
db.triples.find_one()
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d0'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q43'}

# %%
pipeline = [ {"$match": {}}, 
             {"$out": "triplesInvert"},
]
db.triples.aggregate(pipeline)

# %%
db.triplesInvert.find_one()
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d0'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q43'}

# %%
pipeline = [
    {
        '$lookup':
          {
            'from': "triplesInvert",
            'localField': "entity1",
            'foreignField': "entity2",
            'as': "out"
          }
    }
]

results = db.triples.aggregate(pipeline, allowDiskUse=True)

# %%
result = results.next()

# %%
result
# Out:
# {'_id': ObjectId('62078f16162b2abbc195d3d2'),
#  'entity1': 'Q31',
#  'relation': 'P530',
#  'entity2': 'Q77',
#  'out': [{'_id': ObjectId('62078f16162b2abbc195d406'),
#    'entity1': 'Q31',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f16162b2abbc195d558'),
#    'entity1': 'Q1868',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f16162b2abbc195d7b8'),
#    'entity1': 'Q148',
#    'relation': 'P530',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f16162b2abbc195dbc7'),
#    'entity1': 'Q183',
#    'relation': 'P530',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f16162b2abbc195dcd1'),
#    'entity1': 'Q183',
#    'relation': 'P47',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f16162b2abbc195e695'),
#    'entity1': 'Q801',
#    'relation': 'P530',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc195f927'),
#    'entity1': 'Q1693',
#    'relation': 'P205',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196256d'),
#    'entity1': 'Q7318',
#    'relation': 'P47',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196367d'),
#    'entity1': 'Q9337',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1963682'),
#    'entity1': 'Q9337',
#    'relation': 'P131',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1963af4'),
#    'entity1': 'Q9800',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc19649ef'),
#    'entity1': 'Q12445',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc19650a8'),
#    'entity1': 'Q12892',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196516d'),
#    'entity1': 'Q12971',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1965190'),
#    'entity1': 'Q12971',
#    'relation': 'P945',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc19651bc'),
#    'entity1': 'Q12992',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc19651d7'),
#    'entity1': 'Q12999',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1965490'),
#    'entity1': 'Q13582',
#    'relation': 'P710',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1965c97'),
#    'entity1': 'Q14989',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1965cb0'),
#    'entity1': 'Q14999',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1966355'),
#    'entity1': 'Q15990',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967dbf'),
#    'entity1': 'Q20865',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967df0'),
#    'entity1': 'Q20884',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967e09'),
#    'entity1': 'Q20902',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967e11'),
#    'entity1': 'Q20920',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967e19'),
#    'entity1': 'Q20936',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc1967e8a'),
#    'entity1': 'Q20992',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196949d'),
#    'entity1': 'Q24915',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc19694ae'),
#    'entity1': 'Q24926',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196b074'),
#    'entity1': 'Q31129',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196b707'),
#    'entity1': 'Q32733',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196b70c'),
#    'entity1': 'Q32733',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f17162b2abbc196d324'),
#    'entity1': 'Q38889',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc196f608'),
#    'entity1': 'Q44732',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc196fd47'),
#    'entity1': 'Q45857',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1970a35'),
#    'entity1': 'Q48388',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1971181'),
#    'entity1': 'Q49744',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1973e92'),
#    'entity1': 'Q59194',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1973e9e'),
#    'entity1': 'Q59194',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1974060'),
#    'entity1': 'Q59555',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc19762bd'),
#    'entity1': 'Q63944',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1976a13'),
#    'entity1': 'Q65062',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc1979e40'),
#    'entity1': 'Q72919',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc197a0c0'),
#    'entity1': 'Q73360',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc197a0cf'),
#    'entity1': 'Q73360',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc197a795'),
#    'entity1': 'Q74731',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc197a7a0'),
#    'entity1': 'Q74731',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f18162b2abbc197d7e5'),
#    'entity1': 'Q81179',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc1980880'),
#    'entity1': 'Q90942',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc1980893'),
#    'entity1': 'Q90948',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc19816e3'),
#    'entity1': 'Q93740',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc1981766'),
#    'entity1': 'Q93769',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc19817fa'),
#    'entity1': 'Q93920',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc1981896'),
#    'entity1': 'Q94069',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc19818c1'),
#    'entity1': 'Q94077',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc1981d92'),
#    'entity1': 'Q95100',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198350a'),
#    'entity1': 'Q99464',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc19888b8'),
#    'entity1': 'Q117783',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198b586'),
#    'entity1': 'Q128208',
#    'relation': 'P19',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198bc78'),
#    'entity1': 'Q129692',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198bc85'),
#    'entity1': 'Q129692',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198bcd7'),
#    'entity1': 'Q129851',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198bebd'),
#    'entity1': 'Q130262',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198bff3'),
#    'entity1': 'Q130578',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198c6b3'),
#    'entity1': 'Q131927',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f19162b2abbc198cfe7'),
#    'entity1': 'Q134004',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198d76d'),
#    'entity1': 'Q135682',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198daa8'),
#    'entity1': 'Q137475',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198db3b'),
#    'entity1': 'Q137670',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198e5dd'),
#    'entity1': 'Q141146',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198e5e9'),
#    'entity1': 'Q141146',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198e8c0'),
#    'entity1': 'Q141999',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198e9e9'),
#    'entity1': 'Q142627',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198f102'),
#    'entity1': 'Q145062',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198f499'),
#    'entity1': 'Q146452',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc198f5e7'),
#    'entity1': 'Q147084',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990910'),
#    'entity1': 'Q151838',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc199091b'),
#    'entity1': 'Q151838',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990a08'),
#    'entity1': 'Q151985',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990a5b'),
#    'entity1': 'Q152072',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990bfe'),
#    'entity1': 'Q152299',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990c32'),
#    'entity1': 'Q152360',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1990e0b'),
#    'entity1': 'Q152743',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc199145d'),
#    'entity1': 'Q153967',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1991a35'),
#    'entity1': 'Q155065',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1991a42'),
#    'entity1': 'Q155065',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1993342'),
#    'entity1': 'Q159838',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1993d9b'),
#    'entity1': 'Q161959',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc19947c2'),
#    'entity1': 'Q164800',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc19948d9'),
#    'entity1': 'Q165121',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1995046'),
#    'entity1': 'Q167002',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1995780'),
#    'entity1': 'Q168973',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1995cbc'),
#    'entity1': 'Q170080',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1995cc0'),
#    'entity1': 'Q170080',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc199632e'),
#    'entity1': 'Q171444',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc19965b9'),
#    'entity1': 'Q171881',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1996a01'),
#    'entity1': 'Q172761',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1996a3d'),
#    'entity1': 'Q172814',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1996ac9'),
#    'entity1': 'Q172878',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1996b90'),
#    'entity1': 'Q172989',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1996f9a'),
#    'entity1': 'Q173971',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1997639'),
#    'entity1': 'Q176136',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc19978a2'),
#    'entity1': 'Q176955',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1997d8f'),
#    'entity1': 'Q178627',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1997da8'),
#    'entity1': 'Q178627',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc19988bf'),
#    'entity1': 'Q181314',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1998927'),
#    'entity1': 'Q181426',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc199918e'),
#    'entity1': 'Q182896',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc1999500'),
#    'entity1': 'Q183509',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1a162b2abbc199bd35'),
#    'entity1': 'Q192655',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc199e7b6'),
#    'entity1': 'Q203306',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc199fc6a'),
#    'entity1': 'Q208491',
#    'relation': 'P2541',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc199fe68'),
#    'entity1': 'Q208833',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a0876'),
#    'entity1': 'Q211073',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a0ae3'),
#    'entity1': 'Q211540',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a0c26'),
#    'entity1': 'Q211787',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a11a3'),
#    'entity1': 'Q212912',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a132c'),
#    'entity1': 'Q213107',
#    'relation': 'P1001',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a132e'),
#    'entity1': 'Q213107',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a15d7'),
#    'entity1': 'Q213510',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a2588'),
#    'entity1': 'Q215669',
#    'relation': 'P527',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a29b9'),
#    'entity1': 'Q216585',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a3463'),
#    'entity1': 'Q219361',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a3468'),
#    'entity1': 'Q219361',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a3b56'),
#    'entity1': 'Q220683',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a3c17'),
#    'entity1': 'Q220859',
#    'relation': 'P276',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a42c7'),
#    'entity1': 'Q222675',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a42cc'),
#    'entity1': 'Q222675',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a52b6'),
#    'entity1': 'Q228685',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a5349'),
#    'entity1': 'Q228863',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a5a05'),
#    'entity1': 'Q230238',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a5bc7'),
#    'entity1': 'Q230671',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a60f6'),
#    'entity1': 'Q231797',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a65b2'),
#    'entity1': 'Q232785',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a70ff'),
#    'entity1': 'Q235154',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a717c'),
#    'entity1': 'Q235186',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a753d'),
#    'entity1': 'Q236173',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a8365'),
#    'entity1': 'Q239498',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a8cda'),
#    'entity1': 'Q241437',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19a9bb9'),
#    'entity1': 'Q246041',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19ab33b'),
#    'entity1': 'Q253598',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19ab3df'),
#    'entity1': 'Q253798',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19ab8e0'),
#    'entity1': 'Q255261',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1b162b2abbc19ac11c'),
#    'entity1': 'Q258469',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19ac58d'),
#    'entity1': 'Q259550',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19ac757'),
#    'entity1': 'Q259975',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19adbad'),
#    'entity1': 'Q265299',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19adbaf'),
#    'entity1': 'Q265299',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19add59'),
#    'entity1': 'Q266020',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19add5b'),
#    'entity1': 'Q266020',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19ae92b'),
#    'entity1': 'Q269344',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19af28b'),
#    'entity1': 'Q270967',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19af295'),
#    'entity1': 'Q270967',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b037f'),
#    'entity1': 'Q273313',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b0478'),
#    'entity1': 'Q273442',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b076f'),
#    'entity1': 'Q274121',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b0941'),
#    'entity1': 'Q274360',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b0a70'),
#    'entity1': 'Q274551',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b11ea'),
#    'entity1': 'Q275813',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b1218'),
#    'entity1': 'Q275821',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b1844'),
#    'entity1': 'Q277029',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b20e0'),
#    'entity1': 'Q279822',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b24a2'),
#    'entity1': 'Q281411',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b274c'),
#    'entity1': 'Q282233',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b2a80'),
#    'entity1': 'Q283421',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b2e08'),
#    'entity1': 'Q284502',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b3b97'),
#    'entity1': 'Q288872',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b3e98'),
#    'entity1': 'Q289584',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b4082'),
#    'entity1': 'Q290046',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b40b3'),
#    'entity1': 'Q290079',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b5fb8'),
#    'entity1': 'Q300663',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b6b9f'),
#    'entity1': 'Q304680',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b8062'),
#    'entity1': 'Q311601',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b82ab'),
#    'entity1': 'Q311909',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b9163'),
#    'entity1': 'Q313966',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b918e'),
#    'entity1': 'Q314003',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b91a7'),
#    'entity1': 'Q314003',
#    'relation': 'P276',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b92be'),
#    'entity1': 'Q314193',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19b9663'),
#    'entity1': 'Q314922',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1c162b2abbc19ba456'),
#    'entity1': 'Q317524',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bb45b'),
#    'entity1': 'Q320448',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bb71b'),
#    'entity1': 'Q321031',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bbbb3'),
#    'entity1': 'Q322223',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bbdaa'),
#    'entity1': 'Q322862',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bbe3b'),
#    'entity1': 'Q323036',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bbfac'),
#    'entity1': 'Q323408',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bd522'),
#    'entity1': 'Q327170',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bd9f7'),
#    'entity1': 'Q328104',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bdedb'),
#    'entity1': 'Q328858',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bdfab'),
#    'entity1': 'Q329053',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19be241'),
#    'entity1': 'Q329621',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19be247'),
#    'entity1': 'Q329628',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bf84b'),
#    'entity1': 'Q333912',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19bfbb0'),
#    'entity1': 'Q334329',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c0bef'),
#    'entity1': 'Q336978',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c0bf6'),
#    'entity1': 'Q336978',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c0d36'),
#    'entity1': 'Q337289',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c1d41'),
#    'entity1': 'Q343596',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c23f4'),
#    'entity1': 'Q346427',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c2400'),
#    'entity1': 'Q346427',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c2e07'),
#    'entity1': 'Q349659',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c315c'),
#    'entity1': 'Q350698',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c316a'),
#    'entity1': 'Q350698',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c376a'),
#    'entity1': 'Q352369',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c3942'),
#    'entity1': 'Q352952',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c4de1'),
#    'entity1': 'Q359510',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c53b0'),
#    'entity1': 'Q361268',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c5a20'),
#    'entity1': 'Q363251',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c5a28'),
#    'entity1': 'Q363251',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c63fd'),
#    'entity1': 'Q365861',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c64d3'),
#    'entity1': 'Q365992',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c6e6b'),
#    'entity1': 'Q368629',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c77ef'),
#    'entity1': 'Q371277',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c7942'),
#    'entity1': 'Q371690',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c85da'),
#    'entity1': 'Q374874',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c85e1'),
#    'entity1': 'Q374874',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c8720'),
#    'entity1': 'Q375368',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c8f5c'),
#    'entity1': 'Q377071',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c9382'),
#    'entity1': 'Q378208',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c9387'),
#    'entity1': 'Q378208',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1d162b2abbc19c95bf'),
#    'entity1': 'Q378886',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19ca3b4'),
#    'entity1': 'Q381762',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19ca411'),
#    'entity1': 'Q381794',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19ca421'),
#    'entity1': 'Q381794',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19ca601'),
#    'entity1': 'Q382137',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19ca85a'),
#    'entity1': 'Q382744',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cac84'),
#    'entity1': 'Q384379',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19caef9'),
#    'entity1': 'Q385026',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cb33e'),
#    'entity1': 'Q386400',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cb352'),
#    'entity1': 'Q386400',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cb66b'),
#    'entity1': 'Q387448',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cba49'),
#    'entity1': 'Q388891',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cba64'),
#    'entity1': 'Q388897',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cfa33'),
#    'entity1': 'Q421992',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cfa7a'),
#    'entity1': 'Q422053',
#    'relation': 'P1001',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19cfa7d'),
#    'entity1': 'Q422053',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d0904'),
#    'entity1': 'Q428160',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d094b'),
#    'entity1': 'Q428257',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d0966'),
#    'entity1': 'Q428257',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d0cea'),
#    'entity1': 'Q429503',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d0cf2'),
#    'entity1': 'Q429503',
#    'relation': 'P19',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d10de'),
#    'entity1': 'Q431081',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d1906'),
#    'entity1': 'Q433124',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d19a5'),
#    'entity1': 'Q433249',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d27d5'),
#    'entity1': 'Q435627',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d4a80'),
#    'entity1': 'Q445091',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d4a85'),
#    'entity1': 'Q445091',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d4dfe'),
#    'entity1': 'Q445973',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d4ffa'),
#    'entity1': 'Q446461',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d5266'),
#    'entity1': 'Q446846',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d526f'),
#    'entity1': 'Q446846',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d6386'),
#    'entity1': 'Q450700',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d63f5'),
#    'entity1': 'Q450754',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d733c'),
#    'entity1': 'Q453991',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d7c79'),
#    'entity1': 'Q455722',
#    'relation': 'P19',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d7e3f'),
#    'entity1': 'Q455891',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d89c4'),
#    'entity1': 'Q458084',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d89d6'),
#    'entity1': 'Q458095',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d8b7b'),
#    'entity1': 'Q458306',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d8b84'),
#    'entity1': 'Q458315',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1e162b2abbc19d8d75'),
#    'entity1': 'Q458676',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19d957f'),
#    'entity1': 'Q460479',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19d95ad'),
#    'entity1': 'Q460552',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19d95b1'),
#    'entity1': 'Q460552',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19d981b'),
#    'entity1': 'Q461027',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19da38a'),
#    'entity1': 'Q463283',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dac7f'),
#    'entity1': 'Q464656',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19db41b'),
#    'entity1': 'Q465973',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19db480'),
#    'entity1': 'Q466024',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19db537'),
#    'entity1': 'Q466241',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19db86a'),
#    'entity1': 'Q466755',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dc226'),
#    'entity1': 'Q468492',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dc853'),
#    'entity1': 'Q470036',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dc85e'),
#    'entity1': 'Q470036',
#    'relation': 'P551',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dca04'),
#    'entity1': 'Q470232',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dca13'),
#    'entity1': 'Q470232',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dd44c'),
#    'entity1': 'Q472276',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dd617'),
#    'entity1': 'Q472511',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dd663'),
#    'entity1': 'Q472573',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19dea86'),
#    'entity1': 'Q477465',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e01cf'),
#    'entity1': 'Q485309',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e1272'),
#    'entity1': 'Q489338',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e1274'),
#    'entity1': 'Q489338',
#    'relation': 'P740',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e1713'),
#    'entity1': 'Q490586',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e1cda'),
#    'entity1': 'Q491805',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e1cdf'),
#    'entity1': 'Q491805',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e22d3'),
#    'entity1': 'Q493522',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e22fc'),
#    'entity1': 'Q493567',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e3bbc'),
#    'entity1': 'Q499915',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e3bbf'),
#    'entity1': 'Q499915',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e3f60'),
#    'entity1': 'Q500985',
#    'relation': 'P276',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e419e'),
#    'entity1': 'Q501622',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e49cf'),
#    'entity1': 'Q503363',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e5d6f'),
#    'entity1': 'Q506771',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e60ed'),
#    'entity1': 'Q507632',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e67be'),
#    'entity1': 'Q509413',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e67d0'),
#    'entity1': 'Q509434',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e6a34'),
#    'entity1': 'Q509996',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e6a39'),
#    'entity1': 'Q509996',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e72b5'),
#    'entity1': 'Q512254',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e73dc'),
#    'entity1': 'Q512507',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f1f162b2abbc19e770f'),
#    'entity1': 'Q513521',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e8938'),
#    'entity1': 'Q518250',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9189'),
#    'entity1': 'Q520204',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e931e'),
#    'entity1': 'Q520457',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9aa8'),
#    'entity1': 'Q522351',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9e11'),
#    'entity1': 'Q523506',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9e41'),
#    'entity1': 'Q523524',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9e87'),
#    'entity1': 'Q523548',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19e9ecb'),
#    'entity1': 'Q523581',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ea63e'),
#    'entity1': 'Q525501',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ead29'),
#    'entity1': 'Q527442',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19eaf8b'),
#    'entity1': 'Q527949',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19eaf99'),
#    'entity1': 'Q527953',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ebbc0'),
#    'entity1': 'Q531422',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ebe58'),
#    'entity1': 'Q532299',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ec17f'),
#    'entity1': 'Q533339',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ed529'),
#    'entity1': 'Q538878',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ed53a'),
#    'entity1': 'Q538878',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ed60f'),
#    'entity1': 'Q539055',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ed946'),
#    'entity1': 'Q539902',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ed953'),
#    'entity1': 'Q539902',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19edb95'),
#    'entity1': 'Q540657',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19eddd8'),
#    'entity1': 'Q541276',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19eddf7'),
#    'entity1': 'Q541290',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19eddf9'),
#    'entity1': 'Q541291',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ef0b5'),
#    'entity1': 'Q546090',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ef314'),
#    'entity1': 'Q546727',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ef469'),
#    'entity1': 'Q546971',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ef470'),
#    'entity1': 'Q546971',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19ef7b0'),
#    'entity1': 'Q547953',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f07c0'),
#    'entity1': 'Q551836',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f0abb'),
#    'entity1': 'Q552426',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f0bed'),
#    'entity1': 'Q552646',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f0bfb'),
#    'entity1': 'Q552646',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f19b8'),
#    'entity1': 'Q555362',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f1b57'),
#    'entity1': 'Q555715',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f1e0d'),
#    'entity1': 'Q556495',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f215d'),
#    'entity1': 'Q557289',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f2166'),
#    'entity1': 'Q557289',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f2a9c'),
#    'entity1': 'Q559285',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f2ab2'),
#    'entity1': 'Q559285',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f3169'),
#    'entity1': 'Q561224',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f3171'),
#    'entity1': 'Q561224',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f386c'),
#    'entity1': 'Q563065',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f3870'),
#    'entity1': 'Q563065',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f4661'),
#    'entity1': 'Q569045',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f5fe1'),
#    'entity1': 'Q577343',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f5fe4'),
#    'entity1': 'Q577343',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f6799'),
#    'entity1': 'Q580122',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f20162b2abbc19f6b5e'),
#    'entity1': 'Q581491',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f7af2'),
#    'entity1': 'Q587509',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f7be1'),
#    'entity1': 'Q587860',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f7c0c'),
#    'entity1': 'Q587944',
#    'relation': 'P8047',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f7c1a'),
#    'entity1': 'Q587979',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f844f'),
#    'entity1': 'Q591144',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f8453'),
#    'entity1': 'Q591144',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f8639'),
#    'entity1': 'Q591695',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f8bb7'),
#    'entity1': 'Q593793',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f8da3'),
#    'entity1': 'Q594406',
#    'relation': 'P127',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f8e4b'),
#    'entity1': 'Q594861',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f939e'),
#    'entity1': 'Q596858',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f9616'),
#    'entity1': 'Q597777',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f996e'),
#    'entity1': 'Q599127',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19f9b14'),
#    'entity1': 'Q599910',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fa031'),
#    'entity1': 'Q601578',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fa8b4'),
#    'entity1': 'Q604835',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fa9af'),
#    'entity1': 'Q605085',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fa9b7'),
#    'entity1': 'Q605085',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fa9ba'),
#    'entity1': 'Q605099',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fac2f'),
#    'entity1': 'Q605759',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fac7c'),
#    'entity1': 'Q605860',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19faeaa'),
#    'entity1': 'Q606251',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fb0e7'),
#    'entity1': 'Q607182',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fb92b'),
#    'entity1': 'Q610209',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fc1ed'),
#    'entity1': 'Q613420',
#    'relation': 'P150',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fc559'),
#    'entity1': 'Q614819',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fc82a'),
#    'entity1': 'Q615867',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fcbba'),
#    'entity1': 'Q617270',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fcbbc'),
#    'entity1': 'Q617270',
#    'relation': 'P205',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fce4c'),
#    'entity1': 'Q618620',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fd373'),
#    'entity1': 'Q620923',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fd792'),
#    'entity1': 'Q622330',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fd79a'),
#    'entity1': 'Q622330',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fe789'),
#    'entity1': 'Q628124',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fe9c2'),
#    'entity1': 'Q628951',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19fee3c'),
#    'entity1': 'Q631278',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19ff2e5'),
#    'entity1': 'Q632883',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19ffc01'),
#    'entity1': 'Q635802',
#    'relation': 'P840',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc19ffc5a'),
#    'entity1': 'Q635932',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a00825'),
#    'entity1': 'Q640417',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a00fa4'),
#    'entity1': 'Q642899',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a014cb'),
#    'entity1': 'Q644727',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a0156c'),
#    'entity1': 'Q644853',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a01981'),
#    'entity1': 'Q646137',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a0198d'),
#    'entity1': 'Q646137',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a01e80'),
#    'entity1': 'Q648084',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a01fa9'),
#    'entity1': 'Q648412',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a02223'),
#    'entity1': 'Q649249',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a022b4'),
#    'entity1': 'Q649542',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a0299b'),
#    'entity1': 'Q651811',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a02b05'),
#    'entity1': 'Q652379',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a02bc1'),
#    'entity1': 'Q652683',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a02e45'),
#    'entity1': 'Q653663',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a0323f'),
#    'entity1': 'Q655060',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a03a42'),
#    'entity1': 'Q657718',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a03e86'),
#    'entity1': 'Q659345',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a04269'),
#    'entity1': 'Q660389',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f21162b2abbc1a04803'),
#    'entity1': 'Q662107',
#    'relation': 'P495',
# ...
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1a9e461'),
#    'entity1': 'Q1718657',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1a9e910'),
#    'entity1': 'Q1723575',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1a9ee9a'),
#    'entity1': 'Q1725879',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa012a'),
#    'entity1': 'Q1734548',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa3130'),
#    'entity1': 'Q1760825',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa3731'),
#    'entity1': 'Q1764680',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa3f02'),
#    'entity1': 'Q1769361',
#    'relation': 'P527',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa445c'),
#    'entity1': 'Q1771975',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa4bba'),
#    'entity1': 'Q1776216',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa4d16'),
#    'entity1': 'Q1777249',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa4da9'),
#    'entity1': 'Q1777551',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa4dab'),
#    'entity1': 'Q1777551',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa57b2'),
#    'entity1': 'Q1783252',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa6f3c'),
#    'entity1': 'Q1798856',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa7496'),
#    'entity1': 'Q1801971',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa7e21'),
#    'entity1': 'Q1809071',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8194'),
#    'entity1': 'Q1810940',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8389'),
#    'entity1': 'Q1812012',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa852f'),
#    'entity1': 'Q1812913',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8608'),
#    'entity1': 'Q1813247',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa860d'),
#    'entity1': 'Q1813278',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8778'),
#    'entity1': 'Q1814211',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8adc'),
#    'entity1': 'Q1816925',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa8b7b'),
#    'entity1': 'Q1817365',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9014'),
#    'entity1': 'Q1820092',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9070'),
#    'entity1': 'Q1820752',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9075'),
#    'entity1': 'Q1820752',
#    'relation': 'P1001',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9495'),
#    'entity1': 'Q1823848',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9496'),
#    'entity1': 'Q1823853',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa94b1'),
#    'entity1': 'Q1823919',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa94d8'),
#    'entity1': 'Q1824157',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9699'),
#    'entity1': 'Q1825690',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa970a'),
#    'entity1': 'Q1825912',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa973f'),
#    'entity1': 'Q1826102',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9867'),
#    'entity1': 'Q1827275',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9886'),
#    'entity1': 'Q1827402',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9a14'),
#    'entity1': 'Q1830497',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9a52'),
#    'entity1': 'Q1831319',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9abb'),
#    'entity1': 'Q1832089',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9b03'),
#    'entity1': 'Q1832846',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9c68'),
#    'entity1': 'Q1836470',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9ca0'),
#    'entity1': 'Q1836982',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9cb9'),
#    'entity1': 'Q1837074',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9e17'),
#    'entity1': 'Q1839687',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9ef0'),
#    'entity1': 'Q1841048',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9f07'),
#    'entity1': 'Q1841142',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9f47'),
#    'entity1': 'Q1841314',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aa9f61'),
#    'entity1': 'Q1841581',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa07c'),
#    'entity1': 'Q1844316',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa0d8'),
#    'entity1': 'Q1845763',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa0de'),
#    'entity1': 'Q1845763',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa100'),
#    'entity1': 'Q1846022',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa111'),
#    'entity1': 'Q1846068',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa1a5'),
#    'entity1': 'Q1847486',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa1b2'),
#    'entity1': 'Q1847530',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa1f5'),
#    'entity1': 'Q1847918',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa2a2'),
#    'entity1': 'Q1848746',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa3b4'),
#    'entity1': 'Q1849666',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa591'),
#    'entity1': 'Q1851684',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa6a6'),
#    'entity1': 'Q1852989',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaa818'),
#    'entity1': 'Q1854972',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaaba9'),
#    'entity1': 'Q1858579',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaae3f'),
#    'entity1': 'Q1862121',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaae81'),
#    'entity1': 'Q1862404',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaaedd'),
#    'entity1': 'Q1862710',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaaf18'),
#    'entity1': 'Q1862877',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaaf52'),
#    'entity1': 'Q1863267',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab071'),
#    'entity1': 'Q1865073',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab193'),
#    'entity1': 'Q1866294',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab2d0'),
#    'entity1': 'Q1867718',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab39d'),
#    'entity1': 'Q1868450',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab54c'),
#    'entity1': 'Q1870298',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab639'),
#    'entity1': 'Q1871086',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab63a'),
#    'entity1': 'Q1871086',
#    'relation': 'P19',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab704'),
#    'entity1': 'Q1871612',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab756'),
#    'entity1': 'Q1871701',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aab75b'),
#    'entity1': 'Q1871722',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aaba2b'),
#    'entity1': 'Q1873785',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aabdb3'),
#    'entity1': 'Q1875675',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aabdc4'),
#    'entity1': 'Q1875907',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aabe37'),
#    'entity1': 'Q1876194',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aabf39'),
#    'entity1': 'Q1876567',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac06c'),
#    'entity1': 'Q1877169',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac258'),
#    'entity1': 'Q1878710',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac3a3'),
#    'entity1': 'Q1879448',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac3af'),
#    'entity1': 'Q1879448',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac3e7'),
#    'entity1': 'Q1879485',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac421'),
#    'entity1': 'Q1879540',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac44b'),
#    'entity1': 'Q1879689',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac5ce'),
#    'entity1': 'Q1881330',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac631'),
#    'entity1': 'Q1881771',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac728'),
#    'entity1': 'Q1882535',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac7c8'),
#    'entity1': 'Q1883527',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac914'),
#    'entity1': 'Q1884656',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aac984'),
#    'entity1': 'Q1885105',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aacab4'),
#    'entity1': 'Q1886350',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aacbad'),
#    'entity1': 'Q1887018',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2c162b2abbc1aacbd2'),
#    'entity1': 'Q1887078',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad1a8'),
#    'entity1': 'Q1891482',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad2d8'),
#    'entity1': 'Q1892167',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad2dc'),
#    'entity1': 'Q1892176',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad302'),
#    'entity1': 'Q1892304',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad3d9'),
#    'entity1': 'Q1892853',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad541'),
#    'entity1': 'Q1893680',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad702'),
#    'entity1': 'Q1894677',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aad82e'),
#    'entity1': 'Q1895280',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aadab5'),
#    'entity1': 'Q1896633',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aadc26'),
#    'entity1': 'Q1897417',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaddf6'),
#    'entity1': 'Q1898692',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aae069'),
#    'entity1': 'Q1900094',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aae268'),
#    'entity1': 'Q1901527',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aae37a'),
#    'entity1': 'Q1902236',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aae868'),
#    'entity1': 'Q1905348',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aae8ea'),
#    'entity1': 'Q1905770',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaeaba'),
#    'entity1': 'Q1906759',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaed42'),
#    'entity1': 'Q1908829',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaed5b'),
#    'entity1': 'Q1908829',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaef9f'),
#    'entity1': 'Q1910736',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf143'),
#    'entity1': 'Q1912202',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf268'),
#    'entity1': 'Q1912817',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf39f'),
#    'entity1': 'Q1913621',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf4d6'),
#    'entity1': 'Q1914203',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf6da'),
#    'entity1': 'Q1916277',
#    'relation': 'P495',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaf89d'),
#    'entity1': 'Q1917975',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafb88'),
#    'entity1': 'Q1920214',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafc7e'),
#    'entity1': 'Q1921190',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafc85'),
#    'entity1': 'Q1921190',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafd3d'),
#    'entity1': 'Q1921936',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafd88'),
#    'entity1': 'Q1922173',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafddc'),
#    'entity1': 'Q1922599',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafe3b'),
#    'entity1': 'Q1922761',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafe3e'),
#    'entity1': 'Q1922761',
#    'relation': 'P1532',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aafed1'),
#    'entity1': 'Q1923312',
#    'relation': 'P27',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaff1a'),
#    'entity1': 'Q1923610',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   {'_id': ObjectId('62078f2d162b2abbc1aaff4c'),
#    'entity1': 'Q1923848',
#    'relation': 'P17',
#    'entity2': 'Q31'},
#   ...]}

# %% [markdown]
# #### Prepare mBERT

# %%
import torch
from transformers import BertTokenizer, BertModel

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# %%
tokenizer.tokenize('bélier')
# Out:
# ['bé', '##lier']

# %% [markdown]
# #### Preprocessing

# %%
def isLatin(s):
    try:
        s.encode('latin-1')
    except UnicodeEncodeError:
        return False
    else:
        return True

# %%
def isEnglish(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except AttributeError:
        return False
    except UnicodeDecodeError:
        return False
    else:
        return True

# %%
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
def all_same(items):
    return all(x == items[0] for x in items)

# %% [markdown]
# #### Tokenize and Check

# %%
# Parameters
# Get all entities for maxNumRelations
maxNumRelations = 5
languages = ('en','es','fr','de')

# %%
# Single-Token
# Language Agnostic labels (same label across languages)
cand = []
candNon = []

for document in entityList.find({'value':{'$lte':maxNumRelations}}):
    if all(k in document['labels'] for k in languages):
        # Test if labels in all languages are the same
        labels = [document['labels'][k]['value'] for k in languages]
        if not all_same(labels): continue
        
        # Tokenize the universal label
        wordToken = tokenizer.tokenize(document['labels']['en']['value'])
        if (len(wordToken) == 1):
            if document['labels']['en']['value'].isalpha() and isLatin(document['labels']['en']['value']):
                cand.append({'id': document['id'], 'label': document['labels']['en']['value']})
            else:
                candNon.append({'id': document['id'], 'label': document['labels']['en']['value']})

# %%
# Single-Token
# English labels but labels exist in all languages
cand = []
candNon = []

for document in entityList.find({'value':{'$lte':maxNumRelations}}):
    if all(k in document['labels'] for k in languages):
        wordToken = tokenizer.tokenize(document['labels']['en']['value'])
        if (len(wordToken) == 1):
            if document['labels']['en']['value'].isalpha() and isLatin(document['labels']['en']['value']):
                cand.append({'id': document['id'], 'label': document['labels']['en']['value']})
            else:
                candNon.append({'id': document['id'], 'label': document['labels']['en']['value']})

# %%
# Single-Token
# All language labels
cand = []
candNon = []

for document in entityList.find({'value':{'$lte':maxNumRelations}}):
    if all(k in document['labels'] for k in languages):
        wordTokens = [tokenizer.tokenize(document['labels'][k]['value']) for k in languages]
        if (all(len(l) == 1 for l in wordTokens)):
            if all(word[0].isalpha() and isLatin(word[0]) for word in wordTokens):
                j = {'id': document['id']}
                for k in languages: j[k] = document['labels'][k]['value']
                cand.append(j)
            else:
                j = {'id': document['id']}
                for k in languages: j[k] = document['labels'][k]['value']
                candNon.append(j)

# %%
len(cand)
# Out:
# 9934

# %%
cand
# Out:
# [{'id': 'Q27278', 'label': 'H'},
#  {'id': 'Q27931', 'label': 'Okinawa'},
#  {'id': 'Q30011', 'label': 'K'},
#  {'id': 'Q127942', 'label': 'JR'},
#  {'id': 'Q138698', 'label': 'Khmer'},
#  {'id': 'Q171494', 'label': 'Winston'},
#  {'id': 'Q216756', 'label': 'DDR'},
#  {'id': 'Q217417', 'label': 'HF'},
#  {'id': 'Q219240', 'label': 'AK'},
#  {'id': 'Q224432', 'label': 'RMS'},
#  {'id': 'Q224763', 'label': 'ST'},
#  {'id': 'Q225140', 'label': 'SF'},
#  {'id': 'Q225202', 'label': 'IPA'},
#  {'id': 'Q224949', 'label': 'LP'},
#  {'id': 'Q225590', 'label': 'CT'},
#  {'id': 'Q226388', 'label': 'RF'},
#  {'id': 'Q226675', 'label': 'EF'},
#  {'id': 'Q226684', 'label': 'NH'},
#  {'id': 'Q229045', 'label': 'ITF'},
#  {'id': 'Q229602', 'label': 'Sister'},
#  {'id': 'Q230009', 'label': 'SNP'},
#  {'id': 'Q229997', 'label': 'Moravia'},
#  {'id': 'Q231449', 'label': 'Satan'},
#  {'id': 'Q233378', 'label': 'RTL'},
#  {'id': 'Q233713', 'label': 'FCC'},
#  {'id': 'Q233980', 'label': 'Bali'},
#  {'id': 'Q234404', 'label': 'Marathon'},
#  {'id': 'Q236040', 'label': 'Suffolk'},
#  {'id': 'Q237166', 'label': 'Portuguesa'},
#  {'id': 'Q240699', 'label': 'ACM'},
#  {'id': 'Q245801', 'label': 'SBS'},
#  {'id': 'Q247024', 'label': 'PBS'},
#  {'id': 'Q252971', 'label': 'Crisis'},
#  {'id': 'Q254367', 'label': 'Goal'},
#  {'id': 'Q264890', 'label': 'Return'},
#  {'id': 'Q267059', 'label': 'SMK'},
#  {'id': 'Q273429', 'label': 'École'},
#  {'id': 'Q294451', 'label': 'Potsdam'},
#  {'id': 'Q295170', 'label': 'Levante'},
#  {'id': 'Q295147', 'label': 'Celtic'},
#  {'id': 'Q296614', 'label': 'WRC'},
#  {'id': 'Q296462', 'label': 'LL'},
#  {'id': 'Q297686', 'label': 'Subway'},
#  {'id': 'Q298093', 'label': 'ASV'},
#  {'id': 'Q298199', 'label': 'ISS'},
#  {'id': 'Q298642', 'label': 'Lugano'},
#  {'id': 'Q340777', 'label': 'Vinyl'},
#  {'id': 'Q343555', 'label': 'Insight'},
#  {'id': 'Q346636', 'label': 'Color'},
#  {'id': 'Q348858', 'label': 'FBI'},
#  {'id': 'Q355028', 'label': 'Ardèche'},
#  {'id': 'Q356967', 'label': 'Expo'},
#  {'id': 'Q357129', 'label': 'VF'},
#  {'id': 'Q359957', 'label': 'Adobe'},
#  {'id': 'Q360257', 'label': 'Unlimited'},
#  {'id': 'Q364373', 'label': 'Borussia'},
#  {'id': 'Q395126', 'label': 'Neuchâtel'},
#  {'id': 'Q397103', 'label': 'Broadcast'},
#  {'id': 'Q397478', 'label': 'MLB'},
#  {'id': 'Q398156', 'label': 'Funeral'},
#  {'id': 'Q398887', 'label': 'Inside'},
#  {'id': 'Q411842', 'label': 'National'},
#  {'id': 'Q415025', 'label': 'Pasha'},
#  {'id': 'Q437742', 'label': 'TSV'},
#  {'id': 'Q443744', 'label': 'WK'},
#  {'id': 'Q447950', 'label': 'SFR'},
#  {'id': 'Q483208', 'label': 'KG'},
#  {'id': 'Q590243', 'label': 'Melissa'},
#  {'id': 'Q778176', 'label': 'Ausbruch'},
#  {'id': 'Q778256', 'label': 'Auschwitz'},
#  {'id': 'Q1159266', 'label': 'LC'},
#  {'id': 'Q1164104', 'label': 'Yunan'},
#  {'id': 'Q1164527', 'label': 'Bahasa'},
#  {'id': 'Q1178281', 'label': 'Remix'},
#  {'id': 'Q1181095', 'label': 'Dancing'},
#  {'id': 'Q1218610', 'label': 'Smiths'},
#  {'id': 'Q1222523', 'label': 'Byzantium'},
#  {'id': 'Q1276671', 'label': 'Each'},
#  {'id': 'Q1314984', 'label': 'Oggi'},
#  {'id': 'Q1718591', 'label': 'Trennung'},
#  {'id': 'Q1825485', 'label': 'Limited'},
#  {'id': 'Q1932583', 'label': 'Migration'},
#  {'id': 'Q1973069', 'label': 'Tan'},
#  {'id': 'Q2325996', 'label': 'Stadio'},
#  {'id': 'Q2519090', 'label': 'Vertreter'},
#  {'id': 'Q2634942', 'label': 'Grace'},
#  {'id': 'Q2656550', 'label': 'Atlantic'},
#  {'id': 'Q2790543', 'label': 'Songs'},
#  {'id': 'Q2876085', 'label': 'Episcopal'},
#  {'id': 'Q2974950', 'label': 'Clair'},
#  {'id': 'Q3382469', 'label': 'Piccolo'},
#  {'id': 'Q3630421', 'label': 'Authority'},
#  {'id': 'Q3687686', 'label': 'Consulta'},
#  {'id': 'Q4650720', 'label': 'Audio'},
#  {'id': 'Q5380814', 'label': 'Entry'},
#  {'id': 'Q5998458', 'label': 'Yer'},
#  {'id': 'Q7265635', 'label': 'Q'},
#  {'id': 'Q7968827', 'label': 'Waray'},
#  {'id': 'Q8036765', 'label': 'Worldwide'},
#  {'id': 'Q9092883', 'label': 'Vencedor'},
#  {'id': 'Q12321273', 'label': 'Kapitel'},
#  {'id': 'Q13096507', 'label': 'Romawi'},
#  {'id': 'Q13612624', 'label': 'Bangkok'},
#  {'id': 'Q92175953', 'label': 'Musiker'},
#  {'id': 'Q105944793', 'label': 'Museum'},
#  {'id': 'Q80422', 'label': 'Soccer'},
#  {'id': 'Q105745', 'label': 'CD'},
#  {'id': 'Q175966', 'label': 'Kyoto'},
#  {'id': 'Q207900', 'label': 'MM'},
#  {'id': 'Q217359', 'label': 'SD'},
#  {'id': 'Q217419', 'label': 'HR'},
#  {'id': 'Q217424', 'label': 'CH'},
#  {'id': 'Q217488', 'label': 'DB'},
#  {'id': 'Q219099', 'label': 'FF'},
#  {'id': 'Q219084', 'label': 'AV'},
#  {'id': 'Q219108', 'label': 'BS'},
#  {'id': 'Q219204', 'label': 'UA'},
#  {'id': 'Q219246', 'label': 'CP'},
#  {'id': 'Q219343', 'label': 'ICC'},
#  {'id': 'Q219297', 'label': 'VA'},
#  {'id': 'Q219267', 'label': 'ATC'},
#  {'id': 'Q223811', 'label': 'GP'},
#  {'id': 'Q224261', 'label': 'CK'},
#  {'id': 'Q224295', 'label': 'ITU'},
#  {'id': 'Q225582', 'label': 'FC'},
#  {'id': 'Q225866', 'label': 'SMS'},
#  {'id': 'Q226033', 'label': 'CRC'},
#  {'id': 'Q225778', 'label': 'Superior'},
#  {'id': 'Q226362', 'label': 'OP'},
#  {'id': 'Q227200', 'label': 'Meteor'},
#  {'id': 'Q227927', 'label': 'Southampton'},
#  {'id': 'Q228209', 'label': 'Volume'},
#  {'id': 'Q227699', 'label': 'AE'},
#  {'id': 'Q231570', 'label': 'PCR'},
#  {'id': 'Q235623', 'label': 'JNA'},
#  {'id': 'Q236530', 'label': 'BSD'},
#  {'id': 'Q243076', 'label': 'Slag'},
#  {'id': 'Q248734', 'label': 'FAA'},
#  {'id': 'Q249088', 'label': 'WBA'},
#  {'id': 'Q255573', 'label': 'PRL'},
#  {'id': 'Q257287', 'label': 'PSV'},
#  {'id': 'Q258670', 'label': 'Saints'},
#  {'id': 'Q267575', 'label': 'Borgia'},
#  {'id': 'Q295567', 'label': 'Ø'},
#  {'id': 'Q295967', 'label': 'Devil'},
#  {'id': 'Q296137', 'label': 'APG'},
#  {'id': 'Q341348', 'label': 'Elsevier'},
#  {'id': 'Q344600', 'label': 'TC'},
#  {'id': 'Q346571', 'label': 'Exposition'},
#  {'id': 'Q346343', 'label': 'Kamera'},
#  {'id': 'Q346598', 'label': 'Pfalz'},
#  {'id': 'Q351923', 'label': 'MLS'},
#  {'id': 'Q354951', 'label': 'Listen'},
#  {'id': 'Q355061', 'label': 'Chronicle'},
#  {'id': 'Q358634', 'label': 'CBN'},
#  {'id': 'Q366378', 'label': 'Assembly'},
#  {'id': 'Q396510', 'label': 'Sibiu'},
#  {'id': 'Q398628', 'label': 'Design'},
#  {'id': 'Q398098', 'label': 'Sporting'},
#  {'id': 'Q399215', 'label': 'Moscou'},
#  {'id': 'Q400638', 'label': 'Again'},
#  {'id': 'Q403255', 'label': 'Review'},
#  {'id': 'Q404671', 'label': 'GRN'},
#  {'id': 'Q405316', 'label': 'Telegraph'},
#  {'id': 'Q407890', 'label': 'Ayn'},
#  {'id': 'Q408258', 'label': 'Catch'},
#  {'id': 'Q411189', 'label': 'Opening'},
#  {'id': 'Q419307', 'label': 'Shift'},
#  {'id': 'Q420884', 'label': 'Cordillera'},
#  {'id': 'Q450698', 'label': 'Universitas'},
#  {'id': 'Q483217', 'label': 'HB'},
#  {'id': 'Q759848', 'label': 'Aufnahme'},
#  {'id': 'Q783201', 'label': 'WR'},
#  {'id': 'Q1024240', 'label': 'CPU'},
#  {'id': 'Q1166773', 'label': 'Scots'},
#  {'id': 'Q1251649', 'label': 'Doubs'},
#  {'id': 'Q1784743', 'label': 'WWF'},
#  {'id': 'Q1823047', 'label': 'Libia'},
#  {'id': 'Q2095716', 'label': 'Nacht'},
#  {'id': 'Q2467011', 'label': 'UFC'},
#  {'id': 'Q2500623', 'label': 'Flying'},
#  {'id': 'Q2585629', 'label': 'Wirkung'},
#  {'id': 'Q2644458', 'label': 'Eclipse'},
#  {'id': 'Q2646480', 'label': 'Algeria'},
#  {'id': 'Q3246064', 'label': 'Angriff'},
#  {'id': 'Q3348319', 'label': 'Observatoire'},
#  {'id': 'Q3700453', 'label': 'DKI'},
#  {'id': 'Q3705538', 'label': 'Dentro'},
#  {'id': 'Q5375540', 'label': 'Encore'},
#  {'id': 'Q5880028', 'label': 'Assassin'},
#  {'id': 'Q7541600', 'label': 'Slovakia'},
#  {'id': 'Q8344081', 'label': 'Cerca'},
#  {'id': 'Q12084325', 'label': 'Bosna'},
#  {'id': 'Q13424832', 'label': 'Ebene'},
#  {'id': 'Q15880866', 'label': 'Portrait'},
#  {'id': 'Q25174335', 'label': 'Occitanie'},
#  {'id': 'Q55776788', 'label': 'Rt'},
#  {'id': 'Q56604628', 'label': 'Arthur'},
#  {'id': 'Q39721', 'label': 'Rwanda'},
#  {'id': 'Q192336', 'label': 'Perth'},
#  {'id': 'Q205699', 'label': 'GB'},
#  {'id': 'Q210317', 'label': 'MB'},
#  {'id': 'Q210352', 'label': 'PT'},
#  {'id': 'Q217469', 'label': 'TB'},
#  {'id': 'Q217863', 'label': 'PL'},
#  {'id': 'Q218008', 'label': 'SR'},
#  {'id': 'Q218681', 'label': 'BP'},
#  {'id': 'Q219113', 'label': 'ML'},
#  {'id': 'Q219275', 'label': 'NS'},
#  {'id': 'Q223859', 'label': 'CG'},
#  {'id': 'Q224015', 'label': 'NT'},
#  {'id': 'Q224506', 'label': 'RC'},
#  {'id': 'Q224441', 'label': 'FR'},
#  {'id': 'Q224408', 'label': 'Hulk'},
#  {'id': 'Q225351', 'label': 'Skin'},
#  {'id': 'Q225452', 'label': 'Explorer'},
#  {'id': 'Q226942', 'label': 'CAF'},
#  {'id': 'Q227580', 'label': 'GNU'},
#  {'id': 'Q227555', 'label': 'Acid'},
#  {'id': 'Q227465', 'label': 'STS'},
#  {'id': 'Q227964', 'label': 'FX'},
#  {'id': 'Q228905', 'label': 'AP'},
#  {'id': 'Q228919', 'label': 'Peso'},
#  {'id': 'Q229536', 'label': 'SSR'},
#  {'id': 'Q229965', 'label': 'MVP'},
#  {'id': 'Q233570', 'label': 'CSU'},
#  {'id': 'Q234484', 'label': 'Mineral'},
#  {'id': 'Q240551', 'label': 'TNI'},
#  {'id': 'Q241739', 'label': 'IRAS'},
#  {'id': 'Q254250', 'label': 'Smash'},
#  {'id': 'Q258086', 'label': 'UU'},
#  {'id': 'Q290466', 'label': 'ADN'},
#  {'id': 'Q294062', 'label': 'Plains'},
#  {'id': 'Q294834', 'label': 'Application'},
#  {'id': 'Q296451', 'label': 'Canadian'},
#  {'id': 'Q296374', 'label': 'Compostela'},
#  {'id': 'Q297874', 'label': 'Excel'},
#  {'id': 'Q304940', 'label': 'GMT'},
#  {'id': 'Q343285', 'label': 'Deadline'},
#  {'id': 'Q345852', 'label': 'NDR'},
#  {'id': 'Q355132', 'label': 'PMC'},
#  {'id': 'Q395112', 'label': 'Feel'},
#  {'id': 'Q398892', 'label': 'Ticino'},
#  {'id': 'Q404125', 'label': 'Wembley'},
#  {'id': 'Q406463', 'label': 'Vuelta'},
#  {'id': 'Q416166', 'label': 'Occidental'},
#  {'id': 'Q442140', 'label': 'MGM'},
#  {'id': 'Q1061243', 'label': 'Champions'},
#  {'id': 'Q1102313', 'label': 'Juventus'},
#  {'id': 'Q1178276', 'label': 'Sexy'},
#  {'id': 'Q1222011', 'label': 'Racing'},
#  {'id': 'Q1240025', 'label': 'WDR'},
#  {'id': 'Q1341706', 'label': 'Engagement'},
#  {'id': 'Q1411118', 'label': 'Ficus'},
#  {'id': 'Q1654286', 'label': 'IPAC'},
#  {'id': 'Q1918758', 'label': 'Meisterschaft'},
#  {'id': 'Q1997612', 'label': 'PhD'},
#  {'id': 'Q2325407', 'label': 'Stab'},
#  {'id': 'Q2739805', 'label': 'Wonderland'},
#  {'id': 'Q2787518', 'label': 'Door'},
#  {'id': 'Q2927224', 'label': 'Bryozoa'},
#  {'id': 'Q3150833', 'label': 'Information'},
#  {'id': 'Q3273902', 'label': 'Mac'},
#  {'id': 'Q3638419', 'label': 'Beograd'},
#  {'id': 'Q3881929', 'label': 'Oltre'},
#  {'id': 'Q4049442', 'label': 'Siege'},
#  {'id': 'Q4734969', 'label': 'Alpha'},
#  {'id': 'Q4855486', 'label': 'Cyber'},
#  {'id': 'Q8772118', 'label': 'Editorial'},
#  {'id': 'Q16086416', 'label': 'Palatinat'},
#  {'id': 'Q27796353', 'label': 'Sanskrit'},
#  {'id': 'Q55776776', 'label': 'Ra'},
#  {'id': 'Q66317860', 'label': 'Case'},
#  {'id': 'Q30230', 'label': 'Caribe'},
#  {'id': 'Q35968', 'label': 'Aquitania'},
#  {'id': 'Q41431', 'label': 'Commonwealth'},
#  {'id': 'Q81673', 'label': 'Print'},
#  {'id': 'Q129281', 'label': 'UCD'},
#  {'id': 'Q201961', 'label': 'TN'},
#  {'id': 'Q208534', 'label': 'AL'},
#  {'id': 'Q211146', 'label': 'MC'},
#  {'id': 'Q211535', 'label': 'MD'},
#  {'id': 'Q217451', 'label': 'PM'},
#  {'id': 'Q218292', 'label': 'Rochester'},
#  {'id': 'Q219294', 'label': 'PK'},
#  {'id': 'Q219349', 'label': 'KM'},
#  {'id': 'Q224158', 'label': 'Capitol'},
#  {'id': 'Q224837', 'label': 'NF'},
#  {'id': 'Q225803', 'label': 'EHF'},
#  {'id': 'Q225906', 'label': 'TD'},
#  {'id': 'Q226367', 'label': 'UV'},
#  {'id': 'Q226937', 'label': 'AFC'},
#  {'id': 'Q227161', 'label': 'NGC'},
#  {'id': 'Q228461', 'label': 'WBC'},
#  {'id': 'Q231372', 'label': 'Wanted'},
#  {'id': 'Q231718', 'label': 'Ariège'},
#  {'id': 'Q237685', 'label': 'IUE'},
#  {'id': 'Q257559', 'label': 'Transfer'},
#  {'id': 'Q287212', 'label': 'ABD'},
#  {'id': 'Q291840', 'label': 'Actor'},
#  {'id': 'Q292912', 'label': 'UDP'},
#  {'id': 'Q297514', 'label': 'KBS'},
#  {'id': 'Q299831', 'label': 'UAE'},
#  {'id': 'Q300167', 'label': 'AVN'},
#  {'id': 'Q333167', 'label': 'Abstieg'},
#  {'id': 'Q341990', 'label': 'Soft'},
#  {'id': 'Q345840', 'label': 'Vosges'},
#  {'id': 'Q346302', 'label': 'Northumberland'},
#  {'id': 'Q355842', 'label': 'Dominion'},
#  {'id': 'Q388885', 'label': 'After'},
#  {'id': 'Q398496', 'label': 'Outlook'},
#  {'id': 'Q399071', 'label': 'Botafogo'},
#  {'id': 'Q400506', 'label': 'Unknown'},
#  {'id': 'Q401151', 'label': 'Sorry'},
#  {'id': 'Q402103', 'label': 'UCB'},
#  {'id': 'Q402814', 'label': 'Normandie'},
#  {'id': 'Q405642', 'label': 'Spurs'},
#  {'id': 'Q408200', 'label': 'GDP'},
#  {'id': 'Q409534', 'label': 'Fonds'},
#  {'id': 'Q412517', 'label': 'Monkey'},
#  {'id': 'Q419356', 'label': 'Fontainebleau'},
#  {'id': 'Q438380', 'label': 'Alternate'},
#  {'id': 'Q564801', 'label': 'IBM'},
#  {'id': 'Q652630', 'label': 'Nuclear'},
#  {'id': 'Q781244', 'label': 'Australia'},
#  {'id': 'Q790812', 'label': 'Aviation'},
#  {'id': 'Q1010300', 'label': 'Giants'},
#  {'id': 'Q1135348', 'label': 'Corrientes'},
#  {'id': 'Q1812303', 'label': 'Mao'},
#  {'id': 'Q1878377', 'label': 'Luzern'},
#  {'id': 'Q2032596', 'label': 'KHL'},
#  {'id': 'Q2162333', 'label': 'Rage'},
#  {'id': 'Q2468155', 'label': 'USD'},
#  {'id': 'Q2479525', 'label': 'Warrior'},
#  {'id': 'Q2700487', 'label': 'Product'},
#  {'id': 'Q2710624', 'label': 'Victoria'},
#  {'id': 'Q2990970', 'label': 'Comtat'},
#  {'id': 'Q3955121', 'label': 'Sempre'},
#  {'id': 'Q3959195', 'label': 'Sharks'},
#  {'id': 'Q4466098', 'label': 'Turki'},
#  {'id': 'Q7187795', 'label': 'Photography'},
#  {'id': 'Q7312074', 'label': 'Remote'},
#  {'id': 'Q10353862', 'label': 'Primeiro'},
#  {'id': 'Q12794882', 'label': 'Limita'},
#  {'id': 'Q13409125', 'label': 'Futsal'},
#  {'id': 'Q16059965', 'label': 'Jalisco'},
#  {'id': 'Q16245021', 'label': 'AAA'},
#  {'id': 'Q16801563', 'label': 'Collected'},
#  {'id': 'Q20033', 'label': 'Help'},
#  {'id': 'Q63956', 'label': 'Out'},
#  {'id': 'Q83254', 'label': 'Zealand'},
#  {'id': 'Q157119', 'label': 'Monitor'},
#  {'id': 'Q217400', 'label': 'AG'},
#  {'id': 'Q218015', 'label': 'NP'},
#  {'id': 'Q219156', 'label': 'Pasadena'},
#  {'id': 'Q219206', 'label': 'BC'},
#  {'id': 'Q219311', 'label': 'UK'},
#  {'id': 'Q223796', 'label': 'SS'},
#  {'id': 'Q223990', 'label': 'MW'},
#  {'id': 'Q223989', 'label': 'MV'},
#  {'id': 'Q224196', 'label': 'Pegasus'},
#  {'id': 'Q224679', 'label': 'Cherokee'},
#  {'id': 'Q224760', 'label': 'KV'},
#  {'id': 'Q224992', 'label': 'Crash'},
#  {'id': 'Q225160', 'label': 'NN'},
#  {'id': 'Q225768', 'label': 'MJ'},
#  {'id': 'Q226531', 'label': 'AIM'},
#  {'id': 'Q228647', 'label': 'Transit'},
#  {'id': 'Q230645', 'label': 'XP'},
#  {'id': 'Q231743', 'label': 'Calvados'},
#  {'id': 'Q232330', 'label': 'Gateway'},
#  {'id': 'Q234694', 'label': 'Cours'},
#  {'id': 'Q235277', 'label': 'NY'},
#  {'id': 'Q235342', 'label': 'Stat'},
#  {'id': 'Q248506', 'label': 'PJ'},
#  {'id': 'Q254560', 'label': 'Elite'},
#  {'id': 'Q255696', 'label': 'Machine'},
#  {'id': 'Q294383', 'label': 'RD'},
#  {'id': 'Q294642', 'label': 'ANC'},
#  {'id': 'Q298967', 'label': 'RJ'},
#  {'id': 'Q318812', 'label': 'Abend'},
#  {'id': 'Q342055', 'label': 'IEC'},
#  {'id': 'Q346810', 'label': 'Township'},
#  {'id': 'Q354302', 'label': 'GMA'},
#  {'id': 'Q367421', 'label': 'Galatasaray'},
#  {'id': 'Q380124', 'label': 'Daniel'},
#  {'id': 'Q394945', 'label': 'Tucumán'},
#  {'id': 'Q397257', 'label': 'Austrian'},
#  {'id': 'Q398956', 'label': 'Carnaval'},
#  {'id': 'Q399189', 'label': 'Orchestra'},
#  {'id': 'Q405105', 'label': 'TKO'},
#  {'id': 'Q407637', 'label': 'PIB'},
#  {'id': 'Q411388', 'label': 'Verso'},
#  {'id': 'Q418087', 'label': 'Senators'},
#  {'id': 'Q422814', 'label': 'Triple'},
#  {'id': 'Q446168', 'label': 'SR'},
#  {'id': 'Q446861', 'label': 'USSR'},
#  {'id': 'Q447822', 'label': 'Faces'},
#  {'id': 'Q448871', 'label': 'Trail'},
#  {'id': 'Q569320', 'label': 'Connection'},
#  {'id': 'Q924703', 'label': 'Stop'},
#  {'id': 'Q1033389', 'label': 'Cannes'},
#  {'id': 'Q1143963', 'label': 'Cunha'},
#  {'id': 'Q1212728', 'label': 'Linia'},
#  {'id': 'Q1262879', 'label': 'SDSS'},
#  {'id': 'Q1295314', 'label': 'Eucalyptus'},
#  {'id': 'Q1308665', 'label': 'Einsatz'},
#  {'id': 'Q1504290', 'label': 'Picardie'},
#  {'id': 'Q2136572', 'label': 'Planets'},
#  {'id': 'Q2364480', 'label': 'Winter'},
#  {'id': 'Q2389942', 'label': 'Complete'},
#  {'id': 'Q3191476', 'label': 'KPD'},
#  {'id': 'Q3441854', 'label': 'Rookie'},
#  {'id': 'Q4151233', 'label': 'Guayaquil'},
#  {'id': 'Q4335543', 'label': 'Opus'},
#  {'id': 'Q4673426', 'label': 'Exodus'},
#  {'id': 'Q4742725', 'label': 'America'},
#  {'id': 'Q5464688', 'label': 'Follow'},
#  {'id': 'Q7157162', 'label': 'Pe'},
#  {'id': 'Q10898697', 'label': 'Indigenous'},
#  {'id': 'Q11945493', 'label': 'Riau'},
#  {'id': 'Q12477765', 'label': 'Bumi'},
#  {'id': 'Q12505648', 'label': 'Pinus'},
#  {'id': 'Q15176913', 'label': 'Moldavia'},
#  {'id': 'Q16466960', 'label': 'Portrait'},
#  {'id': 'Q18706971', 'label': 'Chinese'},
#  {'id': 'Q96378604', 'label': 'Fortune'},
#  {'id': 'Q106890319', 'label': 'Eagle'},
#  {'id': 'Q59056', 'label': 'RT'},
#  {'id': 'Q184737', 'label': 'Sign'},
#  {'id': 'Q204674', 'label': 'MS'},
#  {'id': 'Q211833', 'label': 'Acre'},
#  {'id': 'Q218057', 'label': 'CR'},
#  {'id': 'Q218352', 'label': 'EC'},
#  {'id': 'Q223829', 'label': 'NL'},
#  {'id': 'Q224072', 'label': 'Yucatán'},
#  {'id': 'Q224044', 'label': 'EM'},
#  {'id': 'Q224129', 'label': 'JP'},
#  {'id': 'Q224421', 'label': 'HD'},
#  {'id': 'Q224503', 'label': 'AFI'},
#  {'id': 'Q224809', 'label': 'DD'},
#  {'id': 'Q225125', 'label': 'IB'},
#  {'id': 'Q225354', 'label': 'Detroit'},
#  {'id': 'Q225644', 'label': 'CBC'},
#  {'id': 'Q225804', 'label': 'AFL'},
#  {'id': 'Q226368', 'label': 'CW'},
#  {'id': 'Q226494', 'label': 'CDC'},
#  {'id': 'Q230550', 'label': 'Guadalcanal'},
#  {'id': 'Q231202', 'label': 'FIS'},
#  {'id': 'Q233200', 'label': 'Spa'},
#  {'id': 'Q242158', 'label': 'RSS'},
#  {'id': 'Q246568', 'label': 'ITV'},
#  {'id': 'Q247419', 'label': 'Buzz'},
#  {'id': 'Q248666', 'label': 'CJ'},
#  {'id': 'Q249332', 'label': 'Dis'},
#  {'id': 'Q251944', 'label': 'IOC'},
#  {'id': 'Q258030', 'label': 'LM'},
#  {'id': 'Q293399', 'label': 'Tunnel'},
#  {'id': 'Q299265', 'label': 'Yokohama'},
#  {'id': 'Q338902', 'label': 'Access'},
#  {'id': 'Q343634', 'label': 'Attack'},
#  {'id': 'Q355826', 'label': 'Nebraska'},
#  {'id': 'Q358484', 'label': 'SMA'},
#  {'id': 'Q361425', 'label': 'Cantal'},
#  {'id': 'Q396302', 'label': 'Gotland'},
#  {'id': 'Q399469', 'label': 'Tonight'},
#  {'id': 'Q414018', 'label': 'Punta'},
#  {'id': 'Q417061', 'label': 'Tiempo'},
#  {'id': 'Q421555', 'label': 'Speedway'},
#  {'id': 'Q422129', 'label': 'EUA'},
#  {'id': 'Q489031', 'label': 'Midnight'},
#  {'id': 'Q493413', 'label': 'Saskatchewan'},
#  {'id': 'Q597406', 'label': 'SDP'},
#  {'id': 'Q814064', 'label': 'Beer'},
#  {'id': 'Q831025', 'label': 'Beteiligung'},
#  {'id': 'Q838655', 'label': 'Noah'},
#  {'id': 'Q940704', 'label': 'Kosovo'},
#  {'id': 'Q1178054', 'label': 'Winnipeg'},
#  {'id': 'Q1207094', 'label': 'Schritt'},
#  {'id': 'Q1211661', 'label': 'Korps'},
#  {'id': 'Q1294710', 'label': 'Science'},
#  {'id': 'Q1397605', 'label': 'Fassung'},
#  {'id': 'Q1523253', 'label': 'Horizon'},
#  {'id': 'Q1552936', 'label': 'Colonial'},
#  {'id': 'Q1718730', 'label': 'KK'},
#  {'id': 'Q1925682', 'label': 'Metro'},
#  {'id': 'Q1948773', 'label': 'Verder'},
#  {'id': 'Q1961363', 'label': 'NRK'},
#  {'id': 'Q2009691', 'label': 'Orange'},
#  {'id': 'Q2080737', 'label': 'Live'},
#  {'id': 'Q2083514', 'label': 'Pfeiffer'},
#  {'id': 'Q2108274', 'label': 'Days'},
#  {'id': 'Q2127785', 'label': 'Brussels'},
#  {'id': 'Q2239446', 'label': 'Schleswig'},
#  {'id': 'Q2649608', 'label': 'Almanya'},
#  {'id': 'Q2751435', 'label': 'Girls'},
#  {'id': 'Q2979262', 'label': 'Clin'},
#  {'id': 'Q3351671', 'label': 'Olympique'},
#  {'id': 'Q3724873', 'label': 'Empty'},
#  {'id': 'Q3791810', 'label': 'Identity'},
#  {'id': 'Q4049313', 'label': 'Services'},
#  {'id': 'Q6640640', 'label': 'Spectrum'},
#  {'id': 'Q8847169', 'label': 'Extremadura'},
#  {'id': 'Q12307355', 'label': 'Dansk'},
#  {'id': 'Q12490534', 'label': 'Kelas'},
#  {'id': 'Q12491461', 'label': 'Ketika'},
#  {'id': 'Q12958579', 'label': 'Muslimani'},
#  {'id': 'Q16801568', 'label': 'Complete'},
#  {'id': 'Q17573619', 'label': 'Handlung'},
#  {'id': 'Q20903134', 'label': 'Banská'},
#  {'id': 'Q29652800', 'label': 'Affair'},
#  {'id': 'Q32978432', 'label': 'Palma'},
#  {'id': 'Q57000599', 'label': 'avoir'},
#  {'id': 'Q21071', 'label': 'J'},
#  {'id': 'Q33589', 'label': 'IQ'},
#  {'id': 'Q60541', 'label': 'Midlands'},
#  {'id': 'Q167763', 'label': 'SW'},
#  {'id': 'Q171257', 'label': 'Taxi'},
#  {'id': 'Q193309', 'label': 'PS'},
#  {'id': 'Q206923', 'label': 'ES'},
#  {'id': 'Q217453', 'label': 'DS'},
#  {'id': 'Q218689', 'label': 'BR'},
#  {'id': 'Q218782', 'label': 'PG'},
#  {'id': 'Q219132', 'label': 'Volga'},
#  {'id': 'Q219130', 'label': 'NC'},
#  {'id': 'Q219189', 'label': 'ICE'},
#  {'id': 'Q224177', 'label': 'CAD'},
#  {'id': 'Q224472', 'label': 'CC'},
#  {'id': 'Q224959', 'label': 'Meiji'},
#  {'id': 'Q225151', 'label': 'RM'},
#  {'id': 'Q225787', 'label': 'Culture'},
#  {'id': 'Q225829', 'label': 'Instrument'},
#  {'id': 'Q226094', 'label': 'Normal'},
#  {'id': 'Q226378', 'label': 'PV'},
#  {'id': 'Q226434', 'label': 'NFC'},
#  {'id': 'Q226838', 'label': 'SED'},
#  {'id': 'Q228330', 'label': 'SAD'},
#  {'id': 'Q228994', 'label': 'Monmouth'},
#  {'id': 'Q229343', 'label': 'DSM'},
#  {'id': 'Q230090', 'label': 'PGA'},
#  {'id': 'Q234414', 'label': 'NSV'},
#  {'id': 'Q246639', 'label': 'Limit'},
#  {'id': 'Q250274', 'label': 'USS'},
#  {'id': 'Q251380', 'label': 'Suez'},
#  {'id': 'Q253849', 'label': 'MBC'},
#  {'id': 'Q254035', 'label': 'ATR'},
#  {'id': 'Q256092', 'label': 'Fars'},
#  {'id': 'Q291805', 'label': 'CDU'},
#  {'id': 'Q292894', 'label': 'SMP'},
#  {'id': 'Q293189', 'label': 'Montreux'},
#  {'id': 'Q296627', 'label': 'MSK'},
#  {'id': 'Q299032', 'label': 'Soldier'},
#  {'id': 'Q342609', 'label': 'Shanghai'},
#  {'id': 'Q346486', 'label': 'THE'},
#  {'id': 'Q350382', 'label': 'VL'},
#  {'id': 'Q352026', 'label': 'NRW'},
#  {'id': 'Q352322', 'label': 'Battlefield'},
#  {'id': 'Q353073', 'label': 'Country'},
#  {'id': 'Q352850', 'label': 'Total'},
#  {'id': 'Q357626', 'label': 'CDATA'},
#  {'id': 'Q357794', 'label': 'Yahoo'},
#  {'id': 'Q361274', 'label': 'TNA'},
#  {'id': 'Q366140', 'label': 'Penguin'},
#  {'id': 'Q399642', 'label': 'Ibiza'},
#  {'id': 'Q399841', 'label': 'Oracle'},
#  {'id': 'Q400957', 'label': 'Sound'},
#  {'id': 'Q407425', 'label': 'SVT'},
#  {'id': 'Q411836', 'label': 'Saguenay'},
#  {'id': 'Q412940', 'label': 'Maybe'},
#  {'id': 'Q413154', 'label': 'ECW'},
#  {'id': 'Q416325', 'label': 'NYC'},
#  {'id': 'Q419342', 'label': 'Business'},
#  {'id': 'Q425060', 'label': 'Road'},
#  {'id': 'Q438562', 'label': 'Global'},
#  {'id': 'Q564568', 'label': 'PGC'},
#  {'id': 'Q642863', 'label': 'IFK'},
#  {'id': 'Q854831', 'label': 'Gericht'},
#  {'id': 'Q1102528', 'label': 'Closer'},
#  {'id': 'Q1164071', 'label': 'PlayStation'},
#  {'id': 'Q1217854', 'label': 'Langue'},
#  {'id': 'Q1247982', 'label': 'Issue'},
#  {'id': 'Q1559968', 'label': 'Housing'},
#  {'id': 'Q1744378', 'label': 'Verband'},
#  {'id': 'Q1886611', 'label': 'Mal'},
#  {'id': 'Q2088087', 'label': 'Apollo'},
#  {'id': 'Q2145687', 'label': 'Resident'},
#  {'id': 'Q2361380', 'label': 'Heritage'},
#  {'id': 'Q2695940', 'label': 'Silva'},
#  {'id': 'Q2793782', 'label': 'Alus'},
#  {'id': 'Q3726196', 'label': 'Entangled'},
#  {'id': 'Q3730835', 'label': 'grave'},
#  {'id': 'Q3979874', 'label': 'Typ'},
#  {'id': 'Q4021613', 'label': 'XXI'},
#  {'id': 'Q4826044', 'label': 'Auto'},
#  {'id': 'Q5469358', 'label': 'Forever'},
#  {'id': 'Q7089300', 'label': 'Olímpico'},
#  {'id': 'Q11242971', 'label': 'Miki'},
#  {'id': 'Q12898664', 'label': 'Allium'},
#  {'id': 'Q15883559', 'label': 'Schmid'},
#  {'id': 'Q17428244', 'label': 'Gold'},
#  {'id': 'Q25500266', 'label': 'Panda'},
#  {'id': 'Q30600575', 'label': 'Orlando'},
#  {'id': 'Q58477512', 'label': 'Blitz'},
#  {'id': 'Q24996', 'label': 'Dolls'},
#  {'id': 'Q108759', 'label': 'Prometheus'},
#  {'id': 'Q183385', 'label': 'Missing'},
#  {'id': 'Q211148', 'label': 'DM'},
#  {'id': 'Q217364', 'label': 'ER'},
#  {'id': 'Q217428', 'label': 'AF'},
#  {'id': 'Q217437', 'label': 'CV'},
#  {'id': 'Q217506', 'label': 'TT'},
#  {'id': 'Q218084', 'label': 'GT'},
#  {'id': 'Q218699', 'label': 'SL'},
#  {'id': 'Q224191', 'label': 'ATV'},
#  {'id': 'Q224271', 'label': 'DR'},
#  {'id': 'Q224389', 'label': 'GC'},
#  {'id': 'Q224498', 'label': 'PSP'},
#  {'id': 'Q224584', 'label': 'FN'},
#  {'id': 'Q225074', 'label': 'EV'},
#  {'id': 'Q225104', 'label': 'WP'},
#  {'id': 'Q227183', 'label': 'Middlesex'},
#  {'id': 'Q229479', 'label': 'UC'},
#  {'id': 'Q229673', 'label': 'XX'},
#  {'id': 'Q231740', 'label': 'Airport'},
#  {'id': 'Q232434', 'label': 'Unity'},
#  {'id': 'Q232676', 'label': 'UCI'},
#  {'id': 'Q235226', 'label': 'TX'},
#  {'id': 'Q235286', 'label': 'UE'},
#  {'id': 'Q246201', 'label': 'USC'},
#  {'id': 'Q246380', 'label': 'CCD'},
#  {'id': 'Q254350', 'label': 'Nacional'},
#  {'id': 'Q258106', 'label': 'NWA'},
#  {'id': 'Q292593', 'label': 'Minute'},
#  {'id': 'Q295519', 'label': 'Nickelodeon'},
#  {'id': 'Q296355', 'label': 'Belgrano'},
#  {'id': 'Q297286', 'label': 'ASCII'},
#  {'id': 'Q298947', 'label': 'Sundance'},
#  {'id': 'Q298999', 'label': 'WM'},
#  {'id': 'Q299172', 'label': 'Disneyland'},
#  {'id': 'Q299874', 'label': 'Estudiantes'},
#  {'id': 'Q342471', 'label': 'Interview'},
#  {'id': 'Q346664', 'label': 'ABA'},
#  {'id': 'Q348882', 'label': 'VOC'},
#  {'id': 'Q353528', 'label': 'Ipswich'},
#  {'id': 'Q354307', 'label': 'Malaya'},
#  {'id': 'Q356435', 'label': 'Godzilla'},
#  {'id': 'Q365907', 'label': 'Tübingen'},
#  {'id': 'Q366111', 'label': 'NSW'},
#  {'id': 'Q397932', 'label': 'Nièvre'},
#  {'id': 'Q398847', 'label': 'Survival'},
#  {'id': 'Q399814', 'label': 'Pirates'},
#  {'id': 'Q400581', 'label': 'Sisters'},
#  {'id': 'Q400960', 'label': 'Away'},
#  {'id': 'Q420940', 'label': 'TCN'},
#  {'id': 'Q529390', 'label': 'Slave'},
#  {'id': 'Q530112', 'label': 'Atelier'},
#  {'id': 'Q563377', 'label': 'PKK'},
#  {'id': 'Q750227', 'label': 'Astra'},
#  {'id': 'Q1060940', 'label': 'Pokémon'},
#  {'id': 'Q1172273', 'label': 'Gaelic'},
#  {'id': 'Q1184090', 'label': 'Sumatra'},
#  {'id': 'Q1206863', 'label': 'Anything'},
#  {'id': 'Q1220470', 'label': 'Huelva'},
#  {'id': 'Q1881261', 'label': 'MBA'},
#  {'id': 'Q2138147', 'label': 'Regio'},
#  {'id': 'Q2521424', 'label': 'VfB'},
#  {'id': 'Q2652034', 'label': 'Circle'},
#  {'id': 'Q2859358', 'label': 'Arabic'},
#  {'id': 'Q3125361', 'label': 'Habitants'},
#  {'id': 'Q3334660', 'label': 'Naast'},
#  {'id': 'Q3418142', 'label': 'Rallye'},
#  {'id': 'Q3524719', 'label': 'This'},
#  {'id': 'Q3553012', 'label': 'VQ'},
#  {'id': 'Q5518952', 'label': 'Galleria'},
#  {'id': 'Q6060744', 'label': 'Investment'},
#  {'id': 'Q7692238', 'label': 'Technical'},
#  {'id': 'Q8043348', 'label': 'Xbox'},
#  {'id': 'Q12231952', 'label': 'Qara'},
#  {'id': 'Q13862594', 'label': 'Move'},
#  {'id': 'Q19284026', 'label': 'Gewicht'},
#  {'id': 'Q29406723', 'label': 'Indonesia'},
#  {'id': 'Q30029155', 'label': 'Industria'},
#  {'id': 'Q27553', 'label': 'N'},
#  {'id': 'Q210481', 'label': 'Terminal'},
#  {'id': 'Q217407', 'label': 'Lotus'},
#  {'id': 'Q218880', 'label': 'Portsmouth'},
#  {'id': 'Q219990', 'label': 'Zoo'},
#  {'id': 'Q226812', 'label': 'LSD'},
#  {'id': 'Q229665', 'label': 'VR'},
#  {'id': 'Q232396', 'label': 'Christchurch'},
#  {'id': 'Q232651', 'label': 'DNS'},
#  {'id': 'Q233255', 'label': 'Stadium'},
#  {'id': 'Q235280', 'label': 'JK'},
#  {'id': 'Q297979', 'label': 'NHL'},
#  {'id': 'Q299037', 'label': 'ATM'},
#  {'id': 'Q361260', 'label': 'FDP'},
#  {'id': 'Q397535', 'label': 'Punk'},
#  {'id': 'Q405902', 'label': 'Showtime'},
#  {'id': 'Q414425', 'label': 'Dual'},
#  {'id': 'Q418977', 'label': 'Emergency'},
#  {'id': 'Q419006', 'label': 'Massacre'},
#  {'id': 'Q572224', 'label': 'Ontario'},
#  {'id': 'Q784301', 'label': 'Auszeichnung'},
#  {'id': 'Q849451', 'label': 'Daisy'},
#  {'id': 'Q933316', 'label': 'Gyula'},
#  {'id': 'Q1089851', 'label': 'Churchill'},
#  {'id': 'Q1180912', 'label': 'Deadline'},
#  {'id': 'Q1906705', 'label': 'Camera'},
#  {'id': 'Q1909354', 'label': 'Lieutenant'},
#  {'id': 'Q1999967', 'label': 'Sevilla'},
#  {'id': 'Q2239888', 'label': 'Wild'},
#  {'id': 'Q2293643', 'label': 'Abdullah'},
#  {'id': 'Q2559123', 'label': 'Format'},
#  {'id': 'Q2765380', 'label': 'Calais'},
#  {'id': 'Q3100526', 'label': 'Generation'},
#  {'id': 'Q3139302', 'label': 'Holden'},
#  {'id': 'Q3412467', 'label': 'Qi'},
#  {'id': 'Q4000030', 'label': 'RS'},
#  {'id': 'Q4358933', 'label': 'Friends'},
#  {'id': 'Q4928150', 'label': 'Bloom'},
#  {'id': 'Q4967008', 'label': 'Brief'},
#  {'id': 'Q5111273', 'label': 'Christmas'},
#  {'id': 'Q5639476', 'label': 'Hair'},
#  {'id': 'Q6029963', 'label': 'Infinity'},
#  {'id': 'Q6059568', 'label': 'Invasion'},
#  {'id': 'Q6059972', 'label': 'Panzer'},
#  {'id': 'Q9311359', 'label': 'Rochester'},
#  {'id': 'Q9385695', 'label': 'Zadar'},
#  {'id': 'Q12485845', 'label': 'Home'},
#  {'id': 'Q12581761', 'label': 'Rose'},
#  {'id': 'Q12628586', 'label': 'CO'},
#  {'id': 'Q13361651', 'label': 'Alba'},
#  {'id': 'Q16481706', 'label': 'Cindy'},
#  {'id': 'Q18247702', 'label': 'am'},
#  {'id': 'Q18252065', 'label': 'll'},
#  {'id': 'Q18252712', 'label': 'nr'},
#  {'id': 'Q18253050', 'label': 'pk'},
#  {'id': 'Q18253996', 'label': 'sea'},
#  {'id': 'Q18253801', 'label': 'ro'},
#  {'id': 'Q18254352', 'label': 'st'},
#  {'id': 'Q18254913', 'label': 'te'},
#  {'id': 'Q18255172', 'label': 'tu'},
#  {'id': 'Q18271765', 'label': 'Ty'},
#  {'id': 'Q18271848', 'label': 'Up'},
#  {'id': 'Q21509120', 'label': 'Denne'},
#  {'id': 'Q21923180', 'label': 'Diamonds'},
#  {'id': 'Q24192410', 'label': 'Mirage'},
#  {'id': 'Q27986472', 'label': 'Angels'},
#  {'id': 'Q28452105', 'label': 'Granada'},
#  {'id': 'Q30317202', 'label': 'Sogn'},
#  {'id': 'Q45373590', 'label': 'Led'},
#  {'id': 'Q54835880', 'label': 'GL'},
#  {'id': 'Q54951158', 'label': 'RPM'},
#  {'id': 'Q54952737', 'label': 'SE'},
#  {'id': 'Q55416169', 'label': 'Reihe'},
#  {'id': 'Q57285102', 'label': 'Monsieur'},
#  {'id': 'Q57387181', 'label': 'Sede'},
#  {'id': 'Q61829520', 'label': 'Bleu'},
#  {'id': 'Q63759910', 'label': 'Desse'},
#  {'id': 'Q65097054', 'label': 'Amiens'},
#  {'id': 'Q68241679', 'label': 'Poker'},
#  {'id': 'Q83350729', 'label': 'Fürsten'},
#  {'id': 'Q83362104', 'label': 'Kirche'},
#  {'id': 'Q83495887', 'label': 'Kaisers'},
#  {'id': 'Q86921287', 'label': 'Direito'},
#  {'id': 'Q87496921', 'label': 'â'},
#  {'id': 'Q92094971', 'label': 'Stadion'},
#  {'id': 'Q92801651', 'label': 'Viva'},
#  {'id': 'Q93539708', 'label': 'EL'},
#  {'id': 'Q99910245', 'label': 'Medi'},
#  {'id': 'Q101208629', 'label': 'Espagne'},
#  {'id': 'Q104592396', 'label': 'Haiti'},
#  {'id': 'Q105975002', 'label': 'Altar'},
#  {'id': 'Q106120903', 'label': 'Rechts'},
#  {'id': 'Q106598448', 'label': 'Blant'},
#  {'id': 'Q107328191', 'label': 'Zwei'},
#  {'id': 'Q107353244', 'label': 'Long'},
#  {'id': 'Q108115282', 'label': 'Norwich'},
#  {'id': 'Q26747', 'label': 'M'},
#  {'id': 'Q81367', 'label': 'Interface'},
#  {'id': 'Q223853', 'label': 'EPA'},
#  {'id': 'Q224860', 'label': 'RTS'},
#  {'id': 'Q227051', 'label': 'Alabama'},
#  {'id': 'Q234023', 'label': 'Ubuntu'},
#  {'id': 'Q355574', 'label': 'Grafschaft'},
#  {'id': 'Q405104', 'label': 'TVB'},
#  {'id': 'Q410090', 'label': 'Edit'},
#  {'id': 'Q491718', 'label': 'Andersson'},
#  {'id': 'Q537953', 'label': 'ET'},
#  {'id': 'Q645794', 'label': 'Bravo'},
#  {'id': 'Q694384', 'label': 'Atkinson'},
#  {'id': 'Q745626', 'label': 'Main'},
#  {'id': 'Q797082', 'label': 'Fantasia'},
#  {'id': 'Q958285', 'label': 'Orleans'},
#  {'id': 'Q1026787', 'label': 'California'},
#  {'id': 'Q1296442', 'label': 'Suche'},
#  {'id': 'Q1319799', 'label': 'Thor'},
#  {'id': 'Q1327819', 'label': 'Status'},
#  {'id': 'Q1642920', 'label': 'Somali'},
#  {'id': 'Q1873606', 'label': 'July'},
#  {'id': 'Q2496062', 'label': 'Escape'},
#  {'id': 'Q2594869', 'label': 'Caesar'},
#  {'id': 'Q2623469', 'label': 'Lucy'},
#  {'id': 'Q2787936', 'label': 'Gold'},
#  {'id': 'Q3062023', 'label': 'Exodus'},
#  {'id': 'Q3784114', 'label': 'Heidi'},
#  {'id': 'Q4976018', 'label': 'Brown'},
#  {'id': 'Q5120430', 'label': 'Cinderella'},
#  {'id': 'Q5831657', 'label': 'Empire'},
#  {'id': 'Q7314969', 'label': 'Rescue'},
#  {'id': 'Q7316514', 'label': 'Resurrection'},
#  {'id': 'Q7848093', 'label': 'Trust'},
#  {'id': 'Q7933206', 'label': 'Violet'},
#  {'id': 'Q14388777', 'label': 'Stay'},
#  {'id': 'Q14600451', 'label': 'Coimbra'},
#  {'id': 'Q17404013', 'label': 'ville'},
#  {'id': 'Q18032738', 'label': 'IV'},
#  {'id': 'Q18248086', 'label': 'can'},
#  {'id': 'Q18250408', 'label': 'epi'},
#  {'id': 'Q18251216', 'label': 'hl'},
#  {'id': 'Q18252027', 'label': 'lec'},
#  {'id': 'Q18252302', 'label': 'mic'},
#  {'id': 'Q18253877', 'label': 'rs'},
#  {'id': 'Q18253919', 'label': 'sal'},
#  {'id': 'Q18254232', 'label': 'soo'},
#  {'id': 'Q18254367', 'label': 'stb'},
#  {'id': 'Q18254425', 'label': 'sy'},
#  {'id': 'Q18254993', 'label': 'ti'},
#  {'id': 'Q18255263', 'label': 'ur'},
#  {'id': 'Q18255254', 'label': 'uns'},
#  {'id': 'Q18271837', 'label': 'Ga'},
#  {'id': 'Q18271854', 'label': 'Dre'},
#  {'id': 'Q18273727', 'label': 'N'},
#  {'id': 'Q18273748', 'label': 'Bey'},
#  {'id': 'Q19999956', 'label': 'Dunia'},
#  {'id': 'Q20763909', 'label': 'ANC'},
#  {'id': 'Q20776887', 'label': 'AN'},
#  {'id': 'Q21146555', 'label': 'Cl'},
#  {'id': 'Q24058576', 'label': 'Slater'},
#  {'id': 'Q30088881', 'label': 'Romsdal'},
#  {'id': 'Q41956548', 'label': 'Monate'},
#  {'id': 'Q49702595', 'label': 'Norsk'},
#  {'id': 'Q52297061', 'label': 'Symphony'},
#  {'id': 'Q54946840', 'label': 'PDF'},
#  {'id': 'Q55261804', 'label': 'Mata'},
#  {'id': 'Q56254935', 'label': 'Chartres'},
#  {'id': 'Q65113643', 'label': 'Seychelles'},
#  {'id': 'Q72099315', 'label': 'Ierland'},
#  {'id': 'Q76421738', 'label': 'Rahmen'},
#  {'id': 'Q87496172', 'label': 'G'},
#  {'id': 'Q87496891', 'label': 'Ö'},
#  {'id': 'Q87496192', 'label': 'O'},
#  {'id': 'Q96312023', 'label': 'Silent'},
#  {'id': 'Q97620128', 'label': 'Ayuntamiento'},
#  {'id': 'Q99909602', 'label': 'Ilha'},
#  {'id': 'Q99909912', 'label': 'Lingua'},
#  {'id': 'Q104854796', 'label': 'Vilaine'},
#  {'id': 'Q105534226', 'label': 'Kuzey'},
#  {'id': 'Q105696424', 'label': 'You'},
#  {'id': 'Q105938999', 'label': 'Gesundheit'},
#  {'id': 'Q106078349', 'label': 'Berlijn'},
#  {'id': 'Q106358395', 'label': 'Ivoire'},
#  {'id': 'Q106455137', 'label': 'Sergei'},
#  {'id': 'Q106854418', 'label': 'Cinta'},
#  {'id': 'Q186929', 'label': 'ATP'},
#  {'id': 'Q189192', 'label': 'Newcastle'},
#  {'id': 'Q218864', 'label': 'ARM'},
#  {'id': 'Q223984', 'label': 'Westminster'},
#  {'id': 'Q225061', 'label': 'PCI'},
#  {'id': 'Q225240', 'label': 'Scream'},
#  {'id': 'Q226430', 'label': 'PSD'},
#  {'id': 'Q226504', 'label': 'ACC'},
#  {'id': 'Q230684', 'label': 'MIT'},
#  {'id': 'Q235303', 'label': 'Belém'},
#  {'id': 'Q248351', 'label': 'UD'},
#  {'id': 'Q248579', 'label': 'CDP'},
#  {'id': 'Q251517', 'label': 'Tirol'},
#  {'id': 'Q333763', 'label': 'Overview'},
#  {'id': 'Q341597', 'label': 'Codex'},
#  {'id': 'Q410394', 'label': 'VP'},
#  {'id': 'Q456120', 'label': 'Amazon'},
#  {'id': 'Q865725', 'label': 'Birmingham'},
#  {'id': 'Q884435', 'label': 'Bliss'},
#  {'id': 'Q956394', 'label': 'Drummond'},
#  {'id': 'Q1030374', 'label': 'Campbell'},
#  {'id': 'Q1070204', 'label': 'Cherbourg'},
#  {'id': 'Q1256916', 'label': 'Drei'},
#  {'id': 'Q1259415', 'label': 'Wood'},
#  {'id': 'Q1539601', 'label': 'Oliver'},
#  {'id': 'Q1957178', 'label': 'Leopard'},
#  {'id': 'Q2112274', 'label': 'Spot'},
#  {'id': 'Q2328689', 'label': 'Mana'},
#  {'id': 'Q2858750', 'label': 'Appleton'},
#  {'id': 'Q2979645', 'label': 'Closer'},
#  {'id': 'Q3061207', 'label': 'Eva'},
#  {'id': 'Q3189142', 'label': 'Julie'},
#  {'id': 'Q3267045', 'label': 'Luke'},
#  {'id': 'Q4038628', 'label': 'Fantasy'},
#  {'id': 'Q4450566', 'label': 'Verder'},
#  {'id': 'Q5393523', 'label': 'Revolución'},
#  {'id': 'Q5940583', 'label': 'Hume'},
#  {'id': 'Q6059565', 'label': 'Invasion'},
#  {'id': 'Q6433359', 'label': 'Kosovo'},
#  {'id': 'Q6683823', 'label': 'Lost'},
#  {'id': 'Q6957370', 'label': 'Nada'},
#  {'id': 'Q10534808', 'label': 'In'},
#  {'id': 'Q11859230', 'label': 'Exit'},
#  {'id': 'Q12485007', 'label': 'Hai'},
#  {'id': 'Q12621611', 'label': 'Panic'},
#  {'id': 'Q12728901', 'label': 'Genius'},
#  {'id': 'Q16912117', 'label': 'Forever'},
#  {'id': 'Q18218479', 'label': 'ac'},
#  {'id': 'Q18250802', 'label': 'ge'},
#  {'id': 'Q18254405', 'label': 'su'},
#  {'id': 'Q18255009', 'label': 'tip'},
#  {'id': 'Q18271762', 'label': 'Wo'},
#  {'id': 'Q18273723', 'label': 'Re'},
#  {'id': 'Q18273726', 'label': 'Li'},
#  {'id': 'Q18273764', 'label': 'Om'},
#  {'id': 'Q18273730', 'label': 'Q'},
#  {'id': 'Q18273739', 'label': 'Tal'},
#  {'id': 'Q18273856', 'label': 'War'},
#  {'id': 'Q18274037', 'label': 'Rua'},
#  {'id': 'Q19696879', 'label': 'Carol'},
#  {'id': 'Q20828512', 'label': 'Oleh'},
#  {'id': 'Q21148571', 'label': 'Tiene'},
#  {'id': 'Q46045701', 'label': 'Steinicke'},
#  {'id': 'Q48373913', 'label': 'Meet'},
#  {'id': 'Q54871743', 'label': 'GSC'},
#  {'id': 'Q55270994', 'label': 'Esto'},
#  {'id': 'Q56243686', 'label': 'Stary'},
#  {'id': 'Q56636303', 'label': 'du'},
#  {'id': 'Q59261362', 'label': 'Sint'},
#  {'id': 'Q63142909', 'label': 'Auf'},
#  {'id': 'Q63439160', 'label': 'Louvain'},
#  {'id': 'Q63759634', 'label': 'Celle'},
#  {'id': 'Q63760833', 'label': 'Publié'},
#  {'id': 'Q64767593', 'label': 'Mivel'},
#  {'id': 'Q65101933', 'label': 'Depuis'},
#  {'id': 'Q65103770', 'label': 'Fel'},
#  {'id': 'Q83339623', 'label': 'Atas'},
#  {'id': 'Q83374140', 'label': 'Nietzsche'},
#  {'id': 'Q83441260', 'label': 'Straße'},
#  {'id': 'Q87496901', 'label': 'Ú'},
#  {'id': 'Q87496953', 'label': 'ï'},
#  {'id': 'Q97016786', 'label': 'Foi'},
#  {'id': 'Q98213289', 'label': 'Teil'},
#  {'id': 'Q104881460', 'label': 'Take'},
#  {'id': 'Q105536230', 'label': 'Neuen'},
#  {'id': 'Q105550829', 'label': 'Dei'},
#  {'id': 'Q106454845', 'label': 'Rossa'},
#  {'id': 'Q106505152', 'label': 'Dessa'},
#  {'id': 'Q108535286', 'label': 'Nello'},
#  {'id': 'Q109518211', 'label': 'Swansea'},
#  {'id': 'Q122407', 'label': 'MTA'},
#  {'id': 'Q132421', 'label': 'GPL'},
#  {'id': 'Q206375', 'label': 'Wimbledon'},
#  {'id': 'Q218723', 'label': 'PD'},
#  {'id': 'Q224035', 'label': 'SAR'},
#  {'id': 'Q225233', 'label': 'Nexus'},
#  {'id': 'Q232715', 'label': 'BBC'},
#  {'id': 'Q284148', 'label': 'Burn'},
#  {'id': 'Q293203', 'label': 'Aveyron'},
#  {'id': 'Q294559', 'label': 'Vintage'},
#  {'id': 'Q295943', 'label': 'Friendship'},
#  {'id': 'Q296284', 'label': 'UGC'},
#  {'id': 'Q298902', 'label': 'Idaho'},
#  {'id': 'Q366357', 'label': 'Globo'},
#  {'id': 'Q437726', 'label': 'Alter'},
#  {'id': 'Q743561', 'label': 'Jørgensen'},
#  {'id': 'Q791098', 'label': 'Fox'},
#  {'id': 'Q958298', 'label': 'Ribera'},
#  {'id': 'Q1140019', 'label': 'Crimea'},
#  {'id': 'Q1337961', 'label': 'Emma'},
#  {'id': 'Q1685187', 'label': 'Southwest'},
#  {'id': 'Q2186428', 'label': 'Asylum'},
#  {'id': 'Q2432646', 'label': 'Arena'},
#  {'id': 'Q2522635', 'label': 'Secrets'},
#  {'id': 'Q2642964', 'label': 'Woman'},
#  {'id': 'Q2746335', 'label': 'Raum'},
#  {'id': 'Q2792257', 'label': 'Horizon'},
#  {'id': 'Q2905403', 'label': 'Live'},
#  {'id': 'Q2923671', 'label': 'Branch'},
#  {'id': 'Q3051492', 'label': 'Elliott'},
#  {'id': 'Q4021355', 'label': 'XIV'},
#  {'id': 'Q4042338', 'label': 'Kraj'},
#  {'id': 'Q5402200', 'label': 'Energy'},
#  {'id': 'Q7097827', 'label': 'Operator'},
#  {'id': 'Q7858409', 'label': 'Twins'},
#  {'id': 'Q12332077', 'label': 'Portland'},
#  {'id': 'Q12798270', 'label': 'Panda'},
#  {'id': 'Q14333702', 'label': 'Seven'},
#  {'id': 'Q18247381', 'label': 'act'},
#  {'id': 'Q18247737', 'label': 'ap'},
#  {'id': 'Q18247838', 'label': 'asa'},
#  {'id': 'Q18248649', 'label': 'da'},
#  {'id': 'Q18252879', 'label': 'pad'},
#  {'id': 'Q18253073', 'label': 'pl'},
#  {'id': 'Q18253450', 'label': 'ras'},
#  {'id': 'Q18253806', 'label': 'rol'},
#  ...]

# %% [markdown]
# ### Postprocess and Save

# %%
import pandas as pd

# %%
# Entity Candidates to Dataframe
df = pd.DataFrame(cand)
print(dataframe)
# Out:
#               id    label
# 0         Q27213  Formula
# 1         Q27278        H
# 2         Q27931  Okinawa
# 3         Q30011        K
# 4        Q127942       JR
# ...          ...      ...
# 8187  Q106120386    Order
# 8188  Q106763844    Front
# 8189  Q107145221   Alonso
# 8190  Q108271743      Mem
# 8191  Q108492091    Tartu
#
# [8192 rows x 2 columns]

# %%
# Remove duplicate labels
df_wo_duplicates = df.drop_duplicates(subset='label', keep='first')
df_wo_duplicates
# Out:
#               id    label
# 0         Q27278        H
# 1         Q27931  Okinawa
# 2         Q30011        K
# 3        Q127942       JR
# 4        Q138698    Khmer
# ...          ...      ...
# 9924  Q104592425    Luigi
# 9925  Q106118969   Körper
# 9928  Q107441724     Drug
# 9930  Q107443100    Irina
# 9932  Q109579551  Despois
#
# [6525 rows x 2 columns]

# %%
df_wo_duplicates.loc[df['label'] == 'Alice']
# Out:
#             id  label
# 1986  Q3611661  Alice

# %%
# Save as CSV for manual cleanup
df_wo_duplicates.to_csv('SingleToken/entities_languageAgnostic_uncleaned.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
#       1 # Save as CSV for manual cleanup
# ----> 2 df.to_csv('Relations/properties_uncleaned.csv', index=False)
#
# NameError: name 'df' is not defined
