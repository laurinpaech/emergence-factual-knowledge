# %% [markdown]
# ### Multilingual labels for Symmetry and Equivalence

# %%
import pandas as pd
from qwikidata.entity import WikidataItem, WikidataLexeme, WikidataProperty
from qwikidata.linked_data_interface import get_entity_dict_from_api

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
db = client.wikidata
db.list_collection_names()
# Out:
# ['entity2_triples',
#  'entity_counts',
#  'triplesInvert',
#  'triples',
#  'equivalence',
#  'nsproperties',
#  'inversion',
#  'entity_subset',
#  'antonym',
#  'relation_subset',
#  'entityList',
#  'entity1_triples',
#  'properties',
#  'symmetry']

# %%
db.properties.count_documents({})
# Out:
# 1371

# %%
db.properties.find_one({})
# Out:
# {'_id': 'P1034'}

# %%
db.relation_subset.count_documents({})
# Out:
# 1142

# %%
db.relation_subset.find_one({})
# Out:
# {'_id': ObjectId('6210c432cf55a123777d8516'),
#  'id': 'P1034',
#  'type': 'property',
#  'labels': {'en': {'language': 'en', 'value': 'main food source'},
#   'nb': {'language': 'nb', 'value': 'hovednæringskilde'},
#   'ca': {'language': 'ca', 'value': "principal font d'alimentació"},
#   'pt': {'language': 'pt', 'value': 'principal fonte alimentar'},
#   'de': {'language': 'de', 'value': 'Hauptnahrungsquelle'},
#   'it': {'language': 'it', 'value': 'principale fonte di nutrizione'},
#   'hu': {'language': 'hu', 'value': 'fő élelemforrás'},
#   'fr': {'language': 'fr', 'value': 'source principale de nourriture'},
#   'pl': {'language': 'pl', 'value': 'główne źródło pożywienia'},
#   'es': {'language': 'es', 'value': 'fuente de alimento principal'},
#   'ru': {'language': 'ru', 'value': 'основной источник питания'},
#   'fa': {'language': 'fa', 'value': 'منبع غذایی اصلی'},
#   'nl': {'language': 'nl', 'value': 'belangrijkste voedselbron'},
#   'br': {'language': 'br', 'value': 'Mammenn emvagañ bennañ'},
#   'mk': {'language': 'mk', 'value': 'главен извор на исхрана'},
#   'cs': {'language': 'cs', 'value': 'hlavní zdroj potravy'},
#   'da': {'language': 'da', 'value': 'primær fødekilde'},
#   'nds': {'language': 'nds', 'value': 'wichtigst Freten'},
#   'uk': {'language': 'uk', 'value': 'ким харчується'},
#   'sr': {'language': 'sr', 'value': 'главни извор хране'},
#   'th': {'language': 'th', 'value': 'แหล่งอาหารหลัก'},
#   'ja': {'language': 'ja', 'value': '主な食料源'},
#   'ko': {'language': 'ko', 'value': '주로 먹는 것'},
#   'oc': {'language': 'oc', 'value': 'font principala de noiridura'},
#   'zh-mo': {'language': 'zh-mo', 'value': '主要食物來源'},
#   'zh': {'language': 'zh', 'value': '主要食物來源'},
#   'zh-cn': {'language': 'zh-cn', 'value': '主要食物来源'},
#   'zh-hans': {'language': 'zh-hans', 'value': '主要食物来源'},
#   'zh-hant': {'language': 'zh-hant', 'value': '主要食物來源'},
#   'zh-hk': {'language': 'zh-hk', 'value': '主要食物來源'},
#   'zh-my': {'language': 'zh-my', 'value': '主要食物来源'},
#   'zh-sg': {'language': 'zh-sg', 'value': '主要食物来源'},
#   'zh-tw': {'language': 'zh-tw', 'value': '主要食物來源'},
#   'ar': {'language': 'ar', 'value': 'مصدر الغذاء الرئيسي'},
#   'eo': {'language': 'eo', 'value': 'ĉefa manĝaĵo de organismo'},
#   'sq': {'language': 'sq', 'value': 'burim kryesor i ushqimit'},
#   'id': {'language': 'id', 'value': 'sumber makanan utama'},
#   'he': {'language': 'he', 'value': 'מקור מזון עיקרי'},
#   'ga': {'language': 'ga', 'value': 'príomhfhoinse bia'},
#   'tt': {'language': 'tt', 'value': 'Туклану чыганагы'},
#   'be-tarask': {'language': 'be-tarask',
#    'value': 'асноўная крыніца харчаваньня'},
#   'eu': {'language': 'eu', 'value': 'elikadura iturri nagusi'},
#   'fi': {'language': 'fi', 'value': 'pääasiallinen ravinto'},
#   'tr': {'language': 'tr', 'value': 'ana besin kaynağı'},
#   'sv': {'language': 'sv', 'value': 'huvudsaklig födokälla'},
#   'ba': {'language': 'ba', 'value': 'туҡланыу сығанағы'},
#   'bn': {'language': 'bn', 'value': 'প্রধান খাদ্যের উৎস'},
#   'vec': {'language': 'vec', 'value': 'prinsipałe fonte ałimentare'}}}

# %%
test  = db.triples.distinct('relation')

# %%
len(test)
# Out:
# 1371

# %%
# Load them into MongoDB
# Keep id, type, labels

for prop in propertyList:
    # Get Property
    p_dict = get_entity_dict_from_api(prop)
    
    # Take only a subset of keys
    p_subset = dict((k, p_dict[k]) for k in ('id', 'type', 'labels'))
    
    # Insert into collection
    db.symmetric.insert_one(p_subset)

# %%
# TODO: Maybe also use less used relations?
db.symmetric.find_one({})
# Out:
# {'_id': ObjectId('6210fede67e09f0d729923b3'),
#  'id': 'P530',
#  'type': 'property',
#  'labels': {'en': {'language': 'en', 'value': 'diplomatic relation'},
#   'nl': {'language': 'nl', 'value': 'diplomatieke relatie'},
#   'de': {'language': 'de', 'value': 'diplomatische Beziehung'},
#   'fa': {'language': 'fa', 'value': 'رابطۀ دیپلماتیک'},
#   'hu': {'language': 'hu', 'value': 'diplomáciai kapcsolat'},
#   'ca': {'language': 'ca', 'value': 'relació diplomàtica'},
#   'fr': {'language': 'fr', 'value': 'relation diplomatique'},
#   'it': {'language': 'it', 'value': 'relazione diplomatica'},
#   'sl': {'language': 'sl', 'value': 'diplomatski odnosi'},
#   'es': {'language': 'es', 'value': 'relación diplomática'},
#   'ru': {'language': 'ru', 'value': 'дипломатические отношения'},
#   'nn': {'language': 'nn', 'value': 'diplomatisk samband'},
#   'gu': {'language': 'gu', 'value': 'રાજદ્વારી સંબંધો'},
#   'sr': {'language': 'sr', 'value': 'дипломатски односи'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'дипломатски односи'},
#   'bs': {'language': 'bs', 'value': 'diplomatski odnosi'},
#   'he': {'language': 'he', 'value': 'יחסים דיפלומטיים'},
#   'pl': {'language': 'pl', 'value': 'stosunki dyplomatyczne'},
#   'zh-tw': {'language': 'zh-tw', 'value': '邦交國'},
#   'zh': {'language': 'zh', 'value': '邦交國'},
#   'el': {'language': 'el', 'value': 'διπλωματικές σχέσεις'},
#   'pt-br': {'language': 'pt-br', 'value': 'relação diplomática'},
#   'pt': {'language': 'pt', 'value': 'relação diplomática'},
#   'uk': {'language': 'uk', 'value': 'дипломатичні стосунки'},
#   'be': {'language': 'be', 'value': 'дыпламатычныя адносіны'},
#   'ja': {'language': 'ja', 'value': '国交のある国'},
#   'nb': {'language': 'nb', 'value': 'diplomatisk relasjon'},
#   'sv': {'language': 'sv', 'value': 'diplomatisk relation'},
#   'ta': {'language': 'ta', 'value': 'தூதரக உறவு'},
#   'sco': {'language': 'sco', 'value': 'diplomatic relation'},
#   'da': {'language': 'da', 'value': 'diplomatiske forbindelse'},
#   'vi': {'language': 'vi', 'value': 'quan hệ ngoại giao'},
#   'sk': {'language': 'sk', 'value': 'diplomatický vzťah'},
#   'zh-hans': {'language': 'zh-hans', 'value': '邦交国'},
#   'zh-hant': {'language': 'zh-hant', 'value': '邦交國'},
#   'cs': {'language': 'cs', 'value': 'diplomatický vztah'},
#   'eo': {'language': 'eo', 'value': 'diplomatia rilato'},
#   'fi': {'language': 'fi', 'value': 'diplomaattisuhteet'},
#   'scn': {'language': 'scn', 'value': 'havi rilazzioni diplumàtichi cu'},
#   'mk': {'language': 'mk', 'value': 'дипломатски односи'},
#   'eu': {'language': 'eu', 'value': 'diplomazia-harremana'},
#   'ko': {'language': 'ko', 'value': '수교국'},
#   'ro': {'language': 'ro', 'value': 'relație diplomatică'},
#   'nds': {'language': 'nds', 'value': 'diplomaatsche Relatschoon'},
#   'zh-hk': {'language': 'zh-hk', 'value': '邦交國'},
#   'zh-cn': {'language': 'zh-cn', 'value': '邦交国'},
#   'zh-mo': {'language': 'zh-mo', 'value': '邦交國'},
#   'zh-my': {'language': 'zh-my', 'value': '邦交国'},
#   'zh-sg': {'language': 'zh-sg', 'value': '邦交国'},
#   'lv': {'language': 'lv', 'value': 'diplomātiskās attiecības'},
#   'gl': {'language': 'gl', 'value': 'relación diplomática'},
#   'ar': {'language': 'ar', 'value': 'العلاقات الدبلوماسية'},
#   'lt': {'language': 'lt', 'value': 'diplomatiniai ryšiai'},
#   'ps': {'language': 'ps', 'value': 'ديپلوماتيکي اړيکې'},
#   'et': {'language': 'et', 'value': 'diplomaatilised suhted'},
#   'id': {'language': 'id', 'value': 'hubungan diplomasi'},
#   'ia': {'language': 'ia', 'value': 'relation diplomatic'},
#   'ka': {'language': 'ka', 'value': 'დიპლომატიური ურთიერთობა'},
#   'ku-latn': {'language': 'ku-latn', 'value': 'têkiliya dîplomatîk'},
#   'bg': {'language': 'bg', 'value': 'дипломатически отношения'},
#   'bn': {'language': 'bn', 'value': 'আন্তর্জাতিক সম্পর্ক'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'дыпляматычныя стасункі'},
#   'tg': {'language': 'tg', 'value': 'робитаҳои дипломатӣ'},
#   'tr': {'language': 'tr', 'value': 'diplomatik ilişki(ler)'},
#   'tt': {'language': 'tt', 'value': 'дипломатик мөнәсәбәтләр'},
#   'lfn': {'language': 'lfn', 'value': 'relata diplomata'},
#   'is': {'language': 'is', 'value': 'stjórnmálasamband'},
#   'hy': {'language': 'hy', 'value': 'դիվանագիտական հարաբերություններ'},
#   'hr': {'language': 'hr', 'value': 'diplomatski odnosi'},
#   'lb': {'language': 'lb', 'value': 'diplomatesch Relatioun'},
#   'sq': {'language': 'sq', 'value': 'lidhje diplomatike'},
#   'ur': {'language': 'ur', 'value': 'سفارتی تعلقات'},
#   'am': {'language': 'am', 'value': 'የዲፕሎማቲክ ግንኙነት'},
#   'nqo': {'language': 'nqo', 'value': 'ߕߍߓߊ߯ߦߊ ߕߋߙߌߦߊ'},
#   'vec': {'language': 'vec', 'value': 'rełasion diplomàtega'},
#   'th': {'language': 'th', 'value': 'ความสัมพันธ์ทางการทูต'},
#   'ms-arab': {'language': 'ms-arab', 'value': 'هوبوڠن ديڤلوماتيک'},
#   'cy': {'language': 'cy', 'value': 'perthynas diplomataidd'}}}

# %% [markdown]
# #### Utils

# %%
def isLatin(s):
    try:
        s.encode('latin-1')
    except UnicodeEncodeError:
        return False
    else:
        return True

# %%
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)

# %%
def all_same(items):
    return all(x == items[0] for x in items)

# %% [markdown]
# #### Processing

# %%
# Set multilingual labels for them
query_languages = ('en','es','fr','de')

# %%
# Only get relations that are available in query_languages
# Should not be the same in all languages
cand = []
candNon = []

for document in db.symmetric.find({}):
    if all(k in document['labels'] for k in query_languages):
        # Ignore relations that are the same in all languages
        labels = [document['labels'][k]['value'] for k in query_languages]
        if all_same(labels): continue
        
        # Sanity check if there are properties that are not in latin script or broken
        if not has_numbers(document['labels']['en']['value']) and isLatin(document['labels']['en']['value']):
            j = {'id': document['id']}
            for k in query_languages: j[k] = document['labels'][k]['value']
            cand.append(j)
        else:
            j = {'id': document['id']}
            for k in query_languages: j[k] = document['labels'][k]['value']
            candNon.append(j)

# %%
cand
# Out:
# [{'id': 'P530',
#   'en': 'diplomatic relation',
#   'es': 'relación diplomática',
#   'fr': 'relation diplomatique',
#   'de': 'diplomatische Beziehung'},
#  {'id': 'P47',
#   'en': 'shares border with',
#   'es': 'comparte fronteras con',
#   'fr': 'limitrophe de',
#   'de': 'gemeinsame Grenze mit'},
#  {'id': 'P461',
#   'en': 'opposite of',
#   'es': 'opuesto a',
#   'fr': 'contraire',
#   'de': 'Gegenteil von'},
#  {'id': 'P460',
#   'en': 'said to be the same as',
#   'es': 'se dice que es lo mismo que',
#   'fr': 'réputé identique à',
#   'de': 'eventuell gleichwertig'},
#  {'id': 'P3373',
#   'en': 'sibling',
#   'es': 'hermano o hermana',
#   'fr': 'frère ou sœur',
#   'de': 'Geschwister'},
#  {'id': 'P26',
#   'en': 'spouse',
#   'es': 'cónyuge',
#   'fr': 'conjoint',
#   'de': 'Ehepartner(in)'},
#  {'id': 'P7047',
#   'en': 'enemy of',
#   'es': 'enemigo de',
#   'fr': 'ennemi de',
#   'de': 'Feind von'},
#  {'id': 'P451',
#   'en': 'unmarried partner',
#   'es': 'pareja',
#   'fr': 'partenaire',
#   'de': 'Lebenspartner/-in'},
#  {'id': 'P112',
#   'en': 'founded by',
#   'es': 'fundador',
#   'fr': 'fondateur',
#   'de': 'Gründer'},
#  {'id': 'P1889',
#   'en': 'different from',
#   'es': 'diferente de',
#   'fr': 'à ne pas confondre avec',
#   'de': 'verschieden von'},
#  {'id': 'P1336',
#   'en': 'territory claimed by',
#   'es': 'territorio reivindicado por',
#   'fr': 'territoire revendiqué par',
#   'de': 'Gebiet wird beansprucht von'},
#  {'id': 'P2959',
#   'en': 'permanent duplicated item',
#   'es': 'ítem duplicado permanente',
#   'fr': 'élément doublon permanent',
#   'de': 'dauerhaftes Duplikat von'},
#  {'id': 'P3403',
#   'en': 'coextensive with',
#   'es': 'mismo territorio que',
#   'fr': 'a le même territoire que',
#   'de': 'koexistiert mit'},
#  {'id': 'P190',
#   'en': 'twinned administrative body',
#   'es': 'ciudad hermana',
#   'fr': 'jumelage ou partenariat',
#   'de': 'Partnerkommune'},
#  {'id': 'P2152',
#   'en': 'antiparticle',
#   'es': 'antipartícula',
#   'fr': 'antiparticule',
#   'de': 'Antiteilchen'},
#  {'id': 'P155',
#   'en': 'follows',
#   'es': 'precedido por',
#   'fr': 'précédé par',
#   'de': 'Vorgänger'},
#  {'id': 'P156',
#   'en': 'followed by',
#   'es': 'sucedido por',
#   'fr': 'suivi par',
#   'de': 'Nachfolger'},
#  {'id': 'P3075',
#   'en': 'official religion',
#   'es': 'religión oficial',
#   'fr': 'religion officielle',
#   'de': 'offizielle Religion'},
#  {'id': 'P1382',
#   'en': 'partially coincident with',
#   'es': 'parcialmente coincidente con',
#   'fr': 'coïncide partiellement avec',
#   'de': 'teilweise übereinstimmend mit'},
#  {'id': 'P463',
#   'en': 'member of',
#   'es': 'miembro de',
#   'fr': 'membre de',
#   'de': 'Mitglied von'},
#  {'id': 'P4777',
#   'en': 'has boundary',
#   'es': 'delimitado por',
#   'fr': 'délimité par',
#   'de': 'hat als Grenze'},
#  {'id': 'P1038',
#   'en': 'relative',
#   'es': 'pariente',
#   'fr': 'parentèle',
#   'de': 'Verwandte'},
#  {'id': 'P197',
#   'en': 'adjacent station',
#   'es': 'estación adyacente',
#   'fr': 'gare voisine',
#   'de': 'benachbarte Station'},
#  {'id': 'P833',
#   'en': 'interchange station',
#   'es': 'estación de intercambio',
#   'fr': "pôle d'échanges",
#   'de': 'Umsteigebahnhof'},
#  {'id': 'P1365',
#   'en': 'replaces',
#   'es': 'reemplaza a',
#   'fr': 'remplace',
#   'de': 'ersetzt'},
#  {'id': 'P974',
#   'en': 'tributary',
#   'es': 'afluente',
#   'fr': 'affluent',
#   'de': 'Nebenfluss'},
#  {'id': 'P1366',
#   'en': 'replaced by',
#   'es': 'reemplazado por',
#   'fr': 'remplacé par',
#   'de': 'ersetzt durch'},
#  {'id': 'P2789',
#   'en': 'connects with',
#   'es': 'se conecta con',
#   'fr': 'se connecte avec',
#   'de': 'physisch verbunden mit'},
#  {'id': 'P131',
#   'en': 'located in the administrative territorial entity',
#   'es': 'situado en la entidad territorial administrativa',
#   'fr': 'localisation administrative',
#   'de': 'liegt in der Verwaltungseinheit'},
#  {'id': 'P3342',
#   'en': 'significant person',
#   'es': 'persona relevante',
#   'fr': 'personne clé',
#   'de': 'relevante Person'},
#  {'id': 'P2293',
#   'en': 'genetic association',
#   'es': 'asociación genética',
#   'fr': 'association génétique',
#   'de': 'genetische Assoziation mit'},
#  {'id': 'P1269',
#   'en': 'facet of',
#   'es': 'faceta de',
#   'fr': 'aspect de',
#   'de': 'Aspekt von'},
#  {'id': 'P1000',
#   'en': 'record held',
#   'es': 'récord',
#   'fr': 'record détenu',
#   'de': 'Rekord'},
#  {'id': 'P2743',
#   'en': 'this zoological name is coordinate with',
#   'es': 'nombre zoológico coordinado por',
#   'fr': 'ce nom zoologique est coordonné avec',
#   'de': 'zugeordneter zoologische Name'},
#  {'id': 'P81',
#   'en': 'connecting line',
#   'es': 'línea de ferrocarril',
#   'fr': 'ligne de chemin de fer',
#   'de': 'Strecke'},
#  {'id': 'P1552',
#   'en': 'has quality',
#   'es': 'caracterizado por',
#   'fr': 'caractérisé par',
#   'de': 'charakterisiert durch'},
#  {'id': 'P1327',
#   'en': 'partner in business or sport',
#   'es': 'en conjunto con',
#   'fr': 'partenaire professionnel ou sportif',
#   'de': 'Berufs- oder Sportpartner'},
#  {'id': 'P399',
#   'en': 'companion of',
#   'es': 'compañero de',
#   'fr': 'compagnon de',
#   'de': 'Begleiter'},
#  {'id': 'P361',
#   'en': 'part of',
#   'es': 'forma parte de',
#   'fr': 'partie de',
#   'de': 'ist Teil von'},
#  {'id': 'P1560',
#   'en': 'given name version for other gender',
#   'es': 'nombre correspondiente en el otro género',
#   'fr': 'prénom correspondant dans le genre grammatical opposé',
#   'de': 'äquivalenter Vorname für das andere Geschlecht'},
#  {'id': 'P1420',
#   'en': 'taxon synonym',
#   'es': 'sinónimo taxonómico',
#   'fr': 'synonyme taxinomique',
#   'de': 'taxonomische Synonyme'},
#  {'id': 'P1037',
#   'en': 'director / manager',
#   'es': 'gerente/director',
#   'fr': 'dirigeant',
#   'de': 'Leiter'},
#  {'id': 'P169',
#   'en': 'chief executive officer',
#   'es': 'director ejecutivo',
#   'fr': 'directeur général',
#   'de': 'Geschäftsführer'},
#  {'id': 'P2579',
#   'en': 'studied by',
#   'es': 'estudiado por',
#   'fr': "discipline dont c'est l'objet",
#   'de': 'Forschungsthema in'},
#  {'id': 'P129',
#   'en': 'physically interacts with',
#   'es': 'interactúa físicamente con',
#   'fr': 'interagit physiquement avec',
#   'de': 'interagiert physikalisch mit'},
#  {'id': 'P36',
#   'en': 'capital',
#   'es': 'capital',
#   'fr': 'capitale',
#   'de': 'Hauptstadt'},
#  {'id': 'P767',
#   'en': 'contributor to the creative work or subject',
#   'es': 'colaborador',
#   'fr': 'collaborateur',
#   'de': 'Mitarbeiter des Werks'},
#  {'id': 'P1322',
#   'en': 'dual to',
#   'es': 'dual de',
#   'fr': 'dual de',
#   'de': 'dual zu'},
#  {'id': 'P170',
#   'en': 'creator',
#   'es': 'creador',
#   'fr': 'créateur',
#   'de': 'Urheber'},
#  {'id': 'P17', 'en': 'country', 'es': 'país', 'fr': 'pays', 'de': 'Staat'},
#  {'id': 'P2375',
#   'en': 'has superpartner',
#   'es': 'tiene como s-partícula',
#   'fr': 'a comme superpartenaire',
#   'de': 'hat Superpartner'},
#  {'id': 'P8702',
#   'en': 'parallel street',
#   'es': 'calle paralela',
#   'fr': 'rue parallèle',
#   'de': 'Parallelstraße'},
#  {'id': 'P279',
#   'en': 'subclass of',
#   'es': 'subclase de',
#   'fr': 'sous-classe de',
#   'de': 'Unterklasse von'},
#  {'id': 'P40',
#   'en': 'child',
#   'es': 'hijo o hija',
#   'fr': 'enfant',
#   'de': 'Kind(er)'},
#  {'id': 'P769',
#   'en': 'significant drug interaction',
#   'es': 'acción farmacológica alterada por',
#   'fr': 'interaction médicamenteuse avec',
#   'de': 'signifikante Arzneimittelwechselwirkung'},
#  {'id': 'P5278',
#   'en': 'gender inflection of surname',
#   'es': 'inflexión de género del apellido',
#   'fr': "forme du nom de famille dans l'autre genre",
#   'de': 'Flexion des Familiennamens durch das Geschlecht'},
#  {'id': 'P1639',
#   'en': 'pendant of',
#   'es': 'pendant de',
#   'fr': 'pendant de',
#   'de': 'Pendant'},
#  {'id': 'P3032',
#   'en': 'adjacent building',
#   'es': 'edificio adyacente',
#   'fr': 'bâtiment adjacent',
#   'de': 'Nachbargebäude'},
#  {'id': 'P166',
#   'en': 'award received',
#   'es': 'premio recibido',
#   'fr': 'distinction reçue',
#   'de': 'Auszeichnung'},
#  {'id': 'P4428',
#   'en': 'implementation of',
#   'es': 'implementación de',
#   'fr': 'implémentation de',
#   'de': 'Implementierung von'},
#  {'id': 'P180',
#   'en': 'depicts',
#   'es': 'representa a',
#   'fr': 'dépeint',
#   'de': 'Motiv'},
#  {'id': 'P559',
#   'en': 'terminus',
#   'es': 'término',
#   'fr': 'extrémité',
#   'de': 'Endpunkt (Objekt)'},
#  {'id': 'P1398',
#   'en': 'structure replaces',
#   'es': 'estructura que reemplaza',
#   'fr': 'structure précédente',
#   'de': 'Bauwerk ersetzt'},
#  {'id': 'P2670',
#   'en': 'has part or parts of the class',
#   'es': 'tiene partes de la clase',
#   'fr': 'comprend des éléments de type',
#   'de': 'enthält Elemente von'},
#  {'id': 'P6185',
#   'en': 'tautomer of',
#   'es': 'tautómero de',
#   'fr': 'tautomère de',
#   'de': 'Tautomer von'},
#  {'id': 'P1535',
#   'en': 'used by',
#   'es': 'utilizado por',
#   'fr': 'utilisé par',
#   'de': 'verwendet von'},
#  {'id': 'P2283',
#   'en': 'uses',
#   'es': 'utiliza',
#   'fr': 'utilise',
#   'de': 'benutzt'},
#  {'id': 'P737',
#   'en': 'influenced by',
#   'es': 'influenciado por',
#   'fr': 'influencé par',
#   'de': 'beeinflusst von'},
#  {'id': 'P3190',
#   'en': 'innervates',
#   'es': 'inerva',
#   'fr': 'innerve',
#   'de': 'innerviert'},
#  {'id': 'P4345',
#   'en': 'director of archaeological fieldwork',
#   'es': 'director de excavación',
#   'fr': 'directeur des fouilles',
#   'de': 'Grabungsleiter'},
#  {'id': 'P915',
#   'en': 'filming location',
#   'es': 'lugar de filmación',
#   'fr': 'lieu du tournage',
#   'de': 'Drehort'},
#  {'id': 'P2176',
#   'en': 'drug or therapy used for treatment',
#   'es': 'medicamento (o droga)',
#   'fr': 'médicament',
#   'de': 'behandelt mit'},
#  {'id': 'P3729',
#   'en': 'next lower rank',
#   'es': 'rango inmediatamente inferior',
#   'fr': 'rang immédiatement inférieur',
#   'de': 'nächstniedrigerer Rang'},
#  {'id': 'P527',
#   'en': 'has part',
#   'es': 'compuesto por',
#   'fr': 'comprend',
#   'de': 'besteht aus'},
#  {'id': 'P1403',
#   'en': 'original combination',
#   'es': 'combinación original',
#   'fr': 'protonyme',
#   'de': 'Erstkombination'},
#  {'id': 'P3179',
#   'en': 'territory overlaps',
#   'es': 'solapamiento territorial',
#   'fr': 'recouvrement territorial',
#   'de': 'Territorium überschneidet sich mit'},
#  {'id': 'P144',
#   'en': 'based on',
#   'es': 'basado en',
#   'fr': 'basé sur',
#   'de': 'basiert auf'},
#  {'id': 'P2444',
#   'en': 'homoglyph',
#   'es': 'homoglifo',
#   'fr': 'homoglyphe',
#   'de': 'Homoglyph'},
#  {'id': 'P8865',
#   'en': 'mathematical inverse',
#   'es': 'inverso matemático',
#   'fr': 'inverse mathématique',
#   'de': 'mathematische Umkehroperation'},
#  {'id': 'P2329',
#   'en': 'antagonist muscle',
#   'es': 'músculo antagonista',
#   'fr': 'muscle antagoniste',
#   'de': 'antagonistischer Muskel'},
#  {'id': 'P684',
#   'en': 'ortholog',
#   'es': 'ortólogo',
#   'fr': 'gène orthologue',
#   'de': 'ortholog'},
#  {'id': 'P2652',
#   'en': 'partnership with',
#   'es': 'en sociedad con',
#   'fr': 'en partenariat avec',
#   'de': 'Geschäftsbeziehung zu'},
#  {'id': 'P3364',
#   'en': 'stereoisomer of',
#   'es': 'estereoisómero de',
#   'fr': 'stéréoisomère de',
#   'de': 'Stereoisomer von'},
#  {'id': 'P161',
#   'en': 'cast member',
#   'es': 'miembro del reparto',
#   'fr': 'distribution',
#   'de': 'Darsteller'},
#  {'id': 'P802',
#   'en': 'student',
#   'es': 'discípulo',
#   'fr': 'élève',
#   'de': 'Schüler'},
#  {'id': 'P1066',
#   'en': 'student of',
#   'es': 'alumno de',
#   'fr': 'élève de',
#   'de': 'Schüler von'},
#  {'id': 'P1424',
#   'en': "topic's main template",
#   'es': 'plantilla principal del tema',
#   'fr': "modèle principal d'un sujet",
#   'de': 'Hauptvorlage des Themas'},
#  {'id': 'P53',
#   'en': 'family',
#   'es': 'familia',
#   'fr': 'famille',
#   'de': 'Familie'},
#  {'id': 'P1416',
#   'en': 'affiliation',
#   'es': 'afiliación',
#   'fr': 'affilié à',
#   'de': 'Zugehörigkeit zu'},
#  {'id': 'P521',
#   'en': 'scheduled service destination',
#   'es': 'destino de servicio programado',
#   'fr': 'destination en service régulier',
#   'de': 'Ziel eines Liniendienstes'},
#  {'id': 'P885',
#   'en': 'origin of the watercourse',
#   'es': 'origen del curso de agua',
#   'fr': 'source',
#   'de': 'Quelle des Wasserlaufs'},
#  {'id': 'P1344',
#   'en': 'participant in',
#   'es': 'participó en',
#   'fr': 'participant à',
#   'de': 'Teilnehmer an'},
#  {'id': 'P137',
#   'en': 'operator',
#   'es': 'operador',
#   'fr': 'opérateur',
#   'de': 'Betreiber'},
#  {'id': 'P157',
#   'en': 'killed by',
#   'es': 'asesinado por',
#   'fr': 'tué par',
#   'de': 'getötet durch'},
#  {'id': 'P7888',
#   'en': 'merged into',
#   'es': 'fusionado con',
#   'fr': 'fusionné dans',
#   'de': 'fusioniert in'},
#  {'id': 'P177',
#   'en': 'crosses',
#   'es': 'atraviesa',
#   'fr': 'franchit',
#   'de': 'Querung'},
#  {'id': 'P488',
#   'en': 'chairperson',
#   'es': 'presidente',
#   'fr': 'président',
#   'de': 'Vorsitzender'},
#  {'id': 'P123',
#   'en': 'publisher',
#   'es': 'editorial',
#   'fr': 'éditeur',
#   'de': 'Verlag'},
#  {'id': 'P551',
#   'en': 'residence',
#   'es': 'residencia',
#   'fr': 'résidence',
#   'de': 'Wohnsitz'},
#  {'id': 'P3730',
#   'en': 'next higher rank',
#   'es': 'rango inmediatamente superior',
#   'fr': 'rang immédiatement supérieur',
#   'de': 'nächsthöherer Rang'},
#  {'id': 'P828',
#   'en': 'has cause',
#   'es': 'causado por',
#   'fr': 'a pour cause',
#   'de': 'Ursache'},
#  {'id': 'P1542',
#   'en': 'has effect',
#   'es': 'causa de',
#   'fr': 'a pour effet',
#   'de': 'Ursache von'},
#  {'id': 'P3113',
#   'en': 'does not have part',
#   'es': 'no contiene',
#   'fr': 'ne comprend pas',
#   'de': 'enthält nicht'},
#  {'id': 'P859',
#   'en': 'sponsor',
#   'es': 'patrocinador',
#   'fr': 'sponsor',
#   'de': 'Sponsor'},
#  {'id': 'P286',
#   'en': 'head coach',
#   'es': 'entrenador',
#   'fr': 'entraîneur / directeur sportif',
#   'de': 'Cheftrainer'},
#  {'id': 'P514',
#   'en': 'interleaves with',
#   'es': 'intercalada con',
#   'fr': "s'imbrique avec",
#   'de': 'verzahnt mit'},
#  {'id': 'P178',
#   'en': 'developer',
#   'es': 'desarrollador',
#   'fr': 'développeur',
#   'de': 'Entwickler'},
#  {'id': 'P6',
#   'en': 'head of government',
#   'es': 'jefe de gobierno',
#   'fr': "chef de l'exécutif",
#   'de': 'Leiter der Regierung oder Verwaltung'},
#  {'id': 'P371',
#   'en': 'presenter',
#   'es': 'presentador',
#   'fr': 'présentateur',
#   'de': 'Moderator'},
#  {'id': 'P138',
#   'en': 'named after',
#   'es': 'nombrado por',
#   'fr': 'nommé en référence à',
#   'de': 'benannt nach'},
#  {'id': 'P185',
#   'en': 'doctoral student',
#   'es': 'doctorando',
#   'fr': 'doctorant',
#   'de': 'Doktorand'},
#  {'id': 'P184',
#   'en': 'doctoral advisor',
#   'es': 'supervisor doctoral',
#   'fr': 'directeur de thèse',
#   'de': 'Promotionsbetreuer'},
#  {'id': 'P403',
#   'en': 'mouth of the watercourse',
#   'es': 'desembocadura del curso de agua',
#   'fr': 'se jette dans',
#   'de': 'mündet in'},
#  {'id': 'P162',
#   'en': 'producer',
#   'es': 'productor',
#   'fr': 'producteur',
#   'de': 'Produzent'},
#  {'id': 'P2860',
#   'en': 'cites work',
#   'es': 'referencia',
#   'fr': 'cite le document',
#   'de': 'zitiert'},
#  {'id': 'P664',
#   'en': 'organizer',
#   'es': 'organizador',
#   'fr': 'organisateur',
#   'de': 'Veranstalter'},
#  {'id': 'P159',
#   'en': 'headquarters location',
#   'es': 'ubicación de la sede',
#   'fr': 'siège',
#   'de': 'Hauptverwaltung'},
#  {'id': 'P2695',
#   'en': 'type locality (geology)',
#   'es': 'localidad tipo (geología)',
#   'fr': 'localité type (géologie)',
#   'de': 'geologische Typlokalität'},
#  {'id': 'P201',
#   'en': 'lake outflow',
#   'es': 'emisario del lago',
#   'fr': 'émissaire du lac',
#   'de': 'Abfluss'},
#  {'id': 'P1376',
#   'en': 'capital of',
#   'es': 'capital de',
#   'fr': 'capitale de',
#   'de': 'Hauptstadt von'},
#  {'id': 'P206',
#   'en': 'located in or next to body of water',
#   'es': 'situado cerca del cuerpo de agua',
#   'fr': 'baigné par',
#   'de': 'liegt am oder im Gewässer'},
#  {'id': 'P263',
#   'en': 'official residence',
#   'es': 'residencia oficial',
#   'fr': 'résidence officielle',
#   'de': 'Amtssitz'},
#  {'id': 'P98',
#   'en': 'editor',
#   'es': 'editor',
#   'fr': 'éditeur scientifique',
#   'de': 'Herausgeber'},
#  {'id': 'P793',
#   'en': 'significant event',
#   'es': 'evento significativo',
#   'fr': 'évènement clé',
#   'de': 'Schlüsselereignis'},
#  {'id': 'P366',
#   'en': 'has use',
#   'es': 'uso',
#   'fr': 'usage',
#   'de': 'Benutzung'},
#  {'id': 'P566',
#   'en': 'basionym',
#   'es': 'basónimo',
#   'fr': 'basionyme',
#   'de': 'Basionym'},
#  {'id': 'P3320',
#   'en': 'board member',
#   'es': 'miembro del consejo',
#   'fr': "membre du conseil d'administration",
#   'de': 'Vorstandsmitglied'},
#  {'id': 'P1039',
#   'en': 'kinship to subject',
#   'es': 'tipo de parentesco',
#   'fr': 'type de parenté',
#   'de': 'Verwandtschaftsverhältnis dieser Person'},
#  {'id': 'P1346',
#   'en': 'winner',
#   'es': 'ganador',
#   'fr': 'vainqueur',
#   'de': 'Sieger'},
#  {'id': 'P1411',
#   'en': 'nominated for',
#   'es': 'nominado a',
#   'fr': 'nommé pour',
#   'de': 'nominiert für'},
#  {'id': 'P276',
#   'en': 'location',
#   'es': 'ubicación',
#   'fr': 'lieu',
#   'de': 'Ort'},
#  {'id': 'P1343',
#   'en': 'described by source',
#   'es': 'descrito en',
#   'fr': 'décrit par',
#   'de': 'beschrieben in'},
#  {'id': 'P5523',
#   'en': 'fanqie',
#   'es': 'fanquie',
#   'fr': 'fanqie',
#   'de': 'Fanqie'},
#  {'id': 'P127',
#   'en': 'owned by',
#   'es': 'propietario',
#   'fr': 'propriétaire',
#   'de': 'Eigentümer'},
#  {'id': 'P108',
#   'en': 'employer',
#   'es': 'empleador',
#   'fr': 'employeur',
#   'de': 'Arbeitgeber'},
#  {'id': 'P8956',
#   'en': 'compatible with',
#   'es': 'compatible con',
#   'fr': 'compatible avec',
#   'de': 'kompatibel mit'},
#  {'id': 'P50', 'en': 'author', 'es': 'autor', 'fr': 'auteur', 'de': 'Autor'},
#  {'id': 'P710',
#   'en': 'participant',
#   'es': 'participante',
#   'fr': 'participant',
#   'de': 'Teilnehmer'},
#  {'id': 'P2567',
#   'en': 'amended by',
#   'es': 'enmendado por',
#   'fr': 'amendé par',
#   'de': 'geändert durch'},
#  {'id': 'P2936',
#   'en': 'language used',
#   'es': 'idioma usado',
#   'fr': 'langue utilisée',
#   'de': 'genutzte Sprache'},
#  {'id': 'P31',
#   'en': 'instance of',
#   'es': 'instancia de',
#   'fr': "nature de l'élément",
#   'de': 'ist ein(e)'},
#  {'id': 'P4552',
#   'en': 'mountain range',
#   'es': 'cordillera',
#   'fr': 'chaîne de montagnes',
#   'de': 'Gebirgszug'},
#  {'id': 'P113',
#   'en': 'airline hub',
#   'es': 'centro de conexión',
#   'fr': 'hub aéroportuaire',
#   'de': 'Luftfahrt-Drehkreuz'},
#  {'id': 'P641',
#   'en': 'sport',
#   'es': 'deporte',
#   'fr': 'sport',
#   'de': 'Sportart'},
#  {'id': 'P706',
#   'en': 'located in/on physical feature',
#   'es': 'situado en la entidad geográfica',
#   'fr': 'localisation géographique',
#   'de': 'liegt geographisch im Gebiet oder Gewässer'},
#  {'id': 'P910',
#   'en': "topic's main category",
#   'es': 'categoría principal del tema',
#   'fr': 'catégorie',
#   'de': 'Hauptkategorie zum Artikel'},
#  {'id': 'P927',
#   'en': 'anatomical location',
#   'es': 'localización anatómica',
#   'fr': 'région anatomique',
#   'de': 'anatomische Lage'},
#  {'id': 'P1441',
#   'en': 'present in work',
#   'es': 'presente en la obra',
#   'fr': "présent dans l'œuvre",
#   'de': 'kommt vor in'},
#  {'id': 'P179',
#   'en': 'part of the series',
#   'es': 'serie',
#   'fr': 'série',
#   'de': 'Teil der Reihe oder Serie'},
#  {'id': 'P1040',
#   'en': 'film editor',
#   'es': 'editor de cine',
#   'fr': 'monteur',
#   'de': 'Filmeditor'},
#  {'id': 'P176',
#   'en': 'manufacturer',
#   'es': 'fabricante',
#   'fr': 'fabricant',
#   'de': 'Hersteller'},
#  {'id': 'P1427',
#   'en': 'start point',
#   'es': 'lugar de inicio',
#   'fr': 'point de départ',
#   'de': 'geografischer Startpunkt'},
#  {'id': 'P61',
#   'en': 'discoverer or inventor',
#   'es': 'descubridor o inventor',
#   'fr': 'découvreur ou inventeur',
#   'de': 'Entdecker oder Erfinder'},
#  {'id': 'P807',
#   'en': 'separated from',
#   'es': 'separado de',
#   'fr': 'séparé de',
#   'de': 'abgetrennt von'},
#  {'id': 'P1598',
#   'en': 'consecrator',
#   'es': 'consagrante',
#   'fr': 'consécrateur',
#   'de': 'Konsekrator'},
#  {'id': 'P6379',
#   'en': 'has works in the collection',
#   'es': 'tiene obras en la colección',
#   'fr': 'collection comprenant une œuvre de la personne',
#   'de': 'Sammlung mit Werk(en) dieser Person'},
#  {'id': 'P287',
#   'en': 'designed by',
#   'es': 'diseñador',
#   'fr': 'designer',
#   'de': 'Designer'},
#  {'id': 'P7719',
#   'en': 'generalization of',
#   'es': 'implica',
#   'fr': 'généralisation de',
#   'de': 'impliziert'},
#  {'id': 'P4913',
#   'en': 'dialect of',
#   'es': 'dialecto de',
#   'fr': 'dialecte de',
#   'de': 'Dialekt von'},
#  {'id': 'P39',
#   'en': 'position held',
#   'es': 'cargo ocupado',
#   'fr': 'fonction',
#   'de': 'öffentliches Amt oder Stellung'},
#  {'id': 'P355',
#   'en': 'subsidiary',
#   'es': 'filial',
#   'fr': 'organisation fille',
#   'de': 'nachgeordnete Organisation'},
#  {'id': 'P22', 'en': 'father', 'es': 'padre', 'fr': 'père', 'de': 'Vater'},
#  {'id': 'P3300',
#   'en': 'musical conductor',
#   'es': 'director de orquesta',
#   'fr': "chef d'orchestre",
#   'de': 'musikalischer Leiter'},
#  {'id': 'P805',
#   'en': 'statement is subject of',
#   'es': 'elemento de la declaración',
#   'fr': 'affirmation détaillée dans',
#   'de': 'beschreibendes Datenobjekt'},
#  {'id': 'P121',
#   'en': 'item operated',
#   'es': 'elemento operado',
#   'fr': 'élément utilisé',
#   'de': 'eingesetztes Objekt'},
#  {'id': 'P1431',
#   'en': 'executive producer',
#   'es': 'productor ejecutivo',
#   'fr': 'producteur délégué',
#   'de': 'Produktionsleiter'},
#  {'id': 'P1268',
#   'en': 'represents',
#   'es': 'representa',
#   'fr': 'représente',
#   'de': 'repräsentiert'},
#  {'id': 'P747',
#   'en': 'has edition or translation',
#   'es': 'edición o traducción',
#   'fr': 'édition',
#   'de': 'hat Ausgaben'},
#  {'id': 'P629',
#   'en': 'edition or translation of',
#   'es': 'edición o traducción de',
#   'fr': 'édition ou traduction de',
#   'de': 'Ausgabe oder Übersetzung von'},
#  {'id': 'P1557',
#   'en': 'manifestation of',
#   'es': 'manifestación de',
#   'fr': 'manifestation de',
#   'de': 'Manifestation von'},
#  {'id': 'P822',
#   'en': 'mascot',
#   'es': 'mascota',
#   'fr': 'mascotte',
#   'de': 'Maskottchen'},
#  {'id': 'P195',
#   'en': 'collection',
#   'es': 'colección',
#   'fr': 'collection',
#   'de': 'Sammlung'},
#  {'id': 'P5940',
#   'en': 'plot expanded in',
#   'es': 'trama continuada en',
#   'fr': 'intrigue continuée dans',
#   'de': 'Handlung wird erweitert in'},
#  {'id': 'P2737',
#   'en': 'union of',
#   'es': 'unión de',
#   'fr': 'union de',
#   'de': 'Vereinigung von'},
#  {'id': 'P360',
#   'en': 'is a list of',
#   'es': 'lista de',
#   'fr': 'est une liste de',
#   'de': 'Liste von'},
#  {'id': 'P7153',
#   'en': 'significant place',
#   'es': 'lugar significativo',
#   'fr': 'lieu important',
#   'de': 'bedeutender Ort'},
#  {'id': 'P2354',
#   'en': 'has list',
#   'es': 'lista del elemento',
#   'fr': "liste d'éléments",
#   'de': 'entsprechende Liste'},
#  {'id': 'P825',
#   'en': 'dedicated to',
#   'es': 'dedicado a',
#   'fr': 'dédicataire',
#   'de': 'Widmung an'},
#  {'id': 'P4900',
#   'en': 'broader concept',
#   'es': 'concepto más amplio',
#   'fr': 'concept plus large',
#   'de': 'übergeordneter Begriff'},
#  {'id': 'P2094',
#   'en': 'competition class',
#   'es': 'clase de competencia',
#   'fr': 'classe de qualification',
#   'de': 'Wettbewerbsklasse'},
#  {'id': 'P749',
#   'en': 'parent organization',
#   'es': 'organización matriz',
#   'fr': 'organisation mère',
#   'de': 'übergeordnete Organisation'},
#  {'id': 'P1830',
#   'en': 'owner of',
#   'es': 'propietario de',
#   'fr': 'propriétaire de',
#   'de': 'Inhaber von'},
#  {'id': 'P237',
#   'en': 'coat of arms',
#   'es': 'escudo de armas',
#   'fr': 'blasonnement',
#   'de': 'Wappen (Item)'},
#  {'id': 'P167',
#   'en': 'structure replaced by',
#   'es': 'estructura reemplazada por',
#   'fr': 'structure remplacée par',
#   'de': 'Nachfolgebauwerk'},
#  {'id': 'P25', 'en': 'mother', 'es': 'madre', 'fr': 'mère', 'de': 'Mutter'},
#  {'id': 'P2546',
#   'en': 'sidekick of',
#   'es': 'ayudante de',
#   'fr': 'faire-valoir de',
#   'de': 'Sidekick von'},
#  {'id': 'P3448',
#   'en': 'stepparent',
#   'es': 'padrastro o madrastra',
#   'fr': 'beau-parent',
#   'de': 'Stiefelternteil'},
#  {'id': 'P404',
#   'en': 'game mode',
#   'es': 'modo de juego',
#   'fr': 'mode de jeu',
#   'de': 'Spielmodus'},
#  {'id': 'P921',
#   'en': 'main subject',
#   'es': 'tema principal de la obra',
#   'fr': 'sujet ou thème principal',
#   'de': 'zentrales Thema'},
#  {'id': 'P186',
#   'en': 'made from material',
#   'es': 'material empleado',
#   'fr': 'matériau',
#   'de': 'Material'},
#  {'id': 'P2522',
#   'en': 'victory',
#   'es': 'victoria',
#   'fr': 'victoire',
#   'de': 'Sieg'},
#  {'id': 'P1075',
#   'en': 'rector',
#   'es': 'rector',
#   'fr': 'recteur',
#   'de': 'Rektor'},
#  {'id': 'P4292',
#   'en': 'possessed by spirit',
#   'es': 'poseído por',
#   'fr': 'esprit possesseur',
#   'de': 'besessen von'},
#  {'id': 'P2210',
#   'en': 'relative to',
#   'es': 'relativo a',
#   'fr': 'relatif à',
#   'de': 'Bezugspunkt'},
#  {'id': 'P674',
#   'en': 'characters',
#   'es': 'personajes',
#   'fr': 'personnages',
#   'de': 'Figuren'},
#  {'id': 'P4675',
#   'en': 'appears in the form of',
#   'es': 'aparece bajo la forma de',
#   'fr': 'se métamorphose en',
#   'de': 'angenommene Gestalt'},
#  {'id': 'P6477',
#   'en': 'does not have quality',
#   'es': 'no tiene la cualidad',
#   'fr': "caractérisé par l'absence de",
#   'de': 'Mangel an'},
#  {'id': 'P3137',
#   'en': 'parent peak',
#   'es': 'cumbre principal',
#   'fr': 'sommet parent',
#   'de': 'Bezugsberg'},
#  {'id': 'P2650',
#   'en': 'interested in',
#   'es': 'interesado en',
#   'fr': 'intéressé par',
#   'de': 'interessiert an'},
#  {'id': 'P676',
#   'en': 'lyrics by',
#   'es': 'letra de',
#   'fr': 'parolier',
#   'de': 'Text von'},
#  {'id': 'P175',
#   'en': 'performer',
#   'es': 'intérprete',
#   'fr': 'interprète',
#   'de': 'Interpret'},
#  {'id': 'P406',
#   'en': 'soundtrack release',
#   'es': 'álbum de banda sonora',
#   'fr': 'album de la bande originale',
#   'de': 'Soundtrack'},
#  {'id': 'P598',
#   'en': 'commander of (DEPRECATED)',
#   'es': 'comandante de (OBSOLETO)',
#   'fr': 'commandement (OBSOLÈTE)',
#   'de': 'befohlene Einheiten (VERALTET)'},
#  {'id': 'P547',
#   'en': 'commemorates',
#   'es': 'conmemora',
#   'fr': 'commémore',
#   'de': 'erinnert an'},
#  {'id': 'P115',
#   'en': 'home venue',
#   'es': 'estadio',
#   'fr': 'stade',
#   'de': 'Heimspielstätte'},
#  {'id': 'P1071',
#   'en': 'location of creation',
#   'es': 'lugar de creación',
#   'fr': 'lieu de fabrication',
#   'de': 'Herstellungsort'},
#  {'id': 'P119',
#   'en': 'place of burial',
#   'es': 'lugar de sepultura',
#   'fr': 'lieu de sépulture',
#   'de': 'Begräbnisort'},
#  {'id': 'P150',
#   'en': 'contains administrative territorial entity',
#   'es': 'subdividido en (división administrativa)',
#   'fr': 'contient les subdivisions territoriales administratives',
#   'de': 'Untereinheit (administrative Einheit)'},
#  {'id': 'P5004',
#   'en': 'in opposition to',
#   'es': 'en oposición a',
#   'fr': 'en opposition à',
#   'de': 'in Opposition zu'},
#  {'id': 'P5135',
#   'en': 'greater than',
#   'es': 'mayor que',
#   'fr': 'supérieur à',
#   'de': 'größer als'},
#  {'id': 'P5136',
#   'en': 'less than',
#   'es': 'menor que',
#   'fr': 'inférieur à',
#   'de': 'weniger als'},
#  {'id': 'P3205',
#   'en': 'patient of',
#   'es': 'paciente de',
#   'fr': 'patient de',
#   'de': 'Patient von'},
#  {'id': 'P466',
#   'en': 'occupant',
#   'es': 'ocupante',
#   'fr': 'occupant',
#   'de': 'Bewohner/Nutzer'},
#  {'id': 'P726',
#   'en': 'candidate',
#   'es': 'candidato',
#   'fr': 'candidat',
#   'de': 'Kandidat'},
#  {'id': 'P971',
#   'en': 'category combines topics',
#   'es': 'temas asociados por la categoría',
#   'fr': 'sujets associés à la catégorie',
#   'de': 'Kategorie kombiniert die Themen'},
#  {'id': 'P797',
#   'en': 'authority',
#   'es': 'autoridad ejecutiva',
#   'fr': 'autorité exécutive',
#   'de': 'Exekutive'},
#  {'id': 'P5869',
#   'en': 'model item',
#   'es': 'elemento ejemplo',
#   'fr': 'élément Wikidata exemplaire',
#   'de': 'Beispielelement'},
#  {'id': 'P1304',
#   'en': 'central bank',
#   'es': 'banco central',
#   'fr': 'banque centrale',
#   'de': 'Zentralbank (Land)'},
#  {'id': 'P2512',
#   'en': 'series spin-off',
#   'es': 'serie derivada',
#   'fr': 'série dérivée',
#   'de': 'Spin-Off-Serie'}]

# %%
candNon
# Out:
# []

# %% [markdown]
# #### Postprocess and Save

# %%
# Entity Candidates to Dataframe
df = pd.DataFrame(cand)
df
# Out:
#         id                        en                                es  \
# 0     P530       diplomatic relation              relación diplomática
# 1      P47        shares border with            comparte fronteras con
# 2     P461               opposite of                         opuesto a
# 3     P460    said to be the same as       se dice que es lo mismo que
# 4    P3373                   sibling                 hermano o hermana
# ..     ...                       ...                               ...
# 214   P971  category combines topics  temas asociados por la categoría
# 215   P797                 authority               autoridad ejecutiva
# 216  P5869                model item                  elemento ejemplo
# 217  P1304              central bank                     banco central
# 218  P2512           series spin-off                    serie derivada
#
#                                  fr                               de
# 0             relation diplomatique          diplomatische Beziehung
# 1                     limitrophe de            gemeinsame Grenze mit
# 2                         contraire                    Gegenteil von
# 3                réputé identique à           eventuell gleichwertig
# 4                     frère ou sœur                      Geschwister
# ..                              ...                              ...
# 214  sujets associés à la catégorie  Kategorie kombiniert die Themen
# 215              autorité exécutive                        Exekutive
# 216     élément Wikidata exemplaire                  Beispielelement
# 217                 banque centrale               Zentralbank (Land)
# 218                   série dérivée                   Spin-Off-Serie
#
# [219 rows x 5 columns]

# %%
# Save as CSV for manual cleanup
df.to_csv('Relations/symmetric_multilingual.csv', index=False)

# %% [markdown]
# #### Equivalence

# %%
# Load relations
properties = pd.read_csv('Relations/equivalence_relations.csv')
properties = properties.rename(columns={'r1.id': 'id1', 'r2.id': 'id2'})
properties
# Out:
#         id1   id2
# 0      P150  P527
# 1      P361  P463
# 2       P47  P530
# 3     P2936   P37
# 4       P30  P361
# ...     ...   ...
# 7374    P17  P669
# 7375    P50  P943
# 7376   P123  P725
# 7377  P5056  P735
# 7378  P8324  P921
#
# [7379 rows x 2 columns]

# %%
propertyList = properties.to_dict('list')
propertyList
# Out:
# {'id1': ['P150',
#   'P361',
#   'P47',
#   'P2936',
#   'P30',
#   'P1412',
#   'P119',
#   'P119',
#   'P119',
#   'P103',
#   'P103',
#   'P1830',
#   'P1830',
#   'P20',
#   'P19',
#   'P551',
#   'P101',
#   'P2652',
#   'P101',
#   'P170',
#   'P112',
#   'P170',
#   'P127',
#   'P127',
#   'P127',
#   'P137',
#   'P137',
#   'P112',
#   'P112',
#   'P112',
#   'P112',
#   'P2184',
#   'P2283',
#   'P1589',
#   'P1365',
#   'P1889',
#   'P1889',
#   'P2283',
#   'P676',
#   'P279',
#   'P1889',
#   'P1889',
#   'P1336',
#   'P122',
#   'P361',
#   'P150',
#   'P1344',
#   'P35',
#   'P1313',
#   'P2012',
#   'P186',
#   'P150',
#   'P1889',
#   'P1622',
#   'P1365',
#   'P1365',
#   'P27',
#   'P30',
#   'P131',
#   'P20',
#   'P1066',
#   'P19',
#   'P119',
#   'P1344',
#   'P180',
#   'P279',
#   'P279',
#   'P19',
#   'P47',
#   'P155',
#   'P155',
#   'P156',
#   'P1376',
#   'P840',
#   'P57',
#   'P272',
#   'P17',
#   'P185',
#   'P108',
#   'P1066',
#   'P1066',
#   'P184',
#   'P101',
#   'P1411',
#   'P17',
#   'P31',
#   'P131',
#   'P1376',
#   'P131',
#   'P112',
#   'P112',
#   'P138',
#   'P20',
#   'P19',
#   'P1376',
#   'P1376',
#   'P131',
#   'P2789',
#   'P279',
#   'P17',
#   'P206',
#   'P170',
#   'P272',
#   'P885',
#   'P2922',
#   'P1347',
#   'P102',
#   'P2184',
#   'P1343',
#   'P112',
#   'P1889',
#   'P131',
#   'P138',
#   'P138',
#   'P17',
#   'P189',
#   'P361',
#   'P301',
#   'P463',
#   'P463',
#   'P598',
#   'P194',
#   'P119',
#   'P1365',
#   'P138',
#   'P138',
#   'P1313',
#   'P39',
#   'P205',
#   'P17',
#   'P361',
#   'P47',
#   'P150',
#   'P131',
#   'P17',
#   'P361',
#   'P1532',
#   'P31',
#   'P17',
#   'P138',
#   'P1441',
#   'P138',
#   'P170',
#   'P1889',
#   'P1889',
#   'P161',
#   'P162',
#   'P144',
#   'P47',
#   'P17',
#   'P1344',
#   'P241',
#   'P1376',
#   'P17',
#   'P131',
#   'P1336',
#   'P4224',
#   'P190',
#   'P1365',
#   'P1889',
#   'P344',
#   'P344',
#   'P138',
#   'P131',
#   'P466',
#   'P127',
#   'P127',
#   'P112',
#   'P112',
#   'P485',
#   'P161',
#   'P161',
#   'P101',
#   'P3450',
#   'P3450',
#   'P1050',
#   'P127',
#   'P1830',
#   'P27',
#   'P138',
#   'P140',
#   'P178',
#   'P112',
#   'P170',
#   'P1552',
#   'P135',
#   'P27',
#   'P1066',
#   'P101',
#   'P106',
#   'P1376',
#   'P131',
#   'P488',
#   'P598',
#   'P166',
#   'P2348',
#   'P136',
#   'P136',
#   'P36',
#   'P1889',
#   'P150',
#   'P170',
#   'P138',
#   'P2541',
#   'P159',
#   'P131',
#   'P1376',
#   'P176',
#   'P1532',
#   'P495',
#   'P2650',
#   'P1026',
#   'P1366',
#   'P1889',
#   'P1366',
#   'P135',
#   'P451',
#   'P3342',
#   'P3342',
#   'P22',
#   'P1552',
#   'P1269',
#   'P159',
#   'P1830',
#   'P112',
#   'P1038',
#   'P20',
#   'P108',
#   'P53',
#   'P156',
#   'P155',
#   'P131',
#   'P131',
#   'P27',
#   'P279',
#   'P361',
#   'P1050',
#   'P1269',
#   'P1269',
#   'P4424',
#   'P131',
#   'P1376',
#   'P2578',
#   'P17',
#   'P112',
#   'P1037',
#   'P17',
#   'P1830',
#   'P138',
#   'P17',
#   'P131',
#   'P162',
#   'P156',
#   'P1889',
#   'P138',
#   'P1269',
#   'P1001',
#   'P726',
#   'P115',
#   'P179',
#   'P1462',
#   'P131',
#   'P3320',
#   'P127',
#   'P16',
#   'P131',
#   'P1000',
#   'P127',
#   'P1343',
#   'P2650',
#   'P140',
#   'P1552',
#   'P1269',
#   'P1049',
#   'P1344',
#   'P119',
#   'P1889',
#   'P361',
#   'P1344',
#   'P54',
#   'P123',
#   'P131',
#   'P5769',
#   'P138',
#   'P1383',
#   'P144',
#   'P552',
#   'P1018',
#   'P1346',
#   'P175',
#   'P175',
#   'P179',
#   'P17',
#   'P291',
#   'P159',
#   'P361',
#   'P749',
#   'P159',
#   'P150',
#   'P150',
#   'P2670',
#   'P2283',
#   'P138',
#   'P527',
#   'P31',
#   'P136',
#   'P159',
#   'P1454',
#   'P1040',
#   'P1040',
#   'P1040',
#   'P1040',
#   'P1040',
#   'P175',
#   'P175',
#   'P175',
#   'P175',
#   'P2554',
#   'P2554',
#   'P2554',
#   'P58',
#   'P57',
#   'P106',
#   'P1830',
#   'P1346',
#   'P136',
#   'P6439',
#   'P2515',
#   'P495',
#   'P1001',
#   'P417',
#   'P17',
#   'P138',
#   'P1269',
#   'P101',
#   'P101',
#   'P31',
#   'P361',
#   'P279',
#   'P361',
#   'P1365',
#   'P463',
#   'P131',
#   'P2650',
#   'P1269',
#   'P355',
#   'P31',
#   'P3403',
#   'P36',
#   'P112',
#   'P127',
#   'P112',
#   'P40',
#   'P3373',
#   'P200',
#   'P138',
#   'P175',
#   'P19',
#   'P1346',
#   'P1557',
#   'P131',
#   'P27',
#   'P832',
#   'P3764',
#   'P1376',
#   'P1366',
#   'P144',
#   'P144',
#   'P2283',
#   'P131',
#   'P162',
#   'P112',
#   'P361',
#   'P1382',
#   'P131',
#   'P138',
#   'P131',
#   'P131',
#   'P123',
#   'P1346',
#   'P137',
#   'P127',
#   'P127',
#   'P127',
#   'P131',
#   'P131',
#   'P1365',
#   'P527',
#   'P1269',
#   'P3113',
#   'P127',
#   'P127',
#   'P469',
#   'P749',
#   'P162',
#   'P131',
#   'P61',
#   'P123',
#   'P179',
#   'P1889',
#   'P126',
#   'P127',
#   'P137',
#   'P1038',
#   'P1038',
#   'P108',
#   'P2936',
#   'P1535',
#   'P1071',
#   'P1029',
#   'P1269',
#   'P200',
#   'P1877',
#   'P17',
#   'P123',
#   'P460',
#   'P136',
#   'P279',
#   'P1889',
#   'P1889',
#   'P206',
#   'P138',
#   'P144',
#   'P1431',
#   'P1431',
#   'P135',
#   'P1142',
#   'P364',
#   'P355',
#   'P461',
#   'P1040',
#   'P150',
#   'P144',
#   'P523',
#   'P1056',
#   'P166',
#   'P361',
#   'P171',
#   'P137',
#   'P1040',
#   'P169',
#   'P1716',
#   'P155',
#   'P155',
#   'P1716',
#   'P1346',
#   'P1923',
#   'P31',
#   'P1027',
#   'P1429',
#   'P170',
#   'P47',
#   'P110',
#   'P1532',
#   'P170',
#   'P50',
#   'P171',
#   'P171',
#   'P54',
#   'P1716',
#   'P1346',
#   'P138',
#   'P155',
#   'P485',
#   'P159',
#   'P161',
#   'P31',
#   'P279',
#   'P1889',
#   'P140',
#   'P282',
#   'P2341',
#   'P279',
#   'P112',
#   'P112',
#   'P123',
#   'P31',
#   'P138',
#   'P1889',
#   'P162',
#   'P17',
#   'P112',
#   'P495',
#   'P1999',
#   'P361',
#   'P155',
#   'P206',
#   'P17',
#   'P127',
#   'P460',
#   'P306',
#   'P3080',
#   'P287',
#   'P156',
#   'P361',
#   'P17',
#   'P276',
#   'P119',
#   'P26',
#   'P276',
#   'P3342',
#   'P138',
#   'P276',
#   'P276',
#   'P1889',
#   'P47',
#   'P1366',
#   'P276',
#   'P138',
#   'P144',
#   'P279',
#   'P1414',
#   'P1365',
#   'P26',
#   'P1366',
#   'P1366',
#   'P1040',
#   'P1434',
#   'P279',
#   'P138',
#   'P138',
#   'P195',
#   'P103',
#   'P1037',
#   'P126',
#   'P108',
#   'P106',
#   'P463',
#   'P1478',
#   'P170',
#   'P178',
#   'P277',
#   'P31',
#   'P279',
#   'P27',
#   'P1830',
#   'P138',
#   'P463',
#   'P361',
#   'P108',
#   'P22',
#   'P101',
#   'P3033',
#   'P411',
#   'P460',
#   'P1035',
#   'P1419',
#   'P155',
#   'P155',
#   'P179',
#   'P138',
#   'P1071',
#   'P127',
#   'P127',
#   'P1269',
#   'P40',
#   'P1192',
#   'P495',
#   'P527',
#   'P121',
#   'P1535',
#   'P533',
#   'P159',
#   'P1269',
#   'P1037',
#   'P1830',
#   'P210',
#   'P112',
#   'P126',
#   'P126',
#   'P1889',
#   'P1158',
#   'P127',
#   'P131',
#   'P47',
#   'P1269',
#   'P1327',
#   'P161',
#   'P170',
#   'P1365',
#   'P138',
#   'P1269',
#   'P1441',
#   'P140',
#   'P2283',
#   'P1066',
#   'P2563',
#   'P1080',
#   'P1080',
#   'P1416',
#   'P138',
#   'P138',
#   'P1552',
#   'P403',
#   'P144',
#   'P301',
#   'P2959',
#   'P1753',
#   'P1754',
#   'P509',
#   'P1889',
#   'P127',
#   'P31',
#   'P1731',
#   'P511',
#   'P106',
#   'P1038',
#   'P1327',
#   'P161',
#   'P2389',
#   'P1001',
#   'P1001',
#   'P101',
#   'P3373',
#   'P27',
#   'P179',
#   'P2416',
#   'P106',
#   'P449',
#   'P144',
#   'P108',
#   'P108',
#   'P1889',
#   'P106',
#   'P1889',
#   'P5096',
#   'P39',
#   'P366',
#   'P276',
#   'P2868',
#   'P1072',
#   'P1366',
#   'P1830',
#   'P1299',
#   'P102',
#   'P1365',
#   'P119',
#   'P185',
#   'P1365',
#   'P1343',
#   'P186',
#   'P1366',
#   'P463',
#   'P138',
#   'P1038',
#   'P450',
#   'P1327',
#   'P3450',
#   'P463',
#   'P1038',
#   'P1366',
#   'P1196',
#   'P674',
#   'P1431',
#   'P1431',
#   'P1532',
#   'P110',
#   'P162',
#   'P180',
#   'P1035',
#   'P463',
#   'P101',
#   'P135',
#   'P39',
#   'P1889',
#   'P551',
#   'P598',
#   'P1269',
#   'P2632',
#   'P1142',
#   'P108',
#   'P184',
#   'P1441',
#   'P157',
#   'P2388',
#   'P527',
#   'P108',
#   'P25',
#   'P361',
#   'P180',
#   'P137',
#   'P19',
#   'P631',
#   'P50',
#   'P1365',
#   'P101',
#   'P1889',
#   'P1365',
#   'P138',
#   'P1346',
#   'P1427',
#   'P1532',
#   'P108',
#   'P1830',
#   'P137',
#   'P131',
#   'P1037',
#   'P101',
#   'P1376',
#   'P1343',
#   'P1269',
#   'P1889',
#   'P276',
#   'P185',
#   'P1382',
#   'P131',
#   'P361',
#   'P1269',
#   'P180',
#   'P2554',
#   'P180',
#   'P180',
#   'P1542',
#   'P547',
#   'P155',
#   'P1269',
#   'P1066',
#   'P161',
#   'P161',
#   'P162',
#   'P3842',
#   'P3842',
#   'P1542',
#   'P106',
#   'P710',
#   'P17',
#   'P1889',
#   'P137',
#   'P241',
#   'P1321',
#   'P119',
#   'P770',
#   'P485',
#   'P1321',
#   'P1321',
#   'P1889',
#   'P27',
#   'P1889',
#   'P36',
#   'P2354',
#   'P1891',
#   'P1066',
#   'P4446',
#   'P1344',
#   'P1001',
#   'P463',
#   'P1542',
#   'P1027',
#   'P1038',
#   'P1537',
#   'P108',
#   'P2522',
#   'P737',
#   'P138',
#   'P127',
#   'P466',
#   'P50',
#   'P50',
#   'P155',
#   'P113',
#   'P199',
#   'P1441',
#   'P19',
#   'P26',
#   'P31',
#   'P3373',
#   'P452',
#   'P1875',
#   'P1889',
#   'P276',
#   'P1889',
#   'P108',
#   'P1582',
#   'P1290',
#   'P485',
#   'P1037',
#   'P1037',
#   'P1875',
#   'P289',
#   'P196',
#   'P3602',
#   'P137',
#   'P1303',
#   'P162',
#   'P1877',
#   'P1366',
#   'P39',
#   'P279',
#   'P159',
#   'P1001',
#   'P361',
#   'P176',
#   'P1420',
#   'P131',
#   'P6379',
#   'P166',
#   'P2868',
#   'P156',
#   'P1412',
#   'P1830',
#   'P674',
#   'P1877',
#   'P1877',
#   'P1877',
#   'P58',
#   'P58',
#   'P58',
#   'P825',
#   'P170',
#   'P112',
#   'P108',
#   'P2515',
#   'P162',
#   'P162',
#   'P162',
#   'P17',
#   'P1639',
#   'P138',
#   'P276',
#   'P1830',
#   'P162',
#   'P2341',
#   'P1001',
#   'P138',
#   'P6275',
#   'P1056',
#   'P126',
#   'P5021',
#   'P463',
#   'P276',
#   'P6379',
#   'P108',
#   'P1889',
#   'P22',
#   'P106',
#   'P123',
#   'P1431',
#   'P138',
#   'P1552',
#   'P166',
#   'P2348',
#   'P1035',
#   'P1420',
#   'P144',
#   'P241',
#   'P112',
#   'P828',
#   'P40',
#   'P1542',
#   'P1889',
#   'P50',
#   'P2094',
#   'P1420',
#   'P137',
#   'P361',
#   'P1142',
#   'P355',
#   'P1366',
#   'P1382',
#   'P1382',
#   'P186',
#   'P112',
#   'P17',
#   'P156',
#   'P31',
#   'P1672',
#   'P276',
#   'P195',
#   'P127',
#   'P1382',
#   'P118',
#   'P137',
#   'P1995',
#   'P1398',
#   'P1080',
#   'P2341',
#   'P1382',
#   'P176',
#   'P189',
#   'P27',
#   'P527',
#   'P176',
#   'P161',
#   'P101',
#   'P176',
#   'P193',
#   'P1299',
#   'P108',
#   'P86',
#   'P156',
#   'P1889',
#   'P1906',
#   'P1571',
#   'P793',
#   'P1478',
#   'P361',
#   'P50',
#   'P155',
#   'P1365',
#   'P101',
#   'P1889',
#   'P3095',
#   'P1950',
#   'P1535',
#   'P140',
#   'P461',
#   'P5642',
#   'P58',
#   'P1056',
#   'P1535',
#   'P1027',
#   'P159',
#   'P2670',
#   'P166',
#   'P2554',
#   'P161',
#   'P1040',
#   'P162',
#   'P161',
#   'P2515',
#   'P138',
#   'P3975',
#   'P279',
#   'P689',
#   'P58',
#   'P3496',
#   'P4320',
#   'P4323',
#   'P2321',
#   'P2321',
#   'P2321',
#   'P3494',
#   'P3494',
#   'P3494',
#   'P2321',
#   'P1346',
#   'P1346',
#   'P1346',
#   'P1346',
#   'P1346',
#   'P1542',
#   'P127',
#   'P206',
#   'P57',
#   'P241',
#   'P176',
#   'P137',
#   'P17',
#   'P2283',
#   'P136',
#   'P102',
#   'P3275',
#   'P3275',
#   'P3092',
#   'P159',
#   'P1376',
#   'P1877',
#   'P136',
#   'P676',
#   'P50',
#   'P50',
#   'P170',
#   'P170',
#   'P170',
#   'P366',
#   'P138',
#   'P138',
#   'P17',
#   'P131',
#   'P131',
#   'P1889',
#   'P2596',
#   'P106',
#   'P1365',
#   'P1365',
#   'P361',
#   'P112',
#   'P138',
#   'P1557',
#   'P2348',
#   'P1312',
#   'P1376',
#   'P127',
#   'P5021',
#   'P1789',
#   'P1037',
#   'P169',
#   'P169',
#   'P291',
#   'P3373',
#   'P101',
#   'P1038',
#   'P131',
#   'P1383',
#   'P169',
#   'P127',
#   'P112',
#   'P1136',
#   'P1441',
#   'P1434',
#   ...],
#  'id2': ['P527',
#   'P463',
#   'P530',
#   'P37',
#   'P361',
#   'P6886',
#   'P20',
#   'P1830',
#   'P551',
#   'P1412',
#   'P6886',
#   'P20',
#   'P551',
#   'P551',
#   'P551',
#   'P937',
#   'P136',
#   'P737',
#   'P61',
#   'P178',
#   'P61',
#   'P50',
#   'P170',
#   'P137',
#   'P178',
#   'P170',
#   'P178',
#   'P170',
#   'P127',
#   'P137',
#   'P178',
#   'P793',
#   'P408',
#   'P206',
#   'P155',
#   'P2579',
#   'P527',
#   'P5009',
#   'P86',
#   'P366',
#   'P706',
#   'P361',
#   'P47',
#   'P31',
#   'P706',
#   'P36',
#   'P463',
#   'P6',
#   'P1906',
#   'P361',
#   'P527',
#   'P793',
#   'P3403',
#   'P5658',
#   'P530',
#   'P47',
#   'P945',
#   'P706',
#   'P1376',
#   'P937',
#   'P69',
#   'P937',
#   'P937',
#   'P607',
#   'P361',
#   'P361',
#   'P31',
#   'P20',
#   'P559',
#   'P156',
#   'P460',
#   'P460',
#   'P17',
#   'P915',
#   'P58',
#   'P750',
#   'P495',
#   'P802',
#   'P69',
#   'P737',
#   'P184',
#   'P737',
#   'P2650',
#   'P166',
#   'P205',
#   'P361',
#   'P17',
#   'P1889',
#   'P1889',
#   'P6',
#   'P35',
#   'P1889',
#   'P27',
#   'P27',
#   'P706',
#   'P47',
#   'P47',
#   'P559',
#   'P460',
#   'P31',
#   'P276',
#   'P58',
#   'P449',
#   'P974',
#   'P4794',
#   'P509',
#   'P463',
#   'P2579',
#   'P1889',
#   'P50',
#   'P47',
#   'P361',
#   'P36',
#   'P150',
#   'P47',
#   'P61',
#   'P4552',
#   'P31',
#   'P598',
#   'P945',
#   'P945',
#   'P208',
#   'P19',
#   'P138',
#   'P206',
#   'P825',
#   'P208',
#   'P97',
#   'P885',
#   'P885',
#   'P47',
#   'P527',
#   'P1589',
#   'P500',
#   'P500',
#   'P500',
#   'P27',
#   'P6106',
#   'P2341',
#   'P2341',
#   'P8345',
#   'P941',
#   'P463',
#   'P279',
#   'P31',
#   'P162',
#   'P58',
#   'P8646',
#   'P501',
#   'P710',
#   'P3602',
#   'P463',
#   'P361',
#   'P1889',
#   'P3403',
#   'P17',
#   'P971',
#   'P47',
#   'P1366',
#   'P36',
#   'P57',
#   'P58',
#   'P931',
#   'P7959',
#   'P88',
#   'P466',
#   'P88',
#   'P466',
#   'P88',
#   'P69',
#   'P58',
#   'P57',
#   'P106',
#   'P361',
#   'P664',
#   'P509',
#   'P749',
#   'P355',
#   'P53',
#   'P31',
#   'P3075',
#   'P943',
#   'P943',
#   'P943',
#   'P366',
#   'P136',
#   'P740',
#   'P22',
#   'P135',
#   'P39',
#   'P150',
#   'P150',
#   'P6',
#   'P607',
#   'P410',
#   'P2596',
#   'P2348',
#   'P2596',
#   'P47',
#   'P190',
#   'P1889',
#   'P272',
#   'P47',
#   'P276',
#   'P36',
#   'P460',
#   'P460',
#   'P178',
#   'P945',
#   'P840',
#   'P737',
#   'P800',
#   'P7888',
#   'P206',
#   'P156',
#   'P140',
#   'P737',
#   'P737',
#   'P451',
#   'P3373',
#   'P361',
#   'P17',
#   'P1830',
#   'P2813',
#   'P488',
#   'P3373',
#   'P2632',
#   'P264',
#   'P734',
#   'P17',
#   'P17',
#   'P155',
#   'P156',
#   'P937',
#   'P641',
#   'P749',
#   'P1576',
#   'P921',
#   'P4424',
#   'P921',
#   'P194',
#   'P194',
#   'P279',
#   'P276',
#   'P169',
#   'P169',
#   'P740',
#   'P199',
#   'P674',
#   'P2541',
#   'P205',
#   'P175',
#   'P26',
#   'P910',
#   'P170',
#   'P179',
#   'P17',
#   'P991',
#   'P1830',
#   'P279',
#   'P178',
#   'P706',
#   'P488',
#   'P17',
#   'P31',
#   'P2341',
#   'P2416',
#   'P1889',
#   'P800',
#   'P800',
#   'P2650',
#   'P31',
#   'P135',
#   'P140',
#   'P793',
#   'P485',
#   'P461',
#   'P927',
#   'P2522',
#   'P6087',
#   'P127',
#   'P291',
#   'P98',
#   'P276',
#   'P36',
#   'P527',
#   'P741',
#   'P170',
#   'P710',
#   'P31',
#   'P179',
#   'P31',
#   'P291',
#   'P495',
#   'P291',
#   'P831',
#   'P831',
#   'P47',
#   'P159',
#   'P47',
#   'P527',
#   'P2578',
#   'P833',
#   'P833',
#   'P366',
#   'P31',
#   'P740',
#   'P31',
#   'P175',
#   'P2554',
#   'P58',
#   'P57',
#   'P86',
#   'P2554',
#   'P58',
#   'P57',
#   'P86',
#   'P58',
#   'P57',
#   'P86',
#   'P86',
#   'P86',
#   'P3716',
#   'P40',
#   'P5053',
#   'P7937',
#   'P941',
#   'P2554',
#   'P915',
#   'P131',
#   'P825',
#   'P361',
#   'P417',
#   'P279',
#   'P1412',
#   'P6886',
#   'P881',
#   'P59',
#   'P4913',
#   'P399',
#   'P1889',
#   'P749',
#   'P31',
#   'P921',
#   'P2650',
#   'P414',
#   'P452',
#   'P706',
#   'P527',
#   'P749',
#   'P138',
#   'P138',
#   'P802',
#   'P802',
#   'P201',
#   'P50',
#   'P676',
#   'P5389',
#   'P3764',
#   'P31',
#   'P190',
#   'P551',
#   'P837',
#   'P5053',
#   'P7938',
#   'P47',
#   'P31',
#   'P2283',
#   'P31',
#   'P1366',
#   'P57',
#   'P527',
#   'P462',
#   'P156',
#   'P609',
#   'P61',
#   'P138',
#   'P931',
#   'P750',
#   'P664',
#   'P466',
#   'P159',
#   'P740',
#   'P131',
#   'P159',
#   'P740',
#   'P17',
#   'P706',
#   'P1889',
#   'P460',
#   'P488',
#   'P361',
#   'P885',
#   'P750',
#   'P170',
#   'P276',
#   'P65',
#   'P178',
#   'P3450',
#   'P460',
#   'P127',
#   'P176',
#   'P176',
#   'P22',
#   'P25',
#   'P1830',
#   'P407',
#   'P3349',
#   'P176',
#   'P1037',
#   'P2283',
#   'P974',
#   'P58',
#   'P8047',
#   'P50',
#   'P747',
#   'P921',
#   'P4000',
#   'P7959',
#   'P2959',
#   'P47',
#   'P2695',
#   'P1889',
#   'P57',
#   'P58',
#   'P463',
#   'P1387',
#   'P407',
#   'P527',
#   'P5135',
#   'P162',
#   'P156',
#   'P921',
#   'P524',
#   'P452',
#   'P2354',
#   'P527',
#   'P279',
#   'P664',
#   'P1431',
#   'P3320',
#   'P1830',
#   'P1830',
#   'P1716',
#   'P199',
#   'P1923',
#   'P2882',
#   'P4132',
#   'P859',
#   'P1830',
#   'P175',
#   'P7153',
#   'P50',
#   'P19',
#   'P6338',
#   'P58',
#   'P1889',
#   'P2743',
#   'P647',
#   'P176',
#   'P138',
#   'P180',
#   'P527',
#   'P527',
#   'P17',
#   'P344',
#   'P7937',
#   'P737',
#   'P737',
#   'P279',
#   'P527',
#   'P37',
#   'P4132',
#   'P98',
#   'P123',
#   'P98',
#   'P3450',
#   'P17',
#   'P2341',
#   'P676',
#   'P37',
#   'P1365',
#   'P740',
#   'P31',
#   'P414',
#   'P355',
#   'P706',
#   'P527',
#   'P355',
#   'P4913',
#   'P400',
#   'P3174',
#   'P3080',
#   'P279',
#   'P403',
#   'P859',
#   'P3018',
#   'P6379',
#   'P451',
#   'P710',
#   'P3373',
#   'P1478',
#   'P4552',
#   'P361',
#   'P797',
#   'P7888',
#   'P3842',
#   'P533',
#   'P533',
#   'P279',
#   'P527',
#   'P527',
#   'P22',
#   'P3373',
#   'P40',
#   'P25',
#   'P161',
#   'P361',
#   'P2894',
#   'P2894',
#   'P279',
#   'P276',
#   'P2936',
#   'P112',
#   'P859',
#   'P463',
#   'P803',
#   'P803',
#   'P366',
#   'P287',
#   'P287',
#   'P737',
#   'P3966',
#   'P2959',
#   'P276',
#   'P1889',
#   'P527',
#   'P6379',
#   'P511',
#   'P54',
#   'P286',
#   'P27',
#   'P527',
#   'P511',
#   'P4969',
#   'P166',
#   'P1889',
#   'P629',
#   'P179',
#   'P629',
#   'P88',
#   'P180',
#   'P195',
#   'P276',
#   'P1366',
#   'P7047',
#   'P81',
#   'P8047',
#   'P559',
#   'P3438',
#   'P1889',
#   'P8032',
#   'P276',
#   'P1535',
#   'P488',
#   'P527',
#   'P488',
#   'P210',
#   'P466',
#   'P137',
#   'P674',
#   'P276',
#   'P551',
#   'P7153',
#   'P807',
#   'P361',
#   'P3373',
#   'P170',
#   'P57',
#   'P460',
#   'P6241',
#   'P276',
#   'P4584',
#   'P463',
#   'P2563',
#   'P26',
#   'P520',
#   'P8345',
#   'P1441',
#   'P463',
#   'P828',
#   'P189',
#   'P1889',
#   'P469',
#   'P8345',
#   'P4224',
#   'P460',
#   'P301',
#   'P910',
#   'P793',
#   'P749',
#   'P169',
#   'P921',
#   'P412',
#   'P97',
#   'P410',
#   'P26',
#   'P737',
#   'P725',
#   'P361',
#   'P361',
#   'P2389',
#   'P9929',
#   'P460',
#   'P495',
#   'P361',
#   'P641',
#   'P136',
#   'P750',
#   'P9234',
#   'P119',
#   'P937',
#   'P22',
#   'P97',
#   'P40',
#   'P598',
#   'P803',
#   'P921',
#   'P495',
#   'P512',
#   'P1073',
#   'P361',
#   'P800',
#   'P361',
#   'P108',
#   'P527',
#   'P2632',
#   'P40',
#   'P150',
#   'P3919',
#   'P462',
#   'P485',
#   'P485',
#   'P371',
#   'P184',
#   'P5096',
#   'P26',
#   'P641',
#   'P69',
#   'P802',
#   'P17',
#   'P1596',
#   'P921',
#   'P162',
#   'P170',
#   'P20',
#   'P736',
#   'P725',
#   'P921',
#   'P39',
#   'P53',
#   'P812',
#   'P170',
#   'P410',
#   'P3373',
#   'P598',
#   'P937',
#   'P50',
#   'P793',
#   'P135',
#   'P485',
#   'P22',
#   'P4969',
#   'P7047',
#   'P488',
#   'P797',
#   'P6087',
#   'P26',
#   'P607',
#   'P547',
#   'P361',
#   'P66',
#   'P84',
#   'P736',
#   'P355',
#   'P5004',
#   'P4969',
#   'P144',
#   'P2647',
#   'P2321',
#   'P1444',
#   'P17',
#   'P241',
#   'P7153',
#   'P276',
#   'P137',
#   'P5769',
#   'P641',
#   'P463',
#   'P463',
#   'P641',
#   'P355',
#   'P706',
#   'P3373',
#   'P460',
#   'P710',
#   'P376',
#   'P180',
#   'P527',
#   'P4608',
#   'P460',
#   'P31',
#   'P461',
#   'P921',
#   'P1889',
#   'P131',
#   'P25',
#   'P1877',
#   'P86',
#   'P86',
#   'P47',
#   'P7888',
#   'P780',
#   'P2868',
#   'P991',
#   'P706',
#   'P39',
#   'P17',
#   'P598',
#   'P19',
#   'P27',
#   'P793',
#   'P6379',
#   'P937',
#   'P20',
#   'P780',
#   'P66',
#   'P3018',
#   'P460',
#   'P800',
#   'P50',
#   'P286',
#   'P749',
#   'P710',
#   'P495',
#   'P611',
#   'P793',
#   'P170',
#   'P1066',
#   'P527',
#   'P140',
#   'P710',
#   'P8371',
#   'P921',
#   'P708',
#   'P708',
#   'P9191',
#   'P86',
#   'P22',
#   'P159',
#   'P355',
#   'P361',
#   'P2348',
#   'P40',
#   'P463',
#   'P451',
#   'P641',
#   'P6275',
#   'P2283',
#   'P527',
#   'P2670',
#   'P127',
#   'P1889',
#   'P3373',
#   'P9419',
#   'P527',
#   'P1875',
#   'P527',
#   'P31',
#   'P361',
#   'P793',
#   'P1416',
#   'P412',
#   'P272',
#   'P86',
#   'P3373',
#   'P53',
#   'P3833',
#   'P495',
#   'P276',
#   'P366',
#   'P287',
#   'P694',
#   'P2348',
#   'P9493',
#   'P31',
#   'P31',
#   'P1889',
#   'P2936',
#   'P3828',
#   'P825',
#   'P674',
#   'P825',
#   'P921',
#   'P674',
#   'P825',
#   'P921',
#   'P921',
#   'P98',
#   'P155',
#   'P800',
#   'P4608',
#   'P2515',
#   'P4608',
#   'P2554',
#   'P3461',
#   'P941',
#   'P200',
#   'P669',
#   'P19',
#   'P750',
#   'P276',
#   'P112',
#   'P676',
#   'P6379',
#   'P121',
#   'P178',
#   'P512',
#   'P54',
#   'P6379',
#   'P800',
#   'P1344',
#   'P734',
#   'P737',
#   'P360',
#   'P749',
#   'P161',
#   'P65',
#   'P7937',
#   'P97',
#   'P27',
#   'P410',
#   'P566',
#   'P674',
#   'P361',
#   'P664',
#   'P921',
#   'P6275',
#   'P361',
#   'P4428',
#   'P98',
#   'P641',
#   'P171',
#   'P241',
#   'P4688',
#   'P1269',
#   'P4379',
#   'P1889',
#   'P1889',
#   'P144',
#   'P2283',
#   'P3320',
#   'P945',
#   'P7888',
#   'P793',
#   'P279',
#   'P608',
#   'P608',
#   'P495',
#   'P361',
#   'P264',
#   'P749',
#   'P2579',
#   'P167',
#   'P361',
#   'P66',
#   'P279',
#   'P1889',
#   'P706',
#   'P39',
#   'P793',
#   'P193',
#   'P2438',
#   'P1576',
#   'P631',
#   'P631',
#   'P913',
#   'P1416',
#   'P87',
#   'P3373',
#   'P366',
#   'P2388',
#   'P1851',
#   'P828',
#   'P828',
#   'P5607',
#   'P674',
#   'P2596',
#   'P2596',
#   'P2578',
#   'P915',
#   'P460',
#   'P734',
#   'P2975',
#   'P611',
#   'P7047',
#   'P828',
#   'P8670',
#   'P31',
#   'P2283',
#   'P138',
#   'P2541',
#   'P31',
#   'P2962',
#   'P344',
#   'P2515',
#   'P344',
#   'P344',
#   'P2554',
#   'P344',
#   'P669',
#   'P488',
#   'P2868',
#   'P927',
#   'P725',
#   'P3497',
#   'P4323',
#   'P710',
#   'P4323',
#   'P3494',
#   'P4320',
#   'P4320',
#   'P4323',
#   'P710',
#   'P710',
#   'P4320',
#   'P4323',
#   'P3494',
#   'P3496',
#   'P3497',
#   'P366',
#   'P50',
#   'P361',
#   'P725',
#   'P749',
#   'P495',
#   'P495',
#   'P176',
#   'P279',
#   'P1552',
#   'P1344',
#   'P58',
#   'P725',
#   'P3275',
#   'P527',
#   'P7959',
#   'P50',
#   'P144',
#   'P87',
#   'P87',
#   'P676',
#   'P87',
#   'P86',
#   'P676',
#   'P407',
#   'P27',
#   'P495',
#   'P27',
#   'P27',
#   'P495',
#   'P4149',
#   'P361',
#   'P641',
#   'P3842',
#   'P361',
#   'P3842',
#   'P3975',
#   'P1557',
#   'P921',
#   'P710',
#   'P3263',
#   'P31',
#   'P463',
#   'P69',
#   'P488',
#   'P1789',
#   'P488',
#   'P1789',
#   'P840',
#   'P40',
#   'P800',
#   'P1889',
#   'P1365',
#   'P527',
#   'P1951',
#   'P1951',
#   'P1951',
#   'P138',
#   'P800',
#   'P1889',
#   ...]}

# %%
# Load them into MongoDB
# Keep id, type, labels

for rel1, rel2 in zip(propertyList['id1'], propertyList['id2']):
    # Get Property
    r1_dict = get_entity_dict_from_api(rel1)
    r2_dict = get_entity_dict_from_api(rel2)
    
    # Take only a subset of keys
    r1_subset = dict((k, r1_dict[k]) for k in ('id', 'labels'))
    r1_subset['id1'] = r1_subset.pop('id')
    r1_subset['labels1'] = r1_subset.pop('labels')

    r2_subset = dict((k, r2_dict[k]) for k in ('id', 'labels'))
    r2_subset['id2'] = r2_subset.pop('id')
    r2_subset['labels2'] = r2_subset.pop('labels')

    r_subset = {**r1_subset, **r2_subset}
    
    # Insert into collection
    db.equivalence.insert_one(r_subset)

# %%
db.equivalence.find_one({})
# Out:
# {'_id': ObjectId('621104eb67e09f0d72992496'),
#  'id1': 'P150',
#  'labels1': {'cs': {'language': 'cs', 'value': 'nižší správní celky'},
#   'en': {'language': 'en',
#    'value': 'contains administrative territorial entity'},
#   'it': {'language': 'it', 'value': 'sottodivisioni amministrative'},
#   'fr': {'language': 'fr',
#    'value': 'contient les subdivisions territoriales administratives'},
#   'zh-hans': {'language': 'zh-hans', 'value': '包含行政领土实体'},
#   'zh-hant': {'language': 'zh-hant', 'value': '包含行政領土實體'},
#   'pt-br': {'language': 'pt-br', 'value': 'subdivide-se em'},
#   'uk': {'language': 'uk',
#    'value': 'адміністративно-територіально поділяється на'},
#   'eo': {'language': 'eo', 'value': 'subdividoj'},
#   'ca': {'language': 'ca', 'value': 'conté la subdivisió administrativa'},
#   'hr': {'language': 'hr', 'value': 'podjedinice'},
#   'fa': {'language': 'fa', 'value': 'زیربخش'},
#   'nds': {'language': 'nds', 'value': 'Ünnerafdelen'},
#   'lv': {'language': 'lv', 'value': 'apakšiedalījumi'},
#   'be': {'language': 'be', 'value': 'адміністрацыйныя адзінкі'},
#   'ru': {'language': 'ru', 'value': 'административно делится на'},
#   'fi': {'language': 'fi', 'value': 'hallinnolliset osa-alueet'},
#   'ro': {'language': 'ro', 'value': 'subdiviziuni'},
#   'he': {'language': 'he', 'value': 'חלוקה משנית'},
#   'ja': {'language': 'ja', 'value': '直下の行政区画'},
#   'ilo': {'language': 'ilo', 'value': 'mabingbingay iti'},
#   'de': {'language': 'de', 'value': 'Untereinheit (administrative Einheit)'},
#   'ta': {'language': 'ta', 'value': 'துணைப்பிரிவுகள்'},
#   'vi': {'language': 'vi', 'value': 'các phân cấp hành chính'},
#   'es': {'language': 'es',
#    'value': 'subdividido en (división administrativa)'},
#   'nl': {'language': 'nl', 'value': 'omvat bestuurlijke eenheid'},
#   'sv': {'language': 'sv',
#    'value': 'innehåller administrativ territoriell enhet'},
#   'ko': {'language': 'ko', 'value': '하위 행정구역'},
#   'ka': {'language': 'ka', 'value': 'ადმინისტრაციულად იყოფა'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'адміністрацыйныя адзінкі'},
#   'pt': {'language': 'pt', 'value': 'subdivide-se em'},
#   'pl': {'language': 'pl', 'value': 'podział administracyjny'},
#   'sr': {'language': 'sr', 'value': 'подељена административно на'},
#   'af': {'language': 'af', 'value': 'administratiewe onderverdeling'},
#   'id': {'language': 'id', 'value': 'pembagian administratif'},
#   'min': {'language': 'min', 'value': 'tabagi dalam'},
#   'uz': {'language': 'uz', 'value': 'maʼmuriy boʻlinishi'},
#   'da': {'language': 'da', 'value': 'inddeles i'},
#   'sco': {'language': 'sco', 'value': 'subdivides intae'},
#   'nb': {'language': 'nb', 'value': 'administrativt delområde'},
#   'el': {'language': 'el', 'value': 'διοικητικά διαιρείται σε'},
#   'bn': {'language': 'bn', 'value': 'প্রশাসনিক বিভক্তি'},
#   'sk': {'language': 'sk', 'value': 'nižšie správne celky'},
#   'br': {'language': 'br', 'value': 'isrannoù'},
#   'nn': {'language': 'nn', 'value': 'underavdeling'},
#   'nds-nl': {'language': 'nds-nl', 'value': 'onderverdeeld in'},
#   'en-gb': {'language': 'en-gb',
#    'value': 'contains administrative territorial entity'},
#   'la': {'language': 'la', 'value': 'subdivisiones'},
#   'oc': {'language': 'oc', 'value': 'subdivisions (division administrativa)'},
#   'mk': {'language': 'mk', 'value': 'административно поделена на'},
#   'sl': {'language': 'sl', 'value': 'administrativne podenote'},
#   'hu': {'language': 'hu', 'value': 'alárendelt egység'},
#   'zh': {'language': 'zh', 'value': '下辖行政领土实体'},
#   'jbo': {'language': 'jbo', 'value': 'selpau'},
#   'en-ca': {'language': 'en-ca',
#    'value': 'contains administrative territorial entity'},
#   'gu': {'language': 'gu', 'value': 'તેના વિભાગો'},
#   'ms': {'language': 'ms', 'value': 'terbahagi kepada (bahagian pentadbiran)'},
#   'bs': {'language': 'bs', 'value': 'podjedinice'},
#   'zh-cn': {'language': 'zh-cn', 'value': '包含行政领土实体'},
#   'is': {'language': 'is', 'value': 'skiptist í (stjórnsýslusvæði)'},
#   'zh-tw': {'language': 'zh-tw', 'value': '包含行政領土實體'},
#   'et': {'language': 'et', 'value': 'haldusüksused'},
#   'lb': {'language': 'lb',
#    'value': 'Ënnerandeelungen (administrativ Eenheeten)'},
#   'zh-hk': {'language': 'zh-hk', 'value': '包含行政領土實體'},
#   'or': {'language': 'or', 'value': 'ପ୍ରଶାସନିକ ଉପବିଭାଗ'},
#   'yi': {'language': 'yi', 'value': 'אונטער־ראיאן'},
#   'hi': {'language': 'hi', 'value': 'प्रशासनिक इकाई'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'подељена административно на'},
#   'sr-el': {'language': 'sr-el', 'value': 'podeljena administrativno na'},
#   'ia': {'language': 'ia',
#    'value': 'contine entitate territorial administrative'},
#   'mg': {'language': 'mg', 'value': 'fizarazarana ara-pandraharahana'},
#   'scn': {'language': 'scn',
#    'value': "cunteni l'entità tirrituriali amministrativa"},
#   'eu': {'language': 'eu', 'value': 'zatiketa (erakunde administratiboak)'},
#   'ne': {'language': 'ne', 'value': 'रहेका प्रशासनिक क्षेत्रहरू'},
#   'cy': {'language': 'cy', 'value': 'yn cynnwys yr ardal weinyddol'},
#   'ar': {'language': 'ar', 'value': 'التقسيمات الإدارية'},
#   'fo': {'language': 'fo', 'value': 'fyrisitingarligt øki'},
#   'hy': {'language': 'hy', 'value': 'վարչականորեն բաժանվում է'},
#   'th': {'language': 'th', 'value': 'หน่วยย่อยการปกครอง'},
#   'bg': {'language': 'bg', 'value': 'териториално-административни единици'},
#   'vmf': {'language': 'vmf', 'value': 'Värwôldungsunnäreihäd'},
#   'yue': {'language': 'yue', 'value': '包含政區'},
#   'tg': {'language': 'tg', 'value': 'зербахш'},
#   'yo': {'language': 'yo', 'value': 'Ní àwon ìpínlè'},
#   'ast': {'language': 'ast', 'value': 'contién la subdivisión alministrativa'},
#   'hsb': {'language': 'hsb',
#    'value': 'podjednotka (administratiwna jednotka)'},
#   'ba': {'language': 'ba', 'value': 'административ рәүештә бүленә'},
#   'tr': {'language': 'tr', 'value': 'idari yapılanması'},
#   'tt': {'language': 'tt', 'value': 'административ бүленеше'},
#   'te': {'language': 'te', 'value': 'దీని కింద ఉన్న పరిపాలనా ప్రాంతం'},
#   'gl': {'language': 'gl', 'value': 'contén a división administrativa'},
#   'sq': {'language': 'sq',
#    'value': 'përmban entitet administrativ territorial'},
#   'frr': {'language': 'frr', 'value': 'onerdiald tu'},
#   'zh-sg': {'language': 'zh-sg', 'value': '包含行政领土实体'},
#   'zh-my': {'language': 'zh-my', 'value': '包含行政领土实体'},
#   'zh-mo': {'language': 'zh-mo', 'value': '包含行政領土實體'},
#   'hyw': {'language': 'hyw', 'value': 'ներքին բաժանում'},
#   'diq': {'language': 'diq', 'value': 'İdareyê bınêni'},
#   'ce': {'language': 'ce', 'value': 'административан йекъало'},
#   'sh': {'language': 'sh', 'value': 'podjedinice'},
#   'ga': {'language': 'ga',
#    'value': 'ina bhfuil eintiteas críochach riaracháin'},
#   'lt': {'language': 'lt', 'value': 'turi kaip administracinį vienetą'},
#   'szl': {'language': 'szl', 'value': 'administracyjny tajlōng'},
#   'ban': {'language': 'ban', 'value': 'wawengkon administratip'},
#   'vec': {'language': 'vec', 'value': 'aministrativamente sudividesto'},
#   'xmf': {'language': 'xmf', 'value': 'ადმინისტრაციულო ირთუ'}},
#  'id2': 'P527',
#  'labels2': {'cs': {'language': 'cs', 'value': 'skládá se z'},
#   'en': {'language': 'en', 'value': 'has part'},
#   'sv': {'language': 'sv', 'value': 'har del'},
#   'de': {'language': 'de', 'value': 'besteht aus'},
#   'es': {'language': 'es', 'value': 'compuesto por'},
#   'ca': {'language': 'ca', 'value': 'format per'},
#   'da': {'language': 'da', 'value': 'har del'},
#   'fr': {'language': 'fr', 'value': 'comprend'},
#   'nn': {'language': 'nn', 'value': 'sett saman av'},
#   'fa': {'language': 'fa', 'value': 'دربرگیرنده'},
#   'hu': {'language': 'hu', 'value': 'alkotórész'},
#   'it': {'language': 'it', 'value': 'consiste di'},
#   'mk': {'language': 'mk', 'value': 'се состои од'},
#   'pl': {'language': 'pl', 'value': 'składa się z'},
#   'nds': {'language': 'nds', 'value': 'besteiht ut'},
#   'fi': {'language': 'fi', 'value': 'koostuu seuraavista'},
#   'sr': {'language': 'sr', 'value': 'састоји се од'},
#   'sr-ec': {'language': 'sr-ec', 'value': 'састоји се од'},
#   'nl': {'language': 'nl', 'value': 'omvat deel'},
#   'ru': {'language': 'ru', 'value': 'состоит из'},
#   'zh': {'language': 'zh', 'value': '可分為'},
#   'oc': {'language': 'oc', 'value': 'compren'},
#   'be': {'language': 'be', 'value': 'складаецца з'},
#   'be-tarask': {'language': 'be-tarask', 'value': 'складаецца з'},
#   'ms': {'language': 'ms', 'value': 'terdiri daripada'},
#   'bs': {'language': 'bs', 'value': 'sastoji se od'},
#   'th': {'language': 'th', 'value': 'ประกอบไปด้วย'},
#   'zh-hant': {'language': 'zh-hant', 'value': '可分為'},
#   'zh-hans': {'language': 'zh-hans', 'value': '可分为'},
#   'ja': {'language': 'ja', 'value': '以下を含む'},
#   'pt': {'language': 'pt', 'value': 'composto de'},
#   'el': {'language': 'el', 'value': 'αποτελείται από'},
#   'en-ca': {'language': 'en-ca', 'value': 'has part'},
#   'nb': {'language': 'nb', 'value': 'har bestanddel'},
#   'ko': {'language': 'ko', 'value': '다음으로 이루어져 있음'},
#   'lb': {'language': 'lb', 'value': 'besteet aus'},
#   'sr-el': {'language': 'sr-el', 'value': 'sastoji se od'},
#   'eo': {'language': 'eo', 'value': 'havas parton'},
#   'sco': {'language': 'sco', 'value': 'haes pairt'},
#   'vi': {'language': 'vi', 'value': 'gồm các phần'},
#   'ilo': {'language': 'ilo', 'value': 'adaan iti paset'},
#   'lv': {'language': 'lv', 'value': 'sastāv no'},
#   'zh-hk': {'language': 'zh-hk', 'value': '可分為'},
#   'gl': {'language': 'gl', 'value': 'composto por'},
#   'id': {'language': 'id', 'value': 'terdiri dari'},
#   'te': {'language': 'te', 'value': 'కలిగియున్న భాగాలు'},
#   'sk': {'language': 'sk', 'value': 'skladá sa z'},
#   'en-gb': {'language': 'en-gb', 'value': 'has part'},
#   'la': {'language': 'la', 'value': 'comprehendit'},
#   'pt-br': {'language': 'pt-br', 'value': 'composto de'},
#   'uk': {'language': 'uk', 'value': 'складники'},
#   'et': {'language': 'et', 'value': 'koosseis'},
#   'zh-cn': {'language': 'zh-cn', 'value': '可分为'},
#   'he': {'language': 'he', 'value': 'מכיל את החלק'},
#   'scn': {'language': 'scn', 'value': 'cunteni'},
#   'ia': {'language': 'ia', 'value': 'componite de'},
#   'sl': {'language': 'sl', 'value': 'vsebuje'},
#   'eu': {'language': 'eu', 'value': 'osatuta'},
#   'bn': {'language': 'bn', 'value': 'এর অংশ'},
#   'ce': {'language': 'ce', 'value': 'хӀоттам'},
#   'hr': {'language': 'hr', 'value': 'sastoji se od'},
#   'jbo': {'language': 'jbo', 'value': 'lo pagbu'},
#   'cy': {'language': 'cy', 'value': 'yn cynnwys'},
#   'lt': {'language': 'lt', 'value': 'susideda iš'},
#   'ast': {'language': 'ast', 'value': 'formáu por'},
#   'ro': {'language': 'ro', 'value': 'constând în'},
#   'ps': {'language': 'ps', 'value': 'برخه لري'},
#   'ka': {'language': 'ka', 'value': 'შედგება'},
#   'ar': {'language': 'ar', 'value': 'يتكوَّن مِن'},
#   'frr': {'language': 'frr', 'value': 'tuupsaat faan'},
#   'mg': {'language': 'mg', 'value': 'ahitana'},
#   'yi': {'language': 'yi', 'value': 'אנטהאלט'},
#   'ta': {'language': 'ta', 'value': 'பகுதிகள்'},
#   'fo': {'language': 'fo', 'value': 'fevnir um'},
#   'zh-mo': {'language': 'zh-mo', 'value': '可分為'},
#   'zh-sg': {'language': 'zh-sg', 'value': '可分为'},
#   'zh-tw': {'language': 'zh-tw', 'value': '可分為'},
#   'ku-latn': {'language': 'ku-latn', 'value': 'pêk tê ji'},
#   'nap': {'language': 'nap', 'value': "e' fatt e"},
#   'vmf': {'language': 'vmf', 'value': 'Zsômmäsedzung'},
#   'bg': {'language': 'bg', 'value': 'състои се от'},
#   'tg': {'language': 'tg', 'value': 'шомили'},
#   'yo': {'language': 'yo', 'value': 'ní ara'},
#   'tg-cyrl': {'language': 'tg-cyrl', 'value': 'иборат аст аз'},
#   'sq': {'language': 'sq', 'value': 'ka pjesë'},
#   'ur': {'language': 'ur', 'value': 'جزو'},
#   'gu': {'language': 'gu', 'value': 'આ ભાગનું બનેલું'},
#   'or': {'language': 'or', 'value': 'ଏହାର ଅଂଶ'},
#   'ba': {'language': 'ba', 'value': 'нимәнән тора'},
#   'kn': {'language': 'kn', 'value': 'ಭಾಗವನ್ನು ಹೊಂದಿದೆ'},
#   'tr': {'language': 'tr', 'value': 'şunlardan oluşur'},
#   'si': {'language': 'si', 'value': 'අයත් කොටස් වන්නේ'},
#   'hsb': {'language': 'hsb', 'value': 'wobsteji z(e)'},
#   'sa': {'language': 'sa', 'value': 'भागोऽस्य कः?'},
#   'tt': {'language': 'tt', 'value': 'нәрсәдән тора'},
#   'tt-cyrl': {'language': 'tt-cyrl', 'value': 'нәрсәдән тора'},
#   'lfn': {'language': 'lfn', 'value': 'ave parte'},
#   'zh-my': {'language': 'zh-my', 'value': '可分为'},
#   'mr': {'language': 'mr', 'value': 'भाग'},
#   'yue': {'language': 'yue', 'value': '包含部分'},
#   'hy': {'language': 'hy', 'value': 'կազմված է'},
#   'gsw': {'language': 'gsw', 'value': 'bstoht us'},
#   'af': {'language': 'af', 'value': 'bestaan uit'},
#   'ky': {'language': 'ky', 'value': 'Курамы'},
#   'ga': {'language': 'ga', 'value': 'le cuid'},
#   'ml': {'language': 'ml', 'value': 'ഇത് ഭാഗമായി'},
#   'vec': {'language': 'vec', 'value': 'formà da'},
#   'br': {'language': 'br', 'value': 'perzh e'},
#   'nqo': {'language': 'nqo', 'value': 'ߡߍ߲ ߘߏ߫ ߦߴߊ߬ ߘߌ߫'},
#   'sh': {'language': 'sh', 'value': 'sastoji se od'},
#   'az': {'language': 'az', 'value': 'bunlardan ibarətdir'},
#   'ban': {'language': 'ban', 'value': 'kadiri antuk'},
#   'diq': {'language': 'diq', 'value': 'Ninan ra yenê pêser'},
#   'se': {'language': 'se', 'value': 'dasa gullet'},
#   'smn': {'language': 'smn', 'value': 'toos kuleh'},
#   'sms': {'language': 'sms', 'value': 'tõzz koʹlle'},
#   'arz': {'language': 'arz', 'value': 'بيتكون من'},
#   'kab': {'language': 'kab', 'value': 'igber seg'},
#   'tl': {'language': 'tl', 'value': 'may parte'},
#   'szl': {'language': 'szl', 'value': 'skłŏdŏ sie z'},
#   'ti': {'language': 'ti', 'value': 'ዝተዳለወ ብ'},
#   'ms-arab': {'language': 'ms-arab', 'value': 'ترديري درڤد'},
#   'ckb': {'language': 'ckb', 'value': 'پێکدێت لە'},
#   'dag': {'language': 'dag', 'value': 'Di malila'},
#   'xmf': {'language': 'xmf', 'value': 'აკმოდირთუ'}}}

# %%
# Only get relations that are available in query_languages
# Should not be the same in all languages
cand = []
candNon = []

for document in db.equivalence.find({}):
    if all(k in document['labels1'] for k in query_languages) and all(k in document['labels2'] for k in query_languages):
        # Ignore relations that are the same in all languages
        labels1 = [document['labels1'][k]['value'] for k in query_languages]
        labels2 = [document['labels2'][k]['value'] for k in query_languages]
        if all_same(labels1) or all_same(labels2): continue
        
        # Sanity check if there are properties that are not in latin script or broken
        if not has_numbers(document['labels1']['en']['value']) and isLatin(document['labels1']['en']['value']) and not has_numbers(document['labels2']['en']['value']) and isLatin(document['labels2']['en']['value']):
            j = {'id1': document['id1']}
            for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
            j['id2'] = document['id2']
            for k in query_languages: j[k + '2'] = document['labels2'][k]['value']
            
            cand.append(j)
        else:
            j = {'id1': document['id1']}
            for k in query_languages: j[k + '1'] = document['labels1'][k]['value']
            j['id2'] = document['id2']
            for k in query_languages: j[k + '2'] = document['labels2'][k]['value']

            candNon.append(j)

# %%
cand
# Out:
# [{'id1': 'P150',
#   'en1': 'contains administrative territorial entity',
#   'es1': 'subdividido en (división administrativa)',
#   'fr1': 'contient les subdivisions territoriales administratives',
#   'de1': 'Untereinheit (administrative Einheit)',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P47',
#   'en1': 'shares border with',
#   'es1': 'comparte fronteras con',
#   'fr1': 'limitrophe de',
#   'de1': 'gemeinsame Grenze mit',
#   'id2': 'P530',
#   'en2': 'diplomatic relation',
#   'es2': 'relación diplomática',
#   'fr2': 'relation diplomatique',
#   'de2': 'diplomatische Beziehung'},
#  {'id1': 'P2936',
#   'en1': 'language used',
#   'es1': 'idioma usado',
#   'fr1': 'langue utilisée',
#   'de1': 'genutzte Sprache',
#   'id2': 'P37',
#   'en2': 'official language',
#   'es2': 'idioma oficial',
#   'fr2': 'langue officielle',
#   'de2': 'Amtssprache'},
#  {'id1': 'P30',
#   'en1': 'continent',
#   'es1': 'continente',
#   'fr1': 'continent',
#   'de1': 'Kontinent',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P1412',
#   'en1': 'languages spoken, written or signed',
#   'es1': 'lenguas habladas, escritas o signadas',
#   'fr1': 'langues parlées, écrites ou signées',
#   'de1': 'gesprochene oder publizierte Sprachen',
#   'id2': 'P6886',
#   'en2': 'writing language',
#   'es2': 'lengua(s) de escritura',
#   'fr2': "langues d'écriture (pour les auteurs publiés seulement)",
#   'de2': 'geschriebene Sprache'},
#  {'id1': 'P119',
#   'en1': 'place of burial',
#   'es1': 'lugar de sepultura',
#   'fr1': 'lieu de sépulture',
#   'de1': 'Begräbnisort',
#   'id2': 'P20',
#   'en2': 'place of death',
#   'es2': 'lugar de fallecimiento',
#   'fr2': 'lieu de mort',
#   'de2': 'Sterbeort'},
#  {'id1': 'P119',
#   'en1': 'place of burial',
#   'es1': 'lugar de sepultura',
#   'fr1': 'lieu de sépulture',
#   'de1': 'Begräbnisort',
#   'id2': 'P1830',
#   'en2': 'owner of',
#   'es2': 'propietario de',
#   'fr2': 'propriétaire de',
#   'de2': 'Inhaber von'},
#  {'id1': 'P119',
#   'en1': 'place of burial',
#   'es1': 'lugar de sepultura',
#   'fr1': 'lieu de sépulture',
#   'de1': 'Begräbnisort',
#   'id2': 'P551',
#   'en2': 'residence',
#   'es2': 'residencia',
#   'fr2': 'résidence',
#   'de2': 'Wohnsitz'},
#  {'id1': 'P103',
#   'en1': 'native language',
#   'es1': 'lengua materna',
#   'fr1': 'langue maternelle',
#   'de1': 'Muttersprache',
#   'id2': 'P1412',
#   'en2': 'languages spoken, written or signed',
#   'es2': 'lenguas habladas, escritas o signadas',
#   'fr2': 'langues parlées, écrites ou signées',
#   'de2': 'gesprochene oder publizierte Sprachen'},
#  {'id1': 'P103',
#   'en1': 'native language',
#   'es1': 'lengua materna',
#   'fr1': 'langue maternelle',
#   'de1': 'Muttersprache',
#   'id2': 'P6886',
#   'en2': 'writing language',
#   'es2': 'lengua(s) de escritura',
#   'fr2': "langues d'écriture (pour les auteurs publiés seulement)",
#   'de2': 'geschriebene Sprache'},
#  {'id1': 'P1830',
#   'en1': 'owner of',
#   'es1': 'propietario de',
#   'fr1': 'propriétaire de',
#   'de1': 'Inhaber von',
#   'id2': 'P20',
#   'en2': 'place of death',
#   'es2': 'lugar de fallecimiento',
#   'fr2': 'lieu de mort',
#   'de2': 'Sterbeort'},
#  {'id1': 'P1830',
#   'en1': 'owner of',
#   'es1': 'propietario de',
#   'fr1': 'propriétaire de',
#   'de1': 'Inhaber von',
#   'id2': 'P551',
#   'en2': 'residence',
#   'es2': 'residencia',
#   'fr2': 'résidence',
#   'de2': 'Wohnsitz'},
#  {'id1': 'P20',
#   'en1': 'place of death',
#   'es1': 'lugar de fallecimiento',
#   'fr1': 'lieu de mort',
#   'de1': 'Sterbeort',
#   'id2': 'P551',
#   'en2': 'residence',
#   'es2': 'residencia',
#   'fr2': 'résidence',
#   'de2': 'Wohnsitz'},
#  {'id1': 'P19',
#   'en1': 'place of birth',
#   'es1': 'lugar de nacimiento',
#   'fr1': 'lieu de naissance',
#   'de1': 'Geburtsort',
#   'id2': 'P551',
#   'en2': 'residence',
#   'es2': 'residencia',
#   'fr2': 'résidence',
#   'de2': 'Wohnsitz'},
#  {'id1': 'P551',
#   'en1': 'residence',
#   'es1': 'residencia',
#   'fr1': 'résidence',
#   'de1': 'Wohnsitz',
#   'id2': 'P937',
#   'en2': 'work location',
#   'es2': 'lugar de trabajo',
#   'fr2': 'lieu de travail',
#   'de2': 'Wirkungsort'},
#  {'id1': 'P101',
#   'en1': 'field of work',
#   'es1': 'campo de trabajo',
#   'fr1': "domaine d'activité",
#   'de1': 'Arbeitsgebiet',
#   'id2': 'P136',
#   'en2': 'genre',
#   'es2': 'género',
#   'fr2': 'genre',
#   'de2': 'Genre'},
#  {'id1': 'P2652',
#   'en1': 'partnership with',
#   'es1': 'en sociedad con',
#   'fr1': 'en partenariat avec',
#   'de1': 'Geschäftsbeziehung zu',
#   'id2': 'P737',
#   'en2': 'influenced by',
#   'es2': 'influenciado por',
#   'fr2': 'influencé par',
#   'de2': 'beeinflusst von'},
#  {'id1': 'P101',
#   'en1': 'field of work',
#   'es1': 'campo de trabajo',
#   'fr1': "domaine d'activité",
#   'de1': 'Arbeitsgebiet',
#   'id2': 'P61',
#   'en2': 'discoverer or inventor',
#   'es2': 'descubridor o inventor',
#   'fr2': 'découvreur ou inventeur',
#   'de2': 'Entdecker oder Erfinder'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P178',
#   'en2': 'developer',
#   'es2': 'desarrollador',
#   'fr2': 'développeur',
#   'de2': 'Entwickler'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P61',
#   'en2': 'discoverer or inventor',
#   'es2': 'descubridor o inventor',
#   'fr2': 'découvreur ou inventeur',
#   'de2': 'Entdecker oder Erfinder'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P50',
#   'en2': 'author',
#   'es2': 'autor',
#   'fr2': 'auteur',
#   'de2': 'Autor'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P170',
#   'en2': 'creator',
#   'es2': 'creador',
#   'fr2': 'créateur',
#   'de2': 'Urheber'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P137',
#   'en2': 'operator',
#   'es2': 'operador',
#   'fr2': 'opérateur',
#   'de2': 'Betreiber'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P178',
#   'en2': 'developer',
#   'es2': 'desarrollador',
#   'fr2': 'développeur',
#   'de2': 'Entwickler'},
#  {'id1': 'P137',
#   'en1': 'operator',
#   'es1': 'operador',
#   'fr1': 'opérateur',
#   'de1': 'Betreiber',
#   'id2': 'P170',
#   'en2': 'creator',
#   'es2': 'creador',
#   'fr2': 'créateur',
#   'de2': 'Urheber'},
#  {'id1': 'P137',
#   'en1': 'operator',
#   'es1': 'operador',
#   'fr1': 'opérateur',
#   'de1': 'Betreiber',
#   'id2': 'P178',
#   'en2': 'developer',
#   'es2': 'desarrollador',
#   'fr2': 'développeur',
#   'de2': 'Entwickler'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P170',
#   'en2': 'creator',
#   'es2': 'creador',
#   'fr2': 'créateur',
#   'de2': 'Urheber'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P127',
#   'en2': 'owned by',
#   'es2': 'propietario',
#   'fr2': 'propriétaire',
#   'de2': 'Eigentümer'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P137',
#   'en2': 'operator',
#   'es2': 'operador',
#   'fr2': 'opérateur',
#   'de2': 'Betreiber'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P178',
#   'en2': 'developer',
#   'es2': 'desarrollador',
#   'fr2': 'développeur',
#   'de2': 'Entwickler'},
#  {'id1': 'P2184',
#   'en1': 'history of topic',
#   'es1': 'historia',
#   'fr1': 'histoire',
#   'de1': 'Geschichte',
#   'id2': 'P793',
#   'en2': 'significant event',
#   'es2': 'evento significativo',
#   'fr2': 'évènement clé',
#   'de2': 'Schlüsselereignis'},
#  {'id1': 'P2283',
#   'en1': 'uses',
#   'es1': 'utiliza',
#   'fr1': 'utilise',
#   'de1': 'benutzt',
#   'id2': 'P408',
#   'en2': 'software engine',
#   'es2': 'motor',
#   'fr2': 'moteur logiciel',
#   'de2': 'Engine'},
#  {'id1': 'P1589',
#   'en1': 'lowest point',
#   'es1': 'punto más bajo',
#   'fr1': 'point le plus bas',
#   'de1': 'tiefster Punkt',
#   'id2': 'P206',
#   'en2': 'located in or next to body of water',
#   'es2': 'situado cerca del cuerpo de agua',
#   'fr2': 'baigné par',
#   'de2': 'liegt am oder im Gewässer'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P155',
#   'en2': 'follows',
#   'es2': 'precedido por',
#   'fr2': 'précédé par',
#   'de2': 'Vorgänger'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P2579',
#   'en2': 'studied by',
#   'es2': 'estudiado por',
#   'fr2': "discipline dont c'est l'objet",
#   'de2': 'Forschungsthema in'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P2283',
#   'en1': 'uses',
#   'es1': 'utiliza',
#   'fr1': 'utilise',
#   'de1': 'benutzt',
#   'id2': 'P5009',
#   'en2': 'complies with',
#   'es2': 'conforme a',
#   'fr2': 'est conforme à',
#   'de2': 'erfüllt'},
#  {'id1': 'P676',
#   'en1': 'lyrics by',
#   'es1': 'letra de',
#   'fr1': 'parolier',
#   'de1': 'Text von',
#   'id2': 'P86',
#   'en2': 'composer',
#   'es2': 'compositor',
#   'fr2': 'compositeur ou compositrice',
#   'de2': 'Komponist'},
#  {'id1': 'P279',
#   'en1': 'subclass of',
#   'es1': 'subclase de',
#   'fr1': 'sous-classe de',
#   'de1': 'Unterklasse von',
#   'id2': 'P366',
#   'en2': 'has use',
#   'es2': 'uso',
#   'fr2': 'usage',
#   'de2': 'Benutzung'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P706',
#   'en2': 'located in/on physical feature',
#   'es2': 'situado en la entidad geográfica',
#   'fr2': 'localisation géographique',
#   'de2': 'liegt geographisch im Gebiet oder Gewässer'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P1336',
#   'en1': 'territory claimed by',
#   'es1': 'territorio reivindicado por',
#   'fr1': 'territoire revendiqué par',
#   'de1': 'Gebiet wird beansprucht von',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P122',
#   'en1': 'basic form of government',
#   'es1': 'forma de gobierno',
#   'fr1': 'régime politique',
#   'de1': 'Regierungsform',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P706',
#   'en2': 'located in/on physical feature',
#   'es2': 'situado en la entidad geográfica',
#   'fr2': 'localisation géographique',
#   'de2': 'liegt geographisch im Gebiet oder Gewässer'},
#  {'id1': 'P150',
#   'en1': 'contains administrative territorial entity',
#   'es1': 'subdividido en (división administrativa)',
#   'fr1': 'contient les subdivisions territoriales administratives',
#   'de1': 'Untereinheit (administrative Einheit)',
#   'id2': 'P36',
#   'en2': 'capital',
#   'es2': 'capital',
#   'fr2': 'capitale',
#   'de2': 'Hauptstadt'},
#  {'id1': 'P1344',
#   'en1': 'participant in',
#   'es1': 'participó en',
#   'fr1': 'participant à',
#   'de1': 'Teilnehmer an',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P35',
#   'en1': 'head of state',
#   'es1': 'jefe de Estado',
#   'fr1': "chef d'État",
#   'de1': 'Staatsoberhaupt',
#   'id2': 'P6',
#   'en2': 'head of government',
#   'es2': 'jefe de gobierno',
#   'fr2': "chef de l'exécutif",
#   'de2': 'Leiter der Regierung oder Verwaltung'},
#  {'id1': 'P1313',
#   'en1': 'office held by head of government',
#   'es1': 'cargo ocupado por el jefe de gobierno',
#   'fr1': "poste occupé par le chef de l'exécutif",
#   'de1': 'oberstes Regierungsamt',
#   'id2': 'P1906',
#   'en2': 'office held by head of state',
#   'es2': 'cargo ocupado por el jefe de Estado',
#   'fr2': "fonction occupée par le chef d'État",
#   'de2': 'Amtsbezeichnung des Staatsoberhaupts'},
#  {'id1': 'P2012',
#   'en1': 'cuisine',
#   'es1': 'cocina',
#   'fr1': 'cuisine servie',
#   'de1': 'Küche',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P186',
#   'en1': 'made from material',
#   'es1': 'material empleado',
#   'fr1': 'matériau',
#   'de1': 'Material',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P150',
#   'en1': 'contains administrative territorial entity',
#   'es1': 'subdividido en (división administrativa)',
#   'fr1': 'contient les subdivisions territoriales administratives',
#   'de1': 'Untereinheit (administrative Einheit)',
#   'id2': 'P793',
#   'en2': 'significant event',
#   'es2': 'evento significativo',
#   'fr2': 'évènement clé',
#   'de2': 'Schlüsselereignis'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P3403',
#   'en2': 'coextensive with',
#   'es2': 'mismo territorio que',
#   'fr2': 'a le même territoire que',
#   'de2': 'koexistiert mit'},
#  {'id1': 'P1622',
#   'en1': 'driving side',
#   'es1': 'lado de conducción',
#   'fr1': 'conduite à',
#   'de1': 'Fahrseite',
#   'id2': 'P5658',
#   'en2': 'railway traffic side',
#   'es2': 'sentido de circulación de trenes',
#   'fr2': 'sens de circulation des trains',
#   'de2': 'Fahrordnung'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P530',
#   'en2': 'diplomatic relation',
#   'es2': 'relación diplomática',
#   'fr2': 'relation diplomatique',
#   'de2': 'diplomatische Beziehung'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P27',
#   'en1': 'country of citizenship',
#   'es1': 'país de nacionalidad',
#   'fr1': 'pays de citoyenneté',
#   'de1': 'Land der Staatsangehörigkeit',
#   'id2': 'P945',
#   'en2': 'allegiance',
#   'es2': 'lealtad',
#   'fr2': 'allégeance envers',
#   'de2': 'Treuepflicht'},
#  {'id1': 'P30',
#   'en1': 'continent',
#   'es1': 'continente',
#   'fr1': 'continent',
#   'de1': 'Kontinent',
#   'id2': 'P706',
#   'en2': 'located in/on physical feature',
#   'es2': 'situado en la entidad geográfica',
#   'fr2': 'localisation géographique',
#   'de2': 'liegt geographisch im Gebiet oder Gewässer'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P1376',
#   'en2': 'capital of',
#   'es2': 'capital de',
#   'fr2': 'capitale de',
#   'de2': 'Hauptstadt von'},
#  {'id1': 'P20',
#   'en1': 'place of death',
#   'es1': 'lugar de fallecimiento',
#   'fr1': 'lieu de mort',
#   'de1': 'Sterbeort',
#   'id2': 'P937',
#   'en2': 'work location',
#   'es2': 'lugar de trabajo',
#   'fr2': 'lieu de travail',
#   'de2': 'Wirkungsort'},
#  {'id1': 'P1066',
#   'en1': 'student of',
#   'es1': 'alumno de',
#   'fr1': 'élève de',
#   'de1': 'Schüler von',
#   'id2': 'P69',
#   'en2': 'educated at',
#   'es2': 'educado en',
#   'fr2': 'scolarité',
#   'de2': 'besuchte Bildungseinrichtung'},
#  {'id1': 'P19',
#   'en1': 'place of birth',
#   'es1': 'lugar de nacimiento',
#   'fr1': 'lieu de naissance',
#   'de1': 'Geburtsort',
#   'id2': 'P937',
#   'en2': 'work location',
#   'es2': 'lugar de trabajo',
#   'fr2': 'lieu de travail',
#   'de2': 'Wirkungsort'},
#  {'id1': 'P119',
#   'en1': 'place of burial',
#   'es1': 'lugar de sepultura',
#   'fr1': 'lieu de sépulture',
#   'de1': 'Begräbnisort',
#   'id2': 'P937',
#   'en2': 'work location',
#   'es2': 'lugar de trabajo',
#   'fr2': 'lieu de travail',
#   'de2': 'Wirkungsort'},
#  {'id1': 'P1344',
#   'en1': 'participant in',
#   'es1': 'participó en',
#   'fr1': 'participant à',
#   'de1': 'Teilnehmer an',
#   'id2': 'P607',
#   'en2': 'conflict',
#   'es2': 'participó en el conflicto',
#   'fr2': 'conflit',
#   'de2': 'Kriegseinsatz'},
#  {'id1': 'P180',
#   'en1': 'depicts',
#   'es1': 'representa a',
#   'fr1': 'dépeint',
#   'de1': 'Motiv',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P279',
#   'en1': 'subclass of',
#   'es1': 'subclase de',
#   'fr1': 'sous-classe de',
#   'de1': 'Unterklasse von',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P279',
#   'en1': 'subclass of',
#   'es1': 'subclase de',
#   'fr1': 'sous-classe de',
#   'de1': 'Unterklasse von',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P19',
#   'en1': 'place of birth',
#   'es1': 'lugar de nacimiento',
#   'fr1': 'lieu de naissance',
#   'de1': 'Geburtsort',
#   'id2': 'P20',
#   'en2': 'place of death',
#   'es2': 'lugar de fallecimiento',
#   'fr2': 'lieu de mort',
#   'de2': 'Sterbeort'},
#  {'id1': 'P47',
#   'en1': 'shares border with',
#   'es1': 'comparte fronteras con',
#   'fr1': 'limitrophe de',
#   'de1': 'gemeinsame Grenze mit',
#   'id2': 'P559',
#   'en2': 'terminus',
#   'es2': 'término',
#   'fr2': 'extrémité',
#   'de2': 'Endpunkt (Objekt)'},
#  {'id1': 'P155',
#   'en1': 'follows',
#   'es1': 'precedido por',
#   'fr1': 'précédé par',
#   'de1': 'Vorgänger',
#   'id2': 'P156',
#   'en2': 'followed by',
#   'es2': 'sucedido por',
#   'fr2': 'suivi par',
#   'de2': 'Nachfolger'},
#  {'id1': 'P155',
#   'en1': 'follows',
#   'es1': 'precedido por',
#   'fr1': 'précédé par',
#   'de1': 'Vorgänger',
#   'id2': 'P460',
#   'en2': 'said to be the same as',
#   'es2': 'se dice que es lo mismo que',
#   'fr2': 'réputé identique à',
#   'de2': 'eventuell gleichwertig'},
#  {'id1': 'P156',
#   'en1': 'followed by',
#   'es1': 'sucedido por',
#   'fr1': 'suivi par',
#   'de1': 'Nachfolger',
#   'id2': 'P460',
#   'en2': 'said to be the same as',
#   'es2': 'se dice que es lo mismo que',
#   'fr2': 'réputé identique à',
#   'de2': 'eventuell gleichwertig'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P17',
#   'en2': 'country',
#   'es2': 'país',
#   'fr2': 'pays',
#   'de2': 'Staat'},
#  {'id1': 'P840',
#   'en1': 'narrative location',
#   'es1': 'lugar de la narración',
#   'fr1': "lieu de l'action",
#   'de1': 'Handlungsort',
#   'id2': 'P915',
#   'en2': 'filming location',
#   'es2': 'lugar de filmación',
#   'fr2': 'lieu du tournage',
#   'de2': 'Drehort'},
#  {'id1': 'P57',
#   'en1': 'director',
#   'es1': 'director',
#   'fr1': 'réalisateur ou metteur en scène',
#   'de1': 'Regisseur',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P272',
#   'en1': 'production company',
#   'es1': 'empresa productora',
#   'fr1': 'société de production',
#   'de1': 'Produktionsgesellschaft',
#   'id2': 'P750',
#   'en2': 'distributed by',
#   'es2': 'distribuidor',
#   'fr2': 'distribué par',
#   'de2': 'Distributor'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P495',
#   'en2': 'country of origin',
#   'es2': 'país de origen',
#   'fr2': 'pays d’origine',
#   'de2': 'Ursprungsland'},
#  {'id1': 'P185',
#   'en1': 'doctoral student',
#   'es1': 'doctorando',
#   'fr1': 'doctorant',
#   'de1': 'Doktorand',
#   'id2': 'P802',
#   'en2': 'student',
#   'es2': 'discípulo',
#   'fr2': 'élève',
#   'de2': 'Schüler'},
#  {'id1': 'P108',
#   'en1': 'employer',
#   'es1': 'empleador',
#   'fr1': 'employeur',
#   'de1': 'Arbeitgeber',
#   'id2': 'P69',
#   'en2': 'educated at',
#   'es2': 'educado en',
#   'fr2': 'scolarité',
#   'de2': 'besuchte Bildungseinrichtung'},
#  {'id1': 'P1066',
#   'en1': 'student of',
#   'es1': 'alumno de',
#   'fr1': 'élève de',
#   'de1': 'Schüler von',
#   'id2': 'P737',
#   'en2': 'influenced by',
#   'es2': 'influenciado por',
#   'fr2': 'influencé par',
#   'de2': 'beeinflusst von'},
#  {'id1': 'P1066',
#   'en1': 'student of',
#   'es1': 'alumno de',
#   'fr1': 'élève de',
#   'de1': 'Schüler von',
#   'id2': 'P184',
#   'en2': 'doctoral advisor',
#   'es2': 'supervisor doctoral',
#   'fr2': 'directeur de thèse',
#   'de2': 'Promotionsbetreuer'},
#  {'id1': 'P184',
#   'en1': 'doctoral advisor',
#   'es1': 'supervisor doctoral',
#   'fr1': 'directeur de thèse',
#   'de1': 'Promotionsbetreuer',
#   'id2': 'P737',
#   'en2': 'influenced by',
#   'es2': 'influenciado por',
#   'fr2': 'influencé par',
#   'de2': 'beeinflusst von'},
#  {'id1': 'P101',
#   'en1': 'field of work',
#   'es1': 'campo de trabajo',
#   'fr1': "domaine d'activité",
#   'de1': 'Arbeitsgebiet',
#   'id2': 'P2650',
#   'en2': 'interested in',
#   'es2': 'interesado en',
#   'fr2': 'intéressé par',
#   'de2': 'interessiert an'},
#  {'id1': 'P1411',
#   'en1': 'nominated for',
#   'es1': 'nominado a',
#   'fr1': 'nommé pour',
#   'de1': 'nominiert für',
#   'id2': 'P166',
#   'en2': 'award received',
#   'es2': 'premio recibido',
#   'fr2': 'distinction reçue',
#   'de2': 'Auszeichnung'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P205',
#   'en2': 'basin country',
#   'es2': 'país de la cuenca',
#   'fr2': 'pays souverain sur le bassin versant',
#   'de2': 'Anrainerstaat'},
#  {'id1': 'P31',
#   'en1': 'instance of',
#   'es1': 'instancia de',
#   'fr1': "nature de l'élément",
#   'de1': 'ist ein(e)',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P17',
#   'en2': 'country',
#   'es2': 'país',
#   'fr2': 'pays',
#   'de2': 'Staat'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P6',
#   'en2': 'head of government',
#   'es2': 'jefe de gobierno',
#   'fr2': "chef de l'exécutif",
#   'de2': 'Leiter der Regierung oder Verwaltung'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P35',
#   'en2': 'head of state',
#   'es2': 'jefe de Estado',
#   'fr2': "chef d'État",
#   'de2': 'Staatsoberhaupt'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P20',
#   'en1': 'place of death',
#   'es1': 'lugar de fallecimiento',
#   'fr1': 'lieu de mort',
#   'de1': 'Sterbeort',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P19',
#   'en1': 'place of birth',
#   'es1': 'lugar de nacimiento',
#   'fr1': 'lieu de naissance',
#   'de1': 'Geburtsort',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P706',
#   'en2': 'located in/on physical feature',
#   'es2': 'situado en la entidad geográfica',
#   'fr2': 'localisation géographique',
#   'de2': 'liegt geographisch im Gebiet oder Gewässer'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P2789',
#   'en1': 'connects with',
#   'es1': 'se conecta con',
#   'fr1': 'se connecte avec',
#   'de1': 'physisch verbunden mit',
#   'id2': 'P559',
#   'en2': 'terminus',
#   'es2': 'término',
#   'fr2': 'extrémité',
#   'de2': 'Endpunkt (Objekt)'},
#  {'id1': 'P279',
#   'en1': 'subclass of',
#   'es1': 'subclase de',
#   'fr1': 'sous-classe de',
#   'de1': 'Unterklasse von',
#   'id2': 'P460',
#   'en2': 'said to be the same as',
#   'es2': 'se dice que es lo mismo que',
#   'fr2': 'réputé identique à',
#   'de2': 'eventuell gleichwertig'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P206',
#   'en1': 'located in or next to body of water',
#   'es1': 'situado cerca del cuerpo de agua',
#   'fr1': 'baigné par',
#   'de1': 'liegt am oder im Gewässer',
#   'id2': 'P276',
#   'en2': 'location',
#   'es2': 'ubicación',
#   'fr2': 'lieu',
#   'de2': 'Ort'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P272',
#   'en1': 'production company',
#   'es1': 'empresa productora',
#   'fr1': 'société de production',
#   'de1': 'Produktionsgesellschaft',
#   'id2': 'P449',
#   'en2': 'original broadcaster',
#   'es2': 'emisora original',
#   'fr2': 'diffuseur original',
#   'de2': 'Sender der Erstausstrahlung'},
#  {'id1': 'P885',
#   'en1': 'origin of the watercourse',
#   'es1': 'origen del curso de agua',
#   'fr1': 'source',
#   'de1': 'Quelle des Wasserlaufs',
#   'id2': 'P974',
#   'en2': 'tributary',
#   'es2': 'afluente',
#   'fr2': 'affluent',
#   'de2': 'Nebenfluss'},
#  {'id1': 'P2922',
#   'en1': 'month of the year',
#   'es1': 'mes del año',
#   'fr1': "mois de l'année",
#   'de1': 'Monat des Jahres',
#   'id2': 'P4794',
#   'en2': 'season starts',
#   'es2': 'inicio de la temporada',
#   'fr2': 'début de la saison',
#   'de2': 'Saisonstart'},
#  {'id1': 'P1347',
#   'en1': 'military casualty classification',
#   'es1': 'clasificación militar de víctimas',
#   'fr1': 'classification militaire des victimes',
#   'de1': 'Klassifikation militärischer Verluste',
#   'id2': 'P509',
#   'en2': 'cause of death',
#   'es2': 'causa de muerte',
#   'fr2': 'cause de la mort',
#   'de2': 'Todesursache'},
#  {'id1': 'P102',
#   'en1': 'member of political party',
#   'es1': 'miembro del partido político',
#   'fr1': 'parti politique',
#   'de1': 'Parteizugehörigkeit',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P2184',
#   'en1': 'history of topic',
#   'es1': 'historia',
#   'fr1': 'histoire',
#   'de1': 'Geschichte',
#   'id2': 'P2579',
#   'en2': 'studied by',
#   'es2': 'estudiado por',
#   'fr2': "discipline dont c'est l'objet",
#   'de2': 'Forschungsthema in'},
#  {'id1': 'P1343',
#   'en1': 'described by source',
#   'es1': 'descrito en',
#   'fr1': 'décrit par',
#   'de1': 'beschrieben in',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P50',
#   'en2': 'author',
#   'es2': 'autor',
#   'fr2': 'auteur',
#   'de2': 'Autor'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P36',
#   'en2': 'capital',
#   'es2': 'capital',
#   'fr2': 'capitale',
#   'de2': 'Hauptstadt'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P150',
#   'en2': 'contains administrative territorial entity',
#   'es2': 'subdividido en (división administrativa)',
#   'fr2': 'contient les subdivisions territoriales administratives',
#   'de2': 'Untereinheit (administrative Einheit)'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P189',
#   'en1': 'location of discovery',
#   'es1': 'lugar de descubrimiento',
#   'fr1': 'lieu de découverte',
#   'de1': 'Fundort',
#   'id2': 'P61',
#   'en2': 'discoverer or inventor',
#   'es2': 'descubridor o inventor',
#   'fr2': 'découvreur ou inventeur',
#   'de2': 'Entdecker oder Erfinder'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P4552',
#   'en2': 'mountain range',
#   'es2': 'cordillera',
#   'fr2': 'chaîne de montagnes',
#   'de2': 'Gebirgszug'},
#  {'id1': 'P301',
#   'en1': "category's main topic",
#   'es1': 'tema principal de la categoría',
#   'fr1': 'sujet de la catégorie',
#   'de1': 'Thema der Kategorie',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P463',
#   'en1': 'member of',
#   'es1': 'miembro de',
#   'fr1': 'membre de',
#   'de1': 'Mitglied von',
#   'id2': 'P598',
#   'en2': 'commander of (DEPRECATED)',
#   'es2': 'comandante de (OBSOLETO)',
#   'fr2': 'commandement (OBSOLÈTE)',
#   'de2': 'befohlene Einheiten (VERALTET)'},
#  {'id1': 'P463',
#   'en1': 'member of',
#   'es1': 'miembro de',
#   'fr1': 'membre de',
#   'de1': 'Mitglied von',
#   'id2': 'P945',
#   'en2': 'allegiance',
#   'es2': 'lealtad',
#   'fr2': 'allégeance envers',
#   'de2': 'Treuepflicht'},
#  {'id1': 'P598',
#   'en1': 'commander of (DEPRECATED)',
#   'es1': 'comandante de (OBSOLETO)',
#   'fr1': 'commandement (OBSOLÈTE)',
#   'de1': 'befohlene Einheiten (VERALTET)',
#   'id2': 'P945',
#   'en2': 'allegiance',
#   'es2': 'lealtad',
#   'fr2': 'allégeance envers',
#   'de2': 'Treuepflicht'},
#  {'id1': 'P194',
#   'en1': 'legislative body',
#   'es1': 'órgano legislativo',
#   'fr1': 'assemblée délibérante',
#   'de1': 'gesetzgebende Körperschaft',
#   'id2': 'P208',
#   'en2': 'executive body',
#   'es2': 'órgano ejecutivo',
#   'fr2': 'exécutif',
#   'de2': 'Exekutivorgan'},
#  {'id1': 'P119',
#   'en1': 'place of burial',
#   'es1': 'lugar de sepultura',
#   'fr1': 'lieu de sépulture',
#   'de1': 'Begräbnisort',
#   'id2': 'P19',
#   'en2': 'place of birth',
#   'es2': 'lugar de nacimiento',
#   'fr2': 'lieu de naissance',
#   'de2': 'Geburtsort'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P138',
#   'en2': 'named after',
#   'es2': 'nombrado por',
#   'fr2': 'nommé en référence à',
#   'de2': 'benannt nach'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P206',
#   'en2': 'located in or next to body of water',
#   'es2': 'situado cerca del cuerpo de agua',
#   'fr2': 'baigné par',
#   'de2': 'liegt am oder im Gewässer'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P825',
#   'en2': 'dedicated to',
#   'es2': 'dedicado a',
#   'fr2': 'dédicataire',
#   'de2': 'Widmung an'},
#  {'id1': 'P1313',
#   'en1': 'office held by head of government',
#   'es1': 'cargo ocupado por el jefe de gobierno',
#   'fr1': "poste occupé par le chef de l'exécutif",
#   'de1': 'oberstes Regierungsamt',
#   'id2': 'P208',
#   'en2': 'executive body',
#   'es2': 'órgano ejecutivo',
#   'fr2': 'exécutif',
#   'de2': 'Exekutivorgan'},
#  {'id1': 'P39',
#   'en1': 'position held',
#   'es1': 'cargo ocupado',
#   'fr1': 'fonction',
#   'de1': 'öffentliches Amt oder Stellung',
#   'id2': 'P97',
#   'en2': 'noble title',
#   'es2': 'título nobiliario',
#   'fr2': 'titre de noblesse',
#   'de2': 'Adelstitel'},
#  {'id1': 'P205',
#   'en1': 'basin country',
#   'es1': 'país de la cuenca',
#   'fr1': 'pays souverain sur le bassin versant',
#   'de1': 'Anrainerstaat',
#   'id2': 'P885',
#   'en2': 'origin of the watercourse',
#   'es2': 'origen del curso de agua',
#   'fr2': 'source',
#   'de2': 'Quelle des Wasserlaufs'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P885',
#   'en2': 'origin of the watercourse',
#   'es2': 'origen del curso de agua',
#   'fr2': 'source',
#   'de2': 'Quelle des Wasserlaufs'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P47',
#   'en1': 'shares border with',
#   'es1': 'comparte fronteras con',
#   'fr1': 'limitrophe de',
#   'de1': 'gemeinsame Grenze mit',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P150',
#   'en1': 'contains administrative territorial entity',
#   'es1': 'subdividido en (división administrativa)',
#   'fr1': 'contient les subdivisions territoriales administratives',
#   'de1': 'Untereinheit (administrative Einheit)',
#   'id2': 'P1589',
#   'en2': 'lowest point',
#   'es2': 'punto más bajo',
#   'fr2': 'point le plus bas',
#   'de2': 'tiefster Punkt'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P500',
#   'en2': 'exclave of',
#   'es2': 'exclave de',
#   'fr2': 'exclave de',
#   'de2': 'Exklave von'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P500',
#   'en2': 'exclave of',
#   'es2': 'exclave de',
#   'fr2': 'exclave de',
#   'de2': 'Exklave von'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P500',
#   'en2': 'exclave of',
#   'es2': 'exclave de',
#   'fr2': 'exclave de',
#   'de2': 'Exklave von'},
#  {'id1': 'P1532',
#   'en1': 'country for sport',
#   'es1': 'nacionalidad deportiva',
#   'fr1': 'pays de nationalité sportive',
#   'de1': 'Land (Sport)',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P31',
#   'en1': 'instance of',
#   'es1': 'instancia de',
#   'fr1': "nature de l'élément",
#   'de1': 'ist ein(e)',
#   'id2': 'P6106',
#   'en2': 'uses capitalization for',
#   'es2': 'usa mayúsculas para',
#   'fr2': 'utilise les majuscules pour',
#   'de2': 'verwendet Großschreibung für'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P2341',
#   'en2': 'indigenous to',
#   'es2': 'nativo de',
#   'fr2': 'autochtone de',
#   'de2': 'einheimisch'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P2341',
#   'en2': 'indigenous to',
#   'es2': 'nativo de',
#   'fr2': 'autochtone de',
#   'de2': 'einheimisch'},
#  {'id1': 'P1441',
#   'en1': 'present in work',
#   'es1': 'presente en la obra',
#   'fr1': "présent dans l'œuvre",
#   'de1': 'kommt vor in',
#   'id2': 'P8345',
#   'en2': 'media franchise',
#   'es2': 'franquicia de medios',
#   'fr2': 'franchise médiatique',
#   'de2': 'Medien-Franchise'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P941',
#   'en2': 'inspired by',
#   'es2': 'inspirado por',
#   'fr2': 'inspiré de',
#   'de2': 'inspiriert von'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P279',
#   'en2': 'subclass of',
#   'es2': 'subclase de',
#   'fr2': 'sous-classe de',
#   'de2': 'Unterklasse von'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P161',
#   'en1': 'cast member',
#   'es1': 'miembro del reparto',
#   'fr1': 'distribution',
#   'de1': 'Darsteller',
#   'id2': 'P162',
#   'en2': 'producer',
#   'es2': 'productor',
#   'fr2': 'producteur',
#   'de2': 'Produzent'},
#  {'id1': 'P162',
#   'en1': 'producer',
#   'es1': 'productor',
#   'fr1': 'producteur',
#   'de1': 'Produzent',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P144',
#   'en1': 'based on',
#   'es1': 'basado en',
#   'fr1': 'basé sur',
#   'de1': 'basiert auf',
#   'id2': 'P8646',
#   'en2': 'expansion of',
#   'es2': 'expansión de',
#   'fr2': 'extension de',
#   'de2': 'Erweiterung von'},
#  {'id1': 'P47',
#   'en1': 'shares border with',
#   'es1': 'comparte fronteras con',
#   'fr1': 'limitrophe de',
#   'de1': 'gemeinsame Grenze mit',
#   'id2': 'P501',
#   'en2': 'enclave within',
#   'es2': 'enclave en',
#   'fr2': 'enclavé dans',
#   'de2': 'Enklave in'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P710',
#   'en2': 'participant',
#   'es2': 'participante',
#   'fr2': 'participant',
#   'de2': 'Teilnehmer'},
#  {'id1': 'P1344',
#   'en1': 'participant in',
#   'es1': 'participó en',
#   'fr1': 'participant à',
#   'de1': 'Teilnehmer an',
#   'id2': 'P3602',
#   'en2': 'candidacy in election',
#   'es2': 'candidato en la elección',
#   'fr2': "candidat à l'élection",
#   'de2': 'kandidiert(e) für'},
#  {'id1': 'P241',
#   'en1': 'military branch',
#   'es1': 'rama militar',
#   'fr1': 'arme',
#   'de1': 'Teilstreitkraft',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P3403',
#   'en2': 'coextensive with',
#   'es2': 'mismo territorio que',
#   'fr2': 'a le même territoire que',
#   'de2': 'koexistiert mit'},
#  {'id1': 'P1336',
#   'en1': 'territory claimed by',
#   'es1': 'territorio reivindicado por',
#   'fr1': 'territoire revendiqué par',
#   'de1': 'Gebiet wird beansprucht von',
#   'id2': 'P17',
#   'en2': 'country',
#   'es2': 'país',
#   'fr2': 'pays',
#   'de2': 'Staat'},
#  {'id1': 'P4224',
#   'en1': 'category contains',
#   'es1': 'categoría contiene',
#   'fr1': "type d'élément contenu dans la catégorie",
#   'de1': 'Kategorie enthält',
#   'id2': 'P971',
#   'en2': 'category combines topics',
#   'es2': 'temas asociados por la categoría',
#   'fr2': 'sujets associés à la catégorie',
#   'de2': 'Kategorie kombiniert die Themen'},
#  {'id1': 'P190',
#   'en1': 'twinned administrative body',
#   'es1': 'ciudad hermana',
#   'fr1': 'jumelage ou partenariat',
#   'de1': 'Partnerkommune',
#   'id2': 'P47',
#   'en2': 'shares border with',
#   'es2': 'comparte fronteras con',
#   'fr2': 'limitrophe de',
#   'de2': 'gemeinsame Grenze mit'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P1366',
#   'en2': 'replaced by',
#   'es2': 'reemplazado por',
#   'fr2': 'remplacé par',
#   'de2': 'ersetzt durch'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P36',
#   'en2': 'capital',
#   'es2': 'capital',
#   'fr2': 'capitale',
#   'de2': 'Hauptstadt'},
#  {'id1': 'P344',
#   'en1': 'director of photography',
#   'es1': 'director de fotografía',
#   'fr1': 'directeur de la photographie',
#   'de1': 'Kameramann',
#   'id2': 'P57',
#   'en2': 'director',
#   'es2': 'director',
#   'fr2': 'réalisateur ou metteur en scène',
#   'de2': 'Regisseur'},
#  {'id1': 'P344',
#   'en1': 'director of photography',
#   'es1': 'director de fotografía',
#   'fr1': 'directeur de la photographie',
#   'de1': 'Kameramann',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P931',
#   'en2': 'place served by transport hub',
#   'es2': 'ciudad asociada',
#   'fr2': 'localité desservie par cette infrastructure de transport',
#   'de2': 'Ort, der vom Verkehrsknotenpunkt bedient wird'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P7959',
#   'en2': 'historic county',
#   'es2': 'condado histórico',
#   'fr2': 'comté historique',
#   'de2': 'historic county'},
#  {'id1': 'P466',
#   'en1': 'occupant',
#   'es1': 'ocupante',
#   'fr1': 'occupant',
#   'de1': 'Bewohner/Nutzer',
#   'id2': 'P88',
#   'en2': 'commissioned by',
#   'es2': 'comisionador',
#   'fr2': 'commanditaire',
#   'de2': 'Auftraggeber'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P466',
#   'en2': 'occupant',
#   'es2': 'ocupante',
#   'fr2': 'occupant',
#   'de2': 'Bewohner/Nutzer'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P88',
#   'en2': 'commissioned by',
#   'es2': 'comisionador',
#   'fr2': 'commanditaire',
#   'de2': 'Auftraggeber'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P466',
#   'en2': 'occupant',
#   'es2': 'ocupante',
#   'fr2': 'occupant',
#   'de2': 'Bewohner/Nutzer'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P88',
#   'en2': 'commissioned by',
#   'es2': 'comisionador',
#   'fr2': 'commanditaire',
#   'de2': 'Auftraggeber'},
#  {'id1': 'P485',
#   'en1': 'archives at',
#   'es1': 'archivado en',
#   'fr1': 'archivé par',
#   'de1': 'archiviert in',
#   'id2': 'P69',
#   'en2': 'educated at',
#   'es2': 'educado en',
#   'fr2': 'scolarité',
#   'de2': 'besuchte Bildungseinrichtung'},
#  {'id1': 'P161',
#   'en1': 'cast member',
#   'es1': 'miembro del reparto',
#   'fr1': 'distribution',
#   'de1': 'Darsteller',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P161',
#   'en1': 'cast member',
#   'es1': 'miembro del reparto',
#   'fr1': 'distribution',
#   'de1': 'Darsteller',
#   'id2': 'P57',
#   'en2': 'director',
#   'es2': 'director',
#   'fr2': 'réalisateur ou metteur en scène',
#   'de2': 'Regisseur'},
#  {'id1': 'P101',
#   'en1': 'field of work',
#   'es1': 'campo de trabajo',
#   'fr1': "domaine d'activité",
#   'de1': 'Arbeitsgebiet',
#   'id2': 'P106',
#   'en2': 'occupation',
#   'es2': 'ocupación',
#   'fr2': 'occupation',
#   'de2': 'Tätigkeit'},
#  {'id1': 'P3450',
#   'en1': 'sports season of league or competition',
#   'es1': 'temporada deportiva de',
#   'fr1': 'saison sportive de',
#   'de1': 'Spielsaison der Liga oder des Wettbewerbs',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P3450',
#   'en1': 'sports season of league or competition',
#   'es1': 'temporada deportiva de',
#   'fr1': 'saison sportive de',
#   'de1': 'Spielsaison der Liga oder des Wettbewerbs',
#   'id2': 'P664',
#   'en2': 'organizer',
#   'es2': 'organizador',
#   'fr2': 'organisateur',
#   'de2': 'Veranstalter'},
#  {'id1': 'P1050',
#   'en1': 'medical condition',
#   'es1': 'condición médica',
#   'fr1': 'affection médicale',
#   'de1': 'Erkrankung',
#   'id2': 'P509',
#   'en2': 'cause of death',
#   'es2': 'causa de muerte',
#   'fr2': 'cause de la mort',
#   'de2': 'Todesursache'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P749',
#   'en2': 'parent organization',
#   'es2': 'organización matriz',
#   'fr2': 'organisation mère',
#   'de2': 'übergeordnete Organisation'},
#  {'id1': 'P1830',
#   'en1': 'owner of',
#   'es1': 'propietario de',
#   'fr1': 'propriétaire de',
#   'de1': 'Inhaber von',
#   'id2': 'P355',
#   'en2': 'subsidiary',
#   'es2': 'filial',
#   'fr2': 'organisation fille',
#   'de2': 'nachgeordnete Organisation'},
#  {'id1': 'P27',
#   'en1': 'country of citizenship',
#   'es1': 'país de nacionalidad',
#   'fr1': 'pays de citoyenneté',
#   'de1': 'Land der Staatsangehörigkeit',
#   'id2': 'P53',
#   'en2': 'family',
#   'es2': 'familia',
#   'fr2': 'famille',
#   'de2': 'Familie'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P140',
#   'en1': 'religion or world view',
#   'es1': 'religión',
#   'fr1': 'religion ou conception du monde',
#   'de1': 'Konfession oder Weltanschauung',
#   'id2': 'P3075',
#   'en2': 'official religion',
#   'es2': 'religión oficial',
#   'fr2': 'religion officielle',
#   'de2': 'offizielle Religion'},
#  {'id1': 'P178',
#   'en1': 'developer',
#   'es1': 'desarrollador',
#   'fr1': 'développeur',
#   'de1': 'Entwickler',
#   'id2': 'P943',
#   'en2': 'programmer',
#   'es2': 'programador',
#   'fr2': 'programmeur',
#   'de2': 'Programmierer'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P943',
#   'en2': 'programmer',
#   'es2': 'programador',
#   'fr2': 'programmeur',
#   'de2': 'Programmierer'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P943',
#   'en2': 'programmer',
#   'es2': 'programador',
#   'fr2': 'programmeur',
#   'de2': 'Programmierer'},
#  {'id1': 'P1552',
#   'en1': 'has quality',
#   'es1': 'caracterizado por',
#   'fr1': 'caractérisé par',
#   'de1': 'charakterisiert durch',
#   'id2': 'P366',
#   'en2': 'has use',
#   'es2': 'uso',
#   'fr2': 'usage',
#   'de2': 'Benutzung'},
#  {'id1': 'P135',
#   'en1': 'movement',
#   'es1': 'movimiento',
#   'fr1': 'mouvement',
#   'de1': 'Bewegung',
# ...
#   'en1': 'winner',
#   'es1': 'ganador',
#   'fr1': 'vainqueur',
#   'de1': 'Sieger',
#   'id2': 'P3497',
#   'en2': 'teams classification by time',
#   'es2': 'clasificación de equipos por tiempo',
#   'fr2': 'classement par équipes aux temps',
#   'de2': 'Mannschaftswertung nach Zeit'},
#  {'id1': 'P1542',
#   'en1': 'has effect',
#   'es1': 'causa de',
#   'fr1': 'a pour effet',
#   'de1': 'Ursache von',
#   'id2': 'P366',
#   'en2': 'has use',
#   'es2': 'uso',
#   'fr2': 'usage',
#   'de2': 'Benutzung'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P50',
#   'en2': 'author',
#   'es2': 'autor',
#   'fr2': 'auteur',
#   'de2': 'Autor'},
#  {'id1': 'P206',
#   'en1': 'located in or next to body of water',
#   'es1': 'situado cerca del cuerpo de agua',
#   'fr1': 'baigné par',
#   'de1': 'liegt am oder im Gewässer',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P57',
#   'en1': 'director',
#   'es1': 'director',
#   'fr1': 'réalisateur ou metteur en scène',
#   'de1': 'Regisseur',
#   'id2': 'P725',
#   'en2': 'voice actor',
#   'es2': 'actor de voz',
#   'fr2': 'comédien de doublage',
#   'de2': 'Sprecher'},
#  {'id1': 'P241',
#   'en1': 'military branch',
#   'es1': 'rama militar',
#   'fr1': 'arme',
#   'de1': 'Teilstreitkraft',
#   'id2': 'P749',
#   'en2': 'parent organization',
#   'es2': 'organización matriz',
#   'fr2': 'organisation mère',
#   'de2': 'übergeordnete Organisation'},
#  {'id1': 'P176',
#   'en1': 'manufacturer',
#   'es1': 'fabricante',
#   'fr1': 'fabricant',
#   'de1': 'Hersteller',
#   'id2': 'P495',
#   'en2': 'country of origin',
#   'es2': 'país de origen',
#   'fr2': 'pays d’origine',
#   'de2': 'Ursprungsland'},
#  {'id1': 'P137',
#   'en1': 'operator',
#   'es1': 'operador',
#   'fr1': 'opérateur',
#   'de1': 'Betreiber',
#   'id2': 'P495',
#   'en2': 'country of origin',
#   'es2': 'país de origen',
#   'fr2': 'pays d’origine',
#   'de2': 'Ursprungsland'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P176',
#   'en2': 'manufacturer',
#   'es2': 'fabricante',
#   'fr2': 'fabricant',
#   'de2': 'Hersteller'},
#  {'id1': 'P2283',
#   'en1': 'uses',
#   'es1': 'utiliza',
#   'fr1': 'utilise',
#   'de1': 'benutzt',
#   'id2': 'P279',
#   'en2': 'subclass of',
#   'es2': 'subclase de',
#   'fr2': 'sous-classe de',
#   'de2': 'Unterklasse von'},
#  {'id1': 'P136',
#   'en1': 'genre',
#   'es1': 'género',
#   'fr1': 'genre',
#   'de1': 'Genre',
#   'id2': 'P1552',
#   'en2': 'has quality',
#   'es2': 'caracterizado por',
#   'fr2': 'caractérisé par',
#   'de2': 'charakterisiert durch'},
#  {'id1': 'P102',
#   'en1': 'member of political party',
#   'es1': 'miembro del partido político',
#   'fr1': 'parti politique',
#   'de1': 'Parteizugehörigkeit',
#   'id2': 'P1344',
#   'en2': 'participant in',
#   'es2': 'participó en',
#   'fr2': 'participant à',
#   'de2': 'Teilnehmer an'},
#  {'id1': 'P3275',
#   'en1': 'storyboard artist',
#   'es1': 'guionista gráfico',
#   'fr1': 'storyboardeur',
#   'de1': 'Storyboard Artist',
#   'id2': 'P58',
#   'en2': 'screenwriter',
#   'es2': 'guionista',
#   'fr2': 'scénariste',
#   'de2': 'Drehbuchautor'},
#  {'id1': 'P3275',
#   'en1': 'storyboard artist',
#   'es1': 'guionista gráfico',
#   'fr1': 'storyboardeur',
#   'de1': 'Storyboard Artist',
#   'id2': 'P725',
#   'en2': 'voice actor',
#   'es2': 'actor de voz',
#   'fr2': 'comédien de doublage',
#   'de2': 'Sprecher'},
#  {'id1': 'P3092',
#   'en1': 'film crew member',
#   'es1': 'miembro del equipo de filmación',
#   'fr1': "membre de l'équipe du film",
#   'de1': 'Mitglied des Filmstabs',
#   'id2': 'P3275',
#   'en2': 'storyboard artist',
#   'es2': 'guionista gráfico',
#   'fr2': 'storyboardeur',
#   'de2': 'Storyboard Artist'},
#  {'id1': 'P159',
#   'en1': 'headquarters location',
#   'es1': 'ubicación de la sede',
#   'fr1': 'siège',
#   'de1': 'Hauptverwaltung',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P7959',
#   'en2': 'historic county',
#   'es2': 'condado histórico',
#   'fr2': 'comté historique',
#   'de2': 'historic county'},
#  {'id1': 'P1877',
#   'en1': 'after a work by',
#   'es1': 'inspirado en la obra de',
#   'fr1': "d'après une œuvre de",
#   'de1': 'nach einem Werk von',
#   'id2': 'P50',
#   'en2': 'author',
#   'es2': 'autor',
#   'fr2': 'auteur',
#   'de2': 'Autor'},
#  {'id1': 'P136',
#   'en1': 'genre',
#   'es1': 'género',
#   'fr1': 'genre',
#   'de1': 'Genre',
#   'id2': 'P144',
#   'en2': 'based on',
#   'es2': 'basado en',
#   'fr2': 'basé sur',
#   'de2': 'basiert auf'},
#  {'id1': 'P676',
#   'en1': 'lyrics by',
#   'es1': 'letra de',
#   'fr1': 'parolier',
#   'de1': 'Text von',
#   'id2': 'P87',
#   'en2': 'librettist',
#   'es2': 'libretista',
#   'fr2': 'librettiste',
#   'de2': 'Librettist'},
#  {'id1': 'P50',
#   'en1': 'author',
#   'es1': 'autor',
#   'fr1': 'auteur',
#   'de1': 'Autor',
#   'id2': 'P87',
#   'en2': 'librettist',
#   'es2': 'libretista',
#   'fr2': 'librettiste',
#   'de2': 'Librettist'},
#  {'id1': 'P50',
#   'en1': 'author',
#   'es1': 'autor',
#   'fr1': 'auteur',
#   'de1': 'Autor',
#   'id2': 'P676',
#   'en2': 'lyrics by',
#   'es2': 'letra de',
#   'fr2': 'parolier',
#   'de2': 'Text von'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P87',
#   'en2': 'librettist',
#   'es2': 'libretista',
#   'fr2': 'librettiste',
#   'de2': 'Librettist'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P86',
#   'en2': 'composer',
#   'es2': 'compositor',
#   'fr2': 'compositeur ou compositrice',
#   'de2': 'Komponist'},
#  {'id1': 'P170',
#   'en1': 'creator',
#   'es1': 'creador',
#   'fr1': 'créateur',
#   'de1': 'Urheber',
#   'id2': 'P676',
#   'en2': 'lyrics by',
#   'es2': 'letra de',
#   'fr2': 'parolier',
#   'de2': 'Text von'},
#  {'id1': 'P366',
#   'en1': 'has use',
#   'es1': 'uso',
#   'fr1': 'usage',
#   'de1': 'Benutzung',
#   'id2': 'P407',
#   'en2': 'language of work or name',
#   'es2': 'idioma de la obra o del nombre',
#   'fr2': "langue de l'œuvre, du nom ou du terme",
#   'de2': 'Sprache des Werks, Namens oder Begriffes'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P495',
#   'en2': 'country of origin',
#   'es2': 'país de origen',
#   'fr2': 'pays d’origine',
#   'de2': 'Ursprungsland'},
#  {'id1': 'P17',
#   'en1': 'country',
#   'es1': 'país',
#   'fr1': 'pays',
#   'de1': 'Staat',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P27',
#   'en2': 'country of citizenship',
#   'es2': 'país de nacionalidad',
#   'fr2': 'pays de citoyenneté',
#   'de2': 'Land der Staatsangehörigkeit'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P495',
#   'en2': 'country of origin',
#   'es2': 'país de origen',
#   'fr2': 'pays d’origine',
#   'de2': 'Ursprungsland'},
#  {'id1': 'P1889',
#   'en1': 'different from',
#   'es1': 'diferente de',
#   'fr1': 'à ne pas confondre avec',
#   'de1': 'verschieden von',
#   'id2': 'P4149',
#   'en2': 'conjugate base',
#   'es2': 'base conjugada',
#   'fr2': 'base conjuguée',
#   'de2': 'konjugierte Base'},
#  {'id1': 'P2596',
#   'en1': 'culture',
#   'es1': 'cultura',
#   'fr1': 'culture',
#   'de1': 'Kultur',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P106',
#   'en1': 'occupation',
#   'es1': 'ocupación',
#   'fr1': 'occupation',
#   'de1': 'Tätigkeit',
#   'id2': 'P641',
#   'en2': 'sport',
#   'es2': 'deporte',
#   'fr2': 'sport',
#   'de2': 'Sportart'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P3842',
#   'en2': 'located in present-day administrative territorial entity',
#   'es2': 'ubicado en la entidad territorial administrativa actual',
#   'fr2': 'entité territoriale administrative actuelle',
#   'de2': 'liegt in der heutigen Verwaltungseinheit'},
#  {'id1': 'P1365',
#   'en1': 'replaces',
#   'es1': 'reemplaza a',
#   'fr1': 'remplace',
#   'de1': 'ersetzt',
#   'id2': 'P361',
#   'en2': 'part of',
#   'es2': 'forma parte de',
#   'fr2': 'partie de',
#   'de2': 'ist Teil von'},
#  {'id1': 'P361',
#   'en1': 'part of',
#   'es1': 'forma parte de',
#   'fr1': 'partie de',
#   'de1': 'ist Teil von',
#   'id2': 'P3842',
#   'en2': 'located in present-day administrative territorial entity',
#   'es2': 'ubicado en la entidad territorial administrativa actual',
#   'fr2': 'entité territoriale administrative actuelle',
#   'de2': 'liegt in der heutigen Verwaltungseinheit'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P3975',
#   'en2': 'secretary general',
#   'es2': 'secretario general',
#   'fr2': 'secrétaire général',
#   'de2': 'Generalsekretär'},
#  {'id1': 'P138',
#   'en1': 'named after',
#   'es1': 'nombrado por',
#   'fr1': 'nommé en référence à',
#   'de1': 'benannt nach',
#   'id2': 'P1557',
#   'en2': 'manifestation of',
#   'es2': 'manifestación de',
#   'fr2': 'manifestation de',
#   'de2': 'Manifestation von'},
#  {'id1': 'P1557',
#   'en1': 'manifestation of',
#   'es1': 'manifestación de',
#   'fr1': 'manifestation de',
#   'de1': 'Manifestation von',
#   'id2': 'P921',
#   'en2': 'main subject',
#   'es2': 'tema principal de la obra',
#   'fr2': 'sujet ou thème principal',
#   'de2': 'zentrales Thema'},
#  {'id1': 'P2348',
#   'en1': 'time period',
#   'es1': 'periodo histórico',
#   'fr1': 'période',
#   'de1': 'Zeitraum',
#   'id2': 'P710',
#   'en2': 'participant',
#   'es2': 'participante',
#   'fr2': 'participant',
#   'de2': 'Teilnehmer'},
#  {'id1': 'P1312',
#   'en1': 'has facet polytope',
#   'es1': 'faceta del politopo',
#   'fr1': 'polytope de facette',
#   'de1': 'Facette des Polytops',
#   'id2': 'P3263',
#   'en2': 'base',
#   'es2': 'base geométrica',
#   'fr2': 'base (géométrie)',
#   'de2': 'Grundfläche'},
#  {'id1': 'P1376',
#   'en1': 'capital of',
#   'es1': 'capital de',
#   'fr1': 'capitale de',
#   'de1': 'Hauptstadt von',
#   'id2': 'P31',
#   'en2': 'instance of',
#   'es2': 'instancia de',
#   'fr2': "nature de l'élément",
#   'de2': 'ist ein(e)'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P463',
#   'en2': 'member of',
#   'es2': 'miembro de',
#   'fr2': 'membre de',
#   'de2': 'Mitglied von'},
#  {'id1': 'P5021',
#   'en1': 'assessment',
#   'es1': 'examen realizado',
#   'fr1': 'examen ou concours effectué',
#   'de1': 'abgelegte Prüfung',
#   'id2': 'P69',
#   'en2': 'educated at',
#   'es2': 'educado en',
#   'fr2': 'scolarité',
#   'de2': 'besuchte Bildungseinrichtung'},
#  {'id1': 'P1789',
#   'en1': 'chief operating officer',
#   'es1': 'jefe de operaciones',
#   'fr1': "directeur de l'exploitation",
#   'de1': 'Chief Operating Officer',
#   'id2': 'P488',
#   'en2': 'chairperson',
#   'es2': 'presidente',
#   'fr2': 'président',
#   'de2': 'Vorsitzender'},
#  {'id1': 'P1037',
#   'en1': 'director / manager',
#   'es1': 'gerente/director',
#   'fr1': 'dirigeant',
#   'de1': 'Leiter',
#   'id2': 'P1789',
#   'en2': 'chief operating officer',
#   'es2': 'jefe de operaciones',
#   'fr2': "directeur de l'exploitation",
#   'de2': 'Chief Operating Officer'},
#  {'id1': 'P169',
#   'en1': 'chief executive officer',
#   'es1': 'director ejecutivo',
#   'fr1': 'directeur général',
#   'de1': 'Geschäftsführer',
#   'id2': 'P488',
#   'en2': 'chairperson',
#   'es2': 'presidente',
#   'fr2': 'président',
#   'de2': 'Vorsitzender'},
#  {'id1': 'P169',
#   'en1': 'chief executive officer',
#   'es1': 'director ejecutivo',
#   'fr1': 'directeur général',
#   'de1': 'Geschäftsführer',
#   'id2': 'P1789',
#   'en2': 'chief operating officer',
#   'es2': 'jefe de operaciones',
#   'fr2': "directeur de l'exploitation",
#   'de2': 'Chief Operating Officer'},
#  {'id1': 'P291',
#   'en1': 'place of publication',
#   'es1': 'lugar de publicación',
#   'fr1': 'lieu de publication',
#   'de1': 'Erscheinungsort',
#   'id2': 'P840',
#   'en2': 'narrative location',
#   'es2': 'lugar de la narración',
#   'fr2': "lieu de l'action",
#   'de2': 'Handlungsort'},
#  {'id1': 'P3373',
#   'en1': 'sibling',
#   'es1': 'hermano o hermana',
#   'fr1': 'frère ou sœur',
#   'de1': 'Geschwister',
#   'id2': 'P40',
#   'en2': 'child',
#   'es2': 'hijo o hija',
#   'fr2': 'enfant',
#   'de2': 'Kind(er)'},
#  {'id1': 'P101',
#   'en1': 'field of work',
#   'es1': 'campo de trabajo',
#   'fr1': "domaine d'activité",
#   'de1': 'Arbeitsgebiet',
#   'id2': 'P800',
#   'en2': 'notable work',
#   'es2': 'obra destacada',
#   'fr2': 'œuvre notable',
#   'de2': 'bedeutende Werke'},
#  {'id1': 'P1038',
#   'en1': 'relative',
#   'es1': 'pariente',
#   'fr1': 'parentèle',
#   'de1': 'Verwandte',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P131',
#   'en1': 'located in the administrative territorial entity',
#   'es1': 'situado en la entidad territorial administrativa',
#   'fr1': 'localisation administrative',
#   'de1': 'liegt in der Verwaltungseinheit',
#   'id2': 'P1365',
#   'en2': 'replaces',
#   'es2': 'reemplaza a',
#   'fr2': 'remplace',
#   'de2': 'ersetzt'},
#  {'id1': 'P1383',
#   'en1': 'contains settlement',
#   'es1': 'núcleo de población',
#   'fr1': 'contient la localité',
#   'de1': 'enthält Siedlung',
#   'id2': 'P527',
#   'en2': 'has part',
#   'es2': 'compuesto por',
#   'fr2': 'comprend',
#   'de2': 'besteht aus'},
#  {'id1': 'P169',
#   'en1': 'chief executive officer',
#   'es1': 'director ejecutivo',
#   'fr1': 'directeur général',
#   'de1': 'Geschäftsführer',
#   'id2': 'P1951',
#   'en2': 'investor',
#   'es2': 'inversionista',
#   'fr2': 'investisseur',
#   'de2': 'Investor'},
#  {'id1': 'P127',
#   'en1': 'owned by',
#   'es1': 'propietario',
#   'fr1': 'propriétaire',
#   'de1': 'Eigentümer',
#   'id2': 'P1951',
#   'en2': 'investor',
#   'es2': 'inversionista',
#   'fr2': 'investisseur',
#   'de2': 'Investor'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P1951',
#   'en2': 'investor',
#   'es2': 'inversionista',
#   'fr2': 'investisseur',
#   'de2': 'Investor'},
#  {'id1': 'P1136',
#   'en1': 'solved by',
#   'es1': 'resuelto por',
#   'fr1': 'résolu par',
#   'de1': 'Gelöst von',
#   'id2': 'P138',
#   'en2': 'named after',
#   'es2': 'nombrado por',
#   'fr2': 'nommé en référence à',
#   'de2': 'benannt nach'},
#  {'id1': 'P1441',
#   'en1': 'present in work',
#   'es1': 'presente en la obra',
#   'fr1': "présent dans l'œuvre",
#   'de1': 'kommt vor in',
#   'id2': 'P800',
#   'en2': 'notable work',
#   'es2': 'obra destacada',
#   'fr2': 'œuvre notable',
#   'de2': 'bedeutende Werke'},
#  {'id1': 'P1434',
#   'en1': 'takes place in fictional universe',
#   'es1': 'describe el universo ficticio',
#   'fr1': "décrit l'univers de fiction",
#   'de1': 'beschreibt fiktives Universum',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  {'id1': 'P4552',
#   'en1': 'mountain range',
#   'es1': 'cordillera',
#   'fr1': 'chaîne de montagnes',
#   'de1': 'Gebirgszug',
#   'id2': 'P4688',
#   'en2': 'geomorphological unit',
#   'es2': 'unidad geomorfológica',
#   'fr2': 'unité géomorphologique',
#   'de2': 'geomorphologische Einheit'},
#  {'id1': 'P112',
#   'en1': 'founded by',
#   'es1': 'fundador',
#   'fr1': 'fondateur',
#   'de1': 'Gründer',
#   'id2': 'P1889',
#   'en2': 'different from',
#   'es2': 'diferente de',
#   'fr2': 'à ne pas confondre avec',
#   'de2': 'verschieden von'},
#  ...]

# %%
len(cand)
# Out:
# 7242

# %%
candNon
# Out:
# []

# %%
# Entity Candidates to Dataframe
df = pd.DataFrame(cand)
df
# Out:
#         id1                                         en1  \
# 0      P150  contains administrative territorial entity
# 1      P361                                     part of
# 2       P47                          shares border with
# 3     P2936                               language used
# 4       P30                                   continent
# ...     ...                                         ...
# 7237    P17                                     country
# 7238    P50                                      author
# 7239   P123                                   publisher
# 7240  P5056        patronym or matronym for this person
# 7241  P8324                                      funder
#
#                                               es1  \
# 0        subdividido en (división administrativa)
# 1                                  forma parte de
# 2                          comparte fronteras con
# 3                                    idioma usado
# 4                                      continente
# ...                                           ...
# 7237                                         país
# 7238                                        autor
# 7239                                    editorial
# 7240  patronímico o matronímico para esta persona
# 7241                                  financiador
#
#                                                     fr1  \
# 0     contient les subdivisions territoriales admini...
# 1                                             partie de
# 2                                         limitrophe de
# 3                                       langue utilisée
# 4                                             continent
# ...                                                 ...
# 7237                                               pays
# 7238                                             auteur
# 7239                                            éditeur
# 7240         patronyme ou matronyme pour cette personne
# 7241                                          financeur
#
#                                         de1   id2  \
# 0     Untereinheit (administrative Einheit)  P527
# 1                              ist Teil von  P463
# 2                     gemeinsame Grenze mit  P530
# 3                          genutzte Sprache   P37
# 4                                 Kontinent  P361
# ...                                     ...   ...
# 7237                                  Staat  P669
# 7238                                  Autor  P943
# 7239                                 Verlag  P725
# 7240   Patronym oder Matronym dieser Person  P735
# 7241                                Stifter  P921
#
#                               en2                        es2  \
# 0                        has part              compuesto por
# 1                       member of                 miembro de
# 2             diplomatic relation       relación diplomática
# 3               official language             idioma oficial
# 4                         part of             forma parte de
# ...                           ...                        ...
# 7237  located on street or square        situado en la calle
# 7238                   programmer                programador
# 7239                  voice actor               actor de voz
# 7240                   given name             nombre de pila
# 7241                 main subject  tema principal de la obra
#
#                            fr2                      de2
# 0                     comprend              besteht aus
# 1                    membre de             Mitglied von
# 2        relation diplomatique  diplomatische Beziehung
# 3            langue officielle              Amtssprache
# 4                    partie de             ist Teil von
# ...                        ...                      ...
# 7237                      voie        Straße oder Platz
# 7238               programmeur            Programmierer
# 7239      comédien de doublage                 Sprecher
# 7240                    prénom                  Vorname
# 7241  sujet ou thème principal          zentrales Thema
#
# [7242 rows x 10 columns]

# %%
# Save as CSV for manual cleanup
df.to_csv('Relations/equivalence_multilingual.csv', index=False)
