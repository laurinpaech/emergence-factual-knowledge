# %% [markdown]
# We add for given properties/relations:
# - alias from wikidata
# - the google translation (unless its already part of the aliases)
# - translate every word in the relation
#
# We do this to reduce the selectional bias of property names.

# %%
from tqdm import tqdm
import pandas as pd
from wikidata.client import Client
import translators as ts
from googletrans import Translator

# %%
wikiclient = Client()
translator = Translator()

# %% [markdown]
# #### Load Properties

# %%
# relations = pd.read_csv('../data/Knowledge/properties_nonsymmetric_multilingual_clean.csv')
relations = pd.read_json('property_notsymmetric_labeled_w_aliases2.json')

# %%
relations
# Out:
#         id                       en                          de  \
# 0    P3719             regulated by               reguliert von
# 1    P1704         is pollinator of               Bestäuber von
# 2    P3173           offers view on            bietet Sicht auf
# 3    P3085      qualifies for event    qualifiziert für Turnier
# 4    P4646        representation of             Vorstellung von
# ..     ...                      ...                         ...
# 729  P5769          editor-in-chief               Chefredakteur
# 730  P8627             closing time                 Schließzeit
# 731  P2770         source of income     Herkunft des Einkommens
# 732  P4794            season starts                 Saisonstart
# 733   P926  postsynaptic connection  postsynaptische Verbindung
#
#                           es                        fr  count  \
# 0               regulado por                  régi par    461
# 1                polinizador          pollinisateur de     58
# 2             ofrece vista a         offre une vue sur    935
# 3    califica para el evento             qualifie pour   2770
# 4          representación de         représentation de    167
# ..                       ...                       ...    ...
# 729         redactor en jefe     responsable éditorial   2248
# 730           hora de cierre        heure de fermeture      5
# 731        fuente de ingreso          source de revenu    494
# 732   inicio de la temporada        début de la saison   2049
# 733   conexión postsináptica  connexion postsynaptique      7
#
#                                               en_alias  \
# 0                    [regulator, regulatory authority]
# 1                          [pollinator of, pollinates]
# 2    [has view of, has views of, offers view of, vi...
# 3                    [league this event qualifies for]
# 4                                                 None
# ..                                                 ...
# 729  [executive editor, editor in chief, lead edito...
# 730                                        [closes at]
# 731  [income source, source of revenue, revenue sou...
# 732                                    [season begins]
# 733                                               None
#
#                                            de_alias  \
# 0                                              None
# 1                                              None
# 2                             [Sicht auf, Aussicht]
# 3                                              None
# 4                                              None
# ..                                              ...
# 729                               [Chefredakteurin]
# 730  [geschlossen um, geschlossen ab, geöffnet bis]
# 731                            [Einkommensherkunft]
# 732                                  [Saisonbeginn]
# 733                                            None
#
#                                               es_alias  \
# 0                                       [regulada por]
# 1                                                 None
# 2    [tiene vista a, ofrece una vista de, ofrece vi...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 729    [editor en jefe, editor ejecutivo, editor jefe]
# 730                                         [cierra a]
# 731                                  [fuente de renta]
# 732                         [comienzo de la temporada]
# 733                                               None
#
#                                               fr_alias  \
# 0    [régie par, régulé par, régulée par, réglement...
# 1                       [pollinise, plante pollinisée]
# 2    [offre un panorama sur, vue sur, a vue sur, jo...
# 3              [ligue à laquelle l'événement qualifie]
# 4                                                 None
# ..                                                 ...
# 729  [directeur de la rédaction, directrice de la r...
# 730                              [moment de fermeture]
# 731                                               None
# 732                                               None
# 733                        [connexion post-synaptique]
#
#                                     en_translate_alias  \
# 0                                        [governed by]
# 1                          [pollinator of, pollinator]
# 2                   [offers view to, offers a view of]
# 3    [qualified for tournament, qualify for the eve...
# 4                                            [idea of]
# ..                                                 ...
# 729                  [editorial manager, chief editor]
# 730                                     [closure hour]
# 731                                 [Origin of Income]
# 732                              [start of the season]
# 733                                               None
#
#                                     de_translate_alias  \
# 0                                      [regiert durch]
# 1                       [Bestäuber, ist Bestäuber von]
# 2     [bietet Aussicht auf, bietet einen Ausblick auf]
# 3    [qualifiziert sich für die Veranstaltung, sich...
# 4                                 [Repräsentation von]
# ..                                                 ...
# 729                                 [Redaktionsleiter]
# 730                                 [Geschäftsschluss]
# 731                                 [Einkommensquelle]
# 732                [Saison beginnt, Beginn der Saison]
# 733                       [Postsynaptische Verbindung]
#
#                                es_translate_alias  \
# 0                   [regulada por, gobernado por]
# 1             [es polinizador de, polinizador de]
# 2            [ofrece ver en, ofrece una vista de]
# 3      [calificado para el torneo, califica para]
# 4                    [idea de, representacion de]
# ..                                            ...
# 729           [gerente editorial, editor en jefe]
# 730                                          None
# 731                      [Origen de los Ingresos]
# 732  [inicio de temporada, comienza la temporada]
# 733                                          None
#
#                                     fr_translate_alias
# 0                                        [régulée par]
# 1                [est pollinisateur de, pollinisateur]
# 2                                                 None
# 3    [se qualifier pour l'événement, qualifié pour ...
# 4                      [idée de, la représentation de]
# ..                                                 ...
# 729               [éditeur en chef, rédacteur en chef]
# 730                                               None
# 731                                [Origine du revenu]
# 732              [début de saison, la saison commence]
# 733                                               None
#
# [734 rows x 14 columns]

# %%
languages = ['en', 'de', 'es', 'fr']

# %% [markdown]
# #### Load aliases

# %%
alias_dict = dict()
for lang in languages:
    alias_dict[lang] = list()

for idx, relation in relations.iterrows():
    
    entity = wikiclient.get(relation['id'], load=True)
    aliases = entity.attributes['aliases']
    
    for lang in languages:
        # Does language have aliases? 
        if lang in aliases:
            alias_dict[lang].append([al['value'] for al in aliases[lang]])
        else:
            alias_dict[lang].append(None)

# %%
relations['en_alias'] = alias_dict['en']

# %%
relations
# Out:
#         id                       en                          de  \
# 0    P3719             regulated by               reguliert von
# 1    P1704         is pollinator of               Bestäuber von
# 2    P3173           offers view on            bietet Sicht auf
# 3    P3085      qualifies for event    qualifiziert für Turnier
# 4    P4646        representation of             Vorstellung von
# ..     ...                      ...                         ...
# 729  P5769          editor-in-chief               Chefredakteur
# 730  P8627             closing time                 Schließzeit
# 731  P2770         source of income     Herkunft des Einkommens
# 732  P4794            season starts                 Saisonstart
# 733   P926  postsynaptic connection  postsynaptische Verbindung
#
#                           es                        fr  count  \
# 0               regulado por                  régi par    461
# 1                polinizador          pollinisateur de     58
# 2             ofrece vista a         offre une vue sur    935
# 3    califica para el evento             qualifie pour   2770
# 4          representación de         représentation de    167
# ..                       ...                       ...    ...
# 729         redactor en jefe     responsable éditorial   2248
# 730           hora de cierre        heure de fermeture      5
# 731        fuente de ingreso          source de revenu    494
# 732   inicio de la temporada        début de la saison   2049
# 733   conexión postsináptica  connexion postsynaptique      7
#
#                                               en_alias  \
# 0                    [regulator, regulatory authority]
# 1                          [pollinator of, pollinates]
# 2    [has view of, has views of, offers view of, vi...
# 3                    [league this event qualifies for]
# 4                                                 None
# ..                                                 ...
# 729  [executive editor, editor in chief, lead edito...
# 730                                        [closes at]
# 731  [income source, source of revenue, revenue sou...
# 732                                    [season begins]
# 733                                               None
#
#                                            de_alias  \
# 0                                              None
# 1                                              None
# 2                             [Sicht auf, Aussicht]
# 3                                              None
# 4                                              None
# ..                                              ...
# 729                               [Chefredakteurin]
# 730  [geschlossen um, geschlossen ab, geöffnet bis]
# 731                            [Einkommensherkunft]
# 732                                  [Saisonbeginn]
# 733                                            None
#
#                                               es_alias  \
# 0                                       [regulada por]
# 1                                                 None
# 2    [tiene vista a, ofrece una vista de, ofrece vi...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 729    [editor en jefe, editor ejecutivo, editor jefe]
# 730                                         [cierra a]
# 731                                  [fuente de renta]
# 732                         [comienzo de la temporada]
# 733                                               None
#
#                                               fr_alias
# 0    [régie par, régulé par, régulée par, réglement...
# 1                       [pollinise, plante pollinisée]
# 2    [offre un panorama sur, vue sur, a vue sur, jo...
# 3              [ligue à laquelle l'événement qualifie]
# 4                                                 None
# ..                                                 ...
# 729  [directeur de la rédaction, directrice de la r...
# 730                              [moment de fermeture]
# 731                                               None
# 732                                               None
# 733                        [connexion post-synaptique]
#
# [734 rows x 10 columns]

# %% [markdown]
# #### Load Translations Aliases
# Translation of relation in all other languages into the target language (e.g. P3719 target 'de', translate 'en', 'es' and 'fr' to 'de' and put them into a list. Again to reduce selection bias. Manual cleanup required!

# %%
translate_dict = dict()
for lang in languages:
    translate_dict[lang] = list()

# %% [markdown]
# Unfortunately this has to be done per language

# %%
target_lang = 'fr'

# Iterate over relations
for idx, relation in tqdm(relations.iterrows(), total=relations.shape[0]):

    translations = []
    for source_lang in languages:
        if source_lang == target_lang:
            continue

        # Translate and add if not same as relation
        # try:
        #     translation = ts.google(relation[source_lang], from_language=source_lang, to_language=target_lang)
        # except:
        translation = translator.translate(relation[source_lang], src=source_lang, dest=target_lang).text

        if translation != relation[target_lang]:
            translations.append(translation)

    # Remove duplicates
    translations = list(set(translations))

    # If empty, use None instead
    if not translations:
        translations = None

    # Add translations for this language for that 
    translate_dict[target_lang].append(translations)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 734/734 [04:59<00:00,  2.45it/s]

# %%
translate_dict['es']
# Out:
# [['regulada por', 'gobernado por'],
#  ['es polinizador de', 'polinizador de'],
#  ['ofrece ver en', 'ofrece una vista de'],
#  ['calificado para el torneo', 'califica para'],
#  ['idea de', 'representacion de'],
#  ['emulado'],
#  ['principal fuente de alimento'],
#  ['contrato de constitución'],
#  ['Puerto de registro', 'distrito de registro'],
#  ['lugar de incorporacion', 'lugar de fundación'],
#  ['beneficiario'],
#  ['régimen político', 'forma basica de gobierno'],
#  None,
#  ['competición deportiva',
#   'Participación en evento deportivo.',
#   'competencia deportiva compitió en'],
#  ['derivado del tipo de organismo'],
#  None,
#  ['mundo natal'],
#  ['empuñadura de raqueta', 'jugando a la mano'],
#  ['a como una persona gramatical', 'tiene persona gramatical'],
#  None,
#  None,
#  ['ubicación de grabación', 'lugar de registro', 'lugar de grabacion'],
#  ['artista del juego', 'artista multimedia'],
#  ['color de linea', 'color del trazo'],
#  ['no causa', 'no tiene efecto'],
#  ['inversor'],
#  None,
#  ['praenomen romano', 'nombre romano', 'prenombre'],
#  ['lugar de origen'],
#  ['piedad', 'agilidad del pie'],
#  ['generalmente vende', 'normalmente vende', 'vendido en general'],
#  ['división electoral', 'distrito electoral asociado', 'distrito electoral'],
#  ['forma de tallo', 'carácter de tallo', 'carácter de estípite'],
#  ['tarea'],
#  None,
#  ['edad de inicio'],
#  None,
#  None,
#  ['invade', 'invasivo en', 'invasivo para'],
#  ['lugar de aterrizaje', 'pista de aterrizaje'],
#  None,
#  None,
#  ['proveedor técnico', 'proveedor de equipos', 'proveedor de kits'],
#  None,
#  ['aflige', 'afectado'],
#  ['superpone', 'muro', 'mintiendo'],
#  ['embarazada'],
#  ['candidato', 'fijado'],
#  ['divisa', 'cambiar'],
#  ['endémica de'],
#  ['bandera'],
#  ['maquilladora'],
#  ['sistema de cristal'],
#  ['cajero'],
#  ['unión muscular', 'inserción muscular'],
#  ['fuente', 'sistema de escritura'],
#  ['lugar de publicacion'],
#  ['orientación del hilo'],
#  ['representación de derechos de autor por'],
#  ['lugar de la muerte'],
#  ['declaración respaldada por', 'Declaración respaldada por'],
#  ['adaptado por', 'editor', 'adaptación por'],
#  None,
#  ['abierto desde el tiempo',
#   'periodo abierto desde',
#   'comienzo del periodo de apertura'],
#  ['misión de astronautas', 'Misión espacial'],
#  ['publicación de la casa'],
#  None,
#  ['meta perseguida',
#   'objetivo del proyecto o acción',
#   'objetivo del proyecto o misión'],
#  None,
#  ['en la pole position al comienzo'],
#  ['Servicio en línea'],
#  ['estudio o trabajo preparatorio para', 'estudiar o diseñar para'],
#  ['subgerente'],
#  None,
#  None,
#  ['utiliza una melodía', 'tiene melodía', 'contiene una melodía de'],
#  ['miembro de la tripulación de', 'Miembro de la tripulación de'],
#  ['Restricción de acceso',
#   'estado de restricción de acceso',
#   'Condiciones de acceso'],
#  ['especies mantenidas', 'especies conservadas'],
#  ['contenido ilustrativo'],
#  ['disponibilidad en línea',
#   'tipo de accesibilidad',
#   'estado de acceso en línea'],
#  ['tipo'],
#  ['sector de actividad'],
#  ['es una forma de hidrato de', 'forma hidratada de'],
#  ['estandarizado por'],
#  ['proyecto descrito utilizado', 'describe un proyecto que utiliza'],
#  ['difusor original', 'Locutor de la primera emisión', 'locutor original'],
#  ['se aplica a las personas'],
#  ['Información turística', 'oficina de Turismo', 'centro de Visitantes'],
#  ['papel narratológico', 'rol narrativo'],
#  ['Interacción'],
#  ['forma de trabajo creativo', 'forma artistica', 'forma de trabajo'],
#  ['escribió para', 'ha escrito para'],
#  ['Color de cabello', 'Color de pelo'],
#  ['área protegida', 'ubicado en área protegida', 'está en un área protegida'],
#  ['ubicación', 'estudio de grabación', 'grabado en estudio o lugar'],
#  ['para el trabajo', 'recompensa por'],
#  None,
#  ['enfermedad'],
#  ['artería', 'afluencia arterial', 'suministro arterial'],
#  None,
#  ['etapa superior del cohete'],
#  ['está en la unidad estadística',
#   'ubicado en la entidad territorial estadística'],
#  ['tiene lugar en un universo ficticio'],
#  ['parroquia'],
#  ['formato de registro'],
#  ['equipos participantes'],
#  ['sistema de potencia de tracción'],
#  ['divisa'],
#  None,
#  ['certificado de producto', 'certificación de producto'],
#  ['formato de pelicula original',
#   'formato de película',
#   'formato de película original'],
#  ['revelado por'],
#  ['causa de la muerte'],
#  ['Invitado de honor'],
#  ['Patrono de', 'dominio de santo o deidad'],
#  ['cerrado el/el', 'días de cierre', 'cerrado el'],
#  ['daños y perjuicios', 'estropeado'],
#  ['demonio a', 'demonio de', 'mas o menos'],
#  ['dramaturgo (producción)'],
#  None,
#  None,
#  ['Expansión de', 'extensión de'],
#  ['capacidad de despegue y aterrizaje'],
#  ['brazo del estuario', 'afluente', 'distribuidor'],
#  ['fracturando', 'descanso'],
#  ['calificación relevante'],
#  ['forma de sombrero de hongo', 'forma de sombrero'],
#  None,
#  ['tarjeta de red', 'red de tarjetas de crédito'],
#  ['Jefe de Estado'],
#  ['elegido en', 'elección'],
#  ['paciente índice de', 'paciente cero de'],
#  ['grupo único', 'grupo de puntos'],
#  ['origen mecanico de la energia', 'energizado por'],
#  ['Ideología política', 'cosmovisión política'],
#  ['nivel de grado más alto', 'nivel escolar más alto'],
#  None,
#  ['protocolo de acceso'],
#  ['mayor expresión en'],
#  ['color de la flor'],
#  ['título (en ajedrez)',
#   'título de persona de ajedrez',
#   'título del juego de ajedrez'],
#  ['Demografía del objeto', 'datos demográficos del tema', 'tema demográfico'],
#  None,
#  ['calcula la solución a'],
#  ['día de publicación', 'Fecha de publicación'],
#  ['derogado por', 'cancelado por'],
#  ['altavoz'],
#  ['fracción'],
#  None,
#  ['producto o material elaborado'],
#  ['autor de la mejor vuelta'],
#  ['destinatario elegible', 'beneficiario elegible', 'calificado para recibir'],
#  ['período', 'periodo de tiempo'],
#  ['candidatura en las elecciones',
#   'candidato para',
#   'candidato a las elecciones'],
#  None,
#  ['gestión de paquetes', 'gerente de empaquetación'],
#  ['caligrafia'],
#  ['lenguajes hablados, escritos o de señas',
#   'idiomas hablados o publicados',
#   'idiomas hablados, escritos o firmados'],
#  None,
#  ['Oficial', 'titular de la Oficina', 'titular'],
#  ['DISTRIBUIDO por', 'distribuidores'],
#  None,
#  ['rotulista'],
#  ['rol de personaje', 'papel'],
#  ['color de impresión de esporas',
#   'impresión de polvo de esporas',
#   'color de la espora'],
#  ['ubicación narrativa', 'lugar de acción', 'escena de acción'],
#  ['coalición'],
#  ['carga',
#   'mercancías o pasajeros transportados',
#   'personas o carga transportada'],
#  ['tiene tiempo', 'a como tiempo gramatical', 'tiene tiempo gramatical'],
#  ['idioma original de la película o programa de televisión',
#   'idioma original'],
#  ['tiene un fenotipo', 'tiene fenotipo'],
#  ['clasificación de combinación',
#   'puntaje combinado',
#   'mejor ranking combinado'],
#  ['tiene ingrediente listado', 'componente listado'],
#  ['Evaluación de'],
#  ['patrocinador', 'cliente', 'encargado por'],
#  None,
#  None,
#  ['Miembro del equipo de filmación'],
#  ['remezclado por', 'remezcla de'],
#  ['tipo de nomenclatura'],
#  ['contiene fonema', 'tiene fonema'],
#  ['la plantilla tiene tema',
#   'Tema principal de la plantilla.',
#   'tema principal de un modelo'],
#  ['Excluyendo', 'eximir', 'no tomado en cuenta'],
#  ['tipo de vista', 'formato mostrado'],
#  ['tipo de fundición'],
#  ['la regulación alterada conduce a',
#   'el cambio de regulación conduce a',
#   'consecuencia de una alteración de la regulación'],
#  ['especialidad de salud', 'especialidad médica'],
#  None,
#  None,
#  None,
#  ['nota de un perfume', 'nota de perfume', 'nota de fragancia'],
#  ['disminución de la expresión en'],
#  ['dirección relativa a la ubicación', 'direccion de ubicacion'],
#  ['desafiado por',
#   'afirmación cuestionada por',
#   'Declaración cuestionada por'],
#  ['punto final geográfico', 'punto de destino', 'destino de la ruta'],
#  ['tiene figura de vértice', 'Superficie siguiente al despuntar'],
#  ['Distrito escolar'],
#  None,
#  ['Sistema de gestión de derechos digitales',
#   'sistema de medidas técnicas de protección'],
#  ['cátedra'],
#  ['deformación', 'culpa'],
#  None,
#  ['geografía del tema'],
#  ['obras significativas', 'trabajo notable'],
#  ['seguidores de'],
#  ['Reservorio de patógenos de'],
#  ['período afectado', 'período aplicable', 'válido en el período'],
#  None,
#  None,
#  ['País de ciudadanía'],
#  ['tiene caso índice', 'paciente cero', 'tiene paciente índice'],
#  ['proveedor de servicio'],
#  ['autor del prólogo'],
#  ['clasificación'],
#  None,
#  ['causa de terminación', 'patrón final', 'causa final'],
#  None,
#  ['tiene reservorio de patógenos'],
#  ['miembro de la Junta', 'miembro del consejo de vigilancia'],
#  None,
#  ['cofactor de'],
#  ['fase de estudio'],
#  ['era'],
#  ['adornar', 'complemento a'],
#  None,
#  ['Sistema de combustible',
#   'tipo de suministro de combustible',
#   'suministro de combustible'],
#  ['Categoría para los empleados de la organización',
#   'categoría para los empleados de la organización'],
#  ['escaladores'],
#  ['lago en el arroyo', 'lagos en el rio', 'lago en progreso'],
#  ['inaugurado oficialmente por'],
#  ['prohibido'],
#  ['participante debut', 'primera participación'],
#  ['responder a', 'Respuesta para'],
#  None,
#  None,
#  ['Configuración del tren de válvulas',
#   'tren de válvulas',
#   'configuración del tren de válvulas'],
#  ['puntos/gol anotado por',
#   'Punto/Golpe anotado por',
#   'punto/gol anotado por'],
#  ['Distrito electoral', 'distrito electoral'],
#  None,
#  ['proceso de transmisión de patógenos'],
#  None,
#  None,
#  None,
#  ['Clasificación de equipos por puntos'],
#  ['final de temporada', 'fin de temporada', 'termina la temporada'],
#  ['admite lenguaje de programación', 'lenguaje de programación compatible'],
#  ['padre', 'padre (sin especificar)'],
#  ['ruido generado', 'sonido emitido'],
#  ['permite pasar', 'transferido', 'lleva'],
#  None,
#  ['Autor del epílogo'],
#  ['Gobierno'],
#  None,
#  ['del universo ficticio', 'del universo narrativo'],
#  ['representado por'],
#  ['Moverse'],
#  ['sistema de impulso', 'sobrealimentador', 'compresor'],
#  None,
#  None,
#  ['exámenes médicos', 'posibles exámenes'],
#  ['forma de vida del hongo',
#   'hongo tipo ecologico',
#   'tipo de hongo ecologico'],
#  ['lugar de detención'],
#  ['conexión'],
#  ['incluso', 'tener en cuenta'],
#  ['ranking de los mejores velocistas',
#   'puntuación de sprint',
#   'mejor clasificación de velocista'],
#  ['Dependiendo de', 'depender de'],
#  None,
#  ['compania de produccion'],
#  ['forma geometrica'],
#  ['ha sido retirado de', 'es retraído por', 'retiro'],
#  ['disciplina deportiva en la que se compite',
#   'disciplina deportiva practicada en competición'],
#  ['elemento de adorno', 'lleva', 'viste'],
#  ['con un permiso de residencia permanente'],
#  ['anular', 'anula'],
#  ['enseñanza', 'institución educativa a la que asistió'],
#  ['ubicación del descubrimiento', 'localidad'],
#  ['se desarrolla a partir de', 'evoluciona'],
#  None,
#  None,
#  ['miembro de la demostración'],
#  ['término parlamentario'],
#  ['oficial corporativo', 'oficial ejecutivo', 'Personal superior'],
#  None,
#  ['designado para este cargo por', 'sugerido por, propuesto por'],
#  None,
#  None,
#  ['campo de actividad de la profesión',
#   'área de ocupación',
#   'campo de esta ocupación'],
#  None,
#  ['director de operaciones'],
#  ['es venerado por', 'deidad de', 'adorado por'],
#  ['club de padres'],
#  ['Lista de personajes'],
#  ['salida venosa'],
#  ['usado para tratar', 'enfermedad tratada'],
#  ['manera de moverse', 'medios de locomoción'],
#  ['dispersion de semillas'],
#  ['censo de población realizado', 'tiene censo'],
#  ['facha', 'compartimento vocal'],
#  ['granularidad'],
#  ['monto objetivo', 'conjunto de llegada'],
#  ['Catalogar', 'catalogar'],
#  ['designado como terrorista por', 'clasificado como terrorista por'],
#  ['codificado', 'sintetiza'],
#  ['puntuación más baja'],
#  ['progresión de acordes'],
#  None,
#  ['última parada', 'hacia'],
#  ['afluencia', 'comida', 'entradas'],
#  None,
#  ['encontrado en el taxón'],
#  None,
#  None,
#  ['zona de captación', 'Cuenca de drenaje', 'Cuenca'],
#  ['Genial'],
#  ['rito catolico', 'rito litúrgico cristiano'],
#  ['anterior cruce aguas arriba'],
#  ['con', 'Juntos con'],
#  ['probado o demostrado por'],
#  ['métrica utilizada', 'medidor usado', 'metro'],
#  ['objeto de disciplina', 'educado', 'estudios'],
#  ['director académico',
#   'importante en la universidad',
#   'principal especialidad de estudio'],
#  ['vice-condado', 'vice condado'],
#  ['icono de'],
#  ['escalas de puertos'],
#  ['primera impresión'],
#  ['listado de bienes patrimoniales', 'Lista de monumentos'],
#  ['programa de recompensas', 'programa de bonificación'],
#  ['sitio del descubrimiento astronómico',
#   'sitio de descubrimiento astronómico',
#   'lugar del descubrimiento astronómico'],
#  None,
#  ['orbita'],
#  ['operador de cámara', 'Director de fotografía'],
#  ['electores'],
#  ['enclave de'],
#  ['conjunto de imágenes', 'imagen de una aplicación', 'imagen de funcion'],
#  None,
#  ['Pasado por', 'legislador'],
#  ['ubicado en la característica lineal',
#   'está a lo largo',
#   'ubicado a lo largo'],
#  ['lanzacohetes'],
#  ['diseñado para llevar', 'transportado'],
#  ['nivel de liga por debajo'],
#  ['Conexión de voz para',
#   'encuadernación de biblioteca',
#   'enlace de la biblioteca de software'],
#  ['tipos de pago aceptados', 'método de pago aceptado'],
#  ['Etiqueta de registro'],
#  ['politopo facetado', 'tiene politopo facetado'],
#  ['tipo de afirmación', 'tipo de declaración'],
#  None,
#  ['autor de portada o manga',
#   'arte de portada por',
#   'diseñador de la portada'],
#  ['categoría para los miembros de este equipo',
#   'categoría para los miembros de un equipo',
#   'Categoría para socios del club'],
#  ['espesor de este conjunto'],
#  ['tipo de caracter', 'carácter típico'],
#  ['motivo de destrucción'],
#  ['plenipotenciario'],
#  ['tipo de señal transmitida'],
#  ['representación diplomática'],
#  ['carrera de animales', 'raza de animales'],
#  ['cargo que ocupa el jefe ejecutivo', 'oficina suprema del gobierno'],
#  ['sistema coordinado', 'sistema de referencia de coordenadas'],
#  ['marco'],
#  ['tesis universitaria'],
#  ['Estado de restricción de uso',
#   'restricciones de uso',
#   'estado de restricción de uso'],
#  ['diploma o distinción otorgada', 'otorga títulos académicos', 'subsidios'],
#  ['candidato a vicepresidente', 'co-candidato', 'compañero de fórmula'],
#  ['politica de actividad en este lugar',
#   'código de conducta para el sitio',
#   'política regulatoria local'],
#  ['empezando desde', 'actos de', 'son procedimientos de'],
#  ['tiene un modo gramatical'],
#  ['configuración de la cámara de cine',
#   'configuración de la cámara',
#   'posición de la cámara'],
#  None,
#  ['tipo de señal recibida', 'señal recogida'],
#  ['pasajero'],
#  ['Tipo espectral del asteroide'],
#  ['lista de títulos'],
#  ['candidato exitoso'],
#  ['icono oficial'],
#  None,
#  ['donante'],
#  None,
#  ['activador'],
#  ['director coral'],
#  ['ubicación del observador',
#   'posición de punto de vista',
#   'ubicación del punto de vista'],
#  ['colegio', 'Escuela de'],
#  ['Color de ojos', 'color de los ojos'],
#  ['lugares principales', 'principales localidades atendidas'],
#  ['estado de los derechos de autor'],
#  ['menciones de inscripción',
#   'inscripción mencionada',
#   'declaración sobre el registro'],
#  ['vehículo', 'embarcación'],
#  ['guión', 'texto'],
#  ['entregado por'],
#  ['Fiesta', 'Día Conmemorativo', 'día festivo'],
#  ['historia de la exposición', 'exhibiciones', 'exposición'],
#  None,
#  ['lugar de listado', 'bolsa'],
#  ['necesario', 'mandatos', 'demanda'],
#  ['letras de canciones', 'tiene letras', 'letras de'],
#  ['Temperatura de funcionamiento', 'temperatura de servicio'],
#  ['rango', 'terreno de juego', 'tipo de voz'],
#  ['clase de barco', 'tipo de barco', 'clase de embarcación'],
#  ['gerente general'],
#  ['categoría de miembro', 'categoría para miembros'],
#  ['se aplica a la jurisdicción',
#   'jurisdicción territorial',
#   'pertenece al área de responsabilidad'],
#  ['nivel de liga por encima'],
#  ['idioma de escritura',
#   'Lengua escrita',
#   'idiomas de escritura (solo para autores publicados)'],
#  None,
#  ['diseño del motor', 'arquitectura del motor'],
#  ['escote'],
#  ['manera de', 'en el estilo de'],
#  ['copia de'],
#  ['orientación política', 'alineación política'],
#  ['año modelo'],
#  None,
#  None,
#  ['cliente'],
#  ['admisible en', 'regla válida en'],
#  None,
#  ['origen de la materia', 'fuente de material'],
#  ['Comunidad Religiosa'],
#  ['área operativa', 'área de cobertura', 'área de operaciones'],
#  None,
#  ['método de entrada'],
#  None,
#  ['aniversario', 'día en el año para la ocurrencia periódica', 'día del año'],
#  None,
#  ['oficina impugnada', 'oficina para la elección', 'posición en el juego'],
#  ['medio de refrigeración'],
#  None,
#  ['taller'],
#  ['juramento hecho por'],
#  ['puerto base'],
#  ['título honorífico', 'saludo honorable'],
#  None,
#  ['republicación'],
#  ['serie'],
#  ['modo de transmisión', 'herencia'],
#  ['citas de trabajo', 'citar el trabajo', 'obra citada textualmente'],
#  ['contratista general',
#   'contratista principal de la construcción',
#   'maestro de obra'],
#  ['lealtad a', 'deber de lealtad'],
#  None,
#  ['lugar de la primera actuación', 'Lugar de estreno o primera emisión'],
#  None,
#  ['alianza de aerolíneas', 'alianza de aviación'],
#  ['titulo academico', 'Titulo academico', 'diploma Universitario'],
#  None,
#  ['autor de la mejor obra', 'Primero en una estadística'],
#  None,
#  ['acreditado por'],
#  ['Primer nombre', 'primer nombre'],
#  ['supervisor'],
#  ['ciudad de licencia',
#   'con licencia para transmitir a',
#   'licencia de radiodifusión en'],
#  ['objeto para ese sentido', 'artículo para este sentido'],
#  ['cumple', 'cumple con'],
#  ['alegato de defensa', 'Abogacía', 'petición'],
#  None,
#  None,
#  ['sistema de explotación', 'Sistema operativo'],
#  ['se desmorona a', 'decae a', 'se desintegra espontáneamente en'],
#  ['ubicación del gráfico', 'registrado en'],
#  ['contiene liquidación', 'contiene la localidad'],
#  None,
#  ['sexo o genero', 'género'],
#  None,
#  ['soportar', 'apoya equipo deportivo'],
#  ['Condición de uso'],
#  ['válido en su lugar', 'válido en/en', 'se aplica al lugar'],
#  ['impacto en el medio ambiente', 'Problema ambiental'],
#  None,
#  None,
#  ['examinado por'],
#  ['tiene patrón decorativo', 'tiene patrón'],
#  ['tiene instalaciones', 'equipo'],
#  ['final'],
#  None,
#  ['tipo de primera'],
#  ['servicio de transporte', 'linaje'],
#  ['autor'],
#  ['seccion joven', 'ala juvenil'],
#  ['organización de defensa', 'Tesis presentada a', 'tesis presentada a'],
#  ['Super poder',
#   'característica o habilidad sobrehumana',
#   'cualidad o habilidad sobrehumana'],
#  ['grupo objetivo', 'Público objetivo'],
#  ['paso', 'ritmo'],
#  None,
#  ['Director', 'director o directora'],
#  ['supervisado por', 'supervisando'],
#  None,
#  ['establecido en el período', 'tiempo de acción'],
#  ['medidas de primeros auxilios', 'Medidas de primeros auxilios'],
#  None,
#  None,
#  ['productor de archivo',
#   'creador de la colección',
#   'Fundador de la colección'],
#  ['equipo o tripulación de respaldo o reserva',
#   'equipo de respaldo',
#   'equipo o tripulación de reserva'],
#  ['accesibilidad para sillas de ruedas'],
#  ['multa', 'convicción'],
#  None,
#  ['posible observación médica', 'posibles hallazgos médicos'],
#  None,
#  ['indígena a', 'indígena'],
#  ['tipología del lenguaje'],
#  ['Director artistico', 'director artistico'],
#  ['otorgado por', 'Conferido por'],
#  ['identificador de acciones'],
#  ['sistema de control de trenes'],
#  None,
#  ['basado en una obra de', 'después de un trabajo de'],
#  ['edición'],
#  ['organización de trabajadores afiliados',
#   'sindicato en el lugar de trabajo'],
#  ['mantenimiento'],
#  ['signos que acompañan al lenguaje hablado', 'formulario firmado'],
#  ['desarrollador de bienes raíces'],
#  ['principal texto normativo', 'base legal'],
#  None,
#  ['efecto magnético', 'pedido magnético', 'orden magnético'],
#  None,
#  None,
#  ['variable de búsqueda'],
#  None,
#  None,
#  ['economía del tema'],
#  None,
#  ['Comité Legislativo'],
#  ['dada por'],
#  ['metaclase para', 'es metaclase para'],
#  ['derivado de', 'inferirse de'],
#  ['puntuación de revisión por'],
#  None,
#  ['aparece en la lista de monumentos clasificados',
#   'aparece en la lista de monumentos patrimoniales',
#   'está en la lista de monumentos culturales'],
#  ['Cultura'],
#  ['tiene causa inmediata', 'tiene la causa inmediata'],
#  ['organismo regulador de la lengua',
#   'institución de normas',
#   'controlando el cuerpo del lenguaje'],
#  ['archivado por', 'archivos en'],
#  ['camiseta distintiva', 'camiseta de clasificación'],
#  ['tipo de movimiento muscular'],
#  ['recepción y tratamiento de emergencias', 'instalaciones de emergencia'],
#  None,
#  ['configuración del ala', 'arreglo de alas'],
#  ['es el frente', 'está frente a', 'es anverso de'],
#  ['campo de definición', 'conjunto de definiciones', 'dominio de definición'],
#  None,
#  ['electorado', 'derecho a votar'],
#  ['origen muscular', 'origen del musculo'],
#  ['titulo de nobleza'],
#  ['Resuelto por'],
#  ['cantidad de entrada', 'conjunto de inicio'],
#  ['red de carreteras'],
#  ['conduciendo a'],
#  ['capturado con', 'grabado con'],
#  ['recuperado de'],
#  ['orden de caballeros'],
#  ['equipo científico llevado',
#   'instrumentos a bordo',
#   'lleva instrumento científico'],
#  ['plato tradicional', 'alimentos asociados tradicionalmente'],
#  ['formato de distribución', 'Tipo de material/canal de distribución'],
#  ['tipo de sangre'],
#  ['deroga', 'recoger'],
#  ['ubicación de la investigación', 'sitio web de investigación'],
#  None,
#  ['dirección de escritura', 'direccionalidad del guión'],
#  None,
#  ['observatorio vulcanologico', 'observatorio de volcanes'],
#  ['presentado', 'listado en'],
#  ['dirección del tren', 'orden de conducción', 'lado del tráfico ferroviario'],
#  ['hecho para'],
#  ['Materia menor en el curso.', 'menor académico', 'segundo mayor'],
#  None,
#  ['clasificación de montaña', 'clasificación de montañas'],
#  ['sin salida al mar', 'enclave dentro'],
#  ['campo de entrenamiento',
#   'campo de estudio profesional',
#   'materia de formacion profesional'],
#  ['rango de taxones', 'rango', 'área de distribución'],
#  ['tiene para evaluación'],
#  ['montar'],
#  ['Signatura de compás'],
#  ['tiene mascota'],
#  ['nombrado por'],
#  ['dirección como afluente',
#   'orilla de la confluencia',
#   'orientación tributaria'],
#  ['destruir', 'destruido'],
#  ['demandado', 'acusado'],
#  ['desde'],
#  ['es polinizado por', 'polinizado por'],
#  ['plan de financiación', 'olla de subsidio'],
#  ['ingrediente activo en', 'es el ingrediente activo en'],
#  None,
#  ['tiene tipo de fruta', 'tipo de fruta'],
#  None,
#  ['prima'],
#  ['Número de Teléfono de Emergencia', 'número de emergencia'],
#  ['depósito de tren', 'depósito ferroviario'],
#  None,
#  ['música hecha para'],
#  ['época afectada', 'período cubierto'],
#  ['es la espalda', 'está detrás de'],
#  ['rango'],
#  ['delta del río de'],
#  ['tipo de lente óptica'],
#  ['Llama encendida por', 'llama encendida por'],
#  ['mecánica del juego'],
#  ['altavoz', 'doblador', 'actor de doblaje'],
#  ['motivo literario', 'motivo narrativo', 'patrón narrativo'],
#  ['solicitante'],
#  None,
#  ['cuerpo astronómico superior',
#   'orbitar alrededor',
#   'cuerpo astronómico padre'],
#  None,
#  ['presentado por', 'es retratado por'],
#  ['los miembros tienen la profesión',
#   'ocupación de miembros',
#   'los miembros tienen ocupación'],
#  None,
#  ['radio de', 'circulo de'],
#  ['Alcance de la propiedad', 'campo de aplicación'],
#  ['Servicio', 'armado'],
#  ['indicador'],
#  ['firmante'],
#  ['lugar de la boda'],
#  None,
#  ['grado de integridad', 'integridad esperada'],
#  ['estructura piramidal de la liga'],
#  ['base', 'base (aritmética)', 'número básico'],
#  ['rango militar'],
#  ['Peligro', 'peligro asociado', 'peligro en el sitio'],
#  ['curador', 'curador o curador'],
#  ['puerto de atraque', 'objetivo de acoplamiento'],
#  ['Método de detección'],
#  None,
#  ['auditor de cuentas'],
#  ['Tipo de estudio'],
#  ['tiene como caso gramatical', 'tiene caso gramatical'],
#  ['universo ficticio se describe en', 'universo ficticio representado en'],
#  ['disciplina de mecanografía', 'mecanografía', 'sistema de escritura'],
#  ['este taxón produce', 'este taxón es fuente de', 'origen de'],
#  None,
#  ['vehiculo normalmente usado', 'vehículo habitualmente utilizado'],
#  ['sospecha la presencia de'],
#  ['tono', 'llave'],
#  None,
#  None,
#  ['refleja los datos de', 'espejo de datos de', 'refleja datos de'],
#  ['tipo de elemento contenido en la categoría'],
#  ['Adición', 'superficie en la que se juega'],
#  ['en cuerpo astronómico', 'ubicado en el cuerpo astronómico'],
#  None,
#  ['capitán del equipo'],
#  ['fecha de nacimiento'],
#  ['categoría de embarazo'],
#  None,
#  ['no causado por', 'no tiene razon', 'no tiene causa'],
#  ['esfera de actividad', 'área de trabajo'],
#  ['punto más profundo'],
#  ['categoría para los destinatarios de este premio',
#   'categoría para los ganadores de este premio',
#   'Categoría para ganadores de premios'],
#  ['confirmado en'],
#  ['posible tratamiento', 'tratamientos médicos', 'posibles tratamientos'],
#  ['portador de la bandera'],
#  ['cargar'],
#  ['día laborable'],
#  ['manera de morir'],
#  None,
#  None,
#  ['arquitecto paisajista'],
#  ['no presente en', 'no probado en'],
#  ['partido político', 'Fiesta de afiliación', 'miembro del partido politico'],
#  ['escala de medición', 'medido con'],
#  ['causa directa de'],
#  ['tiene un factor contribuyente', 'tiene como factor contribuyente'],
#  ['liberarse de', 'liberación de', 'lanzamiento musical de'],
#  ['orquestación'],
#  ['informe del', 'repaso de', 'revisado por'],
#  ['área de negocios', 'división de negocios', 'división'],
#  ['manera', 'calle o plaza', 'ubicado en calle o plaza'],
#  ['patrocinio a través', 'Apoyado por', 'respaldado por'],
#  None,
#  ['Órgano Judicial Supremo', 'Corte Suprema'],
#  ['base (geometría)', 'Espacio de piso', 'base'],
#  ['ambientado en el entorno',
#   'tiene lugar en el medio ambiente',
#   'entorno de la acción'],
#  ['lugar de adoración', 'lugar de culto'],
#  ['contiene el ingrediente activo', 'tiene ingrediente activo'],
#  ['monasterio madre', 'cuartel general'],
#  ['nombrado por'],
#  ['titular de derechos de autor'],
#  ['permitir', 'permitido', 'permisos'],
#  ['tripulación', 'miembro de la tripulación', 'miembros de la tripulación)'],
#  None,
#  None,
#  ['cargo ocupado por el jefe de la organización',
#   'posición al frente de la organización',
#   'Oficina del Jefe'],
#  ['Tuve como última comida'],
#  ['grupo de población', 'grupo étnico'],
#  ['impresora'],
#  ['condición previa', 'requisito previo'],
#  ['plato', 'Corte'],
#  ['método de salida'],
#  ['mano', 'lateralización'],
#  ['hábito de cristal'],
#  ['unidad', 'Miembro de la unidad militar'],
#  ['evacuación médica después',
#   'sitio de evacuación de heridos',
#   'evacuación médica a'],
#  ['expresión, gesto o pose corporal', 'postura o movimiento'],
#  ['tiene género gramatical'],
#  ['sistema de dirección'],
#  None,
#  ['Revisado por', 'examinado por'],
#  ['Día feriado', 'fiesta'],
#  ['el sujeto tiene un rol', 'juega el papel de', 'El sujeto actúa como'],
#  ['cocina servida'],
#  ['cuerpo legislativo', 'asamblea deliberativa'],
#  ['subyace', 'techo', 'colgante'],
#  ['rango de taxón', 'rango taxonómico'],
#  ['nivel de protección biológica'],
#  ['período de cierre'],
#  None,
#  ['padrino o madrina'],
#  None,
#  ['anfitrión'],
#  ['examen o competencia tomada', 'Examen pasado', 'evaluación'],
#  ['fórmula que describe'],
#  ['probado en', 'declarado en'],
#  ['periodicidad de los informes', 'periodicidad de las lecturas'],
#  ['premiado con trofeo', 'trofeo otorgado'],
#  ['determinado por la heurística', 'basado en heurística'],
#  ['bombardeo'],
#  None,
#  ['promueve', 'anuncia', 'se aplica'],
#  ['cartucho'],
#  ['esfuerzo de guerra', 'conflicto'],
#  None,
#  ['Ordenado por'],
#  ['Publicado en'],
#  ['generada a partir de',
#   'producido por el taxón',
#   'producto natural del taxon'],
#  ['lugar de acción', 'ubicación de trabajo'],
#  ['el punto más alto', 'punto mas alto', 'punto culminante'],
#  ['ejecutivo', 'cuerpo ejecutivo'],
#  ['reconocido por'],
#  ['modo de radiación radiactiva',
#   'modo de descomposición',
#   'tipo de descomposición'],
#  ['el objeto tiene un rol', 'El objeto actúa como', 'rol de objeto'],
#  ['la medida', 'medidas'],
#  ['posible creador'],
#  None,
#  None,
#  ['exentos de', 'absuelto por'],
#  ['gerente editorial', 'editor en jefe'],
#  None,
#  ['Origen de los Ingresos'],
#  ['inicio de temporada', 'comienza la temporada'],
#  None]

# %%
relations['fr_translate_alias'] = translate_dict['fr']

# %% [markdown]
# #### Load subword translations
#
# For every relation we take every possible target_language that we want to know if it is being shared into. We iterate over all words of the relation in all other languages and translate them into the target language and save them as subword aliases. My reasoning is that mBERT might sometimes just ignore certain words in a relation and understand them not as a whole in its context but just makse connects with some words.

# %%
subword_dict = dict()
for lang in languages:
    subword_dict[lang] = list()

# %%
# Iterate over relations
for idx, relation in tqdm(relations.iterrows(), total=relations.shape[0]):
    
    # For every language
    for target_lang in languages:
        
        translations = []
        for source_lang in languages:
            if source_lang == target_lang:
                continue
            
            words = relation[source_lang].split()
            
            if len(words) == 1:
                continue
            
            for word in words:
                # Translate
                translation = translator.translate(word, src=source_lang, dest=target_lang).text
                translations.append(translation)

        # Remove duplicates
        translations = list(set(translations))

        # If empty, use None instead
        if not translations:
            translations = None

        # Add translations for this language for that 
        subword_dict[target_lang].append(translations)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 734/734 [25:01<00:00,  2.05s/it]

# %%
relations['fr_subword_alias'] = subword_dict['fr']

# %% [markdown]
# #### Save

# %%
relations
# Out:
#         id                       en                          de  \
# 0    P3719             regulated by               reguliert von
# 1    P1704         is pollinator of               Bestäuber von
# 2    P3173           offers view on            bietet Sicht auf
# 3    P3085      qualifies for event    qualifiziert für Turnier
# 4    P4646        representation of             Vorstellung von
# ..     ...                      ...                         ...
# 729  P5769          editor-in-chief               Chefredakteur
# 730  P8627             closing time                 Schließzeit
# 731  P2770         source of income     Herkunft des Einkommens
# 732  P4794            season starts                 Saisonstart
# 733   P926  postsynaptic connection  postsynaptische Verbindung
#
#                           es                        fr  count  \
# 0               regulado por                  régi par    461
# 1                polinizador          pollinisateur de     58
# 2             ofrece vista a         offre une vue sur    935
# 3    califica para el evento             qualifie pour   2770
# 4          representación de         représentation de    167
# ..                       ...                       ...    ...
# 729         redactor en jefe     responsable éditorial   2248
# 730           hora de cierre        heure de fermeture      5
# 731        fuente de ingreso          source de revenu    494
# 732   inicio de la temporada        début de la saison   2049
# 733   conexión postsináptica  connexion postsynaptique      7
#
#                                               en_alias  \
# 0                    [regulator, regulatory authority]
# 1                          [pollinator of, pollinates]
# 2    [has view of, has views of, offers view of, vi...
# 3                    [league this event qualifies for]
# 4                                                 None
# ..                                                 ...
# 729  [executive editor, editor in chief, lead edito...
# 730                                        [closes at]
# 731  [income source, source of revenue, revenue sou...
# 732                                    [season begins]
# 733                                               None
#
#                                            de_alias  \
# 0                                              None
# 1                                              None
# 2                             [Sicht auf, Aussicht]
# 3                                              None
# 4                                              None
# ..                                              ...
# 729                               [Chefredakteurin]
# 730  [geschlossen um, geschlossen ab, geöffnet bis]
# 731                            [Einkommensherkunft]
# 732                                  [Saisonbeginn]
# 733                                            None
#
#                                               es_alias  \
# 0                                       [regulada por]
# 1                                                 None
# 2    [tiene vista a, ofrece una vista de, ofrece vi...
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 729    [editor en jefe, editor ejecutivo, editor jefe]
# 730                                         [cierra a]
# 731                                  [fuente de renta]
# 732                         [comienzo de la temporada]
# 733                                               None
#
#                                               fr_alias  \
# 0    [régie par, régulé par, régulée par, réglement...
# 1                       [pollinise, plante pollinisée]
# 2    [offre un panorama sur, vue sur, a vue sur, jo...
# 3              [ligue à laquelle l'événement qualifie]
# 4                                                 None
# ..                                                 ...
# 729  [directeur de la rédaction, directrice de la r...
# 730                              [moment de fermeture]
# 731                                               None
# 732                                               None
# 733                        [connexion post-synaptique]
#
#                                     en_translate_alias  \
# 0                                        [governed by]
# 1                          [pollinator of, pollinator]
# 2                   [offers view to, offers a view of]
# 3    [qualified for tournament, qualify for the eve...
# 4                                            [idea of]
# ..                                                 ...
# 729                  [editorial manager, chief editor]
# 730                                     [closure hour]
# 731                                 [Origin of Income]
# 732                              [start of the season]
# 733                                               None
#
#                                     de_translate_alias  \
# 0                                      [regiert durch]
# 1                       [Bestäuber, ist Bestäuber von]
# 2     [bietet Aussicht auf, bietet einen Ausblick auf]
# 3    [qualifiziert sich für die Veranstaltung, sich...
# 4                                 [Repräsentation von]
# ..                                                 ...
# 729                                 [Redaktionsleiter]
# 730                                 [Geschäftsschluss]
# 731                                 [Einkommensquelle]
# 732                [Saison beginnt, Beginn der Saison]
# 733                       [Postsynaptische Verbindung]
#
#                                es_translate_alias  \
# 0                   [regulada por, gobernado por]
# 1             [es polinizador de, polinizador de]
# 2            [ofrece ver en, ofrece una vista de]
# 3      [calificado para el torneo, califica para]
# 4                    [idea de, representacion de]
# ..                                            ...
# 729           [gerente editorial, editor en jefe]
# 730                                          None
# 731                      [Origen de los Ingresos]
# 732  [inicio de temporada, comienza la temporada]
# 733                                          None
#
#                                     fr_translate_alias  \
# 0                                        [régulée par]
# 1                [est pollinisateur de, pollinisateur]
# 2                                                 None
# 3    [se qualifier pour l'événement, qualifié pour ...
# 4                      [idée de, la représentation de]
# ..                                                 ...
# 729               [éditeur en chef, rédacteur en chef]
# 730                                               None
# 731                                [Origine du revenu]
# 732              [début de saison, la saison commence]
# 733                                               None
#
#                                       en_subword_alias  \
# 0                      [by, from, governed, regulated]
# 1                               [of, from, pollinator]
# 2                     [to, view, offer, on, a, offers]
# 3    [event, qualifies, the, for, competition, qual...
# 4                     [representation, of, idea, from]
# ..                                                 ...
# 729         [boss, editorial, editor, on, responsible]
# 730                    [of, time, closing, from, hour]
# 731          [of, from, origin, source, income, entry]
# 732          [of, beginning, season, from, the, start]
# 733       [link, postsynaptic, connection, Connection]
#
#                                      de_subword_alias  \
# 0                          [regiert, durch, geregelt]
# 1                               [von, Bestäuber, ist]
# 2          [bietet an, zu, an, ein, Ansicht, Angebot]
# 3             [zum, Veranstaltung, qualifiziert, der]
# 4                                  [von, Darstellung]
# ..                                                ...
# 729  [Boss, verantwortlich, an, Editor, redaktionell]
# 730                    [Schließen, von, Zeit, Stunde]
# 731                 [Einkommen, von, Quelle, Eintrag]
# 732           [von, Anfang, Jahreszeit, der, beginnt]
# 733                      [Verbindung, postsynaptisch]
#
#                                       es_subword_alias  \
# 0                    [regulado, desde, por, gobernado]
# 1                         [de, desde, es, polinizador]
# 2              [seguro, oferta, en, vista, a, ofertas]
# 3    [competencia, por, calificado, para, evento, c...
# 4                    [desde, de, representación, idea]
# ..                                                 ...
# 729                           [editorial, responsable]
# 730                               [de, hora, clausura]
# 731                      [de, fuente, ingreso, origen]
# 732              [inicio, los, de, empieza, temporada]
# 733                  [postsináptico, Enlace, conexión]
#
#                                       fr_subword_alias
# 0                 [à partir de, pour, réglementé, par]
# 1                [pollinisateur, à partir de, de, est]
# 2                         [au, pour, des offres, voir]
# 3    [se qualifie, la, pour, un événement, qualifié...
# 4              [à partir de, de, représentation, idée]
# ..                                                 ...
# 729                                [au, éditeur, chef]
# 730             [heure, à partir de, fermeture, temps]
# 731  [à partir de, de, la source, origine, le reven...
# 732          [début, départs, à partir de, saison, la]
# 733      [Connexion, lien, post-synaptique, connexion]
#
# [734 rows x 18 columns]

# %%
relations.to_json('properties_w_aliases_full.json')
